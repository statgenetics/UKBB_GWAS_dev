# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/tstv_by_qual.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/tstv_by_qual.0.png (17.7 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/substitutions.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/substitutions.0.png (14.0 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/tstv_by_sample.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/tstv_by_sample.0.png (22.5 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/hets_by_sample.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/hets_by_sample.0.png (23.9 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/snps_by_sample.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/snps_by_sample.0.png (23.3 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/indels_by_sample.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/indels_by_sample.0.png (12.5 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/singletons_by_sample.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/singletons_by_sample.0.png (16.7 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/dp_by_sample.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/dp_by_sample.0.png (23.5 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/depth.0.png
# Out:
# > /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/depth.0.png (26.5 KiB):

# %%
%preview -n /mnt/mfs/statgen/UKBiobank/data/exome_files/project_VCF/testing_bcftools/hwe.0.png
# Out:

# %% [markdown]
# ## Determine how many individuals in the total sample in which they have at least 1 phenotype (cases)

# %% [markdown]
# ### Mega-analysis

# %%
f3393_220K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_aid_f3393_expandedwhite_6436cases_96601ctrl_PC1_2.tsv', header=T)

# %%
f2247_220K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2.tsv', header=T)

# %%
f2257_220K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_noise_f2257_expandedwhite_65660cases_96601ctrl_PC1_2.tsv', header=T)

# %%
mix_200K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Combined_f2247_f2257_expandedwhite_38410cases_96601ctrl_PC1_2.tsv', header=T)

# %%
head(f3393_220K)
# Out:
#   FID     IID     sex f3393 age PC1           PC2
# 1 1000078 1000078 1   0     60   0.0070245643  0.009614509
# 2 1000081 1000081 0   0     67  -0.1198316925 -0.012082002
# 3 1000224 1000224 1   0     58   0.0022356173 -0.012769062
# 4 1000236 1000236 0   0     70  -0.0029660149  0.016806466
# 5 1000255 1000255 1   0     61   0.0042133323  0.002938649
# 6 1000291 1000291 0   0     62   0.0003901785  0.001768452

# %%
df1 <- merge(f3393_220K , f2247_220K, by = c("FID", "IID"), all = TRUE)

# %%
head(df1)
# Out:
#   FID     IID     sex.x f3393 age.x PC1.x        PC2.x        sex.y f2247 age.y
# 1 1000078 1000078  1     0    60     0.007024564  0.009614509 1     0     60
# 2 1000081 1000081  0     0    67    -0.119831692 -0.012082002 0     0     67
# 3 1000198 1000198 NA    NA    NA              NA           NA 1     1     41
# 4 1000224 1000224  1     0    58     0.002235617 -0.012769062 1     0     58
# 5 1000236 1000236  0     0    70    -0.002966015  0.016806466 0     0     70
# 6 1000255 1000255  1     0    61     0.004213332  0.002938649 1     0     61
#   PC1.y        PC2.y
# 1  0.006798619 -0.010207360
# 2 -0.119846087  0.012268567
# 3  0.009587437  0.021359387
# 4  0.002120266  0.012205531
# 5 -0.002484574 -0.016160010
# 6  0.004330577 -0.003459381

# %%
df2 <- merge(df1 , f2257_220K, by = c("FID", "IID"), all = TRUE)

# %%
df3 <- merge(df2, mix_200K , by = c("FID", "IID"), all = TRUE )
# Out:
# Warning message in merge.data.frame(df2, mix_200K, by = c("FID", "IID"), all = TRUE):
# “column names ‘sex.x’, ‘age.x’, ‘PC1.x’, ‘PC2.x’, ‘sex.y’, ‘age.y’, ‘PC1.y’, ‘PC2.y’ are duplicated in the result”

# %%
head(df3)
# Out:
#   FID     IID     sex.x f3393 age.x PC1.x        PC2.x        sex.y f2247 age.y
# 1 1000035 1000035 NA    NA    NA              NA           NA NA    NA    NA
# 2 1000078 1000078  1     0    60     0.007024564  0.009614509  1     0    60
# 3 1000081 1000081  0     0    67    -0.119831692 -0.012082002  0     0    67
# 4 1000198 1000198 NA    NA    NA              NA           NA  1     1    41
# 5 1000224 1000224  1     0    58     0.002235617 -0.012769062  1     0    58
# 6 1000236 1000236  0     0    70    -0.002966015  0.016806466  0     0    70
#   ... sex.x f2257 age.x PC1.x        PC2.x       sex.y f2247_f2257 age.y
# 1 ... 0     1     63    -0.019547873  0.03228784 NA    NA          NA
# 2 ... 1     0     60    -0.006863951 -0.01006661  1     0          60
# 3 ... 0     0     67     0.120157139  0.01217858  0     0          67
# 4 ... 1     1     41    -0.009742730  0.02152371  1     1          41
# 5 ... 1     0     58    -0.002435071  0.01195639  1     0          58
# ...

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
full <- df3 %>% select("FID", "IID", "f3393", "f2247", "f2257", "f2247_f2257")

# %%
head(full)
# Out:
#   FID     IID     f3393 f2247 f2257 f2247_f2257
# 1 1000035 1000035 NA    NA    1     NA
# 2 1000078 1000078  0     0    0      0
# 3 1000081 1000081  0     0    0      0
# 4 1000198 1000198 NA     1    1      1
# 5 1000224 1000224  0     0    0      0
# 6 1000236 1000236  0     0    0      0

# %%
full %>% filter(f3393==1 | f2247==1 | f2257==1 | f2247_f2257==1 )
# Out:
#       FID     IID     f3393 f2247 f2257 f2247_f2257
# 1     1000035 1000035 NA    NA     1    NA
# 2     1000198 1000198 NA     1     1     1
# 3     1000304 1000304 NA    NA     1    NA
# 4     1000396 1000396 NA     1     1     1
# 5     1000494 1000494 NA     1     1     1
# 6     1000551 1000551 NA    NA     1    NA
# 7     1000817 1000817 NA    NA     1    NA
# 8     1000988 1000988 NA    NA     1    NA
# 9     1001076 1001076 NA     1     1     1
# 10    1001080 1001080 NA    NA     1    NA
# 11    1001123 1001123 NA     1     1     1
# 12    1001140 1001140 NA    NA     1    NA
# 13    1001196 1001196 NA     1     1     1
# 14    1001316 1001316 NA     1    NA    NA
# 15    1001373 1001373 NA     1     1     1
# 16    1001384 1001384  1     1     1     1
# 17    1001471 1001471 NA    NA     1    NA
# 18    1001577 1001577 NA     1     1     1
# 19    1001636 1001636 NA     1     1     1
# 20    1001672 1001672 NA    NA     1    NA
# 21    1001775 1001775 NA     1     1     1
# ...

# %%
full %>% filter(f3393==1 & f2247==1 & f2257==1 & f2247_f2257==1 )

# %% [markdown]
# ### Discovery

# %%
f3393_150K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_aid_f3393_expandedwhite_78848ind_150K.tsv', header=T)

# %%
f2247_150K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_107507ind_150K.tsv', header=T)

# %%
f2257_150K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_noise_f2257_expandedwhite_123538ind_150K.tsv', header=T)

# %%
mix_150K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Combined_f2247_f2257_expandedwhite_102133ind_150K.tsv', header=T)

# %%
dis1 <- merge(f3393_150K , f2247_150K, by = c("FID", "IID"), all = TRUE)

# %%
dis2 <- merge(dis1 , f2257_150K, by = c("FID", "IID"), all = TRUE)

# %%
dis3 <- merge(dis2, mix_150K , by = c("FID", "IID"), all = TRUE )
# Out:
# Warning message in merge.data.frame(dis2, mix_150K, by = c("FID", "IID"), all = TRUE):
# “column names ‘sex.x’, ‘age.x’, ‘PC1.x’, ‘PC2.x’, ‘sex.y’, ‘age.y’, ‘PC1.y’, ‘PC2.y’ are duplicated in the result”

# %%
disfull <- dis3 %>% select("FID", "IID", "f3393", "f2247", "f2257", "f2247_f2257")

# %%
head(disfull)
# Out:
#   FID     IID     f3393 f2247 f2257 f2247_f2257
# 1 1000035 1000035 NA    NA    1     NA
# 2 1000081 1000081  0     0    0      0
# 3 1000198 1000198 NA     1    1      1
# 4 1000224 1000224  0     0    0      0
# 5 1000255 1000255  0     0    0      0
# 6 1000291 1000291  0     0    0      0

# %%
disfull %>% filter(f3393==1 | f2247==1 | f2257==1 | f2247_f2257==1 )
# Out:
#       FID     IID     f3393 f2247 f2257 f2247_f2257
# 1     1000035 1000035 NA    NA    1     NA
# 2     1000198 1000198 NA     1    1      1
# 3     1000304 1000304 NA    NA    1     NA
# 4     1000396 1000396 NA     1    1      1
# 5     1000494 1000494 NA     1    1      1
# 6     1000551 1000551 NA    NA    1     NA
# 7     1000817 1000817 NA    NA    1     NA
# 8     1000988 1000988 NA    NA    1     NA
# 9     1001076 1001076 NA     1    1      1
# 10    1001080 1001080 NA    NA    1     NA
# 11    1001123 1001123 NA     1    1      1
# 12    1001196 1001196 NA     1    1      1
# 13    1001384 1001384  1     1    1      1
# 14    1001471 1001471 NA    NA    1     NA
# 15    1001577 1001577 NA     1    1      1
# 16    1001672 1001672 NA    NA    1     NA
# 17    1001775 1001775 NA     1    1      1
# 18    1001789 1001789 NA    NA    1     NA
# 19    1002023 1002023 NA    NA    1     NA
# 20    1002040 1002040 NA    NA    1     NA
# 21    1002230 1002230 NA     1    1      1
# ...

# %% [markdown]
# ### Replication

# %%
f3393_50K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_aid_f3393_expandedwhite_24189ind_50K.tsv', header=T)

# %%
f2247_50K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_34596ind_50K.tsv', header=T)

# %%
f2257_50K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Hearing_noise_f2257_expandedwhite_38723ind_50K.tsv', header=T)

# %%
mix_50K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/090321_UKBB_Combined_f2247_f2257_expandedwhite_32878ind_50K.tsv', header=T)

# %%
rep1 <- merge(f3393_50K , f2247_50K, by = c("FID", "IID"), all = TRUE)

# %%
rep2 <- merge(rep1 , f2257_50K, by = c("FID", "IID"), all = TRUE)

# %%
rep3 <- merge(rep2, mix_50K , by = c("FID", "IID"), all = TRUE )
# Out:
# Warning message in merge.data.frame(rep2, mix_50K, by = c("FID", "IID"), all = TRUE):
# “column names ‘sex.x’, ‘age.x’, ‘PC1.x’, ‘PC2.x’, ‘sex.y’, ‘age.y’, ‘PC1.y’, ‘PC2.y’ are duplicated in the result”

# %%
repfull <- rep3 %>% select("FID", "IID", "f3393", "f2247", "f2257", "f2247_f2257")

# %%
head(repfull)
# Out:
#   FID     IID     f3393 f2247 f2257 f2247_f2257
# 1 1000078 1000078 0     0     0     0
# 2 1000236 1000236 0     0     0     0
# 3 1000331 1000331 0     0     0     0
# 4 1000530 1000530 0     0     0     0
# 5 1000683 1000683 0     0     0     0
# 6 1000992 1000992 0     0     0     0

# %%
repfull %>% filter(f3393==1 | f2247==1 | f2257==1 | f2247_f2257==1 )
# Out:
#       FID     IID     f3393 f2247 f2257 f2247_f2257
# 1     1001140 1001140 NA    NA     1    NA
# 2     1001316 1001316 NA     1    NA    NA
# 3     1001373 1001373 NA     1     1     1
# 4     1001636 1001636 NA     1     1     1
# 5     1001811 1001811 NA    NA     1    NA
# 6     1001897 1001897 NA     1     1     1
# 7     1002268 1002268 NA     1     1     1
# 8     1002548 1002548  1     1     1     1
# 9     1002900 1002900 NA     1     1     1
# 10    1003275 1003275 NA    NA     1    NA
# 11    1003772 1003772 NA     1    NA    NA
# 12    1004146 1004146 NA    NA     1    NA
# 13    1004178 1004178 NA    NA     1    NA
# 14    1004279 1004279 NA    NA     1    NA
# 15    1004461 1004461 NA     1     1     1
# 16    1005088 1005088 NA    NA     1    NA
# 17    1005237 1005237 NA    NA     1    NA
# 18    1005526 1005526 NA     1     1     1
# 19    1005827 1005827 NA     1    NA    NA
# 20    1005849 1005849 NA     1     1     1
# 21    1006174 1006174 NA     1     1     1
# ...

# %% [markdown]
# ### Imputed data 300K

# %%
f3393_im300K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/100521_UKBB_Hearing_aid_f3393_expandedwhite_9165cases_141007ctrl_300k_PC1_PC2', header=T)

# %%
f2247_im300K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/100521_UKBB_Hearing_difficulty_f2247_expandedwhite_64953cases_141007ctrl_300k_PC1_PC2', header=T)

# %%
f2257_im300K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/100521_UKBB_Hearing_noise_f2257_expandedwhite_95794cases_141007ctrl_300k_PC1_PC2', header=T)

# %%
mix_im300K <- read.table('~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/100521_UKBB_Combined_f2247_f2257_expandedwhite_54853cases_141007ctrl_300k_PC1_PC2', header=T)

# %%
im1 <- merge(f3393_im300K , f2247_im300K, by = c("FID", "IID"), all = TRUE)

# %%
im2 <- merge(im1 , f2257_im300K, by = c("FID", "IID"), all = TRUE)

# %%
im3 <- merge(im2, mix_im300K , by = c("FID", "IID"), all = TRUE )
# Out:
# Warning message in merge.data.frame(im2, mix_im300K, by = c("FID", "IID"), all = TRUE):
# “column names ‘sex.x’, ‘age.x’, ‘PC1.x’, ‘PC2.x’, ‘sex.y’, ‘age.y’, ‘PC1.y’, ‘PC2.y’ are duplicated in the result”

# %%
imfull <- im3 %>% select("FID", "IID", "f3393", "f2247", "f2257", "f2247_f2257")

# %%
head(imfull)
# Out:
#   FID     IID     f3393 f2247 f2257 f2247_f2257
# 1 1000022 1000022 NA     1     1     1
# 2 1000046 1000046 NA    NA     1    NA
# 3 1000054 1000054 NA    NA     1    NA
# 4 1000063 1000063  0     0     0     0
# 5 1000090 1000090 NA     1    NA    NA
# 6 1000105 1000105 NA    NA     1    NA

# %%
imfull %>% filter(f3393==1 | f2247==1 | f2257==1 | f2247_f2257==1 )
# Out:
#        FID     IID     f3393 f2247 f2257 f2247_f2257
# 1      1000022 1000022 NA     1     1     1
# 2      1000046 1000046 NA    NA     1    NA
# 3      1000054 1000054 NA    NA     1    NA
# 4      1000090 1000090 NA     1    NA    NA
# 5      1000105 1000105 NA    NA     1    NA
# 6      1000112 1000112  1     1     1     1
# 7      1000164 1000164 NA    NA     1    NA
# 8      1000170 1000170 NA     1     1     1
# 9      1000203 1000203 NA     1     1     1
# 10     1000318 1000318 NA    NA     1    NA
# 11     1000450 1000450 NA    NA     1    NA
# 12     1000482 1000482 NA     1     1     1
# 13     1000549 1000549 NA     1     1     1
# 14     1000728 1000728 NA     1     1     1
# 15     1000745 1000745 NA     1    NA    NA
# 16     1000767 1000767 NA     1     1     1
# 17     1000780 1000780 NA    NA     1    NA
# 18     1000799 1000799 NA    NA     1    NA
# 19     1000800 1000800 NA    NA     1    NA
# 20     1000933 1000933 NA     1     1     1
# ...

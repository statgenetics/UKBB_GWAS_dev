# %%
import pandas as pd
import numpy as np
import csv

columns= ['Chr', "Start", "Ref", "Alt", "Func.refGene", "Gene.refGene", "ExonicFunc.refGene", "Func.refGeneWithVer","Gene.refGeneWithVer", "GeneDetail.refGeneWithVer","ExonicFunc.refGeneWithVer","AAChange.refGeneWithVer","avsnp150", "gnomad312_AF_nfe", "AF_nfe", "CADD_phred", "dbscSNV_ADA_SCORE", "dbscSNV_RF_SCORE"]
df_real = pd.read_csv('/home/dmc2245/UKBiobank/results/ukb23157_500Kexomes_annovar/chr22.hg38.hg38_multianno.csv', header=0, usecols=columns,na_values='.', index_col=False)
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %%
df_real
# Out:
#         Chr     Start Ref Alt    Func.refGene Gene.refGene ExonicFunc.refGene  \
# 0        22  15528067   C   T        upstream       OR11H1                NaN
# 1        22  15528094   A   G        upstream       OR11H1                NaN
# 2        22  15528096   G   A        upstream       OR11H1                NaN
# 3        22  15528109   T   G        upstream       OR11H1                NaN
# 4        22  15528133   A   G        upstream       OR11H1                NaN
# ...     ...       ...  ..  ..             ...          ...                ...
# 613848   22  50782393   C   T  ncRNA_intronic    RPL23AP82                NaN
# 613849   22  50782396   A   C  ncRNA_intronic    RPL23AP82                NaN
# 613850   22  50782398   C   T  ncRNA_intronic    RPL23AP82                NaN
# 613851   22  50782404   C   A  ncRNA_intronic    RPL23AP82                NaN
# 613852   22  50782407   C   T  ncRNA_intronic    RPL23AP82                NaN
#
# ...

# %%
print(df_real['Func.refGeneWithVer'].unique())
# Out:
# ['upstream' 'exonic' 'downstream' 'UTR5' 'splicing' 'intronic'
#  'ncRNA_intronic' 'intergenic' 'UTR3' 'exonic;splicing' 'ncRNA_exonic'
#  'UTR5;UTR3' 'upstream;downstream' 'ncRNA_exonic;splicing'
#  'ncRNA_splicing']

# %%
print(df_real['ExonicFunc.refGeneWithVer'].unique())
# Out:
# [nan 'nonsynonymous SNV' 'stopgain' 'synonymous SNV'
#  'frameshift substitution' 'stoploss' 'nonframeshift substitution'
#  'startloss' 'unknown']

# %%
data_crosstab = pd.crosstab(df_real['Func.refGeneWithVer'],
                            df_real['Func.refGene'], 
                               margins = False)

# %%
data_crosstab
# Out:
# Func.refGene            UTR3   UTR5  UTR5;UTR3  downstream  exonic  \
# Func.refGeneWithVer
# UTR3                   29895      0          0           0       0
# UTR5                       0  21401          0           0       0
# UTR5;UTR3                  0      0         93           0       0
# downstream                 0      0          0         352       0
# exonic                     0      0          0           0  219141
# exonic;splicing            0      0          0           0       0
# intergenic                 0      0          0           0       0
# intronic                   0      0          0           0       0
# ncRNA_exonic               0      0          0           0       0
# ncRNA_exonic;splicing      0      0          0           0       0
# ncRNA_intronic             0      0          0           0       0
# ncRNA_splicing             0      0          0           0       0
# splicing                   0      0          0           0       0
# ...

# %%
df_real[(df_real["Func.refGene"]=="exonic;splicing") & (df_real["Func.refGeneWithVer"]=="exonic")]
# Out:
#         Chr     Start Ref  ... CADD_phred dbscSNV_ADA_SCORE dbscSNV_RF_SCORE
# 680      22  15690701   G  ...      14.27               NaN              NaN
# 681      22  15690702   C  ...      23.70               NaN              NaN
# 682      22  15690708   A  ...      25.20            0.9284            0.698
# 683      22  15690709   G  ...        NaN               NaN              NaN
# 748      22  15695648   G  ...       7.02               NaN              NaN
# ...     ...       ...  ..  ...        ...               ...              ...
# 613737   22  50777972   C  ...      28.60               NaN              NaN
# 613738   22  50777975   C  ...      23.80               NaN              NaN
# 613739   22  50777977   T  ...      12.86               NaN              NaN
# 613803   22  50782189   T  ...      32.00            0.9992            0.920
# 613804   22  50782192   A  ...      25.20               NaN              NaN
#
# [30178 rows x 18 columns]

# %%
df_real[df_real["Func.refGeneWithVer"]=="splicing"]
# Out:
#         Chr     Start Ref  ... CADD_phred dbscSNV_ADA_SCORE dbscSNV_RF_SCORE
# 684      22  15690711   T  ...      25.00               NaN              NaN
# 779      22  15700076   A  ...      21.60               NaN              NaN
# 876      22  15708092   C  ...      13.76               NaN              NaN
# 916      22  15709781   G  ...      15.60               NaN              NaN
# 973      22  15719780   T  ...        NaN               NaN              NaN
# ...     ...       ...  ..  ...        ...               ...              ...
# 613415   22  50769554   T  ...      20.30             0.027            0.000
# 613487   22  50769904   C  ...      33.00             1.000            0.890
# 613520   22  50770017   C  ...      33.00             1.000            0.928
# 613652   22  50776669   C  ...      32.00             1.000            0.776
# 613845   22  50782349   T  ...        NaN             0.000            0.014
#
# [3433 rows x 18 columns]

# %%
df_refGene=df[(df["Func.refGeneWithVer"]=="exonic")]

# %%
df_refGene.to_csv('/home/dmc2245/UKBiobank/results/ukb23157_500Kexomes_annovar/test_chr22_exonic.hg38.hg38_multianno.csv', index=False, header=True, sep="\t")

# %%
gene = df_refGene["Gene.refGeneWithVer"].str.split(";", n = 1, expand = True)

# %%
search_char = ';'

# %%
column_to_check = 'Gene.refGeneWithVer'

# %%
subset_df = df_refGene[df_refGene[column_to_check].str.contains(search_char)]

# %%
subset_df['Gene.refGene'].unique()

# %%
df_refGene["Gene.refGeneWithVer"].head(100)

# %%
gene[1].dropna()

# %%
df_refGene.iloc[501220:501224,]

# %%
df_splice=df[(df["Func.refGeneWithVer"]=="splicing")]

# %%
df_splice[df_splice[column_to_check].str.contains(search_char)]

# %%
df["Gene"]= df1[0]

# %%
df_refGene['Func.refGene'].equals(df_refGene['Func.refGeneWithVer'])

# %%
print(df_real['Func.refGene'].unique())
# Out:
# ['upstream' 'exonic' 'downstream' 'UTR5' 'exonic;splicing' 'splicing'
#  'intronic' 'ncRNA_intronic' 'intergenic' 'UTR3' 'ncRNA_exonic'
#  'UTR5;UTR3' 'upstream;downstream' 'ncRNA_exonic;splicing'
#  'ncRNA_splicing']

# %%
print(df_real['ExonicFunc.refGene'].unique())
# Out:
# [nan 'nonsynonymous SNV' 'stopgain' 'synonymous SNV'
#  'frameshift substitution' 'stoploss' 'nonframeshift substitution'
#  'startloss' 'unknown']

# %%
print(df_real['ExonicFunc.refGeneWithVer'].unique())
# Out:
# [nan 'nonsynonymous SNV' 'stopgain' 'synonymous SNV'
#  'frameshift substitution' 'stoploss' 'nonframeshift substitution'
#  'startloss' 'unknown']

# %%
print(df_real['Func.refGeneWithVer'].unique())
# Out:
# [0]:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# script_6185675315124266311 in <module>
# ----> print(df_real['Func.refGeneWithVer'].unique())
#
#
# NameError: name 'df_real' is not defined

# %%
import pandas as pd
    import numpy as np
    import csv

    columns= ['Chr', "Start", "Ref", "Alt", "Gene.refGene", "ExonicFunc.refGene", "avsnp150", "AF_nfe_exome"]
    df = pd.read_csv('${_input}', compression='gzip', header=0, dtype='string', usecols=columns, index_col=False)

    # Get the refGene definition

    # Get only the first gene name present
    df1 = df["Gene.refGene"].str.split(";", n = 1, expand = True)
    df["Gene"]= df1[0]

    # Get the variants in the chr, pos, ref, alt format

    if ${rsid} == True:
        df["varID"] = df.avsnp150
        tmp = df[~df["avsnp150"].str.startswith('rs', na=False)]
        tmp["varID"] = tmp.Chr.str.cat(others=[tmp.Start, tmp.Ref, tmp.Alt], sep=':')
        df[~df["avsnp150"].str.startswith('rs', na=False)] = tmp
    else:
        df["varID"] = df.Chr.str.cat(others=[df.Start, df.Ref, df.Alt], sep=':')

    # Drop duplicated variants
    df2=df.drop_duplicates(subset='varID', keep='first')
    df2=df2.replace({'AF_nfe_exome':'.'},'0.0')
    df2['AF_nfe_freq'] = df2['AF_nfe_exome'].astype(float)
    # Find duplicated genes in the file
    genes = dict()
    def find_chrom(row):
        if row["Gene"] not in genes.keys():
            genes[row["Gene"]] = set()
        genes[row["Gene"]].add(row["Chr"])
    df2[["Chr", "Gene"]].apply(find_chrom, axis=1)
    
    # Rename the duplicated genes adding the chromosome number to make them unique
    def rename_chrom(row):
        if len(genes[row["Gene"]]) > 1:
            return f'{row["Gene"]}-{row["Chr"]}'
        return row["Gene"]
    df2["Gene"] = df2.apply(rename_chrom, axis=1)
    
    # Match annovar annotations with regenie_burden needs 
    annotation_mappings = {"nonsynonymous":'missense', 
    "synonymous":'synonymous',
    "frameshift":'LoF',
    "stopgain":'LoF', 
    "stoploss":'LoF',
    "startloss":'LoF',
    "nonframeshift":"inframe"
    }
    
    def annotation(x):
        x = x.strip().split()
        for i in x:
            if i in annotation_mappings.keys():
                return annotation_mappings[i]
        return 'other'
    df2["anno_cat"] = df2["ExonicFunc.refGene"].apply(annotation)
    
    # Create the anno_file and add chr in the beggining to match the plink bim files
    with open('${_output[0]}', 'w') as output:
        for row in df2[["varID", "Gene", "anno_cat"]].to_numpy():
            if ${rsid} == True:
                output.write(f'{row[0]} {row[1]} {row[2]}\n')
            else: 
                output.write(f'chr{row[0]} {row[1]} {row[2]}\n')
    # Create the aaf-file for allele frequencies using gnomAD dataset
    with open('${_output[1]}', 'w') as output:
        for row in df2[["varID", "AF_nfe_freq"]].to_numpy():
            if ${rsid} == True:
                output.write(f'{row[0]} {row[1]}\n')
            else: 
                output.write(f'chr{row[0]} {row[1]}\n')
    
    # Create the set_list_file grouping variants per gene. Format gene chrom start varIDs
    grouped = df2.groupby(["Gene"])
    with open('${_output[2]}', 'w') as output:
        for key, values in grouped:
            s = []
            start = values["Start"].min()
            chrom = values["Chr"].min()
            def addToS(x, s):
                if ${rsid} == True:
                    s.append(str(x["varID"]))
                else:
                    s.append(str("chr") + str(x["varID"]))                   
            fxn = lambda x: addToS(x, s)
            values.apply(fxn, axis=1)
            output.write(key + " " + chrom + " " + start + " " + ",".join(s) + "\n")

# %% [markdown]
# ## Look into the CADD database and subset only for chr22 to create a test dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/chr22.CADD.tsv', sep=' ', header=None)

# %%
df

# %%
import pandas as pd
import numpy as np
import csv

#Read the columns we need
columns= ['Chr', "Start", "End","Ref", "Alt", "Func.refGene", "Gene.refGene", "GeneDetail.refGene", "ExonicFunc.refGene", "AAChange.refGene","Func.refGeneWithVer","Gene.refGeneWithVer", "GeneDetail.refGeneWithVer","ExonicFunc.refGeneWithVer","AAChange.refGeneWithVer","avsnp150", "gnomad312_AF_nfe", "AF_nfe", "CADD_phred", "dbscSNV_ADA_SCORE", "dbscSNV_RF_SCORE", "Otherinfo1"]
df = pd.read_csv('/home/dmc2245/UKBiobank/results/ukb23157_500Kexomes_annovar/chr22.hg38.hg38_multianno.csv',header=0,usecols=columns,na_values='.',index_col=False)

# %%
df

# %%
import pandas as pd

# Sample DataFrame
data = {
    'chr':['22', '22', '22','22'],
    'start':['44862583','44862593','23958696','42126648'],
    'ref': ['A','T','G','C'],
    'alt': ['T','C','G','A'],
    'Func.refGeneWithVer': ['exonic', 'intronic', 'exonic', 'exonic;splicing'],
    'Gene.refGeneWithVer': ['GeneA', 'GeneB', 'GeneA;GeneA;GeneC', 'GeneB;GeneD'],
    'ExonicFunc.refGeneWithVer': ['nonsynonymous SNV', 'synonymous SNV', 'stopgain', 'nonsynonymous SNV'],
    'AAChange.refGeneWithVer': ['GeneA:NM1:var1', 'GeneB:NM2:var2', 'GeneA:NM3:var3,GeneC:NM4:var4', 'GeneB:NM5:var5,GeneD:NM6:var6'],
    'Otherinfo1': ['var1_info', 'var2_info', 'var3_info', 'var5_info']
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   chr     start ref alt Func.refGeneWithVer Gene.refGeneWithVer  \
# 0  22  44862583   A   T              exonic               GeneA
# 1  22  44862593   T   C            intronic               GeneB
# 2  22  23958696   G   G              exonic   GeneA;GeneA;GeneC
# 3  22  42126648   C   A     exonic;splicing         GeneB;GeneD
#
#   ExonicFunc.refGeneWithVer        AAChange.refGeneWithVer Otherinfo1
# 0         nonsynonymous SNV                 GeneA:NM1:var1  var1_info
# 1            synonymous SNV                 GeneB:NM2:var2  var2_info
# 2                  stopgain  GeneA:NM3:var3,GeneC:NM4:var4  var3_info
# 3         nonsynonymous SNV  GeneB:NM5:var5,GeneD:NM6:var6  var5_info

# %%
# Split 'Gene.refGeneWithVer' by ';' and create a set of unique genes for each row
df['UniqueGenes'] = df['Gene.refGeneWithVer'].str.split(';').apply(set)

# %%
df
# Out:
#   chr     start ref alt Func.refGeneWithVer Gene.refGeneWithVer  \
# 0  22  44862583   A   T              exonic               GeneA
# 1  22  44862593   T   C            intronic               GeneB
# 2  22  23958696   G   G              exonic   GeneA;GeneA;GeneC
# 3  22  42126648   C   A     exonic;splicing         GeneB;GeneD
#
#   ExonicFunc.refGeneWithVer        AAChange.refGeneWithVer Otherinfo1  \
# 0         nonsynonymous SNV                 GeneA:NM1:var1  var1_info
# 1            synonymous SNV                 GeneB:NM2:var2  var2_info
# 2                  stopgain  GeneA:NM3:var3,GeneC:NM4:var4  var3_info
# 3         nonsynonymous SNV  GeneB:NM5:var5,GeneD:NM6:var6  var5_info
#
#       UniqueGenes
# 0         {GeneA}
# 1         {GeneB}
# 2  {GeneA, GeneC}
# 3  {GeneD, GeneB}

# %%
# Function to extract gene names
def extract_gene_names(row):
    gene_names = []
    values = row['AAChange.refGeneWithVer'].split(',')
    for value in values:
        gene_info = value.split(':')[0:2]
        gene_name = ":".join(gene_info)
        gene_names.append(gene_name)
    return ",".join(gene_names)

# %%
# Apply the function to create a new column with extracted gene names
df['GeneNames'] = df.apply(extract_gene_names, axis=1)

# %%
df
# Out:
#   Func.refGeneWithVer Gene.refGeneWithVer ExonicFunc.refGeneWithVer  \
# 0              exonic               GeneA         nonsynonymous SNV
# 1            intronic               GeneB            synonymous SNV
# 2              exonic   GeneA;GeneA;GeneC                  stopgain
# 3     exonic;splicing         GeneB;GeneD         nonsynonymous SNV
#
#          AAChange.refGeneWithVer Otherinfo1     UniqueGenes  \
# 0                 GeneA:NM1:var1  var1_info         {GeneA}
# 1                 GeneB:NM2:var2  var2_info         {GeneB}
# 2  GeneA:NM3:var3,GeneC:NM4:var4  var3_info  {GeneA, GeneC}
# 3  GeneB:NM5:var5,GeneD:NM6:var6  var5_info  {GeneD, GeneB}
#
#              GeneNames
# 0            GeneA:NM1
# 1            GeneB:NM2
# 2  GeneA:NM3,GeneC:NM4
# 3  GeneB:NM5,GeneD:NM6

# %%
# Function to group variants based on conditions
def group_variants(row):
    if 'exonic' in row['Func.refGeneWithVer']:
        gene_names = row['GeneNames'].split(',')
        if len(gene_names) == 1:
            return ":".join([gene_names[0], row['chr'], row['start'], row['ref'], row['alt']])
        else:
            return [":".join([gene, row['chr'], row['start'], row['ref'], row['alt']]) for gene in gene_names]
    elif 'exonic;splicing' in row['Func.refGeneWithVer']:
        gene_names = row['GeneNames'].split(',')
        if len(gene_names) == 1:
            return ":".join([gene_names[0], row['chr'], row['start'], row['ref'], row['alt']])
        else:
            return [":".join([gene, row['chr'], row['start'], row['ref'], row['alt']]) for gene in gene_names]

# %%
# Apply the function to create a 'GroupedVariants' column
df['GroupedVariants'] = df.apply(group_variants, axis=1)

# %%
df
# Out:
#   chr     start ref alt Func.refGeneWithVer Gene.refGeneWithVer  \
# 0  22  44862583   A   T              exonic               GeneA
# 1  22  44862593   T   C            intronic               GeneB
# 2  22  23958696   G   G              exonic   GeneA;GeneA;GeneC
# 3  22  42126648   C   A     exonic;splicing         GeneB;GeneD
#
#   ExonicFunc.refGeneWithVer        AAChange.refGeneWithVer Otherinfo1  \
# 0         nonsynonymous SNV                 GeneA:NM1:var1  var1_info
# 1            synonymous SNV                 GeneB:NM2:var2  var2_info
# 2                  stopgain  GeneA:NM3:var3,GeneC:NM4:var4  var3_info
# 3         nonsynonymous SNV  GeneB:NM5:var5,GeneD:NM6:var6  var5_info
#
#       UniqueGenes            GeneNames  \
# 0         {GeneA}            GeneA:NM1
# 1         {GeneB}            GeneB:NM2
# 2  {GeneA, GeneC}  GeneA:NM3,GeneC:NM4
# 3  {GeneD, GeneB}  GeneB:NM5,GeneD:NM6
#
#                                      GroupedVariants
# ...

# %%
# Iterate through the DataFrame
for index, row in df.iterrows():
    gene_names = row['Gene.refGeneWithVer'].split(';')
    variant_name = ":".join([row['chr'], row['start'], row['ref'], row['alt']])
    
    # Iterate through gene names and add the variant name to each gene
    for gene in gene_names:
        if gene in gene_variant_dict:
            gene_variant_dict[gene].append(variant_name)
        else:
            gene_variant_dict[gene] = [variant_name]

# %%
# Create a new DataFrame from the dictionary
result_df = pd.DataFrame(gene_variant_dict.items(), columns=['Gene','Variants'])

# Print the resulting DataFrame
print(result_df)
# Out:
#     Gene                                           Variants
# 0  GeneA  [22:44862583:A:T, 22:23958696:G:G, 22:23958696...
# 1  GeneB                 [22:44862593:T:C, 22:42126648:C:A]
# 2  GeneC                                  [22:23958696:G:G]
# 3  GeneD                                  [22:42126648:C:A]

# %%
result_df['Variants'] = result_df['Variants'].apply(lambda x: ",".join(x))

# %%
result_df
# Out:
#     Gene                                         Variants
# 0  GeneA  22:44862583:A:T,22:23958696:G:G,22:23958696:G:G
# 1  GeneB                  22:44862593:T:C,22:42126648:C:A
# 2  GeneC                                  22:23958696:G:G
# 3  GeneD                                  22:42126648:C:A

# %% [markdown]
# ### The real deal

# %%
# subset the dataframe to include only the records that we are interested in

condition1 = df_real['Func.refGene'].str.contains('exonic|splicing')
condition2 = df_real['Func.refGeneWithVer'].str.contains('exonic|splicing')

# Subset the DataFrame based on the conditions
subset_df = df_real[condition1 | condition2]

# %%
subset_df
# Out:
#         Chr     Start Ref Alt Func.refGene Gene.refGene ExonicFunc.refGene  \
# 6        22  15528165   C   A       exonic       OR11H1  nonsynonymous SNV
# 7        22  15528166   C   T       exonic       OR11H1  nonsynonymous SNV
# 8        22  15528177   C   T       exonic       OR11H1           stopgain
# 9        22  15528179   G   T       exonic       OR11H1  nonsynonymous SNV
# 10       22  15528182   C   T       exonic       OR11H1     synonymous SNV
# ...     ...       ...  ..  ..          ...          ...                ...
# 613841   22  50782338   G   C     splicing       RABL2B                NaN
# 613842   22  50782340   T   C     splicing       RABL2B                NaN
# 613843   22  50782342   T   C     splicing       RABL2B                NaN
# 613844   22  50782344   G   T     splicing       RABL2B                NaN
# 613845   22  50782349   T   C     splicing       RABL2B                NaN
#
#        Func.refGeneWithVer Gene.refGeneWithVer  \
# ...

# %%
subset_df['Func.refGene.exonic'] = subset_df['Func.refGene'].str.contains('exonic')
subset_df['Func.refGeneWithVer.exonic'] = subset_df['Func.refGeneWithVer'].str.contains('exonic')
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
subset_df.to_csv
# Out:
#         Chr     Start Ref Alt Func.refGene Gene.refGene ExonicFunc.refGene  \
# 6        22  15528165   C   A       exonic       OR11H1  nonsynonymous SNV
# 7        22  15528166   C   T       exonic       OR11H1  nonsynonymous SNV
# 8        22  15528177   C   T       exonic       OR11H1           stopgain
# 9        22  15528179   G   T       exonic       OR11H1  nonsynonymous SNV
# 10       22  15528182   C   T       exonic       OR11H1     synonymous SNV
# ...     ...       ...  ..  ..          ...          ...                ...
# 613841   22  50782338   G   C     splicing       RABL2B                NaN
# 613842   22  50782340   T   C     splicing       RABL2B                NaN
# 613843   22  50782342   T   C     splicing       RABL2B                NaN
# 613844   22  50782344   G   T     splicing       RABL2B                NaN
# 613845   22  50782349   T   C     splicing       RABL2B                NaN
#
#        Func.refGeneWithVer Gene.refGeneWithVer  \
# ...

# %%
subset_df['Func.refGene.splicing'] = subset_df['Func.refGene'].str.contains('splicing')
subset_df['Func.refGeneWithVer.splicing'] = subset_df['Func.refGeneWithVer'].str.contains('splicing')
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
subset_df
# Out:
#         Chr     Start Ref Alt Func.refGene Gene.refGene ExonicFunc.refGene  \
# 6        22  15528165   C   A       exonic       OR11H1  nonsynonymous SNV
# 7        22  15528166   C   T       exonic       OR11H1  nonsynonymous SNV
# 8        22  15528177   C   T       exonic       OR11H1           stopgain
# 9        22  15528179   G   T       exonic       OR11H1  nonsynonymous SNV
# 10       22  15528182   C   T       exonic       OR11H1     synonymous SNV
# ...     ...       ...  ..  ..          ...          ...                ...
# 613841   22  50782338   G   C     splicing       RABL2B                NaN
# 613842   22  50782340   T   C     splicing       RABL2B                NaN
# 613843   22  50782342   T   C     splicing       RABL2B                NaN
# 613844   22  50782344   G   T     splicing       RABL2B                NaN
# 613845   22  50782349   T   C     splicing       RABL2B                NaN
#
#        Func.refGeneWithVer Gene.refGeneWithVer  \
# ...

# %%
subset_df.to_csv('/home/dmc2245/UKBiobank/results/ukb23157_500Kexomes_annovar/testchr22.csv', sep=",", index=False, header=True)

# %%
df1 = subset_df["Gene.refGeneWithVer"].str.split(";", expand = True)

# %%
filtered_df =subset_df[subset_df['Gene.refGene'].str.count(';') >= 2]

# %%
filtered_df
# Out:
#         Chr     Start Ref Alt     Func.refGene  \
# 13351    22  17581361   C   T  exonic;splicing
# 13352    22  17581365   T   C  exonic;splicing
# 13353    22  17581369   T   A  exonic;splicing
# 13365    22  17581403   C   T  exonic;splicing
# 13366    22  17581405   T   C  exonic;splicing
# ...     ...       ...  ..  ..              ...
# 605171   22  50582563   G   C  exonic;splicing
# 605172   22  50582566   G   A  exonic;splicing
# 605173   22  50582566   G  GT  exonic;splicing
# 605174   22  50582566   G   C  exonic;splicing
# 605175   22  50582568   A   G  exonic;splicing
#
#                           Gene.refGene ExonicFunc.refGene Func.refGeneWithVer  \
# 13351   LOC101929372;SLC25A18;SLC25A18     synonymous SNV              exonic
# 13352   LOC101929372;SLC25A18;SLC25A18  nonsynonymous SNV              exonic
# 13353   LOC101929372;SLC25A18;SLC25A18  nonsynonymous SNV              exonic
# 13365   LOC101929372;SLC25A18;SLC25A18  nonsynonymous SNV              exonic
# ...

# %%
data_subset = pd.crosstab(subset_df['Func.refGeneWithVer'],
                            subset_df['Func.refGene'], 
                               margins = False)

# %%
data_subset
# Out:
# Func.refGene           exonic  exonic;splicing  ncRNA_exonic  \
# Func.refGeneWithVer
# UTR3                        0                0             0
# UTR5                        0                0             0
# UTR5;UTR3                   0                0             0
# exonic                 219141            30178             0
# exonic;splicing             0              120             0
# intronic                    0                0             0
# ncRNA_exonic                0                0          4265
# ncRNA_exonic;splicing       0                0             0
# ncRNA_intronic              0                0             0
# ncRNA_splicing              0                0             0
# splicing                    0                0             0
#
# Func.refGene           ncRNA_exonic;splicing  ncRNA_splicing  splicing
# Func.refGeneWithVer
# UTR3                                       0               0       259
# ...

# %%
for index, row in subset_df.iterrows():
    gene_names = row['Gene.refGeneWithVer'].split(';')

# %%
gene_names
# Out:
# ['RABL2B']

# %%
df_comb= subset_df[["Func.refGene", "Gene.refGene","ExonicFunc.refGene","Func.refGeneWithVer", "Gene.refGeneWithVer", "ExonicFunc.refGeneWithVer"]]

# %%
## Case 2
df_comb[(df_comb["Func.refGeneWithVer"]=="exonic") & (df_comb["Func.refGene"]=="exonic;splicing")]
# Out:
#            Func.refGene   Gene.refGene ExonicFunc.refGene Func.refGeneWithVer  \
# 680     exonic;splicing    POTEH;POTEH  nonsynonymous SNV              exonic
# 681     exonic;splicing    POTEH;POTEH           stopgain              exonic
# 682     exonic;splicing    POTEH;POTEH  nonsynonymous SNV              exonic
# 683     exonic;splicing    POTEH;POTEH           stopgain              exonic
# 748     exonic;splicing    POTEH;POTEH  nonsynonymous SNV              exonic
# ...                 ...            ...                ...                 ...
# 613737  exonic;splicing  RABL2B;RABL2B  nonsynonymous SNV              exonic
# 613738  exonic;splicing  RABL2B;RABL2B  nonsynonymous SNV              exonic
# 613739  exonic;splicing  RABL2B;RABL2B  nonsynonymous SNV              exonic
# 613803  exonic;splicing  RABL2B;RABL2B  nonsynonymous SNV              exonic
# 613804  exonic;splicing  RABL2B;RABL2B  nonsynonymous SNV              exonic
#
# ...

# %%
## Case 3
df_comb[(df_comb["Func.refGeneWithVer"]=="exonic;splicing") & (df_comb["Func.refGene"]=="exonic;splicing")]
# Out:
#            Func.refGene            Gene.refGene ExonicFunc.refGene  \
# 9591    exonic;splicing               ADA2;ADA2  nonsynonymous SNV
# 9592    exonic;splicing               ADA2;ADA2     synonymous SNV
# 33613   exonic;splicing         SLC25A1;SLC25A1     synonymous SNV
# 43393   exonic;splicing               UFD1;UFD1  nonsynonymous SNV
# 45466   exonic;splicing             CDC45;CDC45     synonymous SNV
# ...                 ...                     ...                ...
# 600759  exonic;splicing             ODF3B;ODF3B  nonsynonymous SNV
# 600760  exonic;splicing             ODF3B;ODF3B  nonsynonymous SNV
# 602588  exonic;splicing  CPT1B;CHKB-CPT1B;CPT1B  nonsynonymous SNV
# 613377  exonic;splicing           RABL2B;RABL2B  nonsynonymous SNV
# 613413  exonic;splicing           RABL2B;RABL2B     synonymous SNV
#
#        Func.refGeneWithVer Gene.refGeneWithVer ExonicFunc.refGeneWithVer
# 9591       exonic;splicing           ADA2;ADA2         nonsynonymous SNV
# ...

# %%
df_comb[(df_comb["Func.refGeneWithVer"]=="exonic;splicing") & (df_comb["Func.refGene"]=="exonic;splicing")]

# %%
# Define a function to classify consequences
def classify_consequence(row):
    if row['Func.refGeneWithVer'] == 'exonic' and 'nonsynonymous' in row['ExonicFunc.refGeneWithVer']:
        return 'missense'
    elif row['Func.refGeneWithVer'] == 'exonic' and 'synonymous' in row['ExonicFunc.refGeneWithVer']:
        return 'synonymous'
    elif row['Func.refGeneWithVer'] == 'exonic' and any(x in row['ExonicFunc.refGeneWithVer'] for x in ['frameshift', 'stopgain', 'stoploss', 'startloss']):
        return 'LoF'
    elif row['Func.refGeneWithVer'] == 'splicing':
        return 'LoF'
    elif row['Func.refGene'] == 'splicing' and 'splicing' not in row['Func.refGeneWithVer']:
        return 'splicing'
    else:
        return 'Unknown'

# %%
subset_df['Consequence'] = subset_df.apply(classify_consequence, axis=1)
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
subset_df
# Out:
#         Chr     Start Ref Alt Func.refGene Gene.refGene ExonicFunc.refGene  \
# 6        22  15528165   C   A       exonic       OR11H1  nonsynonymous SNV
# 7        22  15528166   C   T       exonic       OR11H1  nonsynonymous SNV
# 8        22  15528177   C   T       exonic       OR11H1           stopgain
# 9        22  15528179   G   T       exonic       OR11H1  nonsynonymous SNV
# 10       22  15528182   C   T       exonic       OR11H1     synonymous SNV
# ...     ...       ...  ..  ..          ...          ...                ...
# 613841   22  50782338   G   C     splicing       RABL2B                NaN
# 613842   22  50782340   T   C     splicing       RABL2B                NaN
# 613843   22  50782342   T   C     splicing       RABL2B                NaN
# 613844   22  50782344   G   T     splicing       RABL2B                NaN
# 613845   22  50782349   T   C     splicing       RABL2B                NaN
#
#        Func.refGeneWithVer Gene.refGeneWithVer  \
# ...

# %%
unknown=subset_df[subset_df['Consequence']=='Unknown']

# %%
print(subset_df['Func.refGeneWithVer'].unique())
# Out:
# ['exonic' 'splicing' 'intronic' 'ncRNA_intronic' 'UTR5' 'exonic;splicing'
#  'UTR3' 'ncRNA_exonic' 'ncRNA_exonic;splicing' 'ncRNA_splicing'
#  'UTR5;UTR3']

# %%
print(subset_df['Func.refGene'].unique())
# Out:
# ['exonic' 'exonic;splicing' 'splicing' 'ncRNA_exonic'
#  'ncRNA_exonic;splicing' 'ncRNA_splicing']

# %%
data_crosstab = pd.crosstab(unknown['Func.refGeneWithVer'],
                            unknown['Func.refGene'], 
                               margins = False)

# %%
data_crosstab
# Out:
# Func.refGene           exonic  exonic;splicing  ncRNA_exonic  \
# Func.refGeneWithVer
# exonic                   1558              239             0
# exonic;splicing             0              120             0
# ncRNA_exonic                0                0          4265
# ncRNA_exonic;splicing       0                0             0
# ncRNA_intronic              0                0             0
# ncRNA_splicing              0                0             0
#
# Func.refGene           ncRNA_exonic;splicing  ncRNA_splicing
# Func.refGeneWithVer
# exonic                                     0               0
# exonic;splicing                            0               0
# ncRNA_exonic                             391               0
# ncRNA_exonic;splicing                     43               0
# ncRNA_intronic                             0              61
# ncRNA_splicing                             0              14

# %%
case_splice=subset_df[(subset_df["Func.refGene"]=="splicing") & (subset_df["Func.refGeneWithVer"]!="splicing")]

# %%
case_splice["Func.refGeneWithVer"].unique()
# Out:
# array(['intronic', 'ncRNA_intronic', 'UTR5', 'UTR3', 'UTR5;UTR3'],
#       dtype=object)

# %% [markdown]
# # Investigate problems with 1415 code

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Read in the database

# %%
# collect the necessary column names of the database for our analysis

with open("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/092821_UKBB_486416ind_call90.csv") as fp:
    line = fp.readline() # header
    header = line.split(",")
    
    indiv = ["IID", "FID"]
    icd10_colnames = [col.strip('"') for col in header if "f.41270." in col]
    icd10_ages = [col.strip('"') for col in header if "f.41280." in col]
    icd9_colnames = [col.strip('"') for col in header if "f.41271." in col]
    icd9_ages = [col.strip('"') for col in header if "f.41281." in col]
    f20002_colnames = [col.strip('"') for col in header if "f.20002." in col]
    f20009_ages = [col.strip('"') for col in header if "f.20009." in col]
    reported_sex = ["f.31.0.0"]
    genetic_sex = ["f.22001.0.0"]
    ethnicity = [col.strip('"') for col in header if "f.21000." in col]
    hearing_imp_f3393 = [col.strip('"') for col in header if "f.3393." in col]
    hearing_imp_f2247 = [col.strip('"') for col in header if "f.2247." in col]
    hearing_imp_f2257 = [col.strip('"') for col in header if "f.2257." in col]
    tin_cols = [col.strip('"') for col in header if "f.4803." in col]
    ages_f21003_col = [col.strip('"') for col in header if "f.21003." in col]
    ages_f131258_col = [col.strip('"') for col in header if 'f.131258.' in col]
    year_of_birth = [col.strip('"') for col in header if "f.34." in col]
    month_of_birth = [col.strip('"') for col in header if "f.52." in col]

# %%
# combine the column names into one list
combined_cols = indiv + icd10_colnames + icd10_ages + icd9_colnames + icd9_ages + f20002_colnames + f20009_ages + ethnicity + reported_sex + genetic_sex + hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257 + tin_cols + ages_f21003_col + ages_f131258_col + year_of_birth + month_of_birth

# %%
print(datetime.now())
# Out:
# 2022-12-13 09:22:33.135393

# %%
# database of all individuals that we are working with and the selected phenotypes
df = pd.read_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/092821_UKBB_486416ind_call90.csv", quotechar = '"', dtype="string", usecols=combined_cols)
df
# Out:
#             IID      FID f.31.0.0  ... f.41281.0.45 f.41281.0.46 f.131258.0.0
# 0       1000019  1000019   Female  ...         <NA>         <NA>         <NA>
# 1       1000022  1000022     Male  ...         <NA>         <NA>         <NA>
# 2       1000035  1000035     Male  ...         <NA>         <NA>         <NA>
# 3       1000046  1000046   Female  ...         <NA>         <NA>         <NA>
# 4       1000054  1000054   Female  ...         <NA>         <NA>         <NA>
# ...         ...      ...      ...  ...          ...          ...          ...
# 486411  6025390  6025390   Female  ...         <NA>         <NA>         <NA>
# 486412  6025409  6025409   Female  ...         <NA>         <NA>         <NA>
# 486413  6025411  6025411   Female  ...         <NA>         <NA>         <NA>
# 486414  6025425  6025425   Female  ...         <NA>         <NA>         <NA>
# 486415  6025438  6025438     Male  ...         <NA>         <NA>         <NA>
#
# [486416 rows x 848 columns]

# %%
print(datetime.now())
# Out:
# 2022-12-13 09:31:09.904781

# %% [markdown]
# ## Read in exclusion criteria for icd10, icd9, and self-report

# %%
# csv file that contains information on the exclusion criteria for cases and controls
# This exclusion criteria does not exclude code 1415 from self-report variable
exclusion = pd.read_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/ICD10_9_selfreport_incl_excl.csv")
exclusion
# Out:
#     UKBB_field_code  ... observations
# 0           f.41270  ...          NaN
# 1           f.41270  ...          NaN
# 2           f.41270  ...          NaN
# 3           f.41270  ...          NaN
# 4           f.41270  ...          NaN
# ..              ...  ...          ...
# 566         f.20002  ...          NaN
# 567         f.20002  ...          NaN
# 568         f.20002  ...          NaN
# 569         f.20002  ...          NaN
# 570         f.20002  ...          NaN
#
# [571 rows x 11 columns]

# %% [markdown]
# ## Read in exclusion criteria with the 1415 added

# %%
exclusion_1415 = pd.read_csv("/home/dmc2245/exclusion_crit/ICD10_9_selfreport_incl_excl.csv")
exclusion_1415
# Out:
#     UKBB_field_code  ... observations
# 0           f.41270  ...          NaN
# 1           f.41270  ...          NaN
# 2           f.41270  ...          NaN
# 3           f.41270  ...          NaN
# 4           f.41270  ...          NaN
# ..              ...  ...          ...
# 567         f.20002  ...          NaN
# 568         f.20002  ...          NaN
# 569         f.20002  ...          NaN
# 570         f.20002  ...          NaN
# 571         f.20002  ...          NaN
#
# [572 rows x 11 columns]

# %% [markdown]
# # 3. Filter out exclusions from the full database

# %% [markdown]
# If individuals have certain codes from ICD 10, ICD 9, and self-reports they must be fully removed from the analysis.

# %%
# returns if the current individual should be excluded based on the exclusion list
def contains_exclusion(row, exclusion_list):
    for i in row:
        if not pd.isna(i) and i in exclusion_list:
            return True
            
    return False

# %% [markdown]
# ## 3.1. Filter out ICD 10 exclusions

# %%
# these are the columns that represent the icd10 columns in the database
icd10_colnames = [col for col in df if "f.41270" in col]

# %%
# get a dataframe that only contains the icd10 columns from the full database
icd10 = df[icd10_colnames]
icd10
# Out:
#        f.41270.0.0 f.41270.0.1  ... f.41270.0.224 f.41270.0.225
# 0             E041        H738  ...          <NA>          <NA>
# 1             F101        J342  ...          <NA>          <NA>
# 2             H269        K579  ...          <NA>          <NA>
# 3             E780        G473  ...          <NA>          <NA>
# 4             C679        C787  ...          <NA>          <NA>
# ...            ...         ...  ...           ...           ...
# 486411        A099        D649  ...          <NA>          <NA>
# 486412        <NA>        <NA>  ...          <NA>          <NA>
# 486413        O149        O266  ...          <NA>          <NA>
# 486414        G551        M501  ...          <NA>          <NA>
# 486415        D225        <NA>  ...          <NA>          <NA>
#
# [486416 rows x 226 columns]

# %%
icd10_date= [col for col in df if "f.41280" in col]
icd10_date
# Out:
# ['f.41280.0.0',
#  'f.41280.0.1',
#  'f.41280.0.2',
#  'f.41280.0.3',
#  'f.41280.0.4',
#  'f.41280.0.5',
#  'f.41280.0.6',
#  'f.41280.0.7',
#  'f.41280.0.8',
#  'f.41280.0.9',
#  'f.41280.0.10',
#  'f.41280.0.11',
#  'f.41280.0.12',
#  'f.41280.0.13',
#  'f.41280.0.14',
#  'f.41280.0.15',
#  'f.41280.0.16',
#  'f.41280.0.17',
#  'f.41280.0.18',
#  'f.41280.0.19',
#  'f.41280.0.20',
#  'f.41280.0.21',
#  'f.41280.0.22',
#  'f.41280.0.23',
#  'f.41280.0.24',
#  'f.41280.0.25',
#  'f.41280.0.26',
#  'f.41280.0.27',
#  'f.41280.0.28',
#  'f.41280.0.29',
#  'f.41280.0.30',
#  'f.41280.0.31',
#  'f.41280.0.32',
#  'f.41280.0.33',
#  'f.41280.0.34',
#  'f.41280.0.35',
#  'f.41280.0.36',
#  'f.41280.0.37',
#  'f.41280.0.38',
#  'f.41280.0.39',
#  'f.41280.0.40',
#  'f.41280.0.41',
#  'f.41280.0.42',
#  'f.41280.0.43',
#  'f.41280.0.44',
#  'f.41280.0.45',
#  'f.41280.0.46',
#  'f.41280.0.47',
#  'f.41280.0.48',
#  'f.41280.0.49',
#  'f.41280.0.50',
#  'f.41280.0.51',
#  'f.41280.0.52',
#  'f.41280.0.53',
#  'f.41280.0.54',
#  'f.41280.0.55',
#  'f.41280.0.56',
#  'f.41280.0.57',
#  'f.41280.0.58',
#  'f.41280.0.59',
#  'f.41280.0.60',
#  'f.41280.0.61',
#  'f.41280.0.62',
#  'f.41280.0.63',
#  'f.41280.0.64',
#  'f.41280.0.65',
#  'f.41280.0.66',
#  'f.41280.0.67',
#  'f.41280.0.68',
#  'f.41280.0.69',
#  'f.41280.0.70',
#  'f.41280.0.71',
#  'f.41280.0.72',
#  'f.41280.0.73',
#  'f.41280.0.74',
#  'f.41280.0.75',
#  'f.41280.0.76',
#  'f.41280.0.77',
#  'f.41280.0.78',
#  'f.41280.0.79',
#  'f.41280.0.80',
#  'f.41280.0.81',
#  'f.41280.0.82',
#  'f.41280.0.83',
#  'f.41280.0.84',
#  'f.41280.0.85',
#  'f.41280.0.86',
#  'f.41280.0.87',
#  'f.41280.0.88',
#  'f.41280.0.89',
#  'f.41280.0.90',
#  'f.41280.0.91',
#  'f.41280.0.92',
#  'f.41280.0.93',
#  'f.41280.0.94',
#  'f.41280.0.95',
#  'f.41280.0.96',
#  'f.41280.0.97',
#  'f.41280.0.98',
#  'f.41280.0.99',
#  'f.41280.0.100',
#  'f.41280.0.101',
#  'f.41280.0.102',
#  'f.41280.0.103',
#  'f.41280.0.104',
#  'f.41280.0.105',
#  'f.41280.0.106',
#  'f.41280.0.107',
#  'f.41280.0.108',
#  'f.41280.0.109',
#  'f.41280.0.110',
#  'f.41280.0.111',
#  'f.41280.0.112',
#  'f.41280.0.113',
#  'f.41280.0.114',
#  'f.41280.0.115',
#  'f.41280.0.116',
#  'f.41280.0.117',
#  'f.41280.0.118',
#  'f.41280.0.119',
#  'f.41280.0.120',
#  'f.41280.0.121',
#  'f.41280.0.122',
#  'f.41280.0.123',
#  'f.41280.0.124',
#  'f.41280.0.125',
#  'f.41280.0.126',
#  'f.41280.0.127',
#  'f.41280.0.128',
#  'f.41280.0.129',
#  'f.41280.0.130',
#  'f.41280.0.131',
#  'f.41280.0.132',
#  'f.41280.0.133',
#  'f.41280.0.134',
#  'f.41280.0.135',
#  'f.41280.0.136',
#  'f.41280.0.137',
#  'f.41280.0.138',
#  'f.41280.0.139',
#  'f.41280.0.140',
#  'f.41280.0.141',
#  'f.41280.0.142',
#  'f.41280.0.143',
#  'f.41280.0.144',
#  'f.41280.0.145',
#  'f.41280.0.146',
#  'f.41280.0.147',
#  'f.41280.0.148',
#  'f.41280.0.149',
#  'f.41280.0.150',
#  'f.41280.0.151',
#  'f.41280.0.152',
#  'f.41280.0.153',
#  'f.41280.0.154',
#  'f.41280.0.155',
#  'f.41280.0.156',
#  'f.41280.0.157',
#  'f.41280.0.158',
#  'f.41280.0.159',
#  'f.41280.0.160',
#  'f.41280.0.161',
#  'f.41280.0.162',
#  'f.41280.0.163',
#  'f.41280.0.164',
#  'f.41280.0.165',
#  'f.41280.0.166',
#  'f.41280.0.167',
#  'f.41280.0.168',
#  'f.41280.0.169',
#  'f.41280.0.170',
#  'f.41280.0.171',
#  'f.41280.0.172',
#  'f.41280.0.173',
#  'f.41280.0.174',
#  'f.41280.0.175',
#  'f.41280.0.176',
#  'f.41280.0.177',
#  'f.41280.0.178',
#  'f.41280.0.179',
#  'f.41280.0.180',
#  'f.41280.0.181',
#  'f.41280.0.182',
#  'f.41280.0.183',
#  'f.41280.0.184',
#  'f.41280.0.185',
#  'f.41280.0.186',
#  'f.41280.0.187',
#  'f.41280.0.188',
#  'f.41280.0.189',
#  'f.41280.0.190',
#  'f.41280.0.191',
#  'f.41280.0.192',
#  'f.41280.0.193',
#  'f.41280.0.194',
#  'f.41280.0.195',
#  'f.41280.0.196',
#  'f.41280.0.197',
#  'f.41280.0.198',
#  'f.41280.0.199',
#  'f.41280.0.200',
#  'f.41280.0.201',
#  'f.41280.0.202',
#  'f.41280.0.203',
#  'f.41280.0.204',
#  'f.41280.0.205',
#  'f.41280.0.206',
#  'f.41280.0.207',
#  'f.41280.0.208',
#  'f.41280.0.209',
#  'f.41280.0.210',
#  'f.41280.0.211',
#  'f.41280.0.212',
#  'f.41280.0.213',
#  'f.41280.0.214',
#  'f.41280.0.215',
#  'f.41280.0.216',
#  'f.41280.0.217',
#  'f.41280.0.218',
#  'f.41280.0.219',
#  'f.41280.0.220',
#  'f.41280.0.221',
#  'f.41280.0.222',
#  'f.41280.0.223',
#  'f.41280.0.224',
#  'f.41280.0.225']

# %%
# get rows from exclusion database that contian the codes that need to be removed for icd10
exclude_icd10 = exclusion[(exclusion["UKBB_field_code"] == "f.41270") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_icd10
# Out:
#     UKBB_field_code  ... observations
# 27          f.41270  ...          NaN
# 28          f.41270  ...          NaN
# 29          f.41270  ...          NaN
# 30          f.41270  ...          NaN
# 33          f.41270  ...          NaN
# ..              ...  ...          ...
# 276         f.41270  ...          NaN
# 279         f.41270  ...          NaN
# 280         f.41270  ...          NaN
# 281         f.41270  ...          NaN
# 285         f.41270  ...          NaN
#
# [134 rows x 11 columns]

# %%
# get the icd10 codes that should be excluded from database
ex_critia_icd10 = set(["".join( (i.split(" ")[0]).split(".") ) for i in exclude_icd10["Phenotype"].tolist()])
ex_critia_icd10
# Out:
# {'B020',
#  'B021',
#  'B022',
#  'B023',
#  'B027',
#  'B028',
#  'G000',
#  'G001',
#  'G002',
#  'G003',
#  'G008',
#  'G009',
#  'G01',
#  'G020',
#  'G021',
#  'G028',
#  'G030',
#  'G031',
#  'G032',
#  'G038',
#  'G039',
#  'G040',
#  'G041',
#  'G042',
#  'G048',
#  'G049',
#  'G050',
#  'G051',
#  'G052',
#  'G058',
#  'G060',
#  'G061',
#  'G062',
#  'G07',
#  'G08',
#  'G09',
#  'G510',
#  'G511',
#  'G512',
#  'G513',
#  'G514',
#  'G518',
#  'G519',
#  'H652',
#  'H653',
#  'H654',
#  'H659',
#  'H661',
#  'H662',
#  'H663',
#  'H664',
#  'H669',
#  'H680',
#  'H701',
#  'H702',
#  'H708',
#  'H709',
#  'H71',
#  'H731',
#  'H738',
#  'H739',
#  'H740',
#  'H741',
#  'H742',
#  'H743',
#  'H748',
#  'H749',
#  'H750',
#  'H758',
#  'H800',
#  'H801',
#  'H802',
#  'H808',
#  'H809',
#  'H810',
#  'H830',
#  'H831',
#  'H832',
#  'H900',
#  'H901',
#  'H902',
#  'H910',
#  'H933',
#  'H940',
#  'H948',
#  'H950',
#  'H951',
#  'H958',
#  'H959',
#  'S0200',
#  'S0201',
#  'S0210',
#  'S0211',
#  'S0240',
#  'S0241',
#  'S0260',
#  'S0261',
#  'S0270',
#  'S0271',
#  'S0280',
#  'S0281',
#  'S0290',
#  'S0291',
#  'S045',
#  'S046',
#  'S049',
#  'S0600',
#  'S0601',
#  'S0610',
#  'S0611',
#  'S0620',
#  'S0621',
#  'S0630',
#  'S0631',
#  'S0640',
#  'S0641',
#  'S0650',
#  'S0651',
#  'S0660',
#  'S0661',
#  'S0670',
#  'S0671',
#  'S0680',
#  'S0681',
#  'S0690',
#  'S0691',
#  'S070',
#  'S071',
#  'S078',
#  'S079',
#  'S081',
#  'S088',
#  'S089',
#  'S092'}

# %%
# collect the individuals that should be excluded because of icd10
ex_fxn_icd10 = lambda row: contains_exclusion(row, ex_critia_icd10)
ex_10 = icd10.apply(ex_fxn_icd10, axis=1)

# %%
print(sum(ex_10), "500k individuals removed because of icd10 codes")
# Out:
# 13396 500k individuals removed because of icd10 codes

# %%
indiv = ["IID", "FID"]
year_of_birth = [col for col in df if "f.34" in col]
month_of_birth = [col for col in df if "f.52" in col]
icd10_filtered = df[ex_10]
icd10_filtered_ages = icd10_filtered[indiv + year_of_birth + month_of_birth + icd10_colnames + icd10_date]

# %%
icd10_filtered_ages
# Out:
#             IID      FID f.34.0.0  ... f.41280.0.223 f.41280.0.224 f.41280.0.225
# 0       1000019  1000019     1960  ...          <NA>          <NA>          <NA>
# 32      1000357  1000357     1940  ...          <NA>          <NA>          <NA>
# 42      1000477  1000477     1959  ...          <NA>          <NA>          <NA>
# 58      1000638  1000638     1950  ...          <NA>          <NA>          <NA>
# 89      1000947  1000947     1941  ...          <NA>          <NA>          <NA>
# ...         ...      ...      ...  ...           ...           ...           ...
# 486353  6024796  6024796     1946  ...          <NA>          <NA>          <NA>
# 486369  6024960  6024960     1951  ...          <NA>          <NA>          <NA>
# 486370  6024974  6024974     1941  ...          <NA>          <NA>          <NA>
# 486390  6025176  6025176     1950  ...          <NA>          <NA>          <NA>
# 486391  6025180  6025180     1940  ...          <NA>          <NA>          <NA>
#
# [13396 rows x 456 columns]

# %%
icd10_filtered_ages.to_csv("/home/dmc2245/exclusion_crit/icd10_exclusion_dates.tsv", sep='\t', na_rep='NA', header=True, index=False)

# %%
def get_ages_from_birth(row):
    month_dict = {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12}
    year = 0
    month = 0
    i = row[0]
    if not pd.isna(i):
        i = i.split("-")
        year = i[0]
        month = i[1]
    if int(month) >= month_dict[row[month_of_birth[0]]]:
        return int(year) - int(row[year_of_birth[0]])
    return int(year) - int(row[year_of_birth[0]]) - 1

# %%
def find_icd10_ages(row):
    for en, i in enumerate(row[icd10_colnames]):
            if not pd.isna(i) and i in ex_10:
                return get_ages_from_birth(row[icd10_date[en:en+1]+year_of_birth+month_of_birth])

# %%
def age(row):
    if row in icd10_colnames:
        for en, i in enumerate(row[icd10_colnames]):
            if not pd.isna(i) and i in ex_10:
                return get_ages_from_birth(row[icd10_date[en:en+1]+year_of_birth+month_of_birth])

# %%
icd10_filtered_ages.apply(age)

# %%
icd10_test
# Out:
#        f.34.0.0  f.52.0.0 f.41270.0.0 f.41270.0.1 f.41280.0.0 f.41280.0.1
# 0          1960  November        E041        H738  2013-11-21  2007-09-20
# 32         1940     March        H251       M4195  2019-01-17  2018-05-21
# 42         1959      July        G048         I10  2007-01-19  2020-10-02
# 58         1950   January        A170        C509  2006-03-31  2005-11-19
# 89         1941    August        E119        H743  2017-11-15  2008-12-04
# ...         ...       ...         ...         ...         ...         ...
# 486353     1946    August        H269         H71  2020-11-10  2018-10-11
# 486369     1951  November        A692         D70  2002-10-08  2019-06-20
# 486370     1941       May        A099        H810  2019-01-21  2014-05-13
# 486390     1950    August        H663        H740  2003-01-31  2003-01-31
# 486391     1940  February        B968        H669  2001-02-23  2005-12-16
#
# [13396 rows x 6 columns]

# %% [markdown]
# ## 3.2. Filter out ICD 9 exclusions

# %%
# these are the columns that represent the icd9 columns in the working database
icd9_colnames = [col for col in df if "f.41271" in col]

# %%
# get a dataframe that only contains the icd9 columns from the working database
icd9 = df[icd9_colnames]
icd9
# Out:
#        f.41271.0.0 f.41271.0.1  ... f.41271.0.45 f.41271.0.46
# 0             <NA>        <NA>  ...         <NA>         <NA>
# 1             <NA>        <NA>  ...         <NA>         <NA>
# 2             <NA>        <NA>  ...         <NA>         <NA>
# 3             <NA>        <NA>  ...         <NA>         <NA>
# 4             3000        5198  ...         <NA>         <NA>
# ...            ...         ...  ...          ...          ...
# 486411        <NA>        <NA>  ...         <NA>         <NA>
# 486412        <NA>        <NA>  ...         <NA>         <NA>
# 486413        <NA>        <NA>  ...         <NA>         <NA>
# 486414        <NA>        <NA>  ...         <NA>         <NA>
# 486415        <NA>        <NA>  ...         <NA>         <NA>
#
# [486416 rows x 47 columns]

# %%
# get rows from exclusion database that contian the codes that need to be removed for icd9
exclude_icd9 = exclusion[(exclusion["UKBB_field_code"] == "f.41271") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_icd9
# Out:
#     UKBB_field_code  ... observations
# 319         f.41271  ...          NaN
# 320         f.41271  ...          NaN
# 321         f.41271  ...          NaN
# 322         f.41271  ...          NaN
# 323         f.41271  ...          NaN
# ..              ...  ...          ...
# 516         f.41271  ...          NaN
# 526         f.41271  ...          NaN
# 532         f.41271  ...          NaN
# 533         f.41271  ...          NaN
# 537         f.41271  ...          NaN
#
# [123 rows x 11 columns]

# %%
# get the icd9 codes that should be excluded from the working database
ex_critia_icd9 = set(["".join( (i.split(" ")[0]).split(".") ) for i in exclude_icd9["Phenotype"].tolist()])
ex_critia_icd9
# Out:
# {'0530',
#  '0531',
#  '0532',
#  '0537',
#  '0538',
#  '3200',
#  '3201',
#  '3202',
#  '3203',
#  '3204',
#  '3205',
#  '3207',
#  '3208',
#  '3209',
#  '3210',
#  '3211',
#  '3212',
#  '3213',
#  '3214',
#  '3215',
#  '3216',
#  '3217',
#  '3218',
#  '3220',
#  '3221',
#  '3222',
#  '3229',
#  '3230',
#  '3231',
#  '3232',
#  '3233',
#  '3234',
#  '3235',
#  '3236',
#  '3237',
#  '3238',
#  '3239',
#  '3240',
#  '3241',
#  '3249',
#  '3259',
#  '3269',
#  '3510',
#  '3511',
#  '3518',
#  '3519',
#  '3811',
#  '3812',
#  '3813',
#  '3814',
#  '3815',
#  '3816',
#  '3819',
#  '3821',
#  '3822',
#  '3823',
#  '3824',
#  '3829',
#  '3831',
#  '3832',
#  '3833',
#  '3838',
#  '3839',
#  '3841',
#  '3850',
#  '3851',
#  '3852',
#  '3853',
#  '3858',
#  '3859',
#  '3860',
#  '3863',
#  '3864',
#  '3865',
#  '3868',
#  '3869',
#  '3870',
#  '3871',
#  '3872',
#  '3878',
#  '3879',
#  '3885',
#  '3890',
#  '8000',
#  '8001',
#  '8002',
#  '8003',
#  '8010',
#  '8011',
#  '8012',
#  '8013',
#  '8022',
#  '8023',
#  '8024',
#  '8025',
#  '8028',
#  '8029',
#  '8030',
#  '8031',
#  '8032',
#  '8033',
#  '8040',
#  '8041',
#  '8042',
#  '8043',
#  '8509',
#  '8510',
#  '8511',
#  '8520',
#  '8521',
#  '8530',
#  '8531',
#  '8540',
#  '8541',
#  '8726',
#  '8727',
#  '8728',
#  '8729',
#  '9050',
#  '9259',
#  '9514',
#  '9515',
#  '9519'}

# %%
# collect the individuals that should be excluded because of icd9
ex_fxn_icd9 = lambda row: contains_exclusion(row, ex_critia_icd9)
ex_9 = icd9.apply(ex_fxn_icd9, axis=1)

# %%
print(sum(ex_9), "500k individuals removed because of icd9 codes")
# Out:
# 825 500k individuals removed because of icd9 codes

# %%
icd9_date= [col for col in df if "f.41281" in col]
icd9_date

# %%
indiv = ["IID", "FID"]
year_of_birth = [col for col in df if "f.34" in col]
month_of_birth = [col for col in df if "f.52" in col]
icd9_filtered = df[ex_9]
icd9_filtered_ages = icd9_filtered[indiv + year_of_birth + month_of_birth + icd9_colnames + icd9_date]

# %%
icd9_filtered_ages.to_csv("/home/dmc2245/exclusion_crit/icd9_exclusion_dates.tsv", sep='\t', na_rep='NA', header=True, index=False)

# %% [markdown]
# ## 3.3. Filter out f.20002 exclusions

# %%
# these are the columns that represent the self-report columns in the working database
f20002_colnames = [col for col in df if "f.20002" in col]

# %%
# get a dataframe that only contains the self-report columns from the working database
f20002 = df[f20002_colnames]
f20002
# Out:
#        f.20002.0.0 f.20002.0.1  ... f.20002.3.32 f.20002.3.33
# 0             1111        <NA>  ...         <NA>         <NA>
# 1             1065        <NA>  ...         <NA>         <NA>
# 2             1396        1473  ...         <NA>         <NA>
# 3             1065        1294  ...         <NA>         <NA>
# 4             <NA>        <NA>  ...         <NA>         <NA>
# ...            ...         ...  ...          ...          ...
# 486411        1464        <NA>  ...         <NA>         <NA>
# 486412        1478        1473  ...         <NA>         <NA>
# 486413        <NA>        <NA>  ...         <NA>         <NA>
# 486414        1265        <NA>  ...         <NA>         <NA>
# 486415        1065        <NA>  ...         <NA>         <NA>
#
# [486416 rows x 136 columns]

# %%
# get rows from exclusion database that contian the codes that need to be removed for self-report
exclude_f20002 = exclusion[(exclusion["UKBB_field_code"] == "f.20002") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_f20002
# Out:
#     UKBB_field_code  ... observations
# 539         f.20002  ...          NaN
# 540         f.20002  ...          NaN
# 541         f.20002  ...          NaN
# 545         f.20002  ...          NaN
# 546         f.20002  ...          NaN
# 547         f.20002  ...          NaN
# 548         f.20002  ...          NaN
# 550         f.20002  ...          NaN
# 551         f.20002  ...          NaN
# 553         f.20002  ...          NaN
# 558         f.20002  ...          NaN
# 565         f.20002  ...          NaN
# 566         f.20002  ...          NaN
# 569         f.20002  ...          NaN
# 570         f.20002  ...          NaN
#
# [15 rows x 11 columns]

# %%
# get rows from exclusion database that contian the codes that need to be removed for self-report
exclude_1415_f20002 = exclusion_1415[(exclusion_1415["UKBB_field_code"] == "f.20002") & (exclusion_1415["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_1415_f20002
# Out:
#     UKBB_field_code  ... observations
# 539         f.20002  ...          NaN
# 540         f.20002  ...          NaN
# 541         f.20002  ...          NaN
# 545         f.20002  ...          NaN
# 546         f.20002  ...          NaN
# 547         f.20002  ...          NaN
# 548         f.20002  ...          NaN
# 550         f.20002  ...          NaN
# 551         f.20002  ...          NaN
# 553         f.20002  ...          NaN
# 558         f.20002  ...          NaN
# 565         f.20002  ...          NaN
# 566         f.20002  ...          NaN
# 569         f.20002  ...          NaN
# 570         f.20002  ...          NaN
# 571         f.20002  ...          NaN
#
# [16 rows x 11 columns]

# %%
# get the self-report codes that should be excluded from the working database
ex_critia_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_f20002["Phenotype"].tolist()]
ex_critia_f20002
# Out:
# ['1420',
#  '1421',
#  '1499',
#  '1244',
#  '1245',
#  '1246',
#  '1247',
#  '1249',
#  '1250',
#  '1240',
#  '1626',
#  '1086',
#  '1491',
#  '1083',
#  '1425']

# %%
# get the self-report codes that should be excluded from the working database
ex_critia_1415_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_1415_f20002["Phenotype"].tolist()]
ex_critia_1415_f20002
# Out:
# ['1420',
#  '1421',
#  '1499',
#  '1244',
#  '1245',
#  '1246',
#  '1247',
#  '1249',
#  '1250',
#  '1240',
#  '1626',
#  '1086',
#  '1491',
#  '1083',
#  '1425',
#  '1415']

# %%
# collect the individuals that should be excluded because of self-report
ex_fxn_f20002 = lambda row: contains_exclusion(row, ex_critia_f20002)
ex_f20002 = f20002.apply(ex_fxn_f20002, axis=1)

# %%
print(sum(ex_f20002), "500k individuals removed because of self-reported codes")
# Out:
# 7004 500k individuals removed because of self-reported codes

# %%
indiv = ["IID", "FID"]
year_of_birth = [col for col in df if "f.34" in col]
month_of_birth = [col for col in df if "f.52" in col]
f20009_age= [col for col in df if "f.20009" in col]
f20002_filtered = df[ex_f20002]
f20002_filtered_ages = f20002_filtered[indiv + year_of_birth + month_of_birth + f20002_colnames + f20009_ages]

# %%
f20002_filtered_ages
# Out:
#             IID      FID f.34.0.0  ... f.20009.3.31 f.20009.3.32 f.20009.3.33
# 42      1000477  1000477     1959  ...         <NA>         <NA>         <NA>
# 58      1000638  1000638     1950  ...         <NA>         <NA>         <NA>
# 82      1000875  1000875     1950  ...         <NA>         <NA>         <NA>
# 121     1001278  1001278     1958  ...         <NA>         <NA>         <NA>
# 213     1002216  1002216     1945  ...         <NA>         <NA>         <NA>
# ...         ...      ...      ...  ...          ...          ...          ...
# 486209  6023291  6023291     1940  ...         <NA>         <NA>         <NA>
# 486221  6023421  6023421     1951  ...         <NA>         <NA>         <NA>
# 486274  6023965  6023965     1965  ...         <NA>         <NA>         <NA>
# 486319  6024448  6024448     1951  ...         <NA>         <NA>         <NA>
# 486338  6024633  6024633     1943  ...         <NA>         <NA>         <NA>
#
# [7004 rows x 276 columns]

# %%
f20002_filtered_ages.to_csv("/home/dmc2245/exclusion_crit/f20002_filtered_ages.tsv", sep='\t', na_rep='NA', header=True, index=False)

# %%
# collect the individuals that should be excluded because of self-report
ex_fxn_1415_f20002 = lambda row: contains_exclusion(row, ex_critia_1415_f20002)
ex_1415_f20002 = f20002.apply(ex_fxn_1415_f20002, axis=1)

# %%
print(sum(ex_1415_f20002), "500k individuals removed because of self-reported codes")
# Out:
# 11227 500k individuals removed because of self-reported codes

# %%
indiv = ["IID", "FID"]
year_of_birth = [col for col in df if "f.34" in col]
month_of_birth = [col for col in df if "f.52" in col]
f20009_age= [col for col in df if "f.20009" in col]
f20002_1415_filtered = df[ex_1415_f20002]
f20002_1415_filtered_ages = f20002_1415_filtered[indiv + year_of_birth + month_of_birth + f20002_colnames + f20009_ages]

# %%
f20002_1415_filtered_ages
# Out:
#             IID      FID f.34.0.0  ... f.20009.3.31 f.20009.3.32 f.20009.3.33
# 42      1000477  1000477     1959  ...         <NA>         <NA>         <NA>
# 58      1000638  1000638     1950  ...         <NA>         <NA>         <NA>
# 71      1000767  1000767     1959  ...         <NA>         <NA>         <NA>
# 82      1000875  1000875     1950  ...         <NA>         <NA>         <NA>
# 121     1001278  1001278     1958  ...         <NA>         <NA>         <NA>
# ...         ...      ...      ...  ...          ...          ...          ...
# 486269  6023914  6023914     1955  ...         <NA>         <NA>         <NA>
# 486274  6023965  6023965     1965  ...         <NA>         <NA>         <NA>
# 486319  6024448  6024448     1951  ...         <NA>         <NA>         <NA>
# 486338  6024633  6024633     1943  ...         <NA>         <NA>         <NA>
# 486391  6025180  6025180     1940  ...         <NA>         <NA>         <NA>
#
# [11227 rows x 276 columns]

# %%
f20002_1415_clean=f20002_1415_filtered_ages.dropna(axis=1,how='all')

# %%
f20002_1415_clean
# Out:
#             IID      FID f.34.0.0  ... f.20009.3.14 f.20009.3.15 f.20009.3.16
# 42      1000477  1000477     1959  ...         <NA>         <NA>         <NA>
# 58      1000638  1000638     1950  ...         <NA>         <NA>         <NA>
# 71      1000767  1000767     1959  ...         <NA>         <NA>         <NA>
# 82      1000875  1000875     1950  ...         <NA>         <NA>         <NA>
# 121     1001278  1001278     1958  ...         <NA>         <NA>         <NA>
# ...         ...      ...      ...  ...          ...          ...          ...
# 486269  6023914  6023914     1955  ...         <NA>         <NA>         <NA>
# 486274  6023965  6023965     1965  ...         <NA>         <NA>         <NA>
# 486319  6024448  6024448     1951  ...         <NA>         <NA>         <NA>
# 486338  6024633  6024633     1943  ...         <NA>         <NA>         <NA>
# 486391  6025180  6025180     1940  ...         <NA>         <NA>         <NA>
#
# [11227 rows x 188 columns]

# %%
f20002_1415_filtered_ages.to_csv("/home/dmc2245/exclusion_crit/f20002_1415_filtered_ages.tsv", sep='\t', na_rep='NA', header=True, index=False)

# %%
f20002_1415_clean.to_csv("/home/dmc2245/exclusion_crit/f20002_1415_filtered_ages_clean.tsv", sep='\t', na_rep='NA', header=True, index=False)

# %%
f20002_1415_clean=pd.read_csv("/home/dmc2245/exclusion_crit/f20002_1415_filtered_ages_clean.tsv",sep='\t', quotechar = '"', dtype="string")
f20002_1415_clean
# Out:
#            IID      FID f.34.0.0  ... f.20009.3.14 f.20009.3.15 f.20009.3.16
# 0      1000477  1000477     1959  ...         <NA>         <NA>         <NA>
# 1      1000638  1000638     1950  ...         <NA>         <NA>         <NA>
# 2      1000767  1000767     1959  ...         <NA>         <NA>         <NA>
# 3      1000875  1000875     1950  ...         <NA>         <NA>         <NA>
# 4      1001278  1001278     1958  ...         <NA>         <NA>         <NA>
# ...        ...      ...      ...  ...          ...          ...          ...
# 11222  6023914  6023914     1955  ...         <NA>         <NA>         <NA>
# 11223  6023965  6023965     1965  ...         <NA>         <NA>         <NA>
# 11224  6024448  6024448     1951  ...         <NA>         <NA>         <NA>
# 11225  6024633  6024633     1943  ...         <NA>         <NA>         <NA>
# 11226  6025180  6025180     1940  ...         <NA>         <NA>         <NA>
#
# [11227 rows x 188 columns]

# %% [markdown]
# ### Find the number of individuals in the full database with code 1415

# %%
def find_20002(row):
    if "1415" in row.dropna().to_list():
        return True
    return False
lis = df[f20002_colnames].apply(find_20002, axis=1)
1415_ind=df.loc[lis==True,f20002_colnames]
# Out:
#        f.20002.0.0 f.20002.0.1  ... f.20002.3.32 f.20002.3.33
# 71            1294        1251  ...         <NA>         <NA>
# 273           1065        1473  ...         <NA>         <NA>
# 411           1065        1415  ...         <NA>         <NA>
# 528           1537        1415  ...         <NA>         <NA>
# 866           1415        1065  ...         <NA>         <NA>
# ...            ...         ...  ...          ...          ...
# 485948        1065        1474  ...         <NA>         <NA>
# 486079        1666        1065  ...         <NA>         <NA>
# 486188        1065        1471  ...         <NA>         <NA>
# 486269        1403        1402  ...         <NA>         <NA>
# 486391        1065        1478  ...         <NA>         <NA>
#
# [4384 rows x 136 columns]

# %%
ind_1415=df.loc[lis==True,f20002_colnames]

# %%
ind_1415['number'] = ind_1415.apply(lambda row: len(row[row == '1415']), axis=1)

# %%
ind_1415[ind_1415.number > 1]
# Out:
#        f.20002.0.0 f.20002.0.1 f.20002.0.2  ... f.20002.3.33 count number
# 34821         1113        1465        1142  ...         <NA>     2      2
# 66335         1065        1094        1220  ...         <NA>     2      2
# 106379        1065        1201        1415  ...         <NA>     2      2
# 112709        1157       99999        1142  ...         <NA>     2      2
# 112724        1294        1415        1415  ...         <NA>     2      2
# 166841        1207        1415        <NA>  ...         <NA>     2      2
# 192164        1473        1415        1415  ...         <NA>     2      2
# 208176        1065        1387        1415  ...         <NA>     2      2
# 232552        1266        1243        1294  ...         <NA>     2      2
# 241967        1464        1415       99999  ...         <NA>     3      3
# 242431        1415        1406       99999  ...         <NA>     2      2
# 264697        1065        1111        1452  ...         <NA>     2      2
# 266133        1065        1111        1413  ...         <NA>     2      2
# 269843        1415        1617        <NA>  ...         <NA>     2      2
# 280227        1065        1415        1348  ...         <NA>     2      2
# 286132        1415        <NA>        <NA>  ...         <NA>     2      2
# 292972        1065        1415        1415  ...         <NA>     2      2
# 302384       99999        1117        1278  ...         <NA>     2      2
# 313102        1415        1467        1470  ...         <NA>     2      2
# 328020        1465        1415        1415  ...         <NA>     2      2
# 351145        1065        1226        1415  ...         <NA>     2      2
# 352633        1415        1415        <NA>  ...         <NA>     2      2
# 359341        1415        <NA>        <NA>  ...         <NA>     2      2
# 359731        1065        1415        1414  ...         <NA>     2      2
# 382081        1065        1415        1294  ...         <NA>     2      2
# 383877        1415        1415        1201  ...         <NA>     2      2
# 385708        1065        1123        1138  ...         <NA>     2      2
# 387153        1531        1415        <NA>  ...         <NA>     2      2
# 422964        1415        1415        1349  ...         <NA>     2      2
# 423595        1075        1074        1065  ...         <NA>     2      2
# 424510        1065        1350        1402  ...         <NA>     2      2
# 426374        1286        1415        1436  ...         <NA>     2      2
# 426421       99999       99999       99999  ...         <NA>     2      2
# 432275        1081        1113        1111  ...         <NA>     2      2
# 443835        1415        1598        1413  ...         <NA>     2      2
# 467408        1065        1111        1138  ...         <NA>     2      2
# 478708        1065        1111        1415  ...         <NA>     2      2
# 483244        1415        1465        1415  ...         <NA>     2      2
#
# [38 rows x 138 columns]

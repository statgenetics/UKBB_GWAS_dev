# %% [markdown]
# # Generate the phenotypes for the hearing impairment traits from the UKBB

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read in the data

# %%
exclusion = pd.read_csv("~/ICD10_9_selfreport_incl_excl.csv")
exclusion
# Out:
#     UKBB_field_code                              Phenotype cases_UKB_showcase  \
# 0           f.41270       H60-H62 Diseases of external ear                NaN
# 1           f.41270                     H60 Otitis externa                NaN
# 2           f.41270          H60.0 Abscess of external ear                 32
# 3           f.41270       H60.1 Cellulitis of external ear                218
# 4           f.41270         H60.2 Malignant otitis externa                 49
# ..              ...                                    ...                ...
# 571         f.20002                 1491 brain haemorrhage                218
# 572         f.20002                  1583 ischaemic stroke                 44
# 573         f.20002  1082 transient ischaemic attack (tia)               2243
# 574         f.20002    1083 subdural haemorrhage/haematoma                212
# 575         f.20002                 1425 cerebral aneurysm                352
#
#     Excluded_fulldb_lateonsetHI Excluded_from_controls Cases_f3393  \
# 0                           NaN                    NaN         NaN
# 1                           NaN                    NaN         NaN
# 2                             N                      N         NaN
# 3                             N                      N         NaN
# 4                             N                      N         NaN
# ..                          ...                    ...         ...
# 571                           Y                    NaN         NaN
# 572                           N                      N         NaN
# 573                           N                      N         NaN
# 574                           Y                    NaN         NaN
# 575                           Y                    NaN         NaN
#
#     Cases_f2247 Cases_f2257 Cases_f4803 Cases_Mendelian_like  \
# 0           NaN         NaN         NaN                  NaN
# 1           NaN         NaN         NaN                  NaN
# 2           NaN         NaN         NaN                  NaN
# 3           NaN         NaN         NaN                  NaN
# 4           NaN         NaN         NaN                  NaN
# ..          ...         ...         ...                  ...
# 571         NaN         NaN         NaN                  NaN
# 572         NaN         NaN         NaN                  NaN
# 573         NaN         NaN         NaN                  NaN
# 574         NaN         NaN         NaN                  NaN
# 575         NaN         NaN         NaN                  NaN
#
#      Excluded_from_controls_Medelian_like observations
# 0                                     NaN          NaN
# 1                                     NaN          NaN
# 2                                     NaN          NaN
# 3                                     NaN          NaN
# 4                                     NaN          NaN
# ..                                    ...          ...
# 571                                   NaN          NaN
# 572                                   NaN          NaN
# 573                                   NaN          NaN
# 574                                   NaN          NaN
# 575                                   NaN          NaN
#
# [576 rows x 12 columns]

# %%
outlier = pd.read_csv("~/030821_ukb42495_exomed_white_189010ind.pheno.white_expanded_07_09_21_genoarray_projected.pca.projected.outliers", sep="\t")
outlier
# Out:
#      1008606  1008606.1
# 0    1010412    1010412
# 1    1045757    1045757
# 2    1057699    1057699
# 3    1069457    1069457
# 4    1071240    1071240
# ..       ...        ...
# 562  4773865    4773865
# 563  5109700    5109700
# 564  5637210    5637210
# 565  5748329    5748329
# 566  5809112    5809112
#
# [567 rows x 2 columns]

# %%
df = pd.read_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/062421_UKBB_HI_exomes_189009ind.csv", quotechar = '"', dtype="string")
df
# Out:
#             IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0 f.34.0.0  \
# 0       1000019  1000019       0       0       2      -9   Female     1960
# 1       1000035  1000035       0       0       1      -9     Male     1944
# 2       1000078  1000078       0       0       2      -9   Female     1955
# 3       1000081  1000081       0       0       1      -9     Male     1942
# 4       1000198  1000198       0       0       2      -9   Female     1967
# ...         ...      ...     ...     ...     ...     ...      ...      ...
# 189004  6025295  6025295       0       0       1      -9     Male     1961
# 189005  6025319  6025319       0       0       2      -9   Female     1953
# 189006  6025346  6025346       0       0       2      -9   Female     1954
# 189007  6025363  6025363       0       0       1      -9     Male     1944
# 189008  6025411  6025411       0       0       2      -9   Female     1960
#
#           f.53.0.0    f.53.1.0  ... f.131228.0.0       f.131229.0.0  \
# 0       2008-01-24        <NA>  ...         <NA>               <NA>
# 1       2007-11-08        <NA>  ...         <NA>               <NA>
# 2       2007-08-20  2012-11-01  ...         <NA>               <NA>
# 3       2009-12-03        <NA>  ...         <NA>               <NA>
# 4       2009-03-27        <NA>  ...         <NA>               <NA>
# ...            ...         ...  ...          ...                ...
# 189004  2008-01-24        <NA>  ...   1990-04-05  Primary care only
# 189005  2010-02-03        <NA>  ...         <NA>               <NA>
# 189006  2008-08-19        <NA>  ...         <NA>               <NA>
# 189007  2008-05-17        <NA>  ...         <NA>               <NA>
# 189008  2010-04-29        <NA>  ...         <NA>               <NA>
#
#        f.131230.0.0       f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0  \
# 0              <NA>               <NA>         <NA>         <NA>         <NA>
# 1              <NA>               <NA>         <NA>         <NA>         <NA>
# 2              <NA>               <NA>         <NA>         <NA>         <NA>
# 3              <NA>               <NA>         <NA>         <NA>         <NA>
# 4              <NA>               <NA>         <NA>         <NA>         <NA>
# ...             ...                ...          ...          ...          ...
# 189004   1991-02-25  Primary care only         <NA>         <NA>         <NA>
# 189005         <NA>               <NA>         <NA>         <NA>         <NA>
# 189006         <NA>               <NA>         <NA>         <NA>         <NA>
# 189007         <NA>               <NA>         <NA>         <NA>         <NA>
# 189008         <NA>               <NA>         <NA>         <NA>         <NA>
#
#        f.131251.0.0 f.131252.0.0 f.131253.0.0
# 0              <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>
# ...             ...          ...          ...
# 189004         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>
#
# [189009 rows x 2261 columns]

# %% [markdown]
# # Remove outliers from the Full database

# %%
out_ids = outlier["1008606"].to_list()

#find_outliers = lambda row: row["IID"] in out_ids

def find_outliers(row):
    return row["IID"] in out_ids

# %%
exclude = df[["IID", "FID"]].apply(find_outliers, axis=1)

# %%
sum(exclude)
# Out:
# 0

# %%
df = df[~exclude]

# %% [markdown]
# # Filter Out Exclusions from the Full database

# %% [markdown]
# ## Filter out ICD 10 exclusions

# %%
exclude_icd10 = exclusion[(exclusion["UKBB_field_code"] == "f.41270") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_icd10
# Out:
#     UKBB_field_code                                          Phenotype  \
# 27          f.41270                  H65.2 Chronic serous otitis media
# 28          f.41270                  H65.3 Chronic mucoid otitis media
# 29          f.41270    H65.4 Other chronic nonsuppurative otitis media
# 30          f.41270     H65.9 Nonsuppurative otitis media, unspecified
# 33          f.41270  H66.1 Chronic tubotympanic suppurative otitis ...
# ..              ...                                                ...
# 276         f.41270    S07.9 Crushing injury of head, part unspecified
# 279         f.41270                  S08.1 Traumatic amputation of ear
# 280         f.41270  S08.8 Traumatic amputation of other parts of head
# 281         f.41270  S08.9 Traumatic amputation of unspecified part...
# 285         f.41270                S09.2 Traumatic rupture of ear drum
#
#     cases_UKB_showcase Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 27                 103                           Y                    NaN
# 28                 960                           Y                    NaN
# 29                 158                           Y                    NaN
# 30                 508                           Y                    NaN
# 33                  40                           Y                    NaN
# ..                 ...                         ...                    ...
# 276                  1                           Y                    NaN
# 279                 13                           Y                    NaN
# 280                  1                           Y                    NaN
# 281                  1                           Y                    NaN
# 285                 18                           Y                    NaN
#
#     Cases_f3393 Cases_f2247 Cases_f2257 Cases_f4803 Cases_Mendelian_like  \
# 27          NaN         NaN         NaN         NaN                  NaN
# 28          NaN         NaN         NaN         NaN                  NaN
# 29          NaN         NaN         NaN         NaN                  NaN
# 30          NaN         NaN         NaN         NaN                  NaN
# 33          NaN         NaN         NaN         NaN                  NaN
# ..          ...         ...         ...         ...                  ...
# 276         NaN         NaN         NaN         NaN                  NaN
# 279         NaN         NaN         NaN         NaN                  NaN
# 280         NaN         NaN         NaN         NaN                  NaN
# 281         NaN         NaN         NaN         NaN                  NaN
# 285         NaN         NaN         NaN         NaN                  NaN
#
#      Excluded_from_controls_Medelian_like observations
# 27                                    NaN          NaN
# 28                                    NaN          NaN
# 29                                    NaN          NaN
# 30                                    NaN          NaN
# 33                                    NaN          NaN
# ..                                    ...          ...
# 276                                   NaN          NaN
# 279                                   NaN          NaN
# 280                                   NaN          NaN
# 281                                   NaN          NaN
# 285                                   NaN          NaN
#
# [134 rows x 12 columns]

# %%
icd10_colnames = [col for col in df if "f.41270" in col]

# %%
icd10 = df[icd10_colnames]
icd10
# Out:
#        f.41270.0.0 f.41270.0.1 f.41270.0.2 f.41270.0.3 f.41270.0.4  \
# 0             E041        H738        M750        M754        M758
# 1             H269        K579        K590        K621         N40
# 2             D037        L720        <NA>        <NA>        <NA>
# 3             E780        H251        H269         I10        I210
# 4             D171         I10        J301        K409        N898
# ...            ...         ...         ...         ...         ...
# 189004        D171        I845        I846        K318        K429
# 189005        E669         I10        K801        K802         K85
# 189006        O074        <NA>        <NA>        <NA>        <NA>
# 189007        <NA>        <NA>        <NA>        <NA>        <NA>
# 189008        O149        O266        O342        O471         O48
#
#        f.41270.0.5 f.41270.0.6 f.41270.0.7 f.41270.0.8 f.41270.0.9  ...  \
# 0             N898        N920        N946        R104        Z038  ...
# 1             R398        Z466        Z538        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             I219        I251        I252        I258        I259  ...
# 4             O800        Z370        Z721        Z822        Z861  ...
# ...            ...         ...         ...         ...         ...  ...
# 189004        K529        K602        K610        K921        R073  ...
# 189005        M179        M233        N921        R102        <NA>  ...
# 189006        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189007        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189008        O610        O680        Z370        <NA>        <NA>  ...
#
#        f.41270.0.203 f.41270.0.204 f.41270.0.205 f.41270.0.206 f.41270.0.207  \
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 189004          <NA>          <NA>          <NA>          <NA>          <NA>
# 189005          <NA>          <NA>          <NA>          <NA>          <NA>
# 189006          <NA>          <NA>          <NA>          <NA>          <NA>
# 189007          <NA>          <NA>          <NA>          <NA>          <NA>
# 189008          <NA>          <NA>          <NA>          <NA>          <NA>
#
#        f.41270.0.208 f.41270.0.209 f.41270.0.210 f.41270.0.211 f.41270.0.212
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 189004          <NA>          <NA>          <NA>          <NA>          <NA>
# 189005          <NA>          <NA>          <NA>          <NA>          <NA>
# 189006          <NA>          <NA>          <NA>          <NA>          <NA>
# 189007          <NA>          <NA>          <NA>          <NA>          <NA>
# 189008          <NA>          <NA>          <NA>          <NA>          <NA>
#
# [189009 rows x 213 columns]

# %%
ex_critia_icd10 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_icd10["Phenotype"].tolist()]
ex_critia_icd10
# Out:
# ['H652',
#  'H653',
#  'H654',
#  'H659',
#  'H661',
#  'H662',
#  'H663',
#  'H664',
#  'H669',
#  'H680',
#  'H701',
#  'H702',
#  'H708',
#  'H709',
#  'H71',
#  'H731',
#  'H738',
#  'H739',
#  'H740',
#  'H741',
#  'H742',
#  'H743',
#  'H748',
#  'H749',
#  'H750',
#  'H758',
#  'H800',
#  'H801',
#  'H802',
#  'H808',
#  'H809',
#  'H810',
#  'H830',
#  'H831',
#  'H832',
#  'H900',
#  'H901',
#  'H902',
#  'H910',
#  'H933',
#  'H940',
#  'H948',
#  'H950',
#  'H951',
#  'H958',
#  'H959',
#  'B020',
#  'B021',
#  'B022',
#  'B023',
#  'B027',
#  'B028',
#  'G000',
#  'G001',
#  'G002',
#  'G003',
#  'G008',
#  'G009',
#  'G01',
#  'G020',
#  'G021',
#  'G028',
#  'G030',
#  'G031',
#  'G032',
#  'G038',
#  'G039',
#  'G040',
#  'G041',
#  'G042',
#  'G048',
#  'G049',
#  'G050',
#  'G051',
#  'G052',
#  'G058',
#  'G060',
#  'G061',
#  'G062',
#  'G07',
#  'G08',
#  'G09',
#  'G510',
#  'G511',
#  'G512',
#  'G513',
#  'G514',
#  'G518',
#  'G519',
#  'S0200',
#  'S0201',
#  'S0210',
#  'S0211',
#  'S0240',
#  'S0241',
#  'S0260',
#  'S0261',
#  'S0270',
#  'S0271',
#  'S0280',
#  'S0281',
#  'S0290',
#  'S0291',
#  'S045',
#  'S046',
#  'S049',
#  'S0600',
#  'S0601',
#  'S0610',
#  'S0611',
#  'S0620',
#  'S0621',
#  'S0630',
#  'S0631',
#  'S0640',
#  'S0641',
#  'S0650',
#  'S0651',
#  'S0660',
#  'S0661',
#  'S0670',
#  'S0671',
#  'S0680',
#  'S0681',
#  'S0690',
#  'S0691',
#  'S070',
#  'S071',
#  'S078',
#  'S079',
#  'S081',
#  'S088',
#  'S089',
#  'S092']

# %%
def contains_exclusion(row, exclusion_list):
    for i in row:
        try: # this is to catch the nan issue
            if i in exclusion_list:
                return True
        except:
            continue
            
    return False

# %%
ex_fxn_icd10 = lambda row: contains_exclusion(row, ex_critia_icd10)
ex_10 = icd10.apply(ex_fxn_icd10, axis=1)

# %%
filtered = df[~ex_10]

# %%
filtered
# Out:
#             IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0 f.34.0.0  \
# 1       1000035  1000035       0       0       1      -9     Male     1944
# 2       1000078  1000078       0       0       2      -9   Female     1955
# 3       1000081  1000081       0       0       1      -9     Male     1942
# 4       1000198  1000198       0       0       2      -9   Female     1967
# 5       1000210  1000210       0       0       1      -9     Male     1941
# ...         ...      ...     ...     ...     ...     ...      ...      ...
# 189004  6025295  6025295       0       0       1      -9     Male     1961
# 189005  6025319  6025319       0       0       2      -9   Female     1953
# 189006  6025346  6025346       0       0       2      -9   Female     1954
# 189007  6025363  6025363       0       0       1      -9     Male     1944
# 189008  6025411  6025411       0       0       2      -9   Female     1960
#
#           f.53.0.0    f.53.1.0  ... f.131228.0.0       f.131229.0.0  \
# 1       2007-11-08        <NA>  ...         <NA>               <NA>
# 2       2007-08-20  2012-11-01  ...         <NA>               <NA>
# 3       2009-12-03        <NA>  ...         <NA>               <NA>
# 4       2009-03-27        <NA>  ...         <NA>               <NA>
# 5       2008-02-11        <NA>  ...         <NA>               <NA>
# ...            ...         ...  ...          ...                ...
# 189004  2008-01-24        <NA>  ...   1990-04-05  Primary care only
# 189005  2010-02-03        <NA>  ...         <NA>               <NA>
# 189006  2008-08-19        <NA>  ...         <NA>               <NA>
# 189007  2008-05-17        <NA>  ...         <NA>               <NA>
# 189008  2010-04-29        <NA>  ...         <NA>               <NA>
#
#        f.131230.0.0       f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0  \
# 1              <NA>               <NA>         <NA>         <NA>         <NA>
# 2              <NA>               <NA>         <NA>         <NA>         <NA>
# 3              <NA>               <NA>         <NA>         <NA>         <NA>
# 4              <NA>               <NA>         <NA>         <NA>         <NA>
# 5              <NA>               <NA>         <NA>         <NA>         <NA>
# ...             ...                ...          ...          ...          ...
# 189004   1991-02-25  Primary care only         <NA>         <NA>         <NA>
# 189005         <NA>               <NA>         <NA>         <NA>         <NA>
# 189006         <NA>               <NA>         <NA>         <NA>         <NA>
# 189007         <NA>               <NA>         <NA>         <NA>         <NA>
# 189008         <NA>               <NA>         <NA>         <NA>         <NA>
#
#        f.131251.0.0 f.131252.0.0 f.131253.0.0
# 1              <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>
# ...             ...          ...          ...
# 189004         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>
#
# [185344 rows x 2261 columns]

# %% [markdown]
# ## Filter out ICD 9 exclusions

# %%
exclude_icd9 = exclusion[(exclusion["UKBB_field_code"] == "f.41271") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_icd9
# Out:
#     UKBB_field_code                                          Phenotype  \
# 324         f.41271                   3811 Chronic serous otitis media
# 325         f.41271                   3812 Chronic mucoid otitis media
# 326         f.41271  3813 Other and unspecified chronic nonsuppurat...
# 327         f.41271  3814 Nonsuppurative otitis media, not specifie...
# 328         f.41271                        3815 Eustachian salpingitis
# ..              ...                                                ...
# 521         f.41271  9050 Late effect of fracture of skull and face...
# 531         f.41271       9259 Crushing injury of face, scalp and neck
# 537         f.41271                        9514 Injury to facial nerve
# 538         f.41271                      9515 Injury to acoustic nerve
# 542         f.41271           9519 Injury to unspecified cranial nerve
#
#     cases_UKB_showcase Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 324                  8                           Y                    NaN
# 325                 11                           Y                    NaN
# 326                  3                           Y                    NaN
# 327                 19                           Y                    NaN
# 328                  0                           Y                    NaN
# ..                 ...                         ...                    ...
# 521                 19                           Y                    NaN
# 531                  2                           Y                    NaN
# 537                  0                           Y                    NaN
# 538                  1                           Y                    NaN
# 542                  0                           Y                    NaN
#
#     Cases_f3393 Cases_f2247 Cases_f2257 Cases_f4803 Cases_Mendelian_like  \
# 324         NaN         NaN         NaN         NaN                  NaN
# 325         NaN         NaN         NaN         NaN                  NaN
# 326         NaN         NaN         NaN         NaN                  NaN
# 327         NaN         NaN         NaN         NaN                  NaN
# 328         NaN         NaN         NaN         NaN                  NaN
# ..          ...         ...         ...         ...                  ...
# 521         NaN         NaN         NaN         NaN                  NaN
# 531         NaN         NaN         NaN         NaN                  NaN
# 537         NaN         NaN         NaN         NaN                  NaN
# 538         NaN         NaN         NaN         NaN                  NaN
# 542         NaN         NaN         NaN         NaN                  NaN
#
#      Excluded_from_controls_Medelian_like observations
# 324                                   NaN          NaN
# 325                                   NaN          NaN
# 326                                   NaN          NaN
# 327                                   NaN          NaN
# 328                                   NaN          NaN
# ..                                    ...          ...
# 521                                   NaN          NaN
# 531                                   NaN          NaN
# 537                                   NaN          NaN
# 538                                   NaN          NaN
# 542                                   NaN          NaN
#
# [123 rows x 12 columns]

# %%
icd9_colnames = [col for col in filtered if "f.41271" in col]

# %%
icd9 = filtered[icd9_colnames]
icd9
# Out:
#        f.41271.0.0 f.41271.0.1 f.41271.0.2 f.41271.0.3 f.41271.0.4  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             <NA>        <NA>        <NA>        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             <NA>        <NA>        <NA>        <NA>        <NA>
# 5             <NA>        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 189004        3899        4781        8131       E8860        V540
# 189005        <NA>        <NA>        <NA>        <NA>        <NA>
# 189006        <NA>        <NA>        <NA>        <NA>        <NA>
# 189007        <NA>        <NA>        <NA>        <NA>        <NA>
# 189008        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.41271.0.5 f.41271.0.6 f.41271.0.7 f.41271.0.8 f.41271.0.9  ...  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 5             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 189004        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189005        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189006        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189007        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189008        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41271.0.37 f.41271.0.38 f.41271.0.39 f.41271.0.40 f.41271.0.41  \
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 189004         <NA>         <NA>         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.41271.0.42 f.41271.0.43 f.41271.0.44 f.41271.0.45 f.41271.0.46
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 189004         <NA>         <NA>         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [185344 rows x 47 columns]

# %%
ex_critia_icd9 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_icd9["Phenotype"].tolist()]
ex_critia_icd9
# Out:
# ['3811',
#  '3812',
#  '3813',
#  '3814',
#  '3815',
#  '3816',
#  '3819',
#  '3821',
#  '3822',
#  '3823',
#  '3824',
#  '3829',
#  '3831',
#  '3832',
#  '3833',
#  '3838',
#  '3839',
#  '3841',
#  '3850',
#  '3851',
#  '3852',
#  '3853',
#  '3858',
#  '3859',
#  '3860',
#  '3863',
#  '3864',
#  '3865',
#  '3868',
#  '3869',
#  '3870',
#  '3871',
#  '3872',
#  '3878',
#  '3879',
#  '3885',
#  '3890',
#  '0530',
#  '0531',
#  '0532',
#  '0537',
#  '0538',
#  '3200',
#  '3201',
#  '3202',
#  '3203',
#  '3204',
#  '3205',
#  '3207',
#  '3208',
#  '3209',
#  '3210',
#  '3211',
#  '3212',
#  '3213',
#  '3214',
#  '3215',
#  '3216',
#  '3217',
#  '3218',
#  '3220',
#  '3221',
#  '3222',
#  '3229',
#  '3230',
#  '3231',
#  '3232',
#  '3233',
#  '3234',
#  '3235',
#  '3236',
#  '3237',
#  '3238',
#  '3239',
#  '3240',
#  '3241',
#  '3249',
#  '3259',
#  '3269',
#  '3510',
#  '3511',
#  '3518',
#  '3519',
#  '8000',
#  '8001',
#  '8002',
#  '8003',
#  '8010',
#  '8011',
#  '8012',
#  '8013',
#  '8022',
#  '8023',
#  '8024',
#  '8025',
#  '8028',
#  '8029',
#  '8030',
#  '8031',
#  '8032',
#  '8033',
#  '8040',
#  '8041',
#  '8042',
#  '8043',
#  '8509',
#  '8510',
#  '8511',
#  '8520',
#  '8521',
#  '8530',
#  '8531',
#  '8540',
#  '8541',
#  '8726',
#  '8727',
#  '8728',
#  '8729',
#  '9050',
#  '9259',
#  '9514',
#  '9515',
#  '9519']

# %%
ex_fxn_icd9 = lambda row: contains_exclusion(row, ex_critia_icd9)
ex_9 = icd9.apply(ex_fxn_icd9, axis=1)

# %%
filtered = filtered[~ex_9]

# %%
filtered
# Out:
#             IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0 f.34.0.0  \
# 1       1000035  1000035       0       0       1      -9     Male     1944
# 2       1000078  1000078       0       0       2      -9   Female     1955
# 3       1000081  1000081       0       0       1      -9     Male     1942
# 4       1000198  1000198       0       0       2      -9   Female     1967
# 5       1000210  1000210       0       0       1      -9     Male     1941
# ...         ...      ...     ...     ...     ...     ...      ...      ...
# 189004  6025295  6025295       0       0       1      -9     Male     1961
# 189005  6025319  6025319       0       0       2      -9   Female     1953
# 189006  6025346  6025346       0       0       2      -9   Female     1954
# 189007  6025363  6025363       0       0       1      -9     Male     1944
# 189008  6025411  6025411       0       0       2      -9   Female     1960
#
#           f.53.0.0    f.53.1.0  ... f.131228.0.0       f.131229.0.0  \
# 1       2007-11-08        <NA>  ...         <NA>               <NA>
# 2       2007-08-20  2012-11-01  ...         <NA>               <NA>
# 3       2009-12-03        <NA>  ...         <NA>               <NA>
# 4       2009-03-27        <NA>  ...         <NA>               <NA>
# 5       2008-02-11        <NA>  ...         <NA>               <NA>
# ...            ...         ...  ...          ...                ...
# 189004  2008-01-24        <NA>  ...   1990-04-05  Primary care only
# 189005  2010-02-03        <NA>  ...         <NA>               <NA>
# 189006  2008-08-19        <NA>  ...         <NA>               <NA>
# 189007  2008-05-17        <NA>  ...         <NA>               <NA>
# 189008  2010-04-29        <NA>  ...         <NA>               <NA>
#
#        f.131230.0.0       f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0  \
# 1              <NA>               <NA>         <NA>         <NA>         <NA>
# 2              <NA>               <NA>         <NA>         <NA>         <NA>
# 3              <NA>               <NA>         <NA>         <NA>         <NA>
# 4              <NA>               <NA>         <NA>         <NA>         <NA>
# 5              <NA>               <NA>         <NA>         <NA>         <NA>
# ...             ...                ...          ...          ...          ...
# 189004   1991-02-25  Primary care only         <NA>         <NA>         <NA>
# 189005         <NA>               <NA>         <NA>         <NA>         <NA>
# 189006         <NA>               <NA>         <NA>         <NA>         <NA>
# 189007         <NA>               <NA>         <NA>         <NA>         <NA>
# 189008         <NA>               <NA>         <NA>         <NA>         <NA>
#
#        f.131251.0.0 f.131252.0.0 f.131253.0.0
# 1              <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>
# ...             ...          ...          ...
# 189004         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>
#
# [185096 rows x 2261 columns]

# %% [markdown]
# ## Filter out f.20002 exclusions

# %%
exclude_f20002 = exclusion[(exclusion["UKBB_field_code"] == "f.20002") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_f20002
# Out:
#     UKBB_field_code                                Phenotype  \
# 544         f.20002                        1420 otosclerosis
# 545         f.20002                   1421 meniere's disease
# 546         f.20002                       1499 labyrinthitis
# 550         f.20002         1244 infection of nervous system
# 551         f.20002  1245 brain abscess/intracranial abscess
# 552         f.20002                        1246 encephalitis
# 553         f.20002                          1247 meningitis
# 555         f.20002         1249 cranial nerve problem/palsy
# 556         f.20002     1250 bell's palsy/facial nerve palsy
# 558         f.20002          1240 neurological injury/trauma
# 563         f.20002               1626 fracture skull / head
# 570         f.20002            1086 subarachnoid haemorrhage
# 571         f.20002                   1491 brain haemorrhage
# 574         f.20002      1083 subdural haemorrhage/haematoma
# 575         f.20002                   1425 cerebral aneurysm
#
#     cases_UKB_showcase Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 544                260                           Y                    NaN
# 545               1553                           Y                    NaN
# 546                417                           Y                    NaN
# 550                 55                           Y                    NaN
# 551                 79                           Y                    NaN
# 552                348                           Y                    NaN
# 553               2214                           Y                    NaN
# 555                289                           Y                    NaN
# 556                591                           Y                    NaN
# 558                130                           Y                    NaN
# 563                465                           Y                    NaN
# 570                492                           Y                    NaN
# 571                218                           Y                    NaN
# 574                212                           Y                    NaN
# 575                352                           Y                    NaN
#
#     Cases_f3393 Cases_f2247 Cases_f2257 Cases_f4803 Cases_Mendelian_like  \
# 544         NaN         NaN         NaN         NaN                  NaN
# 545         NaN         NaN         NaN         NaN                  NaN
# 546         NaN         NaN         NaN         NaN                  NaN
# 550         NaN         NaN         NaN         NaN                  NaN
# 551         NaN         NaN         NaN         NaN                  NaN
# 552         NaN         NaN         NaN         NaN                  NaN
# 553         NaN         NaN         NaN         NaN                  NaN
# 555         NaN         NaN         NaN         NaN                  NaN
# 556         NaN         NaN         NaN         NaN                  NaN
# 558         NaN         NaN         NaN         NaN                  NaN
# 563         NaN         NaN         NaN         NaN                  NaN
# 570         NaN         NaN         NaN         NaN                  NaN
# 571         NaN         NaN         NaN         NaN                  NaN
# 574         NaN         NaN         NaN         NaN                  NaN
# 575         NaN         NaN         NaN         NaN                  NaN
#
#      Excluded_from_controls_Medelian_like observations
# 544                                   NaN          NaN
# 545                                   NaN          NaN
# 546                                   NaN          NaN
# 550                                   NaN          NaN
# 551                                   NaN          NaN
# 552                                   NaN          NaN
# 553                                   NaN          NaN
# 555                                   NaN          NaN
# 556                                   NaN          NaN
# 558                                   NaN          NaN
# 563                                   NaN          NaN
# 570                                   NaN          NaN
# 571                                   NaN          NaN
# 574                                   NaN          NaN
# 575                                   NaN          NaN

# %%
f20002_colnames = [col for col in filtered if "f.20002" in col]

# %%
f20002 = filtered[f20002_colnames]
f20002
# Out:
#        f.20002.0.0 f.20002.0.1 f.20002.0.2 f.20002.0.3 f.20002.0.4  \
# 1             1396        1473        <NA>        <NA>        <NA>
# 2             <NA>        <NA>        <NA>        <NA>        <NA>
# 3             1075        1440        1473        <NA>        <NA>
# 4             <NA>        <NA>        <NA>        <NA>        <NA>
# 5             1065        1123        1286        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 189004        <NA>        <NA>        <NA>        <NA>        <NA>
# 189005        1065        <NA>        <NA>        <NA>        <NA>
# 189006        1452        1265        1387        <NA>        <NA>
# 189007        <NA>        <NA>        <NA>        <NA>        <NA>
# 189008        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.20002.0.5 f.20002.0.6 f.20002.0.7 f.20002.0.8 f.20002.0.9  ...  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 5             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 189004        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189005        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189006        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189007        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 189008        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.20002.3.24 f.20002.3.25 f.20002.3.26 f.20002.3.27 f.20002.3.28  \
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 189004         <NA>         <NA>         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.20002.3.29 f.20002.3.30 f.20002.3.31 f.20002.3.32 f.20002.3.33
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 189004         <NA>         <NA>         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [185096 rows x 136 columns]

# %%
ex_critia_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_f20002["Phenotype"].tolist()]
ex_critia_f20002
# Out:
# ['1420',
#  '1421',
#  '1499',
#  '1244',
#  '1245',
#  '1246',
#  '1247',
#  '1249',
#  '1250',
#  '1240',
#  '1626',
#  '1086',
#  '1491',
#  '1083',
#  '1425']

# %%
ex_fxn_f20002 = lambda row: contains_exclusion(row, ex_critia_f20002)
ex_f20002 = f20002.apply(ex_fxn_f20002, axis=1)

# %%
filtered = filtered[~ex_f20002]

# %%
filtered
# Out:
#             IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0 f.34.0.0  \
# 1       1000035  1000035       0       0       1      -9     Male     1944
# 2       1000078  1000078       0       0       2      -9   Female     1955
# 3       1000081  1000081       0       0       1      -9     Male     1942
# 4       1000198  1000198       0       0       2      -9   Female     1967
# 5       1000210  1000210       0       0       1      -9     Male     1941
# ...         ...      ...     ...     ...     ...     ...      ...      ...
# 189004  6025295  6025295       0       0       1      -9     Male     1961
# 189005  6025319  6025319       0       0       2      -9   Female     1953
# 189006  6025346  6025346       0       0       2      -9   Female     1954
# 189007  6025363  6025363       0       0       1      -9     Male     1944
# 189008  6025411  6025411       0       0       2      -9   Female     1960
#
#           f.53.0.0    f.53.1.0  ... f.131228.0.0       f.131229.0.0  \
# 1       2007-11-08        <NA>  ...         <NA>               <NA>
# 2       2007-08-20  2012-11-01  ...         <NA>               <NA>
# 3       2009-12-03        <NA>  ...         <NA>               <NA>
# 4       2009-03-27        <NA>  ...         <NA>               <NA>
# 5       2008-02-11        <NA>  ...         <NA>               <NA>
# ...            ...         ...  ...          ...                ...
# 189004  2008-01-24        <NA>  ...   1990-04-05  Primary care only
# 189005  2010-02-03        <NA>  ...         <NA>               <NA>
# 189006  2008-08-19        <NA>  ...         <NA>               <NA>
# 189007  2008-05-17        <NA>  ...         <NA>               <NA>
# 189008  2010-04-29        <NA>  ...         <NA>               <NA>
#
#        f.131230.0.0       f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0  \
# 1              <NA>               <NA>         <NA>         <NA>         <NA>
# 2              <NA>               <NA>         <NA>         <NA>         <NA>
# 3              <NA>               <NA>         <NA>         <NA>         <NA>
# 4              <NA>               <NA>         <NA>         <NA>         <NA>
# 5              <NA>               <NA>         <NA>         <NA>         <NA>
# ...             ...                ...          ...          ...          ...
# 189004   1991-02-25  Primary care only         <NA>         <NA>         <NA>
# 189005         <NA>               <NA>         <NA>         <NA>         <NA>
# 189006         <NA>               <NA>         <NA>         <NA>         <NA>
# 189007         <NA>               <NA>         <NA>         <NA>         <NA>
# 189008         <NA>               <NA>         <NA>         <NA>         <NA>
#
#        f.131251.0.0 f.131252.0.0 f.131253.0.0
# 1              <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>
# ...             ...          ...          ...
# 189004         <NA>         <NA>         <NA>
# 189005         <NA>         <NA>         <NA>
# 189006         <NA>         <NA>         <NA>
# 189007         <NA>         <NA>         <NA>
# 189008         <NA>         <NA>         <NA>
#
# [182675 rows x 2261 columns]

# %% [markdown]
# ### Identify Sex Column

# %%
def find_sex(row):
    if row["f.31.0.0"] == "Male":
        return 0
    return 1

sex = filtered[["f.31.0.0"]].apply(find_sex, axis=1)
sex
# Out:
# 1         0
# 2         1
# 3         0
# 4         1
# 5         0
#          ..
# 189004    0
# 189005    1
# 189006    1
# 189007    0
# 189008    1
# Length: 182675, dtype: int64

# %%
filtered["sex"] = sex
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/312352638.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["sex"] = sex
# /home/tf2478/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
filtered
# Out:
#             IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0 f.34.0.0  \
# 1       1000035  1000035       0       0       1      -9     Male     1944
# 2       1000078  1000078       0       0       2      -9   Female     1955
# 3       1000081  1000081       0       0       1      -9     Male     1942
# 4       1000198  1000198       0       0       2      -9   Female     1967
# 5       1000210  1000210       0       0       1      -9     Male     1941
# ...         ...      ...     ...     ...     ...     ...      ...      ...
# 189004  6025295  6025295       0       0       1      -9     Male     1961
# 189005  6025319  6025319       0       0       2      -9   Female     1953
# 189006  6025346  6025346       0       0       2      -9   Female     1954
# 189007  6025363  6025363       0       0       1      -9     Male     1944
# 189008  6025411  6025411       0       0       2      -9   Female     1960
#
#           f.53.0.0    f.53.1.0  ...       f.131229.0.0 f.131230.0.0  \
# 1       2007-11-08        <NA>  ...               <NA>         <NA>
# 2       2007-08-20  2012-11-01  ...               <NA>         <NA>
# 3       2009-12-03        <NA>  ...               <NA>         <NA>
# 4       2009-03-27        <NA>  ...               <NA>         <NA>
# 5       2008-02-11        <NA>  ...               <NA>         <NA>
# ...            ...         ...  ...                ...          ...
# 189004  2008-01-24        <NA>  ...  Primary care only   1991-02-25
# 189005  2010-02-03        <NA>  ...               <NA>         <NA>
# 189006  2008-08-19        <NA>  ...               <NA>         <NA>
# 189007  2008-05-17        <NA>  ...               <NA>         <NA>
# 189008  2010-04-29        <NA>  ...               <NA>         <NA>
#
#              f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0 f.131251.0.0  \
# 1                    <NA>         <NA>         <NA>         <NA>         <NA>
# 2                    <NA>         <NA>         <NA>         <NA>         <NA>
# 3                    <NA>         <NA>         <NA>         <NA>         <NA>
# 4                    <NA>         <NA>         <NA>         <NA>         <NA>
# 5                    <NA>         <NA>         <NA>         <NA>         <NA>
# ...                   ...          ...          ...          ...          ...
# 189004  Primary care only         <NA>         <NA>         <NA>         <NA>
# 189005               <NA>         <NA>         <NA>         <NA>         <NA>
# 189006               <NA>         <NA>         <NA>         <NA>         <NA>
# 189007               <NA>         <NA>         <NA>         <NA>         <NA>
# 189008               <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.131252.0.0 f.131253.0.0 sex
# 1              <NA>         <NA>   0
# 2              <NA>         <NA>   1
# 3              <NA>         <NA>   0
# 4              <NA>         <NA>   1
# 5              <NA>         <NA>   0
# ...             ...          ...  ..
# 189004         <NA>         <NA>   0
# 189005         <NA>         <NA>   1
# 189006         <NA>         <NA>   1
# 189007         <NA>         <NA>   0
# 189008         <NA>         <NA>   1
#
# [182675 rows x 2262 columns]

# %%
filtered = filtered.reset_index()
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/476735807.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered = filtered.reset_index()

# %%
saved_filtered = filtered

# %%
filtered = saved_filtered

# %% [markdown]
# # f.3393, f.2247, f.2257

# %% [markdown]
# ## Remove inconsistencies or unclear individuals

# %% [markdown]
# Some individuals might be unclear on if they do or do not have hearing difficulties or are inconsistent (found in f.3393, f.2247, and f.2257 ), in which case they cannot be considered either controls or cases and must be removed.
#
# The conditions for being removed are as follows:
# * Saying I don't know after saying either yes or no
# * Only saying I don't know or prefer not to say
# * Being completely deaf

# %% [markdown]
# ### Prior to filtering for inconsistencies

# %% [markdown]
# <b>Hearing difficulty/problems with background noise</b> <br>
# f.2257 = {'Yes': 81218, NA : 513774, 'No': 131091, 'Do not know': 4409, 'Prefer not to answer': 208}

# %% [markdown]
# <b>Hearing difficult/problems</b><br>
# f.2247 = {'No': 151758, : 513806, 'Yes': 55437, 'Do not know': 9489, 'Prefer not to answer': 171, 'I am completely deaf': 39}

# %% [markdown]
# <b>Hearing aid user</b><br>
# f.3393 = {'No': 145486, : 577795, 'Yes': 7237, 'Prefer not to answer': 182}

# %%
phens = ["f.3393", "f.2247", "f.2257"]

hearing_imp_f3393 = [col for col in filtered if "f.3393" in col]
hearing_imp_f2247 = [col for col in filtered if "f.2247" in col]
hearing_imp_f2257 = [col for col in filtered if "f.2257" in col]

icd_10_cols = [col for col in df if "f.41270" in col]
icd_9_cols = [col for col in df if "f.41271" in col]

# %%
hearing_ans = {"Do not know":9, "Yes":1, "No":0}
options = set()
# pass one pheno at a time
def find_options(row):
    answer = "".join([str(hearing_ans[i]) for i in row if not pd.isna(i) and i != "I am completely deaf" and i != "Prefer not to answer"])
    options.add(answer)

# %%
hearing_imp_qs = filtered[hearing_imp_f3393]
s = hearing_imp_qs.apply(find_options, axis=1)
hearing_imp_qs = filtered[hearing_imp_f2247]
s = hearing_imp_qs.apply(find_options, axis=1)
hearing_imp_qs = filtered[hearing_imp_f2257]
s = hearing_imp_qs.apply(find_options, axis=1)

# %%
options
# Out:
# {'',
#  '0',
#  '00',
#  '000',
#  '0000',
#  '0001',
#  '0009',
#  '001',
#  '0010',
#  '0011',
#  '0019',
#  '009',
#  '0090',
#  '0091',
#  '0099',
#  '01',
#  '010',
#  '0100',
#  '0101',
#  '011',
#  '0110',
#  '0111',
#  '019',
#  '09',
#  '090',
#  '0900',
#  '0901',
#  '091',
#  '0910',
#  '0911',
#  '099',
#  '0991',
#  '1',
#  '10',
#  '100',
#  '1000',
#  '1001',
#  '101',
#  '1011',
#  '109',
#  '1090',
#  '1099',
#  '11',
#  '110',
#  '1100',
#  '1101',
#  '111',
#  '1110',
#  '1111',
#  '1119',
#  '119',
#  '1190',
#  '1191',
#  '19',
#  '190',
#  '1900',
#  '191',
#  '199',
#  '9',
#  '90',
#  '900',
#  '9000',
#  '901',
#  '909',
#  '91',
#  '910',
#  '911',
#  '9110',
#  '9111',
#  '919',
#  '99',
#  '990',
#  '991',
#  '999',
#  '9999'}

# %%
just_do_not_know = [i for i in options if '0' not in i and '9' in i and '1' not in i]
do_not_know_no = [i for i in options if '0' in i and '9' in i and '1' not in i]
do_not_know_yes = [i for i in options if '0' not in i and '9' in i and '1' in i]
yes_no = [i for i in options if '0' in i and '9' not in i and '1' in i]
with_all_three = [i for i in options if '0' in i and '9' in i and '1' in i]
might_inconsistent = do_not_know_no + do_not_know_yes + yes_no + with_all_three
exceptions = ["91","911","9111","991","0001","001","0011","01","011","0111", "0091", "091","0911","0991","9001","901","9011", "90", "900", "9000", "990"]
inconsistent = [i for i in might_inconsistent if i not in exceptions]

# %%
inconsistent
# Out:
# ['09',
#  '0099',
#  '0900',
#  '090',
#  '099',
#  '009',
#  '0009',
#  '0090',
#  '909',
#  '1119',
#  '199',
#  '191',
#  '1191',
#  '119',
#  '919',
#  '19',
#  '1011',
#  '0100',
#  '1110',
#  '010',
#  '101',
#  '1000',
#  '0101',
#  '10',
#  '1001',
#  '100',
#  '1101',
#  '0010',
#  '110',
#  '1100',
#  '0110',
#  '109',
#  '9110',
#  '0019',
#  '1099',
#  '910',
#  '019',
#  '190',
#  '1190',
#  '0910',
#  '1090',
#  '0901',
#  '1900']

# %%
def find_empty(row):
    for i in row:
        if not pd.isna(i):
            return False
    return True

# %%
def find_dont_know(row):
    temp = []
    for i in row:
        if not pd.isna(i):
            temp.append(i)
        
    if "Do not know" in temp and "Yes" not in temp and "No" not in temp:
        return True
    return False

# %%
# will return true if that row should be removed
# pass one pheno at a time
def find_inconsistencies(row):
    for i in row:
        if not pd.isna(i) and i == "I am completely deaf":
            return True
    
    answer = "".join([str(hearing_ans[i]) for i in row if not pd.isna(i) and i != "I am completely deaf" and i != "Prefer not to answer"])
    if answer in inconsistent:
        return True
    return False

# if we have individuals that either don't answer or prefer not to say only then we cancel them out
# return true if all the rows have no definitive answers
def find_all_none(row):
    for i in row:
        if not pd.isna(i) and (i == "Yes" or i == "No"):
            return False
    return True

# %% [markdown]
# ### Error checking numbers

# %%
hearing_imp_qs = filtered[hearing_imp_f2257]
sum(hearing_imp_qs.apply(find_empty, axis=1))
# Out:
# 232

# %%
hearing_imp_qs = filtered[hearing_imp_f2257]
sum(hearing_imp_qs.apply(find_dont_know, axis=1))
# Out:
# 3187

# %%
hearing_imp_qs = filtered[hearing_imp_f2247]
sum(hearing_imp_qs.apply(find_dont_know, axis=1))
# Out:
# 6759

# %%
hearing_imp_qs = filtered[hearing_imp_f3393]
sum(hearing_imp_qs.apply(find_dont_know, axis=1))
# Out:
# 0

# %%
hearing_imp_qs = filtered[hearing_imp_f2257]
sum(hearing_imp_qs.apply(find_inconsistencies, axis=1))
# Out:
# 2933

# %%
hearing_imp_qs = filtered[hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257]
sum(hearing_imp_qs.apply(find_all_none, axis=1))
# Out:
# 708

# %% [markdown]
# ### Filtering out the data

# %%
filtered
# Out:
#          index      IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0  \
# 0            1  1000035  1000035       0       0       1      -9     Male
# 1            2  1000078  1000078       0       0       2      -9   Female
# 2            3  1000081  1000081       0       0       1      -9     Male
# 3            4  1000198  1000198       0       0       2      -9   Female
# 4            5  1000210  1000210       0       0       1      -9     Male
# ...        ...      ...      ...     ...     ...     ...     ...      ...
# 182670  189004  6025295  6025295       0       0       1      -9     Male
# 182671  189005  6025319  6025319       0       0       2      -9   Female
# 182672  189006  6025346  6025346       0       0       2      -9   Female
# 182673  189007  6025363  6025363       0       0       1      -9     Male
# 182674  189008  6025411  6025411       0       0       2      -9   Female
#
#        f.34.0.0    f.53.0.0  ...       f.131229.0.0 f.131230.0.0  \
# 0          1944  2007-11-08  ...               <NA>         <NA>
# 1          1955  2007-08-20  ...               <NA>         <NA>
# 2          1942  2009-12-03  ...               <NA>         <NA>
# 3          1967  2009-03-27  ...               <NA>         <NA>
# 4          1941  2008-02-11  ...               <NA>         <NA>
# ...         ...         ...  ...                ...          ...
# 182670     1961  2008-01-24  ...  Primary care only   1991-02-25
# 182671     1953  2010-02-03  ...               <NA>         <NA>
# 182672     1954  2008-08-19  ...               <NA>         <NA>
# 182673     1944  2008-05-17  ...               <NA>         <NA>
# 182674     1960  2010-04-29  ...               <NA>         <NA>
#
#              f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0 f.131251.0.0  \
# 0                    <NA>         <NA>         <NA>         <NA>         <NA>
# 1                    <NA>         <NA>         <NA>         <NA>         <NA>
# 2                    <NA>         <NA>         <NA>         <NA>         <NA>
# 3                    <NA>         <NA>         <NA>         <NA>         <NA>
# 4                    <NA>         <NA>         <NA>         <NA>         <NA>
# ...                   ...          ...          ...          ...          ...
# 182670  Primary care only         <NA>         <NA>         <NA>         <NA>
# 182671               <NA>         <NA>         <NA>         <NA>         <NA>
# 182672               <NA>         <NA>         <NA>         <NA>         <NA>
# 182673               <NA>         <NA>         <NA>         <NA>         <NA>
# 182674               <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.131252.0.0 f.131253.0.0 sex
# 0              <NA>         <NA>   0
# 1              <NA>         <NA>   1
# 2              <NA>         <NA>   0
# 3              <NA>         <NA>   1
# 4              <NA>         <NA>   0
# ...             ...          ...  ..
# 182670         <NA>         <NA>   0
# 182671         <NA>         <NA>   1
# 182672         <NA>         <NA>   1
# 182673         <NA>         <NA>   0
# 182674         <NA>         <NA>   1
#
# [182675 rows x 2263 columns]

# %%
hearing_imp_qs = filtered[hearing_imp_f3393]
exclude = hearing_imp_qs.apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

hearing_imp_qs = filtered[hearing_imp_f2247]
exclude = hearing_imp_qs.apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

hearing_imp_qs = filtered[hearing_imp_f2257]
exclude = hearing_imp_qs.apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

hearing_imp_qs = filtered[hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257]
exclude = hearing_imp_qs.apply(find_all_none, axis=1)
filtered = filtered[~exclude]

# %%
filtered
# Out:
#          index      IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0  \
# 0            1  1000035  1000035       0       0       1      -9     Male
# 1            2  1000078  1000078       0       0       2      -9   Female
# 2            3  1000081  1000081       0       0       1      -9     Male
# 3            4  1000198  1000198       0       0       2      -9   Female
# 4            5  1000210  1000210       0       0       1      -9     Male
# ...        ...      ...      ...     ...     ...     ...     ...      ...
# 182670  189004  6025295  6025295       0       0       1      -9     Male
# 182671  189005  6025319  6025319       0       0       2      -9   Female
# 182672  189006  6025346  6025346       0       0       2      -9   Female
# 182673  189007  6025363  6025363       0       0       1      -9     Male
# 182674  189008  6025411  6025411       0       0       2      -9   Female
#
#        f.34.0.0    f.53.0.0  ...       f.131229.0.0 f.131230.0.0  \
# 0          1944  2007-11-08  ...               <NA>         <NA>
# 1          1955  2007-08-20  ...               <NA>         <NA>
# 2          1942  2009-12-03  ...               <NA>         <NA>
# 3          1967  2009-03-27  ...               <NA>         <NA>
# 4          1941  2008-02-11  ...               <NA>         <NA>
# ...         ...         ...  ...                ...          ...
# 182670     1961  2008-01-24  ...  Primary care only   1991-02-25
# 182671     1953  2010-02-03  ...               <NA>         <NA>
# 182672     1954  2008-08-19  ...               <NA>         <NA>
# 182673     1944  2008-05-17  ...               <NA>         <NA>
# 182674     1960  2010-04-29  ...               <NA>         <NA>
#
#              f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0 f.131251.0.0  \
# 0                    <NA>         <NA>         <NA>         <NA>         <NA>
# 1                    <NA>         <NA>         <NA>         <NA>         <NA>
# 2                    <NA>         <NA>         <NA>         <NA>         <NA>
# 3                    <NA>         <NA>         <NA>         <NA>         <NA>
# 4                    <NA>         <NA>         <NA>         <NA>         <NA>
# ...                   ...          ...          ...          ...          ...
# 182670  Primary care only         <NA>         <NA>         <NA>         <NA>
# 182671               <NA>         <NA>         <NA>         <NA>         <NA>
# 182672               <NA>         <NA>         <NA>         <NA>         <NA>
# 182673               <NA>         <NA>         <NA>         <NA>         <NA>
# 182674               <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.131252.0.0 f.131253.0.0 sex
# 0              <NA>         <NA>   0
# 1              <NA>         <NA>   1
# 2              <NA>         <NA>   0
# 3              <NA>         <NA>   1
# 4              <NA>         <NA>   0
# ...             ...          ...  ..
# 182670         <NA>         <NA>   0
# 182671         <NA>         <NA>   1
# 182672         <NA>         <NA>   1
# 182673         <NA>         <NA>   0
# 182674         <NA>         <NA>   1
#
# [176878 rows x 2263 columns]

# %%
saved_2_filtered = filtered

# %%
filtered = saved_2_filtered

# %% [markdown]
# ## Identify Pure Controls

# %% [markdown]
# Need to make sure that for f.3393, f.2247, and f.2257 we obtain the individuals that say no.
#
# The conditions for saying no are as follows:
# * Never saying yes
# * Not being inconsistent
# * Saying no at least once (prefer not to say is allowed)
#
# We are also not including individuals to be part of the control group if they have certain codes for ICD9, ICD10, or f.20002 (this is in the case that they say no to all f.3393, f.2247, and f.2257). However these individuals can still be part of the cases

# %%
# returns 0 if it's a ctrl or else 1
def find_ctrl(row):
    answer = "".join([str(hearing_ans[i]) for i in row if not pd.isna(i) and i != "Prefer not to answer"])
    if "0" in answer and "1" not in answer:
        return 0
    return 1

# returns 0 if it's a ctrl or else 1
# this is specific for f3393
def find_ctrl_or_NA(row):
    for i in row:
        if not pd.isna(i) and i != "No" and i != "Prefer not to answer": # if we have any answers that are not NA or No only then we don't have a ctrl
            return 1
    return 0

# %%
hearing_imp_qs = filtered[hearing_imp_f3393]
f3393_ctrl = hearing_imp_qs.apply(find_ctrl_or_NA, axis=1).to_list()
hearing_imp_qs = filtered[hearing_imp_f2247]
f2247_ctrl = hearing_imp_qs.apply(find_ctrl, axis=1).to_list()
hearing_imp_qs = filtered[hearing_imp_f2257]
f2257_ctrl = hearing_imp_qs.apply(find_ctrl, axis=1).to_list()

# %%
pure_ctrl = [0 if i == 0 and f2247_ctrl[en] == 0 and f2257_ctrl[en] == 0 else 1 for en, i in enumerate(f3393_ctrl)]

# %%
sum(pure_ctrl)
# Out:
# 78593

# %%
len(pure_ctrl)
# Out:
# 176878

# %% [markdown]
# ### Remove ICD 10 Codes from CTRL

# %%
exclude_ctrl_icd10 = exclusion[(exclusion["UKBB_field_code"] == "f.41270") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd10
# Out:
#     UKBB_field_code                                          Phenotype  \
# 97          f.41270                   H83.3 Noise effects on inner ear
# 98          f.41270        H83.8 Other specified diseases of inner ear
# 99          f.41270            H83.9 Disease of inner ear, unspecified
# 105         f.41270        H90.3 Sensorineural hearing loss, bilateral
# 106         f.41270  H90.4 Sensorineural hearing loss, unilateral w...
# 107         f.41270      H90.5 Sensorineural hearing loss, unspecified
# 108         f.41270  H90.6 Mixed conductive and sensorineural heari...
# 109         f.41270  H90.7 Mixed conductive and sensorineural heari...
# 110         f.41270  H90.8 Mixed conductive and sensorineural heari...
# 113         f.41270                                  H91.1 Presbycusis
# 114         f.41270               H91.2 Sudden idiopathic hearing loss
# 115         f.41270        H91.3 Deaf mutism, not elsewhere classified
# 116         f.41270                 H91.8 Other specified hearing loss
# 117         f.41270                    H91.9 Hearing loss, unspecified
# 123         f.41270   H93.0 Degenerative and vascular disorders of ear
# 125         f.41270          H93.2 Other abnormal auditory perceptions
# 126         f.41270                  H93.3 Disorders of acoustic nerve
# 127         f.41270             H93.8 Other specified disorders of ear
# 128         f.41270                 H93.9 Disorder of ear, unspecified
# 137         f.41270        Z46.1 Fitting and adjustment of hearing aid
# 138         f.41270             Z97.4 Presence of external hearing-aid
#
#     cases_UKB_showcase Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 97                  24                           N                      Y
# 98                  51                           N                      Y
# 99                  33                           N                      Y
# 105                721                           N                      Y
# 106                185                           N                      Y
# 107                880                           N                      Y
# 108                133                           N                      Y
# 109                 75                           N                      Y
# 110                115                           N                      Y
# 113                408                           N                      Y
# 114                 30                           N                      Y
# 115                 56                           N                      Y
# 116                133                           N                      Y
# 117               9386                           N                      Y
# 123                  1                           N                      Y
# 125                 28                           N                      Y
# 126                 27                           Y                      Y
# 127                 68                           N                      Y
# 128                 75                           N                      Y
# 137                 31                           N                      Y
# 138               1682                           N                      Y
#
#                                          Cases_f3393  \
# 97                                               NaN
# 98                                               NaN
# 99                                               NaN
# 105  Y if individual is positive for f3393 and >55yo
# 106  Y if individual is positive for f3393 and >55yo
# 107  Y if individual is positive for f3393 and >55yo
# 108  Y if individual is positive for f3393 and >55yo
# 109  Y if individual is positive for f3393 and >55yo
# 110  Y if individual is positive for f3393 and >55yo
# 113                                              NaN
# 114                                              NaN
# 115                                              NaN
# 116                                              NaN
# 117                                              NaN
# 123                                              NaN
# 125                                              NaN
# 126                                              NaN
# 127                                              NaN
# 128                                              NaN
# 137                                                Y
# 138                                                Y
#
#                                            Cases_f2247  \
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 105    Y if individual is positive for f2247 and >55yo
# 106    Y if individual is positive for f2247 and >55yo
# 107    Y if individual is positive for f2247 and >55yo
# 108    Y if individual is positive for f2247 and >55yo
# 109    Y if individual is positive for f2247 and >55yo
# 110    Y if individual is positive for f2247 and >55yo
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 123                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 137  N (Case only if they reply yes consistenly to ...
# 138  N (Case only if they reply yes consistenly to ...
#
#                                          Cases_f2257 Cases_f4803  \
# 97                                               NaN         NaN
# 98                                               NaN         NaN
# 99                                               NaN         NaN
# 105  Y if individual is positive for f2257 and >55yo         NaN
# 106  Y if individual is positive for f2257 and >55yo         NaN
# 107  Y if individual is positive for f2257 and >55yo         NaN
# 108  Y if individual is positive for f2257 and >55yo         NaN
# 109  Y if individual is positive for f2257 and >55yo         NaN
# 110  Y if individual is positive for f2257 and >55yo         NaN
# 113                                              NaN         NaN
# 114                                              NaN         NaN
# 115                                              NaN         NaN
# 116                                              NaN         NaN
# 117                                              NaN         NaN
# 123                                              NaN         NaN
# 125                                              NaN         NaN
# 126                                              NaN         NaN
# 127                                              NaN         NaN
# 128                                              NaN         NaN
# 137                                                N         NaN
# 138                                                N         NaN
#
#     Cases_Mendelian_like  Excluded_from_controls_Medelian_like  \
# 97                   NaN                                   NaN
# 98                   NaN                                   NaN
# 99                   NaN                                   NaN
# 105                    Y                                   NaN
# 106                    N                                   NaN
# 107                    Y                                   NaN
# 108                    Y                                   NaN
# 109                    N                                   NaN
# 110                    Y                                   NaN
# 113                    N                                   NaN
# 114                    N                                   NaN
# 115                    Y                                   NaN
# 116                    Y                                   NaN
# 117                    Y                                   NaN
# 123                    N                                   NaN
# 125                    N                                   NaN
# 126                    N                                   NaN
# 127                    N                                   NaN
# 128                    N                                   NaN
# 137                  NaN                                   NaN
# 138                  NaN                                   NaN
#
#                                           observations
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 105  Individuals with this code were initially excl...
# 106                                                NaN
# 107  Individuals with this code were initially excl...
# 108  Individuals with this code were initially excl...
# 109                                                NaN
# 110  Individuals with this code were initially excl...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 123                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 137          *not included in the first case filtering
# 138                                                NaN

# %%
ex_critia_ctrl_icd10 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd10["Phenotype"].tolist()]
ex_critia_ctrl_icd10
# Out:
# ['H833',
#  'H838',
#  'H839',
#  'H903',
#  'H904',
#  'H905',
#  'H906',
#  'H907',
#  'H908',
#  'H911',
#  'H912',
#  'H913',
#  'H918',
#  'H919',
#  'H930',
#  'H932',
#  'H933',
#  'H938',
#  'H939',
#  'Z461',
#  'Z974']

# %%
icd10 = filtered[icd10_colnames]
icd10
# Out:
#        f.41270.0.0 f.41270.0.1 f.41270.0.2 f.41270.0.3 f.41270.0.4  \
# 0             H269        K579        K590        K621         N40
# 1             D037        L720        <NA>        <NA>        <NA>
# 2             E780        H251        H269         I10        I210
# 3             D171         I10        J301        K409        N898
# 4              C73        C780         D70        E780        F412
# ...            ...         ...         ...         ...         ...
# 182670        D171        I845        I846        K318        K429
# 182671        E669         I10        K801        K802         K85
# 182672        O074        <NA>        <NA>        <NA>        <NA>
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>
# 182674        O149        O266        O342        O471         O48
#
#        f.41270.0.5 f.41270.0.6 f.41270.0.7 f.41270.0.8 f.41270.0.9  ...  \
# 0             R398        Z466        Z538        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             I219        I251        I252        I258        I259  ...
# 3             O800        Z370        Z721        Z822        Z861  ...
# 4             G473        G479        G620         I48        I828  ...
# ...            ...         ...         ...         ...         ...  ...
# 182670        K529        K602        K610        K921        R073  ...
# 182671        M179        M233        N921        R102        <NA>  ...
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182674        O610        O680        Z370        <NA>        <NA>  ...
#
#        f.41270.0.203 f.41270.0.204 f.41270.0.205 f.41270.0.206 f.41270.0.207  \
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 182670          <NA>          <NA>          <NA>          <NA>          <NA>
# 182671          <NA>          <NA>          <NA>          <NA>          <NA>
# 182672          <NA>          <NA>          <NA>          <NA>          <NA>
# 182673          <NA>          <NA>          <NA>          <NA>          <NA>
# 182674          <NA>          <NA>          <NA>          <NA>          <NA>
#
#        f.41270.0.208 f.41270.0.209 f.41270.0.210 f.41270.0.211 f.41270.0.212
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 182670          <NA>          <NA>          <NA>          <NA>          <NA>
# 182671          <NA>          <NA>          <NA>          <NA>          <NA>
# 182672          <NA>          <NA>          <NA>          <NA>          <NA>
# 182673          <NA>          <NA>          <NA>          <NA>          <NA>
# 182674          <NA>          <NA>          <NA>          <NA>          <NA>
#
# [176878 rows x 213 columns]

# %%
ex_fxn_icd10 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd10)
ex_10 = icd10.apply(ex_fxn_icd10, axis=1)

# %% [markdown]
# ### Remove ICD 9 Codes from Ctrl

# %%
exclude_ctrl_icd9 = exclusion[(exclusion["UKBB_field_code"] == "f.41271") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd9
# Out:
#     UKBB_field_code                                         Phenotype  \
# 376         f.41271   3880 Degenerative and vascular disorders of ear
# 377         f.41271                   3881 Noise effects on inner ear
# 378         f.41271             3882 Sudden hearing loss, unspecified
# 380         f.41271           3884 Other abnormal auditory perception
# 384         f.41271             3888 Other specified disorders of ear
# 385         f.41271                3889 Disorders of ear, unspecified
# 388         f.41271                       3891 Sensorineural deafness
# 389         f.41271  3892 Mixed conductive and sensorineural deafness
# 390         f.41271      3897 Deaf mutism, not elsewhere classifiable
# 391         f.41271            3898 Other specified forms of deafness
# 392         f.41271                         3899 Unspecified deafness
# 393         f.41271                        V412 Problems with hearing
# 394         f.41271        V532 Fitting and adjustment of hearing aid
#
#     cases_UKB_showcase Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 376                  0                           N                      Y
# 377                  0                           N                      Y
# 378                  0                           N                      Y
# 380                  0                           N                      Y
# 384                  1                           N                      Y
# 385                  2                           N                      Y
# 388                  6                           N                      Y
# 389                  1                           N                      Y
# 390                  1                           N                      Y
# 391                  0                           N                      Y
# 392                 93                           N                      Y
# 393                  0                           N                      Y
# 394                  0                           N                      Y
#
#                                          Cases_f3393  \
# 376                                              NaN
# 377                                              NaN
# 378                                              NaN
# 380                                              NaN
# 384                                              NaN
# 385                                              NaN
# 388  Y if individual is positive for f3393 and >55yo
# 389  Y if individual is positive for f3393 and >55yo
# 390  Y if individual is positive for f3393 and >55yo
# 391  Y if individual is positive for f3393 and >55yo
# 392  Y if individual is positive for f3393 and >55yo
# 393                                                Y
# 394                                                Y
#
#                                          Cases_f2247  \
# 376                                              NaN
# 377                                              NaN
# 378                                              NaN
# 380                                              NaN
# 384                                              NaN
# 385                                              NaN
# 388  Y if individual is positive for f2247 and >55yo
# 389  Y if individual is positive for f2247 and >55yo
# 390  Y if individual is positive for f2247 and >55yo
# 391  Y if individual is positive for f2247 and >55yo
# 392  Y if individual is positive for f2247 and >55yo
# 393                                                N
# 394                                                N
#
#                                          Cases_f2257 Cases_f4803  \
# 376                                              NaN         NaN
# 377                                              NaN         NaN
# 378                                              NaN         NaN
# 380                                              NaN         NaN
# 384                                              NaN         NaN
# 385                                              NaN         NaN
# 388  Y if individual is positive for f2257 and >55yo         NaN
# 389  Y if individual is positive for f2257 and >55yo         NaN
# 390  Y if individual is positive for f2257 and >55yo         NaN
# 391  Y if individual is positive for f2257 and >55yo         NaN
# 392  Y if individual is positive for f2257 and >55yo         NaN
# 393                                                N         NaN
# 394                                                N         NaN
#
#     Cases_Mendelian_like  Excluded_from_controls_Medelian_like observations
# 376                  NaN                                   NaN          NaN
# 377                  NaN                                   NaN          NaN
# 378                  NaN                                   NaN          NaN
# 380                  NaN                                   NaN          NaN
# 384                  NaN                                   NaN          NaN
# 385                  NaN                                   NaN          NaN
# 388                    Y                                   NaN          NaN
# 389                    Y                                   NaN          NaN
# 390                    Y                                   NaN          NaN
# 391                    Y                                   NaN          NaN
# 392                    Y                                   NaN          NaN
# 393                  NaN                                   NaN          NaN
# 394                  NaN                                   NaN          NaN

# %%
ex_critia_ctrl_icd9 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd9["Phenotype"].tolist()]
ex_critia_ctrl_icd9
# Out:
# ['3880',
#  '3881',
#  '3882',
#  '3884',
#  '3888',
#  '3889',
#  '3891',
#  '3892',
#  '3897',
#  '3898',
#  '3899',
#  'V412',
#  'V532']

# %%
icd9 = filtered[icd9_colnames]
icd9
# Out:
#        f.41271.0.0 f.41271.0.1 f.41271.0.2 f.41271.0.3 f.41271.0.4  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             <NA>        <NA>        <NA>        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             <NA>        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 182670        3899        4781        8131       E8860        V540
# 182671        <NA>        <NA>        <NA>        <NA>        <NA>
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.41271.0.5 f.41271.0.6 f.41271.0.7 f.41271.0.8 f.41271.0.9  ...  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 182670        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182671        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41271.0.37 f.41271.0.38 f.41271.0.39 f.41271.0.40 f.41271.0.41  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.41271.0.42 f.41271.0.43 f.41271.0.44 f.41271.0.45 f.41271.0.46
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [176878 rows x 47 columns]

# %%
ex_fxn_icd9 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd9)
ex_9 = icd9.apply(ex_fxn_icd9, axis=1)

# %% [markdown]
# ### Remove f20002 Codes from Ctrl

# %%
exclude_ctrl_f20002 = exclusion[(exclusion["UKBB_field_code"] == "f.20002") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_f20002
# Out:
# Empty DataFrame
# Columns: [UKBB_field_code, Phenotype, cases_UKB_showcase, Excluded_fulldb_lateonsetHI, Excluded_from_controls, Cases_f3393, Cases_f2247, Cases_f2257, Cases_f4803, Cases_Mendelian_like, Excluded_from_controls_Medelian_like, observations]
# Index: []

# %%
f20002 = filtered[f20002_colnames]
f20002
# Out:
#        f.20002.0.0 f.20002.0.1 f.20002.0.2 f.20002.0.3 f.20002.0.4  \
# 0             1396        1473        <NA>        <NA>        <NA>
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             1075        1440        1473        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             1065        1123        1286        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 182670        <NA>        <NA>        <NA>        <NA>        <NA>
# 182671        1065        <NA>        <NA>        <NA>        <NA>
# 182672        1452        1265        1387        <NA>        <NA>
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.20002.0.5 f.20002.0.6 f.20002.0.7 f.20002.0.8 f.20002.0.9  ...  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 182670        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182671        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.20002.3.24 f.20002.3.25 f.20002.3.26 f.20002.3.27 f.20002.3.28  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.20002.3.29 f.20002.3.30 f.20002.3.31 f.20002.3.32 f.20002.3.33
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [176878 rows x 136 columns]

# %%
ex_critia_ctrl_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_f20002["Phenotype"].tolist()]
ex_critia_ctrl_f20002
# Out:
# []

# %%
ex_fxn_f20002 = lambda row: contains_exclusion(row, ex_critia_ctrl_f20002)
ex_f20002 = f20002.apply(ex_fxn_f20002, axis=1)

# %%
sum(ex_10), sum(pure_ctrl)
# Out:
# (1659, 78593)

# %%
len(pure_ctrl), len(ex_10)
# Out:
# (176878, 176878)

# %%
sum(pure_ctrl | ex_10 | ex_9 | ex_f20002)
# Out:
# 78796

# %%
temp = pure_ctrl | ex_10 | ex_9 | ex_f20002

# %%
temp = pure_ctrl | ex_10 | ex_9 | ex_f20002
filtered_ctrl = [1 if i else 0 for i in temp.to_list()]

# %%
filtered["hearing_imp_pure_ctrl"] = filtered_ctrl
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/10965548.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["hearing_imp_pure_ctrl"] = filtered_ctrl

# %%
filtered
# Out:
#          index      IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0  \
# 0            1  1000035  1000035       0       0       1      -9     Male
# 1            2  1000078  1000078       0       0       2      -9   Female
# 2            3  1000081  1000081       0       0       1      -9     Male
# 3            4  1000198  1000198       0       0       2      -9   Female
# 4            5  1000210  1000210       0       0       1      -9     Male
# ...        ...      ...      ...     ...     ...     ...     ...      ...
# 182670  189004  6025295  6025295       0       0       1      -9     Male
# 182671  189005  6025319  6025319       0       0       2      -9   Female
# 182672  189006  6025346  6025346       0       0       2      -9   Female
# 182673  189007  6025363  6025363       0       0       1      -9     Male
# 182674  189008  6025411  6025411       0       0       2      -9   Female
#
#        f.34.0.0    f.53.0.0  ... f.131230.0.0       f.131231.0.0 f.131232.0.0  \
# 0          1944  2007-11-08  ...         <NA>               <NA>         <NA>
# 1          1955  2007-08-20  ...         <NA>               <NA>         <NA>
# 2          1942  2009-12-03  ...         <NA>               <NA>         <NA>
# 3          1967  2009-03-27  ...         <NA>               <NA>         <NA>
# 4          1941  2008-02-11  ...         <NA>               <NA>         <NA>
# ...         ...         ...  ...          ...                ...          ...
# 182670     1961  2008-01-24  ...   1991-02-25  Primary care only         <NA>
# 182671     1953  2010-02-03  ...         <NA>               <NA>         <NA>
# 182672     1954  2008-08-19  ...         <NA>               <NA>         <NA>
# 182673     1944  2008-05-17  ...         <NA>               <NA>         <NA>
# 182674     1960  2010-04-29  ...         <NA>               <NA>         <NA>
#
#        f.131233.0.0 f.131250.0.0 f.131251.0.0 f.131252.0.0 f.131253.0.0 sex  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>   0
# 1              <NA>         <NA>         <NA>         <NA>         <NA>   1
# 2              <NA>         <NA>         <NA>         <NA>         <NA>   0
# 3              <NA>         <NA>         <NA>         <NA>         <NA>   1
# 4              <NA>         <NA>         <NA>         <NA>         <NA>   0
# ...             ...          ...          ...          ...          ...  ..
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>   0
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>   1
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>   1
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>   0
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>   1
#
#        hearing_imp_pure_ctrl
# 0                          1
# 1                          0
# 2                          0
# 3                          1
# 4                          1
# ...                      ...
# 182670                     1
# 182671                     0
# 182672                     0
# 182673                     0
# 182674                     0
#
# [176878 rows x 2264 columns]

# %%
filtered = filtered.reset_index()
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/476735807.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered = filtered.reset_index()

# %%
saved_3_filtered = filtered

# %%
filtered = saved_3_filtered

# %% [markdown]
# ### Identify Age and Phenotype Columns

# %%
ages_f21003_col = [col for col in filtered if "f.21003" in col]
ages_f21003_col
# Out:
# ['f.21003.0.0', 'f.21003.1.0', 'f.21003.2.0', 'f.21003.3.0']

# %%
filtered[ages_f21003_col]
# Out:
#        f.21003.0.0 f.21003.1.0 f.21003.2.0 f.21003.3.0
# 0               63        <NA>        <NA>        <NA>
# 1               52          57          60        <NA>
# 2               67        <NA>        <NA>        <NA>
# 3               41        <NA>        <NA>        <NA>
# 4               66        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...
# 176873          46        <NA>        <NA>        <NA>
# 176874          56        <NA>        <NA>        <NA>
# 176875          53        <NA>        <NA>        <NA>
# 176876          64        <NA>        <NA>        <NA>
# 176877          49        <NA>        <NA>        <NA>
#
# [176878 rows x 4 columns]

# %%
def get_ctrl_age(row):
    phens = [hearing_imp_f3393, hearing_imp_f2247, hearing_imp_f2257]
    ages = []
    if row["hearing_imp_pure_ctrl"] == 0:
        temp_all_ages = row[ages_f21003_col].to_list()
        temp_all_ages.reverse()
        
        for phen in phens:
            temp = row[phen].to_list()
            temp.reverse()
            for en, i in enumerate(temp):
                if not pd.isna(i) and i == "No":
                    ages.append(temp_all_ages[en])
                    break
        ages.sort()
        return ages[-1]
    return pd.NA

def get_phen_age(row):
    if row[0] == 1:
        temp = row[1:-4].to_list()
        for en, i in enumerate(temp):
            if not pd.isna(i) and i == "Yes":
                return row[ages_f21003_col][en]
    else:
        return pd.NA
    
def get_min_age(row):
    temp = [i for i in row.to_list() if not pd.isna(i)]
    if len(temp) > 0:
        return min(temp)
    else:
        return pd.NA

# %%
# return 1 if we have a yes (used to find phenos)
def find_yes(row):
    for i in row:
        if not pd.isna(i) and i == "Yes":
            return 1
    return 0

# return 1 if we have a match for the mendelian traits and have at least one of the hearing phenotypes
def find_medelian_like(row):
    mendelian_icd10 = ["H903", "H905", "H906", "H908", "H913", "H918", "H919"]
    mendelian_icd9 = ["3891", "3892", "3897", "3898", "3899"]
    
    for i in row[icd_10_cols]:
        if not pd.isna(i) and i in mendelian_icd10:
            return 1
    for i in row[icd_9_cols]:
        if not pd.isna(i) and i in mendelian_icd9:
            return 1
    return 0

def find_exclusions(row):
    mendelian_icd10 = ["H903", "H904", "H905", "H906", "H907", "H908"]
    mendelian_icd9 = ["3891", "3892", "3897", "3898", "3899"]
    
    try:
        if 1 == row[0]: # the first column will be one of the phenotypes, "f3393", "f2247", or "f2257"
            for i in row[icd_10_cols]:
                if not pd.isna(i) and i in mendelian_icd10 and int(row[1]) <= 55: # row[1] must be the age of the phenotype
                    return 0
            for i in row[icd_9_cols]:
                if not pd.isna(i) and i in mendelian_icd9 and int(row[1]) <= 55:
                    return 0
        return int(row[0])
    except:
        print(row.name)

# return 1 if we have a match for the other cases of f3393 or originally had f3393
def find_f3393_other_cases(row):
    mendelian_icd10 = ["Z461", "Z974"]
    mendelian_icd9 = ["V412", "V532"]
    if 0 == int(row["f3393"]):
        for i in row[icd_10_cols]:
            if not pd.isna(i) and i in mendelian_icd10:
                return 1
        for i in row[icd_9_cols]:
            if not pd.isna(i) and i in mendelian_icd9:
                return 1
    return int(row["f3393"])

def check_code(row):
    for i in row:
        if not pd.isna(i) and i == "H919":
            return 1
    return 0

# %%
hearing_imp_qs = filtered[hearing_imp_f3393]
filtered["f3393"] = hearing_imp_qs.apply(find_yes, axis=1)
filtered["f3393_age"] = filtered[["f3393"] + hearing_imp_f3393 + ages_f21003_col].apply(get_phen_age, axis=1)
filtered["f3393"] = filtered[["f3393", "f3393_age"] + icd_10_cols + icd_9_cols].apply(find_exclusions, axis=1)
filtered["f3393"] = filtered[["f3393"] + icd_10_cols + icd_9_cols].apply(find_f3393_other_cases, axis=1)

hearing_imp_qs = filtered[hearing_imp_f2247]
filtered["f2247"] = hearing_imp_qs.apply(find_yes, axis=1)
filtered["f2247_age"] = filtered[["f2247"] + hearing_imp_f2247 + ages_f21003_col].apply(get_phen_age, axis=1)
filtered["f2247"] = filtered[["f2247", "f2247_age"] + icd_10_cols + icd_9_cols].apply(find_exclusions, axis=1)

hearing_imp_qs = filtered[hearing_imp_f2257]
filtered["f2257"] = hearing_imp_qs.apply(find_yes, axis=1)
filtered["f2257_age"] = filtered[["f2257"] + hearing_imp_f2257 + ages_f21003_col].apply(get_phen_age, axis=1)
filtered["f2257"] = filtered[["f2257", "f2257_age"] + icd_10_cols + icd_9_cols].apply(find_exclusions, axis=1)
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/35935787.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247"] = hearing_imp_qs.apply(find_yes, axis=1)
# /tmp/1752830.1.csg.q/ipykernel_10858/35935787.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247_age"] = filtered[["f2247"] + hearing_imp_f2247 + ages_f21003_col].apply(get_phen_age, axis=1)
# /tmp/1752830.1.csg.q/ipykernel_10858/35935787.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2257"] = hearing_imp_qs.apply(find_yes, axis=1)
# /tmp/1752830.1.csg.q/ipykernel_10858/35935787.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2257_age"] = filtered[["f2257"] + hearing_imp_f2257 + ages_f21003_col].apply(get_phen_age, axis=1)

# %%
filtered["mendelian_age"] = filtered[ages_f21003_col].apply(get_min_age, axis=1)
filtered["mendelian"] = filtered[icd_10_cols + icd_9_cols + ["f3393", "f2247", "f2257"]].apply(find_medelian_like, axis=1)
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/434942267.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["mendelian_age"] = filtered[ages_f21003_col].apply(get_min_age, axis=1)
# /tmp/1752830.1.csg.q/ipykernel_10858/434942267.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["mendelian"] = filtered[icd_10_cols + icd_9_cols + ["f3393", "f2247", "f2257"]].apply(find_medelian_like, axis=1)

# %%
filtered["ctrl_age"] = filtered[["hearing_imp_pure_ctrl"] + ages_f21003_col +  hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257].apply(get_ctrl_age, axis=1)
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/2594180301.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["ctrl_age"] = filtered[["hearing_imp_pure_ctrl"] + ages_f21003_col +  hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257].apply(get_ctrl_age, axis=1)

# %%
filtered["f2247_f2257"] = filtered["f2247"] & filtered["f2257"]
filtered["f2247_f2257_age"] = filtered[["f2247_age", "f2257_age"]].apply(get_min_age, axis=1)
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/3344588228.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247_f2257"] = filtered["f2247"] & filtered["f2257"]
# /tmp/1752830.1.csg.q/ipykernel_10858/3344588228.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247_f2257_age"] = filtered[["f2247_age", "f2257_age"]].apply(get_min_age, axis=1)

# %% [markdown]
# ## File Output

# %%
filtered
# Out:
#         level_0   index      IID      FID ignore1 ignore2 ignore3 ignore4  \
# 0             0       1  1000035  1000035       0       0       1      -9
# 1             1       2  1000078  1000078       0       0       2      -9
# 2             2       3  1000081  1000081       0       0       1      -9
# 3             3       4  1000198  1000198       0       0       2      -9
# 4             4       5  1000210  1000210       0       0       1      -9
# ...         ...     ...      ...      ...     ...     ...     ...     ...
# 176873   182670  189004  6025295  6025295       0       0       1      -9
# 176874   182671  189005  6025319  6025319       0       0       2      -9
# 176875   182672  189006  6025346  6025346       0       0       2      -9
# 176876   182673  189007  6025363  6025363       0       0       1      -9
# 176877   182674  189008  6025411  6025411       0       0       2      -9
#
#        f.31.0.0 f.34.0.0  ... f3393_age f2247 f2247_age f2257 f2257_age  \
# 0          Male     1944  ...       NaN     0      <NA>     1        63
# 1        Female     1955  ...       NaN     0      <NA>     0      <NA>
# 2          Male     1942  ...       NaN     0      <NA>     0      <NA>
# 3        Female     1967  ...       NaN     1        41     1        41
# 4          Male     1941  ...       NaN     0      <NA>     0      <NA>
# ...         ...      ...  ...       ...   ...       ...   ...       ...
# 176873     Male     1961  ...       NaN     0       NaN     0      <NA>
# 176874   Female     1953  ...       NaN     0       NaN     0      <NA>
# 176875   Female     1954  ...       NaN     0       NaN     0      <NA>
# 176876     Male     1944  ...       NaN     0       NaN     0      <NA>
# 176877   Female     1960  ...       NaN     0       NaN     0      <NA>
#
#        mendelian_age mendelian ctrl_age f2247_f2257 f2247_f2257_age
# 0                 63         0     <NA>           0              63
# 1                 52         0       60           0            <NA>
# 2                 67         0       67           0            <NA>
# 3                 41         0     <NA>           1              41
# 4                 66         0     <NA>           0            <NA>
# ...              ...       ...      ...         ...             ...
# 176873            46         1     <NA>           0             NaN
# 176874            56         0       56           0             NaN
# 176875            53         0       53           0             NaN
# 176876            64         0       64           0             NaN
# 176877            49         0       49           0             NaN
#
# [176878 rows x 2276 columns]

# %%
filtered[filtered["hearing_imp_pure_ctrl"] == 0][["FID", "IID", "sex", "hearing_imp_pure_ctrl", "ctrl_age"]].to_csv("pure_ctrl_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["f3393"] == 1][["FID", "IID", "sex", "f3393", "f3393_age"]].to_csv("f3393_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["f2247"] == 1][["FID", "IID", "sex", "f2247", "f2247_age"]].to_csv("f2247_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["f2257"] == 1][["FID", "IID", "sex", "f2257", "f2257_age"]].to_csv("f2257_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["f2247_f2257"] == 1][["FID", "IID", "sex", "f2247_f2257", "f2247_f2257_age"]].to_csv("f2247_f2257_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["mendelian"] == 1][["FID", "IID", "sex", "mendelian", "mendelian_age"]].to_csv("mendelian_pheno_file.tsv", sep='\t', index=False)

# %% [markdown]
# # Tinnitus

# %% [markdown]
# ## Remove inconsistencies or unclear individuals

# %% [markdown]
# ### Prior to filtering for inconsistencies

# %% [markdown]
# <b>Tinnitus</b> <br>
# f.4803 = {'No, never': 76141,
#  'Yes, but not now, but have in the past': 11400,
#  'Yes, now some of the time': 9788,
#  'Yes, now a lot of the time': 2973,
#  'Yes, now most or all of the time': 7426,
#  'Do not know': 1745,
#  'Prefer not to answer': 127}

# %%
filtered = saved_filtered

# %%
tin_cols = [col for col in filtered if "f.4803" in col]

# %%
tin_ans = {"Do not know":9, "Yes":1, "No":0, 'Yes, but not now, but have in the past':1, 'Yes, now some of the time':1, 'Yes, now a lot of the time':1, 'Yes, now most or all of the time':1, 'No, never':0}
options = set()
# pass one pheno at a time
def find_options(row):
    answer = "".join([str(tin_ans[i]) for i in row if not pd.isna(i) and i != "Prefer not to answer"])
    options.add(answer)

# %%
s = filtered[tin_cols].apply(find_options, axis=1)

# %%
options
# Out:
# {'',
#  '0',
#  '00',
#  '000',
#  '0000',
#  '0001',
#  '001',
#  '0010',
#  '0011',
#  '009',
#  '01',
#  '010',
#  '0100',
#  '011',
#  '0111',
#  '019',
#  '09',
#  '090',
#  '091',
#  '099',
#  '1',
#  '10',
#  '100',
#  '1000',
#  '101',
#  '1010',
#  '1011',
#  '11',
#  '110',
#  '1100',
#  '1101',
#  '111',
#  '1110',
#  '1111',
#  '119',
#  '19',
#  '190',
#  '191',
#  '1919',
#  '199',
#  '9',
#  '90',
#  '900',
#  '901',
#  '909',
#  '91',
#  '911',
#  '99',
#  '990',
#  '991'}

# %%
just_do_not_know = [i for i in options if '0' not in i and '9' in i and '1' not in i]
do_not_know_no = [i for i in options if '0' in i and '9' in i and '1' not in i]
do_not_know_yes = [i for i in options if '0' not in i and '9' in i and '1' in i]
yes_no = [i for i in options if '0' in i and '9' not in i and '1' in i]
with_all_three = [i for i in options if '0' in i and '9' in i and '1' in i]
might_inconsistent = do_not_know_no + do_not_know_yes + yes_no + with_all_three
exceptions = ["91","911","9111","991","0001","001","0011","01","011","0111", "0091", "091","0911","0991","9001","901","9011", "90", "900", "9000", "990"]
inconsistent = [i for i in might_inconsistent if i not in exceptions]

# %%
inconsistent
# Out:
# ['09',
#  '090',
#  '099',
#  '009',
#  '909',
#  '199',
#  '191',
#  '1919',
#  '119',
#  '19',
#  '1011',
#  '0100',
#  '1110',
#  '010',
#  '1000',
#  '101',
#  '10',
#  '1010',
#  '100',
#  '1101',
#  '0010',
#  '110',
#  '1100',
#  '019',
#  '190']

# %% [markdown]
# ### Filtering out the data

# %%
filtered
# Out:
#          index      IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0  \
# 0            1  1000035  1000035       0       0       1      -9     Male
# 1            2  1000078  1000078       0       0       2      -9   Female
# 2            3  1000081  1000081       0       0       1      -9     Male
# 3            4  1000198  1000198       0       0       2      -9   Female
# 4            5  1000210  1000210       0       0       1      -9     Male
# ...        ...      ...      ...     ...     ...     ...     ...      ...
# 182670  189004  6025295  6025295       0       0       1      -9     Male
# 182671  189005  6025319  6025319       0       0       2      -9   Female
# 182672  189006  6025346  6025346       0       0       2      -9   Female
# 182673  189007  6025363  6025363       0       0       1      -9     Male
# 182674  189008  6025411  6025411       0       0       2      -9   Female
#
#        f.34.0.0    f.53.0.0  ...       f.131229.0.0 f.131230.0.0  \
# 0          1944  2007-11-08  ...               <NA>         <NA>
# 1          1955  2007-08-20  ...               <NA>         <NA>
# 2          1942  2009-12-03  ...               <NA>         <NA>
# 3          1967  2009-03-27  ...               <NA>         <NA>
# 4          1941  2008-02-11  ...               <NA>         <NA>
# ...         ...         ...  ...                ...          ...
# 182670     1961  2008-01-24  ...  Primary care only   1991-02-25
# 182671     1953  2010-02-03  ...               <NA>         <NA>
# 182672     1954  2008-08-19  ...               <NA>         <NA>
# 182673     1944  2008-05-17  ...               <NA>         <NA>
# 182674     1960  2010-04-29  ...               <NA>         <NA>
#
#              f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0 f.131251.0.0  \
# 0                    <NA>         <NA>         <NA>         <NA>         <NA>
# 1                    <NA>         <NA>         <NA>         <NA>         <NA>
# 2                    <NA>         <NA>         <NA>         <NA>         <NA>
# 3                    <NA>         <NA>         <NA>         <NA>         <NA>
# 4                    <NA>         <NA>         <NA>         <NA>         <NA>
# ...                   ...          ...          ...          ...          ...
# 182670  Primary care only         <NA>         <NA>         <NA>         <NA>
# 182671               <NA>         <NA>         <NA>         <NA>         <NA>
# 182672               <NA>         <NA>         <NA>         <NA>         <NA>
# 182673               <NA>         <NA>         <NA>         <NA>         <NA>
# 182674               <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.131252.0.0 f.131253.0.0 sex
# 0              <NA>         <NA>   0
# 1              <NA>         <NA>   1
# 2              <NA>         <NA>   0
# 3              <NA>         <NA>   1
# 4              <NA>         <NA>   0
# ...             ...          ...  ..
# 182670         <NA>         <NA>   0
# 182671         <NA>         <NA>   1
# 182672         <NA>         <NA>   1
# 182673         <NA>         <NA>   0
# 182674         <NA>         <NA>   1
#
# [182675 rows x 2263 columns]

# %%
# will return true if that row should be removed
# pass one pheno at a time
def find_inconsistencies(row):
    for i in row:
        if not pd.isna(i) and i == "I am completely deaf":
            return True
    
    answer = "".join([str(tin_ans[i]) for i in row if not pd.isna(i) and i != "I am completely deaf" and i != "Prefer not to answer"])
    if answer in inconsistent:
        return True
    return False

# %%
exclude = filtered[tin_cols].apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

# %%
filtered
# Out:
#          index      IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0  \
# 0            1  1000035  1000035       0       0       1      -9     Male
# 1            2  1000078  1000078       0       0       2      -9   Female
# 2            3  1000081  1000081       0       0       1      -9     Male
# 3            4  1000198  1000198       0       0       2      -9   Female
# 4            5  1000210  1000210       0       0       1      -9     Male
# ...        ...      ...      ...     ...     ...     ...     ...      ...
# 182670  189004  6025295  6025295       0       0       1      -9     Male
# 182671  189005  6025319  6025319       0       0       2      -9   Female
# 182672  189006  6025346  6025346       0       0       2      -9   Female
# 182673  189007  6025363  6025363       0       0       1      -9     Male
# 182674  189008  6025411  6025411       0       0       2      -9   Female
#
#        f.34.0.0    f.53.0.0  ...       f.131229.0.0 f.131230.0.0  \
# 0          1944  2007-11-08  ...               <NA>         <NA>
# 1          1955  2007-08-20  ...               <NA>         <NA>
# 2          1942  2009-12-03  ...               <NA>         <NA>
# 3          1967  2009-03-27  ...               <NA>         <NA>
# 4          1941  2008-02-11  ...               <NA>         <NA>
# ...         ...         ...  ...                ...          ...
# 182670     1961  2008-01-24  ...  Primary care only   1991-02-25
# 182671     1953  2010-02-03  ...               <NA>         <NA>
# 182672     1954  2008-08-19  ...               <NA>         <NA>
# 182673     1944  2008-05-17  ...               <NA>         <NA>
# 182674     1960  2010-04-29  ...               <NA>         <NA>
#
#              f.131231.0.0 f.131232.0.0 f.131233.0.0 f.131250.0.0 f.131251.0.0  \
# 0                    <NA>         <NA>         <NA>         <NA>         <NA>
# 1                    <NA>         <NA>         <NA>         <NA>         <NA>
# 2                    <NA>         <NA>         <NA>         <NA>         <NA>
# 3                    <NA>         <NA>         <NA>         <NA>         <NA>
# 4                    <NA>         <NA>         <NA>         <NA>         <NA>
# ...                   ...          ...          ...          ...          ...
# 182670  Primary care only         <NA>         <NA>         <NA>         <NA>
# 182671               <NA>         <NA>         <NA>         <NA>         <NA>
# 182672               <NA>         <NA>         <NA>         <NA>         <NA>
# 182673               <NA>         <NA>         <NA>         <NA>         <NA>
# 182674               <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.131252.0.0 f.131253.0.0 sex
# 0              <NA>         <NA>   0
# 1              <NA>         <NA>   1
# 2              <NA>         <NA>   0
# 3              <NA>         <NA>   1
# 4              <NA>         <NA>   0
# ...             ...          ...  ..
# 182670         <NA>         <NA>   0
# 182671         <NA>         <NA>   1
# 182672         <NA>         <NA>   1
# 182673         <NA>         <NA>   0
# 182674         <NA>         <NA>   1
#
# [181519 rows x 2263 columns]

# %% [markdown]
# ## Identify Pure Controls

# %% [markdown]
# Need to make sure that for tinnitus we obtain the individuals that say no.
#
# The conditions for saying no are as follows:
# * Never saying yes
# * Not being inconsistent
# * Saying no at least once (prefer not to say is allowed)
#
# We are also not including individuals to be part of the control group if they have certain codes for ICD9, ICD10, or f.20002 (this is in the case that they say no to all f.3393, f.2247, and f.2257). However these individuals can still be part of the cases

# %%
# returns 0 if it's a ctrl or else 1
def find_ctrl(row):
    answer = "".join([str(tin_ans[i]) for i in row if not pd.isna(i) and i != "Prefer not to answer"])
    if "0" in answer and "1" not in answer:
        return 0
    return 1

# %%
f4803_ctrl = filtered[tin_cols].apply(find_ctrl, axis=1)

# %%
sum(f4803_ctrl)
# Out:
# 118317

# %% [markdown]
# ### Remove ICD 10 Codes from CTRL

# %%
exclude_ctrl_icd10 = exclusion[(exclusion["UKBB_field_code"] == "f.41270") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd10
# Out:
#     UKBB_field_code                                          Phenotype  \
# 97          f.41270                   H83.3 Noise effects on inner ear
# 98          f.41270        H83.8 Other specified diseases of inner ear
# 99          f.41270            H83.9 Disease of inner ear, unspecified
# 105         f.41270        H90.3 Sensorineural hearing loss, bilateral
# 106         f.41270  H90.4 Sensorineural hearing loss, unilateral w...
# 107         f.41270      H90.5 Sensorineural hearing loss, unspecified
# 108         f.41270  H90.6 Mixed conductive and sensorineural heari...
# 109         f.41270  H90.7 Mixed conductive and sensorineural heari...
# 110         f.41270  H90.8 Mixed conductive and sensorineural heari...
# 113         f.41270                                  H91.1 Presbycusis
# 114         f.41270               H91.2 Sudden idiopathic hearing loss
# 115         f.41270        H91.3 Deaf mutism, not elsewhere classified
# 116         f.41270                 H91.8 Other specified hearing loss
# 117         f.41270                    H91.9 Hearing loss, unspecified
# 123         f.41270   H93.0 Degenerative and vascular disorders of ear
# 125         f.41270          H93.2 Other abnormal auditory perceptions
# 126         f.41270                  H93.3 Disorders of acoustic nerve
# 127         f.41270             H93.8 Other specified disorders of ear
# 128         f.41270                 H93.9 Disorder of ear, unspecified
# 137         f.41270        Z46.1 Fitting and adjustment of hearing aid
# 138         f.41270             Z97.4 Presence of external hearing-aid
#
#     cases_UKB_showcase Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 97                  24                           N                      Y
# 98                  51                           N                      Y
# 99                  33                           N                      Y
# 105                721                           N                      Y
# 106                185                           N                      Y
# 107                880                           N                      Y
# 108                133                           N                      Y
# 109                 75                           N                      Y
# 110                115                           N                      Y
# 113                408                           N                      Y
# 114                 30                           N                      Y
# 115                 56                           N                      Y
# 116                133                           N                      Y
# 117               9386                           N                      Y
# 123                  1                           N                      Y
# 125                 28                           N                      Y
# 126                 27                           Y                      Y
# 127                 68                           N                      Y
# 128                 75                           N                      Y
# 137                 31                           N                      Y
# 138               1682                           N                      Y
#
#                                          Cases_f3393  \
# 97                                               NaN
# 98                                               NaN
# 99                                               NaN
# 105  Y if individual is positive for f3393 and >55yo
# 106  Y if individual is positive for f3393 and >55yo
# 107  Y if individual is positive for f3393 and >55yo
# 108  Y if individual is positive for f3393 and >55yo
# 109  Y if individual is positive for f3393 and >55yo
# 110  Y if individual is positive for f3393 and >55yo
# 113                                              NaN
# 114                                              NaN
# 115                                              NaN
# 116                                              NaN
# 117                                              NaN
# 123                                              NaN
# 125                                              NaN
# 126                                              NaN
# 127                                              NaN
# 128                                              NaN
# 137                                                Y
# 138                                                Y
#
#                                            Cases_f2247  \
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 105    Y if individual is positive for f2247 and >55yo
# 106    Y if individual is positive for f2247 and >55yo
# 107    Y if individual is positive for f2247 and >55yo
# 108    Y if individual is positive for f2247 and >55yo
# 109    Y if individual is positive for f2247 and >55yo
# 110    Y if individual is positive for f2247 and >55yo
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 123                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 137  N (Case only if they reply yes consistenly to ...
# 138  N (Case only if they reply yes consistenly to ...
#
#                                          Cases_f2257 Cases_f4803  \
# 97                                               NaN         NaN
# 98                                               NaN         NaN
# 99                                               NaN         NaN
# 105  Y if individual is positive for f2257 and >55yo         NaN
# 106  Y if individual is positive for f2257 and >55yo         NaN
# 107  Y if individual is positive for f2257 and >55yo         NaN
# 108  Y if individual is positive for f2257 and >55yo         NaN
# 109  Y if individual is positive for f2257 and >55yo         NaN
# 110  Y if individual is positive for f2257 and >55yo         NaN
# 113                                              NaN         NaN
# 114                                              NaN         NaN
# 115                                              NaN         NaN
# 116                                              NaN         NaN
# 117                                              NaN         NaN
# 123                                              NaN         NaN
# 125                                              NaN         NaN
# 126                                              NaN         NaN
# 127                                              NaN         NaN
# 128                                              NaN         NaN
# 137                                                N         NaN
# 138                                                N         NaN
#
#     Cases_Mendelian_like  Excluded_from_controls_Medelian_like  \
# 97                   NaN                                   NaN
# 98                   NaN                                   NaN
# 99                   NaN                                   NaN
# 105                    Y                                   NaN
# 106                    N                                   NaN
# 107                    Y                                   NaN
# 108                    Y                                   NaN
# 109                    N                                   NaN
# 110                    Y                                   NaN
# 113                    N                                   NaN
# 114                    N                                   NaN
# 115                    Y                                   NaN
# 116                    Y                                   NaN
# 117                    Y                                   NaN
# 123                    N                                   NaN
# 125                    N                                   NaN
# 126                    N                                   NaN
# 127                    N                                   NaN
# 128                    N                                   NaN
# 137                  NaN                                   NaN
# 138                  NaN                                   NaN
#
#                                           observations
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 105  Individuals with this code were initially excl...
# 106                                                NaN
# 107  Individuals with this code were initially excl...
# 108  Individuals with this code were initially excl...
# 109                                                NaN
# 110  Individuals with this code were initially excl...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 123                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 137          *not included in the first case filtering
# 138                                                NaN

# %%
ex_critia_ctrl_icd10 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd10["Phenotype"].tolist()]
ex_critia_ctrl_icd10
# Out:
# ['H833',
#  'H838',
#  'H839',
#  'H903',
#  'H904',
#  'H905',
#  'H906',
#  'H907',
#  'H908',
#  'H911',
#  'H912',
#  'H913',
#  'H918',
#  'H919',
#  'H930',
#  'H932',
#  'H933',
#  'H938',
#  'H939',
#  'Z461',
#  'Z974']

# %%
icd10 = filtered[icd10_colnames]
icd10
# Out:
#        f.41270.0.0 f.41270.0.1 f.41270.0.2 f.41270.0.3 f.41270.0.4  \
# 0             H269        K579        K590        K621         N40
# 1             D037        L720        <NA>        <NA>        <NA>
# 2             E780        H251        H269         I10        I210
# 3             D171         I10        J301        K409        N898
# 4              C73        C780         D70        E780        F412
# ...            ...         ...         ...         ...         ...
# 182670        D171        I845        I846        K318        K429
# 182671        E669         I10        K801        K802         K85
# 182672        O074        <NA>        <NA>        <NA>        <NA>
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>
# 182674        O149        O266        O342        O471         O48
#
#        f.41270.0.5 f.41270.0.6 f.41270.0.7 f.41270.0.8 f.41270.0.9  ...  \
# 0             R398        Z466        Z538        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             I219        I251        I252        I258        I259  ...
# 3             O800        Z370        Z721        Z822        Z861  ...
# 4             G473        G479        G620         I48        I828  ...
# ...            ...         ...         ...         ...         ...  ...
# 182670        K529        K602        K610        K921        R073  ...
# 182671        M179        M233        N921        R102        <NA>  ...
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182674        O610        O680        Z370        <NA>        <NA>  ...
#
#        f.41270.0.203 f.41270.0.204 f.41270.0.205 f.41270.0.206 f.41270.0.207  \
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 182670          <NA>          <NA>          <NA>          <NA>          <NA>
# 182671          <NA>          <NA>          <NA>          <NA>          <NA>
# 182672          <NA>          <NA>          <NA>          <NA>          <NA>
# 182673          <NA>          <NA>          <NA>          <NA>          <NA>
# 182674          <NA>          <NA>          <NA>          <NA>          <NA>
#
#        f.41270.0.208 f.41270.0.209 f.41270.0.210 f.41270.0.211 f.41270.0.212
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 182670          <NA>          <NA>          <NA>          <NA>          <NA>
# 182671          <NA>          <NA>          <NA>          <NA>          <NA>
# 182672          <NA>          <NA>          <NA>          <NA>          <NA>
# 182673          <NA>          <NA>          <NA>          <NA>          <NA>
# 182674          <NA>          <NA>          <NA>          <NA>          <NA>
#
# [181519 rows x 213 columns]

# %%
ex_fxn_icd10 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd10)
ex_10 = icd10.apply(ex_fxn_icd10, axis=1)

# %% [markdown]
# ### Remove ICD 9 Codes from Ctrl

# %%
exclude_ctrl_icd9 = exclusion[(exclusion["UKBB_field_code"] == "f.41271") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd9
# Out:
#     UKBB_field_code                                         Phenotype  \
# 376         f.41271   3880 Degenerative and vascular disorders of ear
# 377         f.41271                   3881 Noise effects on inner ear
# 378         f.41271             3882 Sudden hearing loss, unspecified
# 380         f.41271           3884 Other abnormal auditory perception
# 384         f.41271             3888 Other specified disorders of ear
# 385         f.41271                3889 Disorders of ear, unspecified
# 388         f.41271                       3891 Sensorineural deafness
# 389         f.41271  3892 Mixed conductive and sensorineural deafness
# 390         f.41271      3897 Deaf mutism, not elsewhere classifiable
# 391         f.41271            3898 Other specified forms of deafness
# 392         f.41271                         3899 Unspecified deafness
# 393         f.41271                        V412 Problems with hearing
# 394         f.41271        V532 Fitting and adjustment of hearing aid
#
#     cases_UKB_showcase Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 376                  0                           N                      Y
# 377                  0                           N                      Y
# 378                  0                           N                      Y
# 380                  0                           N                      Y
# 384                  1                           N                      Y
# 385                  2                           N                      Y
# 388                  6                           N                      Y
# 389                  1                           N                      Y
# 390                  1                           N                      Y
# 391                  0                           N                      Y
# 392                 93                           N                      Y
# 393                  0                           N                      Y
# 394                  0                           N                      Y
#
#                                          Cases_f3393  \
# 376                                              NaN
# 377                                              NaN
# 378                                              NaN
# 380                                              NaN
# 384                                              NaN
# 385                                              NaN
# 388  Y if individual is positive for f3393 and >55yo
# 389  Y if individual is positive for f3393 and >55yo
# 390  Y if individual is positive for f3393 and >55yo
# 391  Y if individual is positive for f3393 and >55yo
# 392  Y if individual is positive for f3393 and >55yo
# 393                                                Y
# 394                                                Y
#
#                                          Cases_f2247  \
# 376                                              NaN
# 377                                              NaN
# 378                                              NaN
# 380                                              NaN
# 384                                              NaN
# 385                                              NaN
# 388  Y if individual is positive for f2247 and >55yo
# 389  Y if individual is positive for f2247 and >55yo
# 390  Y if individual is positive for f2247 and >55yo
# 391  Y if individual is positive for f2247 and >55yo
# 392  Y if individual is positive for f2247 and >55yo
# 393                                                N
# 394                                                N
#
#                                          Cases_f2257 Cases_f4803  \
# 376                                              NaN         NaN
# 377                                              NaN         NaN
# 378                                              NaN         NaN
# 380                                              NaN         NaN
# 384                                              NaN         NaN
# 385                                              NaN         NaN
# 388  Y if individual is positive for f2257 and >55yo         NaN
# 389  Y if individual is positive for f2257 and >55yo         NaN
# 390  Y if individual is positive for f2257 and >55yo         NaN
# 391  Y if individual is positive for f2257 and >55yo         NaN
# 392  Y if individual is positive for f2257 and >55yo         NaN
# 393                                                N         NaN
# 394                                                N         NaN
#
#     Cases_Mendelian_like  Excluded_from_controls_Medelian_like observations
# 376                  NaN                                   NaN          NaN
# 377                  NaN                                   NaN          NaN
# 378                  NaN                                   NaN          NaN
# 380                  NaN                                   NaN          NaN
# 384                  NaN                                   NaN          NaN
# 385                  NaN                                   NaN          NaN
# 388                    Y                                   NaN          NaN
# 389                    Y                                   NaN          NaN
# 390                    Y                                   NaN          NaN
# 391                    Y                                   NaN          NaN
# 392                    Y                                   NaN          NaN
# 393                  NaN                                   NaN          NaN
# 394                  NaN                                   NaN          NaN

# %%
ex_critia_ctrl_icd9 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd9["Phenotype"].tolist()]
ex_critia_ctrl_icd9
# Out:
# ['3880',
#  '3881',
#  '3882',
#  '3884',
#  '3888',
#  '3889',
#  '3891',
#  '3892',
#  '3897',
#  '3898',
#  '3899',
#  'V412',
#  'V532']

# %%
icd9 = filtered[icd9_colnames]
icd9
# Out:
#        f.41271.0.0 f.41271.0.1 f.41271.0.2 f.41271.0.3 f.41271.0.4  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             <NA>        <NA>        <NA>        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             <NA>        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 182670        3899        4781        8131       E8860        V540
# 182671        <NA>        <NA>        <NA>        <NA>        <NA>
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.41271.0.5 f.41271.0.6 f.41271.0.7 f.41271.0.8 f.41271.0.9  ...  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 182670        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182671        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41271.0.37 f.41271.0.38 f.41271.0.39 f.41271.0.40 f.41271.0.41  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.41271.0.42 f.41271.0.43 f.41271.0.44 f.41271.0.45 f.41271.0.46
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [181519 rows x 47 columns]

# %%
ex_fxn_icd9 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd9)
ex_9 = icd9.apply(ex_fxn_icd9, axis=1)

# %% [markdown]
# ### Remove f20002 Codes from Ctrl

# %%
exclude_ctrl_f20002 = exclusion[(exclusion["UKBB_field_code"] == "f.20002") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_f20002
# Out:
# Empty DataFrame
# Columns: [UKBB_field_code, Phenotype, cases_UKB_showcase, Excluded_fulldb_lateonsetHI, Excluded_from_controls, Cases_f3393, Cases_f2247, Cases_f2257, Cases_f4803, Cases_Mendelian_like, Excluded_from_controls_Medelian_like, observations]
# Index: []

# %%
f20002 = filtered[f20002_colnames]
f20002
# Out:
#        f.20002.0.0 f.20002.0.1 f.20002.0.2 f.20002.0.3 f.20002.0.4  \
# 0             1396        1473        <NA>        <NA>        <NA>
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             1075        1440        1473        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             1065        1123        1286        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 182670        <NA>        <NA>        <NA>        <NA>        <NA>
# 182671        1065        <NA>        <NA>        <NA>        <NA>
# 182672        1452        1265        1387        <NA>        <NA>
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.20002.0.5 f.20002.0.6 f.20002.0.7 f.20002.0.8 f.20002.0.9  ...  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 182670        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182671        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182672        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182673        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 182674        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.20002.3.24 f.20002.3.25 f.20002.3.26 f.20002.3.27 f.20002.3.28  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.20002.3.29 f.20002.3.30 f.20002.3.31 f.20002.3.32 f.20002.3.33
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [181519 rows x 136 columns]

# %%
ex_critia_ctrl_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_f20002["Phenotype"].tolist()]
ex_critia_ctrl_f20002
# Out:
# []

# %%
ex_fxn_f20002 = lambda row: contains_exclusion(row, ex_critia_ctrl_f20002)
ex_f20002 = f20002.apply(ex_fxn_f20002, axis=1)

# %%
sum(ex_10), sum(f4803_ctrl)
# Out:
# (1695, 118317)

# %%
sum(f4803_ctrl | ex_10 | ex_9 | ex_f20002)
# Out:
# 118634

# %%
temp = f4803_ctrl | ex_10 | ex_9 | ex_f20002

# %%
temp = f4803_ctrl | ex_10 | ex_9 | ex_f20002
filtered_ctrl = [1 if i else 0 for i in temp.to_list()]

# %%
filtered["tinnitus_pure_ctrl"] = filtered_ctrl
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/1197503685.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["tinnitus_pure_ctrl"] = filtered_ctrl
# /home/tf2478/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
filtered
# Out:
#          index      IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0  \
# 0            1  1000035  1000035       0       0       1      -9     Male
# 1            2  1000078  1000078       0       0       2      -9   Female
# 2            3  1000081  1000081       0       0       1      -9     Male
# 3            4  1000198  1000198       0       0       2      -9   Female
# 4            5  1000210  1000210       0       0       1      -9     Male
# ...        ...      ...      ...     ...     ...     ...     ...      ...
# 182670  189004  6025295  6025295       0       0       1      -9     Male
# 182671  189005  6025319  6025319       0       0       2      -9   Female
# 182672  189006  6025346  6025346       0       0       2      -9   Female
# 182673  189007  6025363  6025363       0       0       1      -9     Male
# 182674  189008  6025411  6025411       0       0       2      -9   Female
#
#        f.34.0.0    f.53.0.0  ... f.131230.0.0       f.131231.0.0 f.131232.0.0  \
# 0          1944  2007-11-08  ...         <NA>               <NA>         <NA>
# 1          1955  2007-08-20  ...         <NA>               <NA>         <NA>
# 2          1942  2009-12-03  ...         <NA>               <NA>         <NA>
# 3          1967  2009-03-27  ...         <NA>               <NA>         <NA>
# 4          1941  2008-02-11  ...         <NA>               <NA>         <NA>
# ...         ...         ...  ...          ...                ...          ...
# 182670     1961  2008-01-24  ...   1991-02-25  Primary care only         <NA>
# 182671     1953  2010-02-03  ...         <NA>               <NA>         <NA>
# 182672     1954  2008-08-19  ...         <NA>               <NA>         <NA>
# 182673     1944  2008-05-17  ...         <NA>               <NA>         <NA>
# 182674     1960  2010-04-29  ...         <NA>               <NA>         <NA>
#
#        f.131233.0.0 f.131250.0.0 f.131251.0.0 f.131252.0.0 f.131253.0.0 sex  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>   0
# 1              <NA>         <NA>         <NA>         <NA>         <NA>   1
# 2              <NA>         <NA>         <NA>         <NA>         <NA>   0
# 3              <NA>         <NA>         <NA>         <NA>         <NA>   1
# 4              <NA>         <NA>         <NA>         <NA>         <NA>   0
# ...             ...          ...          ...          ...          ...  ..
# 182670         <NA>         <NA>         <NA>         <NA>         <NA>   0
# 182671         <NA>         <NA>         <NA>         <NA>         <NA>   1
# 182672         <NA>         <NA>         <NA>         <NA>         <NA>   1
# 182673         <NA>         <NA>         <NA>         <NA>         <NA>   0
# 182674         <NA>         <NA>         <NA>         <NA>         <NA>   1
#
#        tinnitus_pure_ctrl
# 0                       1
# 1                       0
# 2                       0
# 3                       1
# 4                       1
# ...                   ...
# 182670                  1
# 182671                  0
# 182672                  1
# 182673                  1
# 182674                  0
#
# [181519 rows x 2264 columns]

# %% [markdown]
# ### Identify Age and Phenotype Columns

# %%
ages_f21003_col = [col for col in filtered if "f.21003" in col]
ages_f21003_col
# Out:
# ['f.21003.0.0', 'f.21003.1.0', 'f.21003.2.0', 'f.21003.3.0']

# %%
def get_ctrl_age(row):
    phens = [tin_cols]
    ages = []
    if row["tinnitus_pure_ctrl"] == 0:
        temp_all_ages = row[ages_f21003_col].to_list()
        temp_all_ages.reverse()
        
        for phen in phens:
            temp = row[phen].to_list()
            temp.reverse()
            for en, i in enumerate(temp):
                if not pd.isna(i) and i != "Prefer not to answer" and tin_ans[i] == 0:
                    ages.append(temp_all_ages[en])
                    break
        ages.sort()
        return ages[-1]
    return pd.NA

def get_phen_age(row):
    if row[0] == 1:
        temp = row[1:-4].to_list()
        for en, i in enumerate(temp):
            if not pd.isna(i) and i != "Prefer not to answer" and tin_ans[i] == 1:
                return row[ages_f21003_col][en]
    else:
        return pd.NA

# %%
# return 1 if we have a yes (used to find phenos)
def find_yes(row):
    for i in row:
        if not pd.isna(i) and i != "Prefer not to answer" and tin_ans[i] == 1:
            return 1
    return 0

def check_code(row, code):
    for i in row:
        if not pd.isna(i) and i == code:
            return 1
    return 0

# %%
tinn_yes = filtered[tin_cols].apply(find_yes, axis=1)

# %%
tinn_icd10_check_code = lambda row: check_code(row, "H931")
tinn_icd10 = filtered[icd_10_cols].apply(tinn_icd10_check_code, axis = 1)

# %%
tinn_icd9_check_code = lambda row: check_code(row, "3883")
tinn_icd9 = filtered[icd_9_cols].apply(tinn_icd9_check_code, axis = 1)

# %%
self_report_cols = [col for col in filtered if "f.20002" in col]
tinn_self_report_check_code = lambda row: check_code(row, "1597")
tinn_self_report = filtered[self_report_cols].apply(tinn_self_report_check_code, axis = 1)

# %%
sum(tinn_yes | tinn_icd10 | tinn_icd9 | tinn_self_report)
# Out:
# 27053

# %%
filtered["tinnitus_age"] = filtered[ages_f21003_col].apply(get_min_age, axis=1)
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/1160460590.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["tinnitus_age"] = filtered[ages_f21003_col].apply(get_min_age, axis=1)
# /home/tf2478/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
filtered["tinnitus"] = tinn_yes | tinn_icd10 | tinn_icd9 | tinn_self_report
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/3909690993.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["tinnitus"] = tinn_yes | tinn_icd10 | tinn_icd9 | tinn_self_report

# %%
filtered[ages_f21003_col]
# Out:
#        f.21003.0.0 f.21003.1.0 f.21003.2.0 f.21003.3.0
# 0               63        <NA>        <NA>        <NA>
# 1               52          57          60        <NA>
# 2               67        <NA>        <NA>        <NA>
# 3               41        <NA>        <NA>        <NA>
# 4               66        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...
# 182670          46        <NA>        <NA>        <NA>
# 182671          56        <NA>        <NA>        <NA>
# 182672          53        <NA>        <NA>        <NA>
# 182673          64        <NA>        <NA>        <NA>
# 182674          49        <NA>        <NA>        <NA>
#
# [181519 rows x 4 columns]

# %%
filtered["ctrl_age"] = filtered[["tinnitus_pure_ctrl"] + ages_f21003_col + tin_cols].apply(get_ctrl_age, axis=1)
# Out:
# /tmp/1752830.1.csg.q/ipykernel_10858/3348306806.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["ctrl_age"] = filtered[["tinnitus_pure_ctrl"] + ages_f21003_col + tin_cols].apply(get_ctrl_age, axis=1)
# /home/tf2478/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %% [markdown]
# ## File Output

# %%
filtered
# Out:
#          index      IID      FID ignore1 ignore2 ignore3 ignore4 f.31.0.0  \
# 0            1  1000035  1000035       0       0       1      -9     Male
# 1            2  1000078  1000078       0       0       2      -9   Female
# 2            3  1000081  1000081       0       0       1      -9     Male
# 3            4  1000198  1000198       0       0       2      -9   Female
# 4            5  1000210  1000210       0       0       1      -9     Male
# ...        ...      ...      ...     ...     ...     ...     ...      ...
# 182670  189004  6025295  6025295       0       0       1      -9     Male
# 182671  189005  6025319  6025319       0       0       2      -9   Female
# 182672  189006  6025346  6025346       0       0       2      -9   Female
# 182673  189007  6025363  6025363       0       0       1      -9     Male
# 182674  189008  6025411  6025411       0       0       2      -9   Female
#
#        f.34.0.0    f.53.0.0  ... f.131233.0.0 f.131250.0.0 f.131251.0.0  \
# 0          1944  2007-11-08  ...         <NA>         <NA>         <NA>
# 1          1955  2007-08-20  ...         <NA>         <NA>         <NA>
# 2          1942  2009-12-03  ...         <NA>         <NA>         <NA>
# 3          1967  2009-03-27  ...         <NA>         <NA>         <NA>
# 4          1941  2008-02-11  ...         <NA>         <NA>         <NA>
# ...         ...         ...  ...          ...          ...          ...
# 182670     1961  2008-01-24  ...         <NA>         <NA>         <NA>
# 182671     1953  2010-02-03  ...         <NA>         <NA>         <NA>
# 182672     1954  2008-08-19  ...         <NA>         <NA>         <NA>
# 182673     1944  2008-05-17  ...         <NA>         <NA>         <NA>
# 182674     1960  2010-04-29  ...         <NA>         <NA>         <NA>
#
#        f.131252.0.0 f.131253.0.0 sex tinnitus_pure_ctrl tinnitus_age tinnitus  \
# 0              <NA>         <NA>   0                  1           63        0
# 1              <NA>         <NA>   1                  0           52        0
# 2              <NA>         <NA>   0                  0           67        0
# 3              <NA>         <NA>   1                  1           41        0
# 4              <NA>         <NA>   0                  1           66        0
# ...             ...          ...  ..                ...          ...      ...
# 182670         <NA>         <NA>   0                  1           46        0
# 182671         <NA>         <NA>   1                  0           56        0
# 182672         <NA>         <NA>   1                  1           53        0
# 182673         <NA>         <NA>   0                  1           64        0
# 182674         <NA>         <NA>   1                  0           49        0
#
#        ctrl_age
# 0          <NA>
# 1            60
# 2            67
# 3          <NA>
# 4          <NA>
# ...         ...
# 182670     <NA>
# 182671       56
# 182672     <NA>
# 182673     <NA>
# 182674       49
#
# [181519 rows x 2267 columns]

# %%
filtered[filtered["tinnitus_pure_ctrl"] == 0][["FID", "IID", "sex", "tinnitus_pure_ctrl", "ctrl_age"]].to_csv("tinnitus_pure_ctrl_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["tinnitus"] == 1][["FID", "IID", "sex", "tinnitus", "tinnitus_age"]].to_csv("tinnitus_pheno_file.tsv", sep='\t', index=False)

# %% [markdown]
# # Merge Pheno with Ctrl

# %% [markdown]
# ## f2247, f2257, f3393, and mendilian

# %%
ctrl_file_name = "pure_ctrl_pheno_file.tsv"
f3393_file_name = "f3393_pheno_file.tsv"
f2247_file_name = "f2247_pheno_file.tsv"
f2257_file_name = "f2257_pheno_file.tsv"
f2247_f2257_file_name = "f2247_f2257_pheno_file.tsv"
mendilianlike_file_name = "mendilian-like_pheno_file.tsv"

# %%
f3393 = pd.read_csv(f3393_file_name, sep="\t")
f2247 = pd.read_csv(f2247_file_name, sep="\t")
f2257 = pd.read_csv(f2257_file_name, sep="\t")
f2247_f2257 = pd.read_csv(f2247_f2257_file_name, sep="\t")
ctrl = pd.read_csv(ctrl_file_name, sep="\t")
mendlike = pd.read_csv(mendilianlike_file_name, sep="\t")

# %%
print("ctrl: ",len(ctrl))
print("f2247: ",len(f2247))
print("f2257: ",len(f2257))
print("f2247_f2257: ",len(f2247_f2257))
print("f3393: ",len(f3393))
print("mendlike: ",len(mendlike))
# Out:
# ctrl:  98082
# f2247:  46237
# f2257:  66656
# f2247_f2257:  39049
# f3393:  6305
# mendlike:  1520

# %% [markdown]
# ### f2247

# %%
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f2247.columns[3]})
f2247 = f2247.rename(columns={f2247.columns[4]:"age"})

full_pheno = f2247.append(ctrl)
full_pheno.to_csv("080421_UKBB_Hearing_difficulty_f2247_expandedwhite_46237cases_98082ctrl", sep='\t', index=False)

# %% [markdown]
# ### f2257

# %%
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f2257.columns[3]})
f2257 = f2257.rename(columns={f2257.columns[4]:"age"})

full_pheno = f2257.append(ctrl)
full_pheno.to_csv("080421_UKBB_Hearing_noise_f2257_expandedwhite_66656cases_98082ctrl", sep='\t', index=False)

# %% [markdown]
# ### f2247_f2257

# %%
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f2247_f2257.columns[3]})
f2247_f2257 = f2247_f2257.rename(columns={f2247_f2257.columns[4]:"age"})

full_pheno = f2247_f2257.append(ctrl)
full_pheno.to_csv("080421_UKBB_Combined_f2247_f2257_expandedwhite_39049cases_98082ctrl", sep='\t', index=False)

# %% [markdown]
# ### f3393

# %%
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f3393.columns[3]})
f3393 = f3393.rename(columns={f3393.columns[4]:"age"})

full_pheno = f3393.append(ctrl)
full_pheno.to_csv("080421_UKBB_Hearing_aid_f3393_expandedwhite_6305cases_98082ctrl", sep='\t', index=False)

# %% [markdown]
# ### Mendelian

# %%
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:mendlike.columns[3]})
mendlike = mendlike.rename(columns={mendlike.columns[4]:"age"})

full_pheno = mendlike.append(ctrl)
full_pheno.to_csv("080421_UKBB_Mendelian_expandedwhite_1520cases_98082ctrl", sep='\t', index=False)

# %% [markdown]
# ## Tinnitus

# %%
tinnitus_ctrl_file_name = "tinnitus_pure_ctrl_pheno_file.tsv"
tinnitus_file_name = "tinnitus_pheno_file.tsv"

# %%
tinnitus_ctrl = pd.read_csv(ctrl_file_name, sep="\t")
tinnitus = pd.read_csv(tinnitus_file_name, sep="\t")

# %%
tinnitus_ctrl = tinnitus_ctrl.rename(columns={tinnitus_ctrl.columns[4]:"age", tinnitus_ctrl.columns[3]:tinnitus.columns[3]})
tinnitus = tinnitus.rename(columns={tinnitus.columns[4]:"age"})

# %%
print("ctrl: ",len(tinnitus_ctrl))
print("tinnitus: ",len(tinnitus))
# Out:
# ctrl:  98082
# tinnitus:  27053

# %%
full_pheno = tinnitus.append(tinnitus_ctrl)
full_pheno.to_csv("080421_UKBB_Tinnitus_f4803_expandedwhite_27053cases_62885ctrl", sep='\t', index=False)

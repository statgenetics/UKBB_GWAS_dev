# %% [markdown]
# # Generate the phenotypes for the hearing impairment traits from the UKBB for the 500K individuals with imputed data

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Read in database

# %%
# collect the necessary column names of the database for our analysis
#This database is already subsetted for white Europeans that passed QC by using Elnaz file 
##/mnt/vast/hpc/csg/UKBiobank/data/ukbb_databases/ukb_673643_JUL2023/IDs_WhiteEU_passed_QC_459241.txt
with open("/mnt/vast/hpc/csg/UKBiobank/data/ukbb_databases/ukb_673643_JUL2023/071923_ukb673643_459241ind_call90.csv") as fp:
    line = fp.readline() # header
    header = line.split(",")
    
    indiv = ["IID", "FID"]
    icd10_colnames = [col.strip('"') for col in header if "f.41270." in col]
    icd10_ages = [col.strip('"') for col in header if "f.41280." in col]
    icd9_colnames = [col.strip('"') for col in header if "f.41271." in col]
    icd9_ages = [col.strip('"') for col in header if "f.41281." in col]
    f20002_colnames = [col.strip('"') for col in header if "f.20002." in col]
    f20002_ages = [col.strip('"') for col in header if "f.20009." in col]
    reported_sex = ["f.31.0.0"]
    genetic_sex = ["f.22001.0.0"]
    ethnicity = [col.strip('"') for col in header if "f.21000." in col]
    hearing_imp_f3393 = [col.strip('"') for col in header if "f.3393." in col]
    hearing_imp_f2247 = [col.strip('"') for col in header if "f.2247." in col]
    hearing_imp_f2257 = [col.strip('"') for col in header if "f.2257." in col]
    tin_cols = [col.strip('"') for col in header if "f.4803." in col]
    ages_f21003_col = [col.strip('"') for col in header if "f.21003." in col]
    ages_f131258_col = [col.strip('"') for col in header if 'f.131258.' in col]
    year_of_birth = [col.strip('"') for col in header if "f.34." in col]
    month_of_birth = [col.strip('"') for col in header if "f.52." in col]

# %%
# combine the column names into one list
combined_cols = indiv + icd10_colnames + icd10_ages + icd9_colnames + icd9_ages + f20002_colnames + f20002_ages + ethnicity + reported_sex + genetic_sex + hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257 + tin_cols + ages_f21003_col + ages_f131258_col + year_of_birth + month_of_birth

# %%
print(datetime.now())
# Out:
# 2023-07-24 14:32:00.276623

# %%
import os
os. getcwd()
# Out:
# '/mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/phenotypes'

# %%
# database of all individuals that we are working with and the selected phenotypes july2023 update
df = pd.read_csv("/mnt/vast/hpc/csg/UKBiobank/data/ukbb_databases/ukb_673643_JUL2023/071923_ukb673643_459241ind_call90.csv", quotechar = '"', dtype="string", usecols=combined_cols)
df
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female     1960   November        Yes       <NA>
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 459151  6025390  6025390   Female     1942      March         No       <NA>
# 459152  6025409  6025409   Female     1946   November         No         No
# 459153  6025411  6025411   Female     1960   November         No       <NA>
# 459154  6025425  6025425   Female     1963     August         No       <NA>
# 459155  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... f.41281.0.38 f.41281.0.39  \
# 0            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 1            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 2            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 3              No       <NA>         No  ...         <NA>         <NA>
# 4            <NA>       <NA>        Yes  ...         <NA>         <NA>
# ...           ...        ...        ...  ...          ...          ...
# 459151       <NA>       <NA>        Yes  ...         <NA>         <NA>
# 459152       <NA>       <NA>         No  ...         <NA>         <NA>
# 459153       <NA>       <NA>         No  ...         <NA>         <NA>
# 459154       <NA>       <NA>         No  ...         <NA>         <NA>
# 459155       <NA>       <NA>         No  ...         <NA>         <NA>
#
#        f.41281.0.40 f.41281.0.41 f.41281.0.42 f.41281.0.43 f.41281.0.44  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 459151         <NA>         <NA>         <NA>         <NA>         <NA>
# 459152         <NA>         <NA>         <NA>         <NA>         <NA>
# 459153         <NA>         <NA>         <NA>         <NA>         <NA>
# 459154         <NA>         <NA>         <NA>         <NA>         <NA>
# 459155         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.41281.0.45 f.41281.0.46 f.131258.0.0
# 0              <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>
# ...             ...          ...          ...
# 459151         <NA>         <NA>         <NA>
# 459152         <NA>         <NA>         <NA>
# 459153         <NA>         <NA>         <NA>
# 459154         <NA>         <NA>         <NA>
# 459155         <NA>         <NA>         <NA>
#
# [459156 rows x 915 columns]

# %%
print(datetime.now())
# Out:
# 2023-07-24 14:41:15.563527

# %%
### saving the working file
df.to_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/071923_ukb673643_459241ind_call90_subsetvars.csv",index=False)

# %% [markdown]
# ### Reading working file (subset of original pheno file)

# %%
list(df.columns)
# Out:
# ['IID',
#  'FID',
#  'f.31.0.0',
#  'f.34.0.0',
#  'f.52.0.0',
#  'f.2247.0.0',
#  'f.2247.1.0',
#  'f.2247.2.0',
#  'f.2247.3.0',
#  'f.2257.0.0',
#  'f.2257.1.0',
#  'f.2257.2.0',
#  'f.2257.3.0',
#  'f.3393.0.0',
#  'f.3393.1.0',
#  'f.3393.2.0',
#  'f.3393.3.0',
#  'f.4803.0.0',
#  'f.4803.1.0',
#  'f.4803.2.0',
#  'f.4803.3.0',
#  'f.20002.0.0',
#  'f.20002.0.1',
#  'f.20002.0.2',
#  'f.20002.0.3',
#  'f.20002.0.4',
#  'f.20002.0.5',
#  'f.20002.0.6',
#  'f.20002.0.7',
#  'f.20002.0.8',
#  'f.20002.0.9',
#  'f.20002.0.10',
#  'f.20002.0.11',
#  'f.20002.0.12',
#  'f.20002.0.13',
#  'f.20002.0.14',
#  'f.20002.0.15',
#  'f.20002.0.16',
#  'f.20002.0.17',
#  'f.20002.0.18',
#  'f.20002.0.19',
#  'f.20002.0.20',
#  'f.20002.0.21',
#  'f.20002.0.22',
#  'f.20002.0.23',
#  'f.20002.0.24',
#  'f.20002.0.25',
#  'f.20002.0.26',
#  'f.20002.0.27',
#  'f.20002.0.28',
#  'f.20002.0.29',
#  'f.20002.0.30',
#  'f.20002.0.31',
#  'f.20002.0.32',
#  'f.20002.0.33',
#  'f.20002.1.0',
#  'f.20002.1.1',
#  'f.20002.1.2',
#  'f.20002.1.3',
#  'f.20002.1.4',
#  'f.20002.1.5',
#  'f.20002.1.6',
#  'f.20002.1.7',
#  'f.20002.1.8',
#  'f.20002.1.9',
#  'f.20002.1.10',
#  'f.20002.1.11',
#  'f.20002.1.12',
#  'f.20002.1.13',
#  'f.20002.1.14',
#  'f.20002.1.15',
#  'f.20002.1.16',
#  'f.20002.1.17',
#  'f.20002.1.18',
#  'f.20002.1.19',
#  'f.20002.1.20',
#  'f.20002.1.21',
#  'f.20002.1.22',
#  'f.20002.1.23',
#  'f.20002.1.24',
#  'f.20002.1.25',
#  'f.20002.1.26',
#  'f.20002.1.27',
#  'f.20002.1.28',
#  'f.20002.1.29',
#  'f.20002.1.30',
#  'f.20002.1.31',
#  'f.20002.1.32',
#  'f.20002.1.33',
#  'f.20002.2.0',
#  'f.20002.2.1',
#  'f.20002.2.2',
#  'f.20002.2.3',
#  'f.20002.2.4',
#  'f.20002.2.5',
#  'f.20002.2.6',
#  'f.20002.2.7',
#  'f.20002.2.8',
#  'f.20002.2.9',
#  'f.20002.2.10',
#  'f.20002.2.11',
#  'f.20002.2.12',
#  'f.20002.2.13',
#  'f.20002.2.14',
#  'f.20002.2.15',
#  'f.20002.2.16',
#  'f.20002.2.17',
#  'f.20002.2.18',
#  'f.20002.2.19',
#  'f.20002.2.20',
#  'f.20002.2.21',
#  'f.20002.2.22',
#  'f.20002.2.23',
#  'f.20002.2.24',
#  'f.20002.2.25',
#  'f.20002.2.26',
#  'f.20002.2.27',
#  'f.20002.2.28',
#  'f.20002.2.29',
#  'f.20002.2.30',
#  'f.20002.2.31',
#  'f.20002.2.32',
#  'f.20002.2.33',
#  'f.20002.3.0',
#  'f.20002.3.1',
#  'f.20002.3.2',
#  'f.20002.3.3',
#  'f.20002.3.4',
#  'f.20002.3.5',
#  'f.20002.3.6',
#  'f.20002.3.7',
#  'f.20002.3.8',
#  'f.20002.3.9',
#  'f.20002.3.10',
#  'f.20002.3.11',
#  'f.20002.3.12',
#  'f.20002.3.13',
#  'f.20002.3.14',
#  'f.20002.3.15',
#  'f.20002.3.16',
#  'f.20002.3.17',
#  'f.20002.3.18',
#  'f.20002.3.19',
#  'f.20002.3.20',
#  'f.20002.3.21',
#  'f.20002.3.22',
#  'f.20002.3.23',
#  'f.20002.3.24',
#  'f.20002.3.25',
#  'f.20002.3.26',
#  'f.20002.3.27',
#  'f.20002.3.28',
#  'f.20002.3.29',
#  'f.20002.3.30',
#  'f.20002.3.31',
#  'f.20002.3.32',
#  'f.20002.3.33',
#  'f.20009.0.0',
#  'f.20009.0.1',
#  'f.20009.0.2',
#  'f.20009.0.3',
#  'f.20009.0.4',
#  'f.20009.0.5',
#  'f.20009.0.6',
#  'f.20009.0.7',
#  'f.20009.0.8',
#  'f.20009.0.9',
#  'f.20009.0.10',
#  'f.20009.0.11',
#  'f.20009.0.12',
#  'f.20009.0.13',
#  'f.20009.0.14',
#  'f.20009.0.15',
#  'f.20009.0.16',
#  'f.20009.0.17',
#  'f.20009.0.18',
#  'f.20009.0.19',
#  'f.20009.0.20',
#  'f.20009.0.21',
#  'f.20009.0.22',
#  'f.20009.0.23',
#  'f.20009.0.24',
#  'f.20009.0.25',
#  'f.20009.0.26',
#  'f.20009.0.27',
#  'f.20009.0.28',
#  'f.20009.0.29',
#  'f.20009.0.30',
#  'f.20009.0.31',
#  'f.20009.0.32',
#  'f.20009.0.33',
#  'f.20009.1.0',
#  'f.20009.1.1',
#  'f.20009.1.2',
#  'f.20009.1.3',
#  'f.20009.1.4',
#  'f.20009.1.5',
#  'f.20009.1.6',
#  'f.20009.1.7',
#  'f.20009.1.8',
#  'f.20009.1.9',
#  'f.20009.1.10',
#  'f.20009.1.11',
#  'f.20009.1.12',
#  'f.20009.1.13',
#  'f.20009.1.14',
#  'f.20009.1.15',
#  'f.20009.1.16',
#  'f.20009.1.17',
#  'f.20009.1.18',
#  'f.20009.1.19',
#  'f.20009.1.20',
#  'f.20009.1.21',
#  'f.20009.1.22',
#  'f.20009.1.23',
#  'f.20009.1.24',
#  'f.20009.1.25',
#  'f.20009.1.26',
#  'f.20009.1.27',
#  'f.20009.1.28',
#  'f.20009.1.29',
#  'f.20009.1.30',
#  'f.20009.1.31',
#  'f.20009.1.32',
#  'f.20009.1.33',
#  'f.20009.2.0',
#  'f.20009.2.1',
#  'f.20009.2.2',
#  'f.20009.2.3',
#  'f.20009.2.4',
#  'f.20009.2.5',
#  'f.20009.2.6',
#  'f.20009.2.7',
#  'f.20009.2.8',
#  'f.20009.2.9',
#  'f.20009.2.10',
#  'f.20009.2.11',
#  'f.20009.2.12',
#  'f.20009.2.13',
#  'f.20009.2.14',
#  'f.20009.2.15',
#  'f.20009.2.16',
#  'f.20009.2.17',
#  'f.20009.2.18',
#  'f.20009.2.19',
#  'f.20009.2.20',
#  'f.20009.2.21',
#  'f.20009.2.22',
#  'f.20009.2.23',
#  'f.20009.2.24',
#  'f.20009.2.25',
#  'f.20009.2.26',
#  'f.20009.2.27',
#  'f.20009.2.28',
#  'f.20009.2.29',
#  'f.20009.2.30',
#  'f.20009.2.31',
#  'f.20009.2.32',
#  'f.20009.2.33',
#  'f.20009.3.0',
#  'f.20009.3.1',
#  'f.20009.3.2',
#  'f.20009.3.3',
#  'f.20009.3.4',
#  'f.20009.3.5',
#  'f.20009.3.6',
#  'f.20009.3.7',
#  'f.20009.3.8',
#  'f.20009.3.9',
#  'f.20009.3.10',
#  'f.20009.3.11',
#  'f.20009.3.12',
#  'f.20009.3.13',
#  'f.20009.3.14',
#  'f.20009.3.15',
#  'f.20009.3.16',
#  'f.20009.3.17',
#  'f.20009.3.18',
#  'f.20009.3.19',
#  'f.20009.3.20',
#  'f.20009.3.21',
#  'f.20009.3.22',
#  'f.20009.3.23',
#  'f.20009.3.24',
#  'f.20009.3.25',
#  'f.20009.3.26',
#  'f.20009.3.27',
#  'f.20009.3.28',
#  'f.20009.3.29',
#  'f.20009.3.30',
#  'f.20009.3.31',
#  'f.20009.3.32',
#  'f.20009.3.33',
#  'f.21000.0.0',
#  'f.21000.1.0',
#  'f.21000.2.0',
#  'f.21000.3.0',
#  'f.21003.0.0',
#  'f.21003.1.0',
#  'f.21003.2.0',
#  'f.21003.3.0',
#  'f.22001.0.0',
#  'f.41270.0.0',
#  'f.41270.0.1',
#  'f.41270.0.2',
#  'f.41270.0.3',
#  'f.41270.0.4',
#  'f.41270.0.5',
#  'f.41270.0.6',
#  'f.41270.0.7',
#  'f.41270.0.8',
#  'f.41270.0.9',
#  'f.41270.0.10',
#  'f.41270.0.11',
#  'f.41270.0.12',
#  'f.41270.0.13',
#  'f.41270.0.14',
#  'f.41270.0.15',
#  'f.41270.0.16',
#  'f.41270.0.17',
#  'f.41270.0.18',
#  'f.41270.0.19',
#  'f.41270.0.20',
#  'f.41270.0.21',
#  'f.41270.0.22',
#  'f.41270.0.23',
#  'f.41270.0.24',
#  'f.41270.0.25',
#  'f.41270.0.26',
#  'f.41270.0.27',
#  'f.41270.0.28',
#  'f.41270.0.29',
#  'f.41270.0.30',
#  'f.41270.0.31',
#  'f.41270.0.32',
#  'f.41270.0.33',
#  'f.41270.0.34',
#  'f.41270.0.35',
#  'f.41270.0.36',
#  'f.41270.0.37',
#  'f.41270.0.38',
#  'f.41270.0.39',
#  'f.41270.0.40',
#  'f.41270.0.41',
#  'f.41270.0.42',
#  'f.41270.0.43',
#  'f.41270.0.44',
#  'f.41270.0.45',
#  'f.41270.0.46',
#  'f.41270.0.47',
#  'f.41270.0.48',
#  'f.41270.0.49',
#  'f.41270.0.50',
#  'f.41270.0.51',
#  'f.41270.0.52',
#  'f.41270.0.53',
#  'f.41270.0.54',
#  'f.41270.0.55',
#  'f.41270.0.56',
#  'f.41270.0.57',
#  'f.41270.0.58',
#  'f.41270.0.59',
#  'f.41270.0.60',
#  'f.41270.0.61',
#  'f.41270.0.62',
#  'f.41270.0.63',
#  'f.41270.0.64',
#  'f.41270.0.65',
#  'f.41270.0.66',
#  'f.41270.0.67',
#  'f.41270.0.68',
#  'f.41270.0.69',
#  'f.41270.0.70',
#  'f.41270.0.71',
#  'f.41270.0.72',
#  'f.41270.0.73',
#  'f.41270.0.74',
#  'f.41270.0.75',
#  'f.41270.0.76',
#  'f.41270.0.77',
#  'f.41270.0.78',
#  'f.41270.0.79',
#  'f.41270.0.80',
#  'f.41270.0.81',
#  'f.41270.0.82',
#  'f.41270.0.83',
#  'f.41270.0.84',
#  'f.41270.0.85',
#  'f.41270.0.86',
#  'f.41270.0.87',
#  'f.41270.0.88',
#  'f.41270.0.89',
#  'f.41270.0.90',
#  'f.41270.0.91',
#  'f.41270.0.92',
#  'f.41270.0.93',
#  'f.41270.0.94',
#  'f.41270.0.95',
#  'f.41270.0.96',
#  'f.41270.0.97',
#  'f.41270.0.98',
#  'f.41270.0.99',
#  'f.41270.0.100',
#  'f.41270.0.101',
#  'f.41270.0.102',
#  'f.41270.0.103',
#  'f.41270.0.104',
#  'f.41270.0.105',
#  'f.41270.0.106',
#  'f.41270.0.107',
#  'f.41270.0.108',
#  'f.41270.0.109',
#  'f.41270.0.110',
#  'f.41270.0.111',
#  'f.41270.0.112',
#  'f.41270.0.113',
#  'f.41270.0.114',
#  'f.41270.0.115',
#  'f.41270.0.116',
#  'f.41270.0.117',
#  'f.41270.0.118',
#  'f.41270.0.119',
#  'f.41270.0.120',
#  'f.41270.0.121',
#  'f.41270.0.122',
#  'f.41270.0.123',
#  'f.41270.0.124',
#  'f.41270.0.125',
#  'f.41270.0.126',
#  'f.41270.0.127',
#  'f.41270.0.128',
#  'f.41270.0.129',
#  'f.41270.0.130',
#  'f.41270.0.131',
#  'f.41270.0.132',
#  'f.41270.0.133',
#  'f.41270.0.134',
#  'f.41270.0.135',
#  'f.41270.0.136',
#  'f.41270.0.137',
#  'f.41270.0.138',
#  'f.41270.0.139',
#  'f.41270.0.140',
#  'f.41270.0.141',
#  'f.41270.0.142',
#  'f.41270.0.143',
#  'f.41270.0.144',
#  'f.41270.0.145',
#  'f.41270.0.146',
#  'f.41270.0.147',
#  'f.41270.0.148',
#  'f.41270.0.149',
#  'f.41270.0.150',
#  'f.41270.0.151',
#  'f.41270.0.152',
#  'f.41270.0.153',
#  'f.41270.0.154',
#  'f.41270.0.155',
#  'f.41270.0.156',
#  'f.41270.0.157',
#  'f.41270.0.158',
#  'f.41270.0.159',
#  'f.41270.0.160',
#  'f.41270.0.161',
#  'f.41270.0.162',
#  'f.41270.0.163',
#  'f.41270.0.164',
#  'f.41270.0.165',
#  'f.41270.0.166',
#  'f.41270.0.167',
#  'f.41270.0.168',
#  'f.41270.0.169',
#  'f.41270.0.170',
#  'f.41270.0.171',
#  'f.41270.0.172',
#  'f.41270.0.173',
#  'f.41270.0.174',
#  'f.41270.0.175',
#  'f.41270.0.176',
#  'f.41270.0.177',
#  'f.41270.0.178',
#  'f.41270.0.179',
#  'f.41270.0.180',
#  'f.41270.0.181',
#  'f.41270.0.182',
#  'f.41270.0.183',
#  'f.41270.0.184',
#  'f.41270.0.185',
#  'f.41270.0.186',
#  'f.41270.0.187',
#  'f.41270.0.188',
#  'f.41270.0.189',
#  'f.41270.0.190',
#  'f.41270.0.191',
#  'f.41270.0.192',
#  'f.41270.0.193',
#  'f.41270.0.194',
#  'f.41270.0.195',
#  'f.41270.0.196',
#  'f.41270.0.197',
#  'f.41270.0.198',
#  'f.41270.0.199',
#  'f.41270.0.200',
#  'f.41270.0.201',
#  'f.41270.0.202',
#  'f.41270.0.203',
#  'f.41270.0.204',
#  'f.41270.0.205',
#  'f.41270.0.206',
#  'f.41270.0.207',
#  'f.41270.0.208',
#  'f.41270.0.209',
#  'f.41270.0.210',
#  'f.41270.0.211',
#  'f.41270.0.212',
#  'f.41270.0.213',
#  'f.41270.0.214',
#  'f.41270.0.215',
#  'f.41270.0.216',
#  'f.41270.0.217',
#  'f.41270.0.218',
#  'f.41270.0.219',
#  'f.41270.0.220',
#  'f.41270.0.221',
#  'f.41270.0.222',
#  'f.41270.0.223',
#  'f.41270.0.224',
#  'f.41270.0.225',
#  'f.41270.0.226',
#  'f.41270.0.227',
#  'f.41270.0.228',
#  'f.41270.0.229',
#  'f.41270.0.230',
#  'f.41270.0.231',
#  'f.41270.0.232',
#  'f.41270.0.233',
#  'f.41270.0.234',
#  'f.41270.0.235',
#  'f.41270.0.236',
#  'f.41270.0.237',
#  'f.41270.0.238',
#  'f.41270.0.239',
#  'f.41270.0.240',
#  'f.41270.0.241',
#  'f.41270.0.242',
#  'f.41270.0.243',
#  'f.41270.0.244',
#  'f.41270.0.245',
#  'f.41270.0.246',
#  'f.41270.0.247',
#  'f.41270.0.248',
#  'f.41270.0.249',
#  'f.41270.0.250',
#  'f.41270.0.251',
#  'f.41270.0.252',
#  'f.41270.0.253',
#  'f.41270.0.254',
#  'f.41270.0.255',
#  'f.41270.0.256',
#  'f.41270.0.257',
#  'f.41270.0.258',
#  'f.41271.0.0',
#  'f.41271.0.1',
#  'f.41271.0.2',
#  'f.41271.0.3',
#  'f.41271.0.4',
#  'f.41271.0.5',
#  'f.41271.0.6',
#  'f.41271.0.7',
#  'f.41271.0.8',
#  'f.41271.0.9',
#  'f.41271.0.10',
#  'f.41271.0.11',
#  'f.41271.0.12',
#  'f.41271.0.13',
#  'f.41271.0.14',
#  'f.41271.0.15',
#  'f.41271.0.16',
#  'f.41271.0.17',
#  'f.41271.0.18',
#  'f.41271.0.19',
#  'f.41271.0.20',
#  'f.41271.0.21',
#  'f.41271.0.22',
#  'f.41271.0.23',
#  'f.41271.0.24',
#  'f.41271.0.25',
#  'f.41271.0.26',
#  'f.41271.0.27',
#  'f.41271.0.28',
#  'f.41271.0.29',
#  'f.41271.0.30',
#  'f.41271.0.31',
#  'f.41271.0.32',
#  'f.41271.0.33',
#  'f.41271.0.34',
#  'f.41271.0.35',
#  'f.41271.0.36',
#  'f.41271.0.37',
#  'f.41271.0.38',
#  'f.41271.0.39',
#  'f.41271.0.40',
#  'f.41271.0.41',
#  'f.41271.0.42',
#  'f.41271.0.43',
#  'f.41271.0.44',
#  'f.41271.0.45',
#  'f.41271.0.46',
#  'f.41280.0.0',
#  'f.41280.0.1',
#  'f.41280.0.2',
#  'f.41280.0.3',
#  'f.41280.0.4',
#  'f.41280.0.5',
#  'f.41280.0.6',
#  'f.41280.0.7',
#  'f.41280.0.8',
#  'f.41280.0.9',
#  'f.41280.0.10',
#  'f.41280.0.11',
#  'f.41280.0.12',
#  'f.41280.0.13',
#  'f.41280.0.14',
#  'f.41280.0.15',
#  'f.41280.0.16',
#  'f.41280.0.17',
#  'f.41280.0.18',
#  'f.41280.0.19',
#  'f.41280.0.20',
#  'f.41280.0.21',
#  'f.41280.0.22',
#  'f.41280.0.23',
#  'f.41280.0.24',
#  'f.41280.0.25',
#  'f.41280.0.26',
#  'f.41280.0.27',
#  'f.41280.0.28',
#  'f.41280.0.29',
#  'f.41280.0.30',
#  'f.41280.0.31',
#  'f.41280.0.32',
#  'f.41280.0.33',
#  'f.41280.0.34',
#  'f.41280.0.35',
#  'f.41280.0.36',
#  'f.41280.0.37',
#  'f.41280.0.38',
#  'f.41280.0.39',
#  'f.41280.0.40',
#  'f.41280.0.41',
#  'f.41280.0.42',
#  'f.41280.0.43',
#  'f.41280.0.44',
#  'f.41280.0.45',
#  'f.41280.0.46',
#  'f.41280.0.47',
#  'f.41280.0.48',
#  'f.41280.0.49',
#  'f.41280.0.50',
#  'f.41280.0.51',
#  'f.41280.0.52',
#  'f.41280.0.53',
#  'f.41280.0.54',
#  'f.41280.0.55',
#  'f.41280.0.56',
#  'f.41280.0.57',
#  'f.41280.0.58',
#  'f.41280.0.59',
#  'f.41280.0.60',
#  'f.41280.0.61',
#  'f.41280.0.62',
#  'f.41280.0.63',
#  'f.41280.0.64',
#  'f.41280.0.65',
#  'f.41280.0.66',
#  'f.41280.0.67',
#  'f.41280.0.68',
#  'f.41280.0.69',
#  'f.41280.0.70',
#  'f.41280.0.71',
#  'f.41280.0.72',
#  'f.41280.0.73',
#  'f.41280.0.74',
#  'f.41280.0.75',
#  'f.41280.0.76',
#  'f.41280.0.77',
#  'f.41280.0.78',
#  'f.41280.0.79',
#  'f.41280.0.80',
#  'f.41280.0.81',
#  'f.41280.0.82',
#  'f.41280.0.83',
#  'f.41280.0.84',
#  'f.41280.0.85',
#  'f.41280.0.86',
#  'f.41280.0.87',
#  'f.41280.0.88',
#  'f.41280.0.89',
#  'f.41280.0.90',
#  'f.41280.0.91',
#  'f.41280.0.92',
#  'f.41280.0.93',
#  'f.41280.0.94',
#  'f.41280.0.95',
#  'f.41280.0.96',
#  'f.41280.0.97',
#  'f.41280.0.98',
#  'f.41280.0.99',
#  'f.41280.0.100',
#  'f.41280.0.101',
#  'f.41280.0.102',
#  'f.41280.0.103',
#  'f.41280.0.104',
#  'f.41280.0.105',
#  'f.41280.0.106',
#  'f.41280.0.107',
#  'f.41280.0.108',
#  'f.41280.0.109',
#  'f.41280.0.110',
#  'f.41280.0.111',
#  'f.41280.0.112',
#  'f.41280.0.113',
#  'f.41280.0.114',
#  'f.41280.0.115',
#  'f.41280.0.116',
#  'f.41280.0.117',
#  'f.41280.0.118',
#  'f.41280.0.119',
#  'f.41280.0.120',
#  'f.41280.0.121',
#  'f.41280.0.122',
#  'f.41280.0.123',
#  'f.41280.0.124',
#  'f.41280.0.125',
#  'f.41280.0.126',
#  'f.41280.0.127',
#  'f.41280.0.128',
#  'f.41280.0.129',
#  'f.41280.0.130',
#  'f.41280.0.131',
#  'f.41280.0.132',
#  'f.41280.0.133',
#  'f.41280.0.134',
#  'f.41280.0.135',
#  'f.41280.0.136',
#  'f.41280.0.137',
#  'f.41280.0.138',
#  'f.41280.0.139',
#  'f.41280.0.140',
#  'f.41280.0.141',
#  'f.41280.0.142',
#  'f.41280.0.143',
#  'f.41280.0.144',
#  'f.41280.0.145',
#  'f.41280.0.146',
#  'f.41280.0.147',
#  'f.41280.0.148',
#  'f.41280.0.149',
#  'f.41280.0.150',
#  'f.41280.0.151',
#  'f.41280.0.152',
#  'f.41280.0.153',
#  'f.41280.0.154',
#  'f.41280.0.155',
#  'f.41280.0.156',
#  'f.41280.0.157',
#  'f.41280.0.158',
#  'f.41280.0.159',
#  'f.41280.0.160',
#  'f.41280.0.161',
#  'f.41280.0.162',
#  'f.41280.0.163',
#  'f.41280.0.164',
#  'f.41280.0.165',
#  'f.41280.0.166',
#  'f.41280.0.167',
#  'f.41280.0.168',
#  'f.41280.0.169',
#  'f.41280.0.170',
#  'f.41280.0.171',
#  'f.41280.0.172',
#  'f.41280.0.173',
#  'f.41280.0.174',
#  'f.41280.0.175',
#  'f.41280.0.176',
#  'f.41280.0.177',
#  'f.41280.0.178',
#  'f.41280.0.179',
#  'f.41280.0.180',
#  'f.41280.0.181',
#  'f.41280.0.182',
#  'f.41280.0.183',
#  'f.41280.0.184',
#  'f.41280.0.185',
#  'f.41280.0.186',
#  'f.41280.0.187',
#  'f.41280.0.188',
#  'f.41280.0.189',
#  'f.41280.0.190',
#  'f.41280.0.191',
#  'f.41280.0.192',
#  'f.41280.0.193',
#  'f.41280.0.194',
#  'f.41280.0.195',
#  'f.41280.0.196',
#  'f.41280.0.197',
#  'f.41280.0.198',
#  'f.41280.0.199',
#  'f.41280.0.200',
#  'f.41280.0.201',
#  'f.41280.0.202',
#  'f.41280.0.203',
#  'f.41280.0.204',
#  'f.41280.0.205',
#  'f.41280.0.206',
#  'f.41280.0.207',
#  'f.41280.0.208',
#  'f.41280.0.209',
#  'f.41280.0.210',
#  'f.41280.0.211',
#  'f.41280.0.212',
#  'f.41280.0.213',
#  'f.41280.0.214',
#  'f.41280.0.215',
#  'f.41280.0.216',
#  'f.41280.0.217',
#  'f.41280.0.218',
#  'f.41280.0.219',
#  'f.41280.0.220',
#  'f.41280.0.221',
#  'f.41280.0.222',
#  'f.41280.0.223',
#  'f.41280.0.224',
#  'f.41280.0.225',
#  'f.41280.0.226',
#  'f.41280.0.227',
#  'f.41280.0.228',
#  'f.41280.0.229',
#  'f.41280.0.230',
#  'f.41280.0.231',
#  'f.41280.0.232',
#  'f.41280.0.233',
#  'f.41280.0.234',
#  'f.41280.0.235',
#  'f.41280.0.236',
#  'f.41280.0.237',
#  'f.41280.0.238',
#  'f.41280.0.239',
#  'f.41280.0.240',
#  'f.41280.0.241',
#  'f.41280.0.242',
#  'f.41280.0.243',
#  'f.41280.0.244',
#  'f.41280.0.245',
#  'f.41280.0.246',
#  'f.41280.0.247',
#  'f.41280.0.248',
#  'f.41280.0.249',
#  'f.41280.0.250',
#  'f.41280.0.251',
#  'f.41280.0.252',
#  'f.41280.0.253',
#  'f.41280.0.254',
#  'f.41280.0.255',
#  'f.41280.0.256',
#  'f.41280.0.257',
#  'f.41280.0.258',
#  'f.41281.0.0',
#  'f.41281.0.1',
#  'f.41281.0.2',
#  'f.41281.0.3',
#  'f.41281.0.4',
#  'f.41281.0.5',
#  'f.41281.0.6',
#  'f.41281.0.7',
#  'f.41281.0.8',
#  'f.41281.0.9',
#  'f.41281.0.10',
#  'f.41281.0.11',
#  'f.41281.0.12',
#  'f.41281.0.13',
#  'f.41281.0.14',
#  'f.41281.0.15',
#  'f.41281.0.16',
#  'f.41281.0.17',
#  'f.41281.0.18',
#  'f.41281.0.19',
#  'f.41281.0.20',
#  'f.41281.0.21',
#  'f.41281.0.22',
#  'f.41281.0.23',
#  'f.41281.0.24',
#  'f.41281.0.25',
#  'f.41281.0.26',
#  'f.41281.0.27',
#  'f.41281.0.28',
#  'f.41281.0.29',
#  'f.41281.0.30',
#  'f.41281.0.31',
#  'f.41281.0.32',
#  'f.41281.0.33',
#  'f.41281.0.34',
#  'f.41281.0.35',
#  'f.41281.0.36',
#  'f.41281.0.37',
#  'f.41281.0.38',
#  'f.41281.0.39',
#  'f.41281.0.40',
#  'f.41281.0.41',
#  'f.41281.0.42',
#  'f.41281.0.43',
#  'f.41281.0.44',
#  'f.41281.0.45',
#  'f.41281.0.46',
#  'f.131258.0.0']

# %%
df["f.20002.0.0"].value_counts(dropna=False)
# Out:
# NaN     115043
# 1065    103596
# 1111     34508
# 1465     10777
# 1075     10269
#          ...
# 1236         1
# 1496         1
# 1521         1
# 1621         1
# 1678         1
# Name: f.20002.0.0, Length: 441, dtype: Int64

# %%
#df["f.20009.0.0"]

# %%
non_cancer = df [["IID","f.20002.0.0","f.20009.0.0","f.20002.1.0", "f.20009.1.0"]]
non_cancer
# Out:
#             IID f.20002.0.0 f.20009.0.0 f.20002.1.0 f.20009.1.0
# 0       1000019        1111        47.1        <NA>        <NA>
# 1       1000022        1065        43.5        <NA>        <NA>
# 2       1000035        1396        62.2        <NA>        <NA>
# 3       1000046        1065        61.5        <NA>        <NA>
# 4       1000054        <NA>        <NA>        <NA>        <NA>
# ...         ...         ...         ...         ...         ...
# 459151  6025390        1464        65.3        <NA>        <NA>
# 459152  6025409        1478        39.6        1627        23.6
# 459153  6025411        <NA>        <NA>        <NA>        <NA>
# 459154  6025425        1265        22.5        <NA>        <NA>
# 459155  6025438        1065        50.5        <NA>        <NA>
#
# [459156 rows x 5 columns]

# %%
ICD10 = df [["IID","f.41270.0.0", "f.41280.0.0","f.41270.0.1", "f.41280.0.1"]]
ICD10
# Out:
#             IID f.41270.0.0 f.41280.0.0 f.41270.0.1 f.41280.0.1
# 0       1000019        E041  2013-11-21        F329  2020-03-02
# 1       1000022        F101  2015-07-31        J342  2002-03-14
# 2       1000035        H269  2014-05-10        K579  2007-02-14
# 3       1000046        E780  2009-10-30        G473  2014-05-28
# 4       1000054        C679  2014-01-07        C787  2014-04-08
# ...         ...         ...         ...         ...         ...
# 459151  6025390        A049  2021-01-13        A099  2020-12-01
# 459152  6025409        <NA>        <NA>        <NA>        <NA>
# 459153  6025411        O149  1997-05-13        O266  1997-05-13
# 459154  6025425        G551  2009-02-25        G558  2018-08-08
# 459155  6025438        D225  2002-11-30        S008  2021-05-25
#
# [459156 rows x 5 columns]

# %%
icd9_colnames
# Out:
# ['f.41271.0.0',
#  'f.41271.0.1',
#  'f.41271.0.2',
#  'f.41271.0.3',
#  'f.41271.0.4',
#  'f.41271.0.5',
#  'f.41271.0.6',
#  'f.41271.0.7',
#  'f.41271.0.8',
#  'f.41271.0.9',
#  'f.41271.0.10',
#  'f.41271.0.11',
#  'f.41271.0.12',
#  'f.41271.0.13',
#  'f.41271.0.14',
#  'f.41271.0.15',
#  'f.41271.0.16',
#  'f.41271.0.17',
#  'f.41271.0.18',
#  'f.41271.0.19',
#  'f.41271.0.20',
#  'f.41271.0.21',
#  'f.41271.0.22',
#  'f.41271.0.23',
#  'f.41271.0.24',
#  'f.41271.0.25',
#  'f.41271.0.26',
#  'f.41271.0.27',
#  'f.41271.0.28',
#  'f.41271.0.29',
#  'f.41271.0.30',
#  'f.41271.0.31',
#  'f.41271.0.32',
#  'f.41271.0.33',
#  'f.41271.0.34',
#  'f.41271.0.35',
#  'f.41271.0.36',
#  'f.41271.0.37',
#  'f.41271.0.38',
#  'f.41271.0.39',
#  'f.41271.0.40',
#  'f.41271.0.41',
#  'f.41271.0.42',
#  'f.41271.0.43',
#  'f.41271.0.44',
#  'f.41271.0.45',
#  'f.41271.0.46']

# %%
ICD9 = df [["IID","f.41271.0.0", "f.41281.0.0","f.41271.0.1", "f.41281.0.1"]]
ICD9
# Out:
#             IID f.41271.0.0 f.41281.0.0 f.41271.0.1 f.41281.0.1
# 0       1000019        <NA>        <NA>        <NA>        <NA>
# 1       1000022        <NA>        <NA>        <NA>        <NA>
# 2       1000035        <NA>        <NA>        <NA>        <NA>
# 3       1000046        <NA>        <NA>        <NA>        <NA>
# 4       1000054        3000  1981-01-14        5198  1981-01-14
# ...         ...         ...         ...         ...         ...
# 459151  6025390        <NA>        <NA>        <NA>        <NA>
# 459152  6025409        <NA>        <NA>        <NA>        <NA>
# 459153  6025411        <NA>        <NA>        <NA>        <NA>
# 459154  6025425        <NA>        <NA>        <NA>        <NA>
# 459155  6025438        <NA>        <NA>        <NA>        <NA>
#
# [459156 rows x 5 columns]

# %% [markdown]
# ## Estimating age for each ICD9/10

# %%
###changing brithday to date, need to add day for each individuals
for index, row in df.iterrows():
     df.at[index, 'day'] = 1
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)

# %%
BD = df [["IID","f.34.0.0", "f.52.0.0", "day"]]
BD
# Out:
#             IID f.34.0.0   f.52.0.0  day
# 0       1000019     1960   November  1.0
# 1       1000022     1954     August  1.0
# 2       1000035     1944        May  1.0
# 3       1000046     1946      March  1.0
# 4       1000054     1942    January  1.0
# ...         ...      ...        ...  ...
# 459151  6025390     1942      March  1.0
# 459152  6025409     1946   November  1.0
# 459153  6025411     1960   November  1.0
# 459154  6025425     1963     August  1.0
# 459155  6025438     1952  September  1.0
#
# [459156 rows x 4 columns]

# %%
###Convering month names to number
df.loc[(df['f.52.0.0'] == 'January') , 'month'] = 1 
df.loc[(df['f.52.0.0'] == 'February') , 'month'] = 2
df.loc[(df['f.52.0.0'] == 'March') , 'month'] = 3
df.loc[(df['f.52.0.0'] == 'April') , 'month'] = 4
df.loc[(df['f.52.0.0'] == 'May') , 'month'] = 5
df.loc[(df['f.52.0.0'] == 'June') , 'month'] = 6
df.loc[(df['f.52.0.0'] == 'July') , 'month'] = 7
df.loc[(df['f.52.0.0'] == 'August') , 'month'] = 8
df.loc[(df['f.52.0.0'] == 'September') , 'month'] = 9
df.loc[(df['f.52.0.0'] == 'October') , 'month'] = 10
df.loc[(df['f.52.0.0'] == 'November') , 'month'] = 11
df.loc[(df['f.52.0.0'] == 'December') , 'month'] = 12
df
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1684: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = infer_fill_value(value)
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female     1960   November        Yes       <NA>
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 459151  6025390  6025390   Female     1942      March         No       <NA>
# 459152  6025409  6025409   Female     1946   November         No         No
# 459153  6025411  6025411   Female     1960   November         No       <NA>
# 459154  6025425  6025425   Female     1963     August         No       <NA>
# 459155  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... f.41281.0.40 f.41281.0.41  \
# 0            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 1            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 2            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 3              No       <NA>         No  ...         <NA>         <NA>
# 4            <NA>       <NA>        Yes  ...         <NA>         <NA>
# ...           ...        ...        ...  ...          ...          ...
# 459151       <NA>       <NA>        Yes  ...         <NA>         <NA>
# 459152       <NA>       <NA>         No  ...         <NA>         <NA>
# 459153       <NA>       <NA>         No  ...         <NA>         <NA>
# 459154       <NA>       <NA>         No  ...         <NA>         <NA>
# 459155       <NA>       <NA>         No  ...         <NA>         <NA>
#
#        f.41281.0.42 f.41281.0.43 f.41281.0.44 f.41281.0.45 f.41281.0.46  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 459151         <NA>         <NA>         <NA>         <NA>         <NA>
# 459152         <NA>         <NA>         <NA>         <NA>         <NA>
# 459153         <NA>         <NA>         <NA>         <NA>         <NA>
# 459154         <NA>         <NA>         <NA>         <NA>         <NA>
# 459155         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.131258.0.0  day month
# 0              <NA>  1.0  11.0
# 1              <NA>  1.0   8.0
# 2              <NA>  1.0   5.0
# 3              <NA>  1.0   3.0
# 4              <NA>  1.0   1.0
# ...             ...  ...   ...
# 459151         <NA>  1.0   3.0
# 459152         <NA>  1.0  11.0
# 459153         <NA>  1.0  11.0
# 459154         <NA>  1.0   8.0
# 459155         <NA>  1.0   9.0
#
# [459156 rows x 917 columns]

# %%
### Combining three columns, year (f.31.0.0), month and day to generate one column as date of birth

# %%
import datetime
import time

# %%
df['Date']= pd.to_datetime(dict(year=df['f.34.0.0'], month=df["month"], day=df['day']))
df
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female     1960   November        Yes       <NA>
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 459151  6025390  6025390   Female     1942      March         No       <NA>
# 459152  6025409  6025409   Female     1946   November         No         No
# 459153  6025411  6025411   Female     1960   November         No       <NA>
# 459154  6025425  6025425   Female     1963     August         No       <NA>
# 459155  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... f.41281.0.41 f.41281.0.42  \
# 0            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 1            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 2            <NA>       <NA>        Yes  ...         <NA>         <NA>
# 3              No       <NA>         No  ...         <NA>         <NA>
# 4            <NA>       <NA>        Yes  ...         <NA>         <NA>
# ...           ...        ...        ...  ...          ...          ...
# 459151       <NA>       <NA>        Yes  ...         <NA>         <NA>
# 459152       <NA>       <NA>         No  ...         <NA>         <NA>
# 459153       <NA>       <NA>         No  ...         <NA>         <NA>
# 459154       <NA>       <NA>         No  ...         <NA>         <NA>
# 459155       <NA>       <NA>         No  ...         <NA>         <NA>
#
#        f.41281.0.43 f.41281.0.44 f.41281.0.45 f.41281.0.46 f.131258.0.0  day  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 1              <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 2              <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 3              <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 4              <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# ...             ...          ...          ...          ...          ...  ...
# 459151         <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 459152         <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 459153         <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 459154         <NA>         <NA>         <NA>         <NA>         <NA>  1.0
# 459155         <NA>         <NA>         <NA>         <NA>         <NA>  1.0
#
#        month       Date
# 0       11.0 1960-11-01
# 1        8.0 1954-08-01
# 2        5.0 1944-05-01
# 3        3.0 1946-03-01
# 4        1.0 1942-01-01
# ...      ...        ...
# 459151   3.0 1942-03-01
# 459152  11.0 1946-11-01
# 459153  11.0 1960-11-01
# 459154   8.0 1963-08-01
# 459155   9.0 1952-09-01
#
# [459156 rows x 918 columns]

# %%
### convert BD to date format
df['Date']= pd.to_datetime(df['Date'])

# %%
icd9_dates = [i for i in df if i.startswith('f.41281.0.')]

# %%
icd9_dates
# Out:
# ['f.41281.0.0',
#  'f.41281.0.1',
#  'f.41281.0.2',
#  'f.41281.0.3',
#  'f.41281.0.4',
#  'f.41281.0.5',
#  'f.41281.0.6',
#  'f.41281.0.7',
#  'f.41281.0.8',
#  'f.41281.0.9',
#  'f.41281.0.10',
#  'f.41281.0.11',
#  'f.41281.0.12',
#  'f.41281.0.13',
#  'f.41281.0.14',
#  'f.41281.0.15',
#  'f.41281.0.16',
#  'f.41281.0.17',
#  'f.41281.0.18',
#  'f.41281.0.19',
#  'f.41281.0.20',
#  'f.41281.0.21',
#  'f.41281.0.22',
#  'f.41281.0.23',
#  'f.41281.0.24',
#  'f.41281.0.25',
#  'f.41281.0.26',
#  'f.41281.0.27',
#  'f.41281.0.28',
#  'f.41281.0.29',
#  'f.41281.0.30',
#  'f.41281.0.31',
#  'f.41281.0.32',
#  'f.41281.0.33',
#  'f.41281.0.34',
#  'f.41281.0.35',
#  'f.41281.0.36',
#  'f.41281.0.37',
#  'f.41281.0.38',
#  'f.41281.0.39',
#  'f.41281.0.40',
#  'f.41281.0.41',
#  'f.41281.0.42',
#  'f.41281.0.43',
#  'f.41281.0.44',
#  'f.41281.0.45',
#  'f.41281.0.46']

# %% [markdown]
# ### Estimate the age of inviduals when they report any ICD9 codes

# %%
### change class for all ICD9 dates
for x in range(0,47):
    colname = "f.41281.0.{}".format(x)
    df[colname] = pd.to_datetime(df[colname])

# %%
df[icd9_colnames]
# Out:
#        f.41271.0.0 f.41271.0.1 f.41271.0.2 f.41271.0.3 f.41271.0.4  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             <NA>        <NA>        <NA>        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             3000        5198        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 459151        <NA>        <NA>        <NA>        <NA>        <NA>
# 459152        <NA>        <NA>        <NA>        <NA>        <NA>
# 459153        <NA>        <NA>        <NA>        <NA>        <NA>
# 459154        <NA>        <NA>        <NA>        <NA>        <NA>
# 459155        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.41271.0.5 f.41271.0.6 f.41271.0.7 f.41271.0.8 f.41271.0.9  ...  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 459151        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 459152        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 459153        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 459154        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 459155        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41271.0.37 f.41271.0.38 f.41271.0.39 f.41271.0.40 f.41271.0.41  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 459151         <NA>         <NA>         <NA>         <NA>         <NA>
# 459152         <NA>         <NA>         <NA>         <NA>         <NA>
# 459153         <NA>         <NA>         <NA>         <NA>         <NA>
# 459154         <NA>         <NA>         <NA>         <NA>         <NA>
# 459155         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.41271.0.42 f.41271.0.43 f.41271.0.44 f.41271.0.45 f.41271.0.46
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 459151         <NA>         <NA>         <NA>         <NA>         <NA>
# 459152         <NA>         <NA>         <NA>         <NA>         <NA>
# 459153         <NA>         <NA>         <NA>         <NA>         <NA>
# 459154         <NA>         <NA>         <NA>         <NA>         <NA>
# 459155         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [459156 rows x 47 columns]

# %%
## estimating days differences between BD and ICD9 report date
for x in range(0,47):
    colname = "f.41281.0.{}".format(x)
    newcolname = "age_f.41281.0.{}".format(x)
    df[newcolname] = (df[colname] - df['Date']) / np.timedelta64(1, 'Y')
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/2916656627.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newcolname] = (df[colname] - df['Date']) / np.timedelta64(1, 'Y')

# %%
df['age_f.41281.0.0'].dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female     1960   November        Yes       <NA>
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 459151  6025390  6025390   Female     1942      March         No       <NA>
# 459152  6025409  6025409   Female     1946   November         No         No
# 459153  6025411  6025411   Female     1960   November         No       <NA>
# 459154  6025425  6025425   Female     1963     August         No       <NA>
# 459155  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41281.0.37  \
# 0            <NA>       <NA>        Yes  ...              NaN
# 1            <NA>       <NA>        Yes  ...              NaN
# 2            <NA>       <NA>        Yes  ...              NaN
# 3              No       <NA>         No  ...              NaN
# 4            <NA>       <NA>        Yes  ...              NaN
# ...           ...        ...        ...  ...              ...
# 459151       <NA>       <NA>        Yes  ...              NaN
# 459152       <NA>       <NA>         No  ...              NaN
# 459153       <NA>       <NA>         No  ...              NaN
# 459154       <NA>       <NA>         No  ...              NaN
# 459155       <NA>       <NA>         No  ...              NaN
#
#        age_f.41281.0.38 age_f.41281.0.39 age_f.41281.0.40 age_f.41281.0.41  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 459151              NaN              NaN              NaN              NaN
# 459152              NaN              NaN              NaN              NaN
# 459153              NaN              NaN              NaN              NaN
# 459154              NaN              NaN              NaN              NaN
# 459155              NaN              NaN              NaN              NaN
#
#        age_f.41281.0.42 age_f.41281.0.43 age_f.41281.0.44 age_f.41281.0.45  \
# 0                   NaN              NaN              NaN              NaN
# 1                   NaN              NaN              NaN              NaN
# 2                   NaN              NaN              NaN              NaN
# 3                   NaN              NaN              NaN              NaN
# 4                   NaN              NaN              NaN              NaN
# ...                 ...              ...              ...              ...
# 459151              NaN              NaN              NaN              NaN
# 459152              NaN              NaN              NaN              NaN
# 459153              NaN              NaN              NaN              NaN
# 459154              NaN              NaN              NaN              NaN
# 459155              NaN              NaN              NaN              NaN
#
#        age_f.41281.0.46
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 459151              NaN
# 459152              NaN
# 459153              NaN
# 459154              NaN
# 459155              NaN
#
# [459156 rows x 965 columns]

# %%
test = df [["IID","f.41271.0.0", "age_f.41281.0.0","f.41271.0.1", "age_f.41281.0.1"]]
test
# Out:
#             IID f.41271.0.0  age_f.41281.0.0 f.41271.0.1  age_f.41281.0.1
# 0       1000019        <NA>              NaN        <NA>              NaN
# 1       1000022        <NA>              NaN        <NA>              NaN
# 2       1000035        <NA>              NaN        <NA>              NaN
# 3       1000046        <NA>              NaN        <NA>              NaN
# 4       1000054        3000        39.037078        5198        39.037078
# ...         ...         ...              ...         ...              ...
# 459151  6025390        <NA>              NaN        <NA>              NaN
# 459152  6025409        <NA>              NaN        <NA>              NaN
# 459153  6025411        <NA>              NaN        <NA>              NaN
# 459154  6025425        <NA>              NaN        <NA>              NaN
# 459155  6025438        <NA>              NaN        <NA>              NaN
#
# [459156 rows x 5 columns]

# %% [markdown]
# ### Estimate the age of inviduals when they report any ICD10 codes

# %%
icd10_dates = [i for i in df if i.startswith('f.41280.0.')]

# %%
icd10_dates
# Out:
# ['f.41280.0.0',
#  'f.41280.0.1',
#  'f.41280.0.2',
#  'f.41280.0.3',
#  'f.41280.0.4',
#  'f.41280.0.5',
#  'f.41280.0.6',
#  'f.41280.0.7',
#  'f.41280.0.8',
#  'f.41280.0.9',
#  'f.41280.0.10',
#  'f.41280.0.11',
#  'f.41280.0.12',
#  'f.41280.0.13',
#  'f.41280.0.14',
#  'f.41280.0.15',
#  'f.41280.0.16',
#  'f.41280.0.17',
#  'f.41280.0.18',
#  'f.41280.0.19',
#  'f.41280.0.20',
#  'f.41280.0.21',
#  'f.41280.0.22',
#  'f.41280.0.23',
#  'f.41280.0.24',
#  'f.41280.0.25',
#  'f.41280.0.26',
#  'f.41280.0.27',
#  'f.41280.0.28',
#  'f.41280.0.29',
#  'f.41280.0.30',
#  'f.41280.0.31',
#  'f.41280.0.32',
#  'f.41280.0.33',
#  'f.41280.0.34',
#  'f.41280.0.35',
#  'f.41280.0.36',
#  'f.41280.0.37',
#  'f.41280.0.38',
#  'f.41280.0.39',
#  'f.41280.0.40',
#  'f.41280.0.41',
#  'f.41280.0.42',
#  'f.41280.0.43',
#  'f.41280.0.44',
#  'f.41280.0.45',
#  'f.41280.0.46',
#  'f.41280.0.47',
#  'f.41280.0.48',
#  'f.41280.0.49',
#  'f.41280.0.50',
#  'f.41280.0.51',
#  'f.41280.0.52',
#  'f.41280.0.53',
#  'f.41280.0.54',
#  'f.41280.0.55',
#  'f.41280.0.56',
#  'f.41280.0.57',
#  'f.41280.0.58',
#  'f.41280.0.59',
#  'f.41280.0.60',
#  'f.41280.0.61',
#  'f.41280.0.62',
#  'f.41280.0.63',
#  'f.41280.0.64',
#  'f.41280.0.65',
#  'f.41280.0.66',
#  'f.41280.0.67',
#  'f.41280.0.68',
#  'f.41280.0.69',
#  'f.41280.0.70',
#  'f.41280.0.71',
#  'f.41280.0.72',
#  'f.41280.0.73',
#  'f.41280.0.74',
#  'f.41280.0.75',
#  'f.41280.0.76',
#  'f.41280.0.77',
#  'f.41280.0.78',
#  'f.41280.0.79',
#  'f.41280.0.80',
#  'f.41280.0.81',
#  'f.41280.0.82',
#  'f.41280.0.83',
#  'f.41280.0.84',
#  'f.41280.0.85',
#  'f.41280.0.86',
#  'f.41280.0.87',
#  'f.41280.0.88',
#  'f.41280.0.89',
#  'f.41280.0.90',
#  'f.41280.0.91',
#  'f.41280.0.92',
#  'f.41280.0.93',
#  'f.41280.0.94',
#  'f.41280.0.95',
#  'f.41280.0.96',
#  'f.41280.0.97',
#  'f.41280.0.98',
#  'f.41280.0.99',
#  'f.41280.0.100',
#  'f.41280.0.101',
#  'f.41280.0.102',
#  'f.41280.0.103',
#  'f.41280.0.104',
#  'f.41280.0.105',
#  'f.41280.0.106',
#  'f.41280.0.107',
#  'f.41280.0.108',
#  'f.41280.0.109',
#  'f.41280.0.110',
#  'f.41280.0.111',
#  'f.41280.0.112',
#  'f.41280.0.113',
#  'f.41280.0.114',
#  'f.41280.0.115',
#  'f.41280.0.116',
#  'f.41280.0.117',
#  'f.41280.0.118',
#  'f.41280.0.119',
#  'f.41280.0.120',
#  'f.41280.0.121',
#  'f.41280.0.122',
#  'f.41280.0.123',
#  'f.41280.0.124',
#  'f.41280.0.125',
#  'f.41280.0.126',
#  'f.41280.0.127',
#  'f.41280.0.128',
#  'f.41280.0.129',
#  'f.41280.0.130',
#  'f.41280.0.131',
#  'f.41280.0.132',
#  'f.41280.0.133',
#  'f.41280.0.134',
#  'f.41280.0.135',
#  'f.41280.0.136',
#  'f.41280.0.137',
#  'f.41280.0.138',
#  'f.41280.0.139',
#  'f.41280.0.140',
#  'f.41280.0.141',
#  'f.41280.0.142',
#  'f.41280.0.143',
#  'f.41280.0.144',
#  'f.41280.0.145',
#  'f.41280.0.146',
#  'f.41280.0.147',
#  'f.41280.0.148',
#  'f.41280.0.149',
#  'f.41280.0.150',
#  'f.41280.0.151',
#  'f.41280.0.152',
#  'f.41280.0.153',
#  'f.41280.0.154',
#  'f.41280.0.155',
#  'f.41280.0.156',
#  'f.41280.0.157',
#  'f.41280.0.158',
#  'f.41280.0.159',
#  'f.41280.0.160',
#  'f.41280.0.161',
#  'f.41280.0.162',
#  'f.41280.0.163',
#  'f.41280.0.164',
#  'f.41280.0.165',
#  'f.41280.0.166',
#  'f.41280.0.167',
#  'f.41280.0.168',
#  'f.41280.0.169',
#  'f.41280.0.170',
#  'f.41280.0.171',
#  'f.41280.0.172',
#  'f.41280.0.173',
#  'f.41280.0.174',
#  'f.41280.0.175',
#  'f.41280.0.176',
#  'f.41280.0.177',
#  'f.41280.0.178',
#  'f.41280.0.179',
#  'f.41280.0.180',
#  'f.41280.0.181',
#  'f.41280.0.182',
#  'f.41280.0.183',
#  'f.41280.0.184',
#  'f.41280.0.185',
#  'f.41280.0.186',
#  'f.41280.0.187',
#  'f.41280.0.188',
#  'f.41280.0.189',
#  'f.41280.0.190',
#  'f.41280.0.191',
#  'f.41280.0.192',
#  'f.41280.0.193',
#  'f.41280.0.194',
#  'f.41280.0.195',
#  'f.41280.0.196',
#  'f.41280.0.197',
#  'f.41280.0.198',
#  'f.41280.0.199',
#  'f.41280.0.200',
#  'f.41280.0.201',
#  'f.41280.0.202',
#  'f.41280.0.203',
#  'f.41280.0.204',
#  'f.41280.0.205',
#  'f.41280.0.206',
#  'f.41280.0.207',
#  'f.41280.0.208',
#  'f.41280.0.209',
#  'f.41280.0.210',
#  'f.41280.0.211',
#  'f.41280.0.212',
#  'f.41280.0.213',
#  'f.41280.0.214',
#  'f.41280.0.215',
#  'f.41280.0.216',
#  'f.41280.0.217',
#  'f.41280.0.218',
#  'f.41280.0.219',
#  'f.41280.0.220',
#  'f.41280.0.221',
#  'f.41280.0.222',
#  'f.41280.0.223',
#  'f.41280.0.224',
#  'f.41280.0.225',
#  'f.41280.0.226',
#  'f.41280.0.227',
#  'f.41280.0.228',
#  'f.41280.0.229',
#  'f.41280.0.230',
#  'f.41280.0.231',
#  'f.41280.0.232',
#  'f.41280.0.233',
#  'f.41280.0.234',
#  'f.41280.0.235',
#  'f.41280.0.236',
#  'f.41280.0.237',
#  'f.41280.0.238',
#  'f.41280.0.239',
#  'f.41280.0.240',
#  'f.41280.0.241',
#  'f.41280.0.242',
#  'f.41280.0.243',
#  'f.41280.0.244',
#  'f.41280.0.245',
#  'f.41280.0.246',
#  'f.41280.0.247',
#  'f.41280.0.248',
#  'f.41280.0.249',
#  'f.41280.0.250',
#  'f.41280.0.251',
#  'f.41280.0.252',
#  'f.41280.0.253',
#  'f.41280.0.254',
#  'f.41280.0.255',
#  'f.41280.0.256',
#  'f.41280.0.257',
#  'f.41280.0.258']

# %%
### change class for all ICD10 dates
for x in range(0,259):
    colname_ICD10 = "f.41280.0.{}".format(x)
    df[colname_ICD10] = pd.to_datetime(df[colname_ICD10])

# %%
df[colname_ICD10].dtype
# Out:
# dtype('<M8[ns]')

# %%
## estimating days differences between BD and ICD10 report date
for x in range(0,259):
    colname_ICD10 = "f.41280.0.{}".format(x)
    newcolname_ICD10 = "age_f.41280.0.{}".format(x)
    df[newcolname_ICD10] = (df[colname_ICD10] - df['Date']) / np.timedelta64(1, 'Y')
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/1569581057.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[newcolname_ICD10] = (df[colname_ICD10] - df['Date']) / np.timedelta64(1, 'Y')

# %%
df[['age_f.41280.0.0']]
# Out:
#         age_f.41280.0.0
# 0             53.055162
# 1             60.997830
# 2             70.024710
# 3             63.667290
# 4             72.017906
# ...                 ...
# 459151        78.873625
# 459152              NaN
# 459153        36.529155
# 459154        45.572462
# 459155        50.246069
#
# [459156 rows x 1 columns]

# %%
ICD10_test = df [["IID","Date", "f.41270.0.0", "f.41280.0.0","age_f.41280.0.0","f.41270.0.1","f.41280.0.1", "age_f.41280.0.1", "f.41270.0.100","f.41280.0.100", "age_f.41280.0.100"]]

# %%
ICD10_test
# Out:
#             IID       Date f.41270.0.0 f.41280.0.0  age_f.41280.0.0  \
# 0       1000019 1960-11-01        E041  2013-11-21        53.055162
# 1       1000022 1954-08-01        F101  2015-07-31        60.997830
# 2       1000035 1944-05-01        H269  2014-05-10        70.024710
# 3       1000046 1946-03-01        E780  2009-10-30        63.667290
# 4       1000054 1942-01-01        C679  2014-01-07        72.017906
# ...         ...        ...         ...         ...              ...
# 459151  6025390 1942-03-01        A049  2021-01-13        78.873625
# 459152  6025409 1946-11-01        <NA>         NaT              NaN
# 459153  6025411 1960-11-01        O149  1997-05-13        36.529155
# 459154  6025425 1963-08-01        G551  2009-02-25        45.572462
# 459155  6025438 1952-09-01        D225  2002-11-30        50.246069
#
#        f.41270.0.1 f.41280.0.1  age_f.41280.0.1 f.41270.0.100 f.41280.0.100  \
# 0             F329  2020-03-02        59.333183          <NA>           NaT
# 1             J342  2002-03-14        47.617679          <NA>           NaT
# 2             K579  2007-02-14        62.791159          <NA>           NaT
# 3             G473  2014-05-28        68.242332          <NA>           NaT
# 4             C787  2014-04-08        72.267055          <NA>           NaT
# ...            ...         ...              ...           ...           ...
# 459151        A099  2020-12-01        78.755895          <NA>           NaT
# 459152        <NA>         NaT              NaN          <NA>           NaT
# 459153        O266  1997-05-13        36.529155          <NA>           NaT
# 459154        G558  2018-08-08        55.020979          <NA>           NaT
# 459155        S008  2021-05-25        68.729680          <NA>           NaT
#
#         age_f.41280.0.100
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 459151                NaN
# 459152                NaN
# 459153                NaN
# 459154                NaN
# 459155                NaN
#
# [459156 rows x 11 columns]

# %%
### saving the working file wirh ages for ICD9
#df.to_csv("/mnt/vast/hpc/csg/en2509/Phenotype/500k.ARHL.phe_ICD9_10_ages.csv",index=False)

# %%
df["f.41280.0.100"].value_counts(dropna=False)
# Out:
# NaT           457811
# 2020-05-27         4
# 2019-11-26         4
# 2020-11-02         4
# 2020-06-30         3
#                ...
# 2007-04-04         1
# 1999-10-30         1
# 2016-06-22         1
# 2004-11-15         1
# 2014-10-08         1
# Name: f.41280.0.100, Length: 1230, dtype: int64

# %%
df["age_f.41280.0.100"].value_counts(dropna=False)
# Out:
# NaN          457811
# 72.083616         3
# 81.942819         2
# 60.882838         2
# 62.785683         2
#               ...
# 43.434157         1
# 74.090502         1
# 68.910381         1
# 72.759879         1
# 74.101453         1
# Name: age_f.41280.0.100, Length: 1268, dtype: int64

# %%
### keep white European. In this working file I've already subsetted the white european
#white = pd.read_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/ukb47922_white_460649ind.pheno", sep = '\t', engine = 'python')

# %%
### chnaging string to int before merging 
df['IID'] = df['IID'].astype(int)
df['FID'] = df['FID'].astype(int)

# %%
#df_white = white.merge(df, on=['IID','FID'], how='inner')

# %%
#df_white
# Out:
#             FID      IID ethnicity f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0  \
# 0       1000019  1000019   British   Female     1960   November        Yes
# 1       1000022  1000022   British     Male     1954     August        Yes
# 2       1000035  1000035   British     Male     1944        May         No
# 3       1000046  1000046   British   Female     1946      March         No
# 4       1000054  1000054   British   Female     1942    January         No
# ...         ...      ...       ...      ...      ...        ...        ...
# 460644  6025390  6025390   British   Female     1942      March         No
# 460645  6025409  6025409   British   Female     1946   November         No
# 460646  6025411  6025411   British   Female     1960   November         No
# 460647  6025425  6025425   British   Female     1963     August         No
# 460648  6025438  6025438   British     Male     1952  September         No
#
#        f.2247.1.0 f.2247.2.0 f.2247.3.0  ... age_f.41280.0.216  \
# 0            <NA>       <NA>       <NA>  ...              <NA>
# 1            <NA>       <NA>       <NA>  ...              <NA>
# 2            <NA>       <NA>       <NA>  ...              <NA>
# 3            <NA>         No       <NA>  ...              <NA>
# 4            <NA>       <NA>       <NA>  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 460644       <NA>       <NA>       <NA>  ...              <NA>
# 460645         No       <NA>       <NA>  ...              <NA>
# 460646       <NA>       <NA>       <NA>  ...              <NA>
# 460647       <NA>       <NA>       <NA>  ...              <NA>
# 460648       <NA>       <NA>       <NA>  ...              <NA>
#
#        age_f.41280.0.217 age_f.41280.0.218 age_f.41280.0.219  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 460644              <NA>              <NA>              <NA>
# 460645              <NA>              <NA>              <NA>
# 460646              <NA>              <NA>              <NA>
# 460647              <NA>              <NA>              <NA>
# 460648              <NA>              <NA>              <NA>
#
#        age_f.41280.0.220 age_f.41280.0.221 age_f.41280.0.222  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 460644              <NA>              <NA>              <NA>
# 460645              <NA>              <NA>              <NA>
# 460646              <NA>              <NA>              <NA>
# 460647              <NA>              <NA>              <NA>
# 460648              <NA>              <NA>              <NA>
#
#        age_f.41280.0.223 age_f.41280.0.224 age_f.41280.0.225
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 460644              <NA>              <NA>              <NA>
# 460645              <NA>              <NA>              <NA>
# 460646              <NA>              <NA>              <NA>
# 460647              <NA>              <NA>              <NA>
# 460648              <NA>              <NA>              <NA>
#
# [460649 rows x 1125 columns]

# %%
### saving the working file wirh ages for ICD9 and white Europeans
#df_white.to_csv("/mnt/vast/hpc/csg/en2509/Phenotype/500k.ARHL.phe_ICD9_10_ages_whiteEuro_EN.csv",index=False)

# %%
#df = pd.read_csv("/mnt/vast/hpc/csg/en2509/Phenotype/500k.ARHL.phe_ICD9_10_ages_whiteEuro_EN.csv", quotechar = '"', dtype="string")
#df
# Out:
#             FID      IID ethnicity f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0  \
# 0       1000019  1000019   British   Female     1960   November        Yes
# 1       1000022  1000022   British     Male     1954     August        Yes
# 2       1000035  1000035   British     Male     1944        May         No
# 3       1000046  1000046   British   Female     1946      March         No
# 4       1000054  1000054   British   Female     1942    January         No
# ...         ...      ...       ...      ...      ...        ...        ...
# 460644  6025390  6025390   British   Female     1942      March         No
# 460645  6025409  6025409   British   Female     1946   November         No
# 460646  6025411  6025411   British   Female     1960   November         No
# 460647  6025425  6025425   British   Female     1963     August         No
# 460648  6025438  6025438   British     Male     1952  September         No
#
#        f.2247.1.0 f.2247.2.0 f.2247.3.0  ... age_f.41280.0.216  \
# 0            <NA>       <NA>       <NA>  ...              <NA>
# 1            <NA>       <NA>       <NA>  ...              <NA>
# 2            <NA>       <NA>       <NA>  ...              <NA>
# 3            <NA>         No       <NA>  ...              <NA>
# 4            <NA>       <NA>       <NA>  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 460644       <NA>       <NA>       <NA>  ...              <NA>
# 460645         No       <NA>       <NA>  ...              <NA>
# 460646       <NA>       <NA>       <NA>  ...              <NA>
# 460647       <NA>       <NA>       <NA>  ...              <NA>
# 460648       <NA>       <NA>       <NA>  ...              <NA>
#
#        age_f.41280.0.217 age_f.41280.0.218 age_f.41280.0.219  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 460644              <NA>              <NA>              <NA>
# 460645              <NA>              <NA>              <NA>
# 460646              <NA>              <NA>              <NA>
# 460647              <NA>              <NA>              <NA>
# 460648              <NA>              <NA>              <NA>
#
#        age_f.41280.0.220 age_f.41280.0.221 age_f.41280.0.222  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 460644              <NA>              <NA>              <NA>
# 460645              <NA>              <NA>              <NA>
# 460646              <NA>              <NA>              <NA>
# 460647              <NA>              <NA>              <NA>
# 460648              <NA>              <NA>              <NA>
#
#        age_f.41280.0.223 age_f.41280.0.224 age_f.41280.0.225
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 460644              <NA>              <NA>              <NA>
# 460645              <NA>              <NA>              <NA>
# 460646              <NA>              <NA>              <NA>
# 460647              <NA>              <NA>              <NA>
# 460648              <NA>              <NA>              <NA>
#
# [460649 rows x 1125 columns]

# %%
# outlier individuals that will need to be removed
outlier = pd.read_csv("/mnt/mfs/statgen/UKBiobank/results/092821_PCA_results_500K/092821_PCA_related_pval0.005/ukb47922_white_460649ind.092821_PCA_related_pval0.005.pca.projected.outliers", sep="\t", header=None)
outlier
# Out:
#             0        1
# 0     1003423  1003423
# 1     1008606  1008606
# 2     1009852  1009852
# 3     1010412  1010412
# 4     1010678  1010678
# ...       ...      ...
# 1377  5801962  5801962
# 1378  5807807  5807807
# 1379  5809112  5809112
# 1380  5833189  5833189
# 1381  5939807  5939807
#
# [1382 rows x 2 columns]

# %%
outlier.columns =['FID', 'IID']

# %%
list(outlier.columns)
# Out:
# ['FID', 'IID']

# %%
df.IID.dtype
# Out:
# dtype('int64')

# %%
outlier.IID.dtype
# Out:
# dtype('int64')

# %%
Filtered_PCA = df[~df.loc[:,'IID'].isin(outlier['IID'])]

# %%
Filtered_PCA
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female     1960   November        Yes       <NA>
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 459151  6025390  6025390   Female     1942      March         No       <NA>
# 459152  6025409  6025409   Female     1946   November         No         No
# 459153  6025411  6025411   Female     1960   November         No       <NA>
# 459154  6025425  6025425   Female     1963     August         No       <NA>
# 459155  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.249  \
# 0            <NA>       <NA>        Yes  ...               NaN
# 1            <NA>       <NA>        Yes  ...               NaN
# 2            <NA>       <NA>        Yes  ...               NaN
# 3              No       <NA>         No  ...               NaN
# 4            <NA>       <NA>        Yes  ...               NaN
# ...           ...        ...        ...  ...               ...
# 459151       <NA>       <NA>        Yes  ...               NaN
# 459152       <NA>       <NA>         No  ...               NaN
# 459153       <NA>       <NA>         No  ...               NaN
# 459154       <NA>       <NA>         No  ...               NaN
# 459155       <NA>       <NA>         No  ...               NaN
#
#        age_f.41280.0.250 age_f.41280.0.251 age_f.41280.0.252  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
#        age_f.41280.0.253 age_f.41280.0.254 age_f.41280.0.255  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
#        age_f.41280.0.256 age_f.41280.0.257 age_f.41280.0.258
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
# [459156 rows x 1224 columns]

# %%
### saving the working file wirh ages for ICD9, white Europeans and after removing PCA outliers
Filtered_PCA.to_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/071923_ukb673643_459241ind_call90_subsetvars_ICD9_10_ages_whiteEuro_PCAout.csv",index=False)

# %%
### saving the working file wirh ages for ICD9, white Europeans and after removing PCA outliers
#Filtered_PCA_Exclude.to_csv("/mnt/vast/hpc/csg/en2509/Phenotype/500k.IC9_ICD10_self_reported_EN.csv",index=False)

# %% [markdown]
# ## From here, filter dataframe which have age less than 40 years for any of ICD9, ICD10 or self-reported

# %%
#df = pd.read_csv("/mnt/vast/hpc/csg/en2509/Phenotype/500k.IC9_ICD10_self_reported_EN.csv", quotechar = '"', index_col = "IID")
df = pd.read_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/071923_ukb673643_459241ind_call90_subsetvars_ICD9_10_ages_whiteEuro_PCAout.csv", quotechar = '"')
df
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (296,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,598,602,603,604,605,606,607,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,723,724,725,726,727,728,729,730,731,732,733,734,735,736,737,738,739,740,741,742,743,744,745,746,747,748,749,750,751,752,753,754,755,756,757,758,759,760,761,762,763,764,765,766,767,768,769,770,771,772,773,774,775,776,777,778,779,780,781,782,783,784,785,786,787,788,789,790,791,792,793,794,795,796,797,798,799,800,801,802,803,804,805,806,807,808,809,810,811,812,813,814,815,816,817,818,819,820,821,822,823,824,825,826,827,828,829,830,831,832,833,834,835,836,837,838,839,840,841,842,843,844,845,846,847,848,849,850,851,852,853,854,855,856,857,858,859,860,861,862,863,864,865,866,870,871,872,873,874,875,876,877,878,879,880,881,882,883,884,885,886,887,888,889,890,891,892,893,894,895,896,897,898,899,900,901,902,903,904,905,906,907,908,909,910,911,912,913) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             IID      FID f.31.0.0  f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female      1960   November        Yes        NaN
# 1       1000022  1000022     Male      1954     August        Yes        NaN
# 2       1000035  1000035     Male      1944        May         No        NaN
# 3       1000046  1000046   Female      1946      March         No        NaN
# 4       1000054  1000054   Female      1942    January         No        NaN
# ...         ...      ...      ...       ...        ...        ...        ...
# 459151  6025390  6025390   Female      1942      March         No        NaN
# 459152  6025409  6025409   Female      1946   November         No         No
# 459153  6025411  6025411   Female      1960   November         No        NaN
# 459154  6025425  6025425   Female      1963     August         No        NaN
# 459155  6025438  6025438     Male      1952  September         No        NaN
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.249  \
# 0             NaN        NaN        Yes  ...               NaN
# 1             NaN        NaN        Yes  ...               NaN
# 2             NaN        NaN        Yes  ...               NaN
# 3              No        NaN         No  ...               NaN
# 4             NaN        NaN        Yes  ...               NaN
# ...           ...        ...        ...  ...               ...
# 459151        NaN        NaN        Yes  ...               NaN
# 459152        NaN        NaN         No  ...               NaN
# 459153        NaN        NaN         No  ...               NaN
# 459154        NaN        NaN         No  ...               NaN
# 459155        NaN        NaN         No  ...               NaN
#
#        age_f.41280.0.250 age_f.41280.0.251 age_f.41280.0.252  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
#        age_f.41280.0.253 age_f.41280.0.254 age_f.41280.0.255  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
#        age_f.41280.0.256 age_f.41280.0.257 age_f.41280.0.258
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
# [459156 rows x 1224 columns]

# %%
#list(df.columns)

# %%
df["f.41270.0.0"].value_counts() #categories in ICD10
# Out:
# A099     18147
# E780     15615
# I10      12603
# E039     10544
# C61       9038
#          ...
# G620         1
# R788         1
# M0604        1
# L981         1
# O074         1
# Name: f.41270.0.0, Length: 4863, dtype: int64

# %%
df["f.41271.0.0"].value_counts() #categories in ICD9
# Out:
# V252       795
# 4549       554
# 4549.0     324
# 2189       299
# 6262       243
#           ...
# 2221.0       1
# 3594.0       1
# 721.0        1
# 72709.0      1
# 5343         1
# Name: f.41271.0.0, Length: 2625, dtype: int64

# %%
df["f.20002.0.0"].value_counts() # Categories of non-cancer illness
# Out:
# 1065.0    103596
# 1111.0     34508
# 1465.0     10777
# 1075.0     10269
# 1074.0      9873
#            ...
# 1496.0         1
# 1521.0         1
# 1468.0         1
# 1621.0         1
# 1678.0         1
# Name: f.20002.0.0, Length: 440, dtype: int64

# %%
def self(number):
    if  number == 1415:
        return "self"
    else:
        return "Not Sure"

# %%
selfreport_colnames = [col for col in df if "f.20002" in col]
for col in selfreport_colnames:
    df["test"] = df[col].apply(self)

# %%
df["test"].value_counts()
# Out:
# Not Sure    459156
# Name: test, dtype: int64

# %%
mask_list = []

for i in range(32):
    mask_list.append(df[f"f.20002.0.{i}"] == 1415)
    mask_list.append(df[f"f.20002.1.{i}"] == 1415)
    mask_list.append(df[f"f.20002.2.{i}"] == 1415)
    mask_list.append(df[f"f.20002.3.{i}"] == 1415)

combined_mask = pd.concat(mask_list, axis=1).any(axis=1)
df_1415_all_visits = df[combined_mask]
df_1415_all_visits
# Out:
#             IID      FID f.31.0.0  f.34.0.0  f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 67      1000767  1000767     Male      1959    August        Yes        NaN
# 259     1002847  1002847     Male      1953  November         No        NaN
# 388     1004257  1004257     Male      1939  December        Yes        NaN
# 496     1005452  1005452   Female      1942    August        Yes        NaN
# 814     1009003  1009003   Female      1950      July         No        NaN
# ...         ...      ...      ...       ...       ...        ...        ...
# 458718  6020619  6020619   Female      1944      June         No        NaN
# 458842  6021968  6021968   Female      1940  December        Yes        NaN
# 458945  6023081  6023081   Female      1941  November        Yes        NaN
# 459022  6023914  6023914   Female      1955  February        Yes        NaN
# 459134  6025180  6025180     Male      1940  February        Yes        NaN
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 67            NaN        NaN        Yes  ...               NaN
# 259           NaN        NaN         No  ...               NaN
# 388           NaN        NaN        Yes  ...               NaN
# 496           NaN        NaN        Yes  ...               NaN
# 814           NaN        NaN         No  ...               NaN
# ...           ...        ...        ...  ...               ...
# 458718        NaN        NaN         No  ...               NaN
# 458842        NaN        NaN        Yes  ...               NaN
# 458945        NaN        NaN        Yes  ...               NaN
# 459022        NaN        NaN         No  ...               NaN
# 459134        NaN        NaN        Yes  ...               NaN
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 67                   NaN               NaN               NaN
# 259                  NaN               NaN               NaN
# 388                  NaN               NaN               NaN
# 496                  NaN               NaN               NaN
# 814                  NaN               NaN               NaN
# ...                  ...               ...               ...
# 458718               NaN               NaN               NaN
# 458842               NaN               NaN               NaN
# 458945               NaN               NaN               NaN
# 459022               NaN               NaN               NaN
# 459134               NaN               NaN               NaN
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 67                   NaN               NaN               NaN
# 259                  NaN               NaN               NaN
# 388                  NaN               NaN               NaN
# 496                  NaN               NaN               NaN
# 814                  NaN               NaN               NaN
# ...                  ...               ...               ...
# 458718               NaN               NaN               NaN
# 458842               NaN               NaN               NaN
# 458945               NaN               NaN               NaN
# 459022               NaN               NaN               NaN
# 459134               NaN               NaN               NaN
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 67                   NaN               NaN  Not Sure
# 259                  NaN               NaN  Not Sure
# 388                  NaN               NaN  Not Sure
# 496                  NaN               NaN  Not Sure
# 814                  NaN               NaN  Not Sure
# ...                  ...               ...       ...
# 458718               NaN               NaN  Not Sure
# 458842               NaN               NaN  Not Sure
# 458945               NaN               NaN  Not Sure
# 459022               NaN               NaN  Not Sure
# 459134               NaN               NaN  Not Sure
#
# [4282 rows x 1225 columns]

# %%
mask_list = []

for i in range(32):
    mask_list.append(df_1415_all_visits[f"f.20009.0.{i}"] < 40)
    mask_list.append(df_1415_all_visits[f"f.20009.1.{i}"] < 40)
    mask_list.append(df_1415_all_visits[f"f.20009.2.{i}"] < 40)
    mask_list.append(df_1415_all_visits[f"f.20009.3.{i}"] < 40)

combined_mask = pd.concat(mask_list, axis=1).any(axis=1)
df_1415_all_visits_age_less_40 = df_1415_all_visits[combined_mask]
df_1415_all_visits_age_less_40
# Out:
#             IID      FID f.31.0.0  f.34.0.0  f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 67      1000767  1000767     Male      1959    August        Yes        NaN
# 388     1004257  1004257     Male      1939  December        Yes        NaN
# 496     1005452  1005452   Female      1942    August        Yes        NaN
# 895     1009880  1009880   Female      1955   October         No        NaN
# 901     1009950  1009950     Male      1950   October        Yes        Yes
# ...         ...      ...      ...       ...       ...        ...        ...
# 458016  6012912  6012912   Female      1947      June        Yes        NaN
# 458154  6014453  6014453     Male      1939      June        Yes        NaN
# 458675  6020151  6020151     Male      1957  November        Yes        Yes
# 458718  6020619  6020619   Female      1944      June         No        NaN
# 459022  6023914  6023914   Female      1955  February        Yes        NaN
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 67            NaN        NaN        Yes  ...               NaN
# 388           NaN        NaN        Yes  ...               NaN
# 496           NaN        NaN        Yes  ...               NaN
# 895           NaN        NaN         No  ...               NaN
# 901           Yes        NaN         No  ...               NaN
# ...           ...        ...        ...  ...               ...
# 458016        NaN        NaN        Yes  ...               NaN
# 458154        NaN        NaN        Yes  ...               NaN
# 458675        Yes        NaN        Yes  ...               NaN
# 458718        NaN        NaN         No  ...               NaN
# 459022        NaN        NaN         No  ...               NaN
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 67                   NaN               NaN               NaN
# 388                  NaN               NaN               NaN
# 496                  NaN               NaN               NaN
# 895                  NaN               NaN               NaN
# 901                  NaN               NaN               NaN
# ...                  ...               ...               ...
# 458016               NaN               NaN               NaN
# 458154               NaN               NaN               NaN
# 458675               NaN               NaN               NaN
# 458718               NaN               NaN               NaN
# 459022               NaN               NaN               NaN
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 67                   NaN               NaN               NaN
# 388                  NaN               NaN               NaN
# 496                  NaN               NaN               NaN
# 895                  NaN               NaN               NaN
# 901                  NaN               NaN               NaN
# ...                  ...               ...               ...
# 458016               NaN               NaN               NaN
# 458154               NaN               NaN               NaN
# 458675               NaN               NaN               NaN
# 458718               NaN               NaN               NaN
# 459022               NaN               NaN               NaN
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 67                   NaN               NaN  Not Sure
# 388                  NaN               NaN  Not Sure
# 496                  NaN               NaN  Not Sure
# 895                  NaN               NaN  Not Sure
# 901                  NaN               NaN  Not Sure
# ...                  ...               ...       ...
# 458016               NaN               NaN  Not Sure
# 458154               NaN               NaN  Not Sure
# 458675               NaN               NaN  Not Sure
# 458718               NaN               NaN  Not Sure
# 459022               NaN               NaN  Not Sure
#
# [3187 rows x 1225 columns]

# %%
### saving individuals with 1415 codes and younger than 40 years old (N= 3,923 ind)
### these individuals should remove from ARHL but not tinnitus analysis
#df_1415_all_visits_age_less_40.to_csv("/mnt/vast/hpc/csg/en2509/Phenotype/ind_1415_younger_than_40yo_EN.csv",index=False)

# %% [markdown]
# # For ICD10 interested codes

# %%
cols = df.filter(like='f.41270.0.').columns
mask = df[cols].isin(["H903", "H904", "H905", "H906", "H907", "H908", "H918", "H919"]).any(axis=1)
df_ICD10_all_visits = df[mask]
df_ICD10_all_visits
# Out:
#             IID      FID f.31.0.0  f.34.0.0   f.52.0.0   f.2247.0.0  \
# 55      1000611  1000611   Female      1953      March           No
# 95      1001067  1001067     Male      1959      April          Yes
# 108     1001196  1001196     Male      1949  September          Yes
# 133     1001459  1001459     Male      1944    January          Yes
# 232     1002548  1002548     Male      1948    January          Yes
# ...         ...      ...      ...       ...        ...          ...
# 459056  6024282  6024282   Female      1953     August          Yes
# 459061  6024352  6024352   Female      1939    October          Yes
# 459069  6024448  6024448   Female      1951       July          Yes
# 459104  6024829  6024829   Female      1952   February  Do not know
# 459115  6024960  6024960     Male      1951   November          Yes
#
#        f.2247.1.0 f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 55            NaN        NaN        NaN         No  ...               NaN
# 95            NaN        NaN        NaN        Yes  ...               NaN
# 108           NaN        Yes        NaN        Yes  ...               NaN
# 133           NaN        NaN        NaN        Yes  ...               NaN
# 232           NaN        NaN        NaN        Yes  ...               NaN
# ...           ...        ...        ...        ...  ...               ...
# 459056        NaN        NaN        NaN        Yes  ...               NaN
# 459061        NaN        NaN        NaN        Yes  ...               NaN
# 459069        NaN        NaN        NaN        Yes  ...               NaN
# 459104        NaN        NaN        NaN        Yes  ...               NaN
# 459115        NaN        NaN        NaN        Yes  ...               NaN
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 55                   NaN               NaN               NaN
# 95                   NaN               NaN               NaN
# 108                  NaN               NaN               NaN
# 133                  NaN               NaN               NaN
# 232                  NaN               NaN               NaN
# ...                  ...               ...               ...
# 459056               NaN               NaN               NaN
# 459061               NaN               NaN               NaN
# 459069               NaN               NaN               NaN
# 459104               NaN               NaN               NaN
# 459115               NaN               NaN               NaN
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 55                   NaN               NaN               NaN
# 95                   NaN               NaN               NaN
# 108                  NaN               NaN               NaN
# 133                  NaN               NaN               NaN
# 232                  NaN               NaN               NaN
# ...                  ...               ...               ...
# 459056               NaN               NaN               NaN
# 459061               NaN               NaN               NaN
# 459069               NaN               NaN               NaN
# 459104               NaN               NaN               NaN
# 459115               NaN               NaN               NaN
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 55                   NaN               NaN  Not Sure
# 95                   NaN               NaN  Not Sure
# 108                  NaN               NaN  Not Sure
# 133                  NaN               NaN  Not Sure
# 232                  NaN               NaN  Not Sure
# ...                  ...               ...       ...
# 459056               NaN               NaN  Not Sure
# 459061               NaN               NaN  Not Sure
# 459069               NaN               NaN  Not Sure
# 459104               NaN               NaN  Not Sure
# 459115               NaN               NaN  Not Sure
#
# [13721 rows x 1225 columns]

# %%
from functools import reduce

columns = [f"f.41270.0.{i}" for i in range(259)]
columns_age = [f"f.41280.0.{i}" for i in range(259)]
masks = [df[col].isin(["H903", "H904", "H905", "H906", "H907", "H908", "H918", "H919"]) for col in columns]
Amasks = [df[f"age_{col}"] < 40 for col in columns_age]

df_ICD10_all_visits_age_less_than40 = df[reduce(lambda x, y: x | y, masks) & reduce(lambda x, y: x | y, Amasks)]
df_ICD10_all_visits_age_less_than40
# Out:
#             IID      FID f.31.0.0  f.34.0.0   f.52.0.0   f.2247.0.0  \
# 1913    1021134  1021134   Female      1965   February           No
# 2436    1026921  1026921   Female      1964       July          Yes
# 2493    1027574  1027574   Female      1961      March          Yes
# 3337    1036744  1036744   Female      1967        May          Yes
# 3458    1038061  1038061   Female      1967  September          Yes
# ...         ...      ...      ...       ...        ...          ...
# 456652  5998064  5998064   Female      1967   December          Yes
# 456830  6000020  6000020   Female      1967       July  Do not know
# 457448  6006842  6006842   Female      1960        May           No
# 457663  6009163  6009163     Male      1967    October          Yes
# 458645  6019818  6019818   Female      1965    October          Yes
#
#        f.2247.1.0 f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1913          NaN        NaN        NaN         No  ...               NaN
# 2436          NaN        NaN        NaN         No  ...               NaN
# 2493          NaN        NaN        NaN        Yes  ...               NaN
# 3337          NaN        NaN        NaN        Yes  ...               NaN
# 3458          NaN        NaN        NaN        Yes  ...               NaN
# ...           ...        ...        ...        ...  ...               ...
# 456652        NaN        NaN        NaN        Yes  ...               NaN
# 456830        NaN        NaN        NaN        Yes  ...               NaN
# 457448        NaN        NaN        NaN         No  ...               NaN
# 457663        NaN        NaN        NaN        Yes  ...               NaN
# 458645        NaN        NaN        NaN        Yes  ...               NaN
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1913                 NaN               NaN               NaN
# 2436                 NaN               NaN               NaN
# 2493                 NaN               NaN               NaN
# 3337                 NaN               NaN               NaN
# 3458                 NaN               NaN               NaN
# ...                  ...               ...               ...
# 456652               NaN               NaN               NaN
# 456830               NaN               NaN               NaN
# 457448               NaN               NaN               NaN
# 457663               NaN               NaN               NaN
# 458645               NaN               NaN               NaN
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1913                 NaN               NaN               NaN
# 2436                 NaN               NaN               NaN
# 2493                 NaN               NaN               NaN
# 3337                 NaN               NaN               NaN
# 3458                 NaN               NaN               NaN
# ...                  ...               ...               ...
# 456652               NaN               NaN               NaN
# 456830               NaN               NaN               NaN
# 457448               NaN               NaN               NaN
# 457663               NaN               NaN               NaN
# 458645               NaN               NaN               NaN
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1913                 NaN               NaN  Not Sure
# 2436                 NaN               NaN  Not Sure
# 2493                 NaN               NaN  Not Sure
# 3337                 NaN               NaN  Not Sure
# 3458                 NaN               NaN  Not Sure
# ...                  ...               ...       ...
# 456652               NaN               NaN  Not Sure
# 456830               NaN               NaN  Not Sure
# 457448               NaN               NaN  Not Sure
# 457663               NaN               NaN  Not Sure
# 458645               NaN               NaN  Not Sure
#
# [504 rows x 1225 columns]

# %%
df_ICD10_all_visits_age_less_than40.to_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643ind_ICD10_younger_than_40yo_DMCS.csv",index=False)

# %% [markdown]
# #### Combine IDs of ICD10 and selfreported who have less than 40 years old and should be excluded

# %%
IDs_ICD10_all_visits_age_less_than40 = df_ICD10_all_visits_age_less_than40[["IID", "FID"]]
IDs_1415_all_visits_age_less_40 = df_1415_all_visits_age_less_40[["IID", "FID"]]

# %%
frames = [IDs_ICD10_all_visits_age_less_than40, IDs_1415_all_visits_age_less_40]
Combine = pd.concat(frames)
Combine
# Out:
#             IID      FID
# 1913    1021134  1021134
# 2436    1026921  1026921
# 2493    1027574  1027574
# 3337    1036744  1036744
# 3458    1038061  1038061
# ...         ...      ...
# 458016  6012912  6012912
# 458154  6014453  6014453
# 458675  6020151  6020151
# 458718  6020619  6020619
# 459022  6023914  6023914
#
# [3691 rows x 2 columns]

# %%
Unique_IDs= Combine.drop_duplicates(subset=['IID'], keep=False)
Unique_IDs
# Out:
#             IID      FID
# 1913    1021134  1021134
# 2436    1026921  1026921
# 2493    1027574  1027574
# 3337    1036744  1036744
# 3458    1038061  1038061
# ...         ...      ...
# 458016  6012912  6012912
# 458154  6014453  6014453
# 458675  6020151  6020151
# 458718  6020619  6020619
# 459022  6023914  6023914
#
# [3611 rows x 2 columns]

# %%
Unique_IDs.to_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643_IDs_1415_ICD10_younger_than_40yo_DMCS.csv",index=False)

# %%
#Remove individuals younger than 40 years for ICD10 codes and selfrepoerted from main working dataframe
White_EU_PCA_40years = df[~df.loc[:,'IID'].isin(Unique_IDs['IID'])]

# %%
White_EU_PCA_40years
# Out:
#             IID      FID f.31.0.0  f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female      1960   November        Yes        NaN
# 1       1000022  1000022     Male      1954     August        Yes        NaN
# 2       1000035  1000035     Male      1944        May         No        NaN
# 3       1000046  1000046   Female      1946      March         No        NaN
# 4       1000054  1000054   Female      1942    January         No        NaN
# ...         ...      ...      ...       ...        ...        ...        ...
# 459151  6025390  6025390   Female      1942      March         No        NaN
# 459152  6025409  6025409   Female      1946   November         No         No
# 459153  6025411  6025411   Female      1960   November         No        NaN
# 459154  6025425  6025425   Female      1963     August         No        NaN
# 459155  6025438  6025438     Male      1952  September         No        NaN
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 0             NaN        NaN        Yes  ...               NaN
# 1             NaN        NaN        Yes  ...               NaN
# 2             NaN        NaN        Yes  ...               NaN
# 3              No        NaN         No  ...               NaN
# 4             NaN        NaN        Yes  ...               NaN
# ...           ...        ...        ...  ...               ...
# 459151        NaN        NaN        Yes  ...               NaN
# 459152        NaN        NaN         No  ...               NaN
# 459153        NaN        NaN         No  ...               NaN
# 459154        NaN        NaN         No  ...               NaN
# 459155        NaN        NaN         No  ...               NaN
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               NaN
# 3                    NaN               NaN               NaN
# 4                    NaN               NaN               NaN
# ...                  ...               ...               ...
# 459151               NaN               NaN               NaN
# 459152               NaN               NaN               NaN
# 459153               NaN               NaN               NaN
# 459154               NaN               NaN               NaN
# 459155               NaN               NaN               NaN
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 0                    NaN               NaN  Not Sure
# 1                    NaN               NaN  Not Sure
# 2                    NaN               NaN  Not Sure
# 3                    NaN               NaN  Not Sure
# 4                    NaN               NaN  Not Sure
# ...                  ...               ...       ...
# 459151               NaN               NaN  Not Sure
# 459152               NaN               NaN  Not Sure
# 459153               NaN               NaN  Not Sure
# 459154               NaN               NaN  Not Sure
# 459155               NaN               NaN  Not Sure
#
# [455545 rows x 1225 columns]

# %%
# saving main working dataframe after exluding individulas younger than 40 for ICD10 and selfreported 
White_EU_PCA_40years.to_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643_500k.ARHL.phe_ICD9_10_ages_whiteEuro_PCAout_Olderthan_40_DMCS.csv",index=False)

# %% [markdown]
# #### Read clean dataframe (after age filtering) and exclusion other criteria for icd10, icd9, and self-report

# %%
df = pd.read_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643_500k.ARHL.phe_ICD9_10_ages_whiteEuro_PCAout_Olderthan_40_DMCS.csv", quotechar = '"', dtype="string")
df
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female     1960   November        Yes       <NA>
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 0            <NA>       <NA>        Yes  ...              <NA>
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 0                   <NA>              <NA>  Not Sure
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [455545 rows x 1225 columns]

# %%
exclusion = pd.read_csv("/mnt/vast/hpc/csg/en2509/Phenotype/ICD10_9_selfreport_incl_excl_01252023_EN.csv", quotechar = '"', dtype="string")
exclusion
# Out:
#     UKBB_field_code                              Phenotype cases_UKB_showcase  \
# 0           f.41270       H60-H62 Diseases of external ear               <NA>
# 1           f.41270                     H60 Otitis externa               <NA>
# 2           f.41270          H60.0 Abscess of external ear                 32
# 3           f.41270       H60.1 Cellulitis of external ear                218
# 4           f.41270         H60.2 Malignant otitis externa                 49
# ..              ...                                    ...                ...
# 566         f.20002                 1491 brain haemorrhage                218
# 567         f.20002                  1583 ischaemic stroke                 44
# 568         f.20002  1082 transient ischaemic attack (tia)               2243
# 569         f.20002    1083 subdural haemorrhage/haematoma                212
# 570         f.20002                 1425 cerebral aneurysm                352
#
#     White_EU_After_PCA_clean less than 55 years  Excluded_fulldb_lateonsetHI  \
# 0                       <NA>                <NA>                        <NA>
# 1                       <NA>                <NA>                        <NA>
# 2                       <NA>                <NA>                           N
# 3                       <NA>                <NA>                           N
# 4                       <NA>                <NA>                           N
# ..                       ...                 ...                         ...
# 566                     <NA>                <NA>                           Y
# 567                     <NA>                <NA>                           N
# 568                     <NA>                <NA>                           N
# 569                     <NA>                <NA>                           Y
# 570                     <NA>                <NA>                           Y
#
#     Excluded_from_controls Cases_f3393 Cases_f2247 Cases_f2257
# 0                     <NA>        <NA>        <NA>        <NA>
# 1                     <NA>        <NA>        <NA>        <NA>
# 2                        N        <NA>        <NA>        <NA>
# 3                        N        <NA>        <NA>        <NA>
# 4                        N        <NA>        <NA>        <NA>
# ..                     ...         ...         ...         ...
# 566                   <NA>        <NA>        <NA>        <NA>
# 567                      N        <NA>        <NA>        <NA>
# 568                      N        <NA>        <NA>        <NA>
# 569                   <NA>        <NA>        <NA>        <NA>
# 570                   <NA>        <NA>        <NA>        <NA>
#
# [571 rows x 10 columns]

# %% [markdown]
# If individuals have certain codes from ICD 10, ICD 9, and self-reports they must be fully removed from the analysis.

# %%
# returns if the current individual should be excluded based on the exclusion list
def contains_exclusion(row, exclusion_list):
    for i in row:
        if not pd.isna(i) and i in exclusion_list:
            return True
            
    return False

# %% [markdown]
# ### Filter out ICD 10 exclusions

# %%
# these are the columns that represent the icd10 columns in the database
icd10_colnames = [col for col in df if "f.41270" in col]
icd10_colnames_ages = [col for col in df if "age_f.41280" in col]

# %%
# get a dataframe that only contains the icd10 columns from the full database
icd10 = df[icd10_colnames]
icd10
# Out:
#        f.41270.0.0 f.41270.0.1 f.41270.0.2 f.41270.0.3 f.41270.0.4  \
# 0             E041        F329        H738        M179        M202
# 1             F101        J342        R619       S8280        W010
# 2             H269        K579        K590        K621       M5459
# 3             E780        G473        R065        R074        Z824
# 4             C679        C787        C795        C798        D090
# ...            ...         ...         ...         ...         ...
# 455540        A049        A099        A419        B370        C859
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>
# 455542        O149        O266        O342        O471         O48
# 455543        G551        G558         I10        M501        Z981
# 455544        D225        S008        S109        S198        T797
#
#        f.41270.0.5 f.41270.0.6 f.41270.0.7 f.41270.0.8 f.41270.0.9  ...  \
# 0            M2320        M750        M754        M758        N898  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2              N40        R040         R31        R398        Z466  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             I802        I959        J181        K922        M169  ...
# ...            ...         ...         ...         ...         ...  ...
# 455540        D649        E278        E279        E538        E559  ...
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455542        O610        O680        Z370        <NA>        <NA>  ...
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455544        W238        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41270.0.249 f.41270.0.250 f.41270.0.251 f.41270.0.252 f.41270.0.253  \
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 455540          <NA>          <NA>          <NA>          <NA>          <NA>
# 455541          <NA>          <NA>          <NA>          <NA>          <NA>
# 455542          <NA>          <NA>          <NA>          <NA>          <NA>
# 455543          <NA>          <NA>          <NA>          <NA>          <NA>
# 455544          <NA>          <NA>          <NA>          <NA>          <NA>
#
#        f.41270.0.254 f.41270.0.255 f.41270.0.256 f.41270.0.257 f.41270.0.258
# 0               <NA>          <NA>          <NA>          <NA>          <NA>
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 455540          <NA>          <NA>          <NA>          <NA>          <NA>
# 455541          <NA>          <NA>          <NA>          <NA>          <NA>
# 455542          <NA>          <NA>          <NA>          <NA>          <NA>
# 455543          <NA>          <NA>          <NA>          <NA>          <NA>
# 455544          <NA>          <NA>          <NA>          <NA>          <NA>
#
# [455545 rows x 259 columns]

# %%
# get rows from exclusion database that contian the codes that need to be removed for icd10
exclude_icd10 = exclusion[(exclusion["UKBB_field_code"] == "f.41270") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_icd10
# Out:
#     UKBB_field_code                                          Phenotype  \
# 27          f.41270                  H65.2 Chronic serous otitis media
# 28          f.41270                  H65.3 Chronic mucoid otitis media
# 29          f.41270    H65.4 Other chronic nonsuppurative otitis media
# 30          f.41270     H65.9 Nonsuppurative otitis media, unspecified
# 33          f.41270  H66.1 Chronic tubotympanic suppurative otitis ...
# ..              ...                                                ...
# 276         f.41270    S07.9 Crushing injury of head, part unspecified
# 279         f.41270                  S08.1 Traumatic amputation of ear
# 280         f.41270  S08.8 Traumatic amputation of other parts of head
# 281         f.41270  S08.9 Traumatic amputation of unspecified part...
# 285         f.41270                S09.2 Traumatic rupture of ear drum
#
#     cases_UKB_showcase White_EU_After_PCA_clean less than 55 years   \
# 27                 103                     <NA>                <NA>
# 28                 960                     <NA>                <NA>
# 29                 158                     <NA>                <NA>
# 30                 508                     <NA>                <NA>
# 33                  40                     <NA>                <NA>
# ..                 ...                      ...                 ...
# 276                  1                     <NA>                <NA>
# 279                 13                     <NA>                <NA>
# 280                  1                     <NA>                <NA>
# 281                  1                     <NA>                <NA>
# 285                 18                     <NA>                <NA>
#
#     Excluded_fulldb_lateonsetHI Excluded_from_controls Cases_f3393  \
# 27                            Y                   <NA>        <NA>
# 28                            Y                   <NA>        <NA>
# 29                            Y                   <NA>        <NA>
# 30                            Y                   <NA>        <NA>
# 33                            Y                   <NA>        <NA>
# ..                          ...                    ...         ...
# 276                           Y                   <NA>        <NA>
# 279                           Y                   <NA>        <NA>
# 280                           Y                   <NA>        <NA>
# 281                           Y                   <NA>        <NA>
# 285                           Y                   <NA>        <NA>
#
#     Cases_f2247 Cases_f2257
# 27         <NA>        <NA>
# 28         <NA>        <NA>
# 29         <NA>        <NA>
# 30         <NA>        <NA>
# 33         <NA>        <NA>
# ..          ...         ...
# 276        <NA>        <NA>
# 279        <NA>        <NA>
# 280        <NA>        <NA>
# 281        <NA>        <NA>
# 285        <NA>        <NA>
#
# [136 rows x 10 columns]

# %%
# get the icd10 codes that should be excluded from database
ex_critia_icd10 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_icd10["Phenotype"].tolist()]
ex_critia_icd10
# Out:
# ['H652',
#  'H653',
#  'H654',
#  'H659',
#  'H661',
#  'H662',
#  'H663',
#  'H664',
#  'H669',
#  'H680',
#  'H701',
#  'H702',
#  'H708',
#  'H709',
#  'H71',
#  'H731',
#  'H738',
#  'H739',
#  'H740',
#  'H741',
#  'H742',
#  'H743',
#  'H748',
#  'H749',
#  'H750',
#  'H758',
#  'H800',
#  'H801',
#  'H802',
#  'H808',
#  'H809',
#  'H810',
#  'H830',
#  'H831',
#  'H832',
#  'H900',
#  'H901',
#  'H902',
#  'H910',
#  'H913',
#  'H930',
#  'H933',
#  'H940',
#  'H948',
#  'H950',
#  'H951',
#  'H958',
#  'H959',
#  'B020',
#  'B021',
#  'B022',
#  'B023',
#  'B027',
#  'B028',
#  'G000',
#  'G001',
#  'G002',
#  'G003',
#  'G008',
#  'G009',
#  'G01',
#  'G020',
#  'G021',
#  'G028',
#  'G030',
#  'G031',
#  'G032',
#  'G038',
#  'G039',
#  'G040',
#  'G041',
#  'G042',
#  'G048',
#  'G049',
#  'G050',
#  'G051',
#  'G052',
#  'G058',
#  'G060',
#  'G061',
#  'G062',
#  'G07',
#  'G08',
#  'G09',
#  'G510',
#  'G511',
#  'G512',
#  'G513',
#  'G514',
#  'G518',
#  'G519',
#  'S0200',
#  'S0201',
#  'S0210',
#  'S0211',
#  'S0240',
#  'S0241',
#  'S0260',
#  'S0261',
#  'S0270',
#  'S0271',
#  'S0280',
#  'S0281',
#  'S0290',
#  'S0291',
#  'S045',
#  'S046',
#  'S049',
#  'S0600',
#  'S0601',
#  'S0610',
#  'S0611',
#  'S0620',
#  'S0621',
#  'S0630',
#  'S0631',
#  'S0640',
#  'S0641',
#  'S0650',
#  'S0651',
#  'S0660',
#  'S0661',
#  'S0670',
#  'S0671',
#  'S0680',
#  'S0681',
#  'S0690',
#  'S0691',
#  'S070',
#  'S071',
#  'S078',
#  'S079',
#  'S081',
#  'S088',
#  'S089',
#  'S092']

# %%
# collect the individuals that should be excluded because of icd10
ex_fxn_icd10 = lambda row: contains_exclusion(row, ex_critia_icd10)
ex_10 = icd10.apply(ex_fxn_icd10, axis=1)

# %%
filtered_ICD10 = df[ex_10]
filtered_ICD10
# Out:
#             IID      FID f.31.0.0 f.34.0.0  f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000019  1000019   Female     1960  November        Yes       <NA>
# 31      1000357  1000357   Female     1940     March         No       <NA>
# 41      1000477  1000477     Male     1959      July         No       <NA>
# 83      1000947  1000947   Female     1941    August        Yes       <NA>
# 85      1000965  1000965   Female     1954  December         No       <NA>
# ...         ...      ...      ...      ...       ...        ...        ...
# 455490  6024796  6024796   Female     1946    August         No       <NA>
# 455504  6024960  6024960     Male     1951  November        Yes       <NA>
# 455505  6024974  6024974   Female     1941       May        Yes       <NA>
# 455522  6025176  6025176   Female     1950    August        Yes       <NA>
# 455523  6025180  6025180     Male     1940  February        Yes       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 0            <NA>       <NA>        Yes  ...              <NA>
# 31           <NA>       <NA>         No  ...              <NA>
# 41             No       <NA>         No  ...              <NA>
# 83           <NA>       <NA>         No  ...              <NA>
# 85           <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455490       <NA>       <NA>        Yes  ...              <NA>
# 455504       <NA>       <NA>        Yes  ...              <NA>
# 455505       <NA>       <NA>        Yes  ...              <NA>
# 455522       <NA>       <NA>         No  ...              <NA>
# 455523       <NA>       <NA>        Yes  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 0                   <NA>              <NA>              <NA>
# 31                  <NA>              <NA>              <NA>
# 41                  <NA>              <NA>              <NA>
# 83                  <NA>              <NA>              <NA>
# 85                  <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455490              <NA>              <NA>              <NA>
# 455504              <NA>              <NA>              <NA>
# 455505              <NA>              <NA>              <NA>
# 455522              <NA>              <NA>              <NA>
# 455523              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 0                   <NA>              <NA>              <NA>
# 31                  <NA>              <NA>              <NA>
# 41                  <NA>              <NA>              <NA>
# 83                  <NA>              <NA>              <NA>
# 85                  <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455490              <NA>              <NA>              <NA>
# 455504              <NA>              <NA>              <NA>
# 455505              <NA>              <NA>              <NA>
# 455522              <NA>              <NA>              <NA>
# 455523              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 0                   <NA>              <NA>  Not Sure
# 31                  <NA>              <NA>  Not Sure
# 41                  <NA>              <NA>  Not Sure
# 83                  <NA>              <NA>  Not Sure
# 85                  <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455490              <NA>              <NA>  Not Sure
# 455504              <NA>              <NA>  Not Sure
# 455505              <NA>              <NA>  Not Sure
# 455522              <NA>              <NA>  Not Sure
# 455523              <NA>              <NA>  Not Sure
#
# [13810 rows x 1225 columns]

# %%
ICD10_IDs = filtered_ICD10 [["FID", "IID"]]
ICD10_IDs
# Out:
#             FID      IID
# 0       1000019  1000019
# 31      1000357  1000357
# 41      1000477  1000477
# 83      1000947  1000947
# 85      1000965  1000965
# ...         ...      ...
# 455490  6024796  6024796
# 455504  6024960  6024960
# 455505  6024974  6024974
# 455522  6025176  6025176
# 455523  6025180  6025180
#
# [13810 rows x 2 columns]

# %%
# remove them from the working database (which is now filtered. df remains unchanged)
filtered = df[~ex_10]

# %%
print(sum(ex_10), "individuals removed because of icd10 codes")
# Out:
# 13810 individuals removed because of icd10 codes

# %%
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# 5                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [441735 rows x 1225 columns]

# %% [markdown]
# ### Filter out ICD 9 exclusions

# %%
# these are the columns that represent the icd9 columns in the working database
icd9_colnames = [col for col in filtered if "f.41271" in col]

# %%
# get a dataframe that only contains the icd9 columns from the working database
icd9 = filtered[icd9_colnames]
icd9
# Out:
#        f.41271.0.0 f.41271.0.1 f.41271.0.2 f.41271.0.3 f.41271.0.4  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             <NA>        <NA>        <NA>        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             3000      5198.0        <NA>        <NA>        <NA>
# 5             <NA>        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 455540        <NA>        <NA>        <NA>        <NA>        <NA>
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>
# 455544        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.41271.0.5 f.41271.0.6 f.41271.0.7 f.41271.0.8 f.41271.0.9  ...  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 5             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 455540        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455544        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41271.0.37 f.41271.0.38 f.41271.0.39 f.41271.0.40 f.41271.0.41  \
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.41271.0.42 f.41271.0.43 f.41271.0.44 f.41271.0.45 f.41271.0.46
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [441735 rows x 47 columns]

# %%
# get rows from exclusion database that contian the codes that need to be removed for icd9
exclude_icd9 = exclusion[(exclusion["UKBB_field_code"] == "f.41271") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_icd9
# Out:
#     UKBB_field_code                                          Phenotype  \
# 319         f.41271                   3811 Chronic serous otitis media
# 320         f.41271                   3812 Chronic mucoid otitis media
# 321         f.41271  3813 Other and unspecified chronic nonsuppurat...
# 322         f.41271  3814 Nonsuppurative otitis media, not specifie...
# 323         f.41271                        3815 Eustachian salpingitis
# ..              ...                                                ...
# 516         f.41271  9050 Late effect of fracture of skull and face...
# 526         f.41271       9259 Crushing injury of face, scalp and neck
# 532         f.41271                        9514 Injury to facial nerve
# 533         f.41271                      9515 Injury to acoustic nerve
# 537         f.41271           9519 Injury to unspecified cranial nerve
#
#     cases_UKB_showcase White_EU_After_PCA_clean less than 55 years   \
# 319                  8                     <NA>                <NA>
# 320                 11                     <NA>                <NA>
# 321                  3                     <NA>                <NA>
# 322                 19                     <NA>                <NA>
# 323                  0                     <NA>                <NA>
# ..                 ...                      ...                 ...
# 516                 19                     <NA>                <NA>
# 526                  2                     <NA>                <NA>
# 532                  0                     <NA>                <NA>
# 533                  1                     <NA>                <NA>
# 537                  0                     <NA>                <NA>
#
#     Excluded_fulldb_lateonsetHI Excluded_from_controls Cases_f3393  \
# 319                           Y                   <NA>        <NA>
# 320                           Y                   <NA>        <NA>
# 321                           Y                   <NA>        <NA>
# 322                           Y                   <NA>        <NA>
# 323                           Y                   <NA>        <NA>
# ..                          ...                    ...         ...
# 516                           Y                   <NA>        <NA>
# 526                           Y                   <NA>        <NA>
# 532                           Y                   <NA>        <NA>
# 533                           Y                   <NA>        <NA>
# 537                           Y                   <NA>        <NA>
#
#     Cases_f2247 Cases_f2257
# 319        <NA>        <NA>
# 320        <NA>        <NA>
# 321        <NA>        <NA>
# 322        <NA>        <NA>
# 323        <NA>        <NA>
# ..          ...         ...
# 516        <NA>        <NA>
# 526        <NA>        <NA>
# 532        <NA>        <NA>
# 533        <NA>        <NA>
# 537        <NA>        <NA>
#
# [125 rows x 10 columns]

# %%
# get the icd9 codes that should be excluded from the working database
ex_critia_icd9 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_icd9["Phenotype"].tolist()]
ex_critia_icd9
# Out:
# ['3811',
#  '3812',
#  '3813',
#  '3814',
#  '3815',
#  '3816',
#  '3819',
#  '3821',
#  '3822',
#  '3823',
#  '3824',
#  '3829',
#  '3831',
#  '3832',
#  '3833',
#  '3838',
#  '3839',
#  '3841',
#  '3850',
#  '3851',
#  '3852',
#  '3853',
#  '3858',
#  '3859',
#  '3860',
#  '3863',
#  '3864',
#  '3865',
#  '3868',
#  '3869',
#  '3870',
#  '3871',
#  '3872',
#  '3878',
#  '3879',
#  '3885',
#  '3890',
#  '0530',
#  '0531',
#  '0532',
#  '0537',
#  '0538',
#  '3200',
#  '3201',
#  '3202',
#  '3203',
#  '3204',
#  '3205',
#  '3207',
#  '3208',
#  '3209',
#  '3210',
#  '3211',
#  '3212',
#  '3213',
#  '3214',
#  '3215',
#  '3216',
#  '3217',
#  '3218',
#  '3220',
#  '3221',
#  '3222',
#  '3229',
#  '3230',
#  '3231',
#  '3232',
#  '3233',
#  '3234',
#  '3235',
#  '3236',
#  '3237',
#  '3238',
#  '3239',
#  '3240',
#  '3241',
#  '3249',
#  '3259',
#  '3269',
#  '3510',
#  '3511',
#  '3518',
#  '3519',
#  '8000',
#  '8001',
#  '8002',
#  '8003',
#  '8010',
#  '8011',
#  '8012',
#  '8013',
#  '8022',
#  '8023',
#  '8024',
#  '8025',
#  '8028',
#  '8029',
#  '8030',
#  '8031',
#  '8032',
#  '8033',
#  '8040',
#  '8041',
#  '8042',
#  '8043',
#  '8509',
#  '8510',
#  '8511',
#  '8520',
#  '8521',
#  '8530',
#  '8531',
#  '8540',
#  '8541',
#  '8720',
#  '8721',
#  '8726',
#  '8727',
#  '8728',
#  '8729',
#  '9050',
#  '9259',
#  '9514',
#  '9515',
#  '9519']

# %%
# collect the individuals that should be excluded because of icd9
ex_fxn_icd9 = lambda row: contains_exclusion(row, ex_critia_icd9)
ex_9 = icd9.apply(ex_fxn_icd9, axis=1)

# %%
ICD9_ID = filtered[ex_9]
ICD9_IDs = ICD9_ID [["FID", "IID"]]
ICD9_IDs
# Out:
#             FID      IID
# 1356    1015167  1015167
# 1773    1019691  1019691
# 4013    1044629  1044629
# 6027    1067104  1067104
# 7116    1079051  1079051
# ...         ...      ...
# 451453  5980379  5980379
# 451858  5984843  5984843
# 452432  5991165  5991165
# 453358  6001389  6001389
# 455484  6024723  6024723
#
# [541 rows x 2 columns]

# %%
# remove them from the working database
filtered = filtered[~ex_9]
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# 5                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [441194 rows x 1225 columns]

# %%
print(sum(ex_9), "individuals removed because of icd9 codes")
# Out:
# 541 individuals removed because of icd9 codes

# %%
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# 5                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [441194 rows x 1225 columns]

# %% [markdown]
# ### Filter out f.20002 exclusions

# %%
# these are the columns that represent the self-report columns in the working database
f20002_colnames = [col for col in df if "f.20002" in col]

# %%
# get a dataframe that only contains the self-report columns from the working database
f20002 = df[f20002_colnames]
f20002
# Out:
#        f.20002.0.0 f.20002.0.1 f.20002.0.2 f.20002.0.3 f.20002.0.4  \
# 0           1111.0        <NA>        <NA>        <NA>        <NA>
# 1           1065.0        <NA>        <NA>        <NA>        <NA>
# 2           1396.0      1473.0        <NA>        <NA>        <NA>
# 3           1065.0      1294.0      1476.0      1473.0      1374.0
# 4             <NA>        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 455540      1464.0        <NA>        <NA>        <NA>        <NA>
# 455541      1478.0      1473.0        <NA>        <NA>        <NA>
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>
# 455543      1265.0        <NA>        <NA>        <NA>        <NA>
# 455544      1065.0        <NA>        <NA>        <NA>        <NA>
#
#        f.20002.0.5 f.20002.0.6 f.20002.0.7 f.20002.0.8 f.20002.0.9  ...  \
# 0             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 455540        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455544        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.20002.3.24 f.20002.3.25 f.20002.3.26 f.20002.3.27 f.20002.3.28  \
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.20002.3.29 f.20002.3.30 f.20002.3.31 f.20002.3.32 f.20002.3.33
# 0              <NA>         <NA>         <NA>         <NA>         <NA>
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [455545 rows x 136 columns]

# %%
# get rows from exclusion database that contian the codes that need to be removed for self-report
exclude_f20002 = exclusion[(exclusion["UKBB_field_code"] == "f.20002") & (exclusion["Excluded_fulldb_lateonsetHI"] == 'Y') ]
exclude_f20002
# Out:
#     UKBB_field_code                                Phenotype  \
# 539         f.20002                        1420 otosclerosis
# 540         f.20002                   1421 meniere's disease
# 541         f.20002                       1499 labyrinthitis
# 545         f.20002         1244 infection of nervous system
# 546         f.20002  1245 brain abscess/intracranial abscess
# 547         f.20002                        1246 encephalitis
# 548         f.20002                          1247 meningitis
# 550         f.20002         1249 cranial nerve problem/palsy
# 551         f.20002     1250 bell's palsy/facial nerve palsy
# 553         f.20002          1240 neurological injury/trauma
# 558         f.20002               1626 fracture skull / head
# 565         f.20002            1086 subarachnoid haemorrhage
# 566         f.20002                   1491 brain haemorrhage
# 569         f.20002      1083 subdural haemorrhage/haematoma
# 570         f.20002                   1425 cerebral aneurysm
#
#     cases_UKB_showcase White_EU_After_PCA_clean less than 55 years   \
# 539                260                     <NA>                <NA>
# 540               1553                     <NA>                <NA>
# 541                417                     <NA>                <NA>
# 545                 55                     <NA>                <NA>
# 546                 79                     <NA>                <NA>
# 547                348                     <NA>                <NA>
# 548               2214                     <NA>                <NA>
# 550                289                     <NA>                <NA>
# 551                591                     <NA>                <NA>
# 553                130                     <NA>                <NA>
# 558                465                     <NA>                <NA>
# 565                492                     <NA>                <NA>
# 566                218                     <NA>                <NA>
# 569                212                     <NA>                <NA>
# 570                352                     <NA>                <NA>
#
#     Excluded_fulldb_lateonsetHI Excluded_from_controls Cases_f3393  \
# 539                           Y                   <NA>        <NA>
# 540                           Y                   <NA>        <NA>
# 541                           Y                   <NA>        <NA>
# 545                           Y                   <NA>        <NA>
# 546                           Y                   <NA>        <NA>
# 547                           Y                   <NA>        <NA>
# 548                           Y                   <NA>        <NA>
# 550                           Y                   <NA>        <NA>
# 551                           Y                   <NA>        <NA>
# 553                           Y                   <NA>        <NA>
# 558                           Y                   <NA>        <NA>
# 565                           Y                   <NA>        <NA>
# 566                           Y                   <NA>        <NA>
# 569                           Y                   <NA>        <NA>
# 570                           Y                   <NA>        <NA>
#
#     Cases_f2247 Cases_f2257
# 539        <NA>        <NA>
# 540        <NA>        <NA>
# 541        <NA>        <NA>
# 545        <NA>        <NA>
# 546        <NA>        <NA>
# 547        <NA>        <NA>
# 548        <NA>        <NA>
# 550        <NA>        <NA>
# 551        <NA>        <NA>
# 553        <NA>        <NA>
# 558        <NA>        <NA>
# 565        <NA>        <NA>
# 566        <NA>        <NA>
# 569        <NA>        <NA>
# 570        <NA>        <NA>

# %%
# get the self-report codes that should be excluded from the working database
ex_critia_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_f20002["Phenotype"].tolist()]
ex_critia_f20002
# Out:
# ['1420',
#  '1421',
#  '1499',
#  '1244',
#  '1245',
#  '1246',
#  '1247',
#  '1249',
#  '1250',
#  '1240',
#  '1626',
#  '1086',
#  '1491',
#  '1083',
#  '1425']

# %%
# collect the individuals that should be excluded because of self-report
ex_fxn_f20002 = lambda row: contains_exclusion(row, ex_critia_f20002)
ex_f20002 = f20002.apply(ex_fxn_f20002, axis=1)
df_self_report = filtered[ex_f20002]
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/3386772636.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_self_report = filtered[ex_f20002]

# %%
Self_report_IDs = df_self_report[["FID", "IID"]]
Self_report_IDs
# Out:
# Empty DataFrame
# Columns: [FID, IID]
# Index: []

# %%
#print(sum(ex_f20002), "individuals removed because of self-reported codes")

# %%
# remove them from the working database
filtered = filtered[~filtered.loc[:,'IID'].isin(df_self_report['IID'])]
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# 5                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [441194 rows x 1225 columns]

# %%
# saving main working dataframe after exluding individulas younger than 55 for ICD10 and selfreported and other exclusion critria
filtered.to_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643_500k.ARHL.phe_ICD9_10_ages_whiteEuro_PCAout_Olderthan_40_after_all_exclusion_critria_DMCS.csv",index=False)

# %%
##Combine IDs of individulas how sghould be excluded based on ICD10 and ICD9
frames = [ICD10_IDs, ICD9_IDs, Self_report_IDs]
Combine = pd.concat(frames)
Combine
# Out:
#             FID      IID
# 0       1000019  1000019
# 31      1000357  1000357
# 41      1000477  1000477
# 83      1000947  1000947
# 85      1000965  1000965
# ...         ...      ...
# 451453  5980379  5980379
# 451858  5984843  5984843
# 452432  5991165  5991165
# 453358  6001389  6001389
# 455484  6024723  6024723
#
# [14351 rows x 2 columns]

# %%
Unique_IDs= Combine.drop_duplicates(subset=['IID'], keep=False)
Unique_IDs
# Out:
#             FID      IID
# 0       1000019  1000019
# 31      1000357  1000357
# 41      1000477  1000477
# 83      1000947  1000947
# 85      1000965  1000965
# ...         ...      ...
# 451453  5980379  5980379
# 451858  5984843  5984843
# 452432  5991165  5991165
# 453358  6001389  6001389
# 455484  6024723  6024723
#
# [14351 rows x 2 columns]

# %%
Unique_IDs.to_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/ICD9_10_selfreported_IDs_removed_DMCS.csv",index=False)

# %%
Age_matter = pd.read_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643_IDs_1415_ICD10_younger_than_40yo_DMCS.csv", quotechar = '"', dtype="string")
Age_matter
# Out:
#           IID      FID
# 0     1021134  1021134
# 1     1026921  1026921
# 2     1027574  1027574
# 3     1036744  1036744
# 4     1038061  1038061
# ...       ...      ...
# 3606  6012912  6012912
# 3607  6014453  6014453
# 3608  6020151  6020151
# 3609  6020619  6020619
# 3610  6023914  6023914
#
# [3611 rows x 2 columns]

# %%
##Combine IDs of individulas how sghould be excluded based on ICD10 and ICD9
frames = [ICD10_IDs, ICD9_IDs, Self_report_IDs, Age_matter]
Combine = pd.concat(frames)
Combine
# Out:
#           FID      IID
# 0     1000019  1000019
# 31    1000357  1000357
# 41    1000477  1000477
# 83    1000947  1000947
# 85    1000965  1000965
# ...       ...      ...
# 3606  6012912  6012912
# 3607  6014453  6014453
# 3608  6020151  6020151
# 3609  6020619  6020619
# 3610  6023914  6023914
#
# [17962 rows x 2 columns]

# %%
Unique_IDs= Combine.drop_duplicates(subset=['IID'], keep=False)
Unique_IDs
# Out:
#           FID      IID
# 0     1000019  1000019
# 31    1000357  1000357
# 41    1000477  1000477
# 83    1000947  1000947
# 85    1000965  1000965
# ...       ...      ...
# 3606  6012912  6012912
# 3607  6014453  6014453
# 3608  6020151  6020151
# 3609  6020619  6020619
# 3610  6023914  6023914
#
# [17962 rows x 2 columns]

# %%
Unique_IDs.to_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643_All_ICD9_10_selfreported_IDs_removed_40yo_DMCS.csv",index=False)

# %% [markdown]
# # Phenotype definitions: f.3393, f.2247, f.2257, and f2247_f2257

# %% [markdown]
# ## Remove inconsistencies or unclear individuals

# %%
filtered = pd.read_csv("/mnt/vast/hpc/csg/UKBiobank/phenotype_files/HI_UKBB/072023_ukb673643_500k.ARHL.phe_ICD9_10_ages_whiteEuro_PCAout_Olderthan_40_after_all_exclusion_critria_DMCS.csv", quotechar = '"', dtype="string")
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0 f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 0       1000022  1000022        1     1954        8        1.0       <NA>
# 1       1000035  1000035        1     1944        5        0.0       <NA>
# 2       1000046  1000046        0     1946        3        0.0       <NA>
# 3       1000054  1000054        0     1942        1        0.0       <NA>
# 4       1000063  1000063        1     1967        4        0.0       <NA>
# ...         ...      ...      ...      ...      ...        ...        ...
# 441189  6025390  6025390        0     1942        3        0.0       <NA>
# 441190  6025409  6025409        0     1946       11        0.0        0.0
# 441191  6025411  6025411        0     1960       11        0.0       <NA>
# 441192  6025425  6025425        0     1963        8        0.0       <NA>
# 441193  6025438  6025438        1     1952        9        0.0       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 0            <NA>       <NA>        1.0  ...              <NA>
# 1            <NA>       <NA>        1.0  ...              <NA>
# 2             0.0       <NA>        0.0  ...              <NA>
# 3            <NA>       <NA>        1.0  ...              <NA>
# 4            <NA>       <NA>        0.0  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 441189       <NA>       <NA>        1.0  ...              <NA>
# 441190       <NA>       <NA>        0.0  ...              <NA>
# 441191       <NA>       <NA>        0.0  ...              <NA>
# 441192       <NA>       <NA>        0.0  ...              <NA>
# 441193       <NA>       <NA>        0.0  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 441189              <NA>              <NA>              <NA>
# 441190              <NA>              <NA>              <NA>
# 441191              <NA>              <NA>              <NA>
# 441192              <NA>              <NA>              <NA>
# 441193              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 441189              <NA>              <NA>              <NA>
# 441190              <NA>              <NA>              <NA>
# 441191              <NA>              <NA>              <NA>
# 441192              <NA>              <NA>              <NA>
# 441193              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 0                   <NA>              <NA>  Not Sure
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 441189              <NA>              <NA>  Not Sure
# 441190              <NA>              <NA>  Not Sure
# 441191              <NA>              <NA>  Not Sure
# 441192              <NA>              <NA>  Not Sure
# 441193              <NA>              <NA>  Not Sure
#
# [441194 rows x 1225 columns]

# %% [markdown]
# Some individuals might be unclear on if they do or do not have hearing difficulties or are inconsistent (found in f.3393, f.2247, and f.2257), in which case they cannot be considered either controls or cases and must be removed.
#
# The conditions for being removed are as follows:
# * Saying I don't know after saying either yes or no
# * Only saying I don't know or prefer not to say
# * Being completely deaf

# %% [markdown]
# ### Prior to filtering for inconsistencies

# %% [markdown]
# <b>Hearing difficulty/problems with background noise</b> <br>
# f.2257 = {'Yes': 81218, NA : 513774, 'No': 131091, 'Do not know': 4409, 'Prefer not to answer': 208}

# %% [markdown]
# <b>Hearing difficult/problems</b><br>
# f.2247 = {'No': 151758, : 513806, 'Yes': 55437, 'Do not know': 9489, 'Prefer not to answer': 171, 'I am completely deaf': 39}

# %% [markdown]
# <b>Hearing aid user</b><br>
# f.3393 = {'No': 145486, : 577795, 'Yes': 7237, 'Prefer not to answer': 182}

# %% [markdown]
# ### Setup for inconsistency filtering

# %%
print(filtered.dtypes)
# Out:
# IID                  string
# FID                  string
# f.31.0.0             string
# f.34.0.0             string
# f.52.0.0             string
#                       ...
# age_f.41280.0.255    string
# age_f.41280.0.256    string
# age_f.41280.0.257    string
# age_f.41280.0.258    string
# test                 string
# Length: 1225, dtype: object

# %%
# collect all the columns 
# redefining here for clarity

hearing_imp_f3393 = [col for col in filtered if "f.3393" in col]
hearing_imp_f2247 = [col for col in filtered if "f.2247" in col]
hearing_imp_f2257 = [col for col in filtered if "f.2257" in col]

icd_10_cols = [col for col in filtered if "f.41270" in col]
icd_9_cols = [col for col in filtered if "f.41271" in col]

# %%
# for hearing impairement questions we code the answers with the following for comparison
hearing_ans = {"Do not know":9, "Yes":1, "No":0}

# will contain the complete set of actual combinations of answers from individuals in the database
options = set()

# pass one pheno at a time to this function
def find_options(row):
    answer = "".join([str(hearing_ans[i]) for i in row if not pd.isna(i) and i != "I am completely deaf" and i != "Prefer not to answer"])
    options.add(answer)

# %%
# this builds the options set to contain a set of all the unique answers the individuals in the database have had
# over their hearing impairment questions
hearing_imp_qs = filtered[hearing_imp_f3393]
s = hearing_imp_qs.apply(find_options, axis=1)
hearing_imp_qs = filtered[hearing_imp_f2247]
s = hearing_imp_qs.apply(find_options, axis=1)
hearing_imp_qs = filtered[hearing_imp_f2257]
s = hearing_imp_qs.apply(find_options, axis=1)

# %%
options
# Out:
# {'',
#  '0',
#  '00',
#  '000',
#  '0000',
#  '0001',
#  '0009',
#  '001',
#  '0010',
#  '0011',
#  '0019',
#  '009',
#  '0090',
#  '0091',
#  '0099',
#  '01',
#  '010',
#  '0100',
#  '0101',
#  '0109',
#  '011',
#  '0110',
#  '0111',
#  '0119',
#  '019',
#  '0190',
#  '0191',
#  '0199',
#  '09',
#  '090',
#  '0900',
#  '0901',
#  '0909',
#  '091',
#  '0910',
#  '0911',
#  '0919',
#  '099',
#  '0990',
#  '0991',
#  '0999',
#  '1',
#  '10',
#  '100',
#  '1000',
#  '1001',
#  '1009',
#  '101',
#  '1010',
#  '1011',
#  '1019',
#  '109',
#  '1090',
#  '1099',
#  '11',
#  '110',
#  '1100',
#  '1101',
#  '111',
#  '1110',
#  '1111',
#  '1119',
#  '119',
#  '1190',
#  '1191',
#  '19',
#  '190',
#  '1900',
#  '1901',
#  '191',
#  '1910',
#  '1911',
#  '199',
#  '9',
#  '90',
#  '900',
#  '9000',
#  '9001',
#  '9009',
#  '901',
#  '9011',
#  '909',
#  '9090',
#  '9099',
#  '91',
#  '910',
#  '911',
#  '9110',
#  '9111',
#  '9119',
#  '919',
#  '9191',
#  '99',
#  '990',
#  '9901',
#  '991',
#  '9911',
#  '9919',
#  '999',
#  '9990',
#  '9991',
#  '9999'}

# %%
# we might have inconsistencies if we have don't knows mixed with other answers or even yes and no together
# options contains the set of all unique codes 

do_not_know_no = [i for i in options if '0' in i and '9' in i and '1' not in i]
do_not_know_yes = [i for i in options if '0' not in i and '9' in i and '1' in i]
yes_no = [i for i in options if '0' in i and '9' not in i and '1' in i]
with_all_three = [i for i in options if '0' in i and '9' in i and '1' in i]

# collecting all possible occurances that can be flagged for being inconsistent
might_inconsistent = do_not_know_no + do_not_know_yes + yes_no + with_all_three

# these are exceptions to the possibilities we have that can be flagged for being inconsistent
exceptions = ["91","911","9111","991","0001","001","0011","01","011","0111", "0091", "091","0911","0991","9001","901","9011", "90", "900", "9000", "990"]

# collect the list of answer combinations that are actually inconsistent by removingthe answer combinations that are exceptions
inconsistent = [i for i in might_inconsistent if i not in exceptions]

# %%
inconsistent
# Out:
# ['0090',
#  '0009',
#  '9990',
#  '099',
#  '090',
#  '009',
#  '909',
#  '0900',
#  '09',
#  '9090',
#  '0999',
#  '0990',
#  '9099',
#  '9009',
#  '0099',
#  '0909',
#  '919',
#  '9911',
#  '1191',
#  '1119',
#  '1911',
#  '119',
#  '9991',
#  '9191',
#  '191',
#  '9919',
#  '199',
#  '19',
#  '9119',
#  '100',
#  '1110',
#  '010',
#  '101',
#  '1011',
#  '1000',
#  '0101',
#  '0110',
#  '10',
#  '1001',
#  '0100',
#  '1101',
#  '1100',
#  '110',
#  '1010',
#  '0010',
#  '910',
#  '109',
#  '0901',
#  '9110',
#  '1900',
#  '1019',
#  '1009',
#  '0019',
#  '1910',
#  '1901',
#  '1090',
#  '0109',
#  '9901',
#  '0119',
#  '1099',
#  '0191',
#  '190',
#  '0199',
#  '0910',
#  '1190',
#  '0190',
#  '0919',
#  '019']

# %% [markdown]
# ### Filtering out the data

# %%
# return True if you find an individual that has NA for every answer in each column
def find_empty(row):
    for i in row:
        if not pd.isna(i):
            return False
    return True

# %%
# return True if an individual only answers Do not know but never Yes or No
def find_dont_know(row):
    temp = []
    for i in row:
        if not pd.isna(i):
            temp.append(i)
        
    if "Do not know" in temp and "Yes" not in temp and "No" not in temp:
        return True
    return False

# %%
# will return true if that row should be removed
# pass one pheno at a time through the function
def find_inconsistencies(row):
    for i in row:
        if not pd.isna(i) and i == "I am completely deaf":
            return True
    
    answer = "".join([str(hearing_ans[i]) for i in row if not pd.isna(i) and i != "I am completely deaf" and i != "Prefer not to answer"])
    if answer in inconsistent:
        return True
    return False

# if we have individuals that either don't answer or prefer not to say only then we cancel them out
# return true if all the rows have no definitive answers
def find_all_none(row):
    for i in row:
        if not pd.isna(i) and (i == "Yes" or i == "No"):
            return False
    return True

# %%
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# 5                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [441194 rows x 1225 columns]

# %%
filtered['f.41281.0.0']
# Out:
# 1               <NA>
# 2               <NA>
# 3               <NA>
# 4         1981-01-14
# 5               <NA>
#              ...
# 455540          <NA>
# 455541          <NA>
# 455542          <NA>
# 455543          <NA>
# 455544          <NA>
# Name: f.41281.0.0, Length: 441194, dtype: string

# %%
# filter out inconsistencies for f3393
hearing_imp_qs = filtered[hearing_imp_f3393]
exclude = hearing_imp_qs.apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

# %%
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# 5                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [440991 rows x 1225 columns]

# %%
# filter out inconsistencies for f2247
hearing_imp_qs = filtered[hearing_imp_f2247]
exclude = hearing_imp_qs.apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

# %%
# filter out inconsistencies for f2257
hearing_imp_qs = filtered[hearing_imp_f2257]
exclude = hearing_imp_qs.apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

# %%
# filter out individuals that don't have a definiteive answer for any hearing aid questions
hearing_imp_qs = filtered[hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257]
exclude = hearing_imp_qs.apply(find_all_none, axis=1)
filtered = filtered[~exclude]

# %%
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.250  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.251 age_f.41280.0.252 age_f.41280.0.253  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.254 age_f.41280.0.255 age_f.41280.0.256  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.257 age_f.41280.0.258      test
# 1                   <NA>              <NA>  Not Sure
# 2                   <NA>              <NA>  Not Sure
# 3                   <NA>              <NA>  Not Sure
# 4                   <NA>              <NA>  Not Sure
# 5                   <NA>              <NA>  Not Sure
# ...                  ...               ...       ...
# 455540              <NA>              <NA>  Not Sure
# 455541              <NA>              <NA>  Not Sure
# 455542              <NA>              <NA>  Not Sure
# 455543              <NA>              <NA>  Not Sure
# 455544              <NA>              <NA>  Not Sure
#
# [427009 rows x 1225 columns]

# %%
saved_2_filtered = filtered

# %%
filtered = saved_2_filtered

# %% [markdown]
# ## Identify Pure Controls

# %% [markdown]
# Need to make sure that for f.3393, f.2247, and f.2257 we obtain the individuals that say no.
#
# The conditions for saying no are as follows:
# * Never saying yes
# * Not being inconsistent
# * Saying no at least once (prefer not to say is allowed)
#
# We are also not including individuals to be part of the control group if they have certain codes for ICD9, ICD10, or f.20002 (this is in the case that they say no to all f.3393, f.2247, and f.2257). However these individuals can still be part of the cases

# %%
# returns 0 if it's a ctrl or else 1
def find_ctrl(row):
    answer = "".join([str(hearing_ans[i]) for i in row if not pd.isna(i) and i != "Prefer not to answer"])
    if "0" in answer and "1" not in answer:
        return 0
    return 1

# returns 0 if it's a ctrl or else 1
# this is specific for f3393 because f3393 was only asked under certain circumstances
def find_ctrl_or_NA(row):
    for i in row:
        if not pd.isna(i) and i != "No" and i != "Prefer not to answer": # if we have any answers that are not NA or No only then we don't have a ctrl
            return 1
    return 0

# %%
# filter through the hearing impairment questions to find the controls
hearing_imp_qs = filtered[hearing_imp_f3393]
f3393_ctrl = hearing_imp_qs.apply(find_ctrl_or_NA, axis=1).to_list()
hearing_imp_qs = filtered[hearing_imp_f2247]
f2247_ctrl = hearing_imp_qs.apply(find_ctrl, axis=1).to_list()
hearing_imp_qs = filtered[hearing_imp_f2257]
f2257_ctrl = hearing_imp_qs.apply(find_ctrl, axis=1).to_list()

# %%
pure_ctrl = [0 if i == 0 and f2247_ctrl[en] == 0 and f2257_ctrl[en] == 0 else 1 for en, i in enumerate(f3393_ctrl)]

# %%
print(len(pure_ctrl) - sum(pure_ctrl), "individuals are controls prior to filtration for icd10, icd9 and self-reported codes")
# Out:
# 236230 individuals are controls prior to filtration for icd10, icd9 and self-reported codes

# %% [markdown]
# ### Collect ICD 10 codes to filter out from Ctrl

# %%
exclude_ctrl_icd10 = exclusion[(exclusion["UKBB_field_code"] == "f.41270") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd10
# Out:
#     UKBB_field_code                                          Phenotype  \
# 97          f.41270                   H83.3 Noise effects on inner ear
# 98          f.41270        H83.8 Other specified diseases of inner ear
# 99          f.41270            H83.9 Disease of inner ear, unspecified
# 105         f.41270        H90.3 Sensorineural hearing loss, bilateral
# 106         f.41270  H90.4 Sensorineural hearing loss, unilateral w...
# 107         f.41270      H90.5 Sensorineural hearing loss, unspecified
# 108         f.41270  H90.6 Mixed conductive and sensorineural heari...
# 109         f.41270  H90.7 Mixed conductive and sensorineural heari...
# 110         f.41270  H90.8 Mixed conductive and sensorineural heari...
# 113         f.41270                                  H91.1 Presbycusis
# 114         f.41270               H91.2 Sudden idiopathic hearing loss
# 116         f.41270                 H91.8 Other specified hearing loss
# 117         f.41270                    H91.9 Hearing loss, unspecified
# 125         f.41270          H93.2 Other abnormal auditory perceptions
# 127         f.41270             H93.8 Other specified disorders of ear
# 128         f.41270                 H93.9 Disorder of ear, unspecified
# 137         f.41270        Z46.1 Fitting and adjustment of hearing aid
# 138         f.41270             Z97.4 Presence of external hearing-aid
#
#     cases_UKB_showcase White_EU_After_PCA_clean less than 55 years   \
# 97                  24                     <NA>                <NA>
# 98                  51                     <NA>                <NA>
# 99                  33                     <NA>                <NA>
# 105                721                      679                 289
# 106                185                      164                  94
# 107                880                      813                 336
# 108                133                      118                  60
# 109                 75                       67                  34
# 110                115                      106                  48
# 113                408                     <NA>                <NA>
# 114                 30                     <NA>                <NA>
# 116                133                      124                  61
# 117               9386                     8790                3125
# 125                 28                     <NA>                <NA>
# 127                 68                     <NA>                <NA>
# 128                 75                     <NA>                <NA>
# 137                 31                     <NA>                <NA>
# 138               1682                     <NA>                <NA>
#
#     Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 97                            N                      Y
# 98                            N                      Y
# 99                            N                      Y
# 105                           N                      Y
# 106                           N                      Y
# 107                           N                      Y
# 108                           N                      Y
# 109                           N                      Y
# 110                           N                      Y
# 113                           N                      Y
# 114                           N                      Y
# 116                           N                      Y
# 117                           N                      Y
# 125                           N                      Y
# 127                           N                      Y
# 128                           N                      Y
# 137                           N                      Y
# 138                           N                      Y
#
#                                          Cases_f3393  \
# 97                                              <NA>
# 98                                              <NA>
# 99                                              <NA>
# 105  Y if individual is positive for f3393 and >55yo
# 106  Y if individual is positive for f3393 and >55yo
# 107  Y if individual is positive for f3393 and >55yo
# 108  Y if individual is positive for f3393 and >55yo
# 109  Y if individual is positive for f3393 and >55yo
# 110  Y if individual is positive for f3393 and >55yo
# 113                                             <NA>
# 114                                             <NA>
# 116  Y if individual is positive for f3393 and >55yo
# 117  Y if individual is positive for f3393 and >55yo
# 125                                             <NA>
# 127                                             <NA>
# 128                                             <NA>
# 137                                                Y
# 138                                                Y
#
#                                            Cases_f2247  \
# 97                                                <NA>
# 98                                                <NA>
# 99                                                <NA>
# 105    Y if individual is positive for f2247 and >55yo
# 106    Y if individual is positive for f2247 and >55yo
# 107    Y if individual is positive for f2247 and >55yo
# 108    Y if individual is positive for f2247 and >55yo
# 109    Y if individual is positive for f2247 and >55yo
# 110    Y if individual is positive for f2247 and >55yo
# 113                                               <NA>
# 114                                               <NA>
# 116    Y if individual is positive for f2247 and >55yo
# 117    Y if individual is positive for f2247 and >55yo
# 125                                               <NA>
# 127                                               <NA>
# 128                                               <NA>
# 137  N (Case only if they reply yes consistenly to ...
# 138  N (Case only if they reply yes consistenly to ...
#
#                                          Cases_f2257
# 97                                              <NA>
# 98                                              <NA>
# 99                                              <NA>
# 105  Y if individual is positive for f2257 and >55yo
# 106  Y if individual is positive for f2257 and >55yo
# 107  Y if individual is positive for f2257 and >55yo
# 108  Y if individual is positive for f2257 and >55yo
# 109  Y if individual is positive for f2257 and >55yo
# 110  Y if individual is positive for f2257 and >55yo
# 113                                             <NA>
# 114                                             <NA>
# 116  Y if individual is positive for f2257 and >55yo
# 117  Y if individual is positive for f2257 and >55yo
# 125                                             <NA>
# 127                                             <NA>
# 128                                             <NA>
# 137                                                N
# 138                                                N

# %%
ex_critia_ctrl_icd10 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd10["Phenotype"].tolist()]
ex_critia_ctrl_icd10
# Out:
# ['H833',
#  'H838',
#  'H839',
#  'H903',
#  'H904',
#  'H905',
#  'H906',
#  'H907',
#  'H908',
#  'H911',
#  'H912',
#  'H918',
#  'H919',
#  'H932',
#  'H938',
#  'H939',
#  'Z461',
#  'Z974']

# %%
icd10 = filtered[icd10_colnames]
icd10
# Out:
#        f.41270.0.0 f.41270.0.1 f.41270.0.2 f.41270.0.3 f.41270.0.4  \
# 1             F101        J342        R619       S8280        W010
# 2             H269        K579        K590        K621       M5459
# 3             E780        G473        R065        R074        Z824
# 4             C679        C787        C795        C798        D090
# 5             <NA>        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 455540        A049        A099        A419        B370        C859
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>
# 455542        O149        O266        O342        O471         O48
# 455543        G551        G558         I10        M501        Z981
# 455544        D225        S008        S109        S198        T797
#
#        f.41270.0.5 f.41270.0.6 f.41270.0.7 f.41270.0.8 f.41270.0.9  ...  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2              N40        R040         R31        R398        Z466  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             I802        I959        J181        K922        M169  ...
# 5             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 455540        D649        E278        E279        E538        E559  ...
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455542        O610        O680        Z370        <NA>        <NA>  ...
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455544        W238        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41270.0.249 f.41270.0.250 f.41270.0.251 f.41270.0.252 f.41270.0.253  \
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# 5               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 455540          <NA>          <NA>          <NA>          <NA>          <NA>
# 455541          <NA>          <NA>          <NA>          <NA>          <NA>
# 455542          <NA>          <NA>          <NA>          <NA>          <NA>
# 455543          <NA>          <NA>          <NA>          <NA>          <NA>
# 455544          <NA>          <NA>          <NA>          <NA>          <NA>
#
#        f.41270.0.254 f.41270.0.255 f.41270.0.256 f.41270.0.257 f.41270.0.258
# 1               <NA>          <NA>          <NA>          <NA>          <NA>
# 2               <NA>          <NA>          <NA>          <NA>          <NA>
# 3               <NA>          <NA>          <NA>          <NA>          <NA>
# 4               <NA>          <NA>          <NA>          <NA>          <NA>
# 5               <NA>          <NA>          <NA>          <NA>          <NA>
# ...              ...           ...           ...           ...           ...
# 455540          <NA>          <NA>          <NA>          <NA>          <NA>
# 455541          <NA>          <NA>          <NA>          <NA>          <NA>
# 455542          <NA>          <NA>          <NA>          <NA>          <NA>
# 455543          <NA>          <NA>          <NA>          <NA>          <NA>
# 455544          <NA>          <NA>          <NA>          <NA>          <NA>
#
# [427009 rows x 259 columns]

# %%
# collect the individuals who should not be part of controls because of icd 10 codes
ex_fxn_icd10 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd10)
ex_10 = icd10.apply(ex_fxn_icd10, axis=1)

# %% [markdown]
# ### Collect ICD 9 codes to filter out from Ctrl

# %%
exclude_ctrl_icd9 = exclusion[(exclusion["UKBB_field_code"] == "f.41271") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd9
# Out:
#     UKBB_field_code                                         Phenotype  \
# 371         f.41271   3880 Degenerative and vascular disorders of ear
# 372         f.41271                   3881 Noise effects on inner ear
# 373         f.41271             3882 Sudden hearing loss, unspecified
# 374         f.41271                                     3883 Tinnitus
# 375         f.41271           3884 Other abnormal auditory perception
# 379         f.41271             3888 Other specified disorders of ear
# 380         f.41271                3889 Disorders of ear, unspecified
# 383         f.41271                       3891 Sensorineural deafness
# 384         f.41271  3892 Mixed conductive and sensorineural deafness
# 385         f.41271      3897 Deaf mutism, not elsewhere classifiable
# 386         f.41271            3898 Other specified forms of deafness
# 387         f.41271                         3899 Unspecified deafness
# 388         f.41271                        V412 Problems with hearing
# 389         f.41271        V532 Fitting and adjustment of hearing aid
#
#     cases_UKB_showcase White_EU_After_PCA_clean less than 55 years   \
# 371                  0                     <NA>                <NA>
# 372                  0                     <NA>                <NA>
# 373                  0                     <NA>                <NA>
# 374                 11                     <NA>                <NA>
# 375                  0                     <NA>                <NA>
# 379                  1                     <NA>                <NA>
# 380                  2                     <NA>                <NA>
# 383                  6                     <NA>                <NA>
# 384                  1                     <NA>                <NA>
# 385                  1                     <NA>                <NA>
# 386                  0                     <NA>                <NA>
# 387                 93                     <NA>                <NA>
# 388                  0                     <NA>                <NA>
# 389                  0                     <NA>                <NA>
#
#     Excluded_fulldb_lateonsetHI Excluded_from_controls  \
# 371                           N                      Y
# 372                           N                      Y
# 373                           N                      Y
# 374                           N                      Y
# 375                           N                      Y
# 379                           N                      Y
# 380                           N                      Y
# 383                           N                      Y
# 384                           N                      Y
# 385                           N                      Y
# 386                           N                      Y
# 387                           N                      Y
# 388                           N                      Y
# 389                           N                      Y
#
#                                          Cases_f3393  \
# 371                                             <NA>
# 372                                             <NA>
# 373                                             <NA>
# 374                                             <NA>
# 375                                             <NA>
# 379                                             <NA>
# 380                                             <NA>
# 383  Y if individual is positive for f3393 and >55yo
# 384  Y if individual is positive for f3393 and >55yo
# 385  Y if individual is positive for f3393 and >55yo
# 386  Y if individual is positive for f3393 and >55yo
# 387  Y if individual is positive for f3393 and >55yo
# 388                                                Y
# 389                                                Y
#
#                                          Cases_f2247  \
# 371                                             <NA>
# 372                                             <NA>
# 373                                             <NA>
# 374                                             <NA>
# 375                                             <NA>
# 379                                             <NA>
# 380                                             <NA>
# 383  Y if individual is positive for f2247 and >55yo
# 384  Y if individual is positive for f2247 and >55yo
# 385  Y if individual is positive for f2247 and >55yo
# 386  Y if individual is positive for f2247 and >55yo
# 387  Y if individual is positive for f2247 and >55yo
# 388                                                N
# 389                                                N
#
#                                          Cases_f2257
# 371                                             <NA>
# 372                                             <NA>
# 373                                             <NA>
# 374                                             <NA>
# 375                                             <NA>
# 379                                             <NA>
# 380                                             <NA>
# 383  Y if individual is positive for f2257 and >55yo
# 384  Y if individual is positive for f2257 and >55yo
# 385  Y if individual is positive for f2257 and >55yo
# 386  Y if individual is positive for f2257 and >55yo
# 387  Y if individual is positive for f2257 and >55yo
# 388                                                N
# 389                                                N

# %%
ex_critia_ctrl_icd9 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd9["Phenotype"].tolist()]
ex_critia_ctrl_icd9
# Out:
# ['3880',
#  '3881',
#  '3882',
#  '3883',
#  '3884',
#  '3888',
#  '3889',
#  '3891',
#  '3892',
#  '3897',
#  '3898',
#  '3899',
#  'V412',
#  'V532']

# %%
icd9 = filtered[icd9_colnames]
icd9
# Out:
#        f.41271.0.0 f.41271.0.1 f.41271.0.2 f.41271.0.3 f.41271.0.4  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>
# 2             <NA>        <NA>        <NA>        <NA>        <NA>
# 3             <NA>        <NA>        <NA>        <NA>        <NA>
# 4             3000      5198.0        <NA>        <NA>        <NA>
# 5             <NA>        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 455540        <NA>        <NA>        <NA>        <NA>        <NA>
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>
# 455544        <NA>        <NA>        <NA>        <NA>        <NA>
#
#        f.41271.0.5 f.41271.0.6 f.41271.0.7 f.41271.0.8 f.41271.0.9  ...  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 5             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 455540        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455544        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.41271.0.37 f.41271.0.38 f.41271.0.39 f.41271.0.40 f.41271.0.41  \
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.41271.0.42 f.41271.0.43 f.41271.0.44 f.41271.0.45 f.41271.0.46
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [427009 rows x 47 columns]

# %%
# collect the individuals who should not be part of controls because of icd 9 codes
ex_fxn_icd9 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd9)
ex_9 = icd9.apply(ex_fxn_icd9, axis=1)

# %% [markdown]
# ### Collect f20002 codes to filter out from Ctrl

# %%
exclude_ctrl_f20002 = exclusion[(exclusion["UKBB_field_code"] == "f.20002") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_f20002
# Out:
#     UKBB_field_code                     Phenotype cases_UKB_showcase  \
# 538         f.20002  1415 ear/vestibular disorder               4561
#
#     White_EU_After_PCA_clean less than 55 years  Excluded_fulldb_lateonsetHI  \
# 538                     4228                3923                           N
#
#     Excluded_from_controls                                      Cases_f3393  \
# 538                      Y  Y if individual is positive for f3393 and >55yo
#
#                                          Cases_f2247  \
# 538  Y if individual is positive for f2247 and >55yo
#
#                                          Cases_f2257
# 538  Y if individual is positive for f2257 and >55yo

# %%
f20002 = filtered[f20002_colnames]
f20002
# Out:
#        f.20002.0.0 f.20002.0.1 f.20002.0.2 f.20002.0.3 f.20002.0.4  \
# 1           1065.0        <NA>        <NA>        <NA>        <NA>
# 2           1396.0      1473.0        <NA>        <NA>        <NA>
# 3           1065.0      1294.0      1476.0      1473.0      1374.0
# 4             <NA>        <NA>        <NA>        <NA>        <NA>
# 5           1387.0        <NA>        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...         ...
# 455540      1464.0        <NA>        <NA>        <NA>        <NA>
# 455541      1478.0      1473.0        <NA>        <NA>        <NA>
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>
# 455543      1265.0        <NA>        <NA>        <NA>        <NA>
# 455544      1065.0        <NA>        <NA>        <NA>        <NA>
#
#        f.20002.0.5 f.20002.0.6 f.20002.0.7 f.20002.0.8 f.20002.0.9  ...  \
# 1             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 2             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 3             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 4             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 5             <NA>        <NA>        <NA>        <NA>        <NA>  ...
# ...            ...         ...         ...         ...         ...  ...
# 455540        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455541        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455542        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455543        <NA>        <NA>        <NA>        <NA>        <NA>  ...
# 455544        <NA>        <NA>        <NA>        <NA>        <NA>  ...
#
#        f.20002.3.24 f.20002.3.25 f.20002.3.26 f.20002.3.27 f.20002.3.28  \
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
#        f.20002.3.29 f.20002.3.30 f.20002.3.31 f.20002.3.32 f.20002.3.33
# 1              <NA>         <NA>         <NA>         <NA>         <NA>
# 2              <NA>         <NA>         <NA>         <NA>         <NA>
# 3              <NA>         <NA>         <NA>         <NA>         <NA>
# 4              <NA>         <NA>         <NA>         <NA>         <NA>
# 5              <NA>         <NA>         <NA>         <NA>         <NA>
# ...             ...          ...          ...          ...          ...
# 455540         <NA>         <NA>         <NA>         <NA>         <NA>
# 455541         <NA>         <NA>         <NA>         <NA>         <NA>
# 455542         <NA>         <NA>         <NA>         <NA>         <NA>
# 455543         <NA>         <NA>         <NA>         <NA>         <NA>
# 455544         <NA>         <NA>         <NA>         <NA>         <NA>
#
# [427009 rows x 136 columns]

# %%
ex_critia_ctrl_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_f20002["Phenotype"].tolist()]
ex_critia_ctrl_f20002
# Out:
# ['1415']

# %%
# collect the individuals who should not be part of controls because of self-reported codes
ex_fxn_f20002 = lambda row: contains_exclusion(row, ex_critia_ctrl_f20002)
ex_f20002 = f20002.apply(ex_fxn_f20002, axis=1)

# %% [markdown]
# ### Filter out the HI Ctrl

# %%
temp = pure_ctrl | ex_10 | ex_9 | ex_f20002

# %%
# because individuals that are controls are labeled as 0
# temp says True if an individual is not a control and False if it is a control
# ex_10, ex_9, and ex_f20002 are True for individuals that are not controls and False for individuals that are controls
temp = pure_ctrl | ex_10 | ex_9 | ex_f20002

# we set the control as 0 for each individual that is False in temp
filtered_ctrl = [1 if i else 0 for i in temp.to_list()]

# %%
print(len(filtered_ctrl) - sum(filtered_ctrl), "individuals are controls after addition filtration for icd10, icd9 and self-reported codes")
# Out:
# 234172 individuals are controls after addition filtration for icd10, icd9 and self-reported codes

# %%
filtered["hearing_imp_pure_ctrl"] = filtered_ctrl
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/10965548.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["hearing_imp_pure_ctrl"] = filtered_ctrl

# %%
filtered
# Out:
#             IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0 f.2247.1.0  \
# 1       1000022  1000022     Male     1954     August        Yes       <NA>
# 2       1000035  1000035     Male     1944        May         No       <NA>
# 3       1000046  1000046   Female     1946      March         No       <NA>
# 4       1000054  1000054   Female     1942    January         No       <NA>
# 5       1000063  1000063     Male     1967      April         No       <NA>
# ...         ...      ...      ...      ...        ...        ...        ...
# 455540  6025390  6025390   Female     1942      March         No       <NA>
# 455541  6025409  6025409   Female     1946   November         No         No
# 455542  6025411  6025411   Female     1960   November         No       <NA>
# 455543  6025425  6025425   Female     1963     August         No       <NA>
# 455544  6025438  6025438     Male     1952  September         No       <NA>
#
#        f.2247.2.0 f.2247.3.0 f.2257.0.0  ... age_f.41280.0.251  \
# 1            <NA>       <NA>        Yes  ...              <NA>
# 2            <NA>       <NA>        Yes  ...              <NA>
# 3              No       <NA>         No  ...              <NA>
# 4            <NA>       <NA>        Yes  ...              <NA>
# 5            <NA>       <NA>         No  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 455540       <NA>       <NA>        Yes  ...              <NA>
# 455541       <NA>       <NA>         No  ...              <NA>
# 455542       <NA>       <NA>         No  ...              <NA>
# 455543       <NA>       <NA>         No  ...              <NA>
# 455544       <NA>       <NA>         No  ...              <NA>
#
#        age_f.41280.0.252 age_f.41280.0.253 age_f.41280.0.254  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.255 age_f.41280.0.256 age_f.41280.0.257  \
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# 5                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 455540              <NA>              <NA>              <NA>
# 455541              <NA>              <NA>              <NA>
# 455542              <NA>              <NA>              <NA>
# 455543              <NA>              <NA>              <NA>
# 455544              <NA>              <NA>              <NA>
#
#        age_f.41280.0.258      test hearing_imp_pure_ctrl
# 1                   <NA>  Not Sure                     1
# 2                   <NA>  Not Sure                     1
# 3                   <NA>  Not Sure                     1
# 4                   <NA>  Not Sure                     1
# 5                   <NA>  Not Sure                     0
# ...                  ...       ...                   ...
# 455540              <NA>  Not Sure                     1
# 455541              <NA>  Not Sure                     0
# 455542              <NA>  Not Sure                     0
# 455543              <NA>  Not Sure                     0
# 455544              <NA>  Not Sure                     0
#
# [427009 rows x 1226 columns]

# %%
filtered = filtered.reset_index()
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/476735807.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered = filtered.reset_index()

# %%
saved_3_filtered = filtered

# %%
filtered = saved_3_filtered

# %%
filtered
# Out:
#          index      IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0  \
# 0            1  1000022  1000022     Male     1954     August        Yes
# 1            2  1000035  1000035     Male     1944        May         No
# 2            3  1000046  1000046   Female     1946      March         No
# 3            4  1000054  1000054   Female     1942    January         No
# 4            5  1000063  1000063     Male     1967      April         No
# ...        ...      ...      ...      ...      ...        ...        ...
# 427004  455540  6025390  6025390   Female     1942      March         No
# 427005  455541  6025409  6025409   Female     1946   November         No
# 427006  455542  6025411  6025411   Female     1960   November         No
# 427007  455543  6025425  6025425   Female     1963     August         No
# 427008  455544  6025438  6025438     Male     1952  September         No
#
#        f.2247.1.0 f.2247.2.0 f.2247.3.0  ... age_f.41280.0.251  \
# 0            <NA>       <NA>       <NA>  ...              <NA>
# 1            <NA>       <NA>       <NA>  ...              <NA>
# 2            <NA>         No       <NA>  ...              <NA>
# 3            <NA>       <NA>       <NA>  ...              <NA>
# 4            <NA>       <NA>       <NA>  ...              <NA>
# ...           ...        ...        ...  ...               ...
# 427004       <NA>       <NA>       <NA>  ...              <NA>
# 427005         No       <NA>       <NA>  ...              <NA>
# 427006       <NA>       <NA>       <NA>  ...              <NA>
# 427007       <NA>       <NA>       <NA>  ...              <NA>
# 427008       <NA>       <NA>       <NA>  ...              <NA>
#
#        age_f.41280.0.252 age_f.41280.0.253 age_f.41280.0.254  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 427004              <NA>              <NA>              <NA>
# 427005              <NA>              <NA>              <NA>
# 427006              <NA>              <NA>              <NA>
# 427007              <NA>              <NA>              <NA>
# 427008              <NA>              <NA>              <NA>
#
#        age_f.41280.0.255 age_f.41280.0.256 age_f.41280.0.257  \
# 0                   <NA>              <NA>              <NA>
# 1                   <NA>              <NA>              <NA>
# 2                   <NA>              <NA>              <NA>
# 3                   <NA>              <NA>              <NA>
# 4                   <NA>              <NA>              <NA>
# ...                  ...               ...               ...
# 427004              <NA>              <NA>              <NA>
# 427005              <NA>              <NA>              <NA>
# 427006              <NA>              <NA>              <NA>
# 427007              <NA>              <NA>              <NA>
# 427008              <NA>              <NA>              <NA>
#
#        age_f.41280.0.258      test hearing_imp_pure_ctrl
# 0                   <NA>  Not Sure                     1
# 1                   <NA>  Not Sure                     1
# 2                   <NA>  Not Sure                     1
# 3                   <NA>  Not Sure                     1
# 4                   <NA>  Not Sure                     0
# ...                  ...       ...                   ...
# 427004              <NA>  Not Sure                     1
# 427005              <NA>  Not Sure                     0
# 427006              <NA>  Not Sure                     0
# 427007              <NA>  Not Sure                     0
# 427008              <NA>  Not Sure                     0
#
# [427009 rows x 1227 columns]

# %% [markdown]
# ## Identify All Age and Phenotype Columns

# %%
ages_f21003_col = [col for col in filtered if "f.21003" in col]
ages_f21003_col
# Out:
# ['f.21003.0.0', 'f.21003.1.0', 'f.21003.2.0', 'f.21003.3.0']

# %%
ages_f131258_col = [col.strip('"') for col in filtered if 'f.131258' in col]
ages_f131258_col
# Out:
# ['f.131258.0.0']

# %%
filtered[ages_f21003_col]
# Out:
#        f.21003.0.0 f.21003.1.0 f.21003.2.0 f.21003.3.0
# 0               53        <NA>        <NA>        <NA>
# 1               63        <NA>        <NA>        <NA>
# 2               62        <NA>        73.0        <NA>
# 3               65        <NA>        <NA>        <NA>
# 4               43        <NA>        <NA>        <NA>
# ...            ...         ...         ...         ...
# 427004          67        <NA>        <NA>        <NA>
# 427005          61        66.0        72.0        <NA>
# 427006          49        <NA>        <NA>        <NA>
# 427007          44        <NA>        <NA>        <NA>
# 427008          55        <NA>        <NA>        <NA>
#
# [427009 rows x 4 columns]

# %%
filtered[ages_f131258_col]
# Out:
#        f.131258.0.0
# 0              <NA>
# 1              <NA>
# 2              <NA>
# 3              <NA>
# 4              <NA>
# ...             ...
# 427004         <NA>
# 427005         <NA>
# 427006         <NA>
# 427007         <NA>
# 427008         <NA>
#
# [427009 rows x 1 columns]

# %%
# get the latest time that an individual said no to any of the phenotypes
# return the oldest age that they were
def get_ctrl_age(row):
    phens = [hearing_imp_f3393, hearing_imp_f2247, hearing_imp_f2257]
    ages = []
    if row["hearing_imp_pure_ctrl"] == 0:
        temp_all_ages = row[ages_f21003_col].to_list()
        temp_all_ages.reverse()
        
        for phen in phens:
            temp = row[phen].to_list()
            temp.reverse()
            for en, i in enumerate(temp):
                if not pd.isna(i) and i == "No":
                    ages.append(temp_all_ages[en])
                    break
        ages.sort()
        return ages[-1]
    return pd.NA

# get the earliest time that an individual said yes to having a phenotype
def get_phen_age(row):
    if row[0] == 1:
        temp = row[1:-4].to_list()
        for en, i in enumerate(temp):
            if not pd.isna(i) and i == "Yes":
                return row[ages_f21003_col][en]
    else:
        return pd.NA
    
# return the minium age in the row, or else return NA
def get_min_age(row):
    temp = [i for i in row.to_list() if not pd.isna(i)]
    if len(temp) > 0:
        return min(temp)
    else:
        return pd.NA

# %%
# return 1 if we have a yes (used to find phenos)
def find_yes(row):
    for i in row:
        if not pd.isna(i) and i == "Yes":
            return 1
    return 0

# return 1 if we have a match for the mendelian traits and have at least one of the hearing phenotypes
def find_medelian_like(row):
    mendelian_icd10 = ["H903", "H905", "H906", "H908", "H913", "H918", "H919"]
    mendelian_icd9 = ["3891", "3892", "3897", "3898", "3899"]

    if 1 in row[["f3393", "f2247", "f2257"]].to_list():
        for en, i in enumerate(row[icd_10_cols]):
            if not pd.isna(i) and i in mendelian_icd10:
                return 1, get_ages_from_birth(row[icd10_ages[en:en+1]+year_of_birth+month_of_birth])
        for en, i in enumerate(row[icd_9_cols]):
            if not pd.isna(i) and i in mendelian_icd9:
                return 1, get_ages_from_birth(row[icd9_ages[en:en+1]+year_of_birth+month_of_birth])
    return 0, pd.NA

# return a 0 if the individual is not a case and 1 if they are a case
def find_exclusions(row):
    mendelian_icd10 = ["H903", "H904", "H905", "H906", "H907", "H908"]
    mendelian_icd9 = ["3891", "3892", "3897", "3898", "3899"]

    try:
        if 1 == row[0]: # the first column will be one of the phenotypes, "f3393", "f2247", or "f2257"
            for en, i in enumerate(row[icd_10_cols]):
                if not pd.isna(i) and i in mendelian_icd10:
                    if get_ages_from_birth(row[ages_f131258_col+year_of_birth+month_of_birth]) <= 55: # row[1] must be the age of the phenotype
                        return 0, pd.NA
                    return 1, get_ages_from_birth(row[ages_f131258_col+year_of_birth+month_of_birth])
            for en, i in enumerate(row[icd_9_cols]):
                if not pd.isna(i) and i in mendelian_icd9:
                    if get_ages_from_birth(row[icd9_ages[en:en+1]+year_of_birth+month_of_birth]) <= 55:
                        return 0, pd.NA
                    return 1, get_ages_from_birth(row[icd9_ages[en:en+1]+year_of_birth+month_of_birth])
        return int(row[0]), row[1] # the second column should be the ages of that phenotype
    except:
        print(row["name"])


# return 1 if we have a match for the other cases of f3393 or originally had f3393
def find_f3393_other_cases(row):
    icd10 = ["Z461", "Z974"]
    icd9 = ["V412", "V532"]
    if 0 == int(row["f3393"]):
        for en, i in enumerate(row[icd_10_cols]):
            if not pd.isna(i) and i in icd10:
                return 1, get_ages_from_birth(row[icd10_ages[en:en+1]+year_of_birth+month_of_birth])
        for en, i in enumerate(row[icd_9_cols]):
            if not pd.isna(i) and i in icd9:
                return 1, get_ages_from_birth(row[icd9_ages[en:en+1]+year_of_birth+month_of_birth])
    return int(row["f3393"]), row["f3393_age"]

# check if the h919 code exists in the individual
def check_code(row):
    for i in row:
        if not pd.isna(i) and i == "H919":
            return 1
    return 0

# %%
def get_ages_from_birth(row):
    month_dict = {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12}
    year = 0
    month = 0
    i = row[0]
    if not pd.isna(i):
        i = i.split("-")
        year = i[0]
        month = i[1]
    if int(month) >= month_dict[row[month_of_birth[0]]]:
        return int(year) - int(row[year_of_birth[0]])
    return int(year) - int(row[year_of_birth[0]]) - 1

# %%
# f3393
hearing_imp_qs = filtered[hearing_imp_f3393]
filtered["f3393"] = hearing_imp_qs.apply(find_yes, axis=1)
filtered["f3393_age"] = filtered[["f3393"] + hearing_imp_f3393 + ages_f21003_col].apply(get_phen_age, axis=1)
filtered[["f3393", "f3393_age"]] = filtered[["f3393", "f3393_age"] + icd_10_cols + icd_9_cols + icd10_ages + icd9_ages + ages_f131258_col + year_of_birth + month_of_birth].apply(find_exclusions, axis=1, result_type='expand')
filtered[["f3393", "f3393_age"]] = filtered[["f3393", "f3393_age"] + icd_10_cols + icd_9_cols + icd10_ages + icd9_ages + year_of_birth + month_of_birth].apply(find_f3393_other_cases, axis=1, result_type='expand')
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/4078825862.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f3393"] = hearing_imp_qs.apply(find_yes, axis=1)
# /tmp/5843399.1.csg.q/ipykernel_6463/4078825862.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f3393_age"] = filtered[["f3393"] + hearing_imp_f3393 + ages_f21003_col].apply(get_phen_age, axis=1)

# %%
# check if we have f3393 ages
filtered[(filtered["f3393"] == 1) & (pd.isna(filtered["f3393_age"])) & (pd.isna(filtered[ages_f131258_col[0]]))][["f3393", "f3393_age"] + ages_f131258_col]
# Out:
# Empty DataFrame
# Columns: [f3393, f3393_age, f.131258.0.0]
# Index: []

# %%
# f2247
hearing_imp_qs = filtered[hearing_imp_f2247]
filtered["f2247"] = hearing_imp_qs.apply(find_yes, axis=1)
filtered["f2247_age"] = filtered[["f2247"] + hearing_imp_f2247 + ages_f21003_col].apply(get_phen_age, axis=1)
filtered[["f2247", "f2247_age"]] = filtered[["f2247", "f2247_age"] + icd_10_cols + icd_9_cols + icd10_ages + icd9_ages + ages_f131258_col + year_of_birth + month_of_birth].apply(find_exclusions, axis=1, result_type='expand')
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/165492886.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247"] = hearing_imp_qs.apply(find_yes, axis=1)
# /tmp/5843399.1.csg.q/ipykernel_6463/165492886.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247_age"] = filtered[["f2247"] + hearing_imp_f2247 + ages_f21003_col].apply(get_phen_age, axis=1)

# %%
# check if we have f2247 ages
filtered[(filtered["f2247"] == 1) & (pd.isna(filtered["f2247_age"]))][["f2247", "f2247_age"]]
# Out:
# Empty DataFrame
# Columns: [f2247, f2247_age]
# Index: []

# %%
# f2257
hearing_imp_qs = filtered[hearing_imp_f2257]
filtered["f2257"] = hearing_imp_qs.apply(find_yes, axis=1)
filtered["f2257_age"] = filtered[["f2257"] + hearing_imp_f2257 + ages_f21003_col].apply(get_phen_age, axis=1)
filtered[["f2257", "f2257_age"]] = filtered[["f2257", "f2257_age"] + icd_10_cols + icd_9_cols + icd10_ages + icd9_ages + ages_f131258_col + year_of_birth + month_of_birth].apply(find_exclusions, axis=1, result_type='expand')
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/2446816283.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2257"] = hearing_imp_qs.apply(find_yes, axis=1)
# /tmp/5843399.1.csg.q/ipykernel_6463/2446816283.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2257_age"] = filtered[["f2257"] + hearing_imp_f2257 + ages_f21003_col].apply(get_phen_age, axis=1)

# %%
# check if we have empty f2257 ages
filtered[(filtered["f2257"] == 1) & (pd.isna(filtered["f2257_age"]))][["f2257", "f2257_age"]]
# Out:
# Empty DataFrame
# Columns: [f2257, f2257_age]
# Index: []

# %%
# ctrl age
filtered["ctrl_age"] = filtered[["hearing_imp_pure_ctrl"] + ages_f21003_col +  hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257].apply(get_ctrl_age, axis=1)
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/2773894235.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["ctrl_age"] = filtered[["hearing_imp_pure_ctrl"] + ages_f21003_col +  hearing_imp_f3393 + hearing_imp_f2247 + hearing_imp_f2257].apply(get_ctrl_age, axis=1)

# %%
# check if we have empty ctrl ages
filtered[(filtered["hearing_imp_pure_ctrl"] == 0) & (pd.isna(filtered["ctrl_age"]))][["hearing_imp_pure_ctrl", "ctrl_age"]]
# Out:
# Empty DataFrame
# Columns: [hearing_imp_pure_ctrl, ctrl_age]
# Index: []

# %%
# f2247_f2257
filtered["f2247_f2257"] =  filtered["f2247"] + filtered["f2257"]
filtered["f2247_f2257_age"] = filtered[["f2247_age", "f2257_age"]].apply(get_min_age, axis=1)
filtered["f2247_f2257"]
# Out:
# /tmp/5843399.1.csg.q/ipykernel_6463/3355645291.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247_f2257"] =  filtered["f2247"] + filtered["f2257"]
# /tmp/5843399.1.csg.q/ipykernel_6463/3355645291.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   filtered["f2247_f2257_age"] = filtered[["f2247_age", "f2257_age"]].apply(get_min_age, axis=1)
# 0         2
# 1         1
# 2         1
# 3         1
# 4         0
#          ..
# 427004    1
# 427005    0
# 427006    0
# 427007    0
# 427008    0
# Name: f2247_f2257, Length: 427009, dtype: int64

# %%
# check if we have empty f2247_f2257 ages
filtered[(filtered["f2247_f2257"] == 2) & (pd.isna(filtered["f2247_f2257_age"]))][["f2247_f2257", "f2247_f2257_age"]]
# Out:
# Empty DataFrame
# Columns: [f2247_f2257, f2247_f2257_age]
# Index: []

# %%
mask = filtered["f2247_f2257"] == 2
Both = filtered[mask]
Both
# Out:
#          index      IID      FID f.31.0.0 f.34.0.0   f.52.0.0   f.2247.0.0  \
# 0            1  1000022  1000022     Male     1954     August          Yes
# 9           10  1000112  1000112     Male     1949       June  Do not know
# 14          15  1000170  1000170   Female     1956      April          Yes
# 16          17  1000198  1000198   Female     1967       July          Yes
# 17          18  1000203  1000203   Female     1959  September          Yes
# ...        ...      ...      ...      ...      ...        ...          ...
# 426972  455506  6024983  6024983     Male     1941        May          Yes
# 426973  455507  6024997  6024997   Female     1950      April          Yes
# 426983  455517  6025128  6025128   Female     1944   November          Yes
# 426984  455518  6025134  6025134     Male     1944        May          Yes
# 427001  455537  6025354  6025354   Female     1957   February          Yes
#
#        f.2247.1.0 f.2247.2.0 f.2247.3.0  ... hearing_imp_pure_ctrl f3393  \
# 0            <NA>       <NA>       <NA>  ...                     1     0
# 9            <NA>        Yes       <NA>  ...                     1     1
# 14           <NA>       <NA>       <NA>  ...                     1     0
# 16           <NA>       <NA>       <NA>  ...                     1     0
# 17           <NA>       <NA>       <NA>  ...                     1     0
# ...           ...        ...        ...  ...                   ...   ...
# 426972       <NA>       <NA>       <NA>  ...                     1     0
# 426973       <NA>       <NA>       <NA>  ...                     1     0
# 426983       <NA>       <NA>       <NA>  ...                     1     0
# 426984       <NA>       <NA>       <NA>  ...                     1     1
# 427001       <NA>       <NA>       <NA>  ...                     1     0
#
#        f3393_age f2247 f2247_age f2257 f2257_age ctrl_age f2247_f2257  \
# 0           <NA>     1        53     1        53     <NA>           2
# 9           68.0     1      68.0     1      68.0     <NA>           2
# 14          <NA>     1        51     1        51     <NA>           2
# 16          <NA>     1        41     1        41     <NA>           2
# 17          <NA>     1        49     1        49     <NA>           2
# ...          ...   ...       ...   ...       ...      ...         ...
# 426972      <NA>     1        67     1        67     <NA>           2
# 426973      <NA>     1        58     1        58     <NA>           2
# 426983      <NA>     1        64     1        64     <NA>           2
# 426984        64     1        64     1        64     <NA>           2
# 427001      <NA>     1        52     1        52     <NA>           2
#
#        f2247_f2257_age
# 0                   53
# 9                 68.0
# 14                  51
# 16                  41
# 17                  49
# ...                ...
# 426972              67
# 426973              58
# 426983              64
# 426984              64
# 427001              52
#
# [95380 rows x 1236 columns]

# %% [markdown]
# ## 5.4. File Output

# %%
filtered
# Out:
#          index      IID      FID f.31.0.0 f.34.0.0   f.52.0.0 f.2247.0.0  \
# 0            1  1000022  1000022     Male     1954     August        Yes
# 1            2  1000035  1000035     Male     1944        May         No
# 2            3  1000046  1000046   Female     1946      March         No
# 3            4  1000054  1000054   Female     1942    January         No
# 4            5  1000063  1000063     Male     1967      April         No
# ...        ...      ...      ...      ...      ...        ...        ...
# 427004  455540  6025390  6025390   Female     1942      March         No
# 427005  455541  6025409  6025409   Female     1946   November         No
# 427006  455542  6025411  6025411   Female     1960   November         No
# 427007  455543  6025425  6025425   Female     1963     August         No
# 427008  455544  6025438  6025438     Male     1952  September         No
#
#        f.2247.1.0 f.2247.2.0 f.2247.3.0  ... hearing_imp_pure_ctrl f3393  \
# 0            <NA>       <NA>       <NA>  ...                     1     0
# 1            <NA>       <NA>       <NA>  ...                     1     0
# 2            <NA>         No       <NA>  ...                     1     0
# 3            <NA>       <NA>       <NA>  ...                     1     0
# 4            <NA>       <NA>       <NA>  ...                     0     0
# ...           ...        ...        ...  ...                   ...   ...
# 427004       <NA>       <NA>       <NA>  ...                     1     0
# 427005         No       <NA>       <NA>  ...                     0     0
# 427006       <NA>       <NA>       <NA>  ...                     0     0
# 427007       <NA>       <NA>       <NA>  ...                     0     0
# 427008       <NA>       <NA>       <NA>  ...                     0     0
#
#        f3393_age f2247 f2247_age f2257 f2257_age ctrl_age f2247_f2257  \
# 0            NaN     1        53     1        53     <NA>           2
# 1            NaN     0      <NA>     1        63     <NA>           1
# 2            NaN     0      <NA>     1      73.0     <NA>           1
# 3            NaN     0      <NA>     1        65     <NA>           1
# 4            NaN     0      <NA>     0      <NA>       43           0
# ...          ...   ...       ...   ...       ...      ...         ...
# 427004       NaN     0       NaN     1        67     <NA>           1
# 427005       NaN     0       NaN     0      <NA>     66.0           0
# 427006       NaN     0       NaN     0      <NA>       49           0
# 427007       NaN     0       NaN     0      <NA>       44           0
# 427008       NaN     0       NaN     0      <NA>       55           0
#
#        f2247_f2257_age
# 0                   53
# 1                   63
# 2                 73.0
# 3                   65
# 4                 <NA>
# ...                ...
# 427004              67
# 427005            <NA>
# 427006            <NA>
# 427007            <NA>
# 427008            <NA>
#
# [427009 rows x 1236 columns]

# %%
filtered[filtered["hearing_imp_pure_ctrl"] == 0][["FID", "IID", "f.22001.0.0", "hearing_imp_pure_ctrl", "ctrl_age"]]
# Out:
#             FID      IID f.22001.0.0  hearing_imp_pure_ctrl ctrl_age
# 4       1000063  1000063        Male                      0       43
# 5       1000078  1000078      Female                      0     60.0
# 6       1000081  1000081        Male                      0       67
# 10      1000129  1000129        Male                      0       62
# 11      1000137  1000137      Female                      0       46
# ...         ...      ...         ...                    ...      ...
# 427002  6025363  6025363        Male                      0       64
# 427005  6025409  6025409      Female                      0     66.0
# 427006  6025411  6025411      Female                      0       49
# 427007  6025425  6025425      Female                      0       44
# 427008  6025438  6025438        Male                      0       55
#
# [234172 rows x 5 columns]

# %%
filtered[filtered["hearing_imp_pure_ctrl"] == 0][["FID", "IID", "f.22001.0.0", "hearing_imp_pure_ctrl", "ctrl_age"]].to_csv("pure_ctrl_pheno_file_DMCS.tsv", sep='\t', index=False)

# %%
ctl = filtered[filtered["hearing_imp_pure_ctrl"] == 0][["FID", "IID", "f.22001.0.0", "hearing_imp_pure_ctrl", "ctrl_age"]]
ctl
# Out:
#             FID      IID f.22001.0.0  hearing_imp_pure_ctrl ctrl_age
# 4       1000063  1000063        Male                      0       43
# 5       1000078  1000078      Female                      0     60.0
# 6       1000081  1000081        Male                      0       67
# 10      1000129  1000129        Male                      0       62
# 11      1000137  1000137      Female                      0       46
# ...         ...      ...         ...                    ...      ...
# 427002  6025363  6025363        Male                      0       64
# 427005  6025409  6025409      Female                      0     66.0
# 427006  6025411  6025411      Female                      0       49
# 427007  6025425  6025425      Female                      0       44
# 427008  6025438  6025438        Male                      0       55
#
# [234172 rows x 5 columns]

# %%
ctl['sex'] = 1 
ctl.loc[(ctl['f.22001.0.0'] == 'Female') , 'sex'] = 2
ctl
# Out:
#             FID      IID f.22001.0.0  hearing_imp_pure_ctrl ctrl_age  sex
# 4       1000063  1000063        Male                      0       43    1
# 5       1000078  1000078      Female                      0     60.0    2
# 6       1000081  1000081        Male                      0       67    1
# 10      1000129  1000129        Male                      0       62    1
# 11      1000137  1000137      Female                      0       46    2
# ...         ...      ...         ...                    ...      ...  ...
# 427002  6025363  6025363        Male                      0       64    1
# 427005  6025409  6025409      Female                      0     66.0    2
# 427006  6025411  6025411      Female                      0       49    2
# 427007  6025425  6025425      Female                      0       44    2
# 427008  6025438  6025438        Male                      0       55    1
#
# [234172 rows x 6 columns]

# %%
ctl_2 = ctl[["FID", "IID", "hearing_imp_pure_ctrl", "ctrl_age", "sex"]]
ctl_2
# Out:
#             FID      IID  hearing_imp_pure_ctrl ctrl_age  sex
# 4       1000063  1000063                      0       43    1
# 5       1000078  1000078                      0     60.0    2
# 6       1000081  1000081                      0       67    1
# 10      1000129  1000129                      0       62    1
# 11      1000137  1000137                      0       46    2
# ...         ...      ...                    ...      ...  ...
# 427002  6025363  6025363                      0       64    1
# 427005  6025409  6025409                      0     66.0    2
# 427006  6025411  6025411                      0       49    2
# 427007  6025425  6025425                      0       44    2
# 427008  6025438  6025438                      0       55    1
#
# [234172 rows x 5 columns]

# %%
ctl_2.to_csv("pure_ctrl_pheno_file_DMCS.tsv", sep='\t', index=False)

# %%
ctl_2.isnull().sum()
# Out:
# FID                      0
# IID                      0
# hearing_imp_pure_ctrl    0
# ctrl_age                 0
# sex                      0
# dtype: int64

# %%
ctl_2['ctrl_age'].min()
# Out:
# '38'

# %%
ctl_2['ctrl_age'].value_counts(dropna=False)
# Out:
# 61      10746
# 62      10156
# 60       9892
# 63       9284
# 64       9020
#         ...
# 39          3
# 43.0        3
# 38          1
# 72          1
# 71          1
# Name: ctrl_age, Length: 77, dtype: int64

# %%
filtered[filtered["f3393"] == 1][["FID", "IID", "f.22001.0.0", "f3393", "f3393_age"]]
# Out:
#             FID      IID f.22001.0.0  f3393 f3393_age
# 9       1000112  1000112        Male      1      68.0
# 43      1000551  1000551        Male      1      83.0
# 84      1001067  1001067        Male      1        50
# 114     1001384  1001384      Female      1        61
# 120     1001459  1001459        Male      1        64
# ...         ...      ...         ...    ...       ...
# 426726  6022050  6022050      Female      1        52
# 426772  6022567  6022567        Male      1      73.0
# 426824  6023186  6023186        Male      1        67
# 426857  6023568  6023568      Female      1        68
# 426984  6025134  6025134        Male      1        64
#
# [17389 rows x 5 columns]

# %%
filtered[filtered["f2247"] == 1][["FID", "IID", "f.22001.0.0", "f2247", "f2247_age"]]
# Out:
#             FID      IID f.22001.0.0  f2247 f2247_age
# 0       1000022  1000022        Male      1        53
# 7       1000090  1000090      Female      1        64
# 9       1000112  1000112        Male      1      68.0
# 14      1000170  1000170      Female      1        51
# 16      1000198  1000198      Female      1        41
# ...         ...      ...         ...    ...       ...
# 426972  6024983  6024983        Male      1        67
# 426973  6024997  6024997      Female      1        58
# 426983  6025128  6025128      Female      1        64
# 426984  6025134  6025134        Male      1        64
# 427001  6025354  6025354      Female      1        52
#
# [112495 rows x 5 columns]

# %%
filtered[filtered["f2257"] == 1][["FID", "IID", "f.22001.0.0", "f2257", "f2257_age"]]
# Out:
#             FID      IID f.22001.0.0  f2257 f2257_age
# 0       1000022  1000022        Male      1        53
# 1       1000035  1000035        Male      1        63
# 2       1000046  1000046      Female      1      73.0
# 3       1000054  1000054      Female      1        65
# 8       1000105  1000105      Female      1        54
# ...         ...      ...         ...    ...       ...
# 426998  6025322  6025322      Female      1        63
# 427000  6025346  6025346      Female      1      68.0
# 427001  6025354  6025354      Female      1        52
# 427003  6025378  6025378        Male      1        42
# 427004  6025390  6025390      Female      1        67
#
# [162855 rows x 5 columns]

# %%
filtered[filtered["f2247_f2257"] == 2][["FID", "IID", "f.22001.0.0", "f2247_f2257", "f2247_f2257_age"]]
# Out:
#             FID      IID f.22001.0.0  f2247_f2257 f2247_f2257_age
# 0       1000022  1000022        Male            2              53
# 9       1000112  1000112        Male            2            68.0
# 14      1000170  1000170      Female            2              51
# 16      1000198  1000198      Female            2              41
# 17      1000203  1000203      Female            2              49
# ...         ...      ...         ...          ...             ...
# 426972  6024983  6024983        Male            2              67
# 426973  6024997  6024997      Female            2              58
# 426983  6025128  6025128      Female            2              64
# 426984  6025134  6025134        Male            2              64
# 427001  6025354  6025354      Female            2              52
#
# [95380 rows x 5 columns]

# %%
## remove IDs from cases who used medication based on Francescia report

# %%
medication = pd.read_csv("/mnt/vast/hpc/csg/en2509/Phenotype/IDs_used_medication_removed_ARHL.csv", quotechar = '"', dtype="int")
medication
# Out:
#           IID
# 0     1003108
# 1     1004336
# 2     1007149
# 3     1007824
# 4     1008132
# ...       ...
# 4035  5799083
# 4036  5800395
# 4037  5948042
# 4038  2517668
# 4039  4768640
#
# [4040 rows x 1 columns]

# %%
Both = filtered[filtered["f2247_f2257"] == 2][["FID", "IID", "f.22001.0.0", "f2247_f2257", "f2247_f2257_age"]]
Both_clean = Both[~Both.loc[:,'IID'].isin(medication['IID'])]
Both_clean
# Out:
#             FID      IID f.22001.0.0  f2247_f2257 f2247_f2257_age
# 0       1000022  1000022        Male            2              53
# 9       1000112  1000112        Male            2            68.0
# 14      1000170  1000170      Female            2              51
# 16      1000198  1000198      Female            2              41
# 17      1000203  1000203      Female            2              49
# ...         ...      ...         ...          ...             ...
# 426972  6024983  6024983        Male            2              67
# 426973  6024997  6024997      Female            2              58
# 426983  6025128  6025128      Female            2              64
# 426984  6025134  6025134        Male            2              64
# 427001  6025354  6025354      Female            2              52
#
# [95380 rows x 5 columns]

# %%
Both_clean['sex'] = 1 
Both_clean.loc[(Both_clean['f.22001.0.0'] == 'Female') , 'sex'] = 2
Both_clean
# Out:
#             FID      IID f.22001.0.0  f2247_f2257 f2247_f2257_age  sex
# 0       1000022  1000022        Male            2              53    1
# 9       1000112  1000112        Male            2            68.0    1
# 14      1000170  1000170      Female            2              51    2
# 16      1000198  1000198      Female            2              41    2
# 17      1000203  1000203      Female            2              49    2
# ...         ...      ...         ...          ...             ...  ...
# 426972  6024983  6024983        Male            2              67    1
# 426973  6024997  6024997      Female            2              58    2
# 426983  6025128  6025128      Female            2              64    2
# 426984  6025134  6025134        Male            2              64    1
# 427001  6025354  6025354      Female            2              52    2
#
# [95380 rows x 6 columns]

# %%
Both_clean['both'] = 1 
Both_clean
# Out:
#             FID      IID f.22001.0.0  f2247_f2257 f2247_f2257_age  sex  both
# 0       1000022  1000022        Male            2              53    1     1
# 9       1000112  1000112        Male            2            68.0    1     1
# 14      1000170  1000170      Female            2              51    2     1
# 16      1000198  1000198      Female            2              41    2     1
# 17      1000203  1000203      Female            2              49    2     1
# ...         ...      ...         ...          ...             ...  ...   ...
# 426972  6024983  6024983        Male            2              67    1     1
# 426973  6024997  6024997      Female            2              58    2     1
# 426983  6025128  6025128      Female            2              64    2     1
# 426984  6025134  6025134        Male            2              64    1     1
# 427001  6025354  6025354      Female            2              52    2     1
#
# [95380 rows x 7 columns]

# %%
aid = filtered[filtered["f3393"] == 1][["FID", "IID", "f.22001.0.0", "f3393", "f3393_age"]]
aid_clean = aid[~aid.loc[:,'IID'].isin(medication['IID'])]
aid_clean
# Out:
#             FID      IID f.22001.0.0  f3393 f3393_age
# 9       1000112  1000112        Male      1      68.0
# 43      1000551  1000551        Male      1      83.0
# 84      1001067  1001067        Male      1        50
# 114     1001384  1001384      Female      1        61
# 120     1001459  1001459        Male      1        64
# ...         ...      ...         ...    ...       ...
# 426726  6022050  6022050      Female      1        52
# 426772  6022567  6022567        Male      1      73.0
# 426824  6023186  6023186        Male      1        67
# 426857  6023568  6023568      Female      1        68
# 426984  6025134  6025134        Male      1        64
#
# [17389 rows x 5 columns]

# %%
aid_clean['sex'] = 1 
aid_clean.loc[(aid_clean['f.22001.0.0'] == 'Female') , 'sex'] = 2
aid_clean
# Out:
#             FID      IID f.22001.0.0  f3393 f3393_age  sex
# 9       1000112  1000112        Male      1      68.0    1
# 43      1000551  1000551        Male      1      83.0    1
# 84      1001067  1001067        Male      1        50    1
# 114     1001384  1001384      Female      1        61    2
# 120     1001459  1001459        Male      1        64    1
# ...         ...      ...         ...    ...       ...  ...
# 426726  6022050  6022050      Female      1        52    2
# 426772  6022567  6022567        Male      1      73.0    1
# 426824  6023186  6023186        Male      1        67    1
# 426857  6023568  6023568      Female      1        68    2
# 426984  6025134  6025134        Male      1        64    1
#
# [17389 rows x 6 columns]

# %%
diff = filtered[filtered["f2247"] == 1][["FID", "IID", "f.22001.0.0", "f2247", "f2247_age"]]
diff_clean = diff[~diff.loc[:,'IID'].isin(medication['IID'])]
diff_clean
# Out:
#             FID      IID f.22001.0.0  f2247 f2247_age
# 0       1000022  1000022        Male      1        53
# 7       1000090  1000090      Female      1        64
# 9       1000112  1000112        Male      1      68.0
# 14      1000170  1000170      Female      1        51
# 16      1000198  1000198      Female      1        41
# ...         ...      ...         ...    ...       ...
# 426972  6024983  6024983        Male      1        67
# 426973  6024997  6024997      Female      1        58
# 426983  6025128  6025128      Female      1        64
# 426984  6025134  6025134        Male      1        64
# 427001  6025354  6025354      Female      1        52
#
# [112495 rows x 5 columns]

# %%
diff_clean['sex'] = 1 
diff_clean.loc[(diff_clean['f.22001.0.0'] == 'Female') , 'sex'] = 2
diff_clean
# Out:
#             FID      IID f.22001.0.0  f2247 f2247_age  sex
# 0       1000022  1000022        Male      1        53    1
# 7       1000090  1000090      Female      1        64    2
# 9       1000112  1000112        Male      1      68.0    1
# 14      1000170  1000170      Female      1        51    2
# 16      1000198  1000198      Female      1        41    2
# ...         ...      ...         ...    ...       ...  ...
# 426972  6024983  6024983        Male      1        67    1
# 426973  6024997  6024997      Female      1        58    2
# 426983  6025128  6025128      Female      1        64    2
# 426984  6025134  6025134        Male      1        64    1
# 427001  6025354  6025354      Female      1        52    2
#
# [112495 rows x 6 columns]

# %%
noise = filtered[filtered["f2257"] == 1][["FID", "IID", "f.22001.0.0", "f2257", "f2257_age"]]
noise_clean = noise[~noise.loc[:,'IID'].isin(medication['IID'])]
noise_clean
# Out:
#             FID      IID f.22001.0.0  f2257 f2257_age
# 0       1000022  1000022        Male      1        53
# 1       1000035  1000035        Male      1        63
# 2       1000046  1000046      Female      1      73.0
# 3       1000054  1000054      Female      1        65
# 8       1000105  1000105      Female      1        54
# ...         ...      ...         ...    ...       ...
# 426998  6025322  6025322      Female      1        63
# 427000  6025346  6025346      Female      1      68.0
# 427001  6025354  6025354      Female      1        52
# 427003  6025378  6025378        Male      1        42
# 427004  6025390  6025390      Female      1        67
#
# [162855 rows x 5 columns]

# %%
noise_clean['sex'] = 1 
noise_clean.loc[(noise_clean['f.22001.0.0'] == 'Female') , 'sex'] = 2
noise_clean
# Out:
#             FID      IID f.22001.0.0  f2257 f2257_age  sex
# 0       1000022  1000022        Male      1        53    1
# 1       1000035  1000035        Male      1        63    1
# 2       1000046  1000046      Female      1      73.0    2
# 3       1000054  1000054      Female      1        65    2
# 8       1000105  1000105      Female      1        54    2
# ...         ...      ...         ...    ...       ...  ...
# 426998  6025322  6025322      Female      1        63    2
# 427000  6025346  6025346      Female      1      68.0    2
# 427001  6025354  6025354      Female      1        52    2
# 427003  6025378  6025378        Male      1        42    1
# 427004  6025390  6025390      Female      1        67    2
#
# [162855 rows x 6 columns]

# %%
Both_clean_2 = Both_clean[["FID", "IID", "both", "f2247_f2257_age", "sex"]]
Both_clean_2
# Out:
#             FID      IID  both f2247_f2257_age  sex
# 0       1000022  1000022     1              53    1
# 9       1000112  1000112     1            68.0    1
# 14      1000170  1000170     1              51    2
# 16      1000198  1000198     1              41    2
# 17      1000203  1000203     1              49    2
# ...         ...      ...   ...             ...  ...
# 426972  6024983  6024983     1              67    1
# 426973  6024997  6024997     1              58    2
# 426983  6025128  6025128     1              64    2
# 426984  6025134  6025134     1              64    1
# 427001  6025354  6025354     1              52    2
#
# [95380 rows x 5 columns]

# %%
Both_clean_2.to_csv("f2247_f2257_pheno_file_DMCS.tsv", sep='\t', index=False)

# %%
aid_clean_2 = aid_clean [["FID", "IID", "f3393", "f3393_age", "sex"]]
aid_clean_2
# Out:
#             FID      IID  f3393 f3393_age  sex
# 9       1000112  1000112      1      68.0    1
# 43      1000551  1000551      1      83.0    1
# 84      1001067  1001067      1        50    1
# 114     1001384  1001384      1        61    2
# 120     1001459  1001459      1        64    1
# ...         ...      ...    ...       ...  ...
# 426726  6022050  6022050      1        52    2
# 426772  6022567  6022567      1      73.0    1
# 426824  6023186  6023186      1        67    1
# 426857  6023568  6023568      1        68    2
# 426984  6025134  6025134      1        64    1
#
# [17389 rows x 5 columns]

# %%
aid_clean_2.to_csv("f3393_pheno_file_DMCS.tsv", sep='\t', index=False)

# %%
diff_clean_2 = diff_clean [["FID", "IID", "f2247", "f2247_age", "sex"]]
diff_clean_2
# Out:
#             FID      IID  f2247 f2247_age  sex
# 0       1000022  1000022      1        53    1
# 7       1000090  1000090      1        64    2
# 9       1000112  1000112      1      68.0    1
# 14      1000170  1000170      1        51    2
# 16      1000198  1000198      1        41    2
# ...         ...      ...    ...       ...  ...
# 426972  6024983  6024983      1        67    1
# 426973  6024997  6024997      1        58    2
# 426983  6025128  6025128      1        64    2
# 426984  6025134  6025134      1        64    1
# 427001  6025354  6025354      1        52    2
#
# [112495 rows x 5 columns]

# %%
diff_clean_2.to_csv("f2247_pheno_file_DMCS.tsv", sep='\t', index=False)

# %%
noise_clean_2 = noise_clean [["FID", "IID", "f2257", "f2257_age", "sex"]]
noise_clean_2
# Out:
#             FID      IID  f2257 f2257_age  sex
# 0       1000022  1000022      1        53    1
# 1       1000035  1000035      1        63    1
# 2       1000046  1000046      1      73.0    2
# 3       1000054  1000054      1        65    2
# 8       1000105  1000105      1        54    2
# ...         ...      ...    ...       ...  ...
# 426998  6025322  6025322      1        63    2
# 427000  6025346  6025346      1      68.0    2
# 427001  6025354  6025354      1        52    2
# 427003  6025378  6025378      1        42    1
# 427004  6025390  6025390      1        67    2
#
# [162855 rows x 5 columns]

# %%
noise_clean_2.to_csv("f2257_pheno_file_DMCS.tsv", sep='\t', index=False)

# %%
#diff.isnull().sum()

# %%
#diff['f2247_f2257_age'].min()

# %%
#diff['f2247_age'].value_counts(dropna=False)

# %% [markdown]
# ## Combine pheno files and control

# %%
ctrl_file_name = "pure_ctrl_pheno_file_DMCS.tsv"
f3393_file_name = "f3393_pheno_file_DMCS.tsv"
f2247_file_name = "f2247_pheno_file_DMCS.tsv"
f2257_file_name = "f2257_pheno_file_DMCS.tsv"
f2247_f2257_file_name = "f2247_f2257_pheno_file_DMCS.tsv"

# %%
f3393 = pd.read_csv(f3393_file_name, sep="\t")
f2247 = pd.read_csv(f2247_file_name, sep="\t")
f2257 = pd.read_csv(f2257_file_name, sep="\t")
f2247_f2257 = pd.read_csv(f2247_f2257_file_name, sep="\t")

# %%
ctrl = pd.read_csv(ctrl_file_name, sep="\t")

# %%
print("ctrl: ",len(ctrl))
print("f2247: ",len(f2247))
print("f2257: ",len(f2257))
print("f2247_f2257: ",len(f2247_f2257))
print("f3393: ",len(f3393))
# Out:
# ctrl:  234172
# f2247:  112495
# f2257:  162855
# f2247_f2257:  95380
# f3393:  17389

# %% [markdown]
# ### Final file f2257

# %%
f2257
# Out:
#             FID      IID  f2257  f2257_age  sex
# 0       1000022  1000022      1       53.0    1
# 1       1000035  1000035      1       63.0    1
# 2       1000046  1000046      1       73.0    2
# 3       1000054  1000054      1       65.0    2
# 4       1000105  1000105      1       54.0    2
# ...         ...      ...    ...        ...  ...
# 162850  6025322  6025322      1       63.0    2
# 162851  6025346  6025346      1       68.0    2
# 162852  6025354  6025354      1       52.0    2
# 162853  6025378  6025378      1       42.0    1
# 162854  6025390  6025390      1       67.0    2
#
# [162855 rows x 5 columns]

# %%
ctrl
# Out:
#             FID      IID  hearing_imp_pure_ctrl  ctrl_age  sex
# 0       1000063  1000063                      0      43.0    1
# 1       1000078  1000078                      0      60.0    2
# 2       1000081  1000081                      0      67.0    1
# 3       1000129  1000129                      0      62.0    1
# 4       1000137  1000137                      0      46.0    2
# ...         ...      ...                    ...       ...  ...
# 234167  6025363  6025363                      0      64.0    1
# 234168  6025409  6025409                      0      66.0    2
# 234169  6025411  6025411                      0      49.0    2
# 234170  6025425  6025425                      0      44.0    2
# 234171  6025438  6025438                      0      55.0    1
#
# [234172 rows x 5 columns]

# %%
ctrl_2257 = ctrl.rename(columns={"hearing_imp_pure_ctrl":"f2257", "ctrl_age":"age"})
ctrl_2257
# Out:
#             FID      IID  f2257   age  sex
# 0       1000063  1000063      0  43.0    1
# 1       1000078  1000078      0  60.0    2
# 2       1000081  1000081      0  67.0    1
# 3       1000129  1000129      0  62.0    1
# 4       1000137  1000137      0  46.0    2
# ...         ...      ...    ...   ...  ...
# 234167  6025363  6025363      0  64.0    1
# 234168  6025409  6025409      0  66.0    2
# 234169  6025411  6025411      0  49.0    2
# 234170  6025425  6025425      0  44.0    2
# 234171  6025438  6025438      0  55.0    1
#
# [234172 rows x 5 columns]

# %%
f2257 = f2257.rename(columns={"f2257_age":"age"})
f2257
# Out:
#             FID      IID  f2257   age  sex
# 0       1000022  1000022      1  53.0    1
# 1       1000035  1000035      1  63.0    1
# 2       1000046  1000046      1  73.0    2
# 3       1000054  1000054      1  65.0    2
# 4       1000105  1000105      1  54.0    2
# ...         ...      ...    ...   ...  ...
# 162850  6025322  6025322      1  63.0    2
# 162851  6025346  6025346      1  68.0    2
# 162852  6025354  6025354      1  52.0    2
# 162853  6025378  6025378      1  42.0    1
# 162854  6025390  6025390      1  67.0    2
#
# [162855 rows x 5 columns]

# %%
full_pheno_2257 = f2257.append(ctrl_2257)
full_pheno_2257
# Out:
#             FID      IID  f2257   age  sex
# 0       1000022  1000022      1  53.0    1
# 1       1000035  1000035      1  63.0    1
# 2       1000046  1000046      1  73.0    2
# 3       1000054  1000054      1  65.0    2
# 4       1000105  1000105      1  54.0    2
# ...         ...      ...    ...   ...  ...
# 234167  6025363  6025363      0  64.0    1
# 234168  6025409  6025409      0  66.0    2
# 234169  6025411  6025411      0  49.0    2
# 234170  6025425  6025425      0  44.0    2
# 234171  6025438  6025438      0  55.0    1
#
# [397027 rows x 5 columns]

# %%
## reading array info
array = pd.read_csv("/mnt/vast/hpc/csg/en2509/X_chr/UKBB_Genotype_array", sep='\t')
array
# Out:
#             FID      IID  array
# 0       1000019  1000019      1
# 1       1000022  1000022      1
# 2       1000035  1000035      1
# 3       1000046  1000046      1
# 4       1000054  1000054      2
# ...         ...      ...    ...
# 486411  6025390  6025390      1
# 486412  6025409  6025409      1
# 486413  6025411  6025411      2
# 486414  6025425  6025425      1
# 486415  6025438  6025438      1
#
# [486416 rows x 3 columns]

# %%
merged_2257 = pd.merge(left=full_pheno, right=array, left_on=['IID','FID'], right_on=['IID','FID'])
merged_2257
# Out:
#             FID      IID  f2257   age  sex  array
# 0       1000022  1000022      1  53.0    1      1
# 1       1000035  1000035      1  63.0    1      1
# 2       1000046  1000046      1  73.0    2      1
# 3       1000054  1000054      1  65.0    2      2
# 4       1000105  1000105      1  54.0    2      1
# ...         ...      ...    ...   ...  ...    ...
# 397022  6025363  6025363      0  64.0    1      1
# 397023  6025409  6025409      0  66.0    2      1
# 397024  6025411  6025411      0  49.0    2      2
# 397025  6025425  6025425      0  44.0    2      1
# 397026  6025438  6025438      0  55.0    1      1
#
# [397027 rows x 6 columns]

# %%
merged_2257[["FID", "IID","f2257", "age", "sex", "array"]].to_csv("072423_UKBB_Hnoise_f2257_expandedwhite_DMCS_397027ind.tsv", sep='\t', index=False)

# %%
# Create the phenofile for PCA
merged_2257['ethnicity']='white_european'
merged_2257
merged_2257[["FID", "IID", "ethnicity"]].to_csv("072423_UKBB_Hnoise_f2257_expandedwhite_DMCS_397027ind.phenopca", sep='\t', index=False)

# %%
merged_2257[["FID", "IID","f2257", "age", "sex", "array"]].to_csv("072423_UKBB_Hnoise_f2257_expandedwhite_DMCS_397027ind.tsv", sep='\t', index=False)

# %% [markdown]
# ### Final file f3393

# %%
ctrl_3393 = ctrl.rename(columns={"hearing_imp_pure_ctrl":"f3393", "ctrl_age":"age"})
ctrl_3393
# Out:
#             FID      IID  f3393   age  sex
# 0       1000063  1000063      0  43.0    1
# 1       1000078  1000078      0  60.0    2
# 2       1000081  1000081      0  67.0    1
# 3       1000129  1000129      0  62.0    1
# 4       1000137  1000137      0  46.0    2
# ...         ...      ...    ...   ...  ...
# 234167  6025363  6025363      0  64.0    1
# 234168  6025409  6025409      0  66.0    2
# 234169  6025411  6025411      0  49.0    2
# 234170  6025425  6025425      0  44.0    2
# 234171  6025438  6025438      0  55.0    1
#
# [234172 rows x 5 columns]

# %%
f3393= f3393.rename(columns={"f3393_age":"age"})
f3393
# Out:
#            FID      IID  f3393   age  sex
# 0      1000112  1000112      1  68.0    1
# 1      1000551  1000551      1  83.0    1
# 2      1001067  1001067      1  50.0    1
# 3      1001384  1001384      1  61.0    2
# 4      1001459  1001459      1  64.0    1
# ...        ...      ...    ...   ...  ...
# 17384  6022050  6022050      1  52.0    2
# 17385  6022567  6022567      1  73.0    1
# 17386  6023186  6023186      1  67.0    1
# 17387  6023568  6023568      1  68.0    2
# 17388  6025134  6025134      1  64.0    1
#
# [17389 rows x 5 columns]

# %%
full_pheno_3393 = f3393.append(ctrl_3393)
full_pheno_3393
# Out:
#             FID      IID  f3393   age  sex
# 0       1000112  1000112      1  68.0    1
# 1       1000551  1000551      1  83.0    1
# 2       1001067  1001067      1  50.0    1
# 3       1001384  1001384      1  61.0    2
# 4       1001459  1001459      1  64.0    1
# ...         ...      ...    ...   ...  ...
# 234167  6025363  6025363      0  64.0    1
# 234168  6025409  6025409      0  66.0    2
# 234169  6025411  6025411      0  49.0    2
# 234170  6025425  6025425      0  44.0    2
# 234171  6025438  6025438      0  55.0    1
#
# [251561 rows x 5 columns]

# %%
merged_3393 = pd.merge(left=full_pheno_3393, right=array, left_on=['IID','FID'], right_on=['IID','FID'])
merged_3393
# Out:
#             FID      IID  f3393   age  sex  array
# 0       1000112  1000112      1  68.0    1      1
# 1       1000551  1000551      1  83.0    1      1
# 2       1001067  1001067      1  50.0    1      1
# 3       1001384  1001384      1  61.0    2      1
# 4       1001459  1001459      1  64.0    1      1
# ...         ...      ...    ...   ...  ...    ...
# 251556  6025363  6025363      0  64.0    1      1
# 251557  6025409  6025409      0  66.0    2      1
# 251558  6025411  6025411      0  49.0    2      2
# 251559  6025425  6025425      0  44.0    2      1
# 251560  6025438  6025438      0  55.0    1      1
#
# [251561 rows x 6 columns]

# %%
merged_3393['ethnicity']='white_european'
merged_3393
merged_3393[["FID", "IID" "ethnicity"]].to_csv("072423_UKBB_Haid_f3393_expandedwhite_DMCS_251561ind.phenopca", sep='\t', index=False)

# %%
merged_3393[["FID", "IID","f3393", "age", "sex", "array"]].to_csv("072423_UKBB_Haid_f3393_expandedwhite_DMCS_251561ind.tsv", sep='\t', index=False)

# %% [markdown]
# ### Final file f2247

# %%
ctrl_2247 = ctrl.rename(columns={"hearing_imp_pure_ctrl":"f2247", "ctrl_age":"age"})
ctrl_2247
# Out:
#             FID      IID  f2247   age  sex
# 0       1000063  1000063      0  43.0    1
# 1       1000078  1000078      0  60.0    2
# 2       1000081  1000081      0  67.0    1
# 3       1000129  1000129      0  62.0    1
# 4       1000137  1000137      0  46.0    2
# ...         ...      ...    ...   ...  ...
# 234167  6025363  6025363      0  64.0    1
# 234168  6025409  6025409      0  66.0    2
# 234169  6025411  6025411      0  49.0    2
# 234170  6025425  6025425      0  44.0    2
# 234171  6025438  6025438      0  55.0    1
#
# [234172 rows x 5 columns]

# %%
f2247= f2247.rename(columns={"f2247_age":"age"})
f2247
# Out:
#             FID      IID  f2247   age  sex
# 0       1000022  1000022      1  53.0    1
# 1       1000090  1000090      1  64.0    2
# 2       1000112  1000112      1  68.0    1
# 3       1000170  1000170      1  51.0    2
# 4       1000198  1000198      1  41.0    2
# ...         ...      ...    ...   ...  ...
# 112490  6024983  6024983      1  67.0    1
# 112491  6024997  6024997      1  58.0    2
# 112492  6025128  6025128      1  64.0    2
# 112493  6025134  6025134      1  64.0    1
# 112494  6025354  6025354      1  52.0    2
#
# [112495 rows x 5 columns]

# %%
full_pheno_2247 = f2247.append(ctrl_2247)
full_pheno_2247
# Out:
#             FID      IID  f2247   age  sex
# 0       1000022  1000022      1  53.0    1
# 1       1000090  1000090      1  64.0    2
# 2       1000112  1000112      1  68.0    1
# 3       1000170  1000170      1  51.0    2
# 4       1000198  1000198      1  41.0    2
# ...         ...      ...    ...   ...  ...
# 234167  6025363  6025363      0  64.0    1
# 234168  6025409  6025409      0  66.0    2
# 234169  6025411  6025411      0  49.0    2
# 234170  6025425  6025425      0  44.0    2
# 234171  6025438  6025438      0  55.0    1
#
# [346667 rows x 5 columns]

# %%
merged_2247 = pd.merge(left=full_pheno_2247, right=array, left_on=['IID','FID'], right_on=['IID','FID'])
merged_2247
# Out:
#             FID      IID  f2247   age  sex  array
# 0       1000022  1000022      1  53.0    1      1
# 1       1000090  1000090      1  64.0    2      1
# 2       1000112  1000112      1  68.0    1      1
# 3       1000170  1000170      1  51.0    2      2
# 4       1000198  1000198      1  41.0    2      1
# ...         ...      ...    ...   ...  ...    ...
# 346662  6025363  6025363      0  64.0    1      1
# 346663  6025409  6025409      0  66.0    2      1
# 346664  6025411  6025411      0  49.0    2      2
# 346665  6025425  6025425      0  44.0    2      1
# 346666  6025438  6025438      0  55.0    1      1
#
# [346667 rows x 6 columns]

# %%
merged_2247['ethnicity']='white_european'
merged_2247
merged_2247[["FID", "IID","ethnicity"]].to_csv("072423_UKBB_Hdiff_2247_expandedwhite_DMCS_346667ind.phenopca", sep='\t', index=False)

# %%
merged_2247[["FID", "IID","f2247", "age", "sex", "array"]].to_csv("072423_UKBB_Hdiff_2247_expandedwhite_DMCS_346667ind.tsv", sep='\t', index=False)

# %% [markdown]
# ### Final file f2247_2257

# %%
ctrl_2247_2257 = ctrl.rename(columns={"hearing_imp_pure_ctrl":"f2247_f2257", "ctrl_age":"age"})
ctrl_2247_2257
# Out:
#             FID      IID  f2247_f2257   age  sex
# 0       1000063  1000063            0  43.0    1
# 1       1000078  1000078            0  60.0    2
# 2       1000081  1000081            0  67.0    1
# 3       1000129  1000129            0  62.0    1
# 4       1000137  1000137            0  46.0    2
# ...         ...      ...          ...   ...  ...
# 234167  6025363  6025363            0  64.0    1
# 234168  6025409  6025409            0  66.0    2
# 234169  6025411  6025411            0  49.0    2
# 234170  6025425  6025425            0  44.0    2
# 234171  6025438  6025438            0  55.0    1
#
# [234172 rows x 5 columns]

# %%
f2247_f2257 = f2247_f2257.rename(columns={"f2247_f2257_age":"age", "both":"f2247_f2257"})
f2247_f2257
# Out:
#            FID      IID  f2247_f2257   age  sex
# 0      1000022  1000022            1  53.0    1
# 1      1000112  1000112            1  68.0    1
# 2      1000170  1000170            1  51.0    2
# 3      1000198  1000198            1  41.0    2
# 4      1000203  1000203            1  49.0    2
# ...        ...      ...          ...   ...  ...
# 95375  6024983  6024983            1  67.0    1
# 95376  6024997  6024997            1  58.0    2
# 95377  6025128  6025128            1  64.0    2
# 95378  6025134  6025134            1  64.0    1
# 95379  6025354  6025354            1  52.0    2
#
# [95380 rows x 5 columns]

# %%
full_pheno_2247_2257 = f2247_f2257.append(ctrl_2247_2257)
full_pheno_2247_2257
# Out:
#             FID      IID  f2247_f2257   age  sex
# 0       1000022  1000022            1  53.0    1
# 1       1000112  1000112            1  68.0    1
# 2       1000170  1000170            1  51.0    2
# 3       1000198  1000198            1  41.0    2
# 4       1000203  1000203            1  49.0    2
# ...         ...      ...          ...   ...  ...
# 234167  6025363  6025363            0  64.0    1
# 234168  6025409  6025409            0  66.0    2
# 234169  6025411  6025411            0  49.0    2
# 234170  6025425  6025425            0  44.0    2
# 234171  6025438  6025438            0  55.0    1
#
# [329552 rows x 5 columns]

# %%
merged_2247_2257 = pd.merge(left=full_pheno_2247_2257, right=array, left_on=['IID','FID'], right_on=['IID','FID'])
merged_2247_2257
# Out:
#             FID      IID  f2247_f2257   age  sex  array
# 0       1000022  1000022            1  53.0    1      1
# 1       1000112  1000112            1  68.0    1      1
# 2       1000170  1000170            1  51.0    2      2
# 3       1000198  1000198            1  41.0    2      1
# 4       1000203  1000203            1  49.0    2      1
# ...         ...      ...          ...   ...  ...    ...
# 329547  6025363  6025363            0  64.0    1      1
# 329548  6025409  6025409            0  66.0    2      1
# 329549  6025411  6025411            0  49.0    2      2
# 329550  6025425  6025425            0  44.0    2      1
# 329551  6025438  6025438            0  55.0    1      1
#
# [329552 rows x 6 columns]

# %%
merged_2247_2257['ethnicity']='white_european'
merged_2247_2257
merged_2247_2257[["FID", "IID","ethnicity"]].to_csv("072423_UKBB_Hboth_2247_2257_expandedwhite_DMCS_329552ind.phenopca", sep='\t', index=False)

# %%
merged_2247_2257[["FID", "IID","f2247_f2257", "age", "sex", "array"]].to_csv("072423_UKBB_Hboth_2247_2257_expandedwhite_DMCS_329552ind.tsv", sep='\t', index=False)

# %% [markdown]
# ## Seperate Males and Females

# %% [markdown]
# ### Hnoise

# %%
merged_2257 = pd.read_csv("072423_UKBB_Hnoise_f2257_expandedwhite_DMCS_397027ind.tsv", sep='\t')
merged_2257
# Out:
#             FID      IID  f2257   age  sex  array
# 0       1000022  1000022      1  53.0    1      1
# 1       1000035  1000035      1  63.0    1      1
# 2       1000046  1000046      1  73.0    2      1
# 3       1000054  1000054      1  65.0    2      2
# 4       1000105  1000105      1  54.0    2      1
# ...         ...      ...    ...   ...  ...    ...
# 397022  6025363  6025363      0  64.0    1      1
# 397023  6025409  6025409      0  66.0    2      1
# 397024  6025411  6025411      0  49.0    2      2
# 397025  6025425  6025425      0  44.0    2      1
# 397026  6025438  6025438      0  55.0    1      1
#
# [397027 rows x 6 columns]

# %%
males = merged_2257["sex"] == 1

# %%
Hnoise_males = merged_2257[males]
Hnoise_males
# Out:
#             FID      IID  f2257   age  sex  array
# 0       1000022  1000022      1  53.0    1      1
# 1       1000035  1000035      1  63.0    1      1
# 5       1000112  1000112      1  68.0    1      1
# 11      1000318  1000318      1  52.0    1      2
# 12      1000396  1000396      1  48.0    1      1
# ...         ...      ...    ...   ...  ...    ...
# 397017  6025251  6025251      0  56.0    1      1
# 397018  6025268  6025268      0  65.0    1      2
# 397021  6025335  6025335      0  62.0    1      1
# 397022  6025363  6025363      0  64.0    1      1
# 397026  6025438  6025438      0  55.0    1      1
#
# [180590 rows x 6 columns]

# %%
Hnoise_males[["FID", "IID","f2257", "age", "array"]].to_csv("072423_UKBB_Hnoise_f2257_expandedwhite_DMCS_males_180590ind.tsv", sep='\t', index=False)

# %%
females = merged_2257["sex"] ==2
Hnoise_females = merged_2257[females]
Hnoise_females
# Out:
#             FID      IID  f2257   age  sex  array
# 2       1000046  1000046      1  73.0    2      1
# 3       1000054  1000054      1  65.0    2      2
# 4       1000105  1000105      1  54.0    2      1
# 6       1000164  1000164      1  51.0    2      1
# 7       1000170  1000170      1  51.0    2      2
# ...         ...      ...    ...   ...  ...    ...
# 397019  6025307  6025307      0  55.0    2      2
# 397020  6025319  6025319      0  56.0    2      1
# 397023  6025409  6025409      0  66.0    2      1
# 397024  6025411  6025411      0  49.0    2      2
# 397025  6025425  6025425      0  44.0    2      1
#
# [216437 rows x 6 columns]

# %%
Hnoise_females[["FID", "IID","f2257", "age", "array"]].to_csv("072423_UKBB_Hnoise_f2257_expandedwhite_DMCS_females_216437ind.tsv", sep='\t', index=False)

# %% [markdown]
# ### Haid

# %%
merged_3393 = pd.read_csv("072423_UKBB_Haid_f3393_expandedwhite_DMCS_251561ind.tsv", sep='\t')
merged_3393
# Out:
#             FID      IID  f3393   age  sex  array
# 0       1000112  1000112      1  68.0    1      1
# 1       1000551  1000551      1  83.0    1      1
# 2       1001067  1001067      1  50.0    1      1
# 3       1001384  1001384      1  61.0    2      1
# 4       1001459  1001459      1  64.0    1      1
# ...         ...      ...    ...   ...  ...    ...
# 251556  6025363  6025363      0  64.0    1      1
# 251557  6025409  6025409      0  66.0    2      1
# 251558  6025411  6025411      0  49.0    2      2
# 251559  6025425  6025425      0  44.0    2      1
# 251560  6025438  6025438      0  55.0    1      1
#
# [251561 rows x 6 columns]

# %%
males = merged_3393["sex"] == 1
Haid_males = merged_3393[males]
Haid_males
# Out:
#             FID      IID  f3393   age  sex  array
# 0       1000112  1000112      1  68.0    1      1
# 1       1000551  1000551      1  83.0    1      1
# 2       1001067  1001067      1  50.0    1      1
# 4       1001459  1001459      1  64.0    1      1
# 6       1002216  1002216      1  62.0    1      2
# ...         ...      ...    ...   ...  ...    ...
# 251551  6025251  6025251      0  56.0    1      1
# 251552  6025268  6025268      0  65.0    1      2
# 251555  6025335  6025335      0  62.0    1      1
# 251556  6025363  6025363      0  64.0    1      1
# 251560  6025438  6025438      0  55.0    1      1
#
# [103695 rows x 6 columns]

# %%
Haid_males[["FID", "IID","f3393", "age", "array"]].to_csv("072423_UKBB_Haid_f3393_expandedwhite_DMCS_males_103695ind.tsv", sep='\t', index=False)

# %%
females = merged_3393["sex"] ==2
Haid_females = merged_3393[females]
Haid_females
# Out:
#             FID      IID  f3393   age  sex  array
# 3       1001384  1001384      1  61.0    2      1
# 5       1001941  1001941      1  69.0    2      1
# 8       1002806  1002806      1  72.0    2      1
# 12      1003570  1003570      1  73.0    2      1
# 13      1004012  1004012      1  57.0    2      1
# ...         ...      ...    ...   ...  ...    ...
# 251553  6025307  6025307      0  55.0    2      2
# 251554  6025319  6025319      0  56.0    2      1
# 251557  6025409  6025409      0  66.0    2      1
# 251558  6025411  6025411      0  49.0    2      2
# 251559  6025425  6025425      0  44.0    2      1
#
# [147866 rows x 6 columns]

# %%
Haid_females[["FID", "IID","f3393", "age", "array"]].to_csv("072423_UKBB_Haid_f3393_expandedwhite_DMCS_females_147866ind.tsv", sep='\t', index=False)

# %% [markdown]
# ### Hdiff

# %%
merged_2247 = pd.read_csv("072423_UKBB_Hdiff_2247_expandedwhite_DMCS_346667ind.tsv", sep='\t')
merged_2247
# Out:
#             FID      IID  f2247   age  sex  array
# 0       1000022  1000022      1  53.0    1      1
# 1       1000090  1000090      1  64.0    2      1
# 2       1000112  1000112      1  68.0    1      1
# 3       1000170  1000170      1  51.0    2      2
# 4       1000198  1000198      1  41.0    2      1
# ...         ...      ...    ...   ...  ...    ...
# 346662  6025363  6025363      0  64.0    1      1
# 346663  6025409  6025409      0  66.0    2      1
# 346664  6025411  6025411      0  49.0    2      2
# 346665  6025425  6025425      0  44.0    2      1
# 346666  6025438  6025438      0  55.0    1      1
#
# [346667 rows x 6 columns]

# %%
males = merged_2247["sex"] == 1
Hdiff_males = merged_2247[males]
Hdiff_males
# Out:
#             FID      IID  f2247   age  sex  array
# 0       1000022  1000022      1  53.0    1      1
# 2       1000112  1000112      1  68.0    1      1
# 6       1000396  1000396      1  48.0    1      1
# 7       1000494  1000494      1  61.0    1      1
# 8       1000549  1000549      1  63.0    1      1
# ...         ...      ...    ...   ...  ...    ...
# 346657  6025251  6025251      0  56.0    1      1
# 346658  6025268  6025268      0  65.0    1      2
# 346661  6025335  6025335      0  62.0    1      1
# 346662  6025363  6025363      0  64.0    1      1
# 346666  6025438  6025438      0  55.0    1      1
#
# [156117 rows x 6 columns]

# %%
Hdiff_males[["FID", "IID","f2247", "age", "array"]].to_csv("072423_UKBB_Hdiff_2247_expandedwhite_DMCS_males_156117ind.tsv", sep='\t', index=False)

# %%
females = merged_2247["sex"] ==2
Hdiff_females = merged_2247[females]
Hdiff_females
# Out:
#             FID      IID  f2247   age  sex  array
# 1       1000090  1000090      1  64.0    2      1
# 3       1000170  1000170      1  51.0    2      2
# 4       1000198  1000198      1  41.0    2      1
# 5       1000203  1000203      1  49.0    2      1
# 14      1001052  1001052      1  64.0    2      1
# ...         ...      ...    ...   ...  ...    ...
# 346659  6025307  6025307      0  55.0    2      2
# 346660  6025319  6025319      0  56.0    2      1
# 346663  6025409  6025409      0  66.0    2      1
# 346664  6025411  6025411      0  49.0    2      2
# 346665  6025425  6025425      0  44.0    2      1
#
# [190550 rows x 6 columns]

# %%
Hdiff_females[["FID", "IID","f2247", "age", "array"]].to_csv("072423_UKBB_Hdiff_2247_expandedwhite_DMCS_females_190550ind.tsv", sep='\t', index=False)

# %% [markdown]
# ### Hboth

# %%
merged_2247_2257 = pd.read_csv("072423_UKBB_Hboth_2247_2257_expandedwhite_DMCS_329552ind.tsv", sep='\t')
merged_2247_2257
# Out:
#             FID      IID  f2247_f2257   age  sex  array
# 0       1000022  1000022            1  53.0    1      1
# 1       1000112  1000112            1  68.0    1      1
# 2       1000170  1000170            1  51.0    2      2
# 3       1000198  1000198            1  41.0    2      1
# 4       1000203  1000203            1  49.0    2      1
# ...         ...      ...          ...   ...  ...    ...
# 329547  6025363  6025363            0  64.0    1      1
# 329548  6025409  6025409            0  66.0    2      1
# 329549  6025411  6025411            0  49.0    2      2
# 329550  6025425  6025425            0  44.0    2      1
# 329551  6025438  6025438            0  55.0    1      1
#
# [329552 rows x 6 columns]

# %%
males = merged_2247_2257["sex"] == 1
Hboth_males = merged_2247_2257[males]
Hboth_males
# Out:
#             FID      IID  f2247_f2257   age  sex  array
# 0       1000022  1000022            1  53.0    1      1
# 1       1000112  1000112            1  68.0    1      1
# 5       1000396  1000396            1  48.0    1      1
# 6       1000494  1000494            1  61.0    1      1
# 7       1000549  1000549            1  63.0    1      1
# ...         ...      ...          ...   ...  ...    ...
# 329542  6025251  6025251            0  56.0    1      1
# 329543  6025268  6025268            0  65.0    1      2
# 329546  6025335  6025335            0  62.0    1      1
# 329547  6025363  6025363            0  64.0    1      1
# 329551  6025438  6025438            0  55.0    1      1
#
# [147404 rows x 6 columns]

# %%
Hboth_males[["FID", "IID","f2247_f2257", "age", "array"]].to_csv("072423_UKBB_Hboth_2247_2257_expandedwhite_DMCS_males_147404ind.tsv", sep='\t', index=False)

# %%
females = merged_2247_2257["sex"] ==2
Hboth_females = merged_2247_2257[females]
Hboth_females
# Out:
#             FID      IID  f2247_f2257   age  sex  array
# 2       1000170  1000170            1  51.0    2      2
# 3       1000198  1000198            1  41.0    2      1
# 4       1000203  1000203            1  49.0    2      1
# 14      1001099  1001099            1  62.0    2      1
# 15      1001123  1001123            1  62.0    2      1
# ...         ...      ...          ...   ...  ...    ...
# 329544  6025307  6025307            0  55.0    2      2
# 329545  6025319  6025319            0  56.0    2      1
# 329548  6025409  6025409            0  66.0    2      1
# 329549  6025411  6025411            0  49.0    2      2
# 329550  6025425  6025425            0  44.0    2      1
#
# [182148 rows x 6 columns]

# %%
Hboth_females[["FID", "IID","f2247_f2257", "age", "array"]].to_csv("072423_UKBB_Hboth_2247_2257_expandedwhite_DMCS_females_182148ind.tsv", sep='\t', index=False)

# %% [markdown]
# # After this section belongs to Elnaz other codes
#
# ## Making pheno files for unrelated white European individuals

# %%
Hdiff = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Hdiff_F2247_4PCs_All.pheno', delimiter=' ')
Hdiff
# Out:
#             FID      IID  f2247  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 4       1000090  1000090      1   64    2      1 -0.017105  0.017367
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 346094  6024909  6024909      1   49    2      1 -0.012714  0.006905
# 346095  6025004  6025004      0   70    2      1  0.000891  0.002434
# 346096  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 346097  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 346098  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 4      -0.040881  0.004871
# ...          ...       ...
# 346094 -0.003829 -0.011212
# 346095 -0.011637  0.005646
# 346096 -0.001599 -0.004673
# 346097 -0.008309  0.013414
# 346098 -0.009647  0.005814
#
# [346099 rows x 10 columns]

# %%
Unrelated = pd.read_csv('/mnt/vast/hpc/csg/en2509/Rsq_imputation/European/Unrelated_EU_afterPCA_updated_353088ind.txt', delimiter='\t')
Unrelated
# Out:
#             FID      IID
# 0       1000022  1000022
# 1       1000046  1000046
# 2       1000063  1000063
# 3       1000078  1000078
# 4       1000081  1000081
# ...         ...      ...
# 353083  6020607  6020607
# 353084  6022039  6022039
# 353085  6023046  6023046
# 353086  6023549  6023549
# 353087  6024665  6024665
#
# [353088 rows x 2 columns]

# %%
Hnoise = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Hnoise_F2257_4PCs_All.pheno', delimiter=' ')
Hnoise
# Out:
#             FID      IID  f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000046  1000046      1   73    2      1 -0.009498  0.004089
# 2       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 3       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 4       1000081  1000081      0   67    1      1  0.118118 -0.047693
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 397145  6025004  6025004      0   70    2      1  0.000891  0.002434
# 397146  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 397147  6025322  6025322      1   63    2      1 -0.003041  0.028747
# 397148  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 397149  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1      -0.012498  0.008941
# 2       0.011446  0.004137
# 3       0.012004 -0.000638
# 4      -0.002693  0.010003
# ...          ...       ...
# 397145 -0.011637  0.005646
# 397146 -0.001599 -0.004673
# 397147 -0.009047  0.003363
# 397148 -0.008309  0.013414
# 397149 -0.009647  0.005814
#
# [397150 rows x 10 columns]

# %%
Hboth = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Hboth_F2247_F2257_4PCs_All.pheno', delimiter=' ')
Hboth
# Out:
#             FID      IID  f2247_f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022            1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063            0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078            0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081            0   67    1      1  0.118118 -0.047693
# 4       1000112  1000112            1   68    1      1 -0.006373  0.009384
# ...         ...      ...          ...  ...  ...    ...       ...       ...
# 329117  6024909  6024909            1   49    2      1 -0.012714  0.006905
# 329118  6025004  6025004            0   70    2      1  0.000891  0.002434
# 329119  6025167  6025167            0   52    2      1 -0.001835  0.013914
# 329120  6025425  6025425            0   44    2      1  0.019182 -0.014949
# 329121  6025438  6025438            0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 4      -0.030781  0.006168
# ...          ...       ...
# 329117 -0.003829 -0.011212
# 329118 -0.011637  0.005646
# 329119 -0.001599 -0.004673
# 329120 -0.008309  0.013414
# 329121 -0.009647  0.005814
#
# [329122 rows x 10 columns]

# %%
Haid = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Haid_F3393_4PCs_All.pheno', delimiter=' ')
Haid
# Out:
#             FID      IID  f3393  age  sex  array       PC1       PC2  \
# 0       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 1       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 2       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 3       1000112  1000112      1   68    1      1 -0.006373  0.009384
# 4       1000129  1000129      0   62    1      2 -0.005777 -0.005378
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 252480  6024692  6024692      0   46    1      1  0.004719 -0.008683
# 252481  6025004  6025004      0   70    2      1  0.000891  0.002434
# 252482  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 252483  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 252484  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.011446  0.004137
# 1       0.012004 -0.000638
# 2      -0.002693  0.010003
# 3      -0.030781  0.006168
# 4       0.010749 -0.003741
# ...          ...       ...
# 252480 -0.000753  0.004104
# 252481 -0.011637  0.005646
# 252482 -0.001599 -0.004673
# 252483 -0.008309  0.013414
# 252484 -0.009647  0.005814
#
# [252485 rows x 10 columns]

# %%
Unrelated_Hdiff = Hdiff[Hdiff.loc[:,'IID'].isin(Unrelated['IID'])]
Unrelated_Hdiff
# Out:
#             FID      IID  f2247  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 4       1000090  1000090      1   64    2      1 -0.017105  0.017367
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 346025  6020607  6020607      1   62    1      1 -0.001649  0.000177
# 346048  6022039  6022039      1   57    2      1  0.011899 -0.009931
# 346063  6023046  6023046      0   40    2      1  0.009782  0.001445
# 346070  6023549  6023549      0   65    1      1  0.011020 -0.012357
# 346091  6024665  6024665      1   51    2      1 -0.001921  0.009481
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 4      -0.040881  0.004871
# ...          ...       ...
# 346025  0.016048 -0.002361
# 346048 -0.003741 -0.006151
# 346063  0.016083 -0.020262
# 346070  0.020477  0.003696
# 346091  0.000976  0.000537
#
# [265729 rows x 10 columns]

# %%
Unrelated_Hnoise = Hnoise[Hnoise.loc[:,'IID'].isin(Unrelated['IID'])]
Unrelated_Hnoise
# Out:
#             FID      IID  f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000046  1000046      1   73    2      1 -0.009498  0.004089
# 2       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 3       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 4       1000081  1000081      0   67    1      1  0.118118 -0.047693
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 397064  6020607  6020607      1   62    1      1 -0.001649  0.000177
# 397093  6022039  6022039      1   57    2      1  0.011899 -0.009931
# 397107  6023046  6023046      0   40    2      1  0.009782  0.001445
# 397117  6023549  6023549      0   65    1      1  0.011020 -0.012357
# 397140  6024665  6024665      1   51    2      1 -0.001921  0.009481
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1      -0.012498  0.008941
# 2       0.011446  0.004137
# 3       0.012004 -0.000638
# 4      -0.002693  0.010003
# ...          ...       ...
# 397064  0.016048 -0.002361
# 397093 -0.003741 -0.006151
# 397107  0.016083 -0.020262
# 397117  0.020477  0.003696
# 397140  0.000976  0.000537
#
# [305116 rows x 10 columns]

# %%
Unrelated_Hboth = Hboth[Hboth.loc[:,'IID'].isin(Unrelated['IID'])]
Unrelated_Hboth
# Out:
#             FID      IID  f2247_f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022            1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063            0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078            0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081            0   67    1      1  0.118118 -0.047693
# 4       1000112  1000112            1   68    1      1 -0.006373  0.009384
# ...         ...      ...          ...  ...  ...    ...       ...       ...
# 329053  6020607  6020607            1   62    1      1 -0.001649  0.000177
# 329076  6022039  6022039            1   57    2      1  0.011899 -0.009931
# 329089  6023046  6023046            0   40    2      1  0.009782  0.001445
# 329095  6023549  6023549            0   65    1      1  0.011020 -0.012357
# 329114  6024665  6024665            1   51    2      1 -0.001921  0.009481
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 4      -0.030781  0.006168
# ...          ...       ...
# 329053  0.016048 -0.002361
# 329076 -0.003741 -0.006151
# 329089  0.016083 -0.020262
# 329095  0.020477  0.003696
# 329114  0.000976  0.000537
#
# [252619 rows x 10 columns]

# %%
Unrelated_Haid = Haid[Haid.loc[:,'IID'].isin(Unrelated['IID'])]
Unrelated_Haid
# Out:
#             FID      IID  f3393  age  sex  array       PC1       PC2  \
# 0       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 1       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 2       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 3       1000112  1000112      1   68    1      1 -0.006373  0.009384
# 4       1000129  1000129      0   62    1      2 -0.005777 -0.005378
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 252258  6003694  6003694      1   67    1      1  0.002073 -0.000447
# 252416  6018137  6018137      0   57    2      1  0.014297 -0.003259
# 252455  6022039  6022039      1   57    2      1  0.011899 -0.009931
# 252464  6023046  6023046      0   40    2      1  0.009782  0.001445
# 252468  6023549  6023549      0   65    1      1  0.011020 -0.012357
#
#              PC3       PC4
# 0       0.011446  0.004137
# 1       0.012004 -0.000638
# 2      -0.002693  0.010003
# 3      -0.030781  0.006168
# 4       0.010749 -0.003741
# ...          ...       ...
# 252258 -0.004327 -0.007727
# 252416  0.001209  0.007020
# 252455 -0.003741 -0.006151
# 252464  0.016083 -0.020262
# 252468  0.020477  0.003696
#
# [193980 rows x 10 columns]

# %%
Tinnitus = pd.read_csv('/mnt/mfs/hgrcgrid/homes/fr2540/projects/tinnitus/PCA/tinnitus_case_group3_0222_5081cases_99351controls_related_unrelated.pheno', sep='\t')
Tinnitus
# Out:
#             FID      IID  sex  age  tinnitus_3       PC1       PC2       PC3  \
# 0       1000046  1000046    1   73           0 -0.007985  0.004271 -0.013161
# 1       1000063  1000063    0   43           0 -0.003617  0.002522  0.013547
# 2       1000078  1000078    1   60           0 -0.008100  0.003432  0.010375
# 3       1000081  1000081    0   67           0  0.118704 -0.048038 -0.002625
# 4       1000141  1000141    1   49           0 -0.001355  0.001002  0.003562
# ...         ...      ...  ...  ...         ...       ...       ...       ...
# 104427  6024002  6024002    0   52           0  0.015383 -0.022075 -0.008029
# 104428  6024614  6024614    1   63           0 -0.000132  0.011875 -0.004452
# 104429  6024620  6024620    0   55           1 -0.002454  0.004290  0.014269
# 104430  6024870  6024870    1   53           0 -0.011629 -0.000451 -0.009712
# 104431  6025004  6025004    1   70           0  0.000234  0.003439 -0.014385
#
#              PC4       PC5       PC6       PC7       PC8       PC9      PC10  \
# 0       0.005613 -0.009311 -0.009297  0.000614 -0.001315 -0.001588  0.000533
# 1       0.002792 -0.009610 -0.010373  0.011888  0.012609 -0.010592  0.003954
# 2      -0.006071 -0.007506 -0.010840 -0.001616  0.009411 -0.004137  0.012528
# 3       0.012228  0.006972 -0.002569  0.007648 -0.004643 -0.000582  0.011976
# 4       0.003884 -0.014152 -0.010774  0.010278  0.016399  0.002039  0.001612
# ...          ...       ...       ...       ...       ...       ...       ...
# 104427 -0.005885  0.005767  0.000471  0.003523 -0.000987  0.005845  0.002428
# 104428  0.005759 -0.013814  0.007971 -0.003415 -0.002461  0.007312 -0.013765
# 104429  0.008715  0.002799  0.001548 -0.001065  0.002623  0.007900  0.005889
# 104430  0.000519 -0.007135 -0.006879  0.009101  0.013579  0.007336  0.009927
# 104431 -0.000431  0.002718  0.003698 -0.007741 -0.011813  0.002423 -0.022195
#
#         array
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 104427      1
# 104428      1
# 104429      2
# 104430      1
# 104431      1
#
# [104432 rows x 16 columns]

# %%
Unrelated_Tinnitus = Tinnitus[Tinnitus.loc[:,'IID'].isin(Unrelated['IID'])]
Unrelated_Tinnitus
# Out:
#             FID      IID  sex  age  tinnitus_3       PC1       PC2       PC3  \
# 0       1000046  1000046    1   73           0 -0.007985  0.004271 -0.013161
# 1       1000063  1000063    0   43           0 -0.003617  0.002522  0.013547
# 2       1000078  1000078    1   60           0 -0.008100  0.003432  0.010375
# 3       1000081  1000081    0   67           0  0.118704 -0.048038 -0.002625
# 4       1000141  1000141    1   49           0 -0.001355  0.001002  0.003562
# ...         ...      ...  ...  ...         ...       ...       ...       ...
# 104029  5933453  5933453    1   60           0  0.003846 -0.004126 -0.000154
# 104162  5963216  5963216    1   63           0  0.025315 -0.029438 -0.004490
# 104226  5976649  5976649    1   48           0 -0.005287  0.008702 -0.000494
# 104239  5979222  5979222    1   42           0  0.007609 -0.010344 -0.016789
# 104245  5980170  5980170    0   67           0  0.010409 -0.006290  0.017215
#
#              PC4       PC5       PC6       PC7       PC8       PC9      PC10  \
# 0       0.005613 -0.009311 -0.009297  0.000614 -0.001315 -0.001588  0.000533
# 1       0.002792 -0.009610 -0.010373  0.011888  0.012609 -0.010592  0.003954
# 2      -0.006071 -0.007506 -0.010840 -0.001616  0.009411 -0.004137  0.012528
# 3       0.012228  0.006972 -0.002569  0.007648 -0.004643 -0.000582  0.011976
# 4       0.003884 -0.014152 -0.010774  0.010278  0.016399  0.002039  0.001612
# ...          ...       ...       ...       ...       ...       ...       ...
# 104029 -0.006543  0.001768 -0.001251 -0.000040 -0.005595 -0.009682 -0.002248
# 104162  0.005427  0.000668  0.010613 -0.005363  0.011105  0.003907  0.003028
# 104226  0.007539 -0.001097  0.011666  0.012358  0.004873  0.003849  0.009754
# 104239  0.003753  0.006667  0.012006  0.006291 -0.000754  0.003086  0.004259
# 104245  0.006779 -0.012472  0.000018 -0.002785  0.012179 -0.001512  0.004203
#
#         array
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 104029      1
# 104162      1
# 104226      1
# 104239      1
# 104245      2
#
# [82086 rows x 16 columns]

# %%
Tinnitus_All = pd.read_csv('/mnt/mfs/hgrcgrid/homes/fr2540/projects/tinnitus/PCA/tinnitus_case_group1_all_53202cases_128931controls_related_unrelated.pheno', sep='\t')
Tinnitus_All
# Out:
#             FID      IID  sex  age  tinnitus_1       PC1       PC2       PC3  \
# 0       1000046  1000046    1   73           0 -0.007985  0.004271 -0.013161
# 1       1000063  1000063    0   43           0 -0.003617  0.002522  0.013547
# 2       1000078  1000078    1   60           0 -0.008100  0.003432  0.010375
# 3       1000081  1000081    0   67           0  0.118704 -0.048038 -0.002625
# 4       1000090  1000090    1   64           0 -0.015511  0.019004 -0.041280
# ...         ...      ...  ...  ...         ...       ...       ...       ...
# 182128  6024614  6024614    1   63           0 -0.000132  0.011875 -0.004452
# 182129  6024620  6024620    0   55           1 -0.002454  0.004290  0.014269
# 182130  6024671  6024671    0   64           1 -0.001764 -0.001129 -0.005330
# 182131  6024870  6024870    1   53           0 -0.011629 -0.000451 -0.009712
# 182132  6025004  6025004    1   70           0  0.000234  0.003439 -0.014385
#
#              PC4       PC5       PC6       PC7       PC8       PC9      PC10  \
# 0       0.005613 -0.009311 -0.009297  0.000614 -0.001315 -0.001588  0.000533
# 1       0.002792 -0.009610 -0.010373  0.011888  0.012609 -0.010592  0.003954
# 2      -0.006071 -0.007506 -0.010840 -0.001616  0.009411 -0.004137  0.012528
# 3       0.012228  0.006972 -0.002569  0.007648 -0.004643 -0.000582  0.011976
# 4      -0.000970 -0.015544 -0.010922  0.012069  0.012576  0.001526 -0.003160
# ...          ...       ...       ...       ...       ...       ...       ...
# 182128  0.005759 -0.013814  0.007971 -0.003415 -0.002461  0.007312 -0.013765
# 182129  0.008715  0.002799  0.001548 -0.001065  0.002623  0.007900  0.005889
# 182130  0.000998 -0.011287  0.004729 -0.012297  0.000264 -0.005895 -0.009035
# 182131  0.000519 -0.007135 -0.006879  0.009101  0.013579  0.007336  0.009927
# 182132 -0.000431  0.002718  0.003698 -0.007741 -0.011813  0.002423 -0.022195
#
#         array
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 182128      1
# 182129      2
# 182130      1
# 182131      1
# 182132      1
#
# [182133 rows x 16 columns]

# %%
Unrelated_Tinnitus_All = Tinnitus_All[Tinnitus_All.loc[:,'IID'].isin(Unrelated['IID'])]
Unrelated_Tinnitus_All
# Out:
#             FID      IID  sex  age  tinnitus_1       PC1       PC2       PC3  \
# 0       1000046  1000046    1   73           0 -0.007985  0.004271 -0.013161
# 1       1000063  1000063    0   43           0 -0.003617  0.002522  0.013547
# 2       1000078  1000078    1   60           0 -0.008100  0.003432  0.010375
# 3       1000081  1000081    0   67           0  0.118704 -0.048038 -0.002625
# 4       1000090  1000090    1   64           0 -0.015511  0.019004 -0.041280
# ...         ...      ...  ...  ...         ...       ...       ...       ...
# 181956  6003694  6003694    0   67           1 -0.000311  0.001018  0.000409
# 182017  6010960  6010960    1   54           1  0.008671 -0.019938  0.022205
# 182078  6018780  6018780    1   53           1  0.002949  0.002163 -0.008237
# 182090  6020607  6020607    0   62           0 -0.001818  0.000777  0.011854
# 182104  6022039  6022039    1   57           1  0.013995 -0.008844 -0.000270
#
#              PC4       PC5       PC6       PC7       PC8       PC9      PC10  \
# 0       0.005613 -0.009311 -0.009297  0.000614 -0.001315 -0.001588  0.000533
# 1       0.002792 -0.009610 -0.010373  0.011888  0.012609 -0.010592  0.003954
# 2      -0.006071 -0.007506 -0.010840 -0.001616  0.009411 -0.004137  0.012528
# 3       0.012228  0.006972 -0.002569  0.007648 -0.004643 -0.000582  0.011976
# 4      -0.000970 -0.015544 -0.010922  0.012069  0.012576  0.001526 -0.003160
# ...          ...       ...       ...       ...       ...       ...       ...
# 181956 -0.000617  0.016143 -0.012850  0.004391 -0.000704  0.003083  0.005408
# 182017 -0.039419  0.001856  0.025617 -0.005797  0.010526  0.008437  0.008018
# 182078  0.003069 -0.006749  0.010805  0.009847 -0.007844 -0.010709  0.009259
# 182090  0.003908  0.006565 -0.000488  0.004228  0.001599  0.011280  0.002901
# 182104 -0.003641 -0.001097 -0.007168 -0.014349 -0.016601  0.008980 -0.009463
#
#         array
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 181956      1
# 182017      1
# 182078      1
# 182090      1
# 182104      1
#
# [142447 rows x 16 columns]

# %%
Unrelated_Tinnitus.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/output/Unrelated_Inds/Unrelated_White_EU_Unrelated_Tinnitus_case_group3_Originally_5081cases_99351controls.pheno", sep = '\t', index=False)

# %%
Unrelated_Tinnitus_All.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/output/Unrelated_Inds/Unrelated_White_EU_Tinnitus_All_case_group1_Originally_53202cases_128931controls.pheno", sep = '\t', index=False)

# %%
Unrelated_Haid.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/output/Unrelated_Inds/Unrelated_White_EU_Haid_F3393_4PCs_All.pheno", sep = '\t', index=False)

# %%
Unrelated_Hboth.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/output/Unrelated_Inds/Unrelated_White_EU_Hboth_F2247_F2257_4PCs_All.pheno", sep = '\t', index=False)

# %%
Unrelated_Hdiff.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/output/Unrelated_Inds/Unrelated_White_EU_Hdiff_F2247_4PCs_All.pheno", sep = '\t', index=False)

# %%
Unrelated_Hnoise.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/output/Unrelated_Inds/Unrelated_White_EU_Hnoise_F2257_4PCs_All.pheno", sep = '\t', index=False)

# %% [markdown]
# ## Select Discovery and replication sets based on white British and other white individulas among white Europeans

# %%
### keep white European 
white = pd.read_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/ukb47922_white_460649ind.pheno", sep = '\t', engine = 'python')

# %%
white
# Out:
#             FID      IID ethnicity
# 0       1000019  1000019   British
# 1       1000022  1000022   British
# 2       1000035  1000035   British
# 3       1000046  1000046   British
# 4       1000054  1000054   British
# ...         ...      ...       ...
# 460644  6025390  6025390   British
# 460645  6025409  6025409   British
# 460646  6025411  6025411   British
# 460647  6025425  6025425   British
# 460648  6025438  6025438   British
#
# [460649 rows x 3 columns]

# %%
# outlier individuals that will need to be removed
outlier = pd.read_csv("/mnt/mfs/statgen/UKBiobank/results/092821_PCA_results_500K/092821_PCA_related_pval0.005/ukb47922_white_460649ind.092821_PCA_related_pval0.005.pca.projected.outliers", sep="\t", header=None)
outlier
# Out:
#             0        1
# 0     1003423  1003423
# 1     1008606  1008606
# 2     1009852  1009852
# 3     1010412  1010412
# 4     1010678  1010678
# ...       ...      ...
# 1377  5801962  5801962
# 1378  5807807  5807807
# 1379  5809112  5809112
# 1380  5833189  5833189
# 1381  5939807  5939807
#
# [1382 rows x 2 columns]

# %%
outlier.columns =['FID', 'IID']

# %%
White_Filtered_PCA = white[~white.loc[:,'IID'].isin(outlier['IID'])]
White_Filtered_PCA
# Out:
#             FID      IID ethnicity
# 0       1000019  1000019   British
# 1       1000022  1000022   British
# 2       1000035  1000035   British
# 3       1000046  1000046   British
# 4       1000054  1000054   British
# ...         ...      ...       ...
# 460644  6025390  6025390   British
# 460645  6025409  6025409   British
# 460646  6025411  6025411   British
# 460647  6025425  6025425   British
# 460648  6025438  6025438   British
#
# [459267 rows x 3 columns]

# %%
category_counts = White_Filtered_PCA['ethnicity'].value_counts()
print("Number of individuals per category:")
print(category_counts)
# Out:
# Number of individuals per category:
# British                       428900
# Any_other_white_background     15091
# Irish                          12516
# Unknown                         1655
# Inconsistent_white               584
# White                            521
# Name: ethnicity, dtype: int64

# %% [markdown]
# ### 428,900 British and 30,367 other white

# %%
subset_British = White_Filtered_PCA[White_Filtered_PCA['ethnicity'] == 'British'][['IID', 'FID']]
subset_British
# Out:
#             IID      FID
# 0       1000019  1000019
# 1       1000022  1000022
# 2       1000035  1000035
# 3       1000046  1000046
# 4       1000054  1000054
# ...         ...      ...
# 460644  6025390  6025390
# 460645  6025409  6025409
# 460646  6025411  6025411
# 460647  6025425  6025425
# 460648  6025438  6025438
#
# [428900 rows x 2 columns]

# %%
subset_Other_White = White_Filtered_PCA[White_Filtered_PCA['ethnicity'] != 'British'][['IID', 'FID']]
subset_Other_White
# Out:
#             IID      FID
# 8       1000090  1000090
# 29      1000331  1000331
# 36      1000415  1000415
# 61      1000701  1000701
# 68      1000776  1000776
# ...         ...      ...
# 460524  6024002  6024002
# 460529  6024051  6024051
# 460534  6024100  6024100
# 460543  6024208  6024208
# 460614  6025031  6025031
#
# [30367 rows x 2 columns]

# %%
#subset_British.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/DiscoveryReplication/IDs_WhiteBritish.csv",index=False)

# %%
#subset_Other_White.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/DiscoveryReplication/IDs_OtherWhites.csv",index=False)

# %%
Haid = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Haid_F3393_4PCs_All.pheno', delimiter=' ')
Haid
# Out:
#             FID      IID  f3393  age  sex  array       PC1       PC2  \
# 0       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 1       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 2       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 3       1000112  1000112      1   68    1      1 -0.006373  0.009384
# 4       1000129  1000129      0   62    1      2 -0.005777 -0.005378
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 252480  6024692  6024692      0   46    1      1  0.004719 -0.008683
# 252481  6025004  6025004      0   70    2      1  0.000891  0.002434
# 252482  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 252483  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 252484  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.011446  0.004137
# 1       0.012004 -0.000638
# 2      -0.002693  0.010003
# 3      -0.030781  0.006168
# 4       0.010749 -0.003741
# ...          ...       ...
# 252480 -0.000753  0.004104
# 252481 -0.011637  0.005646
# 252482 -0.001599 -0.004673
# 252483 -0.008309  0.013414
# 252484 -0.009647  0.005814
#
# [252485 rows x 10 columns]

# %%
Hdiff = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Hdiff_F2247_4PCs_All.pheno', delimiter=' ')
Hdiff
# Out:
#             FID      IID  f2247  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 4       1000090  1000090      1   64    2      1 -0.017105  0.017367
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 346094  6024909  6024909      1   49    2      1 -0.012714  0.006905
# 346095  6025004  6025004      0   70    2      1  0.000891  0.002434
# 346096  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 346097  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 346098  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 4      -0.040881  0.004871
# ...          ...       ...
# 346094 -0.003829 -0.011212
# 346095 -0.011637  0.005646
# 346096 -0.001599 -0.004673
# 346097 -0.008309  0.013414
# 346098 -0.009647  0.005814
#
# [346099 rows x 10 columns]

# %%
Hnoise = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Hnoise_F2257_4PCs_All.pheno', delimiter=' ')
Hnoise
# Out:
#             FID      IID  f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000046  1000046      1   73    2      1 -0.009498  0.004089
# 2       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 3       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 4       1000081  1000081      0   67    1      1  0.118118 -0.047693
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 397145  6025004  6025004      0   70    2      1  0.000891  0.002434
# 397146  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 397147  6025322  6025322      1   63    2      1 -0.003041  0.028747
# 397148  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 397149  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1      -0.012498  0.008941
# 2       0.011446  0.004137
# 3       0.012004 -0.000638
# 4      -0.002693  0.010003
# ...          ...       ...
# 397145 -0.011637  0.005646
# 397146 -0.001599 -0.004673
# 397147 -0.009047  0.003363
# 397148 -0.008309  0.013414
# 397149 -0.009647  0.005814
#
# [397150 rows x 10 columns]

# %%
Hboth = pd.read_csv('/mnt/vast/hpc/csg/en2509/Phenotype/ARHL_Phenos_02152023_EN/UKBB_Hboth_F2247_F2257_4PCs_All.pheno', delimiter=' ')
Hboth
# Out:
#             FID      IID  f2247_f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022            1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063            0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078            0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081            0   67    1      1  0.118118 -0.047693
# 4       1000112  1000112            1   68    1      1 -0.006373  0.009384
# ...         ...      ...          ...  ...  ...    ...       ...       ...
# 329117  6024909  6024909            1   49    2      1 -0.012714  0.006905
# 329118  6025004  6025004            0   70    2      1  0.000891  0.002434
# 329119  6025167  6025167            0   52    2      1 -0.001835  0.013914
# 329120  6025425  6025425            0   44    2      1  0.019182 -0.014949
# 329121  6025438  6025438            0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 4      -0.030781  0.006168
# ...          ...       ...
# 329117 -0.003829 -0.011212
# 329118 -0.011637  0.005646
# 329119 -0.001599 -0.004673
# 329120 -0.008309  0.013414
# 329121 -0.009647  0.005814
#
# [329122 rows x 10 columns]

# %%
subset_IIDs = subset_British['IID'].tolist()  # Convert the "IID" column to a list
Discovery_hnoise = Hnoise[Hnoise['IID'].isin(subset_IIDs)]
Discovery_hnoise
# Out:
#             FID      IID  f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000046  1000046      1   73    2      1 -0.009498  0.004089
# 2       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 3       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 4       1000081  1000081      0   67    1      1  0.118118 -0.047693
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 397145  6025004  6025004      0   70    2      1  0.000891  0.002434
# 397146  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 397147  6025322  6025322      1   63    2      1 -0.003041  0.028747
# 397148  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 397149  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1      -0.012498  0.008941
# 2       0.011446  0.004137
# 3       0.012004 -0.000638
# 4      -0.002693  0.010003
# ...          ...       ...
# 397145 -0.011637  0.005646
# 397146 -0.001599 -0.004673
# 397147 -0.009047  0.003363
# 397148 -0.008309  0.013414
# 397149 -0.009647  0.005814
#
# [371387 rows x 10 columns]

# %%
category_counts = Discovery_hnoise['f2257'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    222487
# 1    148900
# Name: f2257, dtype: int64

# %%
columns_to_remove = ['PC1', 'PC2', 'PC3', 'PC4']
df_subset = Discovery_hnoise.drop(columns_to_remove, axis=1)
df_subset
# Out:
#             FID      IID  f2257  age  sex  array
# 0       1000022  1000022      1   53    1      1
# 1       1000046  1000046      1   73    2      1
# 2       1000063  1000063      0   43    1      1
# 3       1000078  1000078      0   60    2      1
# 4       1000081  1000081      0   67    1      1
# ...         ...      ...    ...  ...  ...    ...
# 397145  6025004  6025004      0   70    2      1
# 397146  6025167  6025167      0   52    2      1
# 397147  6025322  6025322      1   63    2      1
# 397148  6025425  6025425      0   44    2      1
# 397149  6025438  6025438      0   55    1      1
#
# [371387 rows x 6 columns]

# %%
df_subset.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/DiscoveryReplication/Hnoise/Discovery/Hnoise_British_Discovery.csv",index=False)

# %%
subset_IIDs = subset_Other_White['IID'].tolist()  # Convert the "IID" column to a list
Replication_hnoise = Hnoise[Hnoise['IID'].isin(subset_IIDs)]
Replication_hnoise
# Out:
#             FID      IID  f2257  age  sex  array       PC1       PC2  \
# 19      1000331  1000331      0   53    2      1  0.076316 -0.046557
# 24      1000415  1000415      0   65    1      1 -0.010352  0.017313
# 39      1000701  1000701      0   58    2      1 -0.002600 -0.003810
# 43      1000799  1000799      1   44    1      1  0.018243 -0.016175
# 47      1000858  1000858      0   61    1      1  0.146847 -0.087013
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 397054  6020127  6020127      1   62    1      1  0.026480 -0.032234
# 397070  6020940  6020940      0   45    1      1  0.003105 -0.008832
# 397076  6021166  6021166      1   60    2      1  0.029255 -0.042018
# 397128  6023920  6023920      0   42    2      1 -0.026426 -0.011967
# 397131  6024002  6024002      0   52    1      1  0.014886 -0.021050
#
#              PC3       PC4
# 19     -0.003439 -0.008151
# 24     -0.047860 -0.002530
# 39      0.011087  0.001300
# 43      0.014078 -0.004426
# 47     -0.031188  0.015055
# ...          ...       ...
# 397054 -0.011307  0.012454
# 397070  0.048612 -0.000320
# 397076  0.022066  0.001429
# 397128 -0.004445 -0.006127
# 397131 -0.005983 -0.004679
#
# [25763 rows x 10 columns]

# %%
category_counts = Replication_hnoise['f2257'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    15083
# 1    10680
# Name: f2257, dtype: int64

# %%
columns_to_remove = ['PC1', 'PC2', 'PC3', 'PC4']
df_subset = Replication_hnoise.drop(columns_to_remove, axis=1)
df_subset
# Out:
#             FID      IID  f2257  age  sex  array
# 19      1000331  1000331      0   53    2      1
# 24      1000415  1000415      0   65    1      1
# 39      1000701  1000701      0   58    2      1
# 43      1000799  1000799      1   44    1      1
# 47      1000858  1000858      0   61    1      1
# ...         ...      ...    ...  ...  ...    ...
# 397054  6020127  6020127      1   62    1      1
# 397070  6020940  6020940      0   45    1      1
# 397076  6021166  6021166      1   60    2      1
# 397128  6023920  6023920      0   42    2      1
# 397131  6024002  6024002      0   52    1      1
#
# [25763 rows x 6 columns]

# %%
df_subset.to_csv("/mnt/vast/hpc/csg/en2509/autosomal/DiscoveryReplication/Hnoise/Replication/Hnoise_OtherWhite_Replication.csv",index=False)

# %%
subset_IIDs = subset_British['IID'].tolist()  # Convert the "IID" column to a list
Discovery_Haid = Haid[Haid['IID'].isin(subset_IIDs)]
Discovery_Haid
# Out:
#             FID      IID  f3393  age  sex  array       PC1       PC2  \
# 0       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 1       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 2       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 3       1000112  1000112      1   68    1      1 -0.006373  0.009384
# 4       1000129  1000129      0   62    1      2 -0.005777 -0.005378
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 252480  6024692  6024692      0   46    1      1  0.004719 -0.008683
# 252481  6025004  6025004      0   70    2      1  0.000891  0.002434
# 252482  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 252483  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 252484  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.011446  0.004137
# 1       0.012004 -0.000638
# 2      -0.002693  0.010003
# 3      -0.030781  0.006168
# 4       0.010749 -0.003741
# ...          ...       ...
# 252480 -0.000753  0.004104
# 252481 -0.011637  0.005646
# 252482 -0.001599 -0.004673
# 252483 -0.008309  0.013414
# 252484 -0.009647  0.005814
#
# [236654 rows x 10 columns]

# %%
category_counts = Discovery_Haid['f3393'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    222487
# 1     14167
# Name: f3393, dtype: int64

# %%
subset_IIDs = subset_British['IID'].tolist()  # Convert the "IID" column to a list
Discovery_Hdiff = Hdiff[Hdiff['IID'].isin(subset_IIDs)]
Discovery_Hdiff
# Out:
#             FID      IID  f2247  age  sex  array       PC1       PC2  \
# 0       1000022  1000022      1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063      0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078      0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081      0   67    1      1  0.118118 -0.047693
# 5       1000112  1000112      1   68    1      1 -0.006373  0.009384
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 346094  6024909  6024909      1   49    2      1 -0.012714  0.006905
# 346095  6025004  6025004      0   70    2      1  0.000891  0.002434
# 346096  6025167  6025167      0   52    2      1 -0.001835  0.013914
# 346097  6025425  6025425      0   44    2      1  0.019182 -0.014949
# 346098  6025438  6025438      0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 5      -0.030781  0.006168
# ...          ...       ...
# 346094 -0.003829 -0.011212
# 346095 -0.011637  0.005646
# 346096 -0.001599 -0.004673
# 346097 -0.008309  0.013414
# 346098 -0.009647  0.005814
#
# [324260 rows x 10 columns]

# %%
category_counts = Discovery_Hdiff['f2247'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    222487
# 1    101773
# Name: f2247, dtype: int64

# %%
subset_IIDs = subset_British['IID'].tolist()  # Convert the "IID" column to a list
Discovery_Hboth = Hboth[Hboth['IID'].isin(subset_IIDs)]
Discovery_Hboth
# Out:
#             FID      IID  f2247_f2257  age  sex  array       PC1       PC2  \
# 0       1000022  1000022            1   53    1      1 -0.001246 -0.002730
# 1       1000063  1000063            0   43    1      1 -0.003469  0.002587
# 2       1000078  1000078            0   60    2      1 -0.009168  0.000995
# 3       1000081  1000081            0   67    1      1  0.118118 -0.047693
# 4       1000112  1000112            1   68    1      1 -0.006373  0.009384
# ...         ...      ...          ...  ...  ...    ...       ...       ...
# 329117  6024909  6024909            1   49    2      1 -0.012714  0.006905
# 329118  6025004  6025004            0   70    2      1  0.000891  0.002434
# 329119  6025167  6025167            0   52    2      1 -0.001835  0.013914
# 329120  6025425  6025425            0   44    2      1  0.019182 -0.014949
# 329121  6025438  6025438            0   55    1      1  0.003167 -0.003508
#
#              PC3       PC4
# 0       0.017134 -0.005394
# 1       0.011446  0.004137
# 2       0.012004 -0.000638
# 3      -0.002693  0.010003
# 4      -0.030781  0.006168
# ...          ...       ...
# 329117 -0.003829 -0.011212
# 329118 -0.011637  0.005646
# 329119 -0.001599 -0.004673
# 329120 -0.008309  0.013414
# 329121 -0.009647  0.005814
#
# [308362 rows x 10 columns]

# %%
category_counts = Discovery_Hboth['f2247_f2257'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    222487
# 1     85875
# Name: f2247_f2257, dtype: int64

# %%
subset_IIDs = subset_Other_White['IID'].tolist()  # Convert the "IID" column to a list
Replication_Haid = Haid[Haid['IID'].isin(subset_IIDs)]
Replication_Haid
# Out:
#             FID      IID  f3393  age  sex  array       PC1       PC2  \
# 10      1000331  1000331      0   53    2      1  0.076316 -0.046557
# 14      1000415  1000415      0   65    1      1 -0.010352  0.017313
# 25      1000701  1000701      0   58    2      1 -0.002600 -0.003810
# 29      1000858  1000858      0   61    1      1  0.146847 -0.087013
# 32      1000914  1000914      0   47    1      1 -0.002959 -0.009982
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 252404  6017262  6017262      0   55    2      1  0.032185 -0.041464
# 252432  6020089  6020089      0   58    1      2  0.026561 -0.038922
# 252442  6020940  6020940      0   45    1      1  0.003105 -0.008832
# 252473  6023920  6023920      0   42    2      1 -0.026426 -0.011967
# 252475  6024002  6024002      0   52    1      1  0.014886 -0.021050
#
#              PC3       PC4
# 10     -0.003439 -0.008151
# 14     -0.047860 -0.002530
# 25      0.011087  0.001300
# 29     -0.031188  0.015055
# 32      0.026722 -0.003840
# ...          ...       ...
# 252404 -0.000240  0.006460
# 252432  0.011565 -0.013214
# 252442  0.048612 -0.000320
# 252473 -0.004445 -0.006127
# 252475 -0.005983 -0.004679
#
# [15831 rows x 10 columns]

# %%
category_counts = Replication_Haid['f3393'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    15083
# 1      748
# Name: f3393, dtype: int64

# %%
subset_IIDs = subset_Other_White['IID'].tolist()  # Convert the "IID" column to a list
Replication_Hdiff = Hdiff[Hdiff['IID'].isin(subset_IIDs)]
Replication_Hdiff
# Out:
#             FID      IID  f2247  age  sex  array       PC1       PC2  \
# 4       1000090  1000090      1   64    2      1 -0.017105  0.017367
# 15      1000331  1000331      0   53    2      1  0.076316 -0.046557
# 20      1000415  1000415      0   65    1      1 -0.010352  0.017313
# 34      1000701  1000701      0   58    2      1 -0.002600 -0.003810
# 40      1000858  1000858      0   61    1      1  0.146847 -0.087013
# ...         ...      ...    ...  ...  ...    ...       ...       ...
# 345998  6018674  6018674      1   62    2      1 -0.008631  0.010347
# 346015  6020089  6020089      0   58    1      2  0.026561 -0.038922
# 346031  6020940  6020940      0   45    1      1  0.003105 -0.008832
# 346081  6023920  6023920      0   42    2      1 -0.026426 -0.011967
# 346083  6024002  6024002      0   52    1      1  0.014886 -0.021050
#
#              PC3       PC4
# 4      -0.040881  0.004871
# 15     -0.003439 -0.008151
# 20     -0.047860 -0.002530
# 34      0.011087  0.001300
# 40     -0.031188  0.015055
# ...          ...       ...
# 345998  0.000801 -0.005217
# 346015  0.011565 -0.013214
# 346031  0.048612 -0.000320
# 346081 -0.004445 -0.006127
# 346083 -0.005983 -0.004679
#
# [21839 rows x 10 columns]

# %%
category_counts = Replication_Hdiff['f2247'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    15083
# 1     6756
# Name: f2247, dtype: int64

# %%
subset_IIDs = subset_Other_White['IID'].tolist()  # Convert the "IID" column to a list
Replication_Hboth = Hboth[Hboth['IID'].isin(subset_IIDs)]
Replication_Hboth
# Out:
#             FID      IID  f2247_f2257  age  sex  array       PC1       PC2  \
# 14      1000331  1000331            0   53    2      1  0.076316 -0.046557
# 19      1000415  1000415            0   65    1      1 -0.010352  0.017313
# 33      1000701  1000701            0   58    2      1 -0.002600 -0.003810
# 38      1000858  1000858            0   61    1      1  0.146847 -0.087013
# 41      1000914  1000914            0   47    1      1 -0.002959 -0.009982
# ...         ...      ...          ...  ...  ...    ...       ...       ...
# 329026  6018674  6018674            1   62    2      1 -0.008631  0.010347
# 329043  6020089  6020089            0   58    1      2  0.026561 -0.038922
# 329059  6020940  6020940            0   45    1      1  0.003105 -0.008832
# 329105  6023920  6023920            0   42    2      1 -0.026426 -0.011967
# 329107  6024002  6024002            0   52    1      1  0.014886 -0.021050
#
#              PC3       PC4
# 14     -0.003439 -0.008151
# 19     -0.047860 -0.002530
# 33      0.011087  0.001300
# 38     -0.031188  0.015055
# 41      0.026722 -0.003840
# ...          ...       ...
# 329026  0.000801 -0.005217
# 329043  0.011565 -0.013214
# 329059  0.048612 -0.000320
# 329105 -0.004445 -0.006127
# 329107 -0.005983 -0.004679
#
# [20760 rows x 10 columns]

# %%
category_counts = Replication_Hboth['f2247_f2257'].value_counts()
print("Number of occurrences per category:")
print(category_counts)
# Out:
# Number of occurrences per category:
# 0    15083
# 1     5677
# Name: f2247_f2257, dtype: int64

# %% [markdown]
# ## Below belongs to Fabiha

# %% [markdown]
# # 6. Tinnitus

# %% [markdown]
# ## 6.1. Remove inconsistencies or unclear individuals

# %% [markdown]
# ### 6.1.1. Prior to filtering for inconsistencies

# %% [markdown]
# <b>Tinnitus</b> <br>
# f.4803 = {'No, never': 76141,
#  'Yes, but not now, but have in the past': 11400,
#  'Yes, now some of the time': 9788,
#  'Yes, now a lot of the time': 2973,
#  'Yes, now most or all of the time': 7426,
#  'Do not know': 1745,
#  'Prefer not to answer': 127}

# %% [markdown]
# ### 6.1.2. Inconsistencies in the tinnitus answers

# %%
filtered = saved_filtered

# %%
tin_cols = [col for col in filtered if "f.4803" in col]

icd_10_cols = [col for col in df if "f.41270" in col]
icd_9_cols = [col for col in df if "f.41271" in col]

# %%
tin_ans = {"Do not know":9, 'Yes, but not now, but have in the past':1, 'Yes, now some of the time':1, 'Yes, now a lot of the time':1, 'Yes, now most or all of the time':1, 'No, never':0}
options = set()
# pass one pheno at a time
def find_options(row):
    answer = "".join([str(tin_ans[i]) for i in row if not pd.isna(i) and i != "Prefer not to answer"])
    options.add(answer)

# %%
s = filtered[tin_cols].apply(find_options, axis=1)

# %%
options

# %%
# we might have inconsistencies if we have don't knows mixed with other answers or even yes and no together
# options contains the set of all unique codes 

do_not_know_no = [i for i in options if '0' in i and '9' in i and '1' not in i]
do_not_know_yes = [i for i in options if '0' not in i and '9' in i and '1' in i]
yes_no = [i for i in options if '0' in i and '9' not in i and '1' in i]
with_all_three = [i for i in options if '0' in i and '9' in i and '1' in i]

# collecting all possible occurances that can be flagged for being inconsistent
might_inconsistent = do_not_know_no + do_not_know_yes + yes_no + with_all_three

# these are exceptions to the possibilities we have that can be flagged for being inconsistent
exceptions = ["91","911","9111","991","0001","001","0011","01","011","0111", "0091", "091","0911","0991","9001","901","9011", "90", "900", "9000", "990"]

# collect the list of answer combinations that are actually inconsistent by removing the answer combinations that are exceptions
inconsistent = [i for i in might_inconsistent if i not in exceptions]

# %%
inconsistent

# %% [markdown]
# #### 6.1.2.1. Filtering out the data

# %%
filtered

# %%
# will return true if that row should be removed
# pass one pheno at a time
def find_inconsistencies(row):
    for i in row:
        if not pd.isna(i) and i == "I am completely deaf":
            return True
    
    answer = "".join([str(tin_ans[i]) for i in row if not pd.isna(i) and i != "I am completely deaf" and i != "Prefer not to answer"])
    if answer in inconsistent:
        return True
    return False

# %%
exclude = filtered[tin_cols].apply(find_inconsistencies, axis=1)
filtered = filtered[~exclude]

# %%
filtered

# %% [markdown]
# ## 6.2. Identify Pure Control

# %% [markdown]
# Need to make sure that for tinnitus we obtain the individuals that say no.
#
# The conditions for saying no are as follows:
# * Never saying yes
# * Not being inconsistent
# * Saying no at least once (prefer not to say is allowed)
#
# We are also not including individuals to be part of the control group if they have certain codes for ICD9, ICD10, or f.20002 (this is in the case that they say no to all tinnitus). However these individuals can still be part of the cases

# %%
tin_ans = {"Do not know":9, 'Yes, but not now, but have in the past':1, 'Yes, now some of the time':1, 'Yes, now a lot of the time':1, 'Yes, now most or all of the time':1, 'No, never':0}

# returns 0 if it's a ctrl or else 1
def find_ctrl(row):
    answer = "".join([str(tin_ans[i]) for i in row if not pd.isna(i) and i != "Prefer not to answer"])
    if "0" in answer and "1" not in answer:
        return False
    return True

# %%
f4803_ctrl = filtered[tin_cols].apply(find_ctrl, axis=1)

# %%
sum(f4803_ctrl)

# %% [markdown]
# ### 6.2.1. Collect ICD 10 codes to filter out from Ctrl

# %%
exclude_ctrl_icd10 = exclusion[(exclusion["UKBB_field_code"] == "f.41270") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd10

# %%
ex_critia_ctrl_icd10 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd10["Phenotype"].tolist()]
ex_critia_ctrl_icd10

# %%
icd10 = filtered[icd10_colnames]
icd10

# %%
ex_fxn_icd10 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd10)
ex_10 = icd10.apply(ex_fxn_icd10, axis=1)

# %% [markdown]
# ### 6.2.2. Collect ICD 9 codes to filter out from Ctrl

# %%
exclude_ctrl_icd9 = exclusion[(exclusion["UKBB_field_code"] == "f.41271") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_icd9

# %%
ex_critia_ctrl_icd9 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_icd9["Phenotype"].tolist()]
ex_critia_ctrl_icd9

# %%
icd9 = filtered[icd9_colnames]
icd9

# %%
ex_fxn_icd9 = lambda row: contains_exclusion(row, ex_critia_ctrl_icd9)
ex_9 = icd9.apply(ex_fxn_icd9, axis=1)

# %% [markdown]
# ### 6.2.3. Collect f20002 codes to filter out from Ctrl

# %%
exclude_ctrl_f20002 = exclusion[(exclusion["UKBB_field_code"] == "f.20002") & (exclusion["Excluded_from_controls"] == 'Y') ]
exclude_ctrl_f20002

# %%
f20002 = filtered[f20002_colnames]
f20002

# %%
ex_critia_ctrl_f20002 = ["".join( (i.split(" ")[0]).split(".") ) for i in exclude_ctrl_f20002["Phenotype"].tolist()]
ex_critia_ctrl_f20002

# %%
ex_fxn_f20002 = lambda row: contains_exclusion(row, ex_critia_ctrl_f20002)
ex_f20002 = f20002.apply(ex_fxn_f20002, axis=1)

# %% [markdown]
# ### 6.2.4. Collect individuals with other tinnitus codes to filter out from CTRL

# %%
# check if the given code exists in the individuals
def check_code(row, code):
    for i in row:
        if not pd.isna(i) and i == code:
            return 1
    return 0

# %%
tinn_icd10_check_code = lambda row: check_code(row, "H931")
tinn_icd10 = filtered[icd_10_cols].apply(tinn_icd10_check_code, axis = 1)

# %%
tinn_icd9_check_code = lambda row: check_code(row, "3883")
tinn_icd9 = filtered[icd_9_cols].apply(tinn_icd9_check_code, axis = 1)

# %%
self_report_cols = [col for col in filtered if "f.20002" in col]
tinn_self_report_check_code = lambda row: check_code(row, "1597")
tinn_self_report = filtered[self_report_cols].apply(tinn_self_report_check_code, axis = 1)

# %% [markdown]
# ### 6.2.5. Filter out Tinnitus Ctrl

# %%
sum(f4803_ctrl | ex_10 | ex_9 | ex_f20002 | tinn_icd10 | tinn_icd9 | tinn_self_report)

# %%
temp = f4803_ctrl | ex_10 | ex_9 | ex_f20002 | tinn_icd10 | tinn_icd9 | tinn_self_report
filtered_ctrl = [1 if i else 0 for i in temp.to_list()]

# %%
filtered["tinnitus_pure_ctrl"] = filtered_ctrl

# %%
filtered

# %% [markdown]
# ## 6.3. Identify Age

# %%
ages_f21003_col = [col for col in filtered if "f.21003" in col]
ages_f21003_col

# %%
#get the minimum age of each individual in the given columns
def get_min_age(row):
    temp = [i for i in row.to_list() if not pd.isna(i)]
    if len(temp) > 0:
        return min(temp)
    else:
        return pd.NA

# %%
filtered["tinnitus_age"] = filtered[ages_f21003_col].apply(get_min_age, axis=1)

# %%
saved_tinn = filtered

# %%
filtered = saved_tinn

# %% [markdown]
# ## 6.4. Noisy workplace and Loud Music Variable

# %% [markdown]
# Two variables that we need to control for in the analysis are f.4825 (noisy workplace) and f.4836 (loud music).

# %% [markdown]
# ### 6.4.1. Check for inconsistencies

# %% [markdown]
# <b>f.4825 "Have you ever worked in a noisy place where you had to shout to be heard?"</b> <br>
# "No"= "0", <br>
# "Yes, for less than a year"= "1", <br>
# "Yes, for around 1-5 years"= "2", <br>
# "Yes, for more than 5 years"= "3", <br>
# "Prefer not to answer"= NA, <br>
# "Do not know"= NA <br>

# %% [markdown]
# <b>f.4836 "Have you ever listened to music for more than 3 hours per week at a volume which you would need to shout to be heard or, if wearing headphones, someone else would need to shout for you to hear them?" </b> <br>
# "No"= "0", <br>
# "Yes, for less than a year"= "1", <br>
# "Yes, for around 1-5 years"= "2", <br>
# "Yes, for more than 5 years"= "3", <br>
# "Prefer not to answer"= NA, <br>
# "Do not know"= NA <br>

# %%
noise_wp_cols = [col for col in df if "f.4825" in col]
loud_music_cols = [col for col in df if "f.4836" in col]

# %%
noise_loud_answers = {"No":0, "Yes, for less than a year":1, "Yes, for around 1-5 years":2, "Yes, for more than 5 years":3}

# if the answers we have are not sorted in the order that they're in the list, then that individual is inconsistent
def find_inconsistencies_noisy_loud(row):
    ans = [noise_loud_answers[i] for i in row if i in noise_loud_answers.keys()] 
    return sorted(ans) != ans

# %%
exclude = filtered[noise_wp_cols].apply(find_inconsistencies_noisy_loud, axis=1)
filtered = filtered[~exclude]

# %%
exclude = filtered[loud_music_cols].apply(find_inconsistencies_noisy_loud, axis=1)
filtered = filtered[~exclude]

# %% [markdown]
# ### 6.4.2. Label Noise and Loud Music

# %%
# find individuals that have yes for either noise or loud sounds
def find_label_noisy_loud(row):
    ans = [noise_loud_answers[i] for i in row if i in noise_loud_answers.keys()]
    if len(ans) > 0:
        return ans[-1]
    return pd.NA

# %%
filtered["noise_wp"] = filtered[noise_wp_cols].apply(find_label_noisy_loud, axis=1)

# %%
filtered["noise_wp"] = filtered["noise_wp"].fillna( int(filtered["noise_wp"].median(skipna=True)) )

# %%
filtered["loud_music"] = filtered[loud_music_cols].apply(find_label_noisy_loud, axis=1)

# %%
filtered["loud_music"] = filtered["loud_music"].fillna( int(filtered["loud_music"].median(skipna=True)) )

# %%
filtered

# %% [markdown]
# ## 6.5. Identify Cases

# %% [markdown]
# **Analysis plan:**
#
# 1. Individuals who currently have tinnitus (all four yes categories) vs no never only controlling for sex, age, noisy workplace and loud music frequency ("crude") (No tinnitus vs anytype of tinnitus). For this analysis the missing data of the noise variables was imputed using the median for cases and controls separately
#
# 3. Individuals in the two top YES categories vs NO never ('No' tinnitus vs 'Yes, now all of the time' and 'Yes, now most of the time')
#
# 4. Individuals that say yes in the top 3 categories vs No never (Remove category 'yes, but not now, but have it in the past')
#
# 5. Individuals who currently have tinnitus (all four yes categories and tinnitus codes). Not filtering for issues with noisy workplace and loud music.

# %%
# return 1 if we have a yes (used to find phenos)
def find_yes(row):
    for i in row:
        if not pd.isna(i) and i != "Prefer not to answer" and i in tin_ans.keys() and tin_ans[i] == 1:
            return 1
    return 0

# %% [markdown]
# ### 6.5.1. Analysis Plan 1

# %%
tin_ans = {"Do not know":9, 'Yes, but not now, but have in the past':1, 'Yes, now some of the time':1, 'Yes, now a lot of the time':1, 'Yes, now most or all of the time':1, 'No, never':0}

# %%
tinn_yes = filtered[tin_cols].apply(find_yes, axis=1)

# %%
filtered["tinnitus_1"] = tinn_yes

# %% [markdown]
# ### 6.5.2. Analysis Plan 2

# %%
tin_ans = {"Do not know":9, 'Yes, now a lot of the time':1, 'Yes, now most or all of the time':1, 'No, never':0}

# %%
tinn_yes = filtered[tin_cols].apply(find_yes, axis=1)

# %%
filtered["tinnitus_2"] = tinn_yes

# %% [markdown]
# ### 6.5.3. Analysis Plan 3

# %%
tin_ans = {"Do not know":9, 'Yes, now some of the time':1, 'Yes, now a lot of the time':1, 'Yes, now most or all of the time':1, 'No, never':0}

# %%
tinn_yes = filtered[tin_cols].apply(find_yes, axis=1)

# %%
sum(tinn_yes)

# %%
filtered["tinnitus_3"] = tinn_yes

# %% [markdown]
# ### 6.5.4. Analysis Plan 4

# %%
filtered_for4 = saved_tinn

# %%
tin_ans = {"Do not know":9, 'Yes, but not now, but have in the past':1, 'Yes, now some of the time':1, 'Yes, now a lot of the time':1, 'Yes, now most or all of the time':1, 'No, never':0}

# %%
tinn_yes = filtered_for4[tin_cols].apply(find_yes, axis=1)

# %%
sum(tinn_yes | tinn_icd10 | tinn_icd9 | tinn_self_report)

# %%
filtered_for4["tinnitus_4"] = tinn_yes | tinn_icd10 | tinn_icd9 | tinn_self_report

# %%
sum(filtered_for4["tinnitus_4"])

# %% [markdown]
# ## 6.6. File Output

# %%
filtered

# %%
filtered_for4

# %%
filtered[filtered["tinnitus_pure_ctrl"] == 0][["FID", "IID", "sex", "tinnitus_pure_ctrl", "tinnitus_age", "noise_wp", "loud_music"]].to_csv("tinnitus_pure_ctrl_pheno_file.tsv", sep='\t', index=False)
#filtered[filtered["tinnitus_pure_ctrl"] == 0][["FID", "IID", "sex", "tinnitus_pure_ctrl", "ctrl_age"]].to_csv("tinnitus_pure_ctrl_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["tinnitus_1"] == 1][["FID", "IID", "sex", "tinnitus_1", "tinnitus_age", "noise_wp", "loud_music"]].to_csv("tinnitus_1_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["tinnitus_2"] == 1][["FID", "IID", "sex", "tinnitus_2", "tinnitus_age", "noise_wp", "loud_music"]].to_csv("tinnitus_2_pheno_file.tsv", sep='\t', index=False)

# %%
filtered[filtered["tinnitus_3"] == 1][["FID", "IID", "sex", "tinnitus_3", "tinnitus_age", "noise_wp", "loud_music"]].to_csv("tinnitus_3_pheno_file.tsv", sep='\t', index=False)

# %%
filtered_for4[filtered_for4["tinnitus_4"] == 1][["FID", "IID", "sex", "tinnitus_4", "tinnitus_age"]].to_csv("tinnitus_4_pheno_file.tsv", sep='\t', index=False)

# %%
filtered_for4[filtered_for4["tinnitus_4"] == 1][["FID", "IID", "sex", "tinnitus_4", "tinnitus_age"]]

# %% [markdown]
# # 7. Merge Pheno with Ctrl

# %% [markdown]
# ## 7.1. f2247, f2257, f3393, and mendilian

# %%
ctrl_file_name = "pure_ctrl_pheno_file.tsv"
f3393_file_name = "f3393_pheno_file.tsv"
f2247_file_name = "f2247_pheno_file.tsv"
f2257_file_name = "f2257_pheno_file.tsv"
f2247_f2257_file_name = "f2247_f2257_pheno_file.tsv"
mendilianlike_file_name = "mendelian_pheno_file.tsv"

# %%
f3393 = pd.read_csv(f3393_file_name, sep="\t")
f2247 = pd.read_csv(f2247_file_name, sep="\t")
f2257 = pd.read_csv(f2257_file_name, sep="\t")
f2247_f2257 = pd.read_csv(f2247_f2257_file_name, sep="\t")
ctrl = pd.read_csv(ctrl_file_name, sep="\t")
mendlike = pd.read_csv(mendilianlike_file_name, sep="\t")

# %%
print("ctrl: ",len(ctrl))
print("f2247: ",len(f2247))
print("f2257: ",len(f2257))
print("f2247_f2257: ",len(f2247_f2257))
print("f3393: ",len(f3393))
print("mendlike: ",len(mendlike))

# %%
mendlike[mendlike["mendelian_age"] > 40]

# %%
mendlike[mendlike["mendelian_age"] < 18]

# %% [markdown]
# ### 7.1.1. f2247

# %%
# create pheno file
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f2247.columns[3]})
f2247 = f2247.rename(columns={f2247.columns[4]:"age"})

full_pheno = f2247.append(ctrl)
full_pheno[["FID", "IID", "sex", "f2247", "age"]].to_csv("090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl", sep='\t', index=False)

# %%
# create PCA pheno file
full_pheno[["FID", "IID", "ethnicity"]].to_csv("090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl.phenopca", sep='\t', index=False)

# %%
# keep id file for genotype data selection
full_pheno[["FID", "IID"]].to_csv("090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl.keep_id", sep='\t', index=False, header=False)

# %% [markdown]
# ### 7.1.2. f2257

# %%
# create pheno file
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f2257.columns[3]})
f2257 = f2257.rename(columns={f2257.columns[4]:"age"})

full_pheno = f2257.append(ctrl)
full_pheno[["FID", "IID", "sex", "f2257", "age"]].to_csv("090321_UKBB_Hearing_noise_f2257_expandedwhite_65660cases_96601ctrl", sep='\t', index=False)

# %%
# create PCA pheno file
full_pheno[["FID", "IID", "ethnicity"]].to_csv("090321_UKBB_Hearing_noise_f2257_expandedwhite_65660cases_96601ctrl.phenopca", sep='\t', index=False)

# %%
# keep id file for genotype data selection
full_pheno[["FID", "IID"]].to_csv("090321_UKBB_Hearing_noise_f2257_expandedwhite_65660cases_96601ctrl.keep_id", sep='\t', index=False, header=False)

# %% [markdown]
# ### 7.1.3. f2247_f2257

# %%
# create pheno file
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f2247_f2257.columns[3]})
f2247_f2257 = f2247_f2257.rename(columns={f2247_f2257.columns[4]:"age"})

full_pheno = f2247_f2257.append(ctrl)
full_pheno[["FID", "IID", "sex", "f2247_f2257", "age"]].to_csv("090321_UKBB_Combined_f2247_f2257_expandedwhite_38410cases_96601ctrl", sep='\t', index=False)

# %%
# create PCA pheno file
full_pheno[["FID", "IID", "ethnicity"]].to_csv("090321_UKBB_Combined_f2247_f2257_expandedwhite_38410cases_96601ctrl.phenopca", sep='\t', index=False)

# %%
# keep id file for genotype data selection
full_pheno[["FID", "IID"]].to_csv("090321_UKBB_Combined_f2247_f2257_expandedwhite_38410cases_96601ctrl.keep_id", sep='\t', index=False, header=False)

# %% [markdown]
# ### 7.1.4. f3393

# %%
# create pheno file
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:f3393.columns[3]})
f3393 = f3393.rename(columns={f3393.columns[4]:"age"})

full_pheno = f3393.append(ctrl)
full_pheno[["FID", "IID", "sex", "f3393", "age"]].to_csv("090321_UKBB_Hearing_aid_f3393_expandedwhite_6436cases_96601ctrl", sep='\t', index=False)

# %%
# create PCA pheno file
full_pheno[["FID", "IID", "ethnicity"]].to_csv("090321_UKBB_Hearing_aid_f3393_expandedwhite_6436cases_96601ctrl.phenopca", sep='\t', index=False)

# %%
# keep id file for genotype data selection
full_pheno[["FID", "IID"]].to_csv("090321_UKBB_Hearing_aid_f3393_expandedwhite_6436cases_96601ctrl.keep_id", sep='\t', index=False, header=False)

# %% [markdown]
# ### 7.1.5. Mendelian

# %%
# create pheno file
ctrl = ctrl.rename(columns={ctrl.columns[4]:"age", ctrl.columns[3]:mendlike.columns[3]})
mendlike = mendlike.rename(columns={mendlike.columns[4]:"age"})

full_pheno = mendlike.append(ctrl)
full_pheno[["FID", "IID", "sex", "mendelian", "age"]].to_csv("090321_UKBB_Mendelian_expandedwhite_2686cases_96601ctrl", sep='\t', index=False)

# %%
# create PCA pheno file
full_pheno[["FID", "IID", "ethnicity"]].to_csv("090321_UKBB_Mendelian_expandedwhite_2686cases_96601ctrl.phenopca", sep='\t', index=False)

# %%
# keep id file for genotype data selection
full_pheno[["FID", "IID"]].to_csv("090321_UKBB_Mendelian_expandedwhite_2686rcases_96601ctrl.keep_id", sep='\t', index=False, header=False)

# %% [markdown]
# ## 7.2. Tinnitus

# %%
tinnitus_ctrl_file_name = "tinnitus_pure_ctrl_pheno_file.tsv"
tinnitus_1_file_name = "tinnitus_1_pheno_file.tsv"
tinnitus_2_file_name = "tinnitus_2_pheno_file.tsv"
tinnitus_3_file_name = "tinnitus_3_pheno_file.tsv"
tinnitus_4_file_name = "tinnitus_4_pheno_file.tsv"

# %%
tinnitus_ctrl = pd.read_csv(tinnitus_ctrl_file_name, sep="\t")
tinnitus_1 = pd.read_csv(tinnitus_1_file_name, sep="\t")
tinnitus_2 = pd.read_csv(tinnitus_2_file_name, sep="\t")
tinnitus_3 = pd.read_csv(tinnitus_3_file_name, sep="\t")
tinnitus_4 = pd.read_csv(tinnitus_4_file_name, sep="\t")

# %%
tinnitus_ctrl = tinnitus_ctrl.rename(columns={tinnitus_ctrl.columns[4]:"age"})
tinnitus_1 = tinnitus_1.rename(columns={tinnitus_1.columns[4]:"age"})
tinnitus_2 = tinnitus_2.rename(columns={tinnitus_2.columns[4]:"age"})
tinnitus_3 = tinnitus_3.rename(columns={tinnitus_3.columns[4]:"age"})
tinnitus_4 = tinnitus_4.rename(columns={tinnitus_4.columns[4]:"age"})

# %%
print("ctrl: ",len(tinnitus_ctrl))
print("tinnitus 1: ",len(tinnitus_1))
print("tinnitus 2: ",len(tinnitus_2))
print("tinnitus 3: ",len(tinnitus_3))
print("tinnitus 4: ",len(tinnitus_4))

# %% [markdown]
# ### 7.2.1. Analysis 1

# %%
tinnitus_ctrl = tinnitus_ctrl.rename(columns={tinnitus_ctrl.columns[3]:tinnitus_1.columns[3]})
full_tinnitus_1 = tinnitus_1.append(tinnitus_ctrl)
full_tinnitus_1

# %% [markdown]
# ### 7.2.2. Analysis 2

# %%
tinnitus_ctrl = tinnitus_ctrl.rename(columns={tinnitus_ctrl.columns[3]:tinnitus_2.columns[3]})
full_tinnitus_2 = tinnitus_2.append(tinnitus_ctrl)
full_tinnitus_2

# %% [markdown]
# ### 7.2.3. Analysis 3

# %%
tinnitus_ctrl = tinnitus_ctrl.rename(columns={tinnitus_ctrl.columns[3]:tinnitus_3.columns[3]})
full_tinnitus_3 = tinnitus_3.append(tinnitus_ctrl)
full_tinnitus_3

# %% [markdown]
# ### 7.2.4. Analysis 4

# %%
tinnitus_ctrl = tinnitus_ctrl.rename(columns={tinnitus_ctrl.columns[3]:tinnitus_4.columns[3]})
full_tinnitus_4 = tinnitus_4.append(tinnitus_ctrl[tinnitus_ctrl.columns[:-2]])
full_tinnitus_4

# %% [markdown]
# # Generate the phenotypes for the hearing impairment traits from the UKBB

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# # 1. Read in the data

# %% [markdown]
# ## 1.1. Read in database

# %%
# collect the necessary column names of the database for our analysis

with open("/mnt/mfs/statgen/UKBiobank/data/ukbb_databases/ukb47922_updatedAug2021/ukb47922.tab") as fp:
    line = fp.readline() # header
    header = line.split("\t")
    
    indiv = ["f.eid"]
    reported_sex = ["f.31.0.0"]
    genetic_sex = ["f.22001.0.0"]
    ethnicity = [col.strip('"') for col in header if "f.21000." in col]
    year_of_birth = [col.strip('"') for col in header if "f.34." in col]
    month_of_birth = [col.strip('"') for col in header if "f.52." in col]

# %%
combined_cols = indiv  + ethnicity + reported_sex + genetic_sex +  year_of_birth + month_of_birth

# %%
print(datetime.now())
# Out:
# 2022-01-10 09:14:21.489797

# %%
df = pd.read_csv("/mnt/mfs/statgen/UKBiobank/data/ukbb_databases/ukb47922_updatedAug2021/ukb47922.tab", dtype="string", sep='\t', usecols=combined_cols)
df
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 0       1000019        0     1960       11        1001        <NA>
# 1       1000022        1     1954        8        1001        <NA>
# 2       1000035        1     1944        5        1001        <NA>
# 3       1000046        0     1946        3        1001        <NA>
# 4       1000054        0     1942        1        1001        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502456  6025409        0     1946       11        1001        1001
# 502457  6025411        0     1960       11        1001        <NA>
# 502458  6025425        0     1963        8        1001        <NA>
# 502459  6025438        1     1952        9        1001        <NA>
# 502460  6025442     <NA>     <NA>     <NA>        <NA>        <NA>
#
#        f.21000.2.0 f.22001.0.0
# 0             <NA>           0
# 1             <NA>           1
# 2             <NA>           1
# 3             <NA>           0
# 4             <NA>           0
# ...            ...         ...
# 502456        <NA>           0
# 502457        <NA>           0
# 502458        <NA>           0
# 502459        <NA>           1
# 502460        <NA>        <NA>
#
# [502461 rows x 8 columns]

# %%
# database of all individuals that we are working with and the selected phenotypes
df = pd.read_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/HI_UKBB/082321_UKBB_exomes.csv", quotechar = '"', dtype="string", usecols=combined_cols)
df
# Out:
#             IID      FID f.31.0.0 f.34.0.0  f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 0       1000019  1000019   Female     1960  November     British        <NA>
# 1       1000035  1000035     Male     1944       May     British        <NA>
# 2       1000078  1000078   Female     1955      June     British     British
# 3       1000081  1000081     Male     1942  February     British        <NA>
# 4       1000198  1000198   Female     1967      July     British        <NA>
# ...         ...      ...      ...      ...       ...         ...         ...
# 200614  6025295  6025295     Male     1961     April     British        <NA>
# 200615  6025319  6025319   Female     1953     March     British        <NA>
# 200616  6025346  6025346   Female     1954   October     British        <NA>
# 200617  6025363  6025363     Male     1944     April     British        <NA>
# 200618  6025411  6025411   Female     1960  November     British        <NA>
#
#        f.21000.2.0 f.22001.0.0
# 0             <NA>      Female
# 1             <NA>        Male
# 2          British      Female
# 3             <NA>        Male
# 4             <NA>      Female
# ...            ...         ...
# 200614        <NA>        Male
# 200615        <NA>      Female
# 200616        <NA>      Female
# 200617        <NA>        Male
# 200618        <NA>      Female
#
# [200619 rows x 9 columns]

# %%
print(datetime.now())
# Out:
# 2022-01-10 09:31:29.972446

# %% [markdown]
# # 2. Sample QC

# %% [markdown]
# ## 2.2. Remove non-white individuals

# %%
# set of answers for the ethnicity question
set(df[ethnicity[0]].to_list()).union( set(df[ethnicity[1]].to_list()) , set(df[ethnicity[2]].to_list()))
# Out:
# {'-1',
#  '-3',
#  '1',
#  '1001',
#  '1002',
#  '1003',
#  '2',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '3',
#  '3001',
#  '3002',
#  '3003',
#  '3004',
#  '4',
#  '4001',
#  '4002',
#  '4003',
#  '5',
#  '6',
#  <NA>}

# %% [markdown]
# ```
# 1	White
# 1001	British
# 2001	White and Black Caribbean
# 3001	Indian
# 4001	Caribbean
# 2	Mixed
# 1002	Irish
# 2002	White and Black African
# 3002	Pakistani
# 4002	African
# 3	Asian or Asian British
# 1003	Any other white background
# 2003	White and Asian
# 3003	Bangladeshi
# 4003	Any other Black background
# 4	Black or Black British
# 2004	Any other mixed background
# 3004	Any other Asian background
# 5	Chinese
# 6	Other ethnic group
# -1	Do not know
# -3	Prefer not to answer
# ```
#
# https://biobank.ctsu.ox.ac.uk/crystal/coding.cgi?id=1001

# %% [markdown]
# ## Select white

# %%
# these should align with all possible options for ethnicity answers except for <NA>, Do not know, and Prefer not to answer
white = ['1001', '1002', '1','1003']
african = ['4001','2001', '4002', '2002', '4', '4003' ]
asian = ['3001', '3002', '2003', '3004', '3003', '3']
mixed = ['2', '2004']
chinese = ['5']
other = ['6']

# figure out the ancestry of each individual
def ancestry(row):
    temp = [x for x in row[ethnicity] if not pd.isna(x) and x != "-3" and x != "-1"]
    if len(temp) == 0:
        return "Unknown"
    
    if len(set(temp)) == 1 and temp[0] in white: # if we have only one unique answer and the answer is in the white variable
        return "_".join(temp[0].split(" ")) # return the unique answer
    
    if len([x for x in temp if x in white]) == len(temp):
        return "Inconsistent_white"
    if len([x for x in temp if x in asian]) == len(temp):
        return "Asian"
    if len([x for x in temp if x in african]) == len(temp):
        return "African"
    if len([x for x in temp if x in mixed]) == len(temp):
        return "Mixed"
    if len([x for x in temp if x in chinese]) == len(temp):
        return "Chinese"
    if len([x for x in temp if x in other]) == len(temp):
        return "Other"
    return "Inconsistent"

# %%
df_white = df.copy()

# %%
df_white["ethnicity"] = df_white[ethnicity].apply(ancestry, axis=1)

# %%
df_white.groupby(['ethnicity']).count()
# Out:
#                      f.eid  f.31.0.0  f.34.0.0  f.52.0.0  f.21000.0.0  \
# ethnicity
# 1                      553       553       553       553          553
# 1001                442342    442342    442342    442342       442337
# 1002                 13021     13021     13021     13021        13021
# 1003                 16149     16149     16149     16149        16148
# African               9096      9096      9096      9096         9096
# Asian                10695     10695     10695     10695        10695
# Chinese               1571      1571      1571      1571         1571
# Inconsistent           134       134       134       134          134
# Inconsistent_white     607       607       607       607          607
# Mixed                 1068      1068      1068      1068         1068
# Other                 4508      4508      4508      4508         4508
# Unknown               2717      2716      2716      2716         1824
#
#                     f.21000.1.0  f.21000.2.0  f.22001.0.0
# ethnicity
# 1                             5            1          529
# 1001                      18619        10593       430782
# 1002                        395          229        12575
# 1003                        377          199        15636
# African                     113           90         8634
# Asian                       152          140        10258
# Chinese                      45           34         1501
# Inconsistent                 97           60          131
# Inconsistent_white          448          271          590
# Mixed                        14            7         1028
# Other                        55           35         4308
# Unknown                      15            9         2249

# %%
def find_non_white(row):
    return row["ethnicity"] not in white and row["ethnicity"] != "Unknown" and row["ethnicity"] != "Inconsistent_white"

# %%
ex_non_white = df_white[["ethnicity"]].apply(find_non_white, axis=1)

# %%
df_white = df_white[~ex_non_white]

# %%
df_white
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 0       1000019        0     1960       11        1001        <NA>
# 1       1000022        1     1954        8        1001        <NA>
# 2       1000035        1     1944        5        1001        <NA>
# 3       1000046        0     1946        3        1001        <NA>
# 4       1000054        0     1942        1        1001        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502456  6025409        0     1946       11        1001        1001
# 502457  6025411        0     1960       11        1001        <NA>
# 502458  6025425        0     1963        8        1001        <NA>
# 502459  6025438        1     1952        9        1001        <NA>
# 502460  6025442     <NA>     <NA>     <NA>        <NA>        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 0             <NA>           0      1001
# 1             <NA>           1      1001
# 2             <NA>           1      1001
# 3             <NA>           0      1001
# 4             <NA>           0      1001
# ...            ...         ...       ...
# 502456        <NA>           0      1001
# 502457        <NA>           0      1001
# 502458        <NA>           0      1001
# 502459        <NA>           1      1001
# 502460        <NA>        <NA>   Unknown
#
# [475389 rows x 9 columns]

# %%
print(sum(ex_non_white), "individuals removed for being non-white")
# Out:
# 27072 individuals removed for being non-white

# %%
df_white[df_white["ethnicity"] == "1001"] #British
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 0       1000019        0     1960       11        1001        <NA>
# 1       1000022        1     1954        8        1001        <NA>
# 2       1000035        1     1944        5        1001        <NA>
# 3       1000046        0     1946        3        1001        <NA>
# 4       1000054        0     1942        1        1001        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502455  6025390        0     1942        3        1001        <NA>
# 502456  6025409        0     1946       11        1001        1001
# 502457  6025411        0     1960       11        1001        <NA>
# 502458  6025425        0     1963        8        1001        <NA>
# 502459  6025438        1     1952        9        1001        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 0             <NA>           0      1001
# 1             <NA>           1      1001
# 2             <NA>           1      1001
# 3             <NA>           0      1001
# 4             <NA>           0      1001
# ...            ...         ...       ...
# 502455        <NA>           0      1001
# 502456        <NA>           0      1001
# 502457        <NA>           0      1001
# 502458        <NA>           0      1001
# 502459        <NA>           1      1001
#
# [442342 rows x 9 columns]

# %%
df_white[df_white["ethnicity"] == "1002"] #Irish
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 8       1000090        0     1945        7        1002        <NA>
# 40      1000415        1     1942       12        1002        <NA>
# 130     1001316        1     1964        9        1002        <NA>
# 148     1001492        1     1947        8        1002        <NA>
# 202     1002031        0     1946        2        1002        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502201  6022857        1     1964       11        1002        <NA>
# 502271  6023551        0     1966        2        1002        <NA>
# 502299  6023832        1     1942        6        1002        <NA>
# 502316  6024002        1     1957        8        1002        <NA>
# 502436  6025202        0     1945        9        1002        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 8             <NA>           0      1002
# 40            <NA>           1      1002
# 130           1002           1      1002
# 148           <NA>           1      1002
# 202           <NA>           0      1002
# ...            ...         ...       ...
# 502201        <NA>           1      1002
# 502271        <NA>           0      1002
# 502299        <NA>           1      1002
# 502316        <NA>           1      1002
# 502436        <NA>           0      1002
#
# [13021 rows x 9 columns]

# %%
df_white[df_white["ethnicity"] == "1"] #White
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 645     1006463        0     1946        6           1        <NA>
# 883     1008841        0     1964       10           1        <NA>
# 1203    1012043        1     1943        6           1        <NA>
# 1730    1017312        0     1947        3           1        <NA>
# 1954    1019550        0     1942        7           1        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 498297  5983819        0     1943       10           1        <NA>
# 498551  5986358        0     1955        5           1        <NA>
# 499802  5998866        1     1946        3           1        <NA>
# 500021  6001050        0     1939        5           1        <NA>
# 501772  6018568        1     1952        4           1        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 645           <NA>        <NA>         1
# 883           <NA>           0         1
# 1203          <NA>           1         1
# 1730          <NA>           0         1
# 1954          <NA>           0         1
# ...            ...         ...       ...
# 498297        <NA>           0         1
# 498551        <NA>           0         1
# 499802        <NA>           1         1
# 500021        <NA>           0         1
# 501772        <NA>           1         1
#
# [553 rows x 9 columns]

# %%
df_white[df_white["ethnicity"] == "Inconsistent_white"]
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 705     1007061        1     1950        5        1002        <NA>
# 2498    1024996        0     1939        2        1002        1001
# 4025    1040261        0     1961        7        1001        <NA>
# 4147    1041484        1     1951       12        1001        1002
# 4530    1045313        1     1953        8        1003        1001
# ...         ...      ...      ...      ...         ...         ...
# 498134  5982180        1     1967        6        1001        1003
# 498463  5985476        0     1955       10        1001        1003
# 498968  5990529        0     1949        8        1001        1003
# 500935  6010193        0     1948        4        1002        1001
# 501766  6018502        1     1944       11        1001        1003
#
#        f.21000.2.0 f.22001.0.0           ethnicity
# 705           1001           1  Inconsistent_white
# 2498          <NA>           0  Inconsistent_white
# 4025          1003        <NA>  Inconsistent_white
# 4147          <NA>           1  Inconsistent_white
# 4530          <NA>           1  Inconsistent_white
# ...            ...         ...                 ...
# 498134        <NA>           1  Inconsistent_white
# 498463        <NA>           0  Inconsistent_white
# 498968        1003           0  Inconsistent_white
# 500935        1001           0  Inconsistent_white
# 501766        <NA>           1  Inconsistent_white
#
# [607 rows x 9 columns]

# %%
df_white[df_white["ethnicity"] == "Unknown"]
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 69      1000701        0     1949       10          -3        <NA>
# 772     1007738        0     1944       12          -3        <NA>
# 889     1008909        1     1944        3          -3        <NA>
# 898     1008997        1     1945        8          -3        <NA>
# 984     1009852        1     1963        6          -1        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 501783  6018674        0     1947        4          -3        <NA>
# 502111  6021951        1     1967        1        <NA>        <NA>
# 502249  6023331        1     1953        7        <NA>        <NA>
# 502278  6023625        0     1941       12        <NA>        <NA>
# 502460  6025442     <NA>     <NA>     <NA>        <NA>        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 69            <NA>           0   Unknown
# 772           <NA>           0   Unknown
# 889           <NA>           1   Unknown
# 898           <NA>           1   Unknown
# 984           <NA>           1   Unknown
# ...            ...         ...       ...
# 501783        <NA>           0   Unknown
# 502111        <NA>           1   Unknown
# 502249        <NA>        <NA>   Unknown
# 502278        <NA>           0   Unknown
# 502460        <NA>        <NA>   Unknown
#
# [2717 rows x 9 columns]

# %%
df_white[df_white["ethnicity"] == "1003"]
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 32      1000331        0     1956       12        1003        <NA>
# 76      1000776        0     1946        6        1003        <NA>
# 78      1000799        1     1963        7        1003        <NA>
# 84      1000858        1     1947        5        1003        <NA>
# 90      1000914        1     1962        7        1003        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502321  6024051        0     1960        2        1003        <NA>
# 502326  6024100        1     1952        6        1003        <NA>
# 502336  6024208        0     1965       11        1003        <NA>
# 502338  6024221        0     1959        9        1003        <NA>
# 502419  6025031        0     1949       10        1003        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 32            <NA>           0      1003
# 76            <NA>           0      1003
# 78            <NA>           1      1003
# 84            <NA>           1      1003
# 90            <NA>           1      1003
# ...            ...         ...       ...
# 502321        <NA>           0      1003
# 502326        <NA>           1      1003
# 502336        <NA>           0      1003
# 502338        <NA>        <NA>      1003
# 502419        <NA>           0      1003
#
# [16149 rows x 9 columns]

# %%
df_white = df_white.rename(columns={'f.eid': 'IID', 'f.31.0.0': 'sex'})

# %%
df_white['FID'] = df_white['IID']

# %%
df_white[["FID","IID","ethnicity"]].to_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/white_IID/011022_ukb47922_white_expanded_475389.iid", sep="\t", index=False)

# %% [markdown]
# ## Select Asians

# %%
# these should align with all possible options for ethnicity answers except for <NA>, Do not know, and Prefer not to answer
white = ['1001', '1002', '1','1003']
african = ['4001','2001', '4002', '2002', '4', '4003' ]
asian = ['3001', '3002', '2003', '3004', '3003', '3']
mixed = ['2', '2004']
chinese = ['5']
other = ['6']

# figure out the ancestry of each individual
def ancestry(row):
    temp = [x for x in row[ethnicity] if not pd.isna(x) and x != "-3" and x != "-1"]
    if len(temp) == 0:
        return "Unknown"
    
    if len(set(temp)) == 1 and temp[0] in asian: # if we have only one unique answer and the answer is in the asian variable
        return "_".join(temp[0].split(" ")) # return the unique answer
    
    if len([x for x in temp if x in asian]) == len(temp):
        return "Inconsistent_asian"
    if len([x for x in temp if x in white]) == len(temp):
        return "White"
    if len([x for x in temp if x in african]) == len(temp):
        return "African"
    if len([x for x in temp if x in mixed]) == len(temp):
        return "Mixed"
    if len([x for x in temp if x in chinese]) == len(temp):
        return "Chinese"
    if len([x for x in temp if x in other]) == len(temp):
        return "Other"
    return "Inconsistent"

# %% [markdown]
# Set an ancestry row that combines the ancestry answers from the database into one

# %%
df2 = df.copy()

# %%
df2["ethnicity"] = df2[ethnicity].apply(ancestry, axis=1)

# %%
def find_asian(row):
    return row["ethnicity"] in asian or row["ethnicity"] == "Inconsistent_asian"

# %%
inc_asian = df2[["ethnicity"]].apply(find_asian, axis=1)

# %%
print(sum(inc_asian), "individuals considered asian")
# Out:
# 10695 individuals considered asian

# %%
# Filter the asian individuals
filtered = df2[inc_asian]

# %%
filtered
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 89      1000906        1     1962        5        3003        <NA>
# 186     1001874        0     1947        8        3004        <NA>
# 248     1002497        0     1968        4        3001        <NA>
# 270     1002712        0     1965       12        3001        <NA>
# 301     1003025        1     1942       10        3001        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502347  6024313        0     1964        5        3004        <NA>
# 502399  6024837        1     1965        5        3001        <NA>
# 502405  6024898        0     1950        9        3001        <NA>
# 502425  6025096        0     1965        9        2003        <NA>
# 502427  6025113        1     1948        8        3001        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 89            <NA>           1      3003
# 186           <NA>           0      3004
# 248           <NA>        <NA>      3001
# 270           <NA>           0      3001
# 301           <NA>           1      3001
# ...            ...         ...       ...
# 502347        <NA>           0      3004
# 502399        <NA>           1      3001
# 502405        <NA>           0      3001
# 502425        <NA>           0      2003
# 502427        <NA>           1      3001
#
# [10695 rows x 9 columns]

# %%
filtered[filtered["ethnicity"] == "3001"] #Indian
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 248     1002497        0     1968        4        3001        <NA>
# 270     1002712        0     1965       12        3001        <NA>
# 301     1003025        1     1942       10        3001        <NA>
# 307     1003083        1     1961       10        3001        <NA>
# 518     1005191        0     1945        1        3001        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502334  6024189        0     1947        6        3001        <NA>
# 502342  6024266        0     1943        2        3001        <NA>
# 502399  6024837        1     1965        5        3001        <NA>
# 502405  6024898        0     1950        9        3001        <NA>
# 502427  6025113        1     1948        8        3001        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 248           <NA>        <NA>      3001
# 270           <NA>           0      3001
# 301           <NA>           1      3001
# 307           <NA>           1      3001
# 518           <NA>           0      3001
# ...            ...         ...       ...
# 502334        <NA>           0      3001
# 502342        <NA>           0      3001
# 502399        <NA>           1      3001
# 502405        <NA>           0      3001
# 502427        <NA>           1      3001
#
# [5948 rows x 9 columns]

# %%
filtered[filtered["ethnicity"] == "3002"] #Pakistani
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 419     1004204        1     1959        5        3002        <NA>
# 421     1004223        1     1953       10        3002        <NA>
# 425     1004262        1     1964        9        3002        <NA>
# 669     1006702        0     1957        1        3002        <NA>
# 789     1007904        0     1958        9        3002        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 501313  6013978        1     1966        6        3002        <NA>
# 501357  6014412        0     1966        6        3002        <NA>
# 501425  6015097        1     1955        8        3002        <NA>
# 501890  6019749        0     1954        4        3002        <NA>
# 502073  6021570        1     1960        7        3002        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 419           <NA>           1      3002
# 421           <NA>           1      3002
# 425           <NA>           1      3002
# 669           <NA>           0      3002
# 789           <NA>           0      3002
# ...            ...         ...       ...
# 501313        <NA>           1      3002
# 501357        <NA>           0      3002
# 501425        <NA>           1      3002
# 501890        <NA>           0      3002
# 502073        <NA>           1      3002
#
# [1834 rows x 9 columns]

# %%
filtered[filtered["ethnicity"] == "2003"] #White and Asian
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 887     1008886        0     1955       11        2003        <NA>
# 1105    1011060        0     1966        5        2003        <NA>
# 1310    1013112        1     1946       12        2003        <NA>
# 1332    1013331        1     1958        5        2003        <NA>
# 1783    1017845        1     1964        2        2003        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 499464  5995487        0     1959        3        2003        <NA>
# 500076  6001605        1     1956       10        2003        <NA>
# 500726  6008102        0     1946        7        2003        <NA>
# 501394  6014783        0     1956        4        2003        <NA>
# 502425  6025096        0     1965        9        2003        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 887           <NA>           0      2003
# 1105          <NA>           0      2003
# 1310          <NA>           1      2003
# 1332          <NA>           1      2003
# 1783          <NA>           1      2003
# ...            ...         ...       ...
# 499464        <NA>           0      2003
# 500076        <NA>           1      2003
# 500726        <NA>           0      2003
# 501394        <NA>           0      2003
# 502425        <NA>           0      2003
#
# [825 rows x 9 columns]

# %%
filtered[filtered["ethnicity"] == "3004"] #Any other Asian background
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 186     1001874        0     1947        8        3004        <NA>
# 526     1005270        0     1948       10        3004        <NA>
# 685     1006862        1     1953        4        3004        <NA>
# 902     1009036        0     1954        2        3004        <NA>
# 1356    1013573        1     1947        1        3004        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 501648  6017324        1     1966        9        3004        <NA>
# 501679  6017630        1     1966       10        3004        <NA>
# 501878  6019629        0     1944        3        3004        <NA>
# 501987  6020711        0     1947        2        3004        <NA>
# 502347  6024313        0     1964        5        3004        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 186           <NA>           0      3004
# 526           <NA>           0      3004
# 685           <NA>           1      3004
# 902           <NA>           0      3004
# 1356          <NA>           1      3004
# ...            ...         ...       ...
# 501648        <NA>           1      3004
# 501679        <NA>           1      3004
# 501878        <NA>           0      3004
# 501987        <NA>        <NA>      3004
# 502347        <NA>           0      3004
#
# [1800 rows x 9 columns]

# %%
filtered[filtered["ethnicity"] == "3003"] #Bangladeshi
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 89      1000906        1     1962        5        3003        <NA>
# 1398    1013992        0     1950        1        3003        <NA>
# 5175    1051760        0     1946        1        3003        <NA>
# 6763    1067648        1     1963        2        3003        <NA>
# 6986    1069878        1     1966       12        3003        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 491214  5912971        1     1964       12        3003        <NA>
# 491949  5920327        0     1943        2        3003        <NA>
# 493003  5930867        0     1952        6        3003        <NA>
# 495715  5957999        1     1957        1        3003        <NA>
# 498236  5983200        1     1958        8        3003        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 89            <NA>           1      3003
# 1398          <NA>           0      3003
# 5175          <NA>           0      3003
# 6763          <NA>           1      3003
# 6986          <NA>           1      3003
# ...            ...         ...       ...
# 491214        <NA>           1      3003
# 491949        <NA>           0      3003
# 493003        <NA>        <NA>      3003
# 495715        <NA>           1      3003
# 498236        <NA>           1      3003
#
# [236 rows x 9 columns]

# %%
filtered[filtered["ethnicity"] == "3"] #Asian or Asian British
#filtered[filtered["ethnicity"] == "3"].count()
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 6640    1066410        0     1949       12           3        <NA>
# 13264   1132651        1     1954        3           3        <NA>
# 13421   1134229        0     1964        1           3        <NA>
# 18792   1187957        0     1950       10           3        <NA>
# 21350   1213548        1     1966        4           3        <NA>
# 36646   1366516        0     1955        4           3        <NA>
# 37673   1376782        0     1952        7           3        <NA>
# 42948   1429546        0     1944        1           3        <NA>
# 46738   1467443        1     1966        1           3        <NA>
# 63381   1633907        1     1957        3           3        <NA>
# 80527   1805408        0     1949       10           3        <NA>
# 98063   1980788        0     1958       10           3        <NA>
# 124152  2241712        1     1954        5           3        <NA>
# 135447  2354701        0     1948       10           3        <NA>
# 150809  2508343        0     1956        6           3        <NA>
# 152767  2527921        0     1963       12           3        <NA>
# 152935  2529603        0     1941        7           3        <NA>
# 159817  2598425        0     1946        6           3        <NA>
# 181081  2811119        0     1954        7           3        <NA>
# 196283  2963139        1     1945        3           3        <NA>
# 254624  3546663        1     1945        8           3        <NA>
# 256316  3563591        1     1946        6          -3          -3
# 258560  3586043        0     1949        5           3        <NA>
# 263176  3632211        0     1965        3           3        <NA>
# 268545  3685920        0     1939        5           3        <NA>
# 271501  3715489        0     1964        1           3        <NA>
# 281798  3818462        0     1969        3           3        <NA>
# 298599  3986516        1     1965        1           3        <NA>
# 306483  4065369        1     1952        6           3        <NA>
# 321733  4217868        1     1938       12           3        <NA>
# 324586  4246405        1     1964        3           3        <NA>
# 343823  4438819        0     1940        1           3        <NA>
# 346177  4462354        1     1967        5           3        <NA>
# 363250  4633113        0     1949       11           3        <NA>
# 366159  4662204        1     1955        2           3        <NA>
# 367147  4672081        1     1961        3           3        <NA>
# 378642  4787065        1     1941        4           3        <NA>
# 391788  4918545        0     1944        1           3        <NA>
# 423523  5235943        1     1960       10           3        <NA>
# 434169  5342410        1     1966        4           3        <NA>
# 440257  5403292        1     1953       12           3        <NA>
# 467253  5673297        1     1968       10           3        <NA>
# 480631  5807115        1     1966        3           3        <NA>
# 481488  5815688        0     1946        6           3        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 6640          <NA>           0         3
# 13264         <NA>           1         3
# 13421         <NA>           0         3
# 18792         <NA>           0         3
# 21350         <NA>           1         3
# 36646         <NA>           0         3
# 37673         <NA>           0         3
# 42948         <NA>           0         3
# 46738         <NA>           1         3
# 63381         <NA>           1         3
# 80527         <NA>           0         3
# 98063         <NA>           0         3
# 124152        <NA>           1         3
# 135447        <NA>           0         3
# 150809        <NA>           0         3
# 152767        <NA>           0         3
# 152935        <NA>           0         3
# 159817        <NA>           0         3
# 181081        <NA>           0         3
# 196283        <NA>           1         3
# 254624        <NA>           1         3
# 256316           3           1         3
# 258560        <NA>           0         3
# 263176        <NA>           0         3
# 268545        <NA>           0         3
# 271501        <NA>           0         3
# 281798        <NA>           0         3
# 298599        <NA>           1         3
# 306483        <NA>           1         3
# 321733        <NA>           1         3
# 324586        <NA>           1         3
# 343823        <NA>           0         3
# 346177        <NA>           1         3
# 363250        <NA>           0         3
# 366159        <NA>           1         3
# 367147        <NA>           1         3
# 378642        <NA>        <NA>         3
# 391788        <NA>           0         3
# 423523        <NA>           1         3
# 434169        <NA>           1         3
# 440257        <NA>           1         3
# 467253        <NA>           1         3
# 480631        <NA>           1         3
# 481488        <NA>           0         3

# %%
filtered[filtered["ethnicity"] == "Inconsistent_asian"]
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 18434   1184372        1     1954        4        3001        3002
# 66460   1664704        1     1962       12        3004        <NA>
# 106027  2060423        0     1954        2        3004        2003
# 125857  2258760        1     1966        7        3002        <NA>
# 146519  2465438        1     1951       10        3001        <NA>
# 253232  3532747        1     1958        7        3004        3002
# 402397  5024641        0     1960        5        3002        <NA>
# 438456  5385280        0     1955        3        2003        <NA>
#
#        f.21000.2.0 f.22001.0.0           ethnicity
# 18434         <NA>           1  Inconsistent_asian
# 66460         3001           1  Inconsistent_asian
# 106027        2003           0  Inconsistent_asian
# 125857        3001           1  Inconsistent_asian
# 146519        3004           1  Inconsistent_asian
# 253232        <NA>           1  Inconsistent_asian
# 402397        3001           0  Inconsistent_asian
# 438456        3003           0  Inconsistent_asian

# %%
filtered = filtered.rename(columns={'f.eid': 'IID', 'f.31.0.0': 'sex'})

# %%
filtered['FID'] = filtered['IID']

# %%
filtered
# Out:
#             IID sex f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0 f.21000.2.0  \
# 89      1000906   1     1962        5        3003        <NA>        <NA>
# 186     1001874   0     1947        8        3004        <NA>        <NA>
# 248     1002497   0     1968        4        3001        <NA>        <NA>
# 270     1002712   0     1965       12        3001        <NA>        <NA>
# 301     1003025   1     1942       10        3001        <NA>        <NA>
# ...         ...  ..      ...      ...         ...         ...         ...
# 502347  6024313   0     1964        5        3004        <NA>        <NA>
# 502399  6024837   1     1965        5        3001        <NA>        <NA>
# 502405  6024898   0     1950        9        3001        <NA>        <NA>
# 502425  6025096   0     1965        9        2003        <NA>        <NA>
# 502427  6025113   1     1948        8        3001        <NA>        <NA>
#
#        f.22001.0.0 ethnicity      FID
# 89               1      3003  1000906
# 186              0      3004  1001874
# 248           <NA>      3001  1002497
# 270              0      3001  1002712
# 301              1      3001  1003025
# ...            ...       ...      ...
# 502347           0      3004  6024313
# 502399           1      3001  6024837
# 502405           0      3001  6024898
# 502425           0      2003  6025096
# 502427           1      3001  6025113
#
# [10695 rows x 10 columns]

# %%
filtered[["FID","IID","ethnicity"]].to_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/asian_IID/010622_ukb47922_asian_10695.iid", sep="\t", index=False)

# %% [markdown]
# ## Select Africans

# %%
# these should align with all possible options for ethnicity answers except for <NA>, Do not know, and Prefer not to answer
white = ['1001', '1002', '1','1003']
african = ['4001','2001', '4002', '2002', '4', '4003' ]
asian = ['3001', '3002', '2003', '3004', '3003', '3']
mixed = ['2', '2004']
chinese = ['5']
other = ['6']

# figure out the ancestry of each individual
def ancestry(row):
    temp = [x for x in row[ethnicity] if not pd.isna(x) and x != "-3" and x != "-1"]
    if len(temp) == 0:
        return "Unknown"
    
    if len(set(temp)) == 1 and temp[0] in african: # if we have only one unique answer and the answer is in the asian variable
        return "_".join(temp[0].split(" ")) # return the unique answer
    
    if len([x for x in temp if x in african]) == len(temp):
        return "Inconsistent_african"
    if len([x for x in temp if x in white]) == len(temp):
        return "White"
    if len([x for x in temp if x in asian]) == len(temp):
        return "Asian"
    if len([x for x in temp if x in mixed]) == len(temp):
        return "Mixed"
    if len([x for x in temp if x in chinese]) == len(temp):
        return "Chinese"
    if len([x for x in temp if x in other]) == len(temp):
        return "Other"
    return "Inconsistent"

# %%
df_afr = df.copy()

# %%
df_afr["ethnicity"] = df_afr[ethnicity].apply(ancestry, axis=1)

# %%
def find_african(row):
    return row["ethnicity"] in african or row["ethnicity"] == "Inconsistent_african"

# %%
inc_african = df_afr[["ethnicity"]].apply(find_african, axis=1)

# %%
print(sum(inc_african), "individuals considered african")
# Out:
# 9096 individuals considered african

# %%
# Filter the asian individuals
filtered_afr = df_afr[inc_african]

# %%
filtered_afr
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 68      1000697        0     1965       10        4001        <NA>
# 143     1001447        0     1961        6        4001        <NA>
# 145     1001465        0     1942        6        2001        <NA>
# 199     1002004        1     1957        2        4002        <NA>
# 234     1002354        0     1962        9        4001        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502221  6023054        0     1941        9        4001        <NA>
# 502390  6024740        0     1945       12        4001        <NA>
# 502417  6025018        0     1960        2        4001        <NA>
# 502443  6025273        0     1947        7        4001        <NA>
# 502454  6025381        1     1968        1        4002        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 68            <NA>           0      4001
# 143           <NA>           0      4001
# 145           <NA>           0      2001
# 199           <NA>           1      4002
# 234           <NA>           0      4001
# ...            ...         ...       ...
# 502221        <NA>           0      4001
# 502390        <NA>           0      4001
# 502417        <NA>           0      4001
# 502443        <NA>           0      4001
# 502454        <NA>           1      4002
#
# [9096 rows x 9 columns]

# %%
filtered_afr[filtered_afr["ethnicity"] == "4001"] #Caribbean
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 68      1000697        0     1965       10        4001        <NA>
# 143     1001447        0     1961        6        4001        <NA>
# 234     1002354        0     1962        9        4001        <NA>
# 259     1002608        0     1963        3        4001        <NA>
# 451     1004525        0     1962        2        4001        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 502165  6022490        0     1958        7        4001        <NA>
# 502221  6023054        0     1941        9        4001        <NA>
# 502390  6024740        0     1945       12        4001        <NA>
# 502417  6025018        0     1960        2        4001        <NA>
# 502443  6025273        0     1947        7        4001        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 68            <NA>           0      4001
# 143           <NA>           0      4001
# 234           <NA>           0      4001
# 259           <NA>           0      4001
# 451           <NA>           0      4001
# ...            ...         ...       ...
# 502165        <NA>           0      4001
# 502221        <NA>           0      4001
# 502390        <NA>           0      4001
# 502417        <NA>           0      4001
# 502443        <NA>           0      4001
#
# [4514 rows x 9 columns]

# %%
filtered_afr[filtered_afr["ethnicity"] == "2001"] #White and Black Caribbean
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 145     1001465        0     1942        6        2001        <NA>
# 312     1003139        0     1967        5        2001        <NA>
# 956     1009579        1     1955        4        2001        <NA>
# 5510    1055119        1     1962       12        2001        <NA>
# 6813    1068145        0     1965        6        2001        2001
# ...         ...      ...      ...      ...         ...         ...
# 500451  6005357        0     1962        8        2001        <NA>
# 500483  6005674        0     1959        2        2001        <NA>
# 501595  6016790        0     1960        9        2001        <NA>
# 501666  6017509        1     1962       10        2001        <NA>
# 501818  6019021        0     1955        8        2001        2001
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 145           <NA>           0      2001
# 312           <NA>           0      2001
# 956           <NA>           1      2001
# 5510          <NA>           1      2001
# 6813          2001           0      2001
# ...            ...         ...       ...
# 500451        2001           0      2001
# 500483        <NA>           0      2001
# 501595        <NA>           0      2001
# 501666        <NA>           1      2001
# 501818        <NA>           0      2001
#
# [617 rows x 9 columns]

# %%
filtered_afr[filtered_afr["ethnicity"] == "4002"] #African
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 199     1002004        1     1957        2        4002        <NA>
# 238     1002390        0     1965        8        4002        <NA>
# 427     1004285        1     1966        2        4002        <NA>
# 461     1004627        0     1957        6        4002        <NA>
# 1268    1012698        1     1957        3        4002        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 501770  6018549        0     1964        5        4002        <NA>
# 501790  6018745        1     1943        8        4002        <NA>
# 501903  6019879        0     1946       11        4002        <NA>
# 502175  6022599        1     1964        1        4002        <NA>
# 502454  6025381        1     1968        1        4002        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 199           <NA>           1      4002
# 238           <NA>           0      4002
# 427           <NA>           1      4002
# 461           <NA>           0      4002
# 1268          <NA>           1      4002
# ...            ...         ...       ...
# 501770        <NA>           0      4002
# 501790        <NA>           1      4002
# 501903        <NA>           0      4002
# 502175        <NA>           1      4002
# 502454        <NA>           1      4002
#
# [3391 rows x 9 columns]

# %%
filtered_afr[filtered_afr["ethnicity"] == "2002"] #White and Black African
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 674     1006751        0     1954        4        2002        <NA>
# 882     1008837        1     1954       10        2002        <NA>
# 1501    1015023        1     1966        2        2002        <NA>
# 2921    1029220        0     1956        1        2002        <NA>
# 3141    1031422        0     1954       12        2002        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 498126  5982101        0     1966        5        2002        <NA>
# 500414  6004982        1     1968        2        2002        <NA>
# 500446  6005304        0     1963        9        2002        <NA>
# 500725  6008093        0     1945        5        2002        <NA>
# 501981  6020654        0     1957        1        2002        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 674           <NA>           0      2002
# 882           <NA>           1      2002
# 1501          <NA>           1      2002
# 2921          <NA>           0      2002
# 3141          <NA>           0      2002
# ...            ...         ...       ...
# 498126        <NA>           0      2002
# 500414        2002           1      2002
# 500446        <NA>           0      2002
# 500725        <NA>           0      2002
# 501981        <NA>        <NA>      2002
#
# [421 rows x 9 columns]

# %%
filtered_afr[filtered_afr["ethnicity"] == "4"] #Black or Black British
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 50562   1505691        1     1955       10           4        <NA>
# 52673   1526806        0     1955        5           4        <NA>
# 63988   1639972        1     1952        5           4        <NA>
# 71989   1720015        0     1942        2           4        <NA>
# 80823   1808366        0     1951        9           4        <NA>
# 93484   1934998        0     1960        2           4        <NA>
# 132183  2322064        0     1954        2           4        <NA>
# 136042  2360659        1     1953        7           4        <NA>
# 144739  2447634        0     1943       11           4        <NA>
# 160450  2604757        1     1958       11           4        <NA>
# 185212  2852420        1     1944        8           4        <NA>
# 203828  3038611        1     1941        2           4        <NA>
# 217087  3171222        0     1966        5           4        <NA>
# 223307  3233431        0     1952        6           4        <NA>
# 231478  3315165        0     1955       11           4        <NA>
# 254803  3548457        0     1968        4           4        <NA>
# 257766  3578103        1     1964       11           4        <NA>
# 266796  3668424        0     1960       11           4        <NA>
# 294354  3944066        0     1965        2           4        <NA>
# 306972  4070259        1     1968        3           4        <NA>
# 359941  4600022        0     1954       12           4        <NA>
# 406078  5061461        1     1940       11           4        <NA>
# 417067  5171367        0     1958        7           4        <NA>
# 427902  5279737        0     1954       12           4        <NA>
# 430264  5303351        0     1956       11           4        <NA>
# 472143  5722214        0     1948        3           4        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 50562         <NA>           1         4
# 52673         <NA>           0         4
# 63988         <NA>           1         4
# 71989         <NA>        <NA>         4
# 80823         <NA>           0         4
# 93484         <NA>           0         4
# 132183        <NA>           0         4
# 136042        <NA>           1         4
# 144739        <NA>           0         4
# 160450        <NA>           1         4
# 185212        <NA>           1         4
# 203828        <NA>           1         4
# 217087        <NA>           0         4
# 223307        <NA>           0         4
# 231478        <NA>           0         4
# 254803        <NA>           0         4
# 257766        <NA>           1         4
# 266796        <NA>           0         4
# 294354        <NA>           0         4
# 306972        <NA>           1         4
# 359941        <NA>           0         4
# 406078        <NA>           1         4
# 417067        <NA>           0         4
# 427902        <NA>           0         4
# 430264        <NA>           0         4
# 472143        <NA>           0         4

# %%
filtered_afr[filtered_afr["ethnicity"] == "4003"] #Any other Black background
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 3568    1035697        0     1965        4        4003        <NA>
# 19433   1194361        0     1955        9        4003        <NA>
# 20756   1207604        1     1952        9        4003        <NA>
# 25336   1253403        0     1962        9        4003        <NA>
# 28529   1285334        0     1947        9        4003        <NA>
# ...         ...      ...      ...      ...         ...         ...
# 479088  5791683        0     1942        3        4003        <NA>
# 480121  5802016        0     1962        4        4003        <NA>
# 484116  5841965        1     1959        7        4003        <NA>
# 492252  5923353        0     1949        7        4003        <NA>
# 500210  6002949        1     1968        4        4003        <NA>
#
#        f.21000.2.0 f.22001.0.0 ethnicity
# 3568          <NA>           0      4003
# 19433         <NA>           0      4003
# 20756         <NA>           1      4003
# 25336         <NA>           0      4003
# 28529         <NA>           0      4003
# ...            ...         ...       ...
# 479088        <NA>           0      4003
# 480121        <NA>           0      4003
# 484116        <NA>           1      4003
# 492252        <NA>           0      4003
# 500210        <NA>           1      4003
#
# [121 rows x 9 columns]

# %%
filtered_afr[filtered_afr["ethnicity"] == "Inconsistent_african"]
# Out:
#           f.eid f.31.0.0 f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0  \
# 29801   1298050        0     1962        4        4003        <NA>
# 131128  2311513        1     1940       11        4001        <NA>
# 178191  2782201        1     1963        4        4001        4003
# 325896  4259501        0     1961        1           4        4001
# 390300  4903663        0     1965        9        4003        4001
# 487712  5877928        0     1955        6        2002        2001
#
#        f.21000.2.0 f.22001.0.0             ethnicity
# 29801         2002           0  Inconsistent_african
# 131128        2001           1  Inconsistent_african
# 178191        <NA>           1  Inconsistent_african
# 325896        <NA>           0  Inconsistent_african
# 390300        <NA>           0  Inconsistent_african
# 487712        <NA>           0  Inconsistent_african

# %%
filtered_afr = filtered_afr.rename(columns={'f.eid': 'IID', 'f.31.0.0': 'sex'})

# %%
filtered_afr['FID'] = filtered_afr['IID']

# %%
filtered_afr
# Out:
#             IID sex f.34.0.0 f.52.0.0 f.21000.0.0 f.21000.1.0 f.21000.2.0  \
# 68      1000697   0     1965       10        4001        <NA>        <NA>
# 143     1001447   0     1961        6        4001        <NA>        <NA>
# 145     1001465   0     1942        6        2001        <NA>        <NA>
# 199     1002004   1     1957        2        4002        <NA>        <NA>
# 234     1002354   0     1962        9        4001        <NA>        <NA>
# ...         ...  ..      ...      ...         ...         ...         ...
# 502221  6023054   0     1941        9        4001        <NA>        <NA>
# 502390  6024740   0     1945       12        4001        <NA>        <NA>
# 502417  6025018   0     1960        2        4001        <NA>        <NA>
# 502443  6025273   0     1947        7        4001        <NA>        <NA>
# 502454  6025381   1     1968        1        4002        <NA>        <NA>
#
#        f.22001.0.0 ethnicity      FID
# 68               0      4001  1000697
# 143              0      4001  1001447
# 145              0      2001  1001465
# 199              1      4002  1002004
# 234              0      4001  1002354
# ...            ...       ...      ...
# 502221           0      4001  6023054
# 502390           0      4001  6024740
# 502417           0      4001  6025018
# 502443           0      4001  6025273
# 502454           1      4002  6025381
#
# [9096 rows x 10 columns]

# %%
filtered_afr[["FID","IID","ethnicity"]].to_csv("/mnt/mfs/statgen/UKBiobank/phenotype_files/african_IID/010622_ukb47922_african_9096.iid", sep="\t", index=False)

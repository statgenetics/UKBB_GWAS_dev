# %% [markdown]
# ## AD data

# %% [markdown]
# ## Aim
#
# Create the phenotype files for AD traits to submit with imputed genotype data

# %%
library('dplyr')
library('tidyverse')

# %%
AD <- read.csv('/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20210804_covariate_phenotype.csv')
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %%
dim(AD)
# Out:
# [1] 501492     52

# %%
head(AD, 20)
# Out:
#    eid     Sex Age father_age mother_age PC1       PC2       PC3
# 1  1000019 0   47  70         67         -12.20530  4.761740 -4.255700
# 2  1000022 1   53  73         87         -11.09070  2.936940 -2.832720
# 3  1000035 1   63  78         89         -15.27530  1.349750 -2.993610
# 4  1000046 0   62  74         81         -13.88090  5.013530 -1.770910
# 5  1000054 0   65  75         86         -13.47650  6.713090 -3.988520
# 6  1000063 1   43  70         69          -9.88345  3.599120 -1.265510
# 7  1000078 0   52  54         82         -14.57510  1.273820 -0.340971
# 8  1000081 1   67  72         91          24.35170 -4.644310 24.033900
# 9  1000090 0   64  86         67         -13.71840  1.728210 -4.381130
# 10 1000105 0   54  84         89         -11.94670  3.574030 -2.412200
# 11 1000112 1   58  NA         58         -14.07430  3.418110 -2.648360
# 12 1000129 1   62  69         95         -14.99580  2.973080 -0.447586
# 13 1000137 0   46  60         72         -12.38140  0.908395 -0.808770
# 14 1000141 0   49  80         75         -10.63570  5.847420 -0.257541
# 15 1000153 0   40  49         56               NaN       NaN       NaN
# 16 1000164 0   51  89         84         -16.19100  3.123060 -1.584510
# 17 1000170 0   51  73         72         -10.88910  3.461440 -0.610086
# 18 1000186 1   53  78         78         -13.20310  6.175830  0.294552
# 19 1000198 0   41  65         65         -15.78040  3.962180 -1.457960
# 20 1000203 0   49  82         78         -15.38490  3.342260 -3.965240
#    PC4        PC5       ... PC37        PC38      PC39       PC40
# 1    3.404380 -0.658608 ... -3.65638000 -0.146136 -1.7480800  0.0766507
# 2   -1.161210 -7.517080 ...  3.35086000 -0.226358 -1.6445700 -2.7941000
# 3    8.395020 17.040800 ... -1.60734000  1.774000 -2.6266900  1.6079300
# 4    3.730100  6.774160 ...  1.84519000  0.518179 -1.9768200  3.8931000
# 5    4.354700  8.732250 ... -1.84256000 -2.977780 -2.0998700  0.2277160
# 6    0.911667 -7.905420 ... -1.04767000  1.158770 -4.6970400  5.6865400
# 7    2.392680 -6.357220 ...  1.41995000  3.883190 -1.4112000  3.9230900
# 8  -56.145200  0.190955 ...  0.00500915  1.827430 -1.5636600  0.4964910
# 9    9.998810 21.706300 ... -1.43614000  1.906750  1.6220200  1.9352900
# 10   0.925606  1.545990 ...  0.34081800 -0.697951 -0.1480180 -7.4066300
# 11   5.806180 16.960700 ... -2.86688000  2.020900 -0.9076780  1.2264300
# 12   1.346680 -5.521600 ...  6.61343000 -1.578990  0.3824580  6.7111800
# 13   5.417450  1.633090 ... -0.31728200  1.651100  1.4878600  2.8385700
# 14  -1.826510 -2.003450 ...  7.27974000  1.668210 -3.1088100  1.9718400
# 15        NaN       NaN ...         NaN       NaN        NaN        NaN
# 16   0.098181  0.306786 ... -2.50008000  2.011150  0.3579680 -3.4410500
# 17  -0.106230 -3.364670 ... -2.96116000  2.818800  2.1976300 -3.7583000
# 18   0.794691 -8.076490 ...  2.70070000  5.802830 -0.0382891 -0.8409690
# 19   5.271940  9.916450 ... -1.05011000  2.835350 -1.4097800  0.3667280
# 20   3.996490  9.024210 ... -1.03837000 -3.885370 -1.3501500  1.1954000
#    mice_original mice_normalized_winsorized PUXGBoost_inductive_original
# 1  0.025         -1.959964                  0.5531328
# 2  0.005         -2.575829                  0.5411571
# 3  0.030         -1.880794                  0.4104153
# 4  0.080         -1.405072                  0.4657961
# 5  0.040         -1.750686                  0.4199592
# 6  0.030         -1.880794                  0.3502401
# 7  0.025         -1.959964                  0.4045241
# 8  0.040         -1.750686                  0.3532499
# 9  0.070         -1.475791                  0.5429349
# 10 0.050         -1.644854                  0.3949218
# 11 0.045         -1.695398                  0.4991820
# 12 0.020         -2.053749                  0.4083824
# 13 0.030         -1.880794                  0.3866032
# 14 0.015         -2.170090                  0.4246109
# 15 0.010         -2.326348                  0.3884794
# 16 0.005         -2.575829                  0.4074528
# 17 0.025         -1.959964                  0.4248470
# 18 0.110         -1.226528                  0.5621722
# 19 0.030         -1.880794                  0.3884794
# 20 0.030         -1.880794                  0.4074528
#    PUXGBoost_inductive_normalized_winsorized PUXGBoost_oob_original
# 1   0.133580380                              0.5447879
# 2   0.103349236                              0.5396527
# 3  -0.226476802                              0.4102584
# 4  -0.085841671                              0.4511171
# 5  -0.201997805                              0.4182417
# 6  -0.384672219                              0.3455048
# 7  -0.241654201                              0.4000528
# 8  -0.376561155                              0.3509900
# 9   0.107830435                              0.5573180
# 10 -0.266513609                              0.3737206
# 11 -0.002050298                              0.5063419
# 12 -0.231708125                              0.4072668
# 13 -0.288183341                              0.3902816
# 14 -0.190111447                              0.4273999
# 15 -0.283284576                              0.3914069
# 16 -0.234102120                              0.4060063
# 17 -0.189508875                              0.4123464
# 18  0.156478836                              0.5714958
# 19 -0.283284576                              0.3914294
# 20 -0.234102120                              0.4060429
#    PUXGBoost_oob_normalized_winsorized
# 1   0.11250348
# 2   0.09955888
# 3  -0.22688034
# 4  -0.12283942
# 5  -0.20639371
# 6  -0.39748543
# 7  -0.25321043
# 8  -0.38264915
# 9   0.14417283
# 10 -0.32201517
# 11  0.01589758
# 12 -0.23458139
# 13 -0.27858508
# 14 -0.18299762
# 15 -0.27565403
# 16 -0.23783034
# 17 -0.22151319
# 18  0.18018374
# 19 -0.27559545
# 20 -0.23773605

# %%
names(AD)[names(AD) == "eid"] <- "FID"
AD$IID <- AD$FID

# %%
head(AD)
# Out:
#   FID     Sex Age father_age mother_age PC1       PC2     PC3      PC4
# 1 1000019 0   47  70         67         -12.20530 4.76174 -4.25570  3.404380
# 2 1000022 1   53  73         87         -11.09070 2.93694 -2.83272 -1.161210
# 3 1000035 1   63  78         89         -15.27530 1.34975 -2.99361  8.395020
# 4 1000046 0   62  74         81         -13.88090 5.01353 -1.77091  3.730100
# 5 1000054 0   65  75         86         -13.47650 6.71309 -3.98852  4.354700
# 6 1000063 1   43  70         69          -9.88345 3.59912 -1.26551  0.911667
#   PC5       ... PC38      PC39     PC40       mice_original
# 1 -0.658608 ... -0.146136 -1.74808  0.0766507 0.025
# 2 -7.517080 ... -0.226358 -1.64457 -2.7941000 0.005
# 3 17.040800 ...  1.774000 -2.62669  1.6079300 0.030
# 4  6.774160 ...  0.518179 -1.97682  3.8931000 0.080
# 5  8.732250 ... -2.977780 -2.09987  0.2277160 0.040
# 6 -7.905420 ...  1.158770 -4.69704  5.6865400 0.030
#   mice_normalized_winsorized PUXGBoost_inductive_original
# 1 -1.959964                  0.5531328
# 2 -2.575829                  0.5411571
# 3 -1.880794                  0.4104153
# 4 -1.405072                  0.4657961
# 5 -1.750686                  0.4199592
# 6 -1.880794                  0.3502401
#   PUXGBoost_inductive_normalized_winsorized PUXGBoost_oob_original
# 1  0.13358038                               0.5447879
# 2  0.10334924                               0.5396527
# 3 -0.22647680                               0.4102584
# 4 -0.08584167                               0.4511171
# 5 -0.20199781                               0.4182417
# 6 -0.38467222                               0.3455048
#   PUXGBoost_oob_normalized_winsorized IID
# 1  0.11250348                         1000019
# 2  0.09955888                         1000022
# 3 -0.22688034                         1000035
# 4 -0.12283942                         1000046
# 5 -0.20639371                         1000054
# 6 -0.39748543                         1000063

# %%
AD_phenotypes <- AD %>%
    select(FID, IID, Sex, Age, father_age, mother_age, starts_with('PC'), starts_with('mice'), starts_with('PUX'))

# %%
head(AD_phenotypes, 20)
# Out:
#    FID     IID     Sex Age father_age mother_age PC1       PC2       PC3
# 1  1000019 1000019 0   47  70         67         -12.20530  4.761740 -4.255700
# 2  1000022 1000022 1   53  73         87         -11.09070  2.936940 -2.832720
# 3  1000035 1000035 1   63  78         89         -15.27530  1.349750 -2.993610
# 4  1000046 1000046 0   62  74         81         -13.88090  5.013530 -1.770910
# 5  1000054 1000054 0   65  75         86         -13.47650  6.713090 -3.988520
# 6  1000063 1000063 1   43  70         69          -9.88345  3.599120 -1.265510
# 7  1000078 1000078 0   52  54         82         -14.57510  1.273820 -0.340971
# 8  1000081 1000081 1   67  72         91          24.35170 -4.644310 24.033900
# 9  1000090 1000090 0   64  86         67         -13.71840  1.728210 -4.381130
# 10 1000105 1000105 0   54  84         89         -11.94670  3.574030 -2.412200
# 11 1000112 1000112 1   58  NA         58         -14.07430  3.418110 -2.648360
# 12 1000129 1000129 1   62  69         95         -14.99580  2.973080 -0.447586
# 13 1000137 1000137 0   46  60         72         -12.38140  0.908395 -0.808770
# 14 1000141 1000141 0   49  80         75         -10.63570  5.847420 -0.257541
# 15 1000153 1000153 0   40  49         56               NaN       NaN       NaN
# 16 1000164 1000164 0   51  89         84         -16.19100  3.123060 -1.584510
# 17 1000170 1000170 0   51  73         72         -10.88910  3.461440 -0.610086
# 18 1000186 1000186 1   53  78         78         -13.20310  6.175830  0.294552
# 19 1000198 1000198 0   41  65         65         -15.78040  3.962180 -1.457960
# 20 1000203 1000203 0   49  82         78         -15.38490  3.342260 -3.965240
#    PC4        ... PC37        PC38      PC39       PC40       mice_original
# 1    3.404380 ... -3.65638000 -0.146136 -1.7480800  0.0766507 0.025
# 2   -1.161210 ...  3.35086000 -0.226358 -1.6445700 -2.7941000 0.005
# 3    8.395020 ... -1.60734000  1.774000 -2.6266900  1.6079300 0.030
# 4    3.730100 ...  1.84519000  0.518179 -1.9768200  3.8931000 0.080
# 5    4.354700 ... -1.84256000 -2.977780 -2.0998700  0.2277160 0.040
# 6    0.911667 ... -1.04767000  1.158770 -4.6970400  5.6865400 0.030
# 7    2.392680 ...  1.41995000  3.883190 -1.4112000  3.9230900 0.025
# 8  -56.145200 ...  0.00500915  1.827430 -1.5636600  0.4964910 0.040
# 9    9.998810 ... -1.43614000  1.906750  1.6220200  1.9352900 0.070
# 10   0.925606 ...  0.34081800 -0.697951 -0.1480180 -7.4066300 0.050
# 11   5.806180 ... -2.86688000  2.020900 -0.9076780  1.2264300 0.045
# 12   1.346680 ...  6.61343000 -1.578990  0.3824580  6.7111800 0.020
# 13   5.417450 ... -0.31728200  1.651100  1.4878600  2.8385700 0.030
# 14  -1.826510 ...  7.27974000  1.668210 -3.1088100  1.9718400 0.015
# 15        NaN ...         NaN       NaN        NaN        NaN 0.010
# 16   0.098181 ... -2.50008000  2.011150  0.3579680 -3.4410500 0.005
# 17  -0.106230 ... -2.96116000  2.818800  2.1976300 -3.7583000 0.025
# 18   0.794691 ...  2.70070000  5.802830 -0.0382891 -0.8409690 0.110
# 19   5.271940 ... -1.05011000  2.835350 -1.4097800  0.3667280 0.030
# 20   3.996490 ... -1.03837000 -3.885370 -1.3501500  1.1954000 0.030
#    mice_normalized_winsorized PUXGBoost_inductive_original
# 1  -1.959964                  0.5531328
# 2  -2.575829                  0.5411571
# 3  -1.880794                  0.4104153
# 4  -1.405072                  0.4657961
# 5  -1.750686                  0.4199592
# 6  -1.880794                  0.3502401
# 7  -1.959964                  0.4045241
# 8  -1.750686                  0.3532499
# 9  -1.475791                  0.5429349
# 10 -1.644854                  0.3949218
# 11 -1.695398                  0.4991820
# 12 -2.053749                  0.4083824
# 13 -1.880794                  0.3866032
# 14 -2.170090                  0.4246109
# 15 -2.326348                  0.3884794
# 16 -2.575829                  0.4074528
# 17 -1.959964                  0.4248470
# 18 -1.226528                  0.5621722
# 19 -1.880794                  0.3884794
# 20 -1.880794                  0.4074528
#    PUXGBoost_inductive_normalized_winsorized PUXGBoost_oob_original
# 1   0.133580380                              0.5447879
# 2   0.103349236                              0.5396527
# 3  -0.226476802                              0.4102584
# 4  -0.085841671                              0.4511171
# 5  -0.201997805                              0.4182417
# 6  -0.384672219                              0.3455048
# 7  -0.241654201                              0.4000528
# 8  -0.376561155                              0.3509900
# 9   0.107830435                              0.5573180
# 10 -0.266513609                              0.3737206
# 11 -0.002050298                              0.5063419
# 12 -0.231708125                              0.4072668
# 13 -0.288183341                              0.3902816
# 14 -0.190111447                              0.4273999
# 15 -0.283284576                              0.3914069
# 16 -0.234102120                              0.4060063
# 17 -0.189508875                              0.4123464
# 18  0.156478836                              0.5714958
# 19 -0.283284576                              0.3914294
# 20 -0.234102120                              0.4060429
#    PUXGBoost_oob_normalized_winsorized
# 1   0.11250348
# 2   0.09955888
# 3  -0.22688034
# 4  -0.12283942
# 5  -0.20639371
# 6  -0.39748543
# 7  -0.25321043
# 8  -0.38264915
# 9   0.14417283
# 10 -0.32201517
# 11  0.01589758
# 12 -0.23458139
# 13 -0.27858508
# 14 -0.18299762
# 15 -0.27565403
# 16 -0.23783034
# 17 -0.22151319
# 18  0.18018374
# 19 -0.27559545
# 20 -0.23773605

# %%
complete_cases <- AD_phenotypes %>%
        drop_na()

# %%
dim(complete_cases)
# Out:
# [1] 460632     52

# %%
head(complete_cases, 20)
# Out:
#    FID     IID     Sex Age father_age mother_age PC1       PC2       PC3
# 1  1000019 1000019 0   47  70         67         -12.20530  4.761740 -4.255700
# 2  1000022 1000022 1   53  73         87         -11.09070  2.936940 -2.832720
# 3  1000035 1000035 1   63  78         89         -15.27530  1.349750 -2.993610
# 4  1000046 1000046 0   62  74         81         -13.88090  5.013530 -1.770910
# 5  1000054 1000054 0   65  75         86         -13.47650  6.713090 -3.988520
# 6  1000063 1000063 1   43  70         69          -9.88345  3.599120 -1.265510
# 7  1000078 1000078 0   52  54         82         -14.57510  1.273820 -0.340971
# 8  1000081 1000081 1   67  72         91          24.35170 -4.644310 24.033900
# 9  1000090 1000090 0   64  86         67         -13.71840  1.728210 -4.381130
# 10 1000105 1000105 0   54  84         89         -11.94670  3.574030 -2.412200
# 11 1000129 1000129 1   62  69         95         -14.99580  2.973080 -0.447586
# 12 1000137 1000137 0   46  60         72         -12.38140  0.908395 -0.808770
# 13 1000141 1000141 0   49  80         75         -10.63570  5.847420 -0.257541
# 14 1000164 1000164 0   51  89         84         -16.19100  3.123060 -1.584510
# 15 1000170 1000170 0   51  73         72         -10.88910  3.461440 -0.610086
# 16 1000186 1000186 1   53  78         78         -13.20310  6.175830  0.294552
# 17 1000198 1000198 0   41  65         65         -15.78040  3.962180 -1.457960
# 18 1000203 1000203 0   49  82         78         -15.38490  3.342260 -3.965240
# 19 1000210 1000210 1   66  84         65         -12.56780  6.088840 -2.566460
# 20 1000224 1000224 0   58  86         87         -12.55110  2.150950 -3.043000
#    PC4        ... PC37        PC38      PC39       PC40       mice_original
# 1    3.404380 ... -3.65638000 -0.146136 -1.7480800  0.0766507 0.025
# 2   -1.161210 ...  3.35086000 -0.226358 -1.6445700 -2.7941000 0.005
# 3    8.395020 ... -1.60734000  1.774000 -2.6266900  1.6079300 0.030
# 4    3.730100 ...  1.84519000  0.518179 -1.9768200  3.8931000 0.080
# 5    4.354700 ... -1.84256000 -2.977780 -2.0998700  0.2277160 0.040
# 6    0.911667 ... -1.04767000  1.158770 -4.6970400  5.6865400 0.030
# 7    2.392680 ...  1.41995000  3.883190 -1.4112000  3.9230900 0.025
# 8  -56.145200 ...  0.00500915  1.827430 -1.5636600  0.4964910 0.040
# 9    9.998810 ... -1.43614000  1.906750  1.6220200  1.9352900 0.070
# 10   0.925606 ...  0.34081800 -0.697951 -0.1480180 -7.4066300 0.050
# 11   1.346680 ...  6.61343000 -1.578990  0.3824580  6.7111800 0.020
# 12   5.417450 ... -0.31728200  1.651100  1.4878600  2.8385700 0.030
# 13  -1.826510 ...  7.27974000  1.668210 -3.1088100  1.9718400 0.015
# 14   0.098181 ... -2.50008000  2.011150  0.3579680 -3.4410500 0.005
# 15  -0.106230 ... -2.96116000  2.818800  2.1976300 -3.7583000 0.025
# 16   0.794691 ...  2.70070000  5.802830 -0.0382891 -0.8409690 0.110
# 17   5.271940 ... -1.05011000  2.835350 -1.4097800  0.3667280 0.030
# 18   3.996490 ... -1.03837000 -3.885370 -1.3501500  1.1954000 0.030
# 19   2.907740 ... -2.89490000 -0.507303 -1.3713000  0.5078900 0.055
# 20   1.499950 ... -2.10550000 -1.862260 -0.1270490 -0.6747940 0.040
#    mice_normalized_winsorized PUXGBoost_inductive_original
# 1  -1.959964                  0.5531328
# 2  -2.575829                  0.5411571
# 3  -1.880794                  0.4104153
# 4  -1.405072                  0.4657961
# 5  -1.750686                  0.4199592
# 6  -1.880794                  0.3502401
# 7  -1.959964                  0.4045241
# 8  -1.750686                  0.3532499
# 9  -1.475791                  0.5429349
# 10 -1.644854                  0.3949218
# 11 -2.053749                  0.4083824
# 12 -1.880794                  0.3866032
# 13 -2.170090                  0.4246109
# 14 -2.575829                  0.4074528
# 15 -1.959964                  0.4248470
# 16 -1.226528                  0.5621722
# 17 -1.880794                  0.3884794
# 18 -1.880794                  0.4074528
# 19 -1.598193                  0.5582297
# 20 -1.750686                  0.4835414
#    PUXGBoost_inductive_normalized_winsorized PUXGBoost_oob_original
# 1   0.13358038                               0.5447879
# 2   0.10334924                               0.5396527
# 3  -0.22647680                               0.4102584
# 4  -0.08584167                               0.4511171
# 5  -0.20199781                               0.4182417
# 6  -0.38467222                               0.3455048
# 7  -0.24165420                               0.4000528
# 8  -0.37656116                               0.3509900
# 9   0.10783044                               0.5573180
# 10 -0.26651361                               0.3737206
# 11 -0.23170813                               0.4072668
# 12 -0.28818334                               0.3902816
# 13 -0.19011145                               0.4273999
# 14 -0.23410212                               0.4060063
# 15 -0.18950887                               0.4123464
# 16  0.15647884                               0.5714958
# 17 -0.28328458                               0.3914294
# 18 -0.23410212                               0.4060429
# 19  0.14648238                               0.5664537
# 20 -0.04126730                               0.5096873
#    PUXGBoost_oob_normalized_winsorized
# 1   0.11250348
# 2   0.09955888
# 3  -0.22688034
# 4  -0.12283942
# 5  -0.20639371
# 6  -0.39748543
# 7  -0.25321043
# 8  -0.38264915
# 9   0.14417283
# 10 -0.32201517
# 11 -0.23458139
# 12 -0.27858508
# 13 -0.18299762
# 14 -0.23783034
# 15 -0.22151319
# 16  0.18018374
# 17 -0.27559545
# 18 -0.23773605
# 19  0.16735271
# 20  0.02428477

# %%
nan_AD <- AD_phenotypes %>%
    filter_all(any_vars(is.nan(.)))

# %%
na_AD <- AD_phenotypes %>%
    filter_all(any_vars(is.na(.)))

# %%
dim(nan_AD)
# Out:
# [1] 14205    52

# %%
dim(na_AD)
# Out:
# [1] 40860    52

# %% [markdown]
# ## Write file with complete cases for regenie analysis

# %%
write.table(complete_cases, file='/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20210804_covariate_phenotype_completecases_460632.tsv', row.names=F, sep='\t', quote=F)

# %% [markdown]
# ## 092121 Phenotype file

# %%
AD <- read.csv('/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20210921_covariate_ltfh_no_NA.csv')

# %%
dim(AD)
# Out:
# [1] 449310     46

# %%
head(AD)
# Out:
#   eid     Sex Age father_age mother_age PC1       PC2     PC3      PC4
# 1 1000019 0   47  70         67         -12.20530 4.76174 -4.25570  3.404380
# 2 1000022 1   53  73         87         -11.09070 2.93694 -2.83272 -1.161210
# 3 1000035 1   63  78         89         -15.27530 1.34975 -2.99361  8.395020
# 4 1000046 0   62  74         81         -13.88090 5.01353 -1.77091  3.730100
# 5 1000054 0   65  75         86         -13.47650 6.71309 -3.98852  4.354700
# 6 1000063 1   43  70         69          -9.88345 3.59912 -1.26551  0.911667
#   PC5       ... PC32       PC33      PC34       PC35      PC36      PC37
# 1 -0.658608 ... -1.5038100 -0.592780  1.2595800  2.669530  3.413450 -3.65638
# 2 -7.517080 ...  1.9325500  1.576150 -0.0734071 -3.324260 -3.989780  3.35086
# 3 17.040800 ...  0.0728806 -3.924350  1.1922200 -0.880838  1.297700 -1.60734
# 4  6.774160 ...  3.0748600  2.842230  2.7507300 -2.837840  2.521430  1.84519
# 5  8.732250 ...  1.1660200 -0.784533 -0.3697420 -4.298070  1.246270 -1.84256
# 6 -7.905420 ...  0.7911460 -2.390580  0.1095570 -2.884630 -0.474187 -1.04767
#   PC38      PC39     PC40       ltfh
# 1 -0.146136 -1.74808  0.0766507 -0.04423335
# 2 -0.226358 -1.64457 -2.7941000 -0.04778911
# 3  1.774000 -2.62669  1.6079300 -0.08916909
# 4  0.518179 -1.97682  3.8931000 -0.08916909
# 5 -2.977780 -2.09987  0.2277160 -0.08916909
# 6  1.158770 -4.69704  5.6865400 -0.08916909

# %%
names(AD)[names(AD) == "eid"] <- "FID"
AD$IID <- AD$FID
head(AD)
AD$IID <- as.character(AD$IID)
AD$FID <- as.character(AD$FID)
# Out:
#   FID     Sex Age father_age mother_age PC1       PC2     PC3      PC4
# 1 1000019 0   47  70         67         -12.20530 4.76174 -4.25570  3.404380
# 2 1000022 1   53  73         87         -11.09070 2.93694 -2.83272 -1.161210
# 3 1000035 1   63  78         89         -15.27530 1.34975 -2.99361  8.395020
# 4 1000046 0   62  74         81         -13.88090 5.01353 -1.77091  3.730100
# 5 1000054 0   65  75         86         -13.47650 6.71309 -3.98852  4.354700
# 6 1000063 1   43  70         69          -9.88345 3.59912 -1.26551  0.911667
#   PC5       ... PC33      PC34       PC35      PC36      PC37     PC38
# 1 -0.658608 ... -0.592780  1.2595800  2.669530  3.413450 -3.65638 -0.146136
# 2 -7.517080 ...  1.576150 -0.0734071 -3.324260 -3.989780  3.35086 -0.226358
# 3 17.040800 ... -3.924350  1.1922200 -0.880838  1.297700 -1.60734  1.774000
# 4  6.774160 ...  2.842230  2.7507300 -2.837840  2.521430  1.84519  0.518179
# 5  8.732250 ... -0.784533 -0.3697420 -4.298070  1.246270 -1.84256 -2.977780
# 6 -7.905420 ... -2.390580  0.1095570 -2.884630 -0.474187 -1.04767  1.158770
#   PC39     PC40       ltfh        IID
# 1 -1.74808  0.0766507 -0.04423335 1000019
# 2 -1.64457 -2.7941000 -0.04778911 1000022
# 3 -2.62669  1.6079300 -0.08916909 1000035
# 4 -1.97682  3.8931000 -0.08916909 1000046
# 5 -2.09987  0.2277160 -0.08916909 1000054
# 6 -4.69704  5.6865400 -0.08916909 1000063

# %%
AD_phenotypes <- AD %>%
    select(FID, IID, Sex, Age, father_age, mother_age, starts_with('PC'), ltfh)
head(AD_phenotypes)
# Out:
#   FID     IID     Sex Age father_age mother_age PC1       PC2     PC3
# 1 1000019 1000019 0   47  70         67         -12.20530 4.76174 -4.25570
# 2 1000022 1000022 1   53  73         87         -11.09070 2.93694 -2.83272
# 3 1000035 1000035 1   63  78         89         -15.27530 1.34975 -2.99361
# 4 1000046 1000046 0   62  74         81         -13.88090 5.01353 -1.77091
# 5 1000054 1000054 0   65  75         86         -13.47650 6.71309 -3.98852
# 6 1000063 1000063 1   43  70         69          -9.88345 3.59912 -1.26551
#   PC4       ... PC32       PC33      PC34       PC35      PC36      PC37
# 1  3.404380 ... -1.5038100 -0.592780  1.2595800  2.669530  3.413450 -3.65638
# 2 -1.161210 ...  1.9325500  1.576150 -0.0734071 -3.324260 -3.989780  3.35086
# 3  8.395020 ...  0.0728806 -3.924350  1.1922200 -0.880838  1.297700 -1.60734
# 4  3.730100 ...  3.0748600  2.842230  2.7507300 -2.837840  2.521430  1.84519
# 5  4.354700 ...  1.1660200 -0.784533 -0.3697420 -4.298070  1.246270 -1.84256
# 6  0.911667 ...  0.7911460 -2.390580  0.1095570 -2.884630 -0.474187 -1.04767
#   PC38      PC39     PC40       ltfh
# 1 -0.146136 -1.74808  0.0766507 -0.04423335
# 2 -0.226358 -1.64457 -2.7941000 -0.04778911
# 3  1.774000 -2.62669  1.6079300 -0.08916909
# 4  0.518179 -1.97682  3.8931000 -0.08916909
# 5 -2.977780 -2.09987  0.2277160 -0.08916909
# 6  1.158770 -4.69704  5.6865400 -0.08916909

# %%
str(AD_phenotypes)
# Out:
# 'data.frame':	449310 obs. of  47 variables:
#  $ FID       : chr  "1000019" "1000022" "1000035" "1000046" ...
#  $ IID       : chr  "1000019" "1000022" "1000035" "1000046" ...
#  $ Sex       : int  0 1 1 0 0 1 0 1 0 0 ...
#  $ Age       : int  47 53 63 62 65 43 52 67 64 54 ...
#  $ father_age: int  70 73 78 74 75 70 54 72 86 84 ...
#  $ mother_age: int  67 87 89 81 86 69 82 91 67 89 ...
#  $ PC1       : num  -12.2 -11.1 -15.3 -13.9 -13.5 ...
#  $ PC2       : num  4.76 2.94 1.35 5.01 6.71 ...
#  $ PC3       : num  -4.26 -2.83 -2.99 -1.77 -3.99 ...
#  $ PC4       : num  3.4 -1.16 8.4 3.73 4.35 ...
#  $ PC5       : num  -0.659 -7.517 17.041 6.774 8.732 ...
#  $ PC6       : num  0.782 -3.193 1.703 -2.294 -0.497 ...
#  $ PC7       : num  2.47 -1.38 -1.47 1.77 3.41 ...
#  $ PC8       : num  0.871 -1.902 0.977 -0.409 0.491 ...
#  $ PC9       : num  -8.79 1.66 4.29 2.27 1.17 ...
#  $ PC10      : num  -3.2 -1.996 -1.396 -0.622 -2.777 ...
#  $ PC11      : num  -1.905 0.616 -4.824 -1.812 -2.299 ...
#  $ PC12      : num  5.007 -3.169 5.92 0.644 -1.634 ...
#  $ PC13      : num  2.111 1.007 1.219 0.988 -0.685 ...
#  $ PC14      : num  1.77 -1.45 11.11 -1.53 4.3 ...
#  $ PC15      : num  0.14 -2.823 -0.852 0.718 1.269 ...
#  $ PC16      : num  1.05 -2.46 -2.76 -1.69 -1.36 ...
#  $ PC17      : num  2.916 -0.104 -0.322 1.516 -0.318 ...
#  $ PC18      : num  2.248 -0.11 -6.132 2.631 -0.037 ...
#  $ PC19      : num  -3.968 -2.38 2.95 -0.197 0.266 ...
#  $ PC20      : num  -4.272 0.964 -6.721 -3.324 -2.764 ...
#  $ PC21      : num  0.351 0.152 -5.764 2.124 0.58 ...
#  $ PC22      : num  1.82 -5.05 7.6 2.99 12.07 ...
#  $ PC23      : num  0.515 5.407 1.243 -0.766 4.48 ...
#  $ PC24      : num  0.95 -3.128 -1.376 -0.82 -0.743 ...
#  $ PC25      : num  -1.569 6.251 -3.436 -0.799 -3.426 ...
#  $ PC26      : num  -2.525 -0.159 0.378 1.287 4.1 ...
#  $ PC27      : num  -1.056 0.112 4.244 4.483 -0.932 ...
#  $ PC28      : num  1.281 -0.476 -5.661 3.168 1.798 ...
#  $ PC29      : num  0.963 -0.555 3.03 -0.129 -0.79 ...
#  $ PC30      : num  1.468 0.681 -1.031 0.386 -2.899 ...
#  $ PC31      : num  -3.2547 3.7492 1.0381 -0.011 -0.0462 ...
#  $ PC32      : num  -1.5038 1.9325 0.0729 3.0749 1.166 ...
#  $ PC33      : num  -0.593 1.576 -3.924 2.842 -0.785 ...
#  $ PC34      : num  1.2596 -0.0734 1.1922 2.7507 -0.3697 ...
#  $ PC35      : num  2.67 -3.324 -0.881 -2.838 -4.298 ...
#  $ PC36      : num  3.41 -3.99 1.3 2.52 1.25 ...
#  $ PC37      : num  -3.66 3.35 -1.61 1.85 -1.84 ...
#  $ PC38      : num  -0.146 -0.226 1.774 0.518 -2.978 ...
#  $ PC39      : num  -1.75 -1.64 -2.63 -1.98 -2.1 ...
#  $ PC40      : num  0.0767 -2.7941 1.6079 3.8931 0.2277 ...
#  $ ltfh      : num  -0.0442 -0.0478 -0.0892 -0.0892 -0.0892 ...

# %%
write.table(AD_phenotypes, file='/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20210921_covariate_ltfh_no_NA_449310ind.tsv', row.names=F, sep='\t', quote=F)

# %%
import pandas as pd
import numpy as np
dat = pd.read_csv('/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20210921_covariate_ltfh_no_NA_449310ind.tsv', header=0, delimiter='\t', dtype=str)
dat = dat.replace(to_replace =np.nan, value ="NA")

# %%
dat.head()
# Out:
#        FID      IID Sex Age father_age mother_age       PC1      PC2  \
# 0  1000019  1000019   0  47         70         67  -12.2053  4.76174
# 1  1000022  1000022   1  53         73         87  -11.0907  2.93694
# 2  1000035  1000035   1  63         78         89  -15.2753  1.34975
# 3  1000046  1000046   0  62         74         81  -13.8809  5.01353
# 4  1000054  1000054   0  65         75         86  -13.4765  6.71309
#
#         PC3       PC4  ...       PC32       PC33        PC34       PC35  \
# 0   -4.2557   3.40438  ...   -1.50381   -0.59278     1.25958    2.66953
# 1  -2.83272  -1.16121  ...    1.93255    1.57615  -0.0734071   -3.32426
# 2  -2.99361   8.39502  ...  0.0728806   -3.92435     1.19222  -0.880838
# 3  -1.77091    3.7301  ...    3.07486    2.84223     2.75073   -2.83784
# 4  -3.98852    4.3547  ...    1.16602  -0.784533   -0.369742   -4.29807
#
#        PC36      PC37       PC38      PC39       PC40                 ltfh
# 0   3.41345  -3.65638  -0.146136  -1.74808  0.0766507  -0.0442333526777836
# 1  -3.98978   3.35086  -0.226358  -1.64457    -2.7941  -0.0477891117131986
# 2    1.2977  -1.60734      1.774  -2.62669    1.60793  -0.0891690922019564
# 3   2.52143   1.84519   0.518179  -1.97682     3.8931  -0.0891690922019564
# 4   1.24627  -1.84256   -2.97778  -2.09987   0.227716  -0.0891690922019564
#
# [5 rows x 47 columns]

# %%
 dat.to_csv("~/test/phenotype.regenie_phenotype", sep='\t', index=False, columns = ['FID', 'IID'] + 'ltfh')

# %% [markdown]
# ### Columbia's cluster
#
# Run this cell if running your jobs on Columbia's cluster

# %%
# Common variables Columbia's cluster
UKBB_PATH=$HOME/UKBiobank
UKBB_yale=$HOME/UKBiobank_Yale_transfer
USER_PATH=$HOME/project
container_lmm=$HOME/containers/lmm.sif
container_marp=$HOME/containers/marp.sif
container_annovar=$HOME/containers/gatk4-annovar.sif
hearing_pheno_path=$UKBB_PATH/phenotype_files/hearing_impairment
AD_pheno_path=$UKBB_PATH/phenotype_files/AD_phenotypes
tpl_file=$USER_PATH/bioworkflows/admin/csg.yml
formatFile_fastgwa=$USER_PATH/UKBB_GWAS_dev/data/fastGWA_template.yml
formatFile_bolt=$USER_PATH/UKBB_GWAS_dev/data/boltlmm_template.yml
formatFile_saige=$USER_PATH/UKBB_GWAS_dev/data/saige_template.yml
formatFile_regenie=$USER_PATH/UKBB_GWAS_dev/data/regenie_template.yml
###bfile=$UKBB_yale/pleiotropy_geneticfiles/UKB_Caucasians_phenotypeindepqc120319_updated082020removedwithdrawnindiv.bed
unrelated_samples=$UKBB_yale/pleiotropy_geneticfiles/unrelated_n307259/UKB_unrelatedcauc_phenotypes_asthmat2dbmiwaisthip_agesex_waisthipratio_040620

# Cleaned Imputed data BGEN input
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample

# Non-QC'ed Exome data PLINK input (as downloaded from the UKBB)
genoFile=`echo $UKBB_yale/ukb28374_exomedata/exome_data_OCT2020/ukb23155_c{1..22}_b0_v1.bed`

# %% [markdown]
# ## Shared variables for workflows and results

# %%
# Workflows
lmm_sos=$USER_PATH/bioworkflows/GWAS/LMM.ipynb
anno_sos=$USER_PATH/bioworkflows/variant-annotation/annovar.ipynb
clumping_sos=$USER_PATH/bioworkflows/GWAS/LD_Clumping.ipynb
extract_sos=$USER_PATH/bioworkflows/GWAS/Region_Extraction.ipynb

# LMM directories for imputed data
lmm_imp_dir_fastgwa=$UKBB_PATH/results/FastGWA_results/results_imputed_data
lmm_imp_dir_bolt=$UKBB_PATH/results/BOLTLMM_results/results_imputed_data
lmm_imp_dir_saige=$UKBB_PATH/results/SAIGE_results/results_imputed_data
lmm_imp_dir_regenie=$UKBB_PATH/results/REGENIE_results/results_imputed_data

# LMM directories for exome data
lmm_exome_dir_fastgwa=$UKBB_PATH/results/FastGWA_results/results_exome_data
lmm_exome_dir_bolt=$UKBB_PATH/results/BOLTLMM_results/results_exome_data
lmm_exome_dir_saige=$UKBB_PATH/results/SAIGE_results/results_exome_data
lmm_exome_dir_regenie=$UKBB_PATH/results/REGENIE_results/results_exome_data

# %% [markdown]
# ## Specification of LMM variables

# %%
## LMM variables 
### Specific to REGENIE
bsize=1000
lowmem=$HOME/scratch60/
lowmem_dir=$HOME/scratch60/predictions
trait=
minMAC=4
bgenMinINFO=0.8
# Quality control applied on genotype array data prior to running regenie
maf_filter=0.01
geno_filter=0.01
hwe_filter=5e-08
mind_filter=0.1
reverse_log_p=True

# %% [markdown]
# ## Scripts for job submission on imputed data

# %% [markdown]
# ## Analysis 08/09/2021

# %% [markdown]
# ### AD submission for imputed data

# %%
lmm_dir_regenie=$lmm_imp_dir_regenie/AD_080921_complete_cases
lmm_sbatch_regenie=$USER_PATH/UKBB_GWAS_dev/output/AD_080921_complete_cases-regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$AD_pheno_path/20210804_covariate_phenotype_completecases_460632.tsv
covarFile=$AD_pheno_path/20210804_covariate_phenotype_completecases_460632.tsv
phenoCol="mice_original mice_normalized_winsorized PUXGBoost_inductive_original PUXGBoost_inductive_normalized_winsorized PUXGBoost_oob_original PUXGBoost_oob_normalized_winsorized"
covarCol=Sex
qCovarCol="Age father_age mother_age PC1 PC2 PC3 PC4 PC5 PC6 PC7 PC8 PC9 PC10 PC11 PC12 PC13 PC14 PC15 PC16"
trait=
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
ylim=0
job_size=1
numThreads=22
#Use the original bed files for the genotype array on regenie step1
bfile=$UKBB_yale/pleiotropy_geneticfiles/UKB_originalgenotypefilesdownloaded083019/UKB_genotypedatadownloaded083019.bed

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $job_size
    --ylim $ylim
    --reverse_log_p $reverse_log_p
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/project/UKBB_GWAS_dev/output/AD_080921_complete_cases-regenie_2021-08-09.sbatch
# INFO: Workflow csg (ID=w501267848827c91b) is executed successfully with 1 completed step.

# %%
cd /UKBiobank/results/REGENIE_results/results_imputed_data/AD_080921_complete_cases
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %% [markdown]
# ## Analysis 09/21/21

# %%
lmm_dir_regenie=$lmm_imp_dir_regenie/092121_AD_Rui
lmm_sbatch_regenie=$USER_PATH/UKBB_GWAS_dev/output/AD_Rui-regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$AD_pheno_path/20210921_covariate_ltfh_no_NA_449310ind.tsv
covarFile=$AD_pheno_path/20210921_covariate_ltfh_no_NA_449310ind.tsv
phenoCol=ltfh
covarCol=Sex
qCovarCol="Age father_age mother_age PC1 PC2 PC3 PC4 PC5 PC6 PC7 PC8 PC9 PC10 PC11 PC12 PC13 PC14 PC15 PC16"
trait=
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
ylim=0
job_size=1
numThreads=22
#Use the original bed files that passed QC using Megan's parameters geno=0.01, mind=0.1, maf=0.01, hwe=5e-08
bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# Quality control applied on genotype array data prior to running regenie
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
reverse_log_p=True

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $job_size
    --ylim $ylim
    --reverse_log_p $reverse_log_p
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/project/UKBB_GWAS_dev/output/AD_Rui-regenie_2021-09-21.sbatch
# INFO: Workflow csg (ID=w94f977221b576677) is executed successfully with 1 completed step.

# %% [markdown]
# ## Analysis 10/07/21

# %%
AD_mice <- read.csv('/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20211004_covariate_phenotype_MICE_kNN_FH_COG_modif.csv')

# %%
AD_puoob <- read.csv('/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20211004_covariate_phenotype_MICE_or_PUoob_FH_or_COG.csv')

# %%
dim(AD_mice)
dim(AD_puoob)
# Out:
# [1] 383859     47
# [1] 501492     54

# %%
head(AD_mice)
head(AD_puoob)
# Out:
#   eid     Sex Age father_age mother_age PC1      PC2      PC3       PC4
# 1 1000022 1   53  73         87         -11.0907  2.93694 -2.832720  -1.16121
# 2 1000035 1   63  78         89         -15.2753  1.34975 -2.993610   8.39502
# 3 1000046 0   62  74         81         -13.8809  5.01353 -1.770910   3.73010
# 4 1000054 0   65  75         86         -13.4765  6.71309 -3.988520   4.35470
# 5 1000078 0   52  54         82         -14.5751  1.27382 -0.340971   2.39268
# 6 1000081 1   67  72         91          24.3517 -4.64431 24.033900 -56.14520
#   PC5       ... PC33       PC34       PC35      PC36     PC37        PC38
# 1 -7.517080 ...  1.5761500 -0.0734071 -3.324260 -3.98978  3.35086000 -0.226358
# 2 17.040800 ... -3.9243500  1.1922200 -0.880838  1.29770 -1.60734000  1.774000
# 3  6.774160 ...  2.8422300  2.7507300 -2.837840  2.52143  1.84519000  0.518179
# 4  8.732250 ... -0.7845330 -0.3697420 -4.298070  1.24627 -1.84256000 -2.977780
# 5 -6.357220 ... -0.0486886 -0.0276104  3.125560 -0.15693  1.41995000  3.883190
# 6  0.190955 ...  2.4419800 -1.8196000  1.200260 -2.51161  0.00500915  1.827430
#   PC39     PC40      mice_kNN_FH_COG_ori mice_kNN_FH_COG_nw
# 1 -1.64457 -2.794100 0.01815789          -2.093374
# 2 -2.62669  1.607930 0.03500000          -1.811911
# 3 -1.97682  3.893100 0.04921053          -1.652557
# 4 -2.09987  0.227716 0.03500000          -1.811911
# 5 -1.41120  3.923090 0.02052632          -2.042998
# 6 -1.56366  0.496491 0.02000000          -2.053749
#   FID     Sex Age father_age mother_age PC1       PC2     PC3      PC4
# 1 1000019 0   47  70         67         -12.20530 4.76174 -4.25570  3.404380
# 2 1000022 1   53  73         87         -11.09070 2.93694 -2.83272 -1.161210
# 3 1000035 1   63  78         89         -15.27530 1.34975 -2.99361  8.395020
# 4 1000046 0   62  74         81         -13.88090 5.01353 -1.77091  3.730100
# 5 1000054 0   65  75         86         -13.47650 6.71309 -3.98852  4.354700
# 6 1000063 1   43  70         69          -9.88345 3.59912 -1.26551  0.911667
#   PC5       ... PC40       mice_FH_ori mice_FH_nw mice_COG_ori mice_COG_nw
# 1 -0.658608 ...  0.0766507 0.055       -1.598193  0.045        -1.695398
# 2 -7.517080 ... -2.7941000 0.045       -1.695398  0.010        -2.326348
# 3 17.040800 ...  1.6079300 0.045       -1.695398  0.015        -2.170090
# 4  6.774160 ...  3.8931000 0.040       -1.750686  0.090        -1.340755
# 5  8.732250 ...  0.2277160 0.030       -1.880794  0.040        -1.750686
# 6 -7.905420 ...  5.6865400 0.035       -1.811911  0.030        -1.880794
#   PUoob_FH_ori PUoob_FH_nw PUoob_COG_ori PUoob_COG_nw  IID
# 1 0.5844285     0.2132358  0.4981464     -0.0046462365 1000019
# 2 0.5593047     0.1492066  0.4905649     -0.0236525299 1000022
# 3 0.4401646    -0.1505518  0.5000590      0.0001477754 1000035
# 4 0.4401793    -0.1505147  0.5067844      0.0170067002 1000046
# 5 0.4401661    -0.1505481  0.5104447      0.0261840360 1000054
# 6 0.4401781    -0.1505176  0.4931394     -0.0171977709 1000063

# %%
names(AD_mice)[names(AD_mice) == "eid"] <- "FID"
AD_mice$IID <- AD_mice$FID
head(AD_mice)
AD_mice$IID <- as.character(AD_mice$IID)
AD_mice$FID <- as.character(AD_mice$FID)
# Out:
#   FID     Sex Age father_age mother_age PC1      PC2      PC3       PC4
# 1 1000022 1   53  73         87         -11.0907  2.93694 -2.832720  -1.16121
# 2 1000035 1   63  78         89         -15.2753  1.34975 -2.993610   8.39502
# 3 1000046 0   62  74         81         -13.8809  5.01353 -1.770910   3.73010
# 4 1000054 0   65  75         86         -13.4765  6.71309 -3.988520   4.35470
# 5 1000078 0   52  54         82         -14.5751  1.27382 -0.340971   2.39268
# 6 1000081 1   67  72         91          24.3517 -4.64431 24.033900 -56.14520
#   PC5       ... PC34       PC35      PC36     PC37        PC38      PC39
# 1 -7.517080 ... -0.0734071 -3.324260 -3.98978  3.35086000 -0.226358 -1.64457
# 2 17.040800 ...  1.1922200 -0.880838  1.29770 -1.60734000  1.774000 -2.62669
# 3  6.774160 ...  2.7507300 -2.837840  2.52143  1.84519000  0.518179 -1.97682
# 4  8.732250 ... -0.3697420 -4.298070  1.24627 -1.84256000 -2.977780 -2.09987
# 5 -6.357220 ... -0.0276104  3.125560 -0.15693  1.41995000  3.883190 -1.41120
# 6  0.190955 ... -1.8196000  1.200260 -2.51161  0.00500915  1.827430 -1.56366
#   PC40      mice_kNN_FH_COG_ori mice_kNN_FH_COG_nw IID
# 1 -2.794100 0.01815789          -2.093374          1000022
# 2  1.607930 0.03500000          -1.811911          1000035
# 3  3.893100 0.04921053          -1.652557          1000046
# 4  0.227716 0.03500000          -1.811911          1000054
# 5  3.923090 0.02052632          -2.042998          1000078
# 6  0.496491 0.02000000          -2.053749          1000081

# %%
names(AD_puoob)[names(AD_puoob) == "eid"] <- "FID"
AD_puoob$IID <- AD_puoob$FID
head(AD_puoob)
AD_puoob$IID <- as.character(AD_puoob$IID)
AD_puoob$FID <- as.character(AD_puoob$FID)
# Out:
#   FID     Sex Age father_age mother_age PC1       PC2     PC3      PC4
# 1 1000019 0   47  70         67         -12.20530 4.76174 -4.25570  3.404380
# 2 1000022 1   53  73         87         -11.09070 2.93694 -2.83272 -1.161210
# 3 1000035 1   63  78         89         -15.27530 1.34975 -2.99361  8.395020
# 4 1000046 0   62  74         81         -13.88090 5.01353 -1.77091  3.730100
# 5 1000054 0   65  75         86         -13.47650 6.71309 -3.98852  4.354700
# 6 1000063 1   43  70         69          -9.88345 3.59912 -1.26551  0.911667
#   PC5       ... PC40       mice_FH_ori mice_FH_nw mice_COG_ori mice_COG_nw
# 1 -0.658608 ...  0.0766507 0.055       -1.598193  0.045        -1.695398
# 2 -7.517080 ... -2.7941000 0.045       -1.695398  0.010        -2.326348
# 3 17.040800 ...  1.6079300 0.045       -1.695398  0.015        -2.170090
# 4  6.774160 ...  3.8931000 0.040       -1.750686  0.090        -1.340755
# 5  8.732250 ...  0.2277160 0.030       -1.880794  0.040        -1.750686
# 6 -7.905420 ...  5.6865400 0.035       -1.811911  0.030        -1.880794
#   PUoob_FH_ori PUoob_FH_nw PUoob_COG_ori PUoob_COG_nw  IID
# 1 0.5844285     0.2132358  0.4981464     -0.0046462365 1000019
# 2 0.5593047     0.1492066  0.4905649     -0.0236525299 1000022
# 3 0.4401646    -0.1505518  0.5000590      0.0001477754 1000035
# 4 0.4401793    -0.1505147  0.5067844      0.0170067002 1000046
# 5 0.4401661    -0.1505481  0.5104447      0.0261840360 1000054
# 6 0.4401781    -0.1505176  0.4931394     -0.0171977709 1000063

# %%
library(dplyr)
AD_mice_pheno <- AD_mice %>%
    select(FID, IID, Sex, Age, father_age, mother_age, starts_with('mice'),starts_with('PC'))
head(AD_mice_pheno)
# Out:
#   FID     IID     Sex Age father_age mother_age mice_kNN_FH_COG_ori
# 1 1000022 1000022 1   53  73         87         0.01815789
# 2 1000035 1000035 1   63  78         89         0.03500000
# 3 1000046 1000046 0   62  74         81         0.04921053
# 4 1000054 1000054 0   65  75         86         0.03500000
# 5 1000078 1000078 0   52  54         82         0.02052632
# 6 1000081 1000081 1   67  72         91         0.02000000
#   mice_kNN_FH_COG_nw PC1      PC2      ... PC31       PC32       PC33
# 1 -2.093374          -11.0907  2.93694 ...  3.7492400  1.9325500  1.5761500
# 2 -1.811911          -15.2753  1.34975 ...  1.0380800  0.0728806 -3.9243500
# 3 -1.652557          -13.8809  5.01353 ... -0.0110311  3.0748600  2.8422300
# 4 -1.811911          -13.4765  6.71309 ... -0.0461863  1.1660200 -0.7845330
# 5 -2.042998          -14.5751  1.27382 ... -2.9304800 -0.6412900 -0.0486886
# 6 -2.053749           24.3517 -4.64431 ... -0.0604470  2.6082900  2.4419800
#   PC34       PC35      PC36     PC37        PC38      PC39     PC40
# 1 -0.0734071 -3.324260 -3.98978  3.35086000 -0.226358 -1.64457 -2.794100
# 2  1.1922200 -0.880838  1.29770 -1.60734000  1.774000 -2.62669  1.607930
# 3  2.7507300 -2.837840  2.52143  1.84519000  0.518179 -1.97682  3.893100
# 4 -0.3697420 -4.298070  1.24627 -1.84256000 -2.977780 -2.09987  0.227716
# 5 -0.0276104  3.125560 -0.15693  1.41995000  3.883190 -1.41120  3.923090
# 6 -1.8196000  1.200260 -2.51161  0.00500915  1.827430 -1.56366  0.496491

# %%
write.table(AD_mice_pheno, file='/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20211004_covariate_phenotype_MICE_kNN_FH_COG_383859ind.tsv', row.names=F, sep='\t', quote=F)

# %%
AD_puoob_pheno <- AD_puoob %>%
    select(FID, IID, Sex, Age, father_age, mother_age, starts_with('mice'),starts_with('PUoob'),starts_with('PC'))
head(AD_puoob_pheno)
# Out:
#   FID     IID     Sex Age father_age mother_age mice_FH_ori mice_FH_nw
# 1 1000019 1000019 0   47  70         67         0.055       -1.598193
# 2 1000022 1000022 1   53  73         87         0.045       -1.695398
# 3 1000035 1000035 1   63  78         89         0.045       -1.695398
# 4 1000046 1000046 0   62  74         81         0.040       -1.750686
# 5 1000054 1000054 0   65  75         86         0.030       -1.880794
# 6 1000063 1000063 1   43  70         69         0.035       -1.811911
#   mice_COG_ori mice_COG_nw ... PC31       PC32       PC33      PC34
# 1 0.045        -1.695398   ... -3.2547200 -1.5038100 -0.592780  1.2595800
# 2 0.010        -2.326348   ...  3.7492400  1.9325500  1.576150 -0.0734071
# 3 0.015        -2.170090   ...  1.0380800  0.0728806 -3.924350  1.1922200
# 4 0.090        -1.340755   ... -0.0110311  3.0748600  2.842230  2.7507300
# 5 0.040        -1.750686   ... -0.0461863  1.1660200 -0.784533 -0.3697420
# 6 0.030        -1.880794   ... -0.6918750  0.7911460 -2.390580  0.1095570
#   PC35      PC36      PC37     PC38      PC39     PC40
# 1  2.669530  3.413450 -3.65638 -0.146136 -1.74808  0.0766507
# 2 -3.324260 -3.989780  3.35086 -0.226358 -1.64457 -2.7941000
# 3 -0.880838  1.297700 -1.60734  1.774000 -2.62669  1.6079300
# 4 -2.837840  2.521430  1.84519  0.518179 -1.97682  3.8931000
# 5 -4.298070  1.246270 -1.84256 -2.977780 -2.09987  0.2277160
# 6 -2.884630 -0.474187 -1.04767  1.158770 -4.69704  5.6865400

# %%
write.table(AD_puoob_pheno, file='/mnt/mfs/statgen/UKBiobank/phenotype_files/AD_phenotypes/20211004_covariate_phenotype_MICE_or_PUoob_FH_or_COG_501492ind.tsv', row.names=F, sep='\t', quote=F)

# %%
lmm_dir_regenie=$lmm_imp_dir_regenie/100721_AD_mice_kNN
lmm_sbatch_regenie=$USER_PATH/UKBB_GWAS_dev/output/AD_mice_kNN-regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$AD_pheno_path/20211004_covariate_phenotype_MICE_kNN_FH_COG_383859ind.tsv
covarFile=$AD_pheno_path/20211004_covariate_phenotype_MICE_kNN_FH_COG_383859ind.tsv
phenoCol="mice_kNN_FH_COG_ori mice_kNN_FH_COG_nw"
covarCol=Sex
qCovarCol="Age father_age mother_age PC1 PC2 PC3 PC4 PC5 PC6 PC7 PC8 PC9 PC10 PC11 PC12 PC13 PC14 PC15 PC16"
trait=
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
ylim=0
job_size=1
numThreads=22
#Use the original bed files that passed QC using Megan's parameters geno=0.01, mind=0.1, maf=0.01, hwe=5e-08
bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# Quality control applied on genotype array data prior to running regenie
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
reverse_log_p=True
label_annotate=SNP

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $job_size
    --ylim $ylim
    --reverse_log_p $reverse_log_p
    --label_annotate $label_annotate
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/project/UKBB_GWAS_dev/output/AD_mice_kNN-regenie_2021-10-08.sbatch
# INFO: Workflow csg (ID=wc64831b01b9dc7e2) is executed successfully with 1 completed step.

# %%
lmm_dir_regenie=$lmm_imp_dir_regenie/100721_AD_mice_PUoob
lmm_sbatch_regenie=$USER_PATH/UKBB_GWAS_dev/output/AD_mice_PUoob-regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$AD_pheno_path/20211004_covariate_phenotype_MICE_or_PUoob_FH_or_COG_501492ind.tsv
covarFile=$AD_pheno_path/20211004_covariate_phenotype_MICE_or_PUoob_FH_or_COG_501492ind.tsv
phenoCol="mice_FH_ori mice_FH_nw mice_COG_ori mice_COG_nw PUoob_FH_ori PUoob_FH_nw PUoob_COG_ori PUoob_COG_nw"
covarCol=Sex
qCovarCol="Age father_age mother_age PC1 PC2 PC3 PC4 PC5 PC6 PC7 PC8 PC9 PC10 PC11 PC12 PC13 PC14 PC15 PC16"
trait=
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
ylim=0
job_size=1
numThreads=22
#Use the original bed files that passed QC using Megan's parameters geno=0.01, mind=0.1, maf=0.01, hwe=5e-08
bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# Quality control applied on genotype array data prior to running regenie
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
reverse_log_p=True
label_annotate=SNP

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $job_size
    --ylim $ylim
    --reverse_log_p $reverse_log_p
    --label_annotate $label_annotate
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/project/UKBB_GWAS_dev/output/AD_mice_PUoob-regenie_2021-10-07.sbatch
# INFO: Workflow csg (ID=wf87c43c648dda5da) is executed successfully with 1 completed step.

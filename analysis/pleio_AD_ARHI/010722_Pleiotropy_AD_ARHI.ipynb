# %% [markdown]
# # Analysis of pleiotopy between Alzheimer's Disease and ARHI traits

# %% [markdown]
# First of all a review of the available references is made regarding AD. Particularly for GWAS using AD and meta-analysis from different studies.
#
# 1. Kunkle et al https://www.nature.com/articles/s41588-019-0358-2
# 2. Jansen et al https://pubmed.ncbi.nlm.nih.gov/30617256/
# 3. Wightman et al https://www.nature.com/articles/s41588-021-00921-z
# 4. [family history based] https://pubmed.ncbi.nlm.nih.gov/29777097/
# 5. Schwartzentruber et al https://pubmed.ncbi.nlm.nih.gov/33589840/
# 6. Bellenguez et al https://www.nature.com/articles/s41588-022-01024-z
#
# **Using AD proxy case definition**
#
# [Schwartzentruber et al 2021](https://www.nature.com/articles/s41588-020-00776-w)
#
# **Using clinically diagnosed LOAD**
#
# [Kunkle et al 2019](https://www.nature.com/articles/s41588-019-0358-2)
#
# **Using clinically diagnosed/proxy AD cases**
#
# [Belenguez et al 2022](https://www.nature.com/articles/s41588-022-01024-z)
#
# - two stage GWAS
# - 111,326 clinically diagnosed/‘proxy’ AD cases and 677,663 controls
# - The European Alzheimer & Dementia Biobank  + UK Biobank
# - GWAS meta-analysis results can be downloaded here https://www.ebi.ac.uk/gwas/studies/GCST90027158
#
# The results from this meta-analysis have been downloaded to our cluster and are located here:
#
# `/mnt/vast/hpc/csg/data_public/GWAS_sumstats/GCST90027158_buildGRCh38.tsv.gz`

# %% [markdown]
# ## GWAS for ARHI used in the pleiotropy analysis
#
# Parameters used for REGENIE
#
# ```
# covarCol=sex
# qCovarCol="age PC1 PC2"
# bgenMinINFO=0.8
# minMAC=4
# bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# genoFile=`echo ~/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
# sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
# ```
#
# The GWAS results are stored here (Note: these results correspond to white European individuals:
#
# - /mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/2021_10_07_f3393_500K
# - /mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/2021_10_07_f2247_500K
# - /mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/2021_10_07_f2257_500K
# - /mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/2021_10_07_combined_500K

# %% [markdown]
# # Step 1. Liftover of the meta-analysis sumtats of AD to match our GWAS results in hg19

# %%
module load Singularity
USER_PATH=~/working
export PATH=$HOME/miniconda3/bin:$PATH
sos run $USER_PATH/bioworkflows/GWAS/liftover.ipynb \
--cwd /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI \
--input_file /mnt/vast/hpc/csg/data_public/GWAS_sumstats/GCST90027158_buildGRCh38.tsv.gz \
--output_file GCST90027158_buildGRCh37.tsv \
--fr 'hg38' \
--to 'hg19' \
--yml_file $USER_PATH/UKBB_GWAS_dev/data/liftover.yml

# %% [markdown]
# # Step 2. Association analysis of the imputed data

# %% [markdown]
# Do the association analysis for the Hearing impairment traits with the white european individuals present in the 500K samples

# %%
# Common variables Columbia's cluster
UKBB_PATH=$HOME/UKBiobank
UKBB_yale=$HOME/UKBiobank_Yale_transfer
USER_PATH=$HOME/project
container_lmm=$HOME/containers/lmm.sif
container_marp=$HOME/containers/marp.sif
container_annovar=$HOME/containers/gatk4-annovar.sif
hearing_pheno_path=$UKBB_PATH/phenotype_files/hearing_impairment
tpl_file=$USER_PATH/bioworkflows/admin/csg.yml
formatFile_fastgwa=$USER_PATH/UKBB_GWAS_dev/data/fastGWA_template.yml
formatFile_bolt=$USER_PATH/UKBB_GWAS_dev/data/boltlmm_template.yml
formatFile_saige=$USER_PATH/UKBB_GWAS_dev/data/saige_template.yml
formatFile_regenie=$USER_PATH/UKBB_GWAS_dev/data/regenie_template.yml
# Workflows
lmm_sos=$USER_PATH/bioworkflows/GWAS/LMM.ipynb
anno_sos=$USER_PATH/bioworkflows/variant-annotation/annovar.ipynb
clumping_sos=$USER_PATH/bioworkflows/GWAS/LD_Clumping.ipynb
extract_sos=$USER_PATH/bioworkflows/GWAS/Region_Extraction.ipynb
snptogene_sos=$USER_PATH/UKBB_GWAS_dev/workflow/snptogene.ipynb

# LMM directories for imputed data
lmm_imp_dir_fastgwa=$UKBB_PATH/results/FastGWA_results/results_imputed_data
lmm_imp_dir_bolt=$UKBB_PATH/results/BOLTLMM_results/results_imputed_data
lmm_imp_dir_saige=$UKBB_PATH/results/SAIGE_results/results_imputed_data
lmm_imp_dir_regenie=$UKBB_PATH/results/REGENIE_results/results_imputed_data

# LMM directories for exome data
lmm_exome_dir_fastgwa=$UKBB_PATH/results/FastGWA_results/results_exome_data
lmm_exome_dir_bolt=$UKBB_PATH/results/BOLTLMM_results/results_exome_data
lmm_exome_dir_saige=$UKBB_PATH/results/SAIGE_results/results_exome_data
lmm_exome_dir_regenie=$UKBB_PATH/results/REGENIE_results/results_exome_data

## LMM variables 
## Specific to Bolt_LMM
LDscoresFile=$UKBB_PATH/LDSCORE.1000G_EUR.tab.gz
geneticMapFile=$UKBB_PATH/genetic_map_hg19_withX.txt.gz
covarMaxLevels=10
numThreads=20
bgenMinMAF=0.001
bgenMinINFO=0.8
lmm_job_size=1
ylim=0

### Specific to FastGWA (depeding if you run from Yale or Columbia)
####Yale's cluster
grmFile=$UKBB_PATH/results/FastGWA_results/results_imputed_data/UKB_Caucasians_phenotypeindepqc120319_updated020720removedwithdrawnindiv.grm.sp
####Columbia's cluster
grmFile=$UKBB_yale/results/FastGWA_results/results_imputed_data/UKB_Caucasians_phenotypeindepqc120319_updated020720removedwithdrawnindiv.grm.sp

### Specific to SAIGE
bgenMinMAC=4
trait_type=binary
loco=TRUE
sampleCol=IID

### Specific to REGENIE
bsize=1000
lowmem=$HOME/scratch60/
lowmem_dir=$HOME/scratch60/predictions
trait=bt
minMAC=4
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
reverse_log_p=True
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %% [markdown]
# ## New PCA
# ### Exclude the samples wiht code 1415 but without the sub-category code

# %%
import pandas as pd
sample500k = pd.read_csv("/home/gl2776/UKBiobank/phenotype_files/HI_UKBB/ukb47922_white_460649ind.keep_id",header=None,sep=" ")
sample500k

# %%
exclusion = pd.read_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/with_1415_without_subcat.500k.sample_id.txt",header=0,sep="\t")
exclusion = exclusion["IID"].to_list()
len(exclusion)

# %%
sample500k[~sample500k[0].isin(exclusion)].shape

# %%
sample500k[~sample500k[0].isin(exclusion)].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/ukb47922_white_456561ind_exclu_1415.keep_id",header=False,index=False,sep=" ")

# %%
## Keep_id for PCA
# f3393
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2"
phe = pd.read_csv(file,header=0,sep="\t")
phe[["FID", "IID"]].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2.keep_id", sep='\t', index=False, header=False)
# f2247
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2"
phe = pd.read_csv(file,header=0,sep="\t")
phe[["FID", "IID"]].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2.keep_id", sep='\t', index=False, header=False)
# f2257
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2"
phe = pd.read_csv(file,header=0,sep="\t")
phe[["FID", "IID"]].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2.keep_id", sep='\t', index=False, header=False)
# f2247_f2257
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2"
phe = pd.read_csv(file,header=0,sep="\t")
phe[["FID", "IID"]].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2.keep_id", sep='\t', index=False, header=False)

# %%
# phenopca
import pandas as pd
# f3393
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2"
list1415 = pd.read_csv(file,header=0,sep="\t")["IID"].to_list()
file = "/home/gl2776/UKBiobank/results/092821_PCA_results_500K/100521_UKBB_Hearing_aid_f3393_expandedwhite_15601cases_237318ctrl_500k.phenopca"
phe = pd.read_csv(file,header=0,sep="\t")
phe[phe["IID"].isin(list1415)].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k.phenopca", sep='\t', index=False)
# f2247
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2"
list1415 = pd.read_csv(file,header=0,sep="\t")["IID"].to_list()
file = "/home/gl2776/UKBiobank/results/092821_PCA_results_500K/100521_UKBB_Hearing_difficulty_f2247_expandedwhite_110453cases_237318ctrl_500k.phenopca"
phe = pd.read_csv(file,header=0,sep="\t")
phe[phe["IID"].isin(list1415)].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k.phenopca", sep='\t', index=False)
# f2247
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2"
list1415 = pd.read_csv(file,header=0,sep="\t")["IID"].to_list()
file = "/home/gl2776/UKBiobank/results/092821_PCA_results_500K/100521_UKBB_Hearing_noise_f2257_expandedwhite_161443cases_237318ctrl_500k.phenopca"
phe = pd.read_csv(file,header=0,sep="\t")
phe[phe["IID"].isin(list1415)].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k.phenopca", sep='\t', index=False)
# f2247
file = "/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2"
list1415 = pd.read_csv(file,header=0,sep="\t")["IID"].to_list()
file = "/home/gl2776/UKBiobank/results/092821_PCA_results_500K/100521_UKBB_Combined_f2247_f2257_expandedwhite_93258cases_237318ctrl_500k.phenopca"
phe = pd.read_csv(file,header=0,sep="\t")
phe[phe["IID"].isin(list1415)].to_csv("/home/gl2776/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k.phenopca", sep='\t', index=False)

# %% [markdown]
# ### Calculate the first 2 PC's for each of these phenotypes to run the association analysis with the imputed data
# #### f.3393
# ##### Step 1

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f3393
#gwas_sbatch=$USER_PATH/UKBB_GWAS_dev/output/qc1_f3393_qcarray_$(date +"%Y-%m-%d").sbatch
gwas_sbatch=$cwd/qc1_f3393_qcarray_$(date +"%Y-%m-%d").sbatch
## Use qc'ed genotype array
genoFile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
keep_samples=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2.keep_id
#Keep variants after LD pruning
keep_variants=$UKBB_PATH/results/092821_PCA_results_500K/092821_ldprun_unrelated/cache/*092821_ldprun_unrelated.filtered.prune.in

#GWAS QC variables set all of this variables to 0 to avoid doing more filtering
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
numThreads=1
mem='30G'

gwasqc_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/GWAS_QC.ipynb

gwasqc_args="""qc:1
    --cwd $cwd
    --genoFile $genoFile
    --keep_samples $keep_samples
    --keep_variants $keep_variants
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
    --mem $mem
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $gwasqc_sos \
    --to-script $gwas_sbatch \
    --args "$gwasqc_args"

# %% [markdown]
# ##### Step 2

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f3393
#This is the bfile obtained in step 1
genoFile=$cwd/*.bed
# Format FID, IID, pop
phenoFile=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k.phenopca
label_col=ethnicity
pop_col=ethnicity
pca_sbatch=$cwd/flashpca_f3393_pc_$(date +"%Y-%m-%d").sbatch
k=2
maha_k=2
min_axis=""
max_axis=""

pca_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/PCA.ipynb

pca_args="""flashpca
    --cwd $cwd
    --genoFile $genoFile
    --phenoFile $phenoFile
    --k $k
    --maha_k $maha_k
    --label_col $label_col
    --pop_col $pop_col
    --min_axis $min_axis
    --max_axis $max_axis
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $pca_sos \
    --to-script $pca_sbatch \
    --args "$pca_args"

# %% [markdown]
# #### f.2247
#
# ##### Step 1

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2247
#gwas_sbatch=$USER_PATH/UKBB_GWAS_dev/output/qc1_f2247_qcarray_$(date +"%Y-%m-%d").sbatch
gwas_sbatch=$cwd/qc1_f2247_qcarray_$(date +"%Y-%m-%d").sbatch
## Use qc'ed genotype array
genoFile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
keep_samples=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2.keep_id
#Keep variants after LD pruning
keep_variants=$UKBB_PATH/results/092821_PCA_results_500K/092821_ldprun_unrelated/cache/*092821_ldprun_unrelated.filtered.prune.in

#GWAS QC variables set all of this variables to 0 to avoid doing more filtering
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
numThreads=1
mem='30G'

gwasqc_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/GWAS_QC.ipynb

gwasqc_args="""qc:1
    --cwd $cwd
    --genoFile $genoFile
    --keep_samples $keep_samples
    --keep_variants $keep_variants
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
    --mem $mem
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $gwasqc_sos \
    --to-script $gwas_sbatch \
    --args "$gwasqc_args"

# %% [markdown]
# ##### Step 2.

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2247
#This is the bfile obtained in step 1
genoFile=$cwd/*.bed
# Format FID, IID, pop
phenoFile=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k.phenopca
label_col=ethnicity
pop_col=ethnicity
pca_sbatch=$cwd/flashpca_f2247_pc_$(date +"%Y-%m-%d").sbatch
k=2
maha_k=2
min_axis=""
max_axis=""

pca_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/PCA.ipynb

pca_args="""flashpca
    --cwd $cwd
    --genoFile $genoFile
    --phenoFile $phenoFile
    --k $k
    --maha_k $maha_k
    --label_col $label_col
    --pop_col $pop_col
    --min_axis $min_axis
    --max_axis $max_axis
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
"""

sos run  $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $pca_sos \
    --to-script $pca_sbatch \
    --args "$pca_args"

# %% [markdown]
# #### f.2257
#
# ##### Step 1

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2257
#gwas_sbatch=$USER_PATH/UKBB_GWAS_dev/output/qc1_f2257_qcarray_$(date +"%Y-%m-%d").sbatch
gwas_sbatch=$cwd/qc1_f2257_qcarray_$(date +"%Y-%m-%d").sbatch
## Use qc'ed genotype array
genoFile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
keep_samples=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2.keep_id
#Keep variants after LD pruning
keep_variants=$UKBB_PATH/results/092821_PCA_results_500K/092821_ldprun_unrelated/cache/*092821_ldprun_unrelated.filtered.prune.in

#GWAS QC variables set all of this variables to 0 to avoid doing more filtering
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
numThreads=1
mem='30G'

gwasqc_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/GWAS_QC.ipynb

gwasqc_args="""qc:1
    --cwd $cwd
    --genoFile $genoFile
    --keep_samples $keep_samples
    --keep_variants $keep_variants
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
    --mem $mem
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $gwasqc_sos \
    --to-script $gwas_sbatch \
    --args "$gwasqc_args"

# %% [markdown]
# ##### Step 2.

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2257
#This is the bfile obtained in step 1
genoFile=$cwd/*.bed
# Format FID, IID, pop
phenoFile=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k.phenopca
label_col=ethnicity
pop_col=ethnicity
pca_sbatch=$cwd/flashpca_f2257_pc_$(date +"%Y-%m-%d").sbatch
k=2
maha_k=2
min_axis=""
max_axis=""

pca_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/PCA.ipynb

pca_args="""flashpca
    --cwd $cwd
    --genoFile $genoFile
    --phenoFile $phenoFile
    --k $k
    --maha_k $maha_k
    --label_col $label_col
    --pop_col $pop_col
    --min_axis $min_axis
    --max_axis $max_axis
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
"""

sos run  $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $pca_sos \
    --to-script $pca_sbatch \
    --args "$pca_args"

# %% [markdown]
# #### Combined f.2247 & f.2257
#
# ##### Step 1

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2247_f2257
#gwas_sbatch=$USER_PATH/UKBB_GWAS_dev/output/qc1_f2247_f2257_qcarray_$(date +"%Y-%m-%d").sbatch
gwas_sbatch=$cwd/qc1_f2247_f2257_qcarray_$(date +"%Y-%m-%d").sbatch
## Use qc'ed genotype array
genoFile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
keep_samples=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2.keep_id
#Keep variants after LD pruning
keep_variants=$UKBB_PATH/results/092821_PCA_results_500K/092821_ldprun_unrelated/cache/*092821_ldprun_unrelated.filtered.prune.in

#GWAS QC variables set all of this variables to 0 to avoid doing more filtering
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
numThreads=1
mem='30G'

gwasqc_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/GWAS_QC.ipynb

gwasqc_args="""qc:1
    --cwd $cwd
    --genoFile $genoFile
    --keep_samples $keep_samples
    --keep_variants $keep_variants
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
    --mem $mem
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $gwasqc_sos \
    --to-script $gwas_sbatch \
    --args "$gwasqc_args"

# %% [markdown]
# ##### Step 2.

# %%
## Columbia's cluster
cwd=$UKBB_PATH/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2247_f2257
#This is the bfile obtained in step 1
genoFile=$cwd/*.bed
# Format FID, IID, pop
phenoFile=$UKBB_PATH/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071122_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k.phenopca
label_col=ethnicity
pop_col=ethnicity
pca_sbatch=$cwd/flashpca_f2247_f2257_pc_$(date +"%Y-%m-%d").sbatch
k=2
maha_k=2
min_axis=""
max_axis=""

pca_sos=$USER_PATH/xqtl-pipeline/code/data_preprocessing/genotype/PCA.ipynb

pca_args="""flashpca
    --cwd $cwd
    --genoFile $genoFile
    --phenoFile $phenoFile
    --k $k
    --maha_k $maha_k
    --label_col $label_col
    --pop_col $pop_col
    --min_axis $min_axis
    --max_axis $max_axis
    --numThreads $numThreads 
    --job_size $job_size
    --container $container_lmm
"""

sos run  $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $pca_sos \
    --to-script $pca_sbatch \
    --args "$pca_args"

# %% [markdown]
# ### Combine the PCs in the phenotype files
#
# Phenotype files named "070722_*_500k_PC1_PC2" are with original PCs calculated by original sample size with code 1415. "071222_*_500k_PC1_PC2" will be the new phenotype files with the newly calculated PCs

# %%
# f3393
import pandas as pd
phe = pd.read_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2",header=0,sep="\t")
pc = pd.read_csv("~/UKBiobank/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f3393/071122_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k.pca.txt",header=0,sep="\t")
phe = phe[['FID', 'IID', 'sex', 'f3393', 'age']]
phe = phe.merge(pc[["IID","PC1","PC2"]],how="left",left_on="IID",right_on="IID")
phe.to_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2",index=False,sep="\t")

# %%
# f2247
phe = pd.read_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2",header=0,sep="\t")
pc = pd.read_csv("~/UKBiobank/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2247/071122_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k.pca.txt",header=0,sep="\t")
phe = phe[['FID', 'IID', 'sex', 'f2247', 'age']]
phe = phe.merge(pc[["IID","PC1","PC2"]],how="left",left_on="IID",right_on="IID")
phe.to_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2",index=False,sep="\t")
# f2257
phe = pd.read_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2",header=0,sep="\t")
pc = pd.read_csv("~/UKBiobank/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2257/071122_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k.pca.txt",header=0,sep="\t")
phe = phe[['FID', 'IID', 'sex', 'f2257', 'age']]
phe = phe.merge(pc[["IID","PC1","PC2"]],how="left",left_on="IID",right_on="IID")
phe.to_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2",index=False,sep="\t")
# f2247_f2257
phe = pd.read_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/070722_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2",header=0,sep="\t")
pc = pd.read_csv("~/UKBiobank/results/092821_PCA_results_500K/071122_PCA_500k_exclu_1415/f2247_f2257/071122_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k.pca.txt",header=0,sep="\t")
phe = phe[['FID', 'IID', 'sex', 'f2247_f2257', 'age']]
phe = phe.merge(pc[["IID","PC1","PC2"]],how="left",left_on="IID",right_on="IID")
phe.to_csv("~/UKBiobank/phenotype_files/hearing_impairment/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2",index=False,sep="\t")

# %% [markdown]
# ## Run association analysis with imputed data for each phenotype
# ### 500k
#
# #### f.3393

# %%
cwd=~/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f3393
lmm_dir_regenie=$cwd
lmm_sbatch_regenie=$cwd/f3393_500K_impdata_regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2
covarFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2
phenoCol=f3393
covarCol=sex
qCovarCol="age PC1 PC2"
bgenMinINFO=0.8
bgenMinMAF=0.001
minMAC=4
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
#Use the original bed files for the genotype array on regenie step1
bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# Use the imputed data hg19 to run the association analysis
genoFile=`echo ~/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
label_annotate=SNP
lowmem_dir=$cwd/predictions
ref_first=True

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $lmm_job_size
    --ylim $ylim
    --label_annotate $label_annotate
    --no-annotate
    --reverse_log_p $reverse_log_p
    --ref_first $ref_first
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f3393/f3393_500K_impdata_regenie_2022-07-26.sbatch
# INFO: Workflow csg (ID=w2e19c78363e8a433) is executed successfully with 1 completed step.

# %% [markdown]
# #### f.2247

# %%
cwd=~/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2247
lmm_dir_regenie=$cwd
lmm_sbatch_regenie=$cwd/f2247_500K_impdata_regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2
covarFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2
phenoCol=f2247
covarCol=sex
qCovarCol="age PC1 PC2"
bgenMinINFO=0.8
bgenMinMAF=0.001
minMAC=4
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
#Use the original bed files for the genotype array on regenie step1
bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# Use the imputed data hg19 to run the association analysis
genoFile=`echo ~/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
label_annotate=SNP
lowmem_dir=$cwd/predictions
ref_first=True

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $lmm_job_size
    --ylim $ylim
    --label_annotate $label_annotate
    --no-annotate
    --reverse_log_p $reverse_log_p
    --ref_first $ref_first
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2247/f2247_500K_impdata_regenie_2022-07-26.sbatch
# INFO: Workflow csg (ID=w416eb35379405fde) is executed successfully with 1 completed step.

# %% [markdown]
# #### f.2257

# %%
cwd=~/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2257
lmm_dir_regenie=$cwd
lmm_sbatch_regenie=$cwd/f2257_500K_impdata_regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2
covarFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2
phenoCol=f2257
covarCol=sex
qCovarCol="age PC1 PC2"
bgenMinINFO=0.8
bgenMinMAF=0.001
minMAC=4
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
#Use the original bed files for the genotype array on regenie step1
bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# Use the imputed data hg19 to run the association analysis
genoFile=`echo ~/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
label_annotate=SNP
lowmem_dir=$cwd/predictions
ref_first=True

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $lmm_job_size
    --ylim $ylim
    --label_annotate $label_annotate
    --no-annotate
    --reverse_log_p $reverse_log_p
    --ref_first $ref_first
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2257/f2257_500K_impdata_regenie_2022-07-26.sbatch
# INFO: Workflow csg (ID=w3ba10e625e2c3b71) is executed successfully with 1 completed step.

# %% [markdown]
# #### Combined f.2247 & f.2257

# %%
cwd=~/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2247_f2257
lmm_dir_regenie=$cwd
lmm_sbatch_regenie=$cwd/f2247_f2257_500K_impdata_regenie_$(date +"%Y-%m-%d").sbatch
phenoFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2
covarFile=$hearing_pheno_path/fulldb_500K/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2
phenoCol=f2247_f2257
covarCol=sex
qCovarCol="age PC1 PC2"
bgenMinINFO=0.8
bgenMinMAF=0.001
minMAC=4
maf_filter=0
geno_filter=0
hwe_filter=0
mind_filter=0
#Use the original bed files for the genotype array on regenie step1
bfile=$UKBB_PATH/genotype_files_processed/090221_sample_variant_qc_final_callrate90/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.bed
# Use the imputed data hg19 to run the association analysis
genoFile=`echo ~/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
label_annotate=SNP
lowmem_dir=$cwd/predictions
ref_first=True

lmm_args="""regenie
    --cwd $lmm_dir_regenie 
    --bfile $bfile 
    --genoFile $genoFile
    --sampleFile $sampleFile
    --phenoFile $phenoFile 
    --formatFile $formatFile_regenie 
    --phenoCol $phenoCol
    --covarCol $covarCol  
    --qCovarCol $qCovarCol
    --bsize $bsize
    --lowmem_dir $lowmem_dir
    --trait $trait 
    --bgenMinMAF $bgenMinMAF 
    --bgenMinINFO $bgenMinINFO
    --maf_filter $maf_filter
    --geno_filter $geno_filter
    --hwe_filter $hwe_filter
    --mind_filter $mind_filter
    --minMAC $minMAC
    --job_size $lmm_job_size
    --ylim $ylim
    --label_annotate $label_annotate
    --no-annotate
    --reverse_log_p $reverse_log_p
    --ref_first $ref_first
    --numThreads $numThreads
    --container_lmm $container_lmm
    --container_marp $container_marp
"""

sos run $USER_PATH/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg\
    --template-file $tpl_file \
    --workflow-file $lmm_sos \
    --to-script $lmm_sbatch_regenie \
    --args "$lmm_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/dmc2245/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2247_f2257/f2247_f2257_500K_impdata_regenie_2022-07-26.sbatch
# INFO: Workflow csg (ID=w0f1374ff2f10b381) is executed successfully with 1 completed step.

# %% [markdown]
# # Step 3. LD clumping between different traits

# %% [markdown]
# ## Format file preparation so that all summary stats match

# %%
import pandas as pd
data = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37.tsv.gz', compression='gzip', sep="\t", header=0)
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']
# /tmp/2658818.1.csg2.q/ipykernel_16933/2685489524.py:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from collections import Sized, KeysView, Sequence

# %%
data.head()
# Out:
#    CHR     POS REF  ALT             SNP    BETA      SE       P
# 0    1  529825   C    T    1:529825:C:T -0.0152  0.3236  0.9626
# 1    1  531142   C  CTG  1:531142:C:CTG -0.2494  0.2247  0.2670
# 2    1  566327   G    A    1:566327:G:A  0.0975  0.4320  0.8214
# 3    1  581537   G    A    1:581537:G:A -0.3028  0.3180  0.3411
# 4    1  661906   G    C    1:661906:G:C  0.2938  0.3171  0.3542

# %%
data.rename(columns={'A0':'REF', 'A1':'ALT', 'STAT':'BETA'}, inplace=True)

# %%
data.head()
# Out:
#    CHR     POS REF  ALT                SNP    BETA      SE       P
# 0    1  529825   C    T    chr1:529825:C:T -0.0152  0.3236  0.9626
# 1    1  531142   C  CTG  chr1:531142:C:CTG -0.2494  0.2247  0.2670
# 2    1  566327   G    A    chr1:566327:G:A  0.0975  0.4320  0.8214
# 3    1  581537   G    A    chr1:581537:G:A -0.3028  0.3180  0.3411
# 4    1  661906   G    C    chr1:661906:G:C  0.2938  0.3171  0.3542

# %%
data['SNP'] = data['SNP'].str.replace('chr', '')

# %%
data.head()
# Out:
#    CHR     POS REF  ALT             SNP    BETA      SE       P
# 0    1  529825   C    T    1:529825:C:T -0.0152  0.3236  0.9626
# 1    1  531142   C  CTG  1:531142:C:CTG -0.2494  0.2247  0.2670
# 2    1  566327   G    A    1:566327:G:A  0.0975  0.4320  0.8214
# 3    1  581537   G    A    1:581537:G:A -0.3028  0.3180  0.3411
# 4    1  661906   G    C    1:661906:G:C  0.2938  0.3171  0.3542

# %%
data.to_csv("/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.tsv.gz", sep='\t', index=False, header=True, compression="gzip")

# %% [markdown]
# ### Re-format the SNP in the 500K GWAS summary stats

# %%
f3393 = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f3393/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.gz', dtype=str, compression='gzip',sep="\t", header=0)

# %%
f3393.head()
# Out:
#   CHR    POS REF ALT          SNP       BETA        SE                    P
# 0   1  13259   A   G  rs562993331  -0.444965  0.405872    0.272939253875768
# 1   1  17569   A   C  rs535086049    1.19541   1.86985   0.5226211725664186
# 2   1  17641   A   G  rs578081284   0.435933  0.233139  0.06150635633786312
# 3   1  30741   A   C  rs558169846    1.28043   1.24525    0.303832341109345
# 4   1  52144   A   T  rs190291950  -0.117852  0.337249   0.7267499323234313

# %%
f3393['var'] = f3393['CHR'] + ':' + f3393['POS'] + ':' + f3393['REF'] + ':' + f3393['ALT']

# %%
f3393.head()
# Out:
#   CHR    POS REF ALT          SNP       BETA        SE                    P  \
# 0   1  13259   A   G  rs562993331  -0.444965  0.405872    0.272939253875768
# 1   1  17569   A   C  rs535086049    1.19541   1.86985   0.5226211725664186
# 2   1  17641   A   G  rs578081284   0.435933  0.233139  0.06150635633786312
# 3   1  30741   A   C  rs558169846    1.28043   1.24525    0.303832341109345
# 4   1  52144   A   T  rs190291950  -0.117852  0.337249   0.7267499323234313
#
#            var
# 0  1:13259:A:G
# 1  1:17569:A:C
# 2  1:17641:A:G
# 3  1:30741:A:C
# 4  1:52144:A:T

# %%
import os
rootdir = '/mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/'

for subdir, dirs, files in os.walk(rootdir):
    for filename in files:
        if filename.endswith("071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.gz"):
            print(os.path.join(subdir, filename))
            df = pd.read_csv(os.path.join(subdir, filename), dtype=str, compression='gzip',sep="\t", header=0)
            df.rename(columns={'SNP':'varid'}, inplace=True)
            df['SNP'] = df['CHR'] + ':' + df['POS'] + ':' + df['REF'] + ':' + df['ALT']
            df.to_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/' + filename, sep='\t', index=False, header=True, compression="gzip")
            print(df.head())
# Out:
# /mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.gz
#   CHR    POS REF ALT        varid        BETA        SE                     P  \
# 0   1  13259   G   A  rs562993331    0.387653  0.169082  0.023122777490193567
# 1   1  17569   C   A  rs535086049   -0.331285  0.764723    0.6648627475668728
# 2   1  17641   G   A  rs578081284  -0.0451544  0.103088    0.6613738204754334
# 3   1  30741   C   A  rs558169846    -1.76303  0.991047  0.024469776350843825
# 4   1  57222   T   C  rs576081345   0.0501817  0.114946    0.6624254356036648
#
#            SNP
# 0  1:13259:G:A
# 1  1:17569:C:A
# 2  1:17641:G:A
# 3  1:30741:C:A
# 4  1:57222:T:C

# %% [markdown]
# # Variables for LD clumping

# %%
clumping_sos=~/project/bioworkflows/GWAS/LD_Clumping.ipynb
## GenoFile is not necessary to run LD clumping but it is needed by the global parameters. It won't be use in this module but you have to provide path
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
reference_genotype_prefix=~/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.nondup.2000.ref_geno.bed
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=varid
numThreads=20
clump_job_size=1
container=~/containers/lmm.sif

# %% [markdown]
# ## Solution to empty clumped files
#
# The empty clumped files were showing up because the varid in the reference file is rsid whereas in the summary stats files it is based on chr:pos:ref:alt
# Therefore, I have decided to re-name all of the variants in the reference file with rsid for the more conventional notation CHR:POS:REF:ALT which can be acomplished using plink2

# %%
module load PLINK/2.0
plink2 --bfile ~/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.2000.ref_geno \
       --make-bed \
       --out ~/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno\
       --new-id-max-allele-len 662 \
       --set-all-var-ids @:#:\$r:\$a
# Out:
# PLINK v2.00a2.3LM 64-bit Intel (24 Jan 2020)   www.cog-genomics.org/plink/2.0/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno.log.
# Options in effect:
#   --bfile /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.2000.ref_geno
#   --make-bed
#   --new-id-max-allele-len 662
#   --out /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno
#   --set-all-var-ids @:#:$r:$a
#
# Start time: Thu Jul 28 13:46:07 2022
# 257481 MiB RAM detected; reserving 128740 MiB for main workspace.
# Allocated 72416 MiB successfully, after larger attempt(s) failed.
# Using up to 64 threads (change this with --threads).
# 2000 samples (1096 females, 904 males; 2000 founders) loaded from
# /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.2000.ref_geno.fam.
# 92457702 variants loaded from
# /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.2000.ref_geno.bim.
# Note: No phenotype data present.
# Writing
# /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno.fam
# ... done.
# Writing
# /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno.bim
# ... done.
# Writing
# /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno.bed
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# End time: Thu Jul 28 13:47:19 2022

# %% [markdown]
# There was still an error because some of the variants after renaming them were duplicated having the same ref/alt alleles. Therefore, I proceded to remove all the duplicated variants

# %%
module load PLINK/2.0
plink2 --bfile ~/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno \
        --rm-dup  'force-first' 'list' --make-bed \
        --out ~/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.nondup.2000.ref_geno
# Out:
# PLINK v1.90b4.9 64-bit (13 Oct 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to plink.log.
# Options in effect:
#   --bfile /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.2000.ref_geno
#   --list-duplicate-vars require-same-ref
#   --memory 60000
#
# Segmentation fault (core dumped)

# %% [markdown]
# ## AD_meta and f3393

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f3393_ADmeta
clumping_sbatch=$clumping_dir/f3393_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080722_f3393_ADmeta/f3393_ADmeta-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=w08dba5e8d7034f9d) is executed successfully with 1 completed step.

# %% [markdown]
# ### Check overlap between AD sumstats and f3393 sumstats

# %%
import pandas as pd
file = "/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.tsv.gz"
AD = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
AD.head()

# %%
#Number of hits that are genome-wide significant
AD_sig=AD[AD['P'] < 5e-08]

# %%
file='/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.gz'
f3393 = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
f3393.head()
# Out:
#    CHR    POS REF ALT        varid      BETA        SE         P          SNP
# 0    1  13259   A   G  rs562993331 -0.444965  0.405872  0.272939  1:13259:A:G
# 1    1  17569   A   C  rs535086049  1.195410  1.869850  0.522621  1:17569:A:C
# 2    1  17641   A   G  rs578081284  0.435933  0.233139  0.061506  1:17641:A:G
# 3    1  30741   A   C  rs558169846  1.280430  1.245250  0.303832  1:30741:A:C
# 4    1  52144   A   T  rs190291950 -0.117852  0.337249  0.726750  1:52144:A:T

# %%
f3393_sig=f3393[f3393['P'] < 5e-08]

# %%
AD_sig[AD_sig['SNP'].isin(f3393_sig['SNP'])]
# Out:
#           CHR       POS REF   ALT                SNP    BETA      SE  \
# 8200715     6  32654502   G     A     6:32654502:G:A  0.0798  0.0123
# 8201118     6  32665728   G     A     6:32665728:G:A  0.0766  0.0121
# 8201135     6  32666173   G     A     6:32666173:G:A  0.0795  0.0123
# 8201140     6  32666295   G     A     6:32666295:G:A  0.0793  0.0123
# 8201173     6  32666875   G     A     6:32666875:G:A  0.0760  0.0122
# 8201174     6  32666899   G     A     6:32666899:G:A  0.0761  0.0122
# 8201177     6  32666968   C     T     6:32666968:C:T  0.0760  0.0122
# 8201179     6  32667006   C  CATG  6:32667006:C:CATG  0.0790  0.0123
# 8201192     6  32667343   T     A     6:32667343:T:A  0.0727  0.0121
# 8201204     6  32667895   G     C     6:32667895:G:C  0.0778  0.0122
# 18707312   17  43946318   C     T    17:43946318:C:T  0.0549  0.0098
#
#                      P
# 8200715   1.004000e-10
# 8201118   2.682000e-10
# 8201135   1.218000e-10
# 8201140   1.323000e-10
# 8201173   3.967000e-10
# 8201174   3.775000e-10
# 8201177   4.034000e-10
# 8201179   1.423000e-10
# 8201192   2.167000e-09
# 8201204   2.088000e-10
# 18707312  2.008000e-08

# %%
f3393_sig[f3393_sig['SNP'].isin(AD_sig['SNP'])]
# Out:
#           CHR       POS REF   ALT        varid      BETA        SE  \
# 8515913     6  32654502   G     A    rs9275183 -0.105956  0.018669
# 8516436     6  32665728   G     A    rs9275312 -0.102268  0.018389
# 8516462     6  32666173   G     A    rs9275318 -0.106932  0.018668
# 8516467     6  32666295   G     A    rs9275319 -0.106943  0.018673
# 8516498     6  32666875   G     A    rs9275330 -0.104214  0.018446
# 8516499     6  32666899   G     A    rs9275331 -0.104226  0.018446
# 8516502     6  32666968   C     T    rs9275333 -0.104285  0.018445
# 8516504     6  32667006   C  CATG  rs760571019 -0.104240  0.018448
# 8516516     6  32667343   T     A    rs9275338 -0.108311  0.018419
# 8516550     6  32667895   G     C    rs9275358 -0.104878  0.018604
# 19375028   17  43946318   C     T     rs753236 -0.082377  0.014885
#
#                      P                SNP
# 8515913   1.915226e-08     6:32654502:G:A
# 8516436   3.606783e-08     6:32665728:G:A
# 8516462   1.418208e-08     6:32666173:G:A
# 8516467   1.427414e-08     6:32666295:G:A
# 8516498   2.200645e-08     6:32666875:G:A
# 8516499   2.191341e-08     6:32666899:G:A
# 8516502   2.151642e-08     6:32666968:C:T
# 8516504   2.189626e-08  6:32667006:C:CATG
# 8516516   5.866648e-09     6:32667343:T:A
# 8516550   2.362490e-08     6:32667895:G:C
# 19375028  3.742743e-08    17:43946318:C:T

# %%
AD[AD['SNP'].isin(f3393['SNP'])]
# Out:
#           CHR       POS REF ALT               SNP    BETA      SE        P
# 16          1    693731   G   A      1:693731:G:A -0.0243  0.0161  0.13180
# 87          1    730087   C   T      1:730087:C:T -0.0078  0.0225  0.72810
# 93          1    731718   C   T      1:731718:C:T -0.0295  0.0155  0.05685
# 94          1    732032   C   A      1:732032:C:A -0.0343  0.0162  0.03397
# 114         1    734349   C   T      1:734349:C:T -0.0308  0.0155  0.04682
# ...       ...       ...  ..  ..               ...     ...     ...      ...
# 21101031   22  51219387   C   T   22:51219387:C:T  0.0004  0.0168  0.97900
# 21101049   22  51221731   C   T   22:51221731:C:T  0.0021  0.0168  0.90140
# 21101081   22  51229805   C   T   22:51229805:C:T -0.0001  0.0169  0.99430
# 21101103   22  51236013  AT   A  22:51236013:AT:A  0.0078  0.0110  0.47460
# 21101107   22  51237063   C   T   22:51237063:C:T -0.0044  0.0103  0.66660
#
# [6488159 rows x 8 columns]

# %%
f3393[f3393['SNP'].isin(AD['SNP'])]
# Out:
#           CHR       POS REF ALT        varid      BETA        SE         P  \
# 32          1    693731   G   A   rs12238997 -0.017106  0.020979  0.414868
# 53          1    730087   C   T  rs148120343  0.008566  0.029290  0.769938
# 54          1    731718   C   T   rs58276399 -0.015556  0.019901  0.434411
# 56          1    732032   C   A   rs61770163 -0.025332  0.021278  0.233832
# 57          1    734349   C   T  rs141242758 -0.015371  0.019910  0.440108
# ...       ...       ...  ..  ..          ...       ...       ...       ...
# 21735882   22  51219387   C   T    rs9616832 -0.040643  0.024311  0.094563
# 21735893   22  51221731   C   T  rs115055839 -0.043280  0.024333  0.075297
# 21735917   22  51229805   C   T    rs9616985 -0.043153  0.024427  0.077291
# 21735922   22  51236013  AT   A  rs200507571  0.002709  0.016160  0.866861
# 21735923   22  51237063   C   T    rs3896457  0.008595  0.014843  0.562525
#
#                        SNP
# 32            1:693731:G:A
# 53            1:730087:C:T
# 54            1:731718:C:T
# 56            1:732032:C:A
# 57            1:734349:C:T
# ...                    ...
# 21735882   22:51219387:C:T
# 21735893   22:51221731:C:T
# 21735917   22:51229805:C:T
# 21735922  22:51236013:AT:A
# 21735923   22:51237063:C:T
#
# [6487845 rows x 9 columns]

# %%
len(f3393['SNP'])
# Out:
# 21735926

# %%
len(AD['SNP'])
# Out:
# 21101114

# %% [markdown]
# ## AD_meta and f2247

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2247_ADmeta
clumping_sbatch=$clumping_dir/f2247_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2247_ADmeta/f2247_ADmeta-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=we08732f2bd56b244) is executed successfully with 1 completed step.

# %% [markdown]
# ### Check overalp between AD sumstats and f2247 sumstats

# %%
import pandas as pd
file = "/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.tsv.gz"
AD = pd.read_csv(file,compression="gzip",header=0,sep="\t")
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %%
AD.head()
# Out:
#    CHR     POS REF  ALT             SNP    BETA      SE       P
# 0    1  529825   C    T    1:529825:C:T -0.0152  0.3236  0.9626
# 1    1  531142   C  CTG  1:531142:C:CTG -0.2494  0.2247  0.2670
# 2    1  566327   G    A    1:566327:G:A  0.0975  0.4320  0.8214
# 3    1  581537   G    A    1:581537:G:A -0.3028  0.3180  0.3411
# 4    1  661906   G    C    1:661906:G:C  0.2938  0.3171  0.3542

# %%
#Number of hits that are genome-wide significant
AD_sig=AD[AD['P'] < 5e-08]

# %%
file='/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.gz'
f2247 = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
f2247.head()
# Out:
#    CHR    POS REF ALT        varid      BETA        SE         P          SNP
# 0    1  13259   A   G  rs562993331 -0.387653  0.169082  0.023123  1:13259:A:G
# 1    1  17569   A   C  rs535086049  0.331285  0.764723  0.664863  1:17569:A:C
# 2    1  17641   A   G  rs578081284  0.045154  0.103088  0.661374  1:17641:A:G
# 3    1  30741   A   C  rs558169846  1.763030  0.991047  0.024470  1:30741:A:C
# 4    1  57222   C   T  rs576081345 -0.050182  0.114946  0.662425  1:57222:C:T

# %%
f2247_sig=f2247[f2247['P'] < 5e-08]

# %%
AD_sig[AD_sig['SNP'].isin(f2247_sig['SNP'])]
# Out:
#          CHR       POS REF   ALT                SNP    BETA      SE  \
# 8199044    6  32577380   G     A     6:32577380:G:A  0.0729  0.0103
# 8199110    6  32578590   G     A     6:32578590:G:A  0.0736  0.0104
# 8199369    6  32584693   G     C     6:32584693:G:C  0.0747  0.0105
# 8200715    6  32654502   G     A     6:32654502:G:A  0.0798  0.0123
# 8201118    6  32665728   G     A     6:32665728:G:A  0.0766  0.0121
# 8201135    6  32666173   G     A     6:32666173:G:A  0.0795  0.0123
# 8201140    6  32666295   G     A     6:32666295:G:A  0.0793  0.0123
# 8201173    6  32666875   G     A     6:32666875:G:A  0.0760  0.0122
# 8201174    6  32666899   G     A     6:32666899:G:A  0.0761  0.0122
# 8201177    6  32666968   C     T     6:32666968:C:T  0.0760  0.0122
# 8201179    6  32667006   C  CATG  6:32667006:C:CATG  0.0790  0.0123
# 8201192    6  32667343   T     A     6:32667343:T:A  0.0727  0.0121
# 8201204    6  32667895   G     C     6:32667895:G:C  0.0778  0.0122
# 8201206    6  32667937   T     A     6:32667937:T:A  0.0793  0.0124
#
#                     P
# 8199044  1.829000e-12
# 8199110  1.362000e-12
# 8199369  9.003000e-13
# 8200715  1.004000e-10
# 8201118  2.682000e-10
# 8201135  1.218000e-10
# 8201140  1.323000e-10
# 8201173  3.967000e-10
# 8201174  3.775000e-10
# 8201177  4.034000e-10
# 8201179  1.423000e-10
# 8201192  2.167000e-09
# 8201204  2.088000e-10
# 8201206  1.512000e-10

# %%
f2247_sig[f2247_sig['SNP'].isin(AD_sig['SNP'])]
# Out:
#          CHR       POS REF   ALT        varid      BETA        SE  \
# 8555319    6  32577380   G     A     rs660895 -0.038348  0.006534
# 8555404    6  32578590   G     A    rs3997868 -0.037369  0.006557
# 8555800    6  32584693   G     C     rs510205 -0.038854  0.006549
# 8561048    6  32654502   G     A    rs9275183 -0.046044  0.008126
# 8561570    6  32665728   G     A    rs9275312 -0.044248  0.007994
# 8561596    6  32666173   G     A    rs9275318 -0.046374  0.008125
# 8561601    6  32666295   G     A    rs9275319 -0.046472  0.008127
# 8561632    6  32666875   G     A    rs9275330 -0.045466  0.008023
# 8561633    6  32666899   G     A    rs9275331 -0.045530  0.008023
# 8561636    6  32666968   C     T    rs9275333 -0.045572  0.008023
# 8561638    6  32667006   C  CATG  rs760571019 -0.044919  0.008025
# 8561650    6  32667343   T     A    rs9275338 -0.045788  0.008027
# 8561684    6  32667895   G     C    rs9275358 -0.045173  0.008094
# 8561687    6  32667937   T     A    rs9275360 -0.045895  0.008346
#
#                     P                SNP
# 8555319  4.579204e-09     6:32577380:G:A
# 8555404  1.251065e-08     6:32578590:G:A
# 8555800  3.103130e-09     6:32584693:G:C
# 8561048  1.546002e-08     6:32654502:G:A
# 8561570  3.286700e-08     6:32665728:G:A
# 8561596  1.216942e-08     6:32666173:G:A
# 8561601  1.144748e-08     6:32666295:G:A
# 8561632  1.541452e-08     6:32666875:G:A
# 8561633  1.469332e-08     6:32666899:G:A
# 8561636  1.425706e-08     6:32666968:C:T
# 8561638  2.305420e-08  6:32667006:C:CATG
# 8561650  1.243083e-08     6:32667343:T:A
# 8561684  2.528192e-08     6:32667895:G:C
# 8561687  4.038499e-08     6:32667937:T:A

# %% [markdown]
# ## AD_meta and f2257

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2257_ADmeta
clumping_sbatch=$clumping_dir/f2257_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2257_ADmeta/f2257_ADmeta-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=w1932b2f70073779a) is executed successfully with 1 completed step.

# %% [markdown]
# ### Check overalp between AD sumstats and f2257 sumstats

# %%
import pandas as pd
file = "/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.tsv.gz"
AD = pd.read_csv(file,compression="gzip",header=0,sep="\t")
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %%
AD.head()
# Out:
#    CHR     POS REF  ALT             SNP    BETA      SE       P
# 0    1  529825   C    T    1:529825:C:T -0.0152  0.3236  0.9626
# 1    1  531142   C  CTG  1:531142:C:CTG -0.2494  0.2247  0.2670
# 2    1  566327   G    A    1:566327:G:A  0.0975  0.4320  0.8214
# 3    1  581537   G    A    1:581537:G:A -0.3028  0.3180  0.3411
# 4    1  661906   G    C    1:661906:G:C  0.2938  0.3171  0.3542

# %%
#Number of hits that are genome-wide significant
AD_sig=AD[AD['P'] < 5e-08]

# %%
file='/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.gz'
f2257 = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
f2257.head()
# Out:
#    CHR    POS REF ALT        varid      BETA        SE         P          SNP
# 0    1  13259   A   G  rs562993331 -0.291280  0.157364  0.064170  1:13259:A:G
# 1    1  17569   A   C  rs535086049  0.301553  0.688140  0.661231  1:17569:A:C
# 2    1  17641   A   G  rs578081284  0.010873  0.090079  0.903924  1:17641:A:G
# 3    1  30741   A   C  rs558169846  0.665389  0.529693  0.209051  1:30741:A:C
# 4    1  57222   C   T  rs576081345  0.052396  0.102875  0.610529  1:57222:C:T

# %%
f2257_sig=f2257[f2257['P'] < 5e-08]

# %%
AD_res=AD_sig[AD_sig['SNP'].isin(f2257_sig['SNP'])]
AD_res.to_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_gwashits_in_f2257imp.tsv' , sep='\t', index=False, header=True)

# %%
f2257_res=f2257_sig[f2257_sig['SNP'].isin(AD_sig['SNP'])]
f2257_res.to_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/f2257imp_gwashits_in_AD.tsv' , sep='\t', index=False, header=True)

# %% [markdown]
# ## AD_meta and f2247_f2257

# %%
# # Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_combined_ADmeta
clumping_sbatch=$clumping_dir/combined_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_combined_ADmeta/combined_ADmeta-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=w807d8b080b4cc717) is executed successfully with 1 completed step.

# %% [markdown]
# ### Check overlap between ADmeta sumstats and combined sumstats

# %%
import pandas as pd
file = "/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.tsv.gz"
AD = pd.read_csv(file,compression="gzip",header=0,sep="\t")
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %%
AD.head()
# Out:
#    CHR     POS REF  ALT             SNP    BETA      SE       P
# 0    1  529825   C    T    1:529825:C:T -0.0152  0.3236  0.9626
# 1    1  531142   C  CTG  1:531142:C:CTG -0.2494  0.2247  0.2670
# 2    1  566327   G    A    1:566327:G:A  0.0975  0.4320  0.8214
# 3    1  581537   G    A    1:581537:G:A -0.3028  0.3180  0.3411
# 4    1  661906   G    C    1:661906:G:C  0.2938  0.3171  0.3542

# %%
#Number of hits that are genome-wide significant
AD_sig=AD[AD['P'] < 5e-08]

# %%
file='/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.gz'
comb = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
comb.head()
# Out:
#    CHR    POS REF ALT        varid      BETA        SE         P          SNP
# 0    1  13259   A   G  rs562993331 -0.439782  0.176722  0.014219  1:13259:A:G
# 1    1  17569   A   C  rs535086049  0.082381  0.804463  0.918436  1:17569:A:C
# 2    1  17641   A   G  rs578081284  0.073457  0.109471  0.502211  1:17641:A:G
# 3    1  30741   A   C  rs558169846  1.587040  0.987036  0.045833  1:30741:A:C
# 4    1  57222   C   T  rs576081345 -0.030952  0.122759  0.800936  1:57222:C:T

# %%
comb_sig=comb[comb['P'] < 5e-08]

# %%
AD_sig[AD_sig['SNP'].isin(comb_sig['SNP'])]
#AD_res.to_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_gwashits_in_f2257imp.tsv' , sep='\t', index=False, header=True)
# Out:
#           CHR       POS REF ALT              SNP    BETA      SE             P
# 8199044     6  32577380   G   A   6:32577380:G:A  0.0729  0.0103  1.829000e-12
# 8199369     6  32584693   G   C   6:32584693:G:C  0.0747  0.0105  9.003000e-13
# 18705003   17  43691377   C   T  17:43691377:C:T  0.0591  0.0101  4.438000e-09
# 18705640   17  43781105   G   A  17:43781105:G:A  0.0534  0.0098  4.805000e-08
# 18705643   17  43781426   C   T  17:43781426:C:T  0.0534  0.0098  4.623000e-08
# 18705734   17  43789640   C   A  17:43789640:C:A  0.0534  0.0098  4.714000e-08
# 18705774   17  43792358   G   A  17:43792358:G:A  0.0534  0.0098  4.648000e-08
# 18705778   17  43792586   C   A  17:43792586:C:A  0.0533  0.0098  4.792000e-08
# 18705781   17  43792895   G   T  17:43792895:G:T  0.0533  0.0098  4.829000e-08
# 18705782   17  43792896   C   T  17:43792896:C:T  0.0533  0.0098  4.749000e-08
# 18706345   17  43848750   C   T  17:43848750:C:T  0.0535  0.0098  4.565000e-08
# 18706391   17  43853133   C   T  17:43853133:C:T  0.0532  0.0098  4.871000e-08
# 18707029   17  43922942   C   T  17:43922942:C:T  0.0533  0.0098  4.580000e-08
# 18707047   17  43924219   C   T  17:43924219:C:T  0.0542  0.0098  2.988000e-08
# 18708109   17  44027366   G   T  17:44027366:G:T  0.0546  0.0098  2.568000e-08
# 18708134   17  44030311   G   T  17:44030311:G:T  0.0544  0.0098  2.727000e-08
# 18708136   17  44030773   G   A  17:44030773:G:A  0.0545  0.0098  2.534000e-08
# 18708163   17  44033002   C   T  17:44033002:C:T  0.0542  0.0098  3.119000e-08
# 18708303   17  44048336   C   T  17:44048336:C:T  0.0539  0.0098  3.972000e-08
# 18708304   17  44048350   C   T  17:44048350:C:T  0.0539  0.0098  3.960000e-08
# 18708469   17  44067400   C   T  17:44067400:C:T  0.0544  0.0098  2.780000e-08
# 18708742   17  44095467   C   T  17:44095467:C:T  0.0575  0.0097  2.991000e-09
# 18708812   17  44103825   C   T  17:44103825:C:T  0.0555  0.0098  1.779000e-08
# 18708836   17  44106220   G   A  17:44106220:G:A  0.0547  0.0098  2.471000e-08
# 18708858   17  44108906   G   A  17:44108906:G:A  0.0546  0.0098  2.558000e-08
# 18708907   17  44114362   T   A  17:44114362:T:A  0.0546  0.0100  4.415000e-08
# 18709006   17  44124535   C   T  17:44124535:C:T  0.0553  0.0098  1.748000e-08
# 18709346   17  44161470   C   A  17:44161470:C:A  0.0555  0.0100  3.175000e-08
# 18709387   17  44165049   G   A  17:44165049:G:A  0.0547  0.0098  2.546000e-08
# 18709388   17  44165069   G   A  17:44165069:G:A  0.0546  0.0098  2.593000e-08
# 18710138   17  44305199   C   T  17:44305199:C:T  0.0545  0.0100  4.775000e-08
# 18710168   17  44315803   C   A  17:44315803:C:A  0.0559  0.0102  4.389000e-08

# %%
comb_sig[comb_sig['SNP'].isin(AD_sig['SNP'])]
#f2257_res.to_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/f2257imp_gwashits_in_AD.tsv' , sep='\t', index=False, header=True)
# Out:
#           CHR       POS REF ALT       varid      BETA        SE             P  \
# 8543520     6  32577380   G   A    rs660895 -0.038974  0.006932  1.974104e-08
# 8544002     6  32584693   G   C    rs510205 -0.039528  0.006947  1.335611e-08
# 19452908   17  43691377   C   T    rs382362 -0.040797  0.007445  4.452665e-08
# 19453605   17  43781105   G   A    rs968028 -0.037328  0.006795  4.097698e-08
# 19453608   17  43781426   C   T  rs62056879 -0.037083  0.006793  4.988845e-08
# 19453696   17  43789640   C   A  rs62056930 -0.037202  0.006790  4.442833e-08
# 19453736   17  43792358   G   A  rs56160448 -0.037528  0.006793  3.439537e-08
# 19453741   17  43792586   C   A   rs1880749 -0.037438  0.006791  3.682392e-08
# 19453742   17  43792895   G   T   rs1568951 -0.037377  0.006791  3.877484e-08
# 19453743   17  43792896   C   T   rs1568950 -0.037377  0.006791  3.877484e-08
# 19454293   17  43848750   C   T  rs62055935 -0.037581  0.006837  4.039801e-08
# 19454339   17  43853133   C   T  rs62055950 -0.037080  0.006793  4.988041e-08
# 19454902   17  43922942   C   T  rs62621252 -0.037133  0.006788  4.672077e-08
# 19454918   17  43924219   C   T  rs12373124 -0.037259  0.006825  4.975996e-08
# 19455918   17  44027366   G   T  rs62062797 -0.037304  0.006827  4.838269e-08
# 19455942   17  44030311   G   T  rs17650651 -0.037078  0.006792  4.970156e-08
# 19455945   17  44030773   G   A  rs62062805 -0.037128  0.006794  4.824919e-08
# 19455961   17  44033002   C   T  rs62063262 -0.037085  0.006793  4.981613e-08
# 19456092   17  44048336   C   T  rs62063299 -0.037758  0.006836  3.469765e-08
# 19456093   17  44048350   C   T  rs62063300 -0.037736  0.006836  3.520303e-08
# 19456260   17  44067400   C   T  rs10445337 -0.037398  0.006789  3.759932e-08
# 19456516   17  44095467   C   T  rs58879558 -0.036907  0.006737  4.459231e-08
# 19456579   17  44103825   C   T  rs75010486 -0.038018  0.006858  3.083472e-08
# 19456603   17  44106220   G   A  rs79772576 -0.037374  0.006786  3.789658e-08
# 19456622   17  44108906   G   A  rs34579536 -0.037543  0.006784  3.262571e-08
# 19456667   17  44114362   T   A  rs62062324 -0.038000  0.006870  3.307425e-08
# 19456758   17  44124535   C   T  rs79065019 -0.037293  0.006787  4.078965e-08
# 19457074   17  44161470   C   A  rs80028338 -0.039447  0.007223  4.925496e-08
# 19457121   17  44165049   G   A   rs3912063 -0.037290  0.006803  4.384398e-08
# 19457122   17  44165069   G   A   rs3912062 -0.037306  0.006802  4.320062e-08
# 19458378   17  44305199   C   T   rs2260227 -0.037357  0.006799  4.081502e-08
# 19458438   17  44315803   C   A   rs2696673 -0.040794  0.007113  1.022869e-08
#
#                       SNP
# 8543520    6:32577380:G:A
# 8544002    6:32584693:G:C
# 19452908  17:43691377:C:T
# 19453605  17:43781105:G:A
# 19453608  17:43781426:C:T
# 19453696  17:43789640:C:A
# 19453736  17:43792358:G:A
# 19453741  17:43792586:C:A
# 19453742  17:43792895:G:T
# 19453743  17:43792896:C:T
# 19454293  17:43848750:C:T
# 19454339  17:43853133:C:T
# 19454902  17:43922942:C:T
# 19454918  17:43924219:C:T
# 19455918  17:44027366:G:T
# 19455942  17:44030311:G:T
# 19455945  17:44030773:G:A
# 19455961  17:44033002:C:T
# 19456092  17:44048336:C:T
# 19456093  17:44048350:C:T
# 19456260  17:44067400:C:T
# 19456516  17:44095467:C:T
# 19456579  17:44103825:C:T
# 19456603  17:44106220:G:A
# 19456622  17:44108906:G:A
# 19456667  17:44114362:T:A
# 19456758  17:44124535:C:T
# 19457074  17:44161470:C:A
# 19457121  17:44165049:G:A
# 19457122  17:44165069:G:A
# 19458378  17:44305199:C:T
# 19458438  17:44315803:C:A

# %% [markdown]
# # Bivariate LD_clumping analysis
#
# **Important Note:** please take into account that the number of clumps in the log file can (and possibly will) be different (higher) that the number of regions in the `*.clumped_regions` file because there will be some variants that are not clumped with any other and thus do not create a region.

# %% [markdown]
# ## AD_proxy data create format compatible with LD_clumping pipeline
#
# The file was provided by Andy DeWan from Yale cluster `/gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_imputed_data/AD`

# %%
file = pd.read_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt')

# %%
from pathlib import Path
formatFile= Path('~/project/UKBB_GWAS_dev/data/regenie_template.yml')
import gzip
import pandas as pd
file = pd.read_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt', header=0,delim_whitespace=True, quotechar='"' )
if formatFile.is_file():
    output = '~/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all' + '_original_columns.snp_stats.gz'
else:
    output = '~/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt' + '.snp_stats.gz'

# %%
file.head()
# Out:
#    CHROM  GENPOS           ID ALLELE0 ALLELE1    A1FREQ      INFO       N  \
# 0      1   13259  rs562993331       G       A  0.000268  0.845414  460649
# 1      1   17569  rs535086049       C       A  0.000012  0.843954  460649
# 2      1   17641  rs578081284       G       A  0.000799  0.853630  460649
# 3      1   30741  rs558169846       C       A  0.000022  0.903759  460649
# 4      1   57222  rs576081345       T       C  0.000622  0.837846  460649
#
#   TEST      BETA        SE     CHISQ    LOG10P  EXTRA         P
# 0  ADD  0.158113  0.203616  0.602991  0.359083    NaN  0.437438
# 1  ADD  1.407020  0.719964  3.579100  1.232760    NaN  0.058511
# 2  ADD  0.078532  0.119229  0.433839  0.292335    NaN  0.510111
# 3  ADD -1.314490  0.771762  2.901010  1.052940    NaN  0.088524
# 4  ADD  0.291624  0.126625  5.008980  1.598320    NaN  0.025216

# %%
file.to_csv(output, compression='gzip', sep='\t', header = True, index = False)

# %%
 # unify output format
import pandas as pd
from pathlib import Path
formatFile = Path('/home/dmc2245/project/UKBB_GWAS_dev/data/regenie_template.yml')
reverse_log_p = True
if formatFile.is_file() or reverse_log_p:
    sumstats = pd.read_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt', header=0,delim_whitespace=True, quotechar='"') 
    if formatFile.is_file():
        import yaml
        config = yaml.safe_load(open(formatFile, 'r'))
    try:
        sumstats = sumstats.loc[:,list(config.values())]
    except:
        raise ValueError(f'According to formatFile, input summary statistics should have the following columns: {list(config.values())}.')
    sumstats.columns = list(config.keys())
    if reverse_log_p:
            sumstats['P'] = sumstats['P'].apply(lambda row: 10**-row)
    sumstats.to_csv("~/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.reheader.snp_stats.gz", compression='gzip', sep='\t', header = True, index = False)

# %%
sumstats.head()
# Out:
#    CHR    POS REF ALT          SNP      BETA        SE         P
# 0    1  13259   G   A  rs562993331  0.158113  0.203616  0.437438
# 1    1  17569   C   A  rs535086049  1.407020  0.719964  0.058511
# 2    1  17641   G   A  rs578081284  0.078532  0.119229  0.510111
# 3    1  30741   C   A  rs558169846 -1.314490  0.771762  0.088524
# 4    1  57222   T   C  rs576081345  0.291624  0.126625  0.025216

# %% [markdown]
# ### AD_proxy and f3393

# %%
import pandas as pd
data = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.reheader.snp_stats.gz', compression='gzip', sep="\t", header=0, dtype=str)

# %%
data.head()
# Out:
#   CHR    POS REF ALT          SNP       BETA        SE                     P
# 0   1  13259   G   A  rs562993331   0.158113  0.203616   0.43743849630213455
# 1   1  17569   C   A  rs535086049    1.40702  0.719964   0.05851133403985255
# 2   1  17641   G   A  rs578081284  0.0785319  0.119229    0.5101113656100561
# 3   1  30741   C   A  rs558169846   -1.31449  0.771762    0.0885237901518778
# 4   1  57222   T   C  rs576081345   0.291624  0.126625  0.025216220879824072

# %%
data.rename(columns={'SNP':'varid'}, inplace=True)
data['SNP'] = data['CHR'] + ':' + data['POS'] + ':' + data['REF'] + ':' + data['ALT']
data.to_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.final.snp_stats.gz', sep='\t', index=False, header=True, compression="gzip")

# %%
data.head()
# Out:
#   CHR    POS REF ALT        varid       BETA        SE                     P  \
# 0   1  13259   G   A  rs562993331   0.158113  0.203616   0.43743849630213455
# 1   1  17569   C   A  rs535086049    1.40702  0.719964   0.05851133403985255
# 2   1  17641   G   A  rs578081284  0.0785319  0.119229    0.5101113656100561
# 3   1  30741   C   A  rs558169846   -1.31449  0.771762    0.0885237901518778
# 4   1  57222   T   C  rs576081345   0.291624  0.126625  0.025216220879824072
#
#            SNP
# 0  1:13259:G:A
# 1  1:17569:C:A
# 2  1:17641:G:A
# 3  1:30741:C:A
# 4  1:57222:T:C

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f3393_ADproxy
clumping_sbatch=$clumping_dir/f3393_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f3393_ADproxy/f3393_ADproxy-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=wf767271d8665d92f) is executed successfully with 1 completed step.

# %% [markdown]
# ### Check overlap between AD proxy sumstats and f3393 sumstats

# %%
import pandas as pd
file = "/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.final.snp_stats.gz"
ADproxy = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
ADproxy.head()
# Out:
#    CHR    POS REF ALT        varid      BETA        SE         P          SNP
# 0    1  13259   G   A  rs562993331  0.158113  0.203616  0.437438  1:13259:G:A
# 1    1  17569   C   A  rs535086049  1.407020  0.719964  0.058511  1:17569:C:A
# 2    1  17641   G   A  rs578081284  0.078532  0.119229  0.510111  1:17641:G:A
# 3    1  30741   C   A  rs558169846 -1.314490  0.771762  0.088524  1:30741:C:A
# 4    1  57222   T   C  rs576081345  0.291624  0.126625  0.025216  1:57222:T:C

# %%
#Number of hits that are genome-wide significant
ADproxy[ADproxy['P'] < 5e-08]
# Out:
#           CHR        POS REF ALT       varid      BETA        SE  \
# 1458344     1  207684192   T   G  rs12037841 -0.046865  0.008055
# 1458360     1  207685965   A   C   rs4562624 -0.047314  0.008047
# 1458405     1  207692049   A   G   rs6656401 -0.048239  0.008065
# 1458559     1  207747296   A   G   rs1752684 -0.045510  0.008029
# 1458600     1  207750568   T   C    rs679515 -0.048780  0.008080
# ...       ...        ...  ..  ..         ...       ...       ...
# 21104267    8   27466912   G  GA  rs11449170  0.044635  0.006392
# 21104276    8   27467686   C   T   rs9331896  0.044401  0.006381
# 21104279    8   27467821   C   G   rs2070926  0.045557  0.006390
# 21104286    8   27468503   C   A    rs867230  0.045308  0.006406
# 22032329    8  139393909   C   T   rs1519369  0.036701  0.006671
#
#                      P              SNP
# 1458344   6.716299e-09  1:207684192:T:G
# 1458360   4.653932e-09  1:207685965:A:C
# 1458405   2.519997e-09  1:207692049:A:G
# 1458559   1.613095e-08  1:207747296:A:G
# 1458600   1.791884e-09  1:207750568:T:C
# ...                ...              ...
# 21104267  2.747894e-12  8:27466912:G:GA
# 21104276  3.305978e-12   8:27467686:C:T
# 21104279  9.600636e-13   8:27467821:C:G
# 21104286  1.451443e-12   8:27468503:C:A
# 22032329  3.941486e-08  8:139393909:C:T
#
# [1742 rows x 9 columns]

# %%
file='/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.gz'
f3393 = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
f3393.head()
# Out:
#    CHR    POS REF ALT        varid      BETA        SE         P          SNP
# 0    1  13259   A   G  rs562993331 -0.444965  0.405872  0.272939  1:13259:A:G
# 1    1  17569   A   C  rs535086049  1.195410  1.869850  0.522621  1:17569:A:C
# 2    1  17641   A   G  rs578081284  0.435933  0.233139  0.061506  1:17641:A:G
# 3    1  30741   A   C  rs558169846  1.280430  1.245250  0.303832  1:30741:A:C
# 4    1  52144   A   T  rs190291950 -0.117852  0.337249  0.726750  1:52144:A:T

# %%
f3393[f3393['P'] < 5e-08]
# Out:
#           CHR       POS REF     ALT                 varid      BETA        SE  \
# 2181439     2  54687254   T       C            rs13026575 -0.091392  0.016453
# 2181496     2  54693754   G       T            rs10169422 -0.089591  0.015662
# 2181535     2  54697387   A      AT       2:54697387_AT_A -0.081630  0.014796
# 2181560     2  54699021   C       T             rs9677271 -0.093448  0.016656
# 2181562     2  54699067   A  AACTTC           rs746705223 -0.093255  0.016662
# ...       ...       ...  ..     ...                   ...       ...       ...
# 21733696   22  50956117   A       G           rs200126237 -0.909770  0.141901
# 21734140   22  50993633   T       C       22:50993633_C_T -1.425390  0.175632
# 21734565   22  51032411   G       A           rs776344563 -1.469330  0.183468
# 21735509   22  51146132   C  CAAATA  22:51146132_CAAATA_C -1.262120  0.186638
# 21735924   22  51237215   T       C           rs536109858 -1.345640  0.209808
#
#                      P                   SNP
# 2181439   3.519978e-08        2:54687254:T:C
# 2181496   1.338474e-08        2:54693754:G:T
# 2181535   4.111308e-08       2:54697387:A:AT
# 2181560   2.598723e-08        2:54699021:C:T
# 2181562   2.809959e-08   2:54699067:A:AACTTC
# ...                ...                   ...
# 21733696  3.488751e-09       22:50956117:A:G
# 21734140  2.767579e-13       22:50993633:T:C
# 21734565  5.858683e-13       22:51032411:G:A
# 21735509  8.077370e-10  22:51146132:C:CAAATA
# 21735924  6.360189e-09       22:51237215:T:C
#
# [1337 rows x 9 columns]

# %%
ADproxy_sig[ADproxy_sig['varid'].isin(f3393_sig['varid'])]
# Out:
#           CHR       POS REF ALT      varid      BETA        SE             P  \
# 18189710    6  32665728   A   G  rs9275312 -0.053307  0.009735  3.834864e-08
# 18189768    6  32666802   C   T  rs9275327 -0.053083  0.009776  4.980696e-08
# 18189770    6  32666822   C   T  rs9275328 -0.053097  0.009776  4.938784e-08
# 18189814    6  32667638   G   A  rs9275348 -0.053767  0.009840  4.097227e-08
# 18189825    6  32667895   C   G  rs9275358 -0.054177  0.009860  3.447625e-08
# 18189831    6  32667957   C   T  rs9275362 -0.054326  0.009988  4.726830e-08
# 18189841    6  32668125   G   A  rs9275365 -0.053562  0.009758  3.556805e-08
#
#                      SNP
# 18189710  6:32665728:A:G
# 18189768  6:32666802:C:T
# 18189770  6:32666822:C:T
# 18189814  6:32667638:G:A
# 18189825  6:32667895:C:G
# 18189831  6:32667957:C:T
# 18189841  6:32668125:G:A

# %%
# Issues with REF/ALT alleles. GWAS was run again with --ref_first to account for these differences. 
f3393_sig[f3393_sig['varid'].isin(ADproxy_sig['varid'])]
# Out:
#          CHR       POS REF ALT      varid      BETA        SE             P  \
# 8516436    6  32665728   G   A  rs9275312 -0.102268  0.018389  3.606783e-08
# 8516493    6  32666802   T   C  rs9275327 -0.104226  0.018451  2.210192e-08
# 8516495    6  32666822   T   C  rs9275328 -0.104121  0.018451  2.281970e-08
# 8516539    6  32667638   A   G  rs9275348 -0.102989  0.018589  4.056113e-08
# 8516550    6  32667895   G   C  rs9275358 -0.104878  0.018604  2.362490e-08
# 8516555    6  32667957   T   C  rs9275362 -0.103782  0.018842  4.881463e-08
# 8516565    6  32668125   A   G  rs9275365 -0.103314  0.018425  2.791130e-08
#
#                     SNP
# 8516436  6:32665728:G:A
# 8516493  6:32666802:T:C
# 8516495  6:32666822:T:C
# 8516539  6:32667638:A:G
# 8516550  6:32667895:G:C
# 8516555  6:32667957:T:C
# 8516565  6:32668125:A:G

# %% [markdown]
# ## AD_proxy and f2247

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2247_ADproxy
clumping_sbatch=$clumping_dir/f2247_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2247_ADproxy/f2247_ADproxy-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=wb761843e0224ccac) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD proxy and f2257

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2257_ADproxy
clumping_sbatch=$clumping_dir/f2257_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2257_ADproxy/f2257_ADproxy-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=w5fad6235b33f0392) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD proxy and f2247_f2257

# %%
# # Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_combined_ADproxy
clumping_sbatch=$clumping_dir/combined_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_combined_ADproxy/combined_ADproxy-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=w79db46045a15b733) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD proxy and ADmeta

# %%
# # Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_ADmeta_ADproxy
clumping_sbatch=$clumping_dir/ADmeta_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz`

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_ADmeta_ADproxy/ADmeta_ADproxy-ldclumping_2022-08-10.sbatch
# INFO: Workflow csg (ID=wccf54b3709973dd2) is executed successfully with 1 completed step.

# %% [markdown]
# ### Use the replicate option
#
# This means that only clumps containing clumped SNPs with p2-significant results in more than one result file are shown.

# %%
## Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/081822_ADmeta_ADproxy_replicate
clumping_sbatch=$clumping_dir/ADmeta_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz`
replicate=True
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=5e-06
clump_r2=0.04
clump_kb=2000
clump_annotate=BETA
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate
    --replicate $replicate
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/081822_ADmeta_ADproxy_replicate/ADmeta_ADproxy-ldclumping_2022-08-18.sbatch
# INFO: Workflow csg (ID=wc52702c093137b46) is executed successfully with 1 completed step.

# %% [markdown]
# ### Find overlap between AD_meta and AD_proxy

# %%
import pandas as pd
file = "/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz"
AD_meta = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
AD_meta
# Out:
#           CHR       POS REF  ALT    BETA      SE       P     SNP_original  \
# 0           1    529825   C    T -0.0152  0.3236  0.9626     1:529825:C:T
# 1           1    531142   C  CTG -0.2494  0.2247  0.2670   1:531142:C:CTG
# 2           1    566327   G    A  0.0975  0.4320  0.8214     1:566327:G:A
# 3           1    581537   G    A -0.3028  0.3180  0.3411     1:581537:G:A
# 4           1    661906   G    C  0.2938  0.3171  0.3542     1:661906:G:C
# ...       ...       ...  ..  ...     ...     ...     ...              ...
# 21101109   22  51237496   C    T  0.1502  0.2931  0.6083  22:51237496:C:T
# 21101110   22  51237535   C    A -0.0655  0.2898  0.8213  22:51237535:C:A
# 21101111   22  51238249   C    A  0.0098  0.0228  0.6673  22:51238249:C:A
# 21101112   22  51238318   T    A  0.0476  0.0813  0.5584  22:51238318:T:A
# 21101113   22  51238328   C    A  0.0312  0.1082  0.7731  22:51238328:C:A
#
#                       SNP
# 0            1:529825:C:T
# 1          1:531142:C:CTG
# 2            1:566327:G:A
# 3            1:581537:G:A
# 4            1:661906:G:C
# ...                   ...
# 21101109  22:51237496:C:T
# 21101110  22:51237535:C:A
# 21101111  22:51238249:C:A
# 21101112  22:51238318:T:A
# 21101113  22:51238328:C:A
#
# [21101114 rows x 9 columns]

# %%
#Number of hits that are genome-wide significant
AD_meta_sig=AD_meta[AD_meta['P'] < 5e-06]

# %%
file='/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz'
AD_proxy = pd.read_csv(file,compression="gzip",header=0,sep="\t")

# %%
AD_proxy
# Out:
#           CHR        POS REF ALT       MAF      INFO      BETA        SE  \
# 0           1      13259   G   A  0.000268  0.845414  0.158113  0.203616
# 1           1      17569   C   A  0.000012  0.843954  1.407020  0.719964
# 2           1      17641   G   A  0.000799  0.853630  0.078532  0.119229
# 3           1      30741   C   A  0.000022  0.903759 -1.314490  0.771762
# 4           1      57222   T   C  0.000622  0.837846  0.291624  0.126625
# ...       ...        ...  ..  ..       ...       ...       ...       ...
# 23095994    9  141101939   C   T  0.022299  1.000000 -0.008858  0.021224
# 23095995    9  141102535  CT   C  0.000484  0.816239  0.266958  0.153428
# 23095996    9  141102859   C   T  0.011236  0.809996 -0.013092  0.032992
# 23095997    9  141104957   G   A  0.010978  0.846640  0.023038  0.032529
# 23095998    9  141109216   A   G  0.000211  0.925246 -0.394753  0.218611
#
#                  P             varid      SNP_original               SNP
# 0         0.437438       rs562993331       1:13259:G:A       1:13259:G:A
# 1         0.058511       rs535086049       1:17569:C:A       1:17569:C:A
# 2         0.510111       rs578081284       1:17641:G:A       1:17641:G:A
# 3         0.088524       rs558169846       1:30741:C:A       1:30741:C:A
# 4         0.025216       rs576081345       1:57222:T:C       1:57222:T:C
# ...            ...               ...               ...               ...
# 23095994  0.676424   9:141101939_C_T   9:141101939:C:T   9:141101939:C:T
# 23095995  0.081865  9:141102535_CT_C  9:141102535:CT:C  9:141102535:CT:C
# 23095996  0.691506   9:141102859_C_T   9:141102859:C:T   9:141102859:C:T
# 23095997  0.478803   9:141104957_G_A   9:141104957:G:A   9:141104957:G:A
# 23095998  0.070959   9:141109216_A_G   9:141109216:A:G   9:141109216:A:G
#
# [23095999 rows x 12 columns]

# %%
AD_proxy_sig=AD_proxy[AD_proxy['P'] < 5e-06]

# %%
AD_meta_sig[AD_meta_sig['SNP'].isin(AD_proxy_sig['SNP'])]
# Out:
#           CHR        POS REF ALT    BETA      SE             P  \
# 991475      1  161097241   T   A  0.0451  0.0090  5.831000e-07
# 991490      1  161100336   T   A  0.0446  0.0090  7.636000e-07
# 991505      1  161103445   G   T -0.0491  0.0088  2.677000e-08
# 991511      1  161104124   G   A  0.0447  0.0090  7.208000e-07
# 991522      1  161106354   G   T -0.0494  0.0088  2.242000e-08
# ...       ...        ...  ..  ..     ...     ...           ...
# 19936176   19   45806553   C   T  0.3074  0.0437  2.034000e-12
# 19936327   19   45825418   C   T  0.3338  0.0521  1.538000e-10
# 19936371   19   45830947   G   A -0.0451  0.0089  4.086000e-07
# 19936431   19   45838141   C   T  0.6209  0.0764  4.215000e-16
# 19936614   19   45855406   G   C  0.5474  0.0649  3.159000e-17
#
#              SNP_original              SNP
# 991475    1:161097241:T:A  1:161097241:T:A
# 991490    1:161100336:T:A  1:161100336:T:A
# 991505    1:161103445:G:T  1:161103445:T:G
# 991511    1:161104124:G:A  1:161104124:G:A
# 991522    1:161106354:G:T  1:161106354:T:G
# ...                   ...              ...
# 19936176  19:45806553:C:T  19:45806553:C:T
# 19936327  19:45825418:C:T  19:45825418:C:T
# 19936371  19:45830947:G:A  19:45830947:G:A
# 19936431  19:45838141:C:T  19:45838141:C:T
# 19936614  19:45855406:G:C  19:45855406:G:C
#
# [2097 rows x 9 columns]

# %%
AD_proxy_sig[AD_proxy_sig['SNP'].isin(AD_meta_sig['SNP'])]
#f2257_res.to_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/f2257imp_gwashits_in_AD.tsv' , sep='\t', index=False, header=True)
# Out:
#           CHR        POS REF ALT       MAF      INFO      BETA        SE  \
# 1065054     1  161097241   T   A  0.275104  0.999587  0.032051  0.006947
# 1065073     1  161100336   T   A  0.275114  0.999638  0.032019  0.006946
# 1065090     1  161103445   T   G  0.295974  0.999809  0.032169  0.006802
# 1065094     1  161104124   G   A  0.275063  0.999811  0.031940  0.006946
# 1065110     1  161106354   T   G  0.295966  0.999906  0.032252  0.006802
# ...       ...        ...  ..  ..       ...       ...       ...       ...
# 21104385    8   27481984   C   T  0.689115  0.987385  0.034706  0.006813
# 21104388    8   27482354   T   G  0.310179  0.987466 -0.034708  0.006816
# 21104425    8   27486916   G   A  0.310241  0.987670 -0.034207  0.006814
# 21104471    8   27494366   T   C  0.041300  0.983765 -0.077456  0.016219
# 21105174    8   27574166   T   G  0.039412  0.978535 -0.080823  0.016641
#
#                      P        varid     SNP_original              SNP
# 1065054   4.102135e-06   rs12727614  1:161097241:T:A  1:161097241:T:A
# 1065073   4.190058e-06   rs11583045  1:161100336:T:A  1:161100336:T:A
# 1065090   2.336307e-06   rs10797093  1:161103445:T:G  1:161103445:T:G
# 1065094   4.421911e-06    rs4540676  1:161104124:G:A  1:161104124:G:A
# 1065110   2.198214e-06   rs11265557  1:161106354:T:G  1:161106354:T:G
# ...                ...          ...              ...              ...
# 21104385  3.361940e-07     rs507341   8:27481984:C:T   8:27481984:T:C
# 21104388  3.401496e-07     rs495150   8:27482354:T:G   8:27482354:T:G
# 21104425  4.962837e-07     rs576748   8:27486916:G:A   8:27486916:G:A
# 21104471  1.470415e-06  rs138529507   8:27494366:T:C   8:27494366:T:C
# 21105174  9.640732e-07  rs117606656   8:27574166:T:G   8:27574166:T:G
#
# [2097 rows x 12 columns]

# %% [markdown]
# # Try univariate clumping to see which regions appear and lower p-value to 5e-06

# %% [markdown]
# ## AD_proxy clump
#
# Run first round of univariate clump to identify variants with flipped alleles

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_ADproxy
clumping_sbatch=$clumping_dir/ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.final.snp_stats.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=BP
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/ADproxy/ADproxy-ldclumping_2022-08-04.sbatch
# INFO: Workflow csg (ID=w117c1f46c49790a7) is executed successfully with 1 completed step.

# %% [markdown]
# ### Create Allele flip file

# %%
# To get the variant ID of the alleles that need to be flipped
cd ~/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_ADproxy
cat AD_step2_BT_all.final.snp_stats.clumped | grep "not found in dataset" | awk '{print $1}' > ADproxy_allele_flip

# %%
import pandas as pd
stat = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.gz', dtype=str, compression='gzip',sep="\t", header=0)
stat.rename(columns={'CHROM':'CHR', 'GENPOS':'POS', 'ID':'varid', 'ALLELE0':'REF', 'ALLELE1':'ALT', 'A1FREQ':'MAF','P':'P'}, inplace=True)
#stat[['P']] = stat[['P']].apply(pd.to_numeric)
#stat['P'] = stat['P'].apply(lambda row: 10**-row)
stat['SNP_original'] = stat["CHR"].str.cat(others=[stat["POS"],stat['REF'],stat['ALT']], sep=':')
stat["CHR_POS"] = stat["CHR"].str.cat(others=[stat["POS"]], sep=':')
flip_list= pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_ADproxy/ADproxy_allele_flip', dtype=str , header=None , names=['SNP'])
changelist = flip_list['SNP'].tolist()
stat['SNP']=stat.loc[:, 'SNP_original']

# %%
def snp_flip(row):
    row["SNP"] = str(row["CHR"])+":"+str(row["POS"])+":"+row["ALT"]+":"+row["REF"]
    return row

# %%
stat[stat['SNP'].isin(changelist)] = stat[stat['SNP'].isin(changelist)].apply(snp_flip,axis=1)

# %%
stat[stat['SNP_original'].isin(changelist)]
# Out:
#          CHR        POS       varid REF ALT       MAF      INFO       N TEST  \
# 1458289    1  207679307   rs4844600   A   G  0.811141  0.993394  460649  ADD
# 1458344    1  207684192  rs12037841   T   G   0.82115  0.998536  460649  ADD
# 1458359    1  207685786   rs4266886   T   C  0.811316   0.99526  460649  ADD
# 1458360    1  207685965   rs4562624   A   C  0.821226       1.0  460649  ADD
# 1458405    1  207692049   rs6656401   A   G   0.82207  0.999179  460649  ADD
# ...       ..        ...         ...  ..  ..       ...       ...     ...  ...
# 22032102   8  139366534  rs11166817   C   T  0.644352  0.998075  460649  ADD
# 22032107   8  139367027  rs17722613   G   A  0.644394  0.998056  460649  ADD
# 22032108   8  139367262  rs11782012   C   T  0.643547  0.998113  460649  ADD
# 22032207   8  139381546    rs340708   G   T  0.644328  0.999248  460649  ADD
# 22032212   8  139382205    rs340710   C   A   0.64429       1.0  460649  ADD
#
#                 BETA          SE    CHISQ   LOG10P EXTRA  \
# 1458289   -0.0389473  0.00792551  24.0149  6.01957   NaN
# 1458344   -0.0468646  0.00805513  33.6153  8.17287   NaN
# 1458359   -0.0400964    0.007919  25.4903  6.35201   NaN
# 1458360   -0.0473144  0.00804713   34.329  8.33218   NaN
# 1458405   -0.0482389  0.00806466  35.5235   8.5986   NaN
# ...              ...         ...      ...      ...   ...
# 22032102  -0.0305679  0.00650746  22.0191  5.56872   NaN
# 22032107  -0.0305161  0.00650787  21.9418  5.55123   NaN
# 22032108  -0.0301768  0.00650446  21.4799  5.44666   NaN
# 22032207  -0.0303928  0.00650423  21.7895  5.51675   NaN
# 22032212  -0.0310882  0.00650286  22.8065  5.74677   NaN
#
#                                P     SNP_original      CHR_POS  \
# 1458289     9.55938603503361e-07  1:207679307:A:G  1:207679307
# 1458344   6.7162986587847305e-09  1:207684192:T:G  1:207684192
# 1458359     4.44621029573694e-07  1:207685786:T:C  1:207685786
# 1458360   4.6539316421925305e-09  1:207685965:A:C  1:207685965
# 1458405   2.5199968621092403e-09  1:207692049:A:G  1:207692049
# ...                          ...              ...          ...
# 22032102    2.69947929013705e-06  8:139366534:C:T  8:139366534
# 22032107    2.81041205724176e-06  8:139367027:G:A  8:139367027
# 22032108    3.57552649044493e-06  8:139367262:C:T  8:139367262
# 22032207    3.04263600373233e-06  8:139381546:G:T  8:139381546
# 22032212     1.7915544003254e-06  8:139382205:C:A  8:139382205
#
#                       SNP
# 1458289   1:207679307:G:A
# 1458344   1:207684192:G:T
# 1458359   1:207685786:C:T
# 1458360   1:207685965:C:A
# 1458405   1:207692049:G:A
# ...                   ...
# 22032102  8:139366534:T:C
# 22032107  8:139367027:A:G
# 22032108  8:139367262:T:C
# 22032207  8:139381546:T:G
# 22032212  8:139382205:A:C
#
# [740 rows x 18 columns]

# %%
header = ["CHR", "POS", "REF", "ALT", "MAF", "INFO", "BETA", "SE", "P", "varid", "SNP_original", "SNP"]
stat.to_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz', index=False, compression='gzip',sep="\t", columns = header)

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_ADproxy
clumping_sbatch=$clumping_dir/ADproxy-ldclumping_flip_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=BP
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_ADproxy/ADproxy-ldclumping_flip_2022-08-04.sbatch
# INFO: Workflow csg (ID=wdd06a4f2948a0bc9) is executed successfully with 1 completed step.

# %% [markdown]
# ### After applying the allele_flip code there are still 15 top variants not present in the reference_file
#
# These variants can be found at the tail of this file
# `~/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_ADproxy/*.regenie.snp_stats.ldclump.clumped`

# %% [markdown]
# ## f3393 clump

# %%
# Set the bash variables 
# memory 80GB
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f3393
clumping_sbatch=$clumping_dir/f3393-ldclumping$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.gz
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=varid
numThreads=1
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f3393/f3393-ldclumping2022-08-05.sbatch
# INFO: Workflow csg (ID=w23848caebd857ce7) is executed successfully with 1 completed step.

# %% [markdown]
# After replacing the reference file for the new one where all the variants are names by CHR:POS:REF:ALT and the duplicated ones are removed we get the following results
#
#
# This new problem arises where some of the alleles are still flipped in the summary stats/reference sequence
#
# ```
# 941 top variant IDs missing; see the end of the .clumped file.
# --clump: 135 clumps formed from 6544 top variants
# ```
#
# In the reference.bim file `ukb39554_c1_22_v3.imputed.renamedvar.nondup.2000.ref_geno.bim`:
#
# Example:
# ```
# 6:32585755:A(major):T(minor)
# 6	6:32585755:A:T	0	32585755	T	A
# ```
#
# In the summary stats file
# ```
# 6:32585755:T(ref):A(alt)
# 6	32585755	T	A	rs3129762	0.0818472	0.0180549	4.992637104333426e-06	6:32585755:T:A
# ```
#
# In dbsnp
#
# ```
# Europeans T=0.14 (reference) and A=0.86 (alternative)
# ```

# %% [markdown]
# I can think of one solution to solve this temporarly
#
# 1. Create an extra column in the sumstats of the f3393 and flip all the variants having this issue to the format found in the bim file (major:minor) keeping the original SNP column renamed to SPN_ref_alt and the other one would be SNP (major/minor)

# %%
import pandas as pd
f3393 = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f3393/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats_original_columns.gz', dtype=str, compression='gzip',sep="\t", header=0)

# %%
f3393.head()
# Out:
#   CHROM GENPOS           ID ALLELE0 ALLELE1       A1FREQ      INFO       N  \
# 0     1  13259  rs562993331       G       A  0.000240613  0.844357  251433
# 1     1  17569  rs535086049       C       A  1.34679e-05  0.894182  251433
# 2     1  17641  rs578081284       G       A  0.000794684  0.852345  251433
# 3     1  30741  rs558169846       C       A  2.55789e-05  0.910708  251433
# 4     1  52144  rs190291950       T       A  0.000485679  0.802923  251433
#
#   TEST       BETA        SE     CHISQ    LOG10P EXTRA
# 0  ADD   0.444965  0.405872   1.20192  0.563934   NaN
# 1  ADD   -1.19541   1.86985  0.408719  0.281813   NaN
# 2  ADD  -0.435933  0.233139    3.4963   1.21108   NaN
# 3  ADD   -1.28043   1.24525    1.0573  0.517366   NaN
# 4  ADD   0.117852  0.337249  0.122117  0.138615   NaN

# %%
f3393.rename(columns={'CHROM':'CHR', 'GENPOS':'POS', 'ID':'varid', 'ALLELE0':'REF', 'ALLELE1':'ALT', 'A1FREQ':'MAF','LOG10P':'P'}, inplace=True)

# %%
f3393.head()
# Out:
#   CHR    POS        varid REF ALT          MAF      INFO       N TEST  \
# 0   1  13259  rs562993331   G   A  0.000240613  0.844357  251433  ADD
# 1   1  17569  rs535086049   C   A  1.34679e-05  0.894182  251433  ADD
# 2   1  17641  rs578081284   G   A  0.000794684  0.852345  251433  ADD
# 3   1  30741  rs558169846   C   A  2.55789e-05  0.910708  251433  ADD
# 4   1  52144  rs190291950   T   A  0.000485679  0.802923  251433  ADD
#
#         BETA        SE     CHISQ         P EXTRA SNP_original
# 0   0.444965  0.405872   1.20192  0.272939   NaN  1:13259:G:A
# 1   -1.19541   1.86985  0.408719  0.522621   NaN  1:17569:C:A
# 2  -0.435933  0.233139    3.4963  0.061506   NaN  1:17641:G:A
# 3   -1.28043   1.24525    1.0573  0.303832   NaN  1:30741:C:A
# 4   0.117852  0.337249  0.122117  0.726750   NaN  1:52144:T:A

# %%
f3393[['P']] = f3393[['P']].apply(pd.to_numeric)
f3393['P'] = f3393['P'].apply(lambda row: 10**-row)

# %%
f3393['SNP_original'] = f3393['CHR'] + ':' + f3393['POS'] + ':' + f3393['REF'] + ':' + f3393['ALT']

# %%
f3393.head()
# Out:
#   CHR    POS        varid REF ALT       A1FREQ      INFO       N TEST  \
# 0   1  13259  rs562993331   G   A  0.000240613  0.844357  251433  ADD
# 1   1  17569  rs535086049   C   A  1.34679e-05  0.894182  251433  ADD
# 2   1  17641  rs578081284   G   A  0.000794684  0.852345  251433  ADD
# 3   1  30741  rs558169846   C   A  2.55789e-05  0.910708  251433  ADD
# 4   1  52144  rs190291950   T   A  0.000485679  0.802923  251433  ADD
#
#         BETA        SE     CHISQ         P EXTRA SNP_original
# 0   0.444965  0.405872   1.20192  0.272939   NaN  1:13259:G:A
# 1   -1.19541   1.86985  0.408719  0.522621   NaN  1:17569:C:A
# 2  -0.435933  0.233139    3.4963  0.061506   NaN  1:17641:G:A
# 3   -1.28043   1.24525    1.0573  0.303832   NaN  1:30741:C:A
# 4   0.117852  0.337249  0.122117  0.726750   NaN  1:52144:T:A

# %%
flip_list= pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/f3393/f3393_allele_flip_list', dtype=str , header=0 , names=['SNP'])

# %%
flip_list.head()
# Out:
#                  SNP
# 0  5:73090165:A:AGTT
# 1     5:73090533:A:G
# 2     5:73090261:T:C
# 3     5:73073615:T:C
# 4     5:73090589:G:A

# %%
flip_var = flip_list['SNP'].tolist()

# %%
f3393['SNP']=f3393.loc[:, 'SNP_original']
f3393.head()
# Out:
#   CHR    POS        varid REF ALT          MAF      INFO       N TEST  \
# 0   1  13259  rs562993331   G   A  0.000240613  0.844357  251433  ADD
# 1   1  17569  rs535086049   C   A  1.34679e-05  0.894182  251433  ADD
# 2   1  17641  rs578081284   G   A  0.000794684  0.852345  251433  ADD
# 3   1  30741  rs558169846   C   A  2.55789e-05  0.910708  251433  ADD
# 4   1  52144  rs190291950   T   A  0.000485679  0.802923  251433  ADD
#
#         BETA        SE     CHISQ         P EXTRA SNP_original          SNP
# 0   0.444965  0.405872   1.20192  0.272939   NaN  1:13259:G:A  1:13259:G:A
# 1   -1.19541   1.86985  0.408719  0.522621   NaN  1:17569:C:A  1:17569:C:A
# 2  -0.435933  0.233139    3.4963  0.061506   NaN  1:17641:G:A  1:17641:G:A
# 3   -1.28043   1.24525    1.0573  0.303832   NaN  1:30741:C:A  1:30741:C:A
# 4   0.117852  0.337249  0.122117  0.726750   NaN  1:52144:T:A  1:52144:T:A

# %%
# To get the variant ID of the alleles that need to be flipped
cd ~/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f3393
cat 071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.clumped | grep "not found in dataset" | awk '{print $1}' > f3393_allele_flip

# %%
import pandas as pd
stat = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f3393/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats_original_columns.gz', dtype=str, compression='gzip',sep="\t", header=0)
stat.rename(columns={'CHROM':'CHR', 'GENPOS':'POS', 'ID':'varid', 'ALLELE0':'REF', 'ALLELE1':'ALT', 'A1FREQ':'MAF','LOG10P':'P'}, inplace=True)
stat[['P']] = stat[['P']].apply(pd.to_numeric)
stat['P'] = stat['P'].apply(lambda row: 10**-row)
stat['SNP_original'] = stat["CHR"].str.cat(others=[stat["POS"],stat['REF'],stat['ALT']], sep=':')
stat["CHR_POS"] = stat["CHR"].str.cat(others=[stat["POS"]], sep=':')
flip_list= pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f3393/f3393_allele_flip', dtype=str , header=None , names=['SNP'])
changelist = flip_list['SNP'].tolist()
stat['SNP']=stat.loc[:, 'SNP_original']

# %%
def snp_flip(row):
    row["SNP"] = str(row["CHR"])+":"+str(row["POS"])+":"+row["ALT"]+":"+row["REF"]
    return row

# %%
stat[stat['SNP'].isin(changelist)] = stat[stat['SNP'].isin(changelist)].apply(snp_flip,axis=1)

# %%
stat
# Out:
#          CHR       POS        varid REF ALT          MAF      INFO       N  \
# 0          1     13259  rs562993331   G   A  0.000240613  0.844357  251433
# 1          1     17569  rs535086049   C   A  1.34679e-05  0.894182  251433
# 2          1     17641  rs578081284   G   A  0.000794684  0.852345  251433
# 3          1     30741  rs558169846   C   A  2.55789e-05  0.910708  251433
# 4          1     52144  rs190291950   T   A  0.000485679  0.802923  251433
# ...       ..       ...          ...  ..  ..          ...       ...     ...
# 21735888  22  51232581    rs5771020   T   C     0.297602  0.801896  251433
# 21735889  22  51236013  rs200507571   A  AT     0.252029  0.805492  251433
# 21735890  22  51237063    rs3896457   T   C     0.298901  0.857807  251433
# 21735891  22  51237215  rs536109858   C   T  0.000413208  0.914193  251433
# 21735892  22  51237712  rs370652263   G   A      0.05513  0.864382  251433
#
#          TEST         BETA         SE      CHISQ             P EXTRA  \
# 0         ADD     0.444965   0.405872    1.20192  2.729393e-01   NaN
# 1         ADD     -1.19541    1.86985   0.408719  5.226212e-01   NaN
# 2         ADD    -0.435933   0.233139     3.4963  6.150636e-02   NaN
# 3         ADD     -1.28043    1.24525     1.0573  3.038323e-01   NaN
# 4         ADD     0.117852   0.337249   0.122117  7.267499e-01   NaN
# ...       ...          ...        ...        ...           ...   ...
# 21735888  ADD   0.00162598  0.0153923   0.011159  9.158710e-01   NaN
# 21735889  ADD  -0.00270919    0.01616  0.0281057  8.668607e-01   NaN
# 21735890  ADD  -0.00859535  0.0148427    0.33535  5.625252e-01   NaN
# 21735891  ADD      1.34564   0.209808    33.7213  6.360189e-09   NaN
# 21735892  ADD   -0.0351139  0.0298536    1.38346  2.395130e-01   NaN
#
#               SNP_original      CHR_POS               SNP
# 0              1:13259:G:A      1:13259       1:13259:G:A
# 1              1:17569:C:A      1:17569       1:17569:C:A
# 2              1:17641:G:A      1:17641       1:17641:G:A
# 3              1:30741:C:A      1:30741       1:30741:C:A
# 4              1:52144:T:A      1:52144       1:52144:T:A
# ...                    ...          ...               ...
# 21735888   22:51232581:T:C  22:51232581   22:51232581:T:C
# 21735889  22:51236013:A:AT  22:51236013  22:51236013:A:AT
# 21735890   22:51237063:T:C  22:51237063   22:51237063:T:C
# 21735891   22:51237215:C:T  22:51237215   22:51237215:C:T
# 21735892   22:51237712:G:A  22:51237712   22:51237712:G:A
#
# [21735893 rows x 17 columns]

# %%
header = ["CHR", "POS", "REF", "ALT", "MAF", "INFO", "BETA", "SE", "P", "varid", "SNP_original", "SNP"]
stat.to_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.gz', index=False, compression='gzip',sep="\t", columns = header)

# %% [markdown]
# ### After applying this code there are still 22 top variants not present in the reference file
#
# ```
# 5:73090534:T:C not found in dataset
# 2:54959092:G:C not found in dataset
# 6:32582603:A:G not found in dataset
# 6:32673475:C:T not found in dataset
# 6:32633668:G:A not found in dataset
# 17:43853922:A:G not found in dataset
# 17:44138377:GA:G not found in dataset
# 17:44138377:GAA:GA not found in dataset
# 17:44129949:G:C not found in dataset
# 17:44063723:C:A not found in dataset
# 17:43756458:A:G not found in dataset
# 17:43950976:T:G not found in dataset
# 17:44293020:A:G not found in dataset
# 14:81846115:C:T not found in dataset
# 3:181975568:CTT:C not found in dataset
# 17:44355634:G:C not found in dataset
# 12:102780879:A:G not found in dataset
# 17:44173502:ATTC:A not found in dataset
# 5:73066154:A:T not found in dataset
# 11:118514022:G:C not found in dataset
# 17:44355634:A:C not found in dataset
# 10:30315633:T:C not found in dataset
# 6:84127089:TTTG:T not found in dataset
# ```

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f3393
clumping_sbatch=$clumping_dir/f3393-ldclumping_flip$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.gz
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=varid
numThreads=1
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f3393/f3393-ldclumping_flip2022-08-05.sbatch
# INFO: Workflow csg (ID=wb50975dbec8641f8) is executed successfully with 1 completed step.

# %% [markdown]
# ## f2247 clump
#
# Asign 80GB memory for the job to run

# %%
module load Singularity/3.5.3
sos dryrun /home/dmc2245/project/bioworkflows/GWAS/LD_Clumping.ipynb \
    default \
    --cwd /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247\
    --genoFile /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr2_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr3_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr4_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr5_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr6_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr7_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr8_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr9_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr10_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr11_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr12_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr13_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr14_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr15_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr16_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr17_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr18_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr19_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr20_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen\
    --sampleFile /home/dmc2245/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb32285_imputedindiv.sample\
    --reference_genotype_prefix /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.nondup  \
    --sumstatsFiles /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.gz \
    --ld_sample_size 2000 \
    --clump_field P\
    --clump_p1 5e-06 \
    --clump_p2 1 \
    --clump_r2 0.04 \
    --clump_kb 2000 \
    --clump_annotate varid \
    --numThreads 20 \
    --job_size 1\
    --container /home/dmc2245/containers/lmm.sif
# Out:
# INFO: Checking default: Perform LD-clumping in PLINKv1.9
# HINT: singularity exec  /home/dmc2245/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpbxu796k5/singularity_run_18882.sh
# plink \
# --bfile /home/dmc2245/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.nondup.2000.ref_geno \
# --clump /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.gz \
# --clump-field P \
# --clump-p1 5e-06 \
# --clump-p2 1.0 \
# --clump-r2 0.04 \
# --clump-kb 2000 \
# --clump-verbose \
# --clump-annotate varid \
# --clump-allow-overlap \
# --out /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats \
# --threads 20 \
# && touch /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.clumped # need to touch and create empty file because some chroms may not have anything significant to clump.
# grep "RANGE" /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.clumped | awk -F ":" '{print $2, $3}' | sort -V | sed 's/\../ /g; s/^[[:blank:]]*//g ; s/chr//g' > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.clumped_region
#
#
# INFO: default is completed.
# INFO: default output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.clumped /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.clumped_region
# INFO: Workflow default (ID=w3dcb6a286447a098) is tested successfully with 1 completed step.

# %%
import pandas as pd
stat = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats_original_columns.gz', dtype=str, compression='gzip',sep="\t", header=0)
stat.rename(columns={'CHROM':'CHR', 'GENPOS':'POS', 'ID':'varid', 'ALLELE0':'REF', 'ALLELE1':'ALT', 'A1FREQ':'MAF','LOG10P':'P'}, inplace=True)
stat[['P']] = stat[['P']].apply(pd.to_numeric)
stat['P'] = stat['P'].apply(lambda row: 10**-row)
stat['SNP_original'] = stat["CHR"].str.cat(others=[stat["POS"],stat['REF'],stat['ALT']], sep=':')
stat["CHR_POS"] = stat["CHR"].str.cat(others=[stat["POS"]], sep=':')
flip_list= pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/f2247_allele_flip', dtype=str , header=None , names=['SNP'])
changelist = flip_list['SNP'].tolist()
stat['SNP']=stat.loc[:, 'SNP_original']

# %%
def snp_flip(row):
    row["SNP"] = str(row["CHR"])+":"+str(row["POS"])+":"+row["ALT"]+":"+row["REF"]
    return row

# %%
stat[stat['SNP'].isin(changelist)] = stat[stat['SNP'].isin(changelist)].apply(snp_flip,axis=1)

# %%
stat[stat['SNP_original'].isin(changelist)]
# Out:
#          CHR       POS             varid REF  ALT        MAF      INFO  \
# 47322      1   6493666       rs569450960   C  CAA  0.0609333   0.96973
# 336176     1  46026397       rs373579463  CT    C   0.566553  0.969944
# 336267     1  46036960          rs514595   T    C   0.840746  0.997817
# 336273     1  46037357          rs518216   C    T    0.83866  0.997918
# 336275     1  46037394          rs659437   T    C   0.838692  0.997913
# ...       ..       ...               ...  ..  ...        ...       ...
# 21850668  22  51043278         rs3219201   G    A   0.678689  0.991739
# 21850695  22  51046096          rs470115   A    G   0.819177  0.970074
# 21850707  22  51047218         rs5770938   G    A     0.7617  0.978794
# 21850720  22  51048059          rs965618   A    G   0.729428  0.995698
# 21851000  22  51078547  22:51078547_TG_T  TG    T    0.82304  0.922781
#
#                N TEST        BETA          SE    CHISQ             P EXTRA  \
# 47322     344693  ADD  -0.0526317   0.0114712  21.1616  4.221337e-06   NaN
# 336176    344693  ADD  -0.0326015  0.00549209  35.2231  2.940086e-09   NaN
# 336267    344693  ADD  -0.0385353  0.00730693  27.7363  1.390273e-07   NaN
# 336273    344693  ADD  -0.0374882     0.00727  26.5194  2.609036e-07   NaN
# 336275    344693  ADD  -0.0375429  0.00727049  26.5931  2.511424e-07   NaN
# ...          ...  ...         ...         ...      ...           ...   ...
# 21850668  344693  ADD  -0.0277026  0.00575655  23.1349  1.510254e-06   NaN
# 21850695  344693  ADD  -0.0323748  0.00706527  20.9521  4.709231e-06   NaN
# 21850707  344693  ADD  -0.0353692  0.00634002  31.0625  2.498561e-08   NaN
# 21850720  344693  ADD  -0.0323653  0.00603233  28.7416  8.270847e-08   NaN
# 21851000  344693  ADD  -0.0377349  0.00728908  26.7332  2.335770e-07   NaN
#
#               SNP_original      CHR_POS               SNP
# 47322      1:6493666:C:CAA    1:6493666   1:6493666:CAA:C
# 336176     1:46026397:CT:C   1:46026397   1:46026397:C:CT
# 336267      1:46036960:T:C   1:46036960    1:46036960:C:T
# 336273      1:46037357:C:T   1:46037357    1:46037357:T:C
# 336275      1:46037394:T:C   1:46037394    1:46037394:C:T
# ...                    ...          ...               ...
# 21850668   22:51043278:G:A  22:51043278   22:51043278:A:G
# 21850695   22:51046096:A:G  22:51046096   22:51046096:G:A
# 21850707   22:51047218:G:A  22:51047218   22:51047218:A:G
# 21850720   22:51048059:A:G  22:51048059   22:51048059:G:A
# 21851000  22:51078547:TG:T  22:51078547  22:51078547:T:TG
#
# [3277 rows x 17 columns]

# %%
header = ["CHR", "POS", "REF", "ALT", "MAF", "INFO", "BETA", "SE", "P", "varid", "SNP_original", "SNP"]
stat.to_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.gz', index=False, compression='gzip',sep="\t", columns = header)

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247
clumping_sbatch=$clumping_dir/f2247-ldclumping_flip_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=varid
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/f2247-ldclumping_flip_2022-08-05.sbatch
# INFO: Workflow csg (ID=w8d2ba18b02a6165c) is executed successfully with 1 completed step.

# %% [markdown]
# ### After applying the allele_flip code there are still 91 top variants not present in the reference_file
#
# These variants can be found at the tail of this file `/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.clumped`

# %% [markdown]
# ## f2257 clump

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2257
clumping_sbatch=$clumping_dir/f2257-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=varid
numThreads=1
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2257/f2257-ldclumping_2022-08-03.sbatch
# INFO: Workflow csg (ID=w27f2a3ef13e0301f) is executed successfully with 1 completed step.

# %%
import pandas as pd
stat = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2257/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats_original_columns.gz', dtype=str, compression='gzip',sep="\t", header=0)
stat.rename(columns={'CHROM':'CHR', 'GENPOS':'POS', 'ID':'varid', 'ALLELE0':'REF', 'ALLELE1':'ALT', 'A1FREQ':'MAF','LOG10P':'P'}, inplace=True)
stat[['P']] = stat[['P']].apply(pd.to_numeric)
stat['P'] = stat['P'].apply(lambda row: 10**-row)
stat['SNP_original'] = stat["CHR"].str.cat(others=[stat["POS"],stat['REF'],stat['ALT']], sep=':')
stat["CHR_POS"] = stat["CHR"].str.cat(others=[stat["POS"]], sep=':')
flip_list= pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2257/f2257_allele_flip', dtype=str , header=None , names=['SNP'])
changelist = flip_list['SNP'].tolist()
stat['SNP']=stat.loc[:, 'SNP_original']

# %%
def snp_flip(row):
    row["SNP"] = str(row["CHR"])+":"+str(row["POS"])+":"+row["ALT"]+":"+row["REF"]
    return row

# %%
stat[stat['SNP'].isin(changelist)] = stat[stat['SNP'].isin(changelist)].apply(snp_flip,axis=1)

# %%
stat[stat['SNP_original'].isin(changelist)]
# Out:
#          CHR       POS            varid REF ALT        MAF      INFO       N  \
# 58269      1   7965280        rs6694557   T   C   0.864359  0.964317  395732
# 209878     1  28975150       rs35910435   C   T  0.0518141       1.0  395732
# 226419     1  31259857  1:31259857_CT_C  CT   C   0.612566  0.811564  395732
# 336745     1  46026397      rs373579463  CT   C   0.566571  0.970091  395732
# 336872     1  46041100        rs1084086   T   G   0.703508       1.0  395732
# ...       ..       ...              ...  ..  ..        ...       ...     ...
# 21795261  22  38474852        rs1004764   G   A   0.620458  0.997395  395732
# 21801263  22  39286208         rs132502   A   C   0.233611       1.0  395732
# 21906441  22  51043278        rs3219201   G   A   0.678556  0.991675  395732
# 21906480  22  51047218        rs5770938   G   A    0.76171  0.978624  395732
# 21906493  22  51048059         rs965618   A   G   0.729347  0.995682  395732
#
#          TEST        BETA          SE    CHISQ             P EXTRA  \
# 58269     ADD  -0.0343144  0.00696062  24.2706  8.370858e-07   NaN
# 209878    ADD   0.0507732   0.0105006  23.3218  1.370377e-06   NaN
# 226419    ADD  -0.0249873  0.00534486  21.8505  2.947406e-06   NaN
# 336745    ADD  -0.0257179  0.00480954  28.5894  8.947259e-08   NaN
# 336872    ADD  -0.0280157  0.00513516  29.7464  4.924136e-08   NaN
# ...       ...         ...         ...      ...           ...   ...
# 21795261  ADD  -0.0234469  0.00483889  23.4727  1.267010e-06   NaN
# 21801263  ADD   -0.026474  0.00556285  22.6694  1.924110e-06   NaN
# 21906441  ADD  -0.0236357  0.00503915  21.9901  2.740627e-06   NaN
# 21906480  ADD  -0.0274931  0.00555585  24.4688  7.552313e-07   NaN
# 21906493  ADD  -0.0261407  0.00528435  24.4552  7.605714e-07   NaN
#
#              SNP_original      CHR_POS              SNP
# 58269       1:7965280:T:C    1:7965280    1:7965280:C:T
# 209878     1:28975150:C:T   1:28975150   1:28975150:T:C
# 226419    1:31259857:CT:C   1:31259857  1:31259857:C:CT
# 336745    1:46026397:CT:C   1:46026397  1:46026397:C:CT
# 336872     1:46041100:T:G   1:46041100   1:46041100:G:T
# ...                   ...          ...              ...
# 21795261  22:38474852:G:A  22:38474852  22:38474852:A:G
# 21801263  22:39286208:A:C  22:39286208  22:39286208:C:A
# 21906441  22:51043278:G:A  22:51043278  22:51043278:A:G
# 21906480  22:51047218:G:A  22:51047218  22:51047218:A:G
# 21906493  22:51048059:A:G  22:51048059  22:51048059:G:A
#
# [3480 rows x 17 columns]

# %%
header = ["CHR", "POS", "REF", "ALT", "MAF", "INFO", "BETA", "SE", "P", "varid", "SNP_original", "SNP"]
stat.to_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.gz', index=False, compression='gzip',sep="\t", columns = header)

# %% [markdown]
# ### After applying the allele_flip code there are still 76 top variants not present in the reference_file
#
# These variants can be found at the tail of this file `~/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2257/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.clumped`

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2257
clumping_sbatch=$clumping_dir/f2257-ldclumping_flip_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=varid
numThreads=1
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg (index=0) is ignored due to saved signature
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2257/f2257-ldclumping_flip_2022-08-05.sbatch
# INFO: Workflow csg (ID=w16814b7e66737f2c) is ignored with 1 ignored step.

# %% [markdown]
# ## Combined clump

# %%
# # Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247_f2257
clumping_sbatch=$clumping_dir/combined-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=BP
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247_f2257/combined-ldclumping_2022-08-04.sbatch
# INFO: Workflow csg (ID=wa5d11405fe8fa890) is executed successfully with 1 completed step.

# %%
# To get the variant ID of the alleles that need to be flipped
cd ~/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247_f2257
cat 071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.clumped | grep "not found in dataset" | awk '{print $1}' > f2247_f2257_allele_flip

# %%
import pandas as pd
stat = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/REGENIE_results/results_imputed_data/071222_500k_without_1415/f2247_f2257/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats_original_columns.gz', dtype=str, compression='gzip',sep="\t", header=0)
stat.rename(columns={'CHROM':'CHR', 'GENPOS':'POS', 'ID':'varid', 'ALLELE0':'REF', 'ALLELE1':'ALT', 'A1FREQ':'MAF','LOG10P':'P'}, inplace=True)
stat[['P']] = stat[['P']].apply(pd.to_numeric)
stat['P'] = stat['P'].apply(lambda row: 10**-row)
stat['SNP_original'] = stat["CHR"].str.cat(others=[stat["POS"],stat['REF'],stat['ALT']], sep=':')
stat["CHR_POS"] = stat["CHR"].str.cat(others=[stat["POS"]], sep=':')
flip_list= pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247_f2257/f2247_f2257_allele_flip', dtype=str , header=None , names=['SNP'])
changelist = flip_list['SNP'].tolist()
stat['SNP']=stat.loc[:, 'SNP_original']

# %%
def snp_flip(row):
    row["SNP"] = str(row["CHR"])+":"+str(row["POS"])+":"+row["ALT"]+":"+row["REF"]
    return row

# %%
stat[stat['SNP'].isin(changelist)] = stat[stat['SNP'].isin(changelist)].apply(snp_flip,axis=1)

# %%
header = ["CHR", "POS", "REF", "ALT", "MAF", "INFO", "BETA", "SE", "P", "varid", "SNP_original", "SNP"]
stat.to_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.gz', index=False, compression='gzip',sep="\t", columns = header)

# %%
## Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247_f2257
clumping_sbatch=$clumping_dir/combined-ldclumping_flip_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=BP
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_f2247_f2257/combined-ldclumping_flip_2022-08-05.sbatch
# INFO: Workflow csg (ID=w9838dfc6f95d510f) is executed successfully with 1 completed step.

# %% [markdown]
# ### After applying the allele_flip code there are still 76 top variants not present in the reference_file
#
# These variants can be found at the tail of this file `~/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/

# %% [markdown]
# ## AD_meta clump

# %%
## Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_AD_meta
clumping_sbatch=$clumping_dir/AD_meta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.tsv.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=BP
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_AD_meta/AD_meta-ldclumping_2022-08-08.sbatch
# INFO: Workflow csg (ID=w5c3d9f868a13359b) is executed successfully with 1 completed step.

# %%
# To get the variant ID of the alleles that need to be flipped
cd ~/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_AD_meta
cat GCST90027158_buildGRCh37_reheader.tsv.clumped| grep "not found in dataset" | awk '{print $1}' > ADmeta_allele_flip

# %%
import pandas as pd
stat = pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.tsv.gz', dtype=str, compression='gzip',sep="\t", header=0)
#stat[['P']] = stat[['P']].apply(pd.to_numeric)
#stat['P'] = stat['P'].apply(lambda row: 10**-row)
stat['SNP_original'] = stat["CHR"].str.cat(others=[stat["POS"],stat['REF'],stat['ALT']], sep=':')
stat["CHR_POS"] = stat["CHR"].str.cat(others=[stat["POS"]], sep=':')
flip_list= pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_AD_meta/ADmeta_allele_flip', dtype=str , header=None , names=['SNP'])
changelist = flip_list['SNP'].tolist()
stat['SNP']=stat.loc[:, 'SNP_original']

# %%
def snp_flip(row):
    row["SNP"] = str(row["CHR"])+":"+str(row["POS"])+":"+row["ALT"]+":"+row["REF"]
    return row

# %%
stat[stat['SNP'].isin(changelist)] = stat[stat['SNP'].isin(changelist)].apply(snp_flip,axis=1)

# %%
stat[stat['SNP_original'].isin(changelist)]
# Out:
#          CHR POS REF ALT      SNP     BETA      SE        P SNP_original  \
# 7474       0   0   G   A  0:0:A:G   0.0052  0.0173   0.7631      0:0:G:A
# 7476       0   0   G   A  0:0:A:G  -0.0071  0.0331   0.8292      0:0:G:A
# 7477       0   0   G   A  0:0:A:G  -0.0015  0.0141    0.916      0:0:G:A
# 7478       0   0   G   A  0:0:A:G   0.0024  0.0151   0.8725      0:0:G:A
# 7479       0   0   C   T  0:0:T:C  -0.3168  0.3158   0.3157      0:0:C:T
# ...       ..  ..  ..  ..      ...      ...     ...      ...          ...
# 21093486   0   0   C   T  0:0:T:C   0.2512  0.4173   0.5472      0:0:C:T
# 21093487   0   0   G   A  0:0:A:G   0.0186  0.0108  0.08605      0:0:G:A
# 21093488   0   0   C   T  0:0:T:C  -0.0327  0.0142  0.02135      0:0:C:T
# 21093489   0   0   C   A  0:0:A:C  -0.1226  0.2286   0.5916      0:0:C:A
# 21093490   0   0   G   A  0:0:A:G   0.0011  0.0119   0.9266      0:0:G:A
#
#          CHR_POS
# 7474         0:0
# 7476         0:0
# 7477         0:0
# 7478         0:0
# 7479         0:0
# ...          ...
# 21093486     0:0
# 21093487     0:0
# 21093488     0:0
# 21093489     0:0
# 21093490     0:0
#
# [34111 rows x 10 columns]

# %%
header = ["CHR", "POS", "REF", "ALT", "BETA", "SE", "P", "SNP_original", "SNP"]
stat.to_csv('~/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz', index=False, compression='gzip',sep="\t", columns = header)

# %%
## Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_AD_meta
clumping_sbatch=$clumping_dir/AD_meta-ldclumping_flip_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz
ld_sample_size=2000
clump_field=P
clump_p1=5e-06
clump_p2=1
clump_r2=0.04
clump_kb=2000
clump_annotate=BP
numThreads=20
clump_job_size=1

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/072822_AD_meta/AD_meta-ldclumping_flip_2022-08-08.sbatch
# INFO: Workflow csg (ID=wa96242296e322948) is executed successfully with 1 completed step.

# %% [markdown]
# # Find intersection between LD clumping regions

# %%
import numpy as np
import pandas as pd
from functools import reduce
import glob
filenames = glob.glob("/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822*/*.clumped_region")

# %%
dfs = [pd.read_csv(filename, dtype=str , sep=' ', header=None) for filename in filenames]

# %%
dfs
# Out:
# [      0         1         2
#  0     1   6315125   6631106
#  1     1  12169337  16161606
#  2     1  20269718  22239026
#  3     1  42273297  43365565
#  4     1  45167429  47068339
#  ..   ..       ...       ...
#  560  22  37977713  38626556
#  561  22  46608847  49887600
#  562  22  48993774  51146132
#  563  22  50436376  51229805
#  564  22  51032153  51173041
#
#  [565 rows x 3 columns],
#        0         1         2
#  0     1   6315125   6631106
#  1     1  12197464  16161606
#  2     1  45167429  47068339
#  3     1  80995695  80995695
#  4     1  82120001  82781655
#  ..   ..       ...       ...
#  450  22  48993774  51146132
#  451  22  49049741  50616646
#  452  22  50436376  51229805
#  453  22  51032153  51173041
#  454  22  51237215  51237215
#
#  [455 rows x 3 columns],
#        0         1         2
#  0     1   6315125   6631106
#  1     1  12169337  16161606
#  2     1  20269718  22239026
#  3     1  42273297  43365565
#  4     1  45100431  46895641
#  ..   ..       ...       ...
#  562  22  37976422  38673790
#  563  22  37977713  38626556
#  564  22  48993774  51146132
#  565  22  50436376  51229805
#  566  22  51032153  51173041
#
#  [567 rows x 3 columns],
#        0         1         2
#  0     1   6315125   6631106
#  1     1  12197464  16161606
#  2     1  45100431  46886953
#  3     1  80995695  80995695
#  4     1  82120001  82781655
#  ..   ..       ...       ...
#  432  22  48993774  51146132
#  433  22  49049741  50616646
#  434  22  50436376  51229805
#  435  22  51032153  51173041
#  436  22  51237215  51237215
#
#  [437 rows x 3 columns],
#        0         1         2
#  0     1   6317585   6631106
#  1     1   7631420   8192898
#  2     1  12169337  16161606
#  3     1  20269718  22239026
#  4     1  24690676  25183119
#  ..   ..       ...       ...
#  582  22  38093414  39346720
#  583  22  38865590  39306080
#  584  22  49606728  51146132
#  585  22  50436376  51229805
#  586  22  50618958  51176164
#
#  [587 rows x 3 columns],
#        0         1         2
#  0     1   6317585   6631106
#  1     1   7631420   8192898
#  2     1  12197464  16161606
#  3     1  24690676  25183119
#  4     1  27805160  29637318
#  ..   ..       ...       ...
#  452  22  49049741  50616646
#  453  22  49606728  51146132
#  454  22  50436376  51229805
#  455  22  50618958  51176164
#  456  22  51237215  51237215
#
#  [457 rows x 3 columns],
#        0         1         2
#  0     1  20269718  22239026
#  1     1  42273297  43365565
#  2     1  50649929  52830530
#  3     1  62814858  63491421
#  4     1  63381854  67224373
#  ..   ..       ...       ...
#  422  21  38925356  42309248
#  423  21  41743586  45396035
#  424  21  43747236  44021573
#  425  22  37978750  38626278
#  426  22  48993774  51146132
#
#  [427 rows x 3 columns],
#        0         1         2
#  0     1   6036864   6036864
#  1     1   6043137   6043137
#  2     1   6048498   6048498
#  3     1   6049935   6049935
#  4     1   6050663   6050663
#  ..   ..       ...       ...
#  310  21  43747236  44021573
#  311  22  37978750  38626278
#  312  22  48993774  51146132
#  313  22  49049741  50616646
#  314  22  51237215  51237215
#
#  [315 rows x 3 columns]]

# %%
reduce(lambda left, right: pd.merge(left, right, how="inner", on=[0,1,2]), dfs)
# Out:
#      0          1          2
# 0    1  207302548  208001215
# 1    2  127773524  127898467
# 2    3  120807217  121829279
# 3    4   10864183   11050683
# 4    4   17421637   18282225
# 5    5   72819206   73187503
# 6    6   38980511   42216621
# 7    6   47312531   47875319
# 8    7  138432792  138552312
# 9   10   11424595   11835147
# 10  10   72300753   74080805
# 11  10   94478104   95067066
# 12  10  126754527  126865062
# 13  11    7910740    8256690
# 14  11  119524157  123096745
# 15  15   58829451   59516875
# 16  19     777560    3061573
# 17  19   43339752   47268323
# 18  19   43423669   47295731
# 19  19   44078282   47394223
# 20  19   44280645   46123098
# 21  19   44294330   45923337
# 22  19   45065068   45740340
# 23  19   45121726   45351516
# 24  19   45192912   45436247
# 25  19   45248856   45913704
# 26  19   45411110   45688601
# 27  19   45449166   45828980
# 28  19   45516125   45516125
# 29  19   45554058   45891241

# %%
f3393_ADmeta=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f3393_ADmeta/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump_071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.clumped_region', dtype=str , sep=' ', header=None )
f2247_ADmeta=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2247_ADmeta/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump_071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.clumped_region', dtype=str , sep=' ', header=None )
f2257_ADmeta=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2257_ADmeta/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump_071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.clumped_region', dtype=str ,sep=' ', header=None )
combined_ADmeta=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_combined_ADmeta/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump_071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.clumped_region', dtype=str , sep=' ', header=None)

f3393_ADproxy=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f3393_ADproxy/AD_step2_BT_all.txt.snp_stats.ldclump_071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.clumped_region', dtype=str ,  sep=' ', header=None)
f2247_ADproxy=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2247_ADproxy/AD_step2_BT_all.txt.snp_stats.ldclump_071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.clumped_region', dtype=str , sep=' ', header=None)
f2257_ADproxy=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_f2257_ADproxy/AD_step2_BT_all.txt.snp_stats.ldclump_071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.clumped_region', dtype=str ,  sep=' ', header=None)
combined_ADproxy=pd.read_csv('/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/080822_combined_ADproxy/AD_step2_BT_all.txt.snp_stats.ldclump_071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.clumped_region', dtype=str , sep=' ', header=None)

# %%
f3393_ADmeta
# Out:
#       0         1         2
# 0     1  20269718  22239026
# 1     1  42273297  43365565
# 2     1  50649929  52830530
# 3     1  62814858  63491421
# 4     1  63381854  67224373
# ..   ..       ...       ...
# 422  21  38925356  42309248
# 423  21  41743586  45396035
# 424  21  43747236  44021573
# 425  22  37978750  38626278
# 426  22  48993774  51146132
#
# [427 rows x 3 columns]

# %%
combined_ADproxy
# Out:
#       0         1         2
# 0     1   6315125   6631106
# 1     1  12197464  16161606
# 2     1  45167429  47068339
# 3     1  80995695  80995695
# 4     1  82120001  82781655
# ..   ..       ...       ...
# 450  22  48993774  51146132
# 451  22  49049741  50616646
# 452  22  50436376  51229805
# 453  22  51032153  51173041
# 454  22  51237215  51237215
#
# [455 rows x 3 columns]

# %%
reduce(lambda left, right: pd.merge(left, right, how="inner", on=[0,1,2]), [f3393_ADmeta,f2247_ADmeta,f2257_ADmeta,combined_ADmeta])
# Out:
#       0         1         2
# 0     1  20269718  22239026
# 1     1  42273297  43365565
# 2     1  50649929  52830530
# 3     1  62814858  63491421
# 4     1  63381854  67224373
# ..   ..       ...       ...
# 329  21  27344189  27765689
# 330  21  28095992  28209494
# 331  21  33951180  37891455
# 332  21  37948100  38914616
# 333  21  38925356  42309248
#
# [334 rows x 3 columns]

# %%
reduce(lambda left, right: pd.merge(left, right, how="inner", on=[0,1,2]), [f3393_ADproxy,f2247_ADproxy,f2257_ADproxy,combined_ADproxy])
# Out:
#       0          1          2
# 0     1   80995695   80995695
# 1     1  105458976  107422312
# 2     1  158531011  158531011
# 3     1  160834616  161383559
# 4     1  169267498  172944529
# ..   ..        ...        ...
# 176  20     776747     894121
# 177  20   43358848   44214164
# 178  20   59195437   62721760
# 179  22   49049741   50616646
# 180  22   51237215   51237215
#
# [181 rows x 3 columns]

# %%
reduce(lambda left, right: pd.merge(left, right, how="inner", on=[0,1,2]), [f3393_ADmeta,f2247_ADmeta,f2257_ADmeta,combined_ADmeta,f3393_ADproxy,f2247_ADproxy,f2257_ADproxy,combined_ADproxy])
# Out:
#      0          1          2
# 0    1  207302548  208001215
# 1    2  127773524  127898467
# 2    3  120807217  121829279
# 3    4   10864183   11050683
# 4    4   17421637   18282225
# 5    5   72819206   73187503
# 6    6   38980511   42216621
# 7    6   47312531   47875319
# 8    7  138432792  138552312
# 9   10   11424595   11835147
# 10  10   72300753   74080805
# 11  10   94478104   95067066
# 12  10  126754527  126865062
# 13  11    7910740    8256690
# 14  11  119524157  123096745
# 15  15   58829451   59516875
# 16  19     777560    3061573
# 17  19   43339752   47268323
# 18  19   43423669   47295731
# 19  19   44078282   47394223
# 20  19   44280645   46123098
# 21  19   44294330   45923337
# 22  19   45065068   45740340
# 23  19   45121726   45351516
# 24  19   45192912   45436247
# 25  19   45248856   45913704
# 26  19   45411110   45688601
# 27  19   45449166   45828980
# 28  19   45516125   45516125
# 29  19   45554058   45891241

# %%
#To find the name of the file where the region was located
grep -RH "1 42273297 43365565" 080822_*/*.clumped_region

# %%
sort -m 080822_*/*.clumped_region | uniq -d > shared_regions.txt
grep -Fx -f shared_regions.txt 080822_*/*.clumped_region

# %% [markdown]
# # Find the shared significant variants between AD_meta and AD_proxy

# %% [markdown]
# # Re-run analysis for bivariate Ld clumping using p=5e-08

# %%
clumping_sos=~/project/bioworkflows/GWAS/LD_Clumping.ipynb
## GenoFile is not necessary to run LD clumping but it is needed by the global parameters. It won't be use in this module but you have to provide path
genoFile=`echo $UKBB_yale/ukb39554_imputeddataset/ukb_imp_chr{1..22}_v3.bgen`
sampleFile=$UKBB_yale/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
reference_genotype_prefix=~/UKBiobank/results/LD_clumping/ref_files/ukb39554_c1_22_v3.imputed.renamedvar.nondup
ld_sample_size=2000
clump_field=P
clump_p1=5e-08
clump_p2=5e-06
clump_r2=0.04
clump_kb=2000
clump_annotate=varid
numThreads=20
clump_job_size=1
container=~/containers/lmm.sif

# %% [markdown]
# ## AD_proxy and f3393

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f3393_ADproxy_5e-08/verbose_false
clumping_sbatch=$clumping_dir/f3393_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.gz`
verbose=False
# Adding -no-verbose and -no-clump-annotate to get just the index variants in each region

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb  
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --no-clump-annotate
    --no-verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f3393_ADproxy_5e-08/verbose_false/f3393_ADproxy-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w8da4a5fe463d231e) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_proxy and f2247

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2247_ADproxy_5e-08/verbose_false
clumping_sbatch=$clumping_dir/f2247_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2247_ADproxy_5e-08/verbose_false/f2247_ADproxy-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w6d5e907034cdc2c0) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_proxy and f2257

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2257_ADproxy_5e-08/verbose_false
clumping_sbatch=$clumping_dir/f2257_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2257_ADproxy_5e-08/verbose_false/f2257_ADproxy-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w407cd8b20c10c2a6) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_proxy and f2247_f2257

# %%
# # Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_combined_ADproxy_5e-08/verbose_false
clumping_sbatch=$clumping_dir/combined_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_combined_ADproxy_5e-08/verbose_false/combined_ADproxy-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w7c6710162c448079) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_meta and f3393

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f3393_ADmeta_5e-08/verbose_false
clumping_sbatch=$clumping_dir/f3393_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_aid_f3393_expandedwhite_14734cases_236699ctrl_500k_PC1_PC2_f3393.regenie.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""
sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f3393_ADmeta_5e-08/verbose_false/f3393_ADmeta-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w85301c5660731b3d) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_meta and f2247

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2247_ADmeta_5e-08/verbose_false
clumping_sbatch=$clumping_dir/f2247_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_difficulty_f2247_expandedwhite_107994cases_236699ctrl_500k_PC1_PC2_f2247.regenie.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2247_ADmeta_5e-08/verbose_false/f2247_ADmeta-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=wd04d31225330ff10) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_meta and f2257

# %%
# Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2257_ADmeta_5e-08/verbose_false
clumping_sbatch=$clumping_dir/f2257_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Hearing_noise_f2257_expandedwhite_159033cases_236699ctrl_500k_PC1_PC2_f2257.regenie.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_f2257_ADmeta_5e-08/verbose_false/f2257_ADmeta-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w1af59e313f5ebf85) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_meta and f2247_f2257

# %%
# # Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_combined_ADmeta_5e-08/verbose_false
clumping_sbatch=$clumping_dir/combined_ADmeta-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/071222_UKBB_Combined_f2247_f2257_expandedwhite_91092cases_236699ctrl_500k_PC1_PC2_f2247_f2257.regenie.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_combined_ADmeta_5e-08/verbose_false/combined_ADmeta-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w51b95599d7540c54) is executed successfully with 1 completed step.

# %% [markdown]
# ## AD_proxy and AD_meta

# %%
# # Set the bash variables 
clumping_dir=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_ADmeta_ADproxy/verbose_false
clumping_sbatch=$clumping_dir/ADmeta_ADproxy-ldclumping_$(date +"%Y-%m-%d").sbatch
sumstatsFiles=`echo /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/GCST90027158_buildGRCh37_reheader.snp_stats.ldclump.gz  /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/AD_step2_BT_all.txt.snp_stats.ldclump.gz`
verbose=False

clumping_args="""default 
    --cwd $clumping_dir
    --genoFile $genoFile
    --sampleFile $sampleFile
    --reference_genotype_prefix $reference_genotype_prefix  
    --sumstatsFiles $sumstatsFiles 
    --ld_sample_size $ld_sample_size 
    --clump_field $clump_field
    --clump_p1 $clump_p1 
    --clump_p2 $clump_p2 
    --clump_r2 $clump_r2 
    --clump_kb $clump_kb 
    --clump_annotate $clump_annotate 
    --numThreads $numThreads 
    --job_size $clump_job_size
    --container $container
    --verbose $verbose
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $clumping_sos \
    --to-script $clumping_sbatch \
    --args "$clumping_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/LD_clumping/112122_ADmeta_ADproxy/verbose_false/ADmeta_ADproxy-ldclumping_2022-11-23.sbatch
# INFO: Workflow csg (ID=w1cd58338d0db8e65) is executed successfully with 1 completed step.

# %% [markdown]
# # Step 4: run region extraction to get some of the regions to test

# %% [markdown]
# # Analysis using the genomewide determined LD clusters

# %% [markdown]
# After discussing with the team on 11/30/22 we have decided on these steps for the analysis
#
# 1. Use LDStore2 to compute 1700 LD matrices and save that on the cluster
# 2. For any GWAS of interest take the list of top independent SNPs from that GWAS paper, and intersect with the 1700 blocks to identify a subset of regions of interest. For the case of AD, depending on what you think is good phenotype definition we should use one of the following: Bellenguez 2022,  Wightman 2021, Kunkle 2019 and i suggest starting with Belenguez 2022
# 3. Perform SuSiE-coloc on regions from 2
# 4. After you identified regions of interest in 3, we can carefully do LD clump and extract a refined subset of variants from 3 and do individual level data mediation analysis just as what we did before -- that means we will have to use AD status based on UKB
# 5. Alternative to 4, we can try summary stats based method: https://pubmed.ncbi.nlm.nih.gov/28464407/ -- I'm just worried the method and software is not the best out there
# 6. Alternative to 4 and 5, we should do a good MR analysis using multiple IV accounting for LD, as well as discerning between horizontal pleiotropy and vertical pleiotropy (mediation) eg https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8890724/  -- this seems a one stop shop i'm just not sure how well the method works
#
# Gao's notes:
# This is a suggestion ... becase I'm not sure about the method performance of 5 and 6. and for 4 the method should be solid I'm not sure about the power. But let's do 1 to 3 at least before our next meeting?
# @Diana please book me if you still have questions on the list above?
#
# @Andy I'm worried about 4 the individual level mediation because I remember Zihan's results even using a better method the liability threshold than proxy , we still only recover a handful of GWAS variants using UKB alone

# %% [markdown]
# # References
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4731402/
#
# Different versions of splitting LD blocks in the human genome
#
# https://academic.oup.com/bioinformatics/article/38/1/255/6321454
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4731402/
#
#
# Download 1725 LD blocks for European population from https://bitbucket.org/nygcresearch/ldetect-data/src/master/

# %% [markdown]
# ## LD blocks
#
# ```
# /mnt/vast/hpc/csg/UKBiobank/data/ldblocks
# ```
#
# Running 113022_bgenix_ldblocks pipeline to generate the bgen files needed for Ldstore (LD calculation)

# %%
cwd=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22
sbatch=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/regions_chr1_chr22_$(date +"%Y-%m-%d").sbatch
region_file='/mnt/vast/hpc/csg/UKBiobank/data/ldblocks/EUR/fourier_ls-all.bed'
genofile_prefix='/mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr'
genofile_suffix='_v3.bgen'
sample_file=/mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb32285_imputedindiv.sample
related_samples=/mnt/vast/hpc/csg/UKBiobank/results/092821_PCA_results_500K/092821_ldprun_related/cache/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.white_europeans.filtered.092821_ldprun_related.filtered.extracted.fam
excluded_samples='UKB_109219_related_ind.txt'
tpl_file=~/project/bioworkflows/admin/csg.yml
bgenix_sos=~/project/UKBB_GWAS_dev/workflow/113022_bgenix_ldblocks.ipynb
job_size=10


bgenix_args="""bgenix
    --cwd $cwd
    --genofile_prefix $genofile_prefix
    --genofile_suffix $genofile_suffix
    --sample_file $sample_file
    --related_samples $related_samples
    --excluded_samples $excluded_samples
    --region_file $region_file
    --job_size $job_size
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $bgenix_sos \
    --to-script $sbatch \
    --args "$bgenix_args"
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/regions_chr1_chr22_2022-12-19.sbatch
# INFO: Workflow csg (ID=wa7e2f3d7cf16f900) is executed successfully with 1 completed step.

# %%
export PATH=$HOME/miniconda3/bin:$PATH
module load Singularity/3.5.3
sos dryrun /home/dmc2245/project/UKBB_GWAS_dev/workflow/113022_bgenix_ldblocks.ipynb \
    bgenix:1\
    --cwd /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22\
    --genofile_prefix /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr\
    --genofile_suffix _v3.bgen\
    --region_file /mnt/vast/hpc/csg/UKBiobank/data/ldblocks/EUR/fourier_ls-all.bed
# Out:
# INFO: Checking extract region: Extract the regions
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpqipl_ri4/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:10583-1892607 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_10583_1892607.bgen
#
#
# INFO: extract region (index=0) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpdks8hout/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:1892607-3582736 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_1892607_3582736.bgen
#
#
# INFO: extract region (index=1) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpuguqq8ri/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:3582736-4380811 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_3582736_4380811.bgen
#
#
# INFO: extract region (index=2) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp2hgqbw67/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:4380811-5913893 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_4380811_5913893.bgen
#
#
# INFO: extract region (index=3) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpr3_6ux7p/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:5913893-7247335 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_5913893_7247335.bgen
#
#
# INFO: extract region (index=4) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmppgdt4o24/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:7247335-9365199 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_7247335_9365199.bgen
#
#
# INFO: extract region (index=5) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpxogpibp_/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:9365199-10806984 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_9365199_10806984.bgen
#
#
# INFO: extract region (index=6) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpf8m6sbct/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:10806984-11777841 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_10806984_11777841.bgen
#
#
# INFO: extract region (index=7) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpn1zo0deq/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:11777841-12779466 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_11777841_12779466.bgen
#
#
# INFO: extract region (index=8) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmppcel3wlv/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:12779466-14891511 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_12779466_14891511.bgen
#
#
# INFO: extract region (index=9) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpx8ls28y7/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:14891511-16897730 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_14891511_16897730.bgen
#
#
# INFO: extract region (index=10) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpy7fy2k_z/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:16897730-18662899 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_16897730_18662899.bgen
#
#
# INFO: extract region (index=11) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpxqtfgz9o/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:18662899-20469149 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_18662899_20469149.bgen
#
#
# INFO: extract region (index=12) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpznpcti7k/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:20469149-21736588 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_20469149_21736588.bgen
#
#
# INFO: extract region (index=13) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpl81u2x48/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:21736588-23086883 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_21736588_23086883.bgen
#
#
# INFO: extract region (index=14) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpv3asaahd/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:23086883-23920590 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_23086883_23920590.bgen
#
#
# INFO: extract region (index=15) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpaexbp96w/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:23920590-25516845 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_23920590_25516845.bgen
#
#
# INFO: extract region (index=16) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpc_fg_je_/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:25516845-27401867 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_25516845_27401867.bgen
#
#
# INFO: extract region (index=17) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp3pvjqvhl/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:27401867-30161881 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_27401867_30161881.bgen
#
#
# INFO: extract region (index=18) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpjqv96243/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:30161881-32438685 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_30161881_32438685.bgen
#
#
# INFO: extract region (index=19) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp9kckqonh/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:32438685-34799758 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_32438685_34799758.bgen
#
#
# INFO: extract region (index=20) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpi4tzb7nb/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:34799758-37549183 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_34799758_37549183.bgen
#
#
# INFO: extract region (index=21) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp8jz098f7/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:37549183-38731847 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_37549183_38731847.bgen
#
#
# INFO: extract region (index=22) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpz9yyiz4_/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:38731847-40200567 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_38731847_40200567.bgen
#
#
# INFO: extract region (index=23) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpcu7bfubr/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:40200567-41975327 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_40200567_41975327.bgen
#
#
# INFO: extract region (index=24) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpe2lpmmdj/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:41975327-43758457 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_41975327_43758457.bgen
#
#
# INFO: extract region (index=25) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp3saj4nqc/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:43758457-44969183 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_43758457_44969183.bgen
#
#
# INFO: extract region (index=26) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmppjxiwjkd/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:44969183-46899501 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_44969183_46899501.bgen
#
#
# INFO: extract region (index=27) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpe8uvy67k/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:46899501-48002576 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_46899501_48002576.bgen
#
#
# INFO: extract region (index=28) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpay5i8zjm/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:48002576-48978188 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_48002576_48978188.bgen
#
#
# INFO: extract region (index=29) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpwr4hj3n8/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:48978188-49894177 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_48978188_49894177.bgen
#
#
# INFO: extract region (index=30) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp5x_u6w11/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:49894177-51713726 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_49894177_51713726.bgen
#
#
# INFO: extract region (index=31) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpqxbegp73/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:51713726-54226262 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_51713726_54226262.bgen
#
#
# INFO: extract region (index=32) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpd2q5b4hd/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:54226262-56413117 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_54226262_56413117.bgen
#
#
# INFO: extract region (index=33) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmplw7lgm_b/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:56413117-57021728 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_56413117_57021728.bgen
#
#
# INFO: extract region (index=34) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpy_ydupbe/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:57021728-58865399 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_57021728_58865399.bgen
#
#
# INFO: extract region (index=35) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp9oxdtnh3/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:58865399-59890409 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_58865399_59890409.bgen
#
#
# INFO: extract region (index=36) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpf947uhtw/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:59890409-61922365 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_59890409_61922365.bgen
#
#
# INFO: extract region (index=37) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpmebv1ewg/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:61922365-63455089 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_61922365_63455089.bgen
#
#
# INFO: extract region (index=38) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpmv4bnpb4/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:63455089-65041704 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_63455089_65041704.bgen
#
#
# INFO: extract region (index=39) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmps1vkil6k/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:65041704-66939404 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_65041704_66939404.bgen
#
#
# INFO: extract region (index=40) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmppid90sqc/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:66939404-68477895 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_66939404_68477895.bgen
#
#
# INFO: extract region (index=41) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp0a_r__75/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:68477895-69687616 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_68477895_69687616.bgen
#
#
# INFO: extract region (index=42) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp82oim8_7/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:69687616-71372470 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_69687616_71372470.bgen
#
#
# INFO: extract region (index=43) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp7nb59as7/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:71372470-71684405 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_71372470_71684405.bgen
#
#
# INFO: extract region (index=44) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp3n1lxs8d/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:71684405-74326907 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_71684405_74326907.bgen
#
#
# INFO: extract region (index=45) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpuu8fdkjc/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:74326907-76728135 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_74326907_76728135.bgen
#
#
# INFO: extract region (index=46) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpxmn0kv7u/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:76728135-79661198 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_76728135_79661198.bgen
#
#
# INFO: extract region (index=47) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp440grvn9/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:79661198-81354191 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_79661198_81354191.bgen
#
#
# INFO: extract region (index=48) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpibjgbnct/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:81354191-83991748 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_81354191_83991748.bgen
#
#
# INFO: extract region (index=49) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpmh89elm6/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:83991748-84844495 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_83991748_84844495.bgen
#
#
# INFO: extract region (index=50) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpabyt6xhb/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:84844495-86454751 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_84844495_86454751.bgen
#
#
# INFO: extract region (index=51) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpi2j0zrjb/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:86454751-88128631 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_86454751_88128631.bgen
#
#
# INFO: extract region (index=52) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp1szb5b6v/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:88128631-90066303 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_88128631_90066303.bgen
#
#
# INFO: extract region (index=53) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpotil1sis/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:90066303-91886317 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_90066303_91886317.bgen
#
#
# INFO: extract region (index=54) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpec5pecda/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:91886317-93536459 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_91886317_93536459.bgen
#
#
# INFO: extract region (index=55) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpjic3_ttx/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:93536459-94506191 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_93536459_94506191.bgen
#
#
# INFO: extract region (index=56) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpeovrflpi/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:94506191-96150893 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_94506191_96150893.bgen
#
#
# INFO: extract region (index=57) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpl415eifc/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:96150893-97885249 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_96150893_97885249.bgen
#
#
# INFO: extract region (index=58) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp95h_s0s7/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:97885249-99800604 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_97885249_99800604.bgen
#
#
# INFO: extract region (index=59) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpm7l_fv3t/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:99800604-100826405 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_99800604_100826405.bgen
#
#
# INFO: extract region (index=60) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpuo8iwqun/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:100826405-102041016 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_100826405_102041016.bgen
#
#
# INFO: extract region (index=61) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmphjn2kt3t/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:102041016-102898745 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_102041016_102898745.bgen
#
#
# INFO: extract region (index=62) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpz675fzi1/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:102898745-103914211 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_102898745_103914211.bgen
#
#
# INFO: extract region (index=63) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp0wmhxn2o/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:103914211-106087842 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_103914211_106087842.bgen
#
#
# INFO: extract region (index=64) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp7xf0_xpi/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:106087842-108409665 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_106087842_108409665.bgen
#
#
# INFO: extract region (index=65) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpwabe54ft/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:108409665-110303931 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_108409665_110303931.bgen
#
#
# INFO: extract region (index=66) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpd5e2lji_/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:110303931-111741737 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_110303931_111741737.bgen
#
#
# INFO: extract region (index=67) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmptkcfd94m/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:111741737-113273306 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_111741737_113273306.bgen
#
#
# INFO: extract region (index=68) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpsh1itzud/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:113273306-114873845 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_113273306_114873845.bgen
#
#
# INFO: extract region (index=69) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpv5vwbzw3/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:114873845-115880593 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_114873845_115880593.bgen
#
#
# INFO: extract region (index=70) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp9tiwq042/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:115880593-118839067 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_115880593_118839067.bgen
#
#
# INFO: extract region (index=71) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp2xy5qse8/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:118839067-144977494 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_118839067_144977494.bgen
#
#
# INFO: extract region (index=72) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpt105m9yv/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:144977494-148361253 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_144977494_148361253.bgen
#
#
# INFO: extract region (index=73) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpcomqfpp_/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:148361253-151538881 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_148361253_151538881.bgen
#
#
# INFO: extract region (index=74) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp25habuga/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:151538881-153180829 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_151538881_153180829.bgen
#
#
# INFO: extract region (index=75) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpf5odo3jh/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:153180829-154770403 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_153180829_154770403.bgen
#
#
# INFO: extract region (index=76) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmptbiaibwl/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:154770403-156336133 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_154770403_156336133.bgen
#
#
# INFO: extract region (index=77) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp7p_njgr5/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:156336133-158027412 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_156336133_158027412.bgen
#
#
# INFO: extract region (index=78) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp1w2t2hi7/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:158027412-159913048 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_158027412_159913048.bgen
#
#
# INFO: extract region (index=79) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp94vnkbxx/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:159913048-162346721 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_159913048_162346721.bgen
#
#
# INFO: extract region (index=80) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpog96d6vg/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:162346721-165191702 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_162346721_165191702.bgen
#
#
# INFO: extract region (index=81) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpwdr4minz/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:165191702-166460517 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_165191702_166460517.bgen
#
#
# INFO: extract region (index=82) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp6s670wj2/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:166460517-169086324 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_166460517_169086324.bgen
#
#
# INFO: extract region (index=83) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpot9pf2n9/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:169086324-170557776 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_169086324_170557776.bgen
#
#
# INFO: extract region (index=84) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp0g9q03y2/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:170557776-173097907 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_170557776_173097907.bgen
#
#
# INFO: extract region (index=85) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpip8uj7bf/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:173097907-175089768 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_173097907_175089768.bgen
#
#
# INFO: extract region (index=86) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpjuov9kzv/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:175089768-177433381 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_175089768_177433381.bgen
#
#
# INFO: extract region (index=87) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpfk1apibr/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:177433381-178944309 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_177433381_178944309.bgen
#
#
# INFO: extract region (index=88) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp24rlmkgr/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:178944309-178954470 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_178944309_178954470.bgen
#
#
# INFO: extract region (index=89) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpa1hxgps6/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:178954470-181144121 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_178954470_181144121.bgen
#
#
# INFO: extract region (index=90) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpuxwrknxt/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:181144121-182755356 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_181144121_182755356.bgen
#
#
# INFO: extract region (index=91) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp1i2w48q5/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:182755356-184595513 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_182755356_184595513.bgen
#
#
# INFO: extract region (index=92) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp7vg_ncgk/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:184595513-186810023 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_184595513_186810023.bgen
#
#
# INFO: extract region (index=93) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpejqqqjwj/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:186810023-188759945 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_186810023_188759945.bgen
#
#
# INFO: extract region (index=94) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpx15r1j4i/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:188759945-189904130 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_188759945_189904130.bgen
#
#
# INFO: extract region (index=95) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpw25xz230/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# -incl-range 01:189904130-191868930 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_189904130_191868930.bgen
#
#
# INFO: extract region (index=96) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpmer21nm0/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr1_v3.bgen \
# ...
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:37870779-38711704 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_37870779_38711704.bgen
#
#
# INFO: extract region (index=1671) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpivrlxcpw/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:38711704-40482902 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_38711704_40482902.bgen
#
#
# INFO: extract region (index=1672) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmplvb91qfw/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:40482902-41389527 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_40482902_41389527.bgen
#
#
# INFO: extract region (index=1673) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmphu3zc8_q/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:41389527-43321528 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_41389527_43321528.bgen
#
#
# INFO: extract region (index=1674) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp58gsiy3g/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:43321528-44506268 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_43321528_44506268.bgen
#
#
# INFO: extract region (index=1675) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp020xss5n/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:44506268-46177105 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_44506268_46177105.bgen
#
#
# INFO: extract region (index=1676) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpktexv2af/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:46177105-47492226 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_46177105_47492226.bgen
#
#
# INFO: extract region (index=1677) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpmicdbt_8/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr21_v3.bgen \
# -incl-range 21:47492226-48119752 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/21/21_47492226_48119752.bgen
#
#
# INFO: extract region (index=1678) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpsop5vd7z/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:16050408-17674295 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_16050408_17674295.bgen
#
#
# INFO: extract region (index=1679) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp0her7sva/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:17674295-18296088 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_17674295_18296088.bgen
#
#
# INFO: extract region (index=1680) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp_q_5u443/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:18296088-19912358 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_18296088_19912358.bgen
#
#
# INFO: extract region (index=1681) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpif31z35g/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:19912358-22357325 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_19912358_22357325.bgen
#
#
# INFO: extract region (index=1682) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp2t4hyjtt/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:22357325-23712647 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_22357325_23712647.bgen
#
#
# INFO: extract region (index=1683) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpgepzhprc/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:23712647-24984204 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_23712647_24984204.bgen
#
#
# INFO: extract region (index=1684) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp33v32vrl/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:24984204-26791628 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_24984204_26791628.bgen
#
#
# INFO: extract region (index=1685) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpcxyp0gls/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:26791628-27834752 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_26791628_27834752.bgen
#
#
# INFO: extract region (index=1686) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpw0yf2ze6/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:27834752-29651799 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_27834752_29651799.bgen
#
#
# INFO: extract region (index=1687) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpp3ta0zi2/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:29651799-31439918 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_29651799_31439918.bgen
#
#
# INFO: extract region (index=1688) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp23me0d5l/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:31439918-32664986 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_31439918_32664986.bgen
#
#
# INFO: extract region (index=1689) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpcpegbnew/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:32664986-34494914 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_32664986_34494914.bgen
#
#
# INFO: extract region (index=1690) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp_9p6us9l/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:34494914-35530985 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_34494914_35530985.bgen
#
#
# INFO: extract region (index=1691) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpg_cc2a72/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:35530985-37570269 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_35530985_37570269.bgen
#
#
# INFO: extract region (index=1692) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpn8st0jb_/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:37570269-39307894 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_37570269_39307894.bgen
#
#
# INFO: extract region (index=1693) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp84cdpmpd/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:39307894-40545797 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_39307894_40545797.bgen
#
#
# INFO: extract region (index=1694) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpm2cmx20z/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:40545797-42690818 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_40545797_42690818.bgen
#
#
# INFO: extract region (index=1695) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp4j3i0vz1/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:42690818-43714200 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_42690818_43714200.bgen
#
#
# INFO: extract region (index=1696) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpqwjv76me/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:43714200-44995308 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_43714200_44995308.bgen
#
#
# INFO: extract region (index=1697) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpai0uex84/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:44995308-46470495 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_44995308_46470495.bgen
#
#
# INFO: extract region (index=1698) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpya231stq/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:46470495-47596318 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_46470495_47596318.bgen
#
#
# INFO: extract region (index=1699) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp7zlql7vl/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:47596318-48903703 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_47596318_48903703.bgen
#
#
# INFO: extract region (index=1700) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmp2yglo73w/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:48903703-49824534 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_48903703_49824534.bgen
#
#
# INFO: extract region (index=1701) is completed.
# HINT: singularity exec  /mnt/vast/hpc/csg/containers/lmm.sif /bin/bash /mnt/mfs/hgrcgrid/homes/dmc2245/project/UKBB_GWAS_dev/analysis/pleio_AD_ARHI/tmpl2cygot4/singularity_run_13594.sh
# bgenix \
# -g /mnt/vast/hpc/csg/UKBiobank_Yale_transfer/ukb39554_imputeddataset/ukb_imp_chr22_v3.bgen \
# -incl-range 22:49824534-51243298 > /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/22/22_49824534_51243298.bgen
#
#
# INFO: extract region (index=1702) is completed.
# INFO: extract region output:   /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_10583_1892607.bgen /mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/01/01_1892607_3582736.bgen... (1703 items in 1703 groups)
# INFO: Workflow bgenix (ID=w5ef173163357eeaa) is tested successfully with 1 completed step and 1703 completed substeps.

# %% [markdown]
# ## Creation of the z_files

# %%
## Set the bash variables 
cwd=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/
variant_files='/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/*/*.variants'
ldstore_sbatch=$cwd/ldstore_test_$(date +"%Y-%m-%d").sbatch
masterfile='master_file_test'
number_of_samples=351430
incl_samples=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/regions_chr1_22/UKB_genotypedatadownloaded083019.090221_sample_variant_qc_final_callrate90.filtered.extracted.white_europeans.filtered.092821_ldprun_unrelated.filtered.fam
jobsize=1
ldstore_sos=~/project/UKBB_GWAS_dev/workflow/111722_LDstore.ipynb
tpl_file=~/project/bioworkflows/admin/csg.yml
mem='80G'
job_size=1
numThreads=4
#rsid_file=/mnt/vast/hpc/csg/UKBiobank/results/pleiotropy_AD_ARHI/111822_LDstore_files/chr22_snplist.snplist

ldstore_args="""default 
    --cwd $cwd
    --masterfile $masterfile
    --number_of_samples $number_of_samples
    --incl_samples $incl_samples
    --numThreads $numThreads 
    --mem $mem 
    --job_size $job_size
"""

sos run ~/project/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $ldstore_sos \
    --to-script $ldstore_sbatch \
    --args "$ldstore_args"

# %% [markdown]
# # How many asians in the 200K WES

# %%
unrel_asian = read.delim('/mnt/mfs/statgen/UKBiobank/phenotype_files/asian_IID/012323_ukb47922_asian_qc_unrel_9077.iid', header=TRUE, sep='')
# Out:
# /home/dmc2245/miniconda3/lib/python3.8/site-packages/sos_notebook/kernel.py:1334: DeprecationWarning: Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   msg['msg_id'] = self._parent_header['header']['msg_id']

# %%
unrel_asian
# Out:
#      FID     IID
# 1    1000906 1000906
# 2    1001874 1001874
# 3    1002712 1002712
# 4    1003025 1003025
# 5    1003083 1003083
# 6    1004204 1004204
# 7    1004223 1004223
# 8    1004262 1004262
# 9    1005191 1005191
# 10   1005270 1005270
# 11   1005298 1005298
# 12   1006702 1006702
# 13   1006862 1006862
# 14   1007904 1007904
# 15   1008886 1008886
# 16   1009036 1009036
# 17   1009977 1009977
# 18   1010506 1010506
# 19   1012478 1012478
# 20   1012605 1012605
# 21   1013112 1013112
# 22   1013236 1013236
# 23   1013573 1013573
# 24   1013817 1013817
# 25   1013992 1013992
# 26   1014243 1014243
# 27   1014282 1014282
# 28   1014469 1014469
# 29   1015650 1015650
# 30   1017644 1017644
# ...  ...     ...
# 9048 6009257 6009257
# 9049 6010399 6010399
# 9050 6011145 6011145
# 9051 6011712 6011712
# 9052 6012433 6012433
# 9053 6012986 6012986
# 9054 6013618 6013618
# 9055 6013978 6013978
# 9056 6014412 6014412
# 9057 6014783 6014783
# 9058 6015097 6015097
# ...

# %%
wes_ind = read.delim('~/UKBiobank/data/exome_files/project_VCF/072721_run/plink/ukb23156_c19.merged.filtered.fam', header=FALSE, sep=' ')

# %%
colnames(wes_ind) <- c('FID', 'IID',"no","no1", 'no2', "no3")

# %%
wes_ind
# Out:
#        FID     IID     no  no1 no2 no3
# 1      1434748 1434748 0   0   0   -9
# 2      5523981 5523981 0   0   0   -9
# 3      5023838 5023838 0   0   0   -9
# 4      4023729 4023729 0   0   0   -9
# 5      4442146 4442146 0   0   0   -9
# 6      5654789 5654789 0   0   0   -9
# 7      4515669 4515669 0   0   0   -9
# 8      1129683 1129683 0   0   0   -9
# 9      5327043 5327043 0   0   0   -9
# 10     4744741 4744741 0   0   0   -9
# 11     1258289 1258289 0   0   0   -9
# 12     1924899 1924899 0   0   0   -9
# 13     5191548 5191548 0   0   0   -9
# 14     3181661 3181661 0   0   0   -9
# 15     3412444 3412444 0   0   0   -9
# 16     1254713 1254713 0   0   0   -9
# 17     1333104 1333104 0   0   0   -9
# 18     1976466 1976466 0   0   0   -9
# 19     1246153 1246153 0   0   0   -9
# 20     3748499 3748499 0   0   0   -9
# 21     2204914 2204914 0   0   0   -9
# 22     1892597 1892597 0   0   0   -9
# 23     5009888 5009888 0   0   0   -9
# ...

# %%
unrel_asian[unrel_asian$FID %in% wes_ind$FID,]
# Out:
#      FID     IID
# 4    1003025 1003025
# 5    1003083 1003083
# 7    1004223 1004223
# 9    1005191 1005191
# 10   1005270 1005270
# 11   1005298 1005298
# 12   1006702 1006702
# 14   1007904 1007904
# 19   1012478 1012478
# 23   1013573 1013573
# 28   1014469 1014469
# 29   1015650 1015650
# 33   1018445 1018445
# 34   1018922 1018922
# 37   1019384 1019384
# 39   1019986 1019986
# 40   1020911 1020911
# 42   1021639 1021639
# 46   1025217 1025217
# 47   1026159 1026159
# 48   1026209 1026209
# 50   1028019 1028019
# 51   1028466 1028466
# 53   1030739 1030739
# 59   1035421 1035421
# 60   1035573 1035573
# 63   1036732 1036732
# 65   1037925 1037925
# 66   1038559 1038559
# 69   1039163 1039163
# ...  ...     ...
# 9005 5987756 5987756
# 9006 5987774 5987774
# 9007 5988487 5988487
# 9010 5989114 5989114
# 9015 5993471 5993471
# 9017 5993941 5993941
# 9021 5995424 5995424
# 9025 5996741 5996741
# 9026 5996806 5996806
# 9027 5998432 5998432
# 9028 5998458 5998458
# ...

# %%
total_asian = read.delim("~/UKBiobank/genotype_files_processed/012323_asian_10189ind_hg38/final_files/UKB_genotypedatadownloaded083019_hg38_674489variants_486416samples.sorted.filtered.extracted.fam", header=FALSE, sep="\t")
colnames(total_asian) <- c('FID', 'IID',"no","no1", 'no2', "no3")

# %%
total_asian

# %%
total_asian[total_asian$FID %in% wes_ind$FID,]
# Out:
#       FID     IID     no  no1 no2 no3
# 4     1003025 1003025 0   0   1   -9
# 5     1003083 1003083 0   0   1   -9
# 7     1004223 1004223 0   0   1   -9
# 9     1005191 1005191 0   0   2   -9
# 10    1005270 1005270 0   0   2   -9
# 11    1005298 1005298 0   0   2   -9
# 12    1006702 1006702 0   0   2   -9
# 14    1007904 1007904 0   0   2   -9
# 19    1011060 1011060 0   0   2   -9
# 21    1012478 1012478 0   0   1   -9
# 25    1013331 1013331 0   0   1   -9
# 26    1013573 1013573 0   0   1   -9
# 31    1014469 1014469 0   0   1   -9
# 32    1015650 1015650 0   0   1   -9
# 36    1018445 1018445 0   0   1   -9
# 37    1018922 1018922 0   0   2   -9
# 40    1019384 1019384 0   0   1   -9
# 42    1019986 1019986 0   0   2   -9
# 43    1020911 1020911 0   0   1   -9
# 45    1021639 1021639 0   0   2   -9
# 49    1023766 1023766 0   0   1   -9
# 50    1025217 1025217 0   0   1   -9
# 51    1026159 1026159 0   0   1   -9
# 52    1026209 1026209 0   0   2   -9
# ...

# %%
unrel_asian[unrel_asian$FID %in% wes_ind$FID,]
# Out:
#      FID     IID
# 4    1003025 1003025
# 5    1003083 1003083
# 7    1004223 1004223
# 9    1005191 1005191
# 10   1005270 1005270
# 11   1005298 1005298
# 12   1006702 1006702
# 14   1007904 1007904
# 19   1012478 1012478
# 23   1013573 1013573
# 28   1014469 1014469
# 29   1015650 1015650
# 33   1018445 1018445
# 34   1018922 1018922
# 37   1019384 1019384
# 39   1019986 1019986
# 40   1020911 1020911
# 42   1021639 1021639
# 46   1025217 1025217
# 47   1026159 1026159
# 48   1026209 1026209
# 50   1028019 1028019
# 51   1028466 1028466
# 53   1030739 1030739
# 59   1035421 1035421
# 60   1035573 1035573
# 63   1036732 1036732
# 65   1037925 1037925
# 66   1038559 1038559
# 69   1039163 1039163
# ...  ...     ...
# 9005 5987756 5987756
# 9006 5987774 5987774
# 9007 5988487 5988487
# 9010 5989114 5989114
# 9015 5993471 5993471
# 9017 5993941 5993941
# 9021 5995424 5995424
# 9025 5996741 5996741
# 9026 5996806 5996806
# 9027 5998432 5998432
# 9028 5998458 5998458
# ...

# %%
unrel_african = read.delim('/mnt/mfs/statgen/UKBiobank/phenotype_files/african_IID/012323_ukb47922_african_qc_unrel_7276.iid', header=TRUE, sep='\t')

# %%
total_african = read.delim("~/UKBiobank/genotype_files_processed/012323_african_9096ind_hg38/final_files/UKB_genotypedatadownloaded083019_hg38_674489variants_486416samples.sorted.filtered.extracted.fam", header=FALSE, sep="\t")

# %%
colnames(total_african) <- c('FID', 'IID',"no","no1", 'no2', "no3")
total_african
# Out:
#      FID     IID     no  no1 no2 no3
# 1    1000697 1000697 0   0   2   -9
# 2    1001447 1001447 0   0   2   -9
# 3    1001465 1001465 0   0   2   -9
# 4    1002004 1002004 0   0   1   -9
# 5    1002354 1002354 0   0   2   -9
# 6    1002390 1002390 0   0   2   -9
# 7    1002608 1002608 0   0   2   -9
# 8    1003139 1003139 0   0   2   -9
# 9    1004285 1004285 0   0   1   -9
# 10   1004525 1004525 0   0   2   -9
# 11   1004627 1004627 0   0   2   -9
# 12   1005750 1005750 0   0   2   -9
# 13   1006015 1006015 0   0   2   -9
# 14   1006751 1006751 0   0   2   -9
# 15   1006879 1006879 0   0   1   -9
# 16   1008161 1008161 0   0   1   -9
# 17   1008785 1008785 0   0   2   -9
# 18   1008837 1008837 0   0   1   -9
# 19   1008960 1008960 0   0   2   -9
# 20   1009579 1009579 0   0   1   -9
# 21   1011293 1011293 0   0   2   -9
# 22   1011457 1011457 0   0   2   -9
# 23   1011881 1011881 0   0   1   -9
# 24   1012698 1012698 0   0   1   -9
# 25   1012903 1012903 0   0   2   -9
# ...

# %%
total_african[total_african$FID %in% wes_ind$FID,]
# Out:
#      FID     IID     no  no1 no2 no3
# 1    1000697 1000697 0   0   2   -9
# 2    1001447 1001447 0   0   2   -9
# 4    1002004 1002004 0   0   1   -9
# 5    1002354 1002354 0   0   2   -9
# 8    1003139 1003139 0   0   2   -9
# 10   1004525 1004525 0   0   2   -9
# 11   1004627 1004627 0   0   2   -9
# 17   1008785 1008785 0   0   2   -9
# 19   1008960 1008960 0   0   2   -9
# 22   1011457 1011457 0   0   2   -9
# 26   1013318 1013318 0   0   1   -9
# 27   1014002 1014002 0   0   2   -9
# 29   1015230 1015230 0   0   1   -9
# 36   1018532 1018532 0   0   2   -9
# 37   1019758 1019758 0   0   2   -9
# 39   1020779 1020779 0   0   2   -9
# 42   1022196 1022196 0   0   2   -9
# 44   1025177 1025177 0   0   2   -9
# 47   1027348 1027348 0   0   2   -9
# 49   1027714 1027714 0   0   2   -9
# 51   1028105 1028105 0   0   2   -9
# 53   1030033 1030033 0   0   2   -9
# 54   1030575 1030575 0   0   2   -9
# 55   1030895 1030895 0   0   1   -9
# 56   1031422 1031422 0   0   2   -9
# ...

# %%
unrel_african
# Out:
#      FID     IID     ethnicity
# 1    1001465 1001465 2001
# 2    1002004 1002004 4002
# 3    1002354 1002354 4001
# 4    1002390 1002390 4002
# 5    1002608 1002608 4001
# 6    1003139 1003139 2001
# 7    1004285 1004285 4002
# 8    1004525 1004525 4001
# 9    1004627 1004627 4002
# 10   1005750 1005750 4001
# 11   1006015 1006015 4001
# 12   1006751 1006751 2002
# 13   1008161 1008161 4001
# 14   1008785 1008785 4001
# 15   1008837 1008837 2002
# 16   1008960 1008960 4001
# 17   1011293 1011293 4001
# 18   1011457 1011457 4001
# 19   1012698 1012698 4002
# 20   1012903 1012903 4002
# 21   1013318 1013318 4001
# 22   1014002 1014002 4001
# 23   1015230 1015230 4002
# 24   1015989 1015989 4001
# 25   1016098 1016098 4002
# 26   1017106 1017106 4001
# 27   1017165 1017165 4002
# 28   1018517 1018517 4002
# 29   1018532 1018532 4002
# 30   1020487 1020487 4002
# ...  ...     ...     ...
# 7247 6004693 6004693 4001
# 7248 6005164 6005164 4001
# 7249 6005357 6005357 2001
# ...

# %%
unrel_african[unrel_african$FID %in% wes_ind$FID,]
# Out:
#      FID     IID     ethnicity
# 2    1002004 1002004 4002
# 3    1002354 1002354 4001
# 6    1003139 1003139 2001
# 8    1004525 1004525 4001
# 9    1004627 1004627 4002
# 14   1008785 1008785 4001
# 16   1008960 1008960 4001
# 18   1011457 1011457 4001
# 21   1013318 1013318 4001
# 22   1014002 1014002 4001
# 23   1015230 1015230 4002
# 29   1018532 1018532 4002
# 31   1020779 1020779 4001
# 33   1022196 1022196 4002
# 35   1025177 1025177 4001
# 38   1027348 1027348 4002
# 40   1027714 1027714 4001
# 42   1028105 1028105 4001
# 43   1030033 1030033 4001
# 44   1030895 1030895 4001
# 45   1031545 1031545 4001
# 46   1031804 1031804 4002
# 51   1034329 1034329 4002
# 52   1035408 1035408 4002
# 53   1036789 1036789 4001
# 54   1038308 1038308 4001
# 56   1041504 1041504 4002
# 60   1043521 1043521 4002
# 63   1046650 1046650 4001
# 64   1047137 1047137 4001
# ...  ...     ...     ...
# 7214 5983628 5983628 4001
# 7217 5987075 5987075 4001
# 7219 5987366 5987366 4002
# ...

# %% [markdown]
# # Results for hearing impairment phenotypes Exome data

# %% [markdown]
# ## 1. Single variant analysis (MAF>0.001)

# %% [markdown]
# ### f.2247 - Hearing difficulty

# %%
%preview /gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/f2247_hearing_difficulty_exomes/010421_UKBB_Hearing_difficulty_f2247_171970ind_exomes_hearing_diff_new.regenie.manhattan.png \
-s png -n --width 2
# Out:
# > /gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/f2247_hearing_difficulty_exomes/010421_UKBB_Hearing_difficulty_f2247_171970ind_exomes_hearing_diff_new.regenie.manhattan.png (120.9 KiB):

# %%
%preview /gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/f2247_hearing_difficulty_exomes/010421_UKBB_Hearing_difficulty_f2247_171970ind_exomes_hearing_diff_new.regenie.qq.png -n
# Out:
# > /gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/f2247_hearing_difficulty_exomes/010421_UKBB_Hearing_difficulty_f2247_171970ind_exomes_hearing_diff_new.regenie.qq.png (73.5 KiB):

# %%
library('qqman')
data <- read.table(gzfile('/gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/tinnitus_plan1_2_3/010421_UKBB_Tinnitus_plan1_2_3_f4803_exomes_tinnitus_p3.regenie.snp_stats.gz'), sep='\t', header=T)
# Out:
# For example usage please run: vignette('qqman')
#
#
#
# Citation appreciated but not required:
#
# Turner, S.D. qqman: an R package for visualizing GWAS results using Q-Q and manhattan plots. biorXiv DOI: 10.1101/005165 (2014).

# %% [markdown]
# # Tinnitus P1 (all)

# %%
data_0 <- read.table(gzfile('/gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/tinnitus_plan1_2_3/010421_UKBB_Tinnitus_plan1_2_3_f4803_exomes_tinnitus.regenie.snp_stats.gz'), sep='\t', header=T)

# %%
manhattan_plot <- manhattan(data_0, chr='CHR', bp='POS', snp='SNP', p='P', main = 'Manhattan plot for tinnitus (regenie)', ylim=c(0,10), cex = 0.6, cex.axis = 0.9, col = c("blue4", "orange3"), chrlabs = as.character(c(1:22)))
# Out:
# Plot with title “Manhattan plot for tinnitus (regenie)”

# %%
qq_plot <- qq(data_0$P, main = 'QQ Plot for tinnitus (regenie)', xlim = c(0, 8),ylim=c(0,10), pch = 18, col = "blue4", cex = 1.5, las = 1)
# Out:
# Plot with title “QQ Plot for tinnitus (regenie)”

# %% [markdown]
# # Tinnitus P2

# %%
data_1 <- read.table(gzfile('/gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/tinnitus_plan1_2_3/010421_UKBB_Tinnitus_plan1_2_3_f4803_exomes_tinnitus_p2.regenie.snp_stats.gz'), sep='\t', header=T)

# %%
manhattan_plot <- manhattan(data_1, chr='CHR', bp='POS', snp='SNP', p='P', main = 'Manhattan plot for tinnitus_p2 (regenie)', ylim=c(0,10), cex = 0.6, cex.axis = 0.9, col = c("blue4", "orange3"), chrlabs = as.character(c(1:22)))
# Out:
# Plot with title “Manhattan plot for tinnitus_p2 (regenie)”

# %%
qq_plot <- qq(data_1$P, main = 'QQ Plot for tinnitus_p2 (regenie)', xlim = c(0, 8),ylim=c(0,10), pch = 18, col = "blue4", cex = 1.5, las = 1)
# Out:
# Plot with title “QQ Plot for tinnitus_p2 (regenie)”

# %% [markdown]
# # Tinnitus P3

# %%
# Creating manhattan plot
#png('/gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/tinnitus_plan1_2_3/010421_UKBB_Tinnitus_plan1_2_3_f4803_exomes_tinnitus_p3.regenie.manhattan.png', width = 6, height = 4, unit='in', res=300)
manhattan_plot <- manhattan(data, chr='CHR', bp='POS', snp='SNP', p='P', main = 'Manhattan plot for tinnitus_p3 (regenie)', ylim=c(0,10), cex = 0.6, cex.axis = 0.9, col = c("blue4", "orange3"), chrlabs = as.character(c(1:22)))
#dev.off()
# Out:
# Plot with title “Manhattan plot for tinnitus_p3 (regenie)”

# %%
# Creating qqplot
#png('/gpfs/gibbs/pi/dewan/data/UKBiobank/results/REGENIE_results/results_exome_data/tinnitus_plan1_2_3/010421_UKBB_Tinnitus_plan1_2_3_f4803_exomes_tinnitus_p3.regenie.qq.png', width = 5, height = 5, unit='in', res=300)
qq_plot <- qq(data$P, main = 'QQ Plot for tinnitus_p3 (regenie)', xlim = c(0, 8),ylim=c(0,10), pch = 18, col = "blue4", cex = 1.5, las = 1)
#dev.off()
# Out:
# Plot with title “QQ Plot for tinnitus_p3 (regenie)”

# %% [markdown]
# ## Create a table with the significant associations for burden test Haid

# %%
import pandas as pd

# %%
# Read the four files
df1 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Haid_CADD/f3393_CADD_skato_burden_sigbelowlogp5.txt')
df2 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hdiff_CADD/f2247_CADD_skato_burden_sigbelowlogp5.txt')
df3 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hnoise_CADD/f2257_CADD_skato_burden_sigbelowlogp5.txt')
df4 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hboth_CADD/f2247_f2257_CADD_skato_burden_sigbelowlogp5.txt')

# Select required columns for each phenotype
df1_selected = df1[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df2_selected = df2[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df3_selected = df3[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df4_selected = df4[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]

# %%
# Rename columns to include the phenotype name
df1_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f3393','TEST', 'BETA_f3393', 'SE_f3393', 'LOG10P_f3393']
df2_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2247','TEST', 'BETA_f2247', 'SE_f2247', 'LOG10P_f2247']
df3_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2257','TEST', 'BETA_f2257', 'SE_f2257', 'LOG10P_f2257']
df4_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2247_f2257', 'TEST', 'BETA_f2247_f2257', 'SE_f2247_f2257', 'LOG10P_f2247_f2257']

# %%
# Merge dataframes on common columns (CHROM and GENPOS)
merged_df = pd.merge(df1_selected, df2_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')
merged_df = pd.merge(merged_df, df3_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')
merged_df = pd.merge(merged_df, df4_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')

# %%
merged_df[['P_f3393', 'P_f2247', 'P_f2257', 'P_f2247_f2257']] = 10 ** -merged_df[['LOG10P_f3393', 'LOG10P_f2247', 'LOG10P_f2257', 'LOG10P_f2247_f2257']]

# %%
merged_df
# Out:
#     CHROM     GENPOS                      ID      ALLELE1  A1FREQ_f3393  \
# 0       5  146339116       POU4F3.Mask1.0.01   Mask1.0.01           NaN
# 1       6  133274701         EYA4.Mask1.0.01   Mask1.0.01           NaN
# 2       6   75817495         MYO6.Mask1.0.01   Mask1.0.01           NaN
# 3       7  103374399      SLC26A5.Mask1.0.01   Mask1.0.01           NaN
# 4       8  101492770        GRHL2.Mask1.0.01   Mask1.0.01           NaN
# ..    ...        ...                     ...          ...           ...
# 85      2  178432096        PRKRA.Mask2.0.01   Mask2.0.01           NaN
# 86      2  178432096       PRKRA.Mask1.0.005  Mask1.0.005           NaN
# 87      2  178432096        PRKRA.Mask1.0.01   Mask1.0.01           NaN
# 88     11  121045662  TBCEL-TECTA.Mask2.0.01   Mask2.0.01           NaN
# 89     11  121102653        TECTA.Mask2.0.01   Mask2.0.01           NaN
#
#          TEST  BETA_f3393  SE_f3393  LOG10P_f3393  A1FREQ_f2247  ...  \
# 0   ADD-SKATO         NaN       NaN       7.95054           NaN  ...
# 1   ADD-SKATO         NaN       NaN      12.87610           NaN  ...
# 2   ADD-SKATO         NaN       NaN      23.40790           NaN  ...
# 3   ADD-SKATO         NaN       NaN       5.37368           NaN  ...
# 4   ADD-SKATO         NaN       NaN      11.67590           NaN  ...
# ..        ...         ...       ...           ...           ...  ...
# 85  ADD-SKATO         NaN       NaN           NaN           NaN  ...
# 86        ADD         NaN       NaN           NaN           NaN  ...
# 87        ADD         NaN       NaN           NaN           NaN  ...
# 88        ADD         NaN       NaN           NaN           NaN  ...
# 89        ADD         NaN       NaN           NaN           NaN  ...
#
#     SE_f2257  LOG10P_f2257  A1FREQ_f2247_f2257  BETA_f2247_f2257  \
# 0        NaN           NaN                 NaN               NaN
# 1        NaN           NaN                 NaN               NaN
# 2        NaN       6.16254                 NaN               NaN
# 3        NaN       7.68818                 NaN               NaN
# 4        NaN           NaN                 NaN               NaN
# ..       ...           ...                 ...               ...
# 85       NaN           NaN                 NaN               NaN
# 86       NaN           NaN            0.013724          0.115639
# 87       NaN           NaN            0.013724          0.115639
# 88       NaN           NaN            0.033482          0.071949
# 89       NaN           NaN            0.032185          0.074098
#
#     SE_f2247_f2257  LOG10P_f2247_f2257       P_f3393       P_f2247  \
# 0              NaN                 NaN  1.120624e-08           NaN
# 1              NaN                 NaN  1.330148e-13           NaN
# 2              NaN            10.12260  3.909309e-24  6.028233e-10
# 3              NaN            11.68360  4.229802e-06  1.409613e-12
# 4              NaN                 NaN  2.109114e-12           NaN
# ..             ...                 ...           ...           ...
# 85             NaN             5.75009           NaN           NaN
# 86        0.024251             5.66873           NaN           NaN
# 87        0.024251             5.66873           NaN           NaN
# 88        0.015984             5.13557           NaN           NaN
# 89        0.016275             5.23965           NaN           NaN
#
#          P_f2257  P_f2247_f2257
# 0            NaN            NaN
# 1            NaN            NaN
# 2   6.877966e-07   7.540497e-11
# 3   2.050312e-08   2.072049e-12
# 4            NaN            NaN
# ..           ...            ...
# 85           NaN   1.777911e-06
# 86           NaN   2.144223e-06
# 87           NaN   2.144223e-06
# 88           NaN   7.318634e-06
# 89           NaN   5.759039e-06
#
# [90 rows x 25 columns]

# %%
merged_df = merged_df.fillna('NA')

# %%
skato_result = merged_df.loc[merged_df['TEST'] == 'ADD-SKATO']

# %%
skato_result = skato_result.sort_values(by=['CHROM'], ascending=[True])

# %%
for allele, group in skato_result.groupby('ALLELE1'):
    # Define the filename using the 'ALLELE1' name
    filename = f'/home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD_{allele}_output.csv'
    
    # Save the group to the CSV file
    group.to_csv(filename, index=False, header=True,dtype='string')

    print(f'Saved group with ALLELE1="{allele}" to {filename}')

# %%
#skato_result.to_csv('/home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD.csv', index=False, header=True)

# %%
burden_result = merged_df.loc[merged_df['TEST'] == 'ADD']

# %%
burden_result = burden_result.sort_values(by=['CHROM'], ascending=[True])

# %%
for allele, group in burden_result.groupby('ALLELE1'):
    # Define the filename using the 'ALLELE1' name
    filename = f'/home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_{allele}_output.csv'
    
    # Save the group to the CSV file
    group.to_csv(filename, index=False, header=True,dtype='string')

    print(f'Saved group with ALLELE1="{allele}" to {filename}')
# Out:
# Saved group with ALLELE1="Mask1.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.0.005_output.csv
# Saved group with ALLELE1="Mask1.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.0.01_output.csv
# Saved group with ALLELE1="Mask2.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.0.005_output.csv
# Saved group with ALLELE1="Mask2.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.0.01_output.csv

# %%
#burden_result.to_csv('/home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD.csv', index=False, header=True)

# %% [markdown]
# ## Start with the full summary stats

# %%
~/UKBiobank/RAP/results/autosomal/aggregate/Haid_CADD/

# %%
# Read the four files
df1 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Haid_CADD/f3393.regenie', comment='#', sep=" ")
df2 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hdiff_CADD/f2247.regenie',comment='#', sep=" ")
df3 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hnoise_CADD/f2257.regenie',comment='#', sep=" ")
df4 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hboth_CADD/f2247_f2257.regenie',comment='#', sep=" ")

# %%
# Select required columns for each phenotype
df1_selected = df1[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df2_selected = df2[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df3_selected = df3[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df4_selected = df4[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]

# %%
# Rename columns to include the phenotype name
df1_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f3393','TEST', 'BETA_f3393', 'SE_f3393', 'LOG10P_f3393']
df2_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2247','TEST', 'BETA_f2247', 'SE_f2247', 'LOG10P_f2247']
df3_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2257','TEST', 'BETA_f2257', 'SE_f2257', 'LOG10P_f2257']
df4_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2247_f2257', 'TEST', 'BETA_f2247_f2257', 'SE_f2247_f2257', 'LOG10P_f2247_f2257']

# %%
# Merge dataframes on common columns (CHROM and GENPOS)
merged_df = pd.merge(df1_selected, df2_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')
merged_df = pd.merge(merged_df, df3_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')
merged_df = pd.merge(merged_df, df4_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')

# %%
merged_df
# Out:
#        CHROM    GENPOS                         ID          ALLELE1  \
# 0          1  33306769    A3GALT2.Mask1.singleton  Mask1.singleton
# 1          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 2          1  33306769         A3GALT2.Mask1.0.01       Mask1.0.01
# 3          1  33306769         A3GALT2.Mask1.0.01       Mask1.0.01
# 4          1  33306769         A3GALT2.Mask1.0.01       Mask1.0.01
# ...      ...       ...                        ...              ...
# 374368    11  71582370  KRTAP5-11.Mask2.singleton  Mask2.singleton
# 374369    14  22575049       DAD1.Mask1.singleton  Mask1.singleton
# 374370    16  48361588      SIAH1.Mask1.singleton  Mask1.singleton
# 374371    17   7481519    SLC35G6.Mask1.singleton  Mask1.singleton
# 374372    19  48030561      CABP5.Mask1.singleton  Mask1.singleton
#
#        A1FREQ_f3393       TEST BETA_f3393  SE_f3393 LOG10P_f3393 A1FREQ_f2247  \
# 0       1.25259e-05        ADD   -1.14905   1.65401     0.312259  1.21429e-05
# 1       0.000265131        ADD   0.647419  0.301917      1.36031  0.000267143
# 2               NaN   ADD-SKAT        NaN       NaN     0.884134          NaN
# 3               NaN  ADD-SKATO        NaN       NaN      1.15877          NaN
# 4       0.000265131        ADD   0.647419  0.301917      1.36031  0.000267143
# ...             ...        ...        ...       ...          ...          ...
# 374368          NaN        ADD        NaN       NaN          NaN          NaN
# 374369          NaN        ADD        NaN       NaN          NaN          NaN
# 374370          NaN        ADD        NaN       NaN          NaN          NaN
# 374371          NaN        ADD        NaN       NaN          NaN          NaN
# 374372          NaN        ADD        NaN       NaN          NaN          NaN
#
#         ...  SE_f2247 LOG10P_f2247 A1FREQ_f2257 BETA_f2257  SE_f2257  \
# 0       ...  0.760633    0.0957525  1.72188e-05   0.609199  0.572847
# 1       ...  0.166358     0.733251  0.000271527   0.178833  0.144475
# 2       ...       NaN     0.994283          NaN        NaN       NaN
# 3       ...       NaN     0.795937          NaN        NaN       NaN
# 4       ...  0.166358     0.733251  0.000271527   0.178833  0.144475
# ...     ...       ...          ...          ...        ...       ...
# 374368  ...       NaN          NaN          NaN        NaN       NaN
# 374369  ...       NaN          NaN          NaN        NaN       NaN
# 374370  ...       NaN          NaN          NaN        NaN       NaN
# 374371  ...       NaN          NaN          NaN        NaN       NaN
# 374372  ...       NaN          NaN          NaN        NaN       NaN
#
#        LOG10P_f2257 A1FREQ_f2247_f2257 BETA_f2247_f2257 SE_f2247_f2257  \
# 0           0.54125         1.4366e-05         0.243349       0.748279
# 1          0.665978        0.000260185         0.152691       0.178964
# 2           1.32189                NaN              NaN            NaN
# 3           1.10832                NaN              NaN            NaN
# 4          0.665978        0.000260185         0.152691       0.178964
# ...             ...                ...              ...            ...
# 374368          NaN        7.98113e-06         0.509823        1.00098
# 374369          NaN        7.98113e-06          1.32459       0.979513
# 374370          NaN        7.98113e-06        -0.220062        1.05555
# 374371          NaN        7.98113e-06         0.474355        1.00001
# 374372          NaN        7.98113e-06          0.59386        1.02471
#
#        LOG10P_f2247_f2257
# 0                0.127832
# 1                0.404998
# 2                 1.03021
# 3                0.827662
# 4                0.404998
# ...                   ...
# 374368           0.214297
# 374369           0.753794
# 374370          0.0783897
# 374371           0.197056
# 374372           0.250089
#
# [374373 rows x 21 columns]

# %%
merged_df[['LOG10P_f3393', 'LOG10P_f2247', 'LOG10P_f2257', 'LOG10P_f2247_f2257']] = merged_df[['LOG10P_f3393', 'LOG10P_f2247', 'LOG10P_f2257', 'LOG10P_f2247_f2257']].apply(pd.to_numeric, errors='coerce')

# %%
merged_df[['P_f3393', 'P_f2247', 'P_f2257', 'P_f2247_f2257']] = 10 ** -merged_df[['LOG10P_f3393', 'LOG10P_f2247', 'LOG10P_f2257', 'LOG10P_f2247_f2257']]

# %%
merged_df
# Out:
#        CHROM    GENPOS                         ID          ALLELE1  \
# 0          1  33306769    A3GALT2.Mask1.singleton  Mask1.singleton
# 1          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 2          1  33306769         A3GALT2.Mask1.0.01       Mask1.0.01
# 3          1  33306769         A3GALT2.Mask1.0.01       Mask1.0.01
# 4          1  33306769         A3GALT2.Mask1.0.01       Mask1.0.01
# ...      ...       ...                        ...              ...
# 374368    11  71582370  KRTAP5-11.Mask2.singleton  Mask2.singleton
# 374369    14  22575049       DAD1.Mask1.singleton  Mask1.singleton
# 374370    16  48361588      SIAH1.Mask1.singleton  Mask1.singleton
# 374371    17   7481519    SLC35G6.Mask1.singleton  Mask1.singleton
# 374372    19  48030561      CABP5.Mask1.singleton  Mask1.singleton
#
#        A1FREQ_f3393       TEST BETA_f3393  SE_f3393  LOG10P_f3393  \
# 0       1.25259e-05        ADD   -1.14905   1.65401      0.312259
# 1       0.000265131        ADD   0.647419  0.301917      1.360310
# 2               NaN   ADD-SKAT        NaN       NaN      0.884134
# 3               NaN  ADD-SKATO        NaN       NaN      1.158770
# 4       0.000265131        ADD   0.647419  0.301917      1.360310
# ...             ...        ...        ...       ...           ...
# 374368          NaN        ADD        NaN       NaN           NaN
# 374369          NaN        ADD        NaN       NaN           NaN
# 374370          NaN        ADD        NaN       NaN           NaN
# 374371          NaN        ADD        NaN       NaN           NaN
# 374372          NaN        ADD        NaN       NaN           NaN
#
#        A1FREQ_f2247  ...  SE_f2257 LOG10P_f2257  A1FREQ_f2247_f2257  \
# 0       1.21429e-05  ...  0.572847     0.541250          1.4366e-05
# 1       0.000267143  ...  0.144475     0.665978         0.000260185
# 2               NaN  ...       NaN     1.321890                 NaN
# 3               NaN  ...       NaN     1.108320                 NaN
# 4       0.000267143  ...  0.144475     0.665978         0.000260185
# ...             ...  ...       ...          ...                 ...
# 374368          NaN  ...       NaN          NaN         7.98113e-06
# 374369          NaN  ...       NaN          NaN         7.98113e-06
# 374370          NaN  ...       NaN          NaN         7.98113e-06
# 374371          NaN  ...       NaN          NaN         7.98113e-06
# 374372          NaN  ...       NaN          NaN         7.98113e-06
#
#        BETA_f2247_f2257 SE_f2247_f2257 LOG10P_f2247_f2257   P_f3393   P_f2247  \
# 0              0.243349       0.748279           0.127832  0.487238  0.802135
# 1              0.152691       0.178964           0.404998  0.043620  0.184820
# 2                   NaN            NaN           1.030210  0.130577  0.101325
# 3                   NaN            NaN           0.827662  0.069379  0.159979
# 4              0.152691       0.178964           0.404998  0.043620  0.184820
# ...                 ...            ...                ...       ...       ...
# 374368         0.509823        1.00098           0.214297       NaN       NaN
# 374369          1.32459       0.979513           0.753794       NaN       NaN
# 374370        -0.220062        1.05555           0.078390       NaN       NaN
# 374371         0.474355        1.00001           0.197056       NaN       NaN
# 374372          0.59386        1.02471           0.250089       NaN       NaN
#
#          P_f2257 P_f2247_f2257
# 0       0.287574      0.745020
# 1       0.215785      0.393552
# 2       0.047655      0.093280
# 3       0.077926      0.148709
# 4       0.215785      0.393552
# ...          ...           ...
# 374368       NaN      0.610524
# 374369       NaN      0.176281
# 374370       NaN      0.834854
# 374371       NaN      0.635249
# 374372       NaN      0.562226
#
# [374373 rows x 25 columns]

# %%
# Ensure 'TEST' column is a string type
merged_df['TEST'] = merged_df['TEST'].astype(str)

# Ensure 'P_1', 'P_2', 'P_3', 'P_4' columns are numeric types
merged_df[['P_f3393', 'P_f2247', 'P_f2257', 'P_f2247_f2257']] = merged_df[['P_f3393', 'P_f2247', 'P_f2257', 'P_f2247_f2257']].apply(pd.to_numeric, errors='coerce')

# %%
skato_result = merged_df.loc[(merged_df['TEST'] == 'ADD-SKATO')  & ((merged_df['P_f3393'] <= 2.5e-06) | (merged_df['P_f2247'] <= 2.5e-06) | (merged_df['P_f2257'] <= 2.5e-06) | (merged_df['P_f2247_f2257'] <= 2.5e-06))]

# %%
skato_result
# Out:
#        CHROM     GENPOS                      ID     ALLELE1 A1FREQ_f3393  \
# 3401       1  102878022      COL11A1.Mask1.0.01  Mask1.0.01           NA
# 5474       1   11648706        FBXO2.Mask2.0.01  Mask2.0.01           NA
# 8045       1   40784099        KCNQ4.Mask2.0.01  Mask2.0.01           NA
# 221522     2  178432096        PRKRA.Mask1.0.01  Mask1.0.01           NA
# 221527     2  178432096        PRKRA.Mask2.0.01  Mask2.0.01           NA
# 231749     3  142664192         PLS1.Mask1.0.01  Mask1.0.01           NA
# 247669     5     271691        PDCD6.Mask2.0.01  Mask2.0.01           NA
# 247922     5  146339116       POU4F3.Mask1.0.01  Mask1.0.01           NA
# 252748     6  133274701         EYA4.Mask1.0.01  Mask1.0.01           NA
# 252753     6  133274701         EYA4.Mask2.0.01  Mask2.0.01           NA
# 255942     6   75817495         MYO6.Mask1.0.01  Mask1.0.01           NA
# 255947     6   75817495         MYO6.Mask2.0.01  Mask2.0.01           NA
# 258712     6  157981963        SYNJ2.Mask2.0.01  Mask2.0.01           NA
# 266698     7  103374399      SLC26A5.Mask1.0.01  Mask1.0.01           NA
# 266703     7  103374399      SLC26A5.Mask2.0.01  Mask2.0.01           NA
# 271041     8  101492770        GRHL2.Mask1.0.01  Mask1.0.01           NA
# 283542    10   71439816        CDH23.Mask2.0.01  Mask2.0.01           NA
# 295090    11   77130577        MYO7A.Mask2.0.01  Mask2.0.01           NA
# 299844    11  121045662  TBCEL-TECTA.Mask1.0.01  Mask1.0.01           NA
# 299849    11  121045662  TBCEL-TECTA.Mask2.0.01  Mask2.0.01           NA
# 299909    11  121102653        TECTA.Mask1.0.01  Mask1.0.01           NA
# 299914    11  121102653        TECTA.Mask2.0.01  Mask2.0.01           NA
# 310684    12   43795589         TWF1.Mask1.0.01  Mask1.0.01           NA
# 312204    13   20188904         GJB2.Mask1.0.01  Mask1.0.01           NA
# 312209    13   20188904         GJB2.Mask2.0.01  Mask2.0.01           NA
# 318786    14   60646284         SIX1.Mask1.0.01  Mask1.0.01           NA
# 333495    17   81510690        ACTG1.Mask2.0.01  Mask2.0.01           NA
# 348388    19   44701457     CEACAM16.Mask2.0.01  Mask2.0.01           NA
# 353856    19   14053608        PALM3.Mask1.0.01  Mask1.0.01           NA
# 367070    21   42372764      TMPRSS3.Mask2.0.01  Mask2.0.01           NA
# 368906    22   50548069      KLHDC7B.Mask1.0.01  Mask1.0.01           NA
# 368911    22   50548069      KLHDC7B.Mask2.0.01  Mask2.0.01           NA
# 370891    22   40125762       TNRC6B.Mask1.0.01  Mask1.0.01           NA
#
#              TEST BETA_f3393 SE_f3393 LOG10P_f3393 A1FREQ_f2247  ... SE_f2257  \
# 3401    ADD-SKATO         NA       NA      2.95336           NA  ...       NA
# 5474    ADD-SKATO         NA       NA      3.80124           NA  ...       NA
# 8045    ADD-SKATO         NA       NA      8.86184           NA  ...       NA
# 221522  ADD-SKATO         NA       NA     0.072506           NA  ...       NA
# 221527  ADD-SKATO         NA       NA     0.119361           NA  ...       NA
# 231749  ADD-SKATO         NA       NA      4.08784           NA  ...       NA
# 247669  ADD-SKATO         NA       NA      40.8393           NA  ...       NA
# 247922  ADD-SKATO         NA       NA      7.95054           NA  ...       NA
# 252748  ADD-SKATO         NA       NA      12.8761           NA  ...       NA
# 252753  ADD-SKATO         NA       NA      5.69813           NA  ...       NA
# 255942  ADD-SKATO         NA       NA      23.4079           NA  ...       NA
# 255947  ADD-SKATO         NA       NA      12.1511           NA  ...       NA
# 258712  ADD-SKATO         NA       NA      8.20999           NA  ...       NA
# 266698  ADD-SKATO         NA       NA      5.37368           NA  ...       NA
# 266703  ADD-SKATO         NA       NA      8.78781           NA  ...       NA
# 271041  ADD-SKATO         NA       NA      11.6759           NA  ...       NA
# 283542  ADD-SKATO         NA       NA      9.35013           NA  ...       NA
# 295090  ADD-SKATO         NA       NA      4.83255           NA  ...       NA
# 299844  ADD-SKATO         NA       NA      9.16692           NA  ...       NA
# 299849  ADD-SKATO         NA       NA      5.08519           NA  ...       NA
# 299909  ADD-SKATO         NA       NA      9.54577           NA  ...       NA
# 299914  ADD-SKATO         NA       NA      4.91484           NA  ...       NA
# 310684  ADD-SKATO         NA       NA      7.82178           NA  ...       NA
# 312204  ADD-SKATO         NA       NA       3.4884           NA  ...       NA
# 312209  ADD-SKATO         NA       NA       3.2611           NA  ...       NA
# 318786  ADD-SKATO         NA       NA      5.10977           NA  ...       NA
# 333495  ADD-SKATO         NA       NA      8.97582           NA  ...       NA
# 348388  ADD-SKATO         NA       NA      8.33145           NA  ...       NA
# 353856  ADD-SKATO         NA       NA       6.8589           NA  ...       NA
# 367070  ADD-SKATO         NA       NA      6.37795           NA  ...       NA
# 368906  ADD-SKATO         NA       NA      14.2206           NA  ...       NA
# 368911  ADD-SKATO         NA       NA      6.56347           NA  ...       NA
# 370891  ADD-SKATO         NA       NA      5.70498           NA  ...       NA
#
#        LOG10P_f2257 A1FREQ_f2247_f2257 BETA_f2247_f2257 SE_f2247_f2257  \
# 3401        3.95672                 NA               NA             NA
# 5474         4.5813                 NA               NA             NA
# 8045        4.18083                 NA               NA             NA
# 333495            4.60063  1.057256e-09  9.140922e-05  5.617072e-03
# 348388            13.4349  4.661761e-09  2.058733e-13  1.171089e-07
# 353856            4.60292  1.383885e-07  2.581844e-04  1.728144e-03
# 367070            5.22647  4.188418e-07  1.334259e-06  3.593602e-04
# 368906            28.4811  6.017277e-15  3.401731e-29  7.932316e-20
# 368911            11.8437  2.732310e-07  5.037325e-11  1.069572e-10
# 370891            2.89455  1.972514e-06  5.505921e-03  2.640098e-02
#
#        P_f2247_f2257
# 3401    1.967297e-07
# 5474    9.680103e-07
# 8045    1.044816e-06
# 221522  1.488847e-06
# 221527  1.777911e-06
# 231749  4.980352e-09
# 247669  5.242036e-64
# 247922  5.084755e-05
# 252748  3.362637e-04
# 252753  1.955897e-01
# 255942  7.540497e-11
# 255947  9.568195e-08
# 258712  2.914070e-13
# 266698  2.072049e-12
# 266703  9.831052e-20
# 271041  9.330609e-05
# 283542  3.077514e-11
# 295090  3.514229e-07
# 299844  4.509205e-14
# 299849  3.582531e-07
# 299909  1.749041e-13
# 299914  7.498597e-07
# 310684  2.441406e-06
# 312204  7.005030e-09
# 312209  6.039486e-12
# 318786  1.281681e-07
# 333495  2.508245e-05
# 348388  3.673669e-14
# 353856  2.495054e-05
# 367070  5.936494e-06
# 368906  3.302935e-29
# 368911  1.433178e-12
# 370891  1.274823e-03
#
# [33 rows x 25 columns]

# %%
skato_result['CHROM'] = skato_result['CHROM'].astype(int)
skato_result['GENPOS'] = skato_result['GENPOS'].astype(int)

# %%
skato_result = skato_result.sort_values(by=['CHROM', 'GENPOS'], ascending=[True, True])

# %%
skato_result
# Out:
#         CHROM     GENPOS                      ID     ALLELE1 A1FREQ_f3393  \
# 5474        1   11648706        FBXO2.Mask2.0.01  Mask2.0.01           NA
# 8045        1   40784099        KCNQ4.Mask2.0.01  Mask2.0.01           NA
# 3401        1  102878022      COL11A1.Mask1.0.01  Mask1.0.01           NA
# 221522      2  178432096        PRKRA.Mask1.0.01  Mask1.0.01           NA
# 221527      2  178432096        PRKRA.Mask2.0.01  Mask2.0.01           NA
# 231749      3  142664192         PLS1.Mask1.0.01  Mask1.0.01           NA
# 247669      5     271691        PDCD6.Mask2.0.01  Mask2.0.01           NA
# 247922      5  146339116       POU4F3.Mask1.0.01  Mask1.0.01           NA
# 255942      6   75817495         MYO6.Mask1.0.01  Mask1.0.01           NA
# 255947      6   75817495         MYO6.Mask2.0.01  Mask2.0.01           NA
# 252748      6  133274701         EYA4.Mask1.0.01  Mask1.0.01           NA
# 252753      6  133274701         EYA4.Mask2.0.01  Mask2.0.01           NA
# 258712      6  157981963        SYNJ2.Mask2.0.01  Mask2.0.01           NA
# 266698      7  103374399      SLC26A5.Mask1.0.01  Mask1.0.01           NA
# 266703      7  103374399      SLC26A5.Mask2.0.01  Mask2.0.01           NA
# 271041      8  101492770        GRHL2.Mask1.0.01  Mask1.0.01           NA
# 283542     10   71439816        CDH23.Mask2.0.01  Mask2.0.01           NA
# 295090     11   77130577        MYO7A.Mask2.0.01  Mask2.0.01           NA
# 299844     11  121045662  TBCEL-TECTA.Mask1.0.01  Mask1.0.01           NA
# 299849     11  121045662  TBCEL-TECTA.Mask2.0.01  Mask2.0.01           NA
# 299909     11  121102653        TECTA.Mask1.0.01  Mask1.0.01           NA
# 299914     11  121102653        TECTA.Mask2.0.01  Mask2.0.01           NA
# 310684     12   43795589         TWF1.Mask1.0.01  Mask1.0.01           NA
# 312204     13   20188904         GJB2.Mask1.0.01  Mask1.0.01           NA
# 312209     13   20188904         GJB2.Mask2.0.01  Mask2.0.01           NA
# 318786     14   60646284         SIX1.Mask1.0.01  Mask1.0.01           NA
# 333495     17   81510690        ACTG1.Mask2.0.01  Mask2.0.01           NA
# 353856     19   14053608        PALM3.Mask1.0.01  Mask1.0.01           NA
# 348388     19   44701457     CEACAM16.Mask2.0.01  Mask2.0.01           NA
# 367070     21   42372764      TMPRSS3.Mask2.0.01  Mask2.0.01           NA
# 370891     22   40125762       TNRC6B.Mask1.0.01  Mask1.0.01           NA
# 368906     22   50548069      KLHDC7B.Mask1.0.01  Mask1.0.01           NA
# 368911     22   50548069      KLHDC7B.Mask2.0.01  Mask2.0.01           NA
#
#              TEST BETA_f3393 SE_f3393 LOG10P_f3393 A1FREQ_f2247  ... SE_f2257  \
# 5474    ADD-SKATO         NA       NA      3.80124           NA  ...       NA
# 8045    ADD-SKATO         NA       NA      8.86184           NA  ...       NA
# 3401    ADD-SKATO         NA       NA      2.95336           NA  ...       NA
# 221522  ADD-SKATO         NA       NA     0.072506           NA  ...       NA
# 221527  ADD-SKATO         NA       NA     0.119361           NA  ...       NA
# 231749  ADD-SKATO         NA       NA      4.08784           NA  ...       NA
# 247669  ADD-SKATO         NA       NA      40.8393           NA  ...       NA
# 247922  ADD-SKATO         NA       NA      7.95054           NA  ...       NA
# 255942  ADD-SKATO         NA       NA      23.4079           NA  ...       NA
# 255947  ADD-SKATO         NA       NA      12.1511           NA  ...       NA
# 252748  ADD-SKATO         NA       NA      12.8761           NA  ...       NA
# 252753  ADD-SKATO         NA       NA      5.69813           NA  ...       NA
# 258712  ADD-SKATO         NA       NA      8.20999           NA  ...       NA
# 266698  ADD-SKATO         NA       NA      5.37368           NA  ...       NA
# 266703  ADD-SKATO         NA       NA      8.78781           NA  ...       NA
# 271041  ADD-SKATO         NA       NA      11.6759           NA  ...       NA
# 283542  ADD-SKATO         NA       NA      9.35013           NA  ...       NA
# 295090  ADD-SKATO         NA       NA      4.83255           NA  ...       NA
# 299844  ADD-SKATO         NA       NA      9.16692           NA  ...       NA
# 299849  ADD-SKATO         NA       NA      5.08519           NA  ...       NA
# 299909  ADD-SKATO         NA       NA      9.54577           NA  ...       NA
# 299914  ADD-SKATO         NA       NA      4.91484           NA  ...       NA
# 310684  ADD-SKATO         NA       NA      7.82178           NA  ...       NA
# 312204  ADD-SKATO         NA       NA       3.4884           NA  ...       NA
# 312209  ADD-SKATO         NA       NA       3.2611           NA  ...       NA
# 318786  ADD-SKATO         NA       NA      5.10977           NA  ...       NA
# 333495  ADD-SKATO         NA       NA      8.97582           NA  ...       NA
# 353856  ADD-SKATO         NA       NA       6.8589           NA  ...       NA
# 348388  ADD-SKATO         NA       NA      8.33145           NA  ...       NA
# 367070  ADD-SKATO         NA       NA      6.37795           NA  ...       NA
# 370891  ADD-SKATO         NA       NA      5.70498           NA  ...       NA
# 368906  ADD-SKATO         NA       NA      14.2206           NA  ...       NA
# 368911  ADD-SKATO         NA       NA      6.56347           NA  ...       NA
#
#        LOG10P_f2257 A1FREQ_f2247_f2257 BETA_f2247_f2257 SE_f2247_f2257  \
# 5474         4.5813                 NA               NA             NA
# 8045        4.18083                 NA               NA             NA
# 3401        3.95672                 NA               NA             NA
# 221522      1.61591                 NA               NA             NA
# 221527      1.51689                 NA               NA             NA
# 231749      5.40881                 NA               NA             NA
# 247669      41.6218                 NA               NA             NA
# 247922      3.54282                 NA               NA             NA
# 255942      6.16254                 NA               NA             NA
# 255947      4.12317                 NA               NA             NA
# 252748      1.89524                 NA               NA             NA
# 252753     0.541309                 NA               NA             NA
# 258712      7.64343                 NA               NA             NA
# 266698      7.68818                 NA               NA             NA
# 266703      12.9971                 NA               NA             NA
# 271041      2.11698                 NA               NA             NA
# 283542      6.90515                 NA               NA             NA
# 295090      4.28428                 NA               NA             NA
# 299844      10.5238                 NA               NA             NA
# 299849       2.8911                 NA               NA             NA
# 299909      10.1752                 NA               NA             NA
# 299914      2.77601                 NA               NA             NA
# 310684      3.72197                 NA               NA             NA
# 312204      7.32654                 NA               NA             NA
# 312209      9.17176                 NA               NA             NA
# 318786      5.27708                 NA               NA             NA
# 333495      2.25049                 NA               NA             NA
# 353856      2.76242                 NA               NA             NA
# 348388      6.93141                 NA               NA             NA
# 367070      3.44447                 NA               NA             NA
# 370891      1.57838                 NA               NA             NA
# 368906      19.1006                 NA               NA             NA
# 368911      9.97079                 NA               NA             NA
#
#        LOG10P_f2247_f2257       P_f3393       P_f2247       P_f2257  \
# 5474              6.01412  1.580374e-04  2.193764e-06  2.622406e-05
# 8045              5.98096  1.374548e-09  8.312085e-06  6.594320e-05
# 3401              6.70613  1.113371e-03  1.516282e-07  1.104791e-04
# 221522            5.82715  8.462403e-01  2.801302e-05  2.421531e-02
# 221527            5.75009  7.596945e-01  3.974935e-05  3.041655e-02
# 231749            8.30274  8.168833e-05  1.483064e-07  3.901126e-06
# 247669            63.2805  1.447771e-41  7.462769e-62  2.388911e-42
# 247922            4.29373  1.120624e-08  9.758656e-05  2.865365e-04
# 255942            10.1226  3.909309e-24  6.028233e-10  6.877966e-07
# 255947            7.01917  7.061549e-13  1.546215e-07  7.530607e-05
# 252748            3.47332  1.330148e-13  4.835262e-04  1.272800e-02
# 252753           0.708654  2.003872e-06  5.767133e-02  2.875352e-01
# 258712            12.5355  6.166092e-09  7.636599e-15  2.272846e-08
# 266698            11.6836  4.229802e-06  1.409613e-12  2.050312e-08
# 266703            19.0074  1.630009e-09  8.871560e-19  1.006700e-13
# 271041            4.03009  2.109114e-12  2.414960e-04  7.638710e-03
# 283542            10.5118  4.465499e-10  8.590135e-11  1.244085e-07
# 295090            6.45417  1.470449e-05  1.876333e-06  5.196609e-05
# 299844            13.3459  6.808948e-10  1.755092e-14  2.993643e-11
# 299849            6.44581  8.218830e-06  3.342951e-06  1.284991e-03
# 299909            12.7572  2.845968e-10  4.837266e-14  6.680362e-11
# 299914            6.12502  1.216634e-05  6.864043e-06  1.674904e-03
# 310684            5.61236  1.507370e-08  4.170038e-06  1.896837e-04
# 312204            8.15459  3.247880e-04  1.355252e-09  4.714764e-08
# 312209             11.219  5.481507e-04  1.136842e-11  6.733487e-10
# 318786            6.89222  7.766583e-06  9.829241e-08  5.283479e-06
# 333495            4.60063  1.057256e-09  9.140922e-05  5.617072e-03
# 353856            4.60292  1.383885e-07  2.581844e-04  1.728144e-03
# 348388            13.4349  4.661761e-09  2.058733e-13  1.171089e-07
# 367070            5.22647  4.188418e-07  1.334259e-06  3.593602e-04
# 370891            2.89455  1.972514e-06  5.505921e-03  2.640098e-02
# 368906            28.4811  6.017277e-15  3.401731e-29  7.932316e-20
# 368911            11.8437  2.732310e-07  5.037325e-11  1.069572e-10
#
#        P_f2247_f2257
# 5474    9.680103e-07
# 8045    1.044816e-06
# 3401    1.967297e-07
# 221522  1.488847e-06
# 221527  1.777911e-06
# 231749  4.980352e-09
# 247669  5.242036e-64
# 247922  5.084755e-05
# 255942  7.540497e-11
# 255947  9.568195e-08
# 252748  3.362637e-04
# 252753  1.955897e-01
# 258712  2.914070e-13
# 266698  2.072049e-12
# 266703  9.831052e-20
# 271041  9.330609e-05
# 283542  3.077514e-11
# 295090  3.514229e-07
# 299844  4.509205e-14
# 299849  3.582531e-07
# 299909  1.749041e-13
# 299914  7.498597e-07
# 310684  2.441406e-06
# 312204  7.005030e-09
# 312209  6.039486e-12
# 318786  1.281681e-07
# 333495  2.508245e-05
# 353856  2.495054e-05
# 348388  3.673669e-14
# 367070  5.936494e-06
# 370891  1.274823e-03
# 368906  3.302935e-29
# 368911  1.433178e-12
#
# [33 rows x 25 columns]

# %%
for allele, group in skato_result.groupby('ALLELE1'):
    # Define the filename using the 'ALLELE1' name
    filename = f'/home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD_{allele}_output.csv'
    
    # Save the group to the CSV file
    group.to_csv(filename, index=False, header=True)

    print(f'Saved group with ALLELE1="{allele}" to {filename}')
# Out:
# Saved group with ALLELE1="Mask1.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD_Mask1.0.01_output.csv
# Saved group with ALLELE1="Mask2.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD_Mask2.0.01_output.csv

# %%
burden_result = merged_df.loc[(merged_df['TEST'] == 'ADD')  & ((merged_df['P_f3393'] <= 2.5e-06) | (merged_df['P_f2247'] <= 2.5e-06) | (merged_df['P_f2257'] <= 2.5e-06) | (merged_df['P_f2247_f2257'] <= 2.5e-06))]

# %%
burden_result['CHROM'] = burden_result['CHROM'].astype(int)
burden_result['GENPOS'] = burden_result['GENPOS'].astype(int)

# %%
burden_result = burden_result.sort_values(by=['CHROM', 'GENPOS'], ascending=[True, True])

# %%
burden_result
# Out:
#         CHROM     GENPOS                       ID          ALLELE1  \
# 5472        1   11648706        FBXO2.Mask2.0.005      Mask2.0.005
# 5475        1   11648706         FBXO2.Mask2.0.01       Mask2.0.01
# 8043        1   40784099        KCNQ4.Mask2.0.005      Mask2.0.005
# 8046        1   40784099         KCNQ4.Mask2.0.01       Mask2.0.01
# 221520      2  178432096        PRKRA.Mask1.0.005      Mask1.0.005
# 221523      2  178432096         PRKRA.Mask1.0.01       Mask1.0.01
# 231747      3  142664192         PLS1.Mask1.0.005      Mask1.0.005
# 231750      3  142664192          PLS1.Mask1.0.01       Mask1.0.01
# 247667      5     271691        PDCD6.Mask2.0.005      Mask2.0.005
# 247670      5     271691         PDCD6.Mask2.0.01       Mask2.0.01
# 247919      5  146339116   POU4F3.Mask1.singleton  Mask1.singleton
# 247920      5  146339116       POU4F3.Mask1.0.005      Mask1.0.005
# 247923      5  146339116        POU4F3.Mask1.0.01       Mask1.0.01
# 247924      5  146339116   POU4F3.Mask2.singleton  Mask2.singleton
# 255939      6   75817495     MYO6.Mask1.singleton  Mask1.singleton
# 255940      6   75817495         MYO6.Mask1.0.005      Mask1.0.005
# 255943      6   75817495          MYO6.Mask1.0.01       Mask1.0.01
# 255944      6   75817495     MYO6.Mask2.singleton  Mask2.singleton
# 255945      6   75817495         MYO6.Mask2.0.005      Mask2.0.005
# 255948      6   75817495          MYO6.Mask2.0.01       Mask2.0.01
# 252745      6  133274701     EYA4.Mask1.singleton  Mask1.singleton
# 252746      6  133274701         EYA4.Mask1.0.005      Mask1.0.005
# 252749      6  133274701          EYA4.Mask1.0.01       Mask1.0.01
# 266696      7  103374399      SLC26A5.Mask1.0.005      Mask1.0.005
# 266699      7  103374399       SLC26A5.Mask1.0.01       Mask1.0.01
# 266701      7  103374399      SLC26A5.Mask2.0.005      Mask2.0.005
# 266704      7  103374399       SLC26A5.Mask2.0.01       Mask2.0.01
# 271038      8  101492770    GRHL2.Mask1.singleton  Mask1.singleton
# 271039      8  101492770        GRHL2.Mask1.0.005      Mask1.0.005
# 271042      8  101492770         GRHL2.Mask1.0.01       Mask1.0.01
# 271043      8  101492770    GRHL2.Mask2.singleton  Mask2.singleton
# 299842     11  121045662  TBCEL-TECTA.Mask1.0.005      Mask1.0.005
# 299845     11  121045662   TBCEL-TECTA.Mask1.0.01       Mask1.0.01
# 299847     11  121045662  TBCEL-TECTA.Mask2.0.005      Mask2.0.005
# 299907     11  121102653        TECTA.Mask1.0.005      Mask1.0.005
# 299910     11  121102653         TECTA.Mask1.0.01       Mask1.0.01
# 299912     11  121102653        TECTA.Mask2.0.005      Mask2.0.005
# 310682     12   43795589         TWF1.Mask1.0.005      Mask1.0.005
# 310685     12   43795589          TWF1.Mask1.0.01       Mask1.0.01
# 312205     13   20188904          GJB2.Mask1.0.01       Mask1.0.01
# 312210     13   20188904          GJB2.Mask2.0.01       Mask2.0.01
# 333492     17   81510690    ACTG1.Mask2.singleton  Mask2.singleton
# 333493     17   81510690        ACTG1.Mask2.0.005      Mask2.0.005
# 333496     17   81510690         ACTG1.Mask2.0.01       Mask2.0.01
# 353854     19   14053608        PALM3.Mask1.0.005      Mask1.0.005
# 353857     19   14053608         PALM3.Mask1.0.01       Mask1.0.01
# 348386     19   44701457     CEACAM16.Mask2.0.005      Mask2.0.005
# 348389     19   44701457      CEACAM16.Mask2.0.01       Mask2.0.01
# 368904     22   50548069      KLHDC7B.Mask1.0.005      Mask1.0.005
# 368907     22   50548069       KLHDC7B.Mask1.0.01       Mask1.0.01
# 368909     22   50548069      KLHDC7B.Mask2.0.005      Mask2.0.005
# 368912     22   50548069       KLHDC7B.Mask2.0.01       Mask2.0.01
#
#        A1FREQ_f3393 TEST BETA_f3393   SE_f3393 LOG10P_f3393 A1FREQ_f2247  ...  \
# 5472      0.0015219  ADD   0.534273   0.130861      3.96663   0.00163018  ...
# 5475      0.0015219  ADD   0.534273   0.130861      3.96663   0.00163018  ...
# 8043     0.00329222  ADD   0.534572   0.089837      7.73459   0.00337572  ...
# 8046     0.00329222  ADD   0.534572   0.089837      7.73459   0.00337572  ...
# 221520    0.0133171  ADD  0.0229401  0.0511612     0.184507    0.0137063  ...
# 221523    0.0133171  ADD  0.0229401  0.0511612     0.184507    0.0137063  ...
# 231747  0.000413354  ADD   0.965209   0.226192      4.07867  0.000481162  ...
# 231750  0.000413354  ADD   0.965209   0.226192      4.07867  0.000481162  ...
# 247667   0.00341748  ADD   0.995987  0.0760999      32.5429   0.00383715  ...
# 247670   0.00341748  ADD   0.995987  0.0760999      32.5429   0.00383715  ...
# 247919  1.04382e-05  ADD    6.30714    1.72473      7.95054   1.0625e-05  ...
# 247920  1.04382e-05  ADD    6.30714    1.72473      7.95054   1.0625e-05  ...
# 247923  1.04382e-05  ADD    6.30714    1.72473      7.95054   1.0625e-05  ...
# 247924  0.000121084  ADD     2.3156   0.320975      10.0207  0.000100179  ...
# 255939  5.42788e-05  ADD    3.61081    0.47877      13.3489  4.70537e-05  ...
# 255940  0.000578278  ADD    1.57223   0.162917      17.1656  0.000591966  ...
# 255943  0.000578278  ADD    1.57223   0.162917      17.1656  0.000591966  ...
# 255944  0.000473896  ADD    1.43681   0.188216      11.0787  0.000367322  ...
# 255945   0.00750509  ADD   0.456442   0.061229      11.9394   0.00768645  ...
# 255948    0.0131438  ADD   0.325421  0.0482793      10.1429    0.0133405  ...
# 252745  3.75777e-05  ADD    3.31162   0.562007      7.49779    2.125e-05  ...
# 252746  0.000135697  ADD     2.3633    0.30719      11.4206  0.000133572  ...
# 252749  0.000135697  ADD     2.3633    0.30719      11.4206  0.000133572  ...
# 266696  0.000123171  ADD    1.71399   0.337689      5.37368  0.000180625  ...
# 266699  0.000123171  ADD    1.71399   0.337689      5.37368  0.000180625  ...
# 266701   0.00798317  ADD   0.374975  0.0603349      8.64642   0.00842413  ...
# 266704   0.00798317  ADD   0.374975  0.0603349      8.64642   0.00842413  ...
# 271038  2.71394e-05  ADD    4.33901   0.671747      11.6664  1.66965e-05  ...
# 271039  3.96653e-05  ADD    3.87147   0.522081      11.6759  3.64287e-05  ...
# 266701  3.789658e-13  5.040806e-19
# 266704  3.789658e-13  5.040806e-19
# 271038  5.186209e-03  1.592172e-04
# 271039  7.638710e-03  9.330609e-05
# 271042  7.638710e-03  9.330609e-05
# 271043  4.035525e-02  4.951537e-02
# 299842  3.415073e-12  4.963637e-15
# 299845  3.415073e-12  4.963637e-15
# 299847  9.767648e-04  2.192452e-08
# 299907  7.803690e-12  1.931524e-14
# 299910  7.803690e-12  1.931524e-14
# 299912  2.686767e-04  1.074385e-08
# 310682  1.617074e-04  2.045502e-06
# 310685  1.617074e-04  2.045502e-06
# 312205  4.673261e-08  8.646294e-09
# 312210  2.160827e-09  3.147024e-11
# 333492  2.349254e-03  5.165591e-05
# 333493  1.732527e-02  1.609756e-04
# 333496  1.732527e-02  1.609756e-04
# 353854  1.728144e-03  2.495054e-05
# 353857  1.728144e-03  2.495054e-05
# 348386  2.230848e-06  2.164213e-12
# 348389  2.230848e-06  2.164213e-12
# 368904  1.675329e-20  5.061742e-30
# 368907  1.675329e-20  5.061742e-30
# 368909  2.217992e-10  6.625215e-12
# 368912  2.217992e-10  6.625215e-12
#
# [52 rows x 25 columns]

# %%
for allele, group in burden_result.groupby('ALLELE1'):
    # Define the filename using the 'ALLELE1' name
    filename = f'/home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_{allele}_output.csv'
    
    # Save the group to the CSV file
    group.to_csv(filename, index=False, header=True)

    print(f'Saved group with ALLELE1="{allele}" to {filename}')
# Out:
# Saved group with ALLELE1="Mask1.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.0.005_output.csv
# Saved group with ALLELE1="Mask1.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.0.01_output.csv
# Saved group with ALLELE1="Mask1.singleton" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.singleton_output.csv
# Saved group with ALLELE1="Mask2.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.0.005_output.csv
# Saved group with ALLELE1="Mask2.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.0.01_output.csv
# Saved group with ALLELE1="Mask2.singleton" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.singleton_output.csv

# %% [markdown]
# ## Now do it for the SKATO 0.005

# %%
~/UKBiobank/RAP/results/autosomal/aggregate/Haid_CADD/

# %%
# Read the four files
df1 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Haid_CADD_skato_0.005/f3393.regenie', comment='#', sep=" ")
df2 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hdiff_CADD_skato_0.005/f2247.regenie',comment='#', sep=" ")
df3 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hnoise_CADD_skato_0.005/f2257.regenie',comment='#', sep=" ")
df4 = pd.read_csv('~/UKBiobank/RAP/results/autosomal/aggregate/Hboth_CADD_skato_0.005/f2247_f2257.regenie',comment='#', sep=" ")

# %%
# Select required columns for each phenotype
df1_selected = df1[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df2_selected = df2[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df3_selected = df3[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]
df4_selected = df4[['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ', 'TEST', 'BETA', 'SE', 'LOG10P']]

# %%
# Rename columns to include the phenotype name
df1_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f3393','TEST', 'BETA_f3393', 'SE_f3393', 'LOG10P_f3393']
df2_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2247','TEST', 'BETA_f2247', 'SE_f2247', 'LOG10P_f2247']
df3_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2257','TEST', 'BETA_f2257', 'SE_f2257', 'LOG10P_f2257']
df4_selected.columns = ['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'A1FREQ_f2247_f2257', 'TEST', 'BETA_f2247_f2257', 'SE_f2247_f2257', 'LOG10P_f2247_f2257']

# %%
# Merge dataframes on common columns (CHROM and GENPOS)
merged_df = pd.merge(df1_selected, df2_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')
merged_df = pd.merge(merged_df, df3_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')
merged_df = pd.merge(merged_df, df4_selected, on=['CHROM', 'GENPOS', 'ID', 'ALLELE1', 'TEST'], how='outer')

# %%
merged_df
# Out:
#        CHROM    GENPOS                         ID          ALLELE1  \
# 0          1  33306769    A3GALT2.Mask1.singleton  Mask1.singleton
# 1          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 2          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 3          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 4          1  33306769    A3GALT2.Mask2.singleton  Mask2.singleton
# ...      ...       ...                        ...              ...
# 337945    11  71582370  KRTAP5-11.Mask2.singleton  Mask2.singleton
# 337946    14  22575049       DAD1.Mask1.singleton  Mask1.singleton
# 337947    16  48361588      SIAH1.Mask1.singleton  Mask1.singleton
# 337948    17   7481519    SLC35G6.Mask1.singleton  Mask1.singleton
# 337949    19  48030561      CABP5.Mask1.singleton  Mask1.singleton
#
#        A1FREQ_f3393       TEST BETA_f3393  SE_f3393 LOG10P_f3393 A1FREQ_f2247  \
# 0       1.25259e-05        ADD   -1.14905   1.65401     0.312259  1.21429e-05
# 1               NaN   ADD-SKAT        NaN       NaN     0.884134          NaN
# 2               NaN  ADD-SKATO        NaN       NaN      1.15877          NaN
# 3       0.000265131        ADD   0.647419  0.301917      1.36031  0.000267143
# 4       0.000127347        ADD  -0.835586  0.555621     0.877416   0.00010625
# ...             ...        ...        ...       ...          ...          ...
# 337945          NaN        ADD        NaN       NaN          NaN          NaN
# 337946          NaN        ADD        NaN       NaN          NaN          NaN
# 337947          NaN        ADD        NaN       NaN          NaN          NaN
# 337948          NaN        ADD        NaN       NaN          NaN          NaN
# 337949          NaN        ADD        NaN       NaN          NaN          NaN
#
#         ...  SE_f2247 LOG10P_f2247 A1FREQ_f2257   BETA_f2257  SE_f2257  \
# 0       ...  0.760633    0.0957525  1.72188e-05     0.609199  0.572847
# 1       ...       NaN     0.994283          NaN          NaN       NaN
# 2       ...       NaN     0.795937          NaN          NaN       NaN
# 3       ...  0.166358     0.733251  0.000271527     0.178833  0.144475
# 4       ...  0.263772    0.0160562  0.000105962  -0.00753251  0.231717
# ...     ...       ...          ...          ...          ...       ...
# 337945  ...       NaN          NaN          NaN          NaN       NaN
# 337946  ...       NaN          NaN          NaN          NaN       NaN
# 337947  ...       NaN          NaN          NaN          NaN       NaN
# 337948  ...       NaN          NaN          NaN          NaN       NaN
# 337949  ...       NaN          NaN          NaN          NaN       NaN
#
#        LOG10P_f2257 A1FREQ_f2247_f2257 BETA_f2247_f2257 SE_f2247_f2257  \
# 0           0.54125         1.4366e-05         0.243349       0.748279
# 1           1.32189                NaN              NaN            NaN
# 2           1.10832                NaN              NaN            NaN
# 3          0.665978        0.000260185         0.152691       0.178964
# 4          0.011411         0.00011014        -0.194088       0.272825
# ...             ...                ...              ...            ...
# 337945          NaN        7.98113e-06         0.509823        1.00098
# 337946          NaN        7.98113e-06          1.32459       0.979513
# 337947          NaN        7.98113e-06        -0.220062        1.05555
# 337948          NaN        7.98113e-06         0.474355        1.00001
# 337949          NaN        7.98113e-06          0.59386        1.02471
#
#        LOG10P_f2247_f2257
# 0                0.127832
# 1                 1.03021
# 2                0.827662
# 3                0.404998
# 4                0.321631
# ...                   ...
# 337945           0.214297
# 337946           0.753794
# 337947          0.0783897
# 337948           0.197056
# 337949           0.250089
#
# [337950 rows x 21 columns]

# %%
merged_df[['LOG10P_f3393', 'LOG10P_f2247', 'LOG10P_f2257', 'LOG10P_f2247_f2257']] = merged_df[['LOG10P_f3393', 'LOG10P_f2247', 'LOG10P_f2257', 'LOG10P_f2247_f2257']].apply(pd.to_numeric, errors='coerce')

# %%
merged_df[['P_f3393', 'P_f2247', 'P_f2257', 'P_f2247_f2257']] = 10 ** -merged_df[['LOG10P_f3393', 'LOG10P_f2247', 'LOG10P_f2257', 'LOG10P_f2247_f2257']]

# %%
merged_df
# Out:
#        CHROM    GENPOS                         ID          ALLELE1  \
# 0          1  33306769    A3GALT2.Mask1.singleton  Mask1.singleton
# 1          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 2          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 3          1  33306769        A3GALT2.Mask1.0.005      Mask1.0.005
# 4          1  33306769    A3GALT2.Mask2.singleton  Mask2.singleton
# ...      ...       ...                        ...              ...
# 337945    11  71582370  KRTAP5-11.Mask2.singleton  Mask2.singleton
# 337946    14  22575049       DAD1.Mask1.singleton  Mask1.singleton
# 337947    16  48361588      SIAH1.Mask1.singleton  Mask1.singleton
# 337948    17   7481519    SLC35G6.Mask1.singleton  Mask1.singleton
# 337949    19  48030561      CABP5.Mask1.singleton  Mask1.singleton
#
#        A1FREQ_f3393       TEST BETA_f3393  SE_f3393  LOG10P_f3393  \
# 0       1.25259e-05        ADD   -1.14905   1.65401      0.312259
# 1               NaN   ADD-SKAT        NaN       NaN      0.884134
# 2               NaN  ADD-SKATO        NaN       NaN      1.158770
# 3       0.000265131        ADD   0.647419  0.301917      1.360310
# 4       0.000127347        ADD  -0.835586  0.555621      0.877416
# ...             ...        ...        ...       ...           ...
# 337945          NaN        ADD        NaN       NaN           NaN
# 337946          NaN        ADD        NaN       NaN           NaN
# 337947          NaN        ADD        NaN       NaN           NaN
# 337948          NaN        ADD        NaN       NaN           NaN
# 337949          NaN        ADD        NaN       NaN           NaN
#
#        A1FREQ_f2247  ...  SE_f2257 LOG10P_f2257  A1FREQ_f2247_f2257  \
# 0       1.21429e-05  ...  0.572847     0.541250          1.4366e-05
# 1               NaN  ...       NaN     1.321890                 NaN
# 2               NaN  ...       NaN     1.108320                 NaN
# 3       0.000267143  ...  0.144475     0.665978         0.000260185
# 4        0.00010625  ...  0.231717     0.011411          0.00011014
# ...             ...  ...       ...          ...                 ...
# 337945          NaN  ...       NaN          NaN         7.98113e-06
# 337946          NaN  ...       NaN          NaN         7.98113e-06
# 337947          NaN  ...       NaN          NaN         7.98113e-06
# 337948          NaN  ...       NaN          NaN         7.98113e-06
# 337949          NaN  ...       NaN          NaN         7.98113e-06
#
#        BETA_f2247_f2257 SE_f2247_f2257 LOG10P_f2247_f2257   P_f3393   P_f2247  \
# 0              0.243349       0.748279           0.127832  0.487238  0.802135
# 1                   NaN            NaN           1.030210  0.130577  0.101325
# 2                   NaN            NaN           0.827662  0.069379  0.159979
# 3              0.152691       0.178964           0.404998  0.043620  0.184820
# 4             -0.194088       0.272825           0.321631  0.132612  0.963704
# ...                 ...            ...                ...       ...       ...
# 337945         0.509823        1.00098           0.214297       NaN       NaN
# 337946          1.32459       0.979513           0.753794       NaN       NaN
# 337947        -0.220062        1.05555           0.078390       NaN       NaN
# 337948         0.474355        1.00001           0.197056       NaN       NaN
# 337949          0.59386        1.02471           0.250089       NaN       NaN
#
#          P_f2257 P_f2247_f2257
# 0       0.287574      0.745020
# 1       0.047655      0.093280
# 2       0.077926      0.148709
# 3       0.215785      0.393552
# 4       0.974067      0.476836
# ...          ...           ...
# 337945       NaN      0.610524
# 337946       NaN      0.176281
# 337947       NaN      0.834854
# 337948       NaN      0.635249
# 337949       NaN      0.562226
#
# [337950 rows x 25 columns]

# %%
# Ensure 'TEST' column is a string type
merged_df['TEST'] = merged_df['TEST'].astype(str)

# Ensure 'P_1', 'P_2', 'P_3', 'P_4' columns are numeric types
merged_df[['P_f3393', 'P_f2247', 'P_f2257', 'P_f2247_f2257']] = merged_df[['P_f3393', 'P_f2247', 'P_f2257', 'P_f2247_f2257']].apply(pd.to_numeric, errors='coerce')

# %%
skato_result = merged_df.loc[(merged_df['TEST'] == 'ADD-SKATO')  & ((merged_df['P_f3393'] <= 2.5e-06) | (merged_df['P_f2247'] <= 2.5e-06) | (merged_df['P_f2257'] <= 2.5e-06) | (merged_df['P_f2247_f2257'] <= 2.5e-06))]

# %%
skato_result
# Out:
#        CHROM     GENPOS                       ID      ALLELE1 A1FREQ_f3393  \
# 2711       1  102878022      COL11A1.Mask1.0.005  Mask1.0.005          NaN
# 4362       1   11648706        FBXO2.Mask2.0.005  Mask2.0.005          NaN
# 6409       1   40784099        KCNQ4.Mask2.0.005  Mask2.0.005          NaN
# 216012     2  178432096        PRKRA.Mask1.0.005  Mask1.0.005          NaN
# 216016     2  178432096        PRKRA.Mask2.0.005  Mask2.0.005          NaN
# 224165     3  142664192         PLS1.Mask1.0.005  Mask1.0.005          NaN
# 236847     5     271691        PDCD6.Mask2.0.005  Mask2.0.005          NaN
# 237049     5  146339116       POU4F3.Mask1.0.005  Mask1.0.005          NaN
# 240893     6  133274701         EYA4.Mask1.0.005  Mask1.0.005          NaN
# 240897     6  133274701         EYA4.Mask2.0.005  Mask2.0.005          NaN
# 243433     6   75817495         MYO6.Mask1.0.005  Mask1.0.005          NaN
# 243437     6   75817495         MYO6.Mask2.0.005  Mask2.0.005          NaN
# 251997     7  103374399      SLC26A5.Mask1.0.005  Mask1.0.005          NaN
# 252001     7  103374399      SLC26A5.Mask2.0.005  Mask2.0.005          NaN
# 255448     8  101492770        GRHL2.Mask1.0.005  Mask1.0.005          NaN
# 274595    11   77130577        MYO7A.Mask2.0.005  Mask2.0.005          NaN
# 278382    11  121045662  TBCEL-TECTA.Mask1.0.005  Mask1.0.005          NaN
# 278386    11  121045662  TBCEL-TECTA.Mask2.0.005  Mask2.0.005          NaN
# 278434    11  121102653        TECTA.Mask1.0.005  Mask1.0.005          NaN
# 278438    11  121102653        TECTA.Mask2.0.005  Mask2.0.005          NaN
# 287021    12   43795589         TWF1.Mask1.0.005  Mask1.0.005          NaN
# 293476    14   60646284         SIX1.Mask1.0.005  Mask1.0.005          NaN
# 305190    17   81510690        ACTG1.Mask2.0.005  Mask2.0.005          NaN
# 313206    17    6641083      TXNDC17.Mask2.0.005  Mask2.0.005          NaN
# 317042    19   44701457     CEACAM16.Mask2.0.005  Mask2.0.005          NaN
# 321395    19   14053608        PALM3.Mask1.0.005  Mask1.0.005          NaN
# 331914    21   42372764      TMPRSS3.Mask2.0.005  Mask2.0.005          NaN
# 333373    22   50548069      KLHDC7B.Mask1.0.005  Mask1.0.005          NaN
# 333377    22   50548069      KLHDC7B.Mask2.0.005  Mask2.0.005          NaN
# 334952    22   40125762       TNRC6B.Mask1.0.005  Mask1.0.005          NaN
#
#              TEST BETA_f3393 SE_f3393  LOG10P_f3393 A1FREQ_f2247  ...  \
# 2711    ADD-SKATO        NaN      NaN      2.953360          NaN  ...
# 4362    ADD-SKATO        NaN      NaN      3.801240          NaN  ...
# 6409    ADD-SKATO        NaN      NaN      8.861840          NaN  ...
# 216012  ADD-SKATO        NaN      NaN      0.072506          NaN  ...
# 216016  ADD-SKATO        NaN      NaN      0.119361          NaN  ...
# 224165  ADD-SKATO        NaN      NaN      4.087840          NaN  ...
# 236847  ADD-SKATO        NaN      NaN     40.839300          NaN  ...
# 237049  ADD-SKATO        NaN      NaN      7.950540          NaN  ...
# 240893  ADD-SKATO        NaN      NaN     12.876100          NaN  ...
# 240897  ADD-SKATO        NaN      NaN      5.698130          NaN  ...
# 243433  ADD-SKATO        NaN      NaN     23.407900          NaN  ...
# 243437  ADD-SKATO        NaN      NaN     17.518300          NaN  ...
# 251997  ADD-SKATO        NaN      NaN      5.373680          NaN  ...
# 252001  ADD-SKATO        NaN      NaN      8.787810          NaN  ...
# 255448  ADD-SKATO        NaN      NaN     11.675900          NaN  ...
# 274595  ADD-SKATO        NaN      NaN      4.832550          NaN  ...
# 278382  ADD-SKATO        NaN      NaN      9.166920          NaN  ...
# 278386  ADD-SKATO        NaN      NaN      8.820080          NaN  ...
# 278434  ADD-SKATO        NaN      NaN      9.545770          NaN  ...
# 278438  ADD-SKATO        NaN      NaN      8.828220          NaN  ...
# 287021  ADD-SKATO        NaN      NaN      7.821780          NaN  ...
# 293476  ADD-SKATO        NaN      NaN      5.109770          NaN  ...
# 305190  ADD-SKATO        NaN      NaN      8.975820          NaN  ...
# 313206  ADD-SKATO        NaN      NaN      1.829580          NaN  ...
# 317042  ADD-SKATO        NaN      NaN      8.331450          NaN  ...
# 321395  ADD-SKATO        NaN      NaN      6.858900          NaN  ...
# 331914  ADD-SKATO        NaN      NaN      6.377950          NaN  ...
# 333373  ADD-SKATO        NaN      NaN     14.220600          NaN  ...
# 333377  ADD-SKATO        NaN      NaN      6.563470          NaN  ...
# 334952  ADD-SKATO        NaN      NaN      5.704980          NaN  ...
#
#        SE_f2257 LOG10P_f2257  A1FREQ_f2247_f2257 BETA_f2247_f2257  \
# 2711        NaN     3.956720                 NaN              NaN
# 4362        NaN     4.581300                 NaN              NaN
# 6409        NaN     4.180830                 NaN              NaN
# 216012      NaN     1.615910                 NaN              NaN
# 216016      NaN     1.516890                 NaN              NaN
# 224165      NaN     5.408810                 NaN              NaN
# 236847      NaN    41.621800                 NaN              NaN
# 237049      NaN     3.542820                 NaN              NaN
# 240893      NaN     1.895240                 NaN              NaN
# 240897      NaN     0.541309                 NaN              NaN
# 243433      NaN     6.162540                 NaN              NaN
# 243437      NaN     5.863070                 NaN              NaN
# 251997      NaN     7.688180                 NaN              NaN
# 252001      NaN    12.997100                 NaN              NaN
# 255448      NaN     2.116980                 NaN              NaN
# 274595      NaN     4.284280                 NaN              NaN
# 278382      NaN    10.523800                 NaN              NaN
# 278386      NaN     5.428320                 NaN              NaN
# 278434      NaN    10.175200                 NaN              NaN
# 278438      NaN     5.289550                 NaN              NaN
# 287021      NaN     3.721970                 NaN              NaN
# 293476      NaN     5.277080                 NaN              NaN
# 305190      NaN     2.250490                 NaN              NaN
# 313206      NaN     3.595750                 NaN              NaN
# 317042      NaN     6.931410                 NaN              NaN
# 321395      NaN     2.762420                 NaN              NaN
# 331914      NaN     3.444470                 NaN              NaN
# 333373      NaN    19.100600                 NaN              NaN
# 333377      NaN     9.970790                 NaN              NaN
# 334952      NaN     1.578380                 NaN              NaN
#
#        SE_f2247_f2257 LOG10P_f2247_f2257       P_f3393       P_f2247  \
# 2711              NaN           6.706130  1.113371e-03  1.516282e-07
# 4362              NaN           6.014120  1.580374e-04  2.193764e-06
# 6409              NaN           5.980960  1.374548e-09  8.312085e-06
# 216012            NaN           5.827150  8.462403e-01  2.801302e-05
# 216016            NaN           5.750090  7.596945e-01  3.974935e-05
# 224165            NaN           8.302740  8.168833e-05  1.483064e-07
# 236847            NaN          63.280500  1.447771e-41  7.462769e-62
# 237049            NaN           4.293730  1.120624e-08  9.758656e-05
# 240893            NaN           3.473320  1.330148e-13  4.835262e-04
# 240897            NaN           0.708654  2.003872e-06  5.767133e-02
py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skato_result['GENPOS'] = skato_result['GENPOS'].astype(int)

# %%
skato_result = skato_result.sort_values(by=['CHROM', 'GENPOS'], ascending=[True, True])

# %%
skato_result
# Out:
#         CHROM     GENPOS                       ID      ALLELE1 A1FREQ_f3393  \
# 4362        1   11648706        FBXO2.Mask2.0.005  Mask2.0.005          NaN
# 6409        1   40784099        KCNQ4.Mask2.0.005  Mask2.0.005          NaN
# 2711        1  102878022      COL11A1.Mask1.0.005  Mask1.0.005          NaN
# 216012      2  178432096        PRKRA.Mask1.0.005  Mask1.0.005          NaN
# 216016      2  178432096        PRKRA.Mask2.0.005  Mask2.0.005          NaN
# 224165      3  142664192         PLS1.Mask1.0.005  Mask1.0.005          NaN
# 236847      5     271691        PDCD6.Mask2.0.005  Mask2.0.005          NaN
# 237049      5  146339116       POU4F3.Mask1.0.005  Mask1.0.005          NaN
# 243433      6   75817495         MYO6.Mask1.0.005  Mask1.0.005          NaN
# 243437      6   75817495         MYO6.Mask2.0.005  Mask2.0.005          NaN
# 240893      6  133274701         EYA4.Mask1.0.005  Mask1.0.005          NaN
# 240897      6  133274701         EYA4.Mask2.0.005  Mask2.0.005          NaN
# 251997      7  103374399      SLC26A5.Mask1.0.005  Mask1.0.005          NaN
# 252001      7  103374399      SLC26A5.Mask2.0.005  Mask2.0.005          NaN
# 255448      8  101492770        GRHL2.Mask1.0.005  Mask1.0.005          NaN
# 274595     11   77130577        MYO7A.Mask2.0.005  Mask2.0.005          NaN
# 278382     11  121045662  TBCEL-TECTA.Mask1.0.005  Mask1.0.005          NaN
# 278386     11  121045662  TBCEL-TECTA.Mask2.0.005  Mask2.0.005          NaN
# 278434     11  121102653        TECTA.Mask1.0.005  Mask1.0.005          NaN
# 278438     11  121102653        TECTA.Mask2.0.005  Mask2.0.005          NaN
# 287021     12   43795589         TWF1.Mask1.0.005  Mask1.0.005          NaN
# 293476     14   60646284         SIX1.Mask1.0.005  Mask1.0.005          NaN
# 313206     17    6641083      TXNDC17.Mask2.0.005  Mask2.0.005          NaN
# 305190     17   81510690        ACTG1.Mask2.0.005  Mask2.0.005          NaN
# 321395     19   14053608        PALM3.Mask1.0.005  Mask1.0.005          NaN
# 317042     19   44701457     CEACAM16.Mask2.0.005  Mask2.0.005          NaN
# 331914     21   42372764      TMPRSS3.Mask2.0.005  Mask2.0.005          NaN
# 334952     22   40125762       TNRC6B.Mask1.0.005  Mask1.0.005          NaN
# 333373     22   50548069      KLHDC7B.Mask1.0.005  Mask1.0.005          NaN
# 333377     22   50548069      KLHDC7B.Mask2.0.005  Mask2.0.005          NaN
#
#              TEST BETA_f3393 SE_f3393  LOG10P_f3393 A1FREQ_f2247  ...  \
# 4362    ADD-SKATO        NaN      NaN      3.801240          NaN  ...
# 6409    ADD-SKATO        NaN      NaN      8.861840          NaN  ...
# 2711    ADD-SKATO        NaN      NaN      2.953360          NaN  ...
# 216012  ADD-SKATO        NaN      NaN      0.072506          NaN  ...
# 216016  ADD-SKATO        NaN      NaN      0.119361          NaN  ...
# 224165  ADD-SKATO        NaN      NaN      4.087840          NaN  ...
# 236847  ADD-SKATO        NaN      NaN     40.839300          NaN  ...
# 237049  ADD-SKATO        NaN      NaN      7.950540          NaN  ...
# 243433  ADD-SKATO        NaN      NaN     23.407900          NaN  ...
# 243437  ADD-SKATO        NaN      NaN     17.518300          NaN  ...
# 240893  ADD-SKATO        NaN      NaN     12.876100          NaN  ...
# 240897  ADD-SKATO        NaN      NaN      5.698130          NaN  ...
# 251997  ADD-SKATO        NaN      NaN      5.373680          NaN  ...
# 252001  ADD-SKATO        NaN      NaN      8.787810          NaN  ...
# 255448  ADD-SKATO        NaN      NaN     11.675900          NaN  ...
# 274595  ADD-SKATO        NaN      NaN      4.832550          NaN  ...
# 278382  ADD-SKATO        NaN      NaN      9.166920          NaN  ...
# 278386  ADD-SKATO        NaN      NaN      8.820080          NaN  ...
# 278434  ADD-SKATO        NaN      NaN      9.545770          NaN  ...
# 278438  ADD-SKATO        NaN      NaN      8.828220          NaN  ...
# 287021  ADD-SKATO        NaN      NaN      7.821780          NaN  ...
# 293476  ADD-SKATO        NaN      NaN      5.109770          NaN  ...
# 313206  ADD-SKATO        NaN      NaN      1.829580          NaN  ...
# 305190  ADD-SKATO        NaN      NaN      8.975820          NaN  ...
# 321395  ADD-SKATO        NaN      NaN      6.858900          NaN  ...
# 317042  ADD-SKATO        NaN      NaN      8.331450          NaN  ...
# 331914  ADD-SKATO        NaN      NaN      6.377950          NaN  ...
# 334952  ADD-SKATO        NaN      NaN      5.704980          NaN  ...
# 333373  ADD-SKATO        NaN      NaN     14.220600          NaN  ...
# 333377  ADD-SKATO        NaN      NaN      6.563470          NaN  ...
#
#        SE_f2257 LOG10P_f2257  A1FREQ_f2247_f2257 BETA_f2247_f2257  \
# 4362        NaN     4.581300                 NaN              NaN
# 6409        NaN     4.180830                 NaN              NaN
# 2711        NaN     3.956720                 NaN              NaN
# 216012      NaN     1.615910                 NaN              NaN
# 216016      NaN     1.516890                 NaN              NaN
# 224165      NaN     5.408810                 NaN              NaN
# 236847      NaN    41.621800                 NaN              NaN
# 237049      NaN     3.542820                 NaN              NaN
# 243433      NaN     6.162540                 NaN              NaN
# 243437      NaN     5.863070                 NaN              NaN
# 240893      NaN     1.895240                 NaN              NaN
# 240897      NaN     0.541309                 NaN              NaN
# 251997      NaN     7.688180                 NaN              NaN
# 252001      NaN    12.997100                 NaN              NaN
# 255448      NaN     2.116980                 NaN              NaN
# 274595      NaN     4.284280                 NaN              NaN
# 278382      NaN    10.523800                 NaN              NaN
# 278386      NaN     5.428320                 NaN              NaN
# 278434      NaN    10.175200                 NaN              NaN
# 278438      NaN     5.289550                 NaN              NaN
# 287021      NaN     3.721970                 NaN              NaN
# 293476      NaN     5.277080                 NaN              NaN
# 313206      NaN     3.595750                 NaN              NaN
# 305190      NaN     2.250490                 NaN              NaN
# 321395      NaN     2.762420                 NaN              NaN
# 317042      NaN     6.931410                 NaN              NaN
# 331914      NaN     3.444470                 NaN              NaN
# 334952      NaN     1.578380                 NaN              NaN
# 333373      NaN    19.100600                 NaN              NaN
# 333377      NaN     9.970790                 NaN              NaN
#
#        SE_f2247_f2257 LOG10P_f2247_f2257       P_f3393       P_f2247  \
home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD_{allele}_output.csv'
    
    # Save the group to the CSV file
    group.to_csv(filename, index=False, header=True)

    print(f'Saved group with ALLELE1="{allele}" to {filename}')
# Out:
# Saved group with ALLELE1="Mask1.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD_Mask1.0.005_output.csv
# Saved group with ALLELE1="Mask2.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_skato_CADD_Mask2.0.005_output.csv

# %%
burden_result = merged_df.loc[(merged_df['TEST'] == 'ADD')  & ((merged_df['P_f3393'] <= 2.5e-06) | (merged_df['P_f2247'] <= 2.5e-06) | (merged_df['P_f2257'] <= 2.5e-06) | (merged_df['P_f2247_f2257'] <= 2.5e-06))]

# %%
burden_result['CHROM'] = burden_result['CHROM'].astype(int)
burden_result['GENPOS'] = burden_result['GENPOS'].astype(int)

# %%
burden_result = burden_result.sort_values(by=['CHROM', 'GENPOS'], ascending=[True, True])

# %%
burden_result
# Out:
#         CHROM     GENPOS                       ID          ALLELE1  \
# 5472        1   11648706        FBXO2.Mask2.0.005      Mask2.0.005
# 5475        1   11648706         FBXO2.Mask2.0.01       Mask2.0.01
# 8043        1   40784099        KCNQ4.Mask2.0.005      Mask2.0.005
# 8046        1   40784099         KCNQ4.Mask2.0.01       Mask2.0.01
# 221520      2  178432096        PRKRA.Mask1.0.005      Mask1.0.005
# 221523      2  178432096         PRKRA.Mask1.0.01       Mask1.0.01
# 231747      3  142664192         PLS1.Mask1.0.005      Mask1.0.005
# 231750      3  142664192          PLS1.Mask1.0.01       Mask1.0.01
# 247667      5     271691        PDCD6.Mask2.0.005      Mask2.0.005
# 247670      5     271691         PDCD6.Mask2.0.01       Mask2.0.01
# 247919      5  146339116   POU4F3.Mask1.singleton  Mask1.singleton
# 247920      5  146339116       POU4F3.Mask1.0.005      Mask1.0.005
# 247923      5  146339116        POU4F3.Mask1.0.01       Mask1.0.01
# 247924      5  146339116   POU4F3.Mask2.singleton  Mask2.singleton
# 255939      6   75817495     MYO6.Mask1.singleton  Mask1.singleton
# 255940      6   75817495         MYO6.Mask1.0.005      Mask1.0.005
# 255943      6   75817495          MYO6.Mask1.0.01       Mask1.0.01
# 255944      6   75817495     MYO6.Mask2.singleton  Mask2.singleton
# 255945      6   75817495         MYO6.Mask2.0.005      Mask2.0.005
# 255948      6   75817495          MYO6.Mask2.0.01       Mask2.0.01
# 252745      6  133274701     EYA4.Mask1.singleton  Mask1.singleton
# 252746      6  133274701         EYA4.Mask1.0.005      Mask1.0.005
# 252749      6  133274701          EYA4.Mask1.0.01       Mask1.0.01
# 266696      7  103374399      SLC26A5.Mask1.0.005      Mask1.0.005
# 266699      7  103374399       SLC26A5.Mask1.0.01       Mask1.0.01
# 266701      7  103374399      SLC26A5.Mask2.0.005      Mask2.0.005
# 266704      7  103374399       SLC26A5.Mask2.0.01       Mask2.0.01
# 271038      8  101492770    GRHL2.Mask1.singleton  Mask1.singleton
# 271039      8  101492770        GRHL2.Mask1.0.005      Mask1.0.005
# 271042      8  101492770         GRHL2.Mask1.0.01       Mask1.0.01
# 271043      8  101492770    GRHL2.Mask2.singleton  Mask2.singleton
# 299842     11  121045662  TBCEL-TECTA.Mask1.0.005      Mask1.0.005
# 299845     11  121045662   TBCEL-TECTA.Mask1.0.01       Mask1.0.01
# 299847     11  121045662  TBCEL-TECTA.Mask2.0.005      Mask2.0.005
# 299907     11  121102653        TECTA.Mask1.0.005      Mask1.0.005
# 299910     11  121102653         TECTA.Mask1.0.01       Mask1.0.01
# 299912     11  121102653        TECTA.Mask2.0.005      Mask2.0.005
# 310682     12   43795589         TWF1.Mask1.0.005      Mask1.0.005
# 310685     12   43795589          TWF1.Mask1.0.01       Mask1.0.01
# 312205     13   20188904          GJB2.Mask1.0.01       Mask1.0.01
# 312210     13   20188904          GJB2.Mask2.0.01       Mask2.0.01
# 333492     17   81510690    ACTG1.Mask2.singleton  Mask2.singleton
# 333493     17   81510690        ACTG1.Mask2.0.005      Mask2.0.005
# 333496     17   81510690         ACTG1.Mask2.0.01       Mask2.0.01
# 353854     19   14053608        PALM3.Mask1.0.005      Mask1.0.005
# 353857     19   14053608         PALM3.Mask1.0.01       Mask1.0.01
# 348386     19   44701457     CEACAM16.Mask2.0.005      Mask2.0.005
# 348389     19   44701457      CEACAM16.Mask2.0.01       Mask2.0.01
# 368904     22   50548069      KLHDC7B.Mask1.0.005      Mask1.0.005
# 368907     22   50548069       KLHDC7B.Mask1.0.01       Mask1.0.01
# 368909     22   50548069      KLHDC7B.Mask2.0.005      Mask2.0.005
# 368912     22   50548069       KLHDC7B.Mask2.0.01       Mask2.0.01
#
#        A1FREQ_f3393 TEST BETA_f3393   SE_f3393 LOG10P_f3393 A1FREQ_f2247  ...  \
# 5472      0.0015219  ADD   0.534273   0.130861      3.96663   0.00163018  ...
# 5475      0.0015219  ADD   0.534273   0.130861      3.96663   0.00163018  ...
# 8043     0.00329222  ADD   0.534572   0.089837      7.73459   0.00337572  ...
# 8046     0.00329222  ADD   0.534572   0.089837      7.73459   0.00337572  ...
# 221520    0.0133171  ADD  0.0229401  0.0511612     0.184507    0.0137063  ...
# 221523    0.0133171  ADD  0.0229401  0.0511612     0.184507    0.0137063  ...
# 231747  0.000413354  ADD   0.965209   0.226192      4.07867  0.000481162  ...
# 231750  0.000413354  ADD   0.965209   0.226192      4.07867  0.000481162  ...
# 247667   0.00341748  ADD   0.995987  0.0760999      32.5429   0.00383715  ...
# 247670   0.00341748  ADD   0.995987  0.0760999      32.5429   0.00383715  ...
# 247919  1.04382e-05  ADD    6.30714    1.72473      7.95054   1.0625e-05  ...
# 247920  1.04382e-05  ADD    6.30714    1.72473      7.95054   1.0625e-05  ...
# 247923  1.04382e-05  ADD    6.30714    1.72473      7.95054   1.0625e-05  ...
# 247924  0.000121084  ADD     2.3156   0.320975      10.0207  0.000100179  ...
# 255939  5.42788e-05  ADD    3.61081    0.47877      13.3489  4.70537e-05  ...
# 255940  0.000578278  ADD    1.57223   0.162917      17.1656  0.000591966  ...
# 255943  0.000578278  ADD    1.57223   0.162917      17.1656  0.000591966  ...
# 255944  0.000473896  ADD    1.43681   0.188216      11.0787  0.000367322  ...
# 255945   0.00750509  ADD   0.456442   0.061229      11.9394   0.00768645  ...
# 255948    0.0131438  ADD   0.325421  0.0482793      10.1429    0.0133405  ...
# 252745  3.75777e-05  ADD    3.31162   0.562007      7.49779    2.125e-05  ...
# 252746  0.000135697  ADD     2.3633    0.30719      11.4206  0.000133572  ...
# 252749  0.000135697  ADD     2.3633    0.30719      11.4206  0.000133572  ...
# 266696  0.000123171  ADD    1.71399   0.337689      5.37368  0.000180625  ...
# 266699  0.000123171  ADD    1.71399   0.337689      5.37368  0.000180625  ...
# 266701   0.00798317  ADD   0.374975  0.0603349      8.64642   0.00842413  ...
# 266704   0.00798317  ADD   0.374975  0.0603349      8.64642   0.00842413  ...
# 271038  2.71394e-05  ADD    4.33901   0.671747      11.6664  1.66965e-05  ...
# 271039  3.96653e-05  ADD    3.87147   0.522081      11.6759  3.64287e-05  ...
# 271042  3.96653e-05  ADD    3.87147   0.522081      11.6759  3.64287e-05  ...
# 271043  0.000198327  ADD    1.75114   0.264352      8.33981  0.000147232  ...
# 299842  0.000751553  ADD    1.11713   0.158916      9.89644  0.000877323  ...
# 299845  0.000751553  ADD    1.11713   0.158916      9.89644  0.000877323  ...
# 299847    0.0196155  ADD   0.190185  0.0419488      5.05513    0.0199902  ...
# 299907   0.00073694  ADD    1.14689   0.159532      10.2919  0.000857591  ...
# 299910   0.00073694  ADD    1.14689   0.159532      10.2919  0.000857591  ...
# 299912    0.0183108  ADD   0.203363  0.0431472      5.40375    0.0186651  ...
# 310682  7.30677e-05  ADD    2.45096   0.409007      7.82178  8.50002e-05  ...
# 310685  7.30677e-05  ADD    2.45096   0.409007      7.82178  8.50002e-05  ...
# 312205   0.00877438  ADD   0.217551  0.0610958      3.29681   0.00910413  ...
# 312210     0.016031  ADD   0.143268  0.0468069      2.58913    0.0165083  ...
# 333492  0.000121084  ADD    2.15162   0.345608      7.61749  0.000116875  ...
# 333493  0.000277657  ADD    1.60544   0.236353      8.97582  0.000280804  ...
# 333496  0.000277657  ADD    1.60544   0.236353      8.97582  0.000280804  ...
# 353854  8.35059e-05  ADD    2.42863   0.417924       6.8589  9.10716e-05  ...
# 353857  8.35059e-05  ADD    2.42863   0.417924       6.8589  9.10716e-05  ...
# 348386   0.00426298  ADD   0.453848   0.079959       7.2172   0.00452474  ...
# 348389   0.00426298  ADD   0.453848   0.079959       7.2172   0.00452474  ...
# 368904   0.00124841  ADD    1.02973   0.126653      13.0067   0.00150875  ...
# 368907   0.00124841  ADD    1.02973   0.126653      13.0067   0.00150875  ...
# 368909   0.00665542  ADD   0.334336  0.0661177      5.98235   0.00693814  ...
# 368912   0.00665542  ADD   0.334336  0.0661177      5.98235   0.00693814  ...
#
#          SE_f2257 LOG10P_f2257 A1FREQ_f2247_f2257 BETA_f2247_f2257  \
# 5472    0.0582332      4.85004         0.00162655         0.343168
#              P_f2257 P_f2247_f2257
# 5472    1.412407e-05  5.052659e-07
# 5475    1.412407e-05  5.052659e-07
# 8043    3.078364e-04  5.253636e-06
# 8046    3.078364e-04  5.253636e-06
# 221520  1.462682e-02  2.144223e-06
# 221523  1.462682e-02  2.144223e-06
# 231747  3.375592e-06  4.459437e-09
# 231750  3.375592e-06  4.459437e-09
# 247667  9.455837e-29  4.247173e-46
# 247670  9.455837e-29  4.247173e-46
# 247919  2.865365e-04  5.084755e-05
# 247920  2.865365e-04  5.084755e-05
# 247923  2.865365e-04  5.084755e-05
# 247924  3.483614e-03  1.584565e-04
# 255939  9.473272e-06  3.496150e-08
# 255940  1.671283e-05  3.240783e-07
# 255943  1.671283e-05  3.240783e-07
# 255944  2.943947e-03  3.669104e-05
# 255945  2.255018e-05  9.324166e-09
# 255948  4.925950e-05  8.776675e-08
# 252745  1.404999e-01  1.922074e-02
# 252746  7.289706e-03  1.268528e-03
# 252749  7.289706e-03  1.268528e-03
# 266696  2.822669e-08  3.393907e-12
# 266699  2.822669e-08  3.393907e-12
# 266701  3.789658e-13  5.040806e-19
# 266704  3.789658e-13  5.040806e-19
# 271038  5.186209e-03  1.592172e-04
# 271039  7.638710e-03  9.330609e-05
# 271042  7.638710e-03  9.330609e-05
# 271043  4.035525e-02  4.951537e-02
# 299842  3.415073e-12  4.963637e-15
# 299845  3.415073e-12  4.963637e-15
# 299847  9.767648e-04  2.192452e-08
# 299907  7.803690e-12  1.931524e-14
# 299910  7.803690e-12  1.931524e-14
# 299912  2.686767e-04  1.074385e-08
# 310682  1.617074e-04  2.045502e-06
# 310685  1.617074e-04  2.045502e-06
# 312205  4.673261e-08  8.646294e-09
# 312210  2.160827e-09  3.147024e-11
# 333492  2.349254e-03  5.165591e-05
# 333493  1.732527e-02  1.609756e-04
# 333496  1.732527e-02  1.609756e-04
# 353854  1.728144e-03  2.495054e-05
# 353857  1.728144e-03  2.495054e-05
# 348386  2.230848e-06  2.164213e-12
# 348389  2.230848e-06  2.164213e-12
# 368904  1.675329e-20  5.061742e-30
# 368907  1.675329e-20  5.061742e-30
# 368909  2.217992e-10  6.625215e-12
# 368912  2.217992e-10  6.625215e-12
#
# [52 rows x 25 columns]

# %%
for allele, group in burden_result.groupby('ALLELE1'):
    # Define the filename using the 'ALLELE1' name
    filename = f'/home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_{allele}_output.csv'
    
    # Save the group to the CSV file
    group.to_csv(filename, index=False, header=True)

    print(f'Saved group with ALLELE1="{allele}" to {filename}')
# Out:
# Saved group with ALLELE1="Mask1.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.0.005_output.csv
# Saved group with ALLELE1="Mask1.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.0.01_output.csv
# Saved group with ALLELE1="Mask1.singleton" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask1.singleton_output.csv
# Saved group with ALLELE1="Mask2.0.005" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.0.005_output.csv
# Saved group with ALLELE1="Mask2.0.01" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.0.01_output.csv
# Saved group with ALLELE1="Mask2.singleton" to /home/dmc2245/UKBiobank/RAP/results/autosomal/aggregate/ARHI_burden_CADD_Mask2.singleton_output.csv

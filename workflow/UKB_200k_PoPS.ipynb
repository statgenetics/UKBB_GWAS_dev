# %% [markdown]
# # PoPS scripts for ARHI

# %%
ls ~/UKBiobank/results/REGENIE_results/results_exome_data/090921_f2247_hearing_difficulty_200K/
# Out:
# 020422_gcta_cojo_chr1
# 020422_gcta_cojo_chr6
# 020422_gcta_slct_chr1
# 020422_gcta_slct_chr6
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie_1.loco
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.analysis_summary.html
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.analysis_summary.md
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.analysis_summary.pptx
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.analysis_summary.stderr
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.analysis_summary.stdout
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.log
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.manhattan_annotated.pdf
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.manhattan_annotated.png
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.manhattan_annotated.stderr
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.manhattan_annotated.stdout
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.manhattan.png
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.manhattan.stderr
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.manhattan.stdout
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.plot_data.rds
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie_pred.list
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie_pred.stderr
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie_pred.stdout
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.qq.png
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_counts.txt
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats.gz
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats.log
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats_original_columns.gz
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.top_snps.tsv
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2.regenie_covar
# 090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2.regenie_phenotype
# 091321_annotation
# cache

# %%
## 200k f2247
zcat ~/UKBiobank/results/REGENIE_results/results_exome_data/090921_f2247_hearing_difficulty_200K/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats.gz | head
# Out:
# CHR	POS	REF	ALT	SNP	BETA	SE	P
# 1	925862	G	A	chr1:925862:G:A	-2.33963	1.65071	0.0372940887505491
# 1	925881	G	A	chr1:925881:G:A	-0.11466	0.0622274	0.06538678739672098
# 1	925885	C	T	chr1:925885:C:T	-0.708778	0.836337	0.3967281343781035
# 1	925908	G	GGCTCT	chr1:925908:G:GGCTCT	0.579427	0.712331	0.4159747793049654
# 1	925912	C	G	chr1:925912:C:G	-0.253633	1.11535	0.8201113077139006
# 1	925913	T	G	chr1:925913:T:G	0.476509	1.04703	0.6490348247167547
# 1	925915	C	T	chr1:925915:C:T	0.809962	0.510483	0.11259056538701506
# 1	925917	C	T	chr1:925917:C:T	0.338906	0.991582	0.732514118985383
# 1	925928	G	A	chr1:925928:G:A	-0.405535	1.00479	0.6865054668429901
#
# gzip: stdout: Broken pipe

# %%
zcat ~/UKBiobank/results/REGENIE_results/results_exome_data/090921_f2247_hearing_difficulty_200K/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats_original_columns.gz | head
# Out:
# CHROM	GENPOS	ID	ALLELE0	ALLELE1	A1FREQ	N	TEST	BETA	SE	CHISQ	LOG10P	EXTRA
# 1	925862	chr1:925862:G:A	G	A	1.94324e-05	128651	ADD	-2.33963	1.65071	4.33692	1.42836
# 1	925881	chr1:925881:G:A	G	A	0.00458938	138254	ADD	-0.11466	0.0622274	3.39518	1.18451
# 1	925885	chr1:925885:C:T	C	T	2.87453e-05	139153	ADD	-0.708778	0.836337	0.718221	0.401507
# 1	925908	chr1:925908:G:GGCTCT	G	GGCTCT	3.5247e-05	141856	ADD	0.579427	0.712331	0.66166	0.380933
# 1	925912	chr1:925912:C:G	C	G	1.40838e-05	142007	ADD	-0.253633	1.11535	0.0517116	0.0861272
# 1	925913	chr1:925913:T:G	T	G	1.40838e-05	142007	ADD	0.476509	1.04703	0.207119	0.187732
# 1	925915	chr1:925915:C:T	C	T	6.33673e-05	142029	ADD	0.809962	0.510483	2.51748	0.948498
# 1	925917	chr1:925917:C:T	C	T	1.75987e-05	142056	ADD	0.338906	0.991582	0.116816	0.135184
# 1	925928	chr1:925928:G:A	G	A	1.75955e-05	142082	ADD	-0.405535	1.00479	0.162894	0.163356
#
# gzip: stdout: Broken pipe

# %%
import pandas as pd
df = pd.read_csv("~/UKBiobank/results/REGENIE_results/results_exome_data/090921_f2247_hearing_difficulty_200K/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats_original_columns.gz",header=0,sep="\t")
df
# Out:
#          CHROM    GENPOS                    ID ALLELE0 ALLELE1    A1FREQ  \
# 0            1    925862       chr1:925862:G:A       G       A  0.000019
# 1            1    925881       chr1:925881:G:A       G       A  0.004589
# 2            1    925885       chr1:925885:C:T       C       T  0.000029
# 3            1    925908  chr1:925908:G:GGCTCT       G  GGCTCT  0.000035
# 4            1    925912       chr1:925912:C:G       C       G  0.000014
# ...        ...       ...                   ...     ...     ...       ...
# 3732740     22  50782243    chr22:50782243:C:T       C       T  0.001023
# 3732741     22  50782271    chr22:50782271:C:T       C       T  0.000116
# 3732742     22  50782306    chr22:50782306:T:C       T       C  0.007858
# 3732743     22  50782329    chr22:50782329:G:A       G       A  0.000106
# 3732744     22  50782396    chr22:50782396:A:C       A       C  0.000015
#
#               N TEST      BETA        SE     CHISQ    LOG10P  EXTRA
# 0        128651  ADD -2.339630  1.650710  4.336920  1.428360    NaN
# 1        138254  ADD -0.114660  0.062227  3.395180  1.184510    NaN
# 2        139153  ADD -0.708778  0.836337  0.718221  0.401507    NaN
# 3        141856  ADD  0.579427  0.712331  0.661660  0.380933    NaN
# 4        142007  ADD -0.253633  1.115350  0.051712  0.086127    NaN
# ...         ...  ...       ...       ...       ...       ...    ...
# 3732740  141687  ADD -0.245217  0.129395  3.591420  1.235980    NaN
# 3732741  141694  ADD -0.483093  0.388400  1.547040  0.670455    NaN
# 3732742  129105  ADD  0.069862  0.049575  1.985870  0.799221    NaN
# 3732743  131815  ADD  0.161382  0.411172  0.154050  0.158206    NaN
# 3732744  136976  ADD  1.784520  1.113010  3.564600  1.228970    NaN
#
# [3732745 rows x 13 columns]

# %%
df = df[["ID","N","LOG10P"]] 
df["P"]= 10**(-df["LOG10P"])
df
# Out:
# /tmp/2255593.1.high_mem.q/ipykernel_34789/1288375671.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["P"]= 10**(-df["LOG10P"])
#                            ID       N    LOG10P         P
# 0             chr1:925862:G:A  128651  1.428360  0.037294
# 1             chr1:925881:G:A  138254  1.184510  0.065387
# 2             chr1:925885:C:T  139153  0.401507  0.396728
# 3        chr1:925908:G:GGCTCT  141856  0.380933  0.415975
# 4             chr1:925912:C:G  142007  0.086127  0.820111
# ...                       ...     ...       ...       ...
# 3732740    chr22:50782243:C:T  141687  1.235980  0.058079
# 3732741    chr22:50782271:C:T  141694  0.670455  0.213572
# 3732742    chr22:50782306:T:C  129105  0.799221  0.158774
# 3732743    chr22:50782329:G:A  131815  0.158206  0.694695
# 3732744    chr22:50782396:A:C  136976  1.228970  0.059024
#
# [3732745 rows x 4 columns]

# %%
df.to_csv("~/project/guangyou/20220218_UKB_pops/magma/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats.txt",index=False,sep="\t")

# %%
head /home/gl2776/UKBiobank/data/exome_files/project_VCF/072721_run/plink/ukb23156_c1.merged.filtered.bim
# Out:
# 1	chr1:925862:G:A	0	925862	A	G
# 1	chr1:925869:G:A	0	925869	A	G
# 1	chr1:925870:C:T	0	925870	T	C
# 1	chr1:925874:C:G	0	925874	G	C
# 1	chr1:925874:C:T	0	925874	T	C
# 1	chr1:925875:A:G	0	925875	G	A
# 1	chr1:925880:C:T	0	925880	T	C
# 1	chr1:925881:G:A	0	925881	A	G
# 1	chr1:925883:G:T	0	925883	T	G
# 1	chr1:925884:C:T	0	925884	T	C

# %%
head /mnt/mfs/statgen/guangyou/data/pops-MWE/NCBI38.gene.loc
# Out:
# 79501	1	69091	70008	+	OR4F5
# 100996442	1	141934	174394	-	LOC100996442
# 102725121	1	181045	184254	+	LOC102725121
# 102723897	1	184916	200470	-	LOC102723897
# 729759	1	450740	451678	-	OR4F29
# 105378947	1	586287	611297	-	LOC105378947
# 81399	1	685716	686654	-	OR4F16
# 105378580	1	803398	805130	+	LOC105378580
# 148398	1	925741	944581	+	SAMD11
# 26155	1	944203	959299	-	NOC2L

# %%
tpl_file=~/working/bioworkflows/admin/csg.yml
pops_sos=~/working/bioworkflows/PoPS/pops.ipynb
pops_sbatch_regenie=~/project/guangyou/20220218_UKB_pops/scripts/annoate_$(date +"%Y-%m-%d").sbatch
work_dir=~/project/guangyou/20220218_UKB_pops/magma
snp_loc=`echo /home/gl2776/UKBiobank/data/exome_files/project_VCF/072721_run/plink/ukb23156_c{1..22}.merged.filtered.bim`
gene_loc=/mnt/mfs/statgen/guangyou/data/pops-MWE/NCBI38.gene.loc
winup=0
windown=0
out=~/project/guangyou/20220218_UKB_pops/magma/annoate

pops_args="""annotate
    --cwd ${work_dir} \
    --snp_loc ${snp_loc}\
    --gene_loc ${gene_loc}\
    --container_pops /mnt/mfs/statgen/guangyou/containers/pops.sif\
    --out ${out}
"""
#--winup ${winup}\
#--windown ${windown}\
sos run ~/working/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $pops_sos \
    --to-script $pops_sbatch_regenie \
    --args "$pops_args"
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/pops_2022-02-18.sbatch
# INFO: Workflow csg (ID=wa727400d6bd90e45) is executed successfully with 1 completed step.

# %%
for i in {1..22}
do
tpl_file=~/working/bioworkflows/admin/csg.yml
pops_sos=~/working/bioworkflows/PoPS/pops.ipynb
pops_sbatch_regenie=~/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr${i}_$(date +"%Y-%m-%d").sbatch
work_dir=~/project/guangyou/20220218_UKB_pops/magma
bfile=/home/gl2776/UKBiobank/data/exome_files/project_VCF/072721_run/plink/ukb23156_c${i}.merged.filtered.bed
gene_loc=/mnt/mfs/statgen/guangyou/data/pops-MWE/NCBI38.gene.loc
gene_annot=~/project/guangyou/20220218_UKB_pops/magma/annoate.genes.annot
pval=~/project/guangyou/20220218_UKB_pops/magma/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats.txt
snpcol="ID"
pvalcol="P"
ncol="N"
out=~/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_chr${i}

pops_args="""magma
    --cwd ${work_dir} \
    --bfile ${bfile}\
    --gene_annot ${gene_annot}\
    --pval ${pval}\
    --snpcol ${snpcol}\
    --pvalcol ${pvalcol}\
    --ncol ${ncol}\
    --container_pops /mnt/mfs/statgen/guangyou/containers/pops.sif\
    --out ${out}
"""


sos run ~/working/UKBB_GWAS_dev/admin/Get_Job_Script.ipynb csg \
    --template-file $tpl_file \
    --workflow-file $pops_sos \
    --to-script $pops_sbatch_regenie \
    --args "$pops_args"
done
# Out:
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr1_2022-02-21.sbatch
# INFO: Workflow csg (ID=wf07bf0c4285b41f7) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr2_2022-02-21.sbatch
# INFO: Workflow csg (ID=w12c649329d11e254) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr3_2022-02-21.sbatch
# INFO: Workflow csg (ID=w833c8c22dc28d58a) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr4_2022-02-21.sbatch
# INFO: Workflow csg (ID=wa66c2dd0f48a1faf) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr5_2022-02-21.sbatch
# INFO: Workflow csg (ID=wd7e70c7e223db8e5) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr6_2022-02-21.sbatch
# INFO: Workflow csg (ID=w4097cc62d7dafe87) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr7_2022-02-21.sbatch
# INFO: Workflow csg (ID=wd6bec5533f162b24) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr8_2022-02-21.sbatch
# INFO: Workflow csg (ID=w7987823d8c11414b) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr9_2022-02-21.sbatch
# INFO: Workflow csg (ID=w8c17474e79ad290a) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr10_2022-02-21.sbatch
# INFO: Workflow csg (ID=w2bf8feeb3f02b5fa) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr11_2022-02-21.sbatch
# INFO: Workflow csg (ID=wae90684f766b4743) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr12_2022-02-21.sbatch
# INFO: Workflow csg (ID=wd8670d53d42770b6) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr13_2022-02-21.sbatch
# INFO: Workflow csg (ID=waeff6d54743d7c67) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr14_2022-02-21.sbatch
# INFO: Workflow csg (ID=w161c6c0f0d747ea8) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr15_2022-02-21.sbatch
# INFO: Workflow csg (ID=w1c31dd463a96cdb0) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr16_2022-02-21.sbatch
# INFO: Workflow csg (ID=w99d850bb01300ccb) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr17_2022-02-21.sbatch
# INFO: Workflow csg (ID=w6e53eb87fd6eef28) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr18_2022-02-21.sbatch
# INFO: Workflow csg (ID=w148b9d7004f12c56) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr19_2022-02-21.sbatch
# INFO: Workflow csg (ID=w3f7528e3ab7f62e6) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr20_2022-02-21.sbatch
# INFO: Workflow csg (ID=w9bb7a72b9821f38e) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr21_2022-02-21.sbatch
# INFO: Workflow csg (ID=w02b041c4cc8a126a) is executed successfully with 1 completed step.
# INFO: Running csg: Configuration for Columbia csg partition cluster
# INFO: csg is completed.
# INFO: csg output:   /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_f2247_chr22_2022-02-21.sbatch
# INFO: Workflow csg (ID=w6a4db4218015fb31) is executed successfully with 1 completed step.

# %%
# Combine the scripts
i=1
FILE=~/project/guangyou/20220218_UKB_pops/scripts/annotate_chr${i}_2022-02-22.sbatch
cat > ${FILE} <<- EOM
#!/bin/sh
#$ -l h_rt=36:00:00
#$ -l h_vmem=16G
#$ -N pops_2022-02-18
#$ -o /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/pops_2022-02-18-$JOB_ID.out
#$ -e /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/pops_2022-02-18-$JOB_ID.err  
#$ -j y
#$ -q csg.q
#$ -S /bin/bash
export PATH=$HOME/miniconda3/bin:$PATH
module load Singularity/3.5.3
sos run /home/gl2776/working/bioworkflows/PoPS/pops.ipynb \
    annotate\
    --cwd /home/gl2776/project/guangyou/20220218_UKB_pops/magma     --snp_loc /home/gl2776/UKBiobank/data/exome_files/project_VCF/072721_run/plink/ukb23156_c${i}.merged.filtered.bim   --gene_loc /mnt/mfs/statgen/guangyou/data/pops-MWE/NCBI38.gene.loc    --winup 0    --windown 0    --container_pops /mnt/mfs/statgen/guangyou/containers/pops.sif    --out /home/gl2776/project/guangyou/20220218_UKB_pops/magma/annoate \
    -c /home/gl2776/working/bioworkflows/admin/csg.yml \
    -q csg -s force \
    &> /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/annotate_chr${i}_2022-02-22.log
EOM

# %%
for index in range(1,23):
    text_file = open("/home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_chr"+str(index)+"_2022-02-22.sh", "w")
    script='''#!/bin/sh
#$ -l h_rt=10:00:00
#$ -l h_vmem=8G
#$ -N magma_chr%i_2022-02-22
#$ -o /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_chr%i_2022-02-22-$JOB_ID.out
#$ -e /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_chr%i_2022-02-22-$JOB_ID.err  
#$ -j y
#$ -q csg.q
#$ -S /bin/bash
export PATH=$HOME/miniconda3/bin:$PATH
module load Singularity/3.5.3
sos run /home/gl2776/working/bioworkflows/PoPS/pops.ipynb \
    annotate\
    --cwd /home/gl2776/project/guangyou/20220218_UKB_pops/magma     --snp_loc /home/gl2776/UKBiobank/data/exome_files/project_VCF/072721_run/plink/ukb23156_c%i.merged.filtered.bim   --gene_loc /mnt/mfs/statgen/guangyou/data/pops-MWE/NCBI38.gene.loc    --winup 0    --windown 0    --container_pops /mnt/mfs/statgen/guangyou/containers/pops.sif    --out /home/gl2776/project/guangyou/20220218_UKB_pops/magma/annotate_chr%i \
    -c /home/gl2776/working/bioworkflows/admin/csg.yml \
    -q csg -s force 
sos run /home/gl2776/working/bioworkflows/PoPS/pops.ipynb \
    magma\
    --cwd /home/gl2776/project/guangyou/20220218_UKB_pops/magma     --bfile /home/gl2776/UKBiobank/data/exome_files/project_VCF/072721_run/plink/ukb23156_c%i.merged.filtered.bed     --gene_annot /home/gl2776/project/guangyou/20220218_UKB_pops/magma/annotate_chr%i.genes.annot    --pval /home/gl2776/project/guangyou/20220218_UKB_pops/magma/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats.txt   --snpcol ID    --pvalcol P    --ncol N    --container_pops /mnt/mfs/statgen/guangyou/containers/pops.sif    --out /home/gl2776/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_chr%i \
    -c /home/gl2776/working/bioworkflows/admin/csg.yml \
    -q csg -s force
    '''%(index,index,index,index,index,index,index,index)
    n = text_file.write(script)
    text_file.close()

# %%
for i in {1..22}
do
qsub /home/gl2776/project/guangyou/20220218_UKB_pops/scripts/magma_chr${i}_2022-02-22.sh
done

# %% [markdown]
# ## Anaylsis of magama result

# %%
import pandas as pd
df = pd.read_csv("~/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_chr1.genes.out", header =0, delim_whitespace=True)
df
# Out:
#         GENE  CHR      START       STOP  NSNPS  NPARAM       N     ZSTAT  \
# 0     148398    1     925741     944581    542     495  141201 -1.986400
# 1      26155    1     944203     959299    544     464  141329 -0.294960
# 2     339451    1     959952     965720    520     448  141584  0.645990
# 3      84069    1     966497     975108    480     432  141861  0.532210
# 4      84808    1     975199     982117    339     288  141862  1.337300
# ...      ...  ...        ...        ...    ...     ...     ...       ...
# 1990  646627    1  248721230  248755792     35      29  141731 -0.545730
# 1991   80851    1  248810446  248825955    176     157  141613  1.118600
# 1992   79894    1  248838178  248849517    105      85  142101  0.029189
# 1993   55657    1  248850004  248860798    178     153  141662  0.515740
# 1994  267002    1  248872850  248919146    137     123  141873  1.773100
#
#              P
# 0     0.976510
# 1     0.615990
# 2     0.259140
# 3     0.297290
# 4     0.090564
# ...        ...
# 1990  0.707370
# 1991  0.131650
# 1992  0.488360
# 1993  0.303020
# 1994  0.038107
#
# [1995 rows x 9 columns]

# %%
result = pd.DataFrame(columns=df.columns)
for i in range(1,23):
    tmp = pd.read_csv("~/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_chr"+str(i)+".genes.out", header =0, delim_whitespace=True)
    result = pd.concat([result,tmp],axis=0,ignore_index=True)
result
# Out:
#             GENE CHR     START      STOP NSNPS NPARAM       N    ZSTAT  \
# 0         148398   1    925741    944581   542    495  141201 -1.98640
# 1          26155   1    944203    959299   544    464  141329 -0.29496
# 2         339451   1    959952    965720   520    448  141584  0.64599
# 3          84069   1    966497    975108   480    432  141861  0.53221
# 4          84808   1    975199    982117   339    288  141862  1.33730
# ...          ...  ..       ...       ...   ...    ...     ...      ...
# 18454  105373099  22  50606999  50610205    11      7  139333 -1.09810
# 18455        410  22  50622754  50628173   202    176  141806  1.53680
# 18456      85358  22  50674642  50733212   619    560  141489 -0.72667
# 18457         49  22  50738224  50745299   130    116  141483  0.26108
# 18458      11158  22  50767492  50783675   122    106  141034  1.00460
#
#               P
# 0      0.976510
# 1      0.615990
# 2      0.259140
# 3      0.297290
# 4      0.090564
# ...         ...
# 18454  0.863930
# 18455  0.062172
# 18456  0.766290
# 18457  0.397020
# 18458  0.157540
#
# [18459 rows x 9 columns]

# %%
result.to_csv("~/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_merged..genes.out",sep="\t",index=False)

# %%
geneloc = pd.read_csv("/mnt/mfs/statgen/guangyou/data/pops-MWE/NCBI38.gene.loc",header=None,sep="\t")
geneloc
# Out:
#                0  1         2         3  4             5
# 0          79501  1     69091     70008  +         OR4F5
# 1      100996442  1    141934    174394  -  LOC100996442
# 2      102725121  1    181045    184254  +  LOC102725121
# 3      102723897  1    184916    200470  -  LOC102723897
# 4         729759  1    450740    451678  -        OR4F29
# ...          ... ..       ...       ... ..           ...
# 20132     442867  Y  24618004  24639207  +         BPY2B
# 20133      57054  Y  24763069  24813505  -          DAZ3
# 20134      57135  Y  24833800  24907040  +          DAZ4
# 20135     442868  Y  25030901  25052104  -         BPY2C
# 20136       9085  Y  25622115  25634745  +          CDY1
#
# [20137 rows x 6 columns]

# %%
result = result.merge(geneloc[[0,5]],how = "inner",left_on = ["GENE"], right_on = [0])
result = result.drop([0], axis=1)
result = result.drop(["GENE"], axis=1)
result = result.rename(columns={5:"GENE"})
result
# Out:
#       CHR     START      STOP NSNPS NPARAM       N    ZSTAT         P  \
# 0       1    925741    944581   542    495  141201 -1.98640  0.976510
# 1       1    944203    959299   544    464  141329 -0.29496  0.615990
# 2       1    959952    965720   520    448  141584  0.64599  0.259140
# 3       1    966497    975108   480    432  141861  0.53221  0.297290
# 4       1    975199    982117   339    288  141862  1.33730  0.090564
# ...    ..       ...       ...   ...    ...     ...      ...       ...
# 18454  22  50606999  50610205    11      7  139333 -1.09810  0.863930
# 18455  22  50622754  50628173   202    176  141806  1.53680  0.062172
# 18456  22  50674642  50733212   619    560  141489 -0.72667  0.766290
# 18457  22  50738224  50745299   130    116  141483  0.26108  0.397020
# 18458  22  50767492  50783675   122    106  141034  1.00460  0.157540
#
#                GENE
# 0            SAMD11
# 1             NOC2L
# 2            KLHL17
# 3           PLEKHN1
# 4             PERM1
# ...             ...
# 18454  LOC105373099
# 18455          ARSA
# 18456        SHANK3
# 18457           ACR
# 18458        RABL2B
#
# [18459 rows x 9 columns]

# %%
result.to_csv("~/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_gene_level_p.txt",sep="\t",index=False)

# %%
result.sort_values("P").head(50)
# Out:
#       CHR      START       STOP NSNPS NPARAM       N   ZSTAT             P  \
# 5236    5   73626158   73941993   614    527  141042  5.5863  1.160000e-08
# 6349    6   43299741   43309614   211    187  141209  5.5259  1.639300e-08
# 5002    5     271621     314974   186    145  140766  5.0561  2.140000e-07
# 618     1   45694324   45750813   167    146  140851  4.8630  5.781000e-07
# 619     1   45786992   46036124   558    492  141418  4.3264  7.579000e-06
# 18275  22   37696988   37776556   833    688  141686  4.2972  8.649000e-06
# 11976  12  109388277  109449004   451    391  140706  4.0889  2.166800e-05
# 18449  22   50548033   50551023   144    130  141895  4.0834  2.219600e-05
# 11780  12   67269281   67314692   193    172  140508  4.0823  2.229900e-05
# 616     1   45627304   45688110   162    141  140831  4.0207  2.900700e-05
# 615     1   45620044   45624787   215    176  141905  3.9671  3.637200e-05
# 18289  22   38084883   38111304   321    285  140079  3.8693  5.456300e-05
# 614     1   45583988   45618906   247    212  140170  3.8232  6.586300e-05
# 5628    5  149141483  149260439   439    361  141037  3.7310  9.537800e-05
# 9607   10   93061264   93068697   237    202  142072  3.7266  9.704300e-05
# 620     1   46040140   46176495   232    206  141360  3.6935  1.106000e-04
# 8217    8  101492406  101678098   214    192  140523  3.6486  1.318300e-04
# 6707    6  133241335  133532120   291    258  141065  3.6482  1.320600e-04
# 10330  11   54603069   54603998   100     79  141769  3.6469  1.327200e-04
# 11979  12  109553715  109573553   159    136  140795  3.6322  1.405000e-04
# 7204    7   73536353   73557735   118    105  140857  3.6257  1.440700e-04
# 2994    2  214725646  214809711   205    163  141032  3.5726  1.767500e-04
# 7205    7   73568944   73578683   144    128  142059  3.5525  1.908300e-04
# 9514   10   73998078   74120160   348    295  141617  3.5186  2.169500e-04
# 6811    6  157981856  158099176   780    659  141483  3.5030  2.299800e-04
# 4319    4    2930560    2934868   312    269  141845  3.3991  3.379900e-04
# 6913    7    4799109    4883704  1008    762  141342  3.3138  4.601600e-04
# 7208    7   73680918   73683451    53     43  142060  3.2761  5.263200e-04
# 364     1   27005020   27012842   100     87  141984  3.2647  5.479900e-04
# 9173    9  137434364  137441662   230    205  141879  3.2439  5.896300e-04
# 13987  16   23835979   24220611   510    430  141179  3.2356  6.069300e-04
# 4548    4   69955256   69993629    71     61  140748  3.2293  6.204100e-04
# 6803    6  155090289  155257723   588    494  141240  3.2177  6.462100e-04
# 14581  17    4897769    4903128   346    291  141804  3.2085  6.671100e-04
# 16917  19   48029383   48044054   111     85  141161  3.2063  6.721700e-04
# 8742    9   93576627   93679587   501    381  140897  3.1842  7.257200e-04
# 11978  12  109477410  109543628   489    419  141040  3.1667  7.710200e-04
# 13881  16   11267857   11269303    60     49  141724  3.1658  7.731900e-04
# 12734  14   52004802   52069231   503    402  141266  3.1468  8.254200e-04
# 1554    1  181483311  181806784   592    519  141115  3.1427  8.369400e-04
# 18276  22   37729416   37747434   155    137  141571  3.1236  8.932100e-04
# 12829  14   67589306   67600300    93     75  141081  3.1198  9.048200e-04
# 3227    3    4303304    4317265   214    180  141850  3.1034  9.564300e-04
# 13655  15  100400395  100544786   145    128  140137  3.0866  1.012300e-03
# 17078  19   51991332   52008238   144    125  141839  3.0751  1.052300e-03
# 15200  17   45894382   46028334   338    204  141098  3.0557  1.122700e-03
# 11111  11  125063067  125090516   324    270  140826  3.0526  1.134200e-03
# 15587  17   81539885   81552403   371    326  141493  3.0494  1.146500e-03
# 17965  21   42371887   42396846   250    229  141605  3.0345  1.204700e-03
# 8143    8   85463902   85481492   117    101  140392  3.0283  1.229500e-03
#
#                GENE
# 5236       ARHGEF28
# 6349          CRIP3
# 5002          PDCD6
# 618             IPP
# 619           MAST2
# 18275        TRIOBP
# 11976         MYO1H
# 18449       KLHDC7B
# 11780         CAND1
# 616         GPBP1L1
# 615          CCDC17
# 18289      BAIAP2L2
# 614            NASP
# 5628         ABLIM3
# 9607        CYP26C1
# 620          PIK3R3
# 8217          GRHL2
# 6707           EYA4
# 10330        OR4C46
# 11979          MMAB
# 7204          BCL7B
# 2994          BARD1
# 7205           TBL2
# 9514            VCL
# 6811          SYNJ2
# 4319         MFSD10
# 6913          RADIL
# 7208        DNAJC30
# 364          FAM46B
# 9173         ENTPD8
# 13987         PRKCB
# 4548           CSN2
# 6803          TIAM2
# 14581         CHRNE
# 16917         CABP5
# 8742           PHF2
# 11978         UBE3B
# 13881          TNP2
# 12734          NID2
# 1554        CACNA1E
# 18276  LOC102724378
# 12829          PIGH
# 3227         SETMAR
# 13655         CERS3
# 17078        ZNF615
# 15200          MAPT
# 11111       SLC37A2
# 15587      C17orf70
# 17965       TMPRSS3
# 8143            CA2

# %%
0.05/18459
# Out:
# 2.7087057803781356e-06

# %%
result[result["GENE"]=="MYO6"]
# Out:
#      CHR     START      STOP NSNPS NPARAM       N    ZSTAT        P  GENE
# 6484   6  75749176  75919537   369    340  140000  0.50139  0.30805  MYO6

# %% [markdown]
# ## PoPS for f2247

# %% [markdown]
# ### feature merge and selection
#
# Use the features of brain tissues from https://github.com/FinucaneLab/gene_features/tree/master/features . It seems that the brain tissue is the only one relevent

# %%
import pandas as pd
import os 
# Gene expression features read in and merge
path="/home/gl2776/project/guangyou/20220218_UKB_pops/features/gene_features/features/"
folderlist = [f for f in os.listdir(path) if f.startswith("human_brain")]
subpath = folderlist[0]
files = [f for f in os.listdir(os.path.join(path,subpath)) if f.endswith(".txt.gz")]
files
# Out:
# ['projected_pcaloadings_clusters.txt.gz',
#  'projected_pcaloadings.txt.gz',
#  'projected_icaloadings.txt.gz',
#  'diffexprs_tstat_clusters.txt.gz',
#  'diffexprs_genes_clusters.txt.gz',
#  'diffexprs_down_genes_clusters.txt.gz',
#  'average_expression.txt.gz']

# %%
folderlist
# Out:
# ['human_brain_visualcortex',
#  'human_brain_frontalcortex',
#  'human_brain_cerebellarhem',
#  'human_brain4',
#  'human_brain3_prenatal',
#  'human_brain3_adult',
#  'human_brain2']

# %%
files = [f for f in os.listdir(os.path.join(path,subpath)) if f.endswith(".txt.gz")]
feature_df=pd.read_csv(os.path.join(path,subpath,files[0]),sep="\t",compression = "gzip")
feature_df=feature_df.add_prefix("%s_%s_"%(subpath,files[0].split(".")[0]))
feature_df=feature_df.rename(columns={"%s_%s_ENSG"%(subpath,files[0].split(".")[0]):"ENSG"})
for i in range(1,len(files)):
    x=pd.read_csv(os.path.join(path,subpath,files[i]),sep="\t",compression = "gzip")
    x=x.add_prefix("%s_%s_"%(subpath,files[0].split(".")[0]))
    x=x.rename(columns={"%s_%s_ENSG"%(subpath,files[0].split(".")[0]):"ENSG"})
    feature_df=feature_df.merge(x, on='ENSG', how='inner')
feature_df=feature_df.rename(columns={"ENSG":"ENSGID"})
feature_df
# Out:
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster11_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster8_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster1_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster13_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster24_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster4_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster14_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster18_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster7_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster27_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster12_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster23_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster19_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster29_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster26_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster3_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster5_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster25_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster21_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster16_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster22_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster9_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster28_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster17_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster15_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster2_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster10_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster20_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster30_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster6_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster11_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster8_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster1_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster13_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster24_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster4_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster14_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster18_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster7_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster27_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster12_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster23_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster19_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster29_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster26_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster3_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster5_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster30_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster25_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster21_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster16_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster22_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster9_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster28_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster17_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster15_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster10_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster2_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster20_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster6_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
#                 ENSGID  \
# 0      ENSG00000186092
# 1      ENSG00000235249
# 2      ENSG00000185097
# 3      ENSG00000187634
# 4      ENSG00000188976
# ...                ...
# 18378  ENSG00000165724
# 18379  ENSG00000197070
# 18380  ENSG00000203993
# 18381  ENSG00000181090
# 18382  ENSG00000148408
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_1  \
# 0                                           -1415.408377
# 1                                           -1415.408377
# 2                                           -1415.408377
# 3                                           -1516.307957
# 4                                            1932.841236
# ...                                                  ...
# 18378                                       -1203.336578
# 18379                                       -1415.408377
# 18380                                        -970.121390
# 18381                                        -289.714948
# 18382                                        5771.411633
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_2  \
# 0                                            -208.495831
# 1                                            -208.495831
# 2                                            -208.495831
# 3                                            -429.289142
# 4                                             107.223395
# ...                                                  ...
# 18378                                          -8.325020
# 18379                                        -208.495831
# 18380                                         -78.738569
# 18381                                         407.205997
# 18382                                         237.344635
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_3  \
# 0                                             -52.532710
# 1                                             -52.532710
# 2                                             -52.532710
# 3                                            -173.571643
# 4                                             152.477412
# ...                                                  ...
# 18378                                          66.995677
# 18379                                         -52.532710
# 18380                                        -182.579093
# 18381                                         133.120281
# 18382                                        -176.000892
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_4  \
# 0                                             126.568954
# 1                                             126.568954
# 2                                             126.568954
# 3                                              74.184554
# 4                                             -63.108860
# ...                                                  ...
# 18378                                         293.861971
# 18379                                         126.568954
# 18380                                         300.109003
# 18381                                        -186.987583
# 18382                                         224.015074
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_5  \
# 0                                             -98.044176
# 1                                             -98.044176
# 2                                             -98.044176
# 3                                              13.024309
# 4                                             185.466197
# ...                                                  ...
# 18378                                          -0.921706
# 18379                                         -98.044176
# 18380                                         -56.501196
# 18381                                          11.718665
# 18382                                        -149.203522
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_6  \
# 0                                               4.278081
# 1                                               4.278081
# 2                                               4.278081
# 3                                             170.650950
# 4                                             -82.776976
# ...                                                  ...
# 18378                                         -39.462031
# 18379                                           4.278081
# 18380                                        -213.255023
# 18381                                        -210.899607
# 18382                                         156.717018
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_7  \
# 0                                               7.176377
# 1                                               7.176377
# 2                                               7.176377
# 3                                             101.897474
# 4                                              27.926504
# ...                                                  ...
# 18378                                          38.021343
# 18379                                           7.176377
# 18380                                          45.497069
# 18381                                         138.611336
# 18382                                          60.068502
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_8  \
# 0                                              -9.941368
# 1                                              -9.941368
# 2                                              -9.941368
# 3                                            -114.510236
# 4                                             247.719743
# ...                                                  ...
# 18378                                          90.845317
# 18379                                          -9.941368
# 18380                                         -74.656820
# 18381                                        -227.522182
# 18382                                        -137.252054
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_ClusterExN2a_PC_9  \
# 0                                             -20.595100
# 1                                             -20.595100
# 2                                             -20.595100
# 3                                             -97.842915
# 4                                              -6.075643
# ...                                                  ...
# 18378                                         -36.967206
# 18379                                         -20.595100
# 18380                                         157.983324
# 18381                                        -220.369493
# 18382                                        -161.621941
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 18378  ...
# 18379  ...
# 18380  ...
# 18381  ...
# 18382  ...
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster22  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.018561
# 4                                               0.038903
# ...                                                  ...
# 18378                                          -0.009684
# 18379                                           0.000000
# 18380                                          -0.001262
# 18381                                          -0.043008
# 18382                                           0.368390
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster23  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                               0.168051
# ...                                                  ...
# 18378                                          -0.101123
# 18379                                           0.000000
# 18380                                           0.033347
# 18381                                           0.269764
# 18382                                           0.306888
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster24  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.025021
# 4                                               0.106217
# ...                                                  ...
# 18378                                           0.053191
# 18379                                           0.000000
# 18380                                           0.037542
# 18381                                           0.057349
# 18382                                           0.729629
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster25  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.800278
# 4                                              -0.120050
# ...                                                  ...
# 18378                                          -0.084158
# 18379                                           0.000000
# 18380                                          -0.106752
# 18381                                          -0.118122
# 18382                                          -1.050615
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster26  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.019409
# 4                                              -0.076598
# ...                                                  ...
# 18378                                           0.034617
# 18379                                           0.000000
# 18380                                           0.019703
# 18381                                          -0.139267
# 18382                                          -0.246131
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster27  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.006358
# 4                                               0.045286
# ...                                                  ...
# 18378                                          -0.068638
# 18379                                           0.000000
# 18380                                          -0.073622
# 18381                                          -0.183495
# 18382                                          -0.867136
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster28  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                              -0.125720
# ...                                                  ...
# 18378                                          -0.098025
# 18379                                           0.000000
# 18380                                          -0.016542
# 18381                                          -0.195513
# 18382                                          -1.205946
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster29  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.022437
# 4                                              -0.102892
# ...                                                  ...
# 18378                                           0.097588
# 18379                                           0.000000
# 18380                                           0.001874
# 18381                                          -0.018975
# 18382                                          -0.119212
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster30  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                               0.457230
# ...                                                  ...
# 18378                                           0.072081
# 18379                                           0.000000
# 18380                                           0.309783
# 18381                                           0.394791
# 18382                                           0.590808
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Allcells_y
# 0                                           0.000000e+00
# 1                                           0.000000e+00
# 2                                           0.000000e+00
# 3                                          -1.609493e-02
# 4                                          -2.352003e-17
# ...                                                  ...
# 18378                                       1.648738e-16
# 18379                                       0.000000e+00
# 18380                                       3.645872e-16
# 18381                                      -2.216545e-18
# 18382                                       6.791812e-15
#
# [18383 rows x 927 columns]

# %%
feature = feature_df[["ENSGID"]]
for subpath in folderlist[:6]:
    files = [f for f in os.listdir(os.path.join(path,subpath)) if f.endswith(".txt.gz")]
    feature_df=pd.read_csv(os.path.join(path,subpath,files[0]),sep="\t",compression = "gzip")
    feature_df=feature_df.add_prefix("%s_%s_"%(subpath,files[0].split(".")[0]))
    feature_df=feature_df.rename(columns={"%s_%s_ENSG"%(subpath,files[0].split(".")[0]):"ENSG"})
    for i in range(1,len(files)):
        x=pd.read_csv(os.path.join(path,subpath,files[i]),sep="\t",compression = "gzip")
        x=x.add_prefix("%s_%s_"%(subpath,files[0].split(".")[0]))
        x=x.rename(columns={"%s_%s_ENSG"%(subpath,files[0].split(".")[0]):"ENSG"})
        feature_df=feature_df.merge(x, on='ENSG', how='inner')
    feature_df=feature_df.rename(columns={"ENSG":"ENSGID"})
    feature=feature.merge(feature_df, on='ENSGID', how='inner')
feature
# Out:
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster13_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster5_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster2_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster16_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster4_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster7_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster3_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster11_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster10_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster6_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster15_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster8_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster12_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster14_x', 'human_brain_visualcortex_projected_pcaloadings_clusters_Cluster9_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster2_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster17_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster10_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster11_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster5_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster3_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster16_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster12_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster7_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster8_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster6_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster4_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster15_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster9_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster13_x', 'human_brain_frontalcortex_projected_pcaloadings_clusters_Cluster14_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster2_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster9_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster3_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster6_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster4_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster1_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster11_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster10_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster5_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster8_x', 'human_brain_cerebellarhem_projected_pcaloadings_clusters_Cluster7_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain4_projected_pcaloadings_clusters_Cluster9_x', 'human_brain4_projected_pcaloadings_clusters_Cluster13_x', 'human_brain4_projected_pcaloadings_clusters_Cluster6_x', 'human_brain4_projected_pcaloadings_clusters_Cluster2_x', 'human_brain4_projected_pcaloadings_clusters_Cluster11_x', 'human_brain4_projected_pcaloadings_clusters_Cluster12_x', 'human_brain4_projected_pcaloadings_clusters_Cluster10_x', 'human_brain4_projected_pcaloadings_clusters_Cluster4_x', 'human_brain4_projected_pcaloadings_clusters_Cluster15_x', 'human_brain4_projected_pcaloadings_clusters_Cluster8_x', 'human_brain4_projected_pcaloadings_clusters_Cluster3_x', 'human_brain4_projected_pcaloadings_clusters_Cluster5_x', 'human_brain4_projected_pcaloadings_clusters_Cluster14_x', 'human_brain4_projected_pcaloadings_clusters_Cluster1_x', 'human_brain4_projected_pcaloadings_clusters_Cluster16_x', 'human_brain4_projected_pcaloadings_clusters_Cluster7_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster11_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster2_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster6_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster8_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster10_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster12_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster1_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster3_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster9_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster5_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster4_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster7_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster11_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster9_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster2_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster6_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster8_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster10_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster12_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster3_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster4_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster5_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster1_x', 'human_brain3_prenatal_projected_pcaloadings_clusters_pre_def_Cluster7_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster11_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster8_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster1_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster13_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster24_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster4_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster14_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster18_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster7_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster27_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster12_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster23_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster19_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster29_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster26_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster3_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster5_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster25_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster21_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster16_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster22_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster9_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster28_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster17_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster15_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster2_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster10_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster20_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster30_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster6_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
# /home/gl2776/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster11_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster8_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster1_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster13_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster24_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster4_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster14_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster18_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster7_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster27_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster12_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster23_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster19_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster29_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster26_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster3_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster5_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster30_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster25_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster21_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster16_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster22_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster9_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster28_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster17_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster15_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster10_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster2_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster20_x', 'human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster6_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
#                 ENSGID  \
# 0      ENSG00000186092
# 1      ENSG00000235249
# 2      ENSG00000185097
# 3      ENSG00000187634
# 4      ENSG00000188976
# ...                ...
# 18378  ENSG00000165724
# 18379  ENSG00000197070
# 18380  ENSG00000203993
# 18381  ENSG00000181090
# 18382  ENSG00000148408
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_1  \
# 0                                           -1072.596606
# 1                                           -1072.596606
# 2                                           -1072.596606
# 3                                            -706.293546
# 4                                             600.682521
# ...                                                  ...
# 18378                                       -1072.596606
# 18379                                         294.262660
# 18380                                       -1072.596606
# 18381                                        1503.971864
# 18382                                        2100.828432
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_2  \
# 0                                            -124.067985
# 1                                            -124.067985
# 2                                            -124.067985
# 3                                             -97.677329
# 4                                             367.446447
# ...                                                  ...
# 18378                                        -124.067985
# 18379                                          -9.385824
# 18380                                        -124.067985
# 18381                                        -342.096939
# 18382                                       -1033.246577
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_3  \
# 0                                              42.190302
# 1                                              42.190302
# 2                                              42.190302
# 3                                              30.987533
# 4                                            -135.241222
# ...                                                  ...
# 18378                                          42.190302
# 18379                                        -199.080011
# 18380                                          42.190302
# 18381                                        -100.867854
# 18382                                        -451.114139
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_4  \
# 0                                             -45.145445
# 1                                             -45.145445
# 2                                             -45.145445
# 3                                             -31.558871
# 4                                              87.094821
# ...                                                  ...
# 18378                                         -45.145445
# 18379                                          48.521030
# 18380                                         -45.145445
# 18381                                          24.174575
# 18382                                         644.605304
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_5  \
# 0                                              -2.722995
# 1                                              -2.722995
# 2                                              -2.722995
# 3                                              -7.588708
# 4                                              59.437691
# ...                                                  ...
# 18378                                          -2.722995
# 18379                                         -80.311631
# 18380                                          -2.722995
# 18381                                           4.008464
# 18382                                          64.904144
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_6  \
# 0                                               9.336803
# 1                                               9.336803
# 2                                               9.336803
# 3                                              -0.557585
# 4                                            -137.824705
# ...                                                  ...
# 18378                                           9.336803
# 18379                                         -41.778395
# 18380                                           9.336803
# 18381                                          28.066271
# 18382                                         -99.131772
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_7  \
# 0                                               8.357140
# 1                                               8.357140
# 2                                               8.357140
# 3                                              26.757240
# 4                                              -1.602850
# ...                                                  ...
# 18378                                           8.357140
# 18379                                          41.652693
# 18380                                           8.357140
# 18381                                        -104.159476
# 18382                                         -44.965729
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_8  \
# 0                                               7.174701
# 1                                               7.174701
# 2                                               7.174701
# 3                                              -1.455205
# 4                                             -24.007959
# ...                                                  ...
# 18378                                           7.174701
# 18379                                           1.754435
# 18380                                           7.174701
# 18381                                         -31.719344
# 18382                                        -115.980322
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_9  \
# 0                                               6.274336
# 1                                               6.274336
# 2                                               6.274336
# 3                                             -11.373283
# 4                                              -7.338037
# ...                                                  ...
# 18378                                           6.274336
# 18379                                          34.973111
# 18380                                           6.274336
# 18381                                          90.405635
# 18382                                          31.241089
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 18378  ...
# 18379  ...
# 18380  ...
# 18381  ...
# 18382  ...
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster22  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.018561
# 4                                               0.038903
# ...                                                  ...
# 18378                                          -0.009684
# 18379                                           0.000000
# 18380                                          -0.001262
# 18381                                          -0.043008
# 18382                                           0.368390
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster23  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                               0.168051
# ...                                                  ...
# 18378                                          -0.101123
# 18379                                           0.000000
# 18380                                           0.033347
# 18381                                           0.269764
# 18382                                           0.306888
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster24  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.025021
# 4                                               0.106217
# ...                                                  ...
# 18378                                           0.053191
# 18379                                           0.000000
# 18380                                           0.037542
# 18381                                           0.057349
# 18382                                           0.729629
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster25  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.800278
# 4                                              -0.120050
# ...                                                  ...
# 18378                                          -0.084158
# 18379                                           0.000000
# 18380                                          -0.106752
# 18381                                          -0.118122
# 18382                                          -1.050615
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster26  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.019409
# 4                                              -0.076598
# ...                                                  ...
# 18378                                           0.034617
# 18379                                           0.000000
# 18380                                           0.019703
# 18381                                          -0.139267
# 18382                                          -0.246131
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster27  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.006358
# 4                                               0.045286
# ...                                                  ...
# 18378                                          -0.068638
# 18379                                           0.000000
# 18380                                          -0.073622
# 18381                                          -0.183495
# 18382                                          -0.867136
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster28  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                              -0.125720
# ...                                                  ...
# 18378                                          -0.098025
# 18379                                           0.000000
# 18380                                          -0.016542
# 18381                                          -0.195513
# 18382                                          -1.205946
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster29  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.022437
# 4                                              -0.102892
# ...                                                  ...
# 18378                                           0.097588
# 18379                                           0.000000
# 18380                                           0.001874
# 18381                                          -0.018975
# 18382                                          -0.119212
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster30  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                               0.457230
# ...                                                  ...
# 18378                                           0.072081
# 18379                                           0.000000
# 18380                                           0.309783
# 18381                                           0.394791
# 18382                                           0.590808
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Allcells_y
# 0                                           0.000000e+00
# 1                                           0.000000e+00
# 2                                           0.000000e+00
# 3                                          -1.609493e-02
# 4                                          -2.352003e-17
# ...                                                  ...
# 18378                                       1.648738e-16
# 18379                                       0.000000e+00
# 18380                                       3.645872e-16
# 18381                                      -2.216545e-18
# 18382                                       6.791812e-15
#
# [18383 rows x 2581 columns]

# %%
feature.to_csv("~/project/guangyou/20220218_UKB_pops/features/merged_features.txt",sep="\t",index=False)

# %%
import pandas as pd
feature = pd.read_csv("~/project/guangyou/20220218_UKB_pops/features/merged_features.txt",sep="\t",header=0)
feature
# Out:
# Traceback (most recent call last):
#   File "/home/gl2776/miniconda3/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/gl2776/miniconda3/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/gl2776/miniconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 15, in <module>
#     from ipykernel import kernelapp as app
#   File "/home/gl2776/miniconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 22, in <module>
#     from IPython.core.application import (
#   File "/home/gl2776/miniconda3/lib/python3.8/site-packages/IPython/__init__.py", line 52, in <module>
#     from .terminal.embed import embed
#   File "/home/gl2776/miniconda3/lib/python3.8/site-packages/IPython/terminal/embed.py", line 16, in <module>
#     from IPython.terminal.interactiveshell import TerminalInteractiveShell
#   File "/home/gl2776/miniconda3/lib/python3.8/site-packages/IPython/terminal/interactiveshell.py", line 31, in <module>
#     from prompt_toolkit.auto_suggest import AutoSuggestFromHistory
#   File "/home/gl2776/miniconda3/lib/python3.8/site-packages/prompt_toolkit/__init__.py", line 18, in <module>
#     from .shortcuts import PromptSession, print_formatted_text, prompt
#   File "/home/gl2776/miniconda3/lib/python3.8/site-packages/prompt_toolkit/shortcuts/__init__.py", line 10, in <module>
#     from .progress_bar import ProgressBar, ProgressBarCounter
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 874, in get_code
#   File "<frozen importlib._bootstrap_external>", line 973, in get_data
# KeyboardInterrupt
#                 ENSGID  \
# 0      ENSG00000186092
# 1      ENSG00000235249
# 2      ENSG00000185097
# 3      ENSG00000187634
# 4      ENSG00000188976
# ...                ...
# 18378  ENSG00000165724
# 18379  ENSG00000197070
# 18380  ENSG00000203993
# 18381  ENSG00000181090
# 18382  ENSG00000148408
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_1  \
# 0                                           -1072.596606
# 1                                           -1072.596606
# 2                                           -1072.596606
# 3                                            -706.293546
# 4                                             600.682521
# ...                                                  ...
# 18378                                       -1072.596606
# 18379                                         294.262660
# 18380                                       -1072.596606
# 18381                                        1503.971864
# 18382                                        2100.828432
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_2  \
# 0                                            -124.067985
# 1                                            -124.067985
# 2                                            -124.067985
# 3                                             -97.677329
# 4                                             367.446447
# ...                                                  ...
# 18378                                        -124.067985
# 18379                                          -9.385824
# 18380                                        -124.067985
# 18381                                        -342.096939
# 18382                                       -1033.246577
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_3  \
# 0                                              42.190302
# 1                                              42.190302
# 2                                              42.190302
# 3                                              30.987533
# 4                                            -135.241222
# ...                                                  ...
# 18378                                          42.190302
# 18379                                        -199.080011
# 18380                                          42.190302
# 18381                                        -100.867854
# 18382                                        -451.114139
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_4  \
# 0                                             -45.145445
# 1                                             -45.145445
# 2                                             -45.145445
# 3                                             -31.558871
# 4                                              87.094821
# ...                                                  ...
# 18378                                         -45.145445
# 18379                                          48.521030
# 18380                                         -45.145445
# 18381                                          24.174575
# 18382                                         644.605304
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_5  \
# 0                                              -2.722995
# 1                                              -2.722995
# 2                                              -2.722995
# 3                                              -7.588708
# 4                                              59.437691
# ...                                                  ...
# 18378                                          -2.722995
# 18379                                         -80.311631
# 18380                                          -2.722995
# 18381                                           4.008464
# 18382                                          64.904144
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_6  \
# 0                                               9.336803
# 1                                               9.336803
# 2                                               9.336803
# 3                                              -0.557585
# 4                                            -137.824705
# ...                                                  ...
# 18378                                           9.336803
# 18379                                         -41.778395
# 18380                                           9.336803
# 18381                                          28.066271
# 18382                                         -99.131772
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_7  \
# 0                                               8.357140
# 1                                               8.357140
# 2                                               8.357140
# 3                                              26.757240
# 4                                              -1.602850
# ...                                                  ...
# 18378                                           8.357140
# 18379                                          41.652693
# 18380                                           8.357140
# 18381                                        -104.159476
# 18382                                         -44.965729
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_8  \
# 0                                               7.174701
# 1                                               7.174701
# 2                                               7.174701
# 3                                              -1.455205
# 4                                             -24.007959
# ...                                                  ...
# 18378                                           7.174701
# 18379                                           1.754435
# 18380                                           7.174701
# 18381                                         -31.719344
# 18382                                        -115.980322
#
#        human_brain_visualcortex_projected_pcaloadings_clusters_Cluster0_PC_9  \
# 0                                               6.274336
# 1                                               6.274336
# 2                                               6.274336
# 3                                             -11.373283
# 4                                              -7.338037
# ...                                                  ...
# 18378                                           6.274336
# 18379                                          34.973111
# 18380                                           6.274336
# 18381                                          90.405635
# 18382                                          31.241089
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 18378  ...
# 18379  ...
# 18380  ...
# 18381  ...
# 18382  ...
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster22  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.018561
# 4                                               0.038903
# ...                                                  ...
# 18378                                          -0.009684
# 18379                                           0.000000
# 18380                                          -0.001262
# 18381                                          -0.043008
# 18382                                           0.368390
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster23  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                               0.168051
# ...                                                  ...
# 18378                                          -0.101123
# 18379                                           0.000000
# 18380                                           0.033347
# 18381                                           0.269764
# 18382                                           0.306888
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster24  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.025021
# 4                                               0.106217
# ...                                                  ...
# 18378                                           0.053191
# 18379                                           0.000000
# 18380                                           0.037542
# 18381                                           0.057349
# 18382                                           0.729629
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster25  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.800278
# 4                                              -0.120050
# ...                                                  ...
# 18378                                          -0.084158
# 18379                                           0.000000
# 18380                                          -0.106752
# 18381                                          -0.118122
# 18382                                          -1.050615
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster26  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.019409
# 4                                              -0.076598
# ...                                                  ...
# 18378                                           0.034617
# 18379                                           0.000000
# 18380                                           0.019703
# 18381                                          -0.139267
# 18382                                          -0.246131
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster27  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.006358
# 4                                               0.045286
# ...                                                  ...
# 18378                                          -0.068638
# 18379                                           0.000000
# 18380                                          -0.073622
# 18381                                          -0.183495
# 18382                                          -0.867136
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster28  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                              -0.125720
# ...                                                  ...
# 18378                                          -0.098025
# 18379                                           0.000000
# 18380                                          -0.016542
# 18381                                          -0.195513
# 18382                                          -1.205946
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster29  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.022437
# 4                                              -0.102892
# ...                                                  ...
# 18378                                           0.097588
# 18379                                           0.000000
# 18380                                           0.001874
# 18381                                          -0.018975
# 18382                                          -0.119212
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Cluster30  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -0.078347
# 4                                               0.457230
# ...                                                  ...
# 18378                                           0.072081
# 18379                                           0.000000
# 18380                                           0.309783
# 18381                                           0.394791
# 18382                                           0.590808
#
#        human_brain3_adult_projected_pcaloadings_clusters_pre_def_Allcells_y
# 0                                           0.000000e+00
# 1                                           0.000000e+00
# 2                                           0.000000e+00
# 3                                          -1.609493e-02
# 4                                          -2.352003e-17
# ...                                                  ...
# 18378                                       1.648738e-16
# 18379                                       0.000000e+00
# 18380                                       3.645872e-16
# 18381                                      -2.216545e-18
# 18382                                       6.791812e-15
#
# [18383 rows x 2581 columns]

# %%
feature["ENSGID"].dtypes
# Out:
# dtype('O')

# %%
feature["ENSGID"] = feature["ENSGID"].astype("string")
feature["ENSGID"].dtypes
# Out:
# string[python]

# %%
feature.to_csv("~/project/guangyou/20220218_UKB_pops/features/merged_features.txt",sep="\t",index=False)

# %%
sos run ~/working/bioworkflows/PoPS/pops.ipynb feature_selection\
    --cwd ~/project/guangyou/20220218_UKB_pops/pops\
    --features ~/project/guangyou/20220218_UKB_pops/features/merged_features.txt\
    --gene_results ~/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_merged..genes.out\
    --container_pops /mnt/mfs/statgen/guangyou/containers/pops.sif\
    --out ~/project/guangyou/20220218_UKB_pops/pops/UKBB_Hearing_difficulty_f2247

# %%
sos run ~/working/bioworkflows/PoPS/pops.ipynb predict_scores\
    --cwd ~/project/guangyou/20220218_UKB_pops/pops\
    --gene_loc ~/pops/data/gene_loc.txt\
    --gene_results ~/project/guangyou/20220218_UKB_pops/magma/UKBB_Hearing_difficulty_f2247_merged..genes.out\
    --features ~/project/guangyou/20220218_UKB_pops/features/merged_features.txt\
    --selected_features ~/project/guangyou/20220218_UKB_pops/pops/UKBB_Hearing_difficulty_f2247.features\
    --control_features ~/pops/data/control.features\
    --chromosome 1\
    --container_pops /mnt/mfs/statgen/guangyou/containers/pops.sif\
    --out ~/project/guangyou/20220218_UKB_pops/pops/UKBB_Hearing_difficulty_f2247
